# %% [markdown]
# Obs 0934201001 source 003. First X-ray detection. (263.53, -32.48, 2.25")
#
# No SIMBAD
#
# ALSO XMM
# + 0886040201 src 20
# + 0934201001 src 19
#
# Vizier - Gaia 4054631272700204672 4.0"
# + Parallax 1.0285. Distance 972 pc. (501 pc spec)
# + Teff 3520K
# + Rstar 0.412
# + Mstar unknown
#
# Vizier - Gaia 4054631272700205184 4.9"
# + Parallax 1.2783. Distance 782 pc. (301 pc spec)
# + Teff unknown
# + Rstar unknown
# + Mstar unknown

# %%
# %load_ext wurlitzer
import numpy as np
import os
import stingray as st
import matplotlib.pyplot as plt
from astropy.io import fits
from xspec import *
plt.rcParams['figure.figsize'] = [15, 8]

lc = fits.open('0934200401_003/0934200401_M13_dt5.lc')
bkg = fits.open('0934200401_003/0934200401_M13_dt5_bkg.lc')
full_gti = []
for j in lc[2].data:
    full_gti.append([j[0],j[1]])
soft = fits.open('0934200401_003/0934200401_M13_dt5_0.2-2keV.lc')
sbkg = fits.open('0934200401_003/0934200401_M13_dt5_0.2-2keV_bkg.lc')
soft_gti = []
for j in soft[2].data:
    soft_gti.append([j[0],j[1]])
hard = fits.open('0934200401_003/0934200401_M13_dt5_2-12keV.lc')
hbkg = fits.open('0934200401_003/0934200401_M13_dt5_2-12keV_bkg.lc')
hard_gti = []
for j in hard[2].data:
    hard_gti.append([j[0],j[1]])
    
lc2 = fits.open('0934200401_003/0934200401_M23_dt5.lc')
bkg2 = fits.open('0934200401_003/0934200401_M23_dt5_bkg.lc')
full_gti2 = []
for j in lc2[2].data:
    full_gti2.append([j[0],j[1]])
soft2 = fits.open('0934200401_003/0934200401_M23_dt5_0.2-2keV.lc')
sbkg2 = fits.open('0934200401_003/0934200401_M23_dt5_0.2-2keV_bkg.lc')
soft_gti2 = []
for j in soft2[2].data:
    soft_gti2.append([j[0],j[1]])
hard2 = fits.open('0934200401_003/0934200401_M23_dt5_2-12keV.lc')
hbkg2 = fits.open('0934200401_003/0934200401_M23_dt5_2-12keV_bkg.lc')
hard_gti2 = []
for j in hard2[2].data:
    hard_gti2.append([j[0],j[1]])

# %%
full_lc = st.Lightcurve(lc[1].data.field('TIME'),lc[1].data.field('RATE'),err=lc[1].data.field('ERROR'),gti=full_gti,input_counts=False)
full_bkg = st.Lightcurve(bkg[1].data.field('TIME'),bkg[1].data.field('RATE'),err=bkg[1].data.field('ERROR'),gti=full_gti,input_counts=False)

soft_lc = st.Lightcurve(soft[1].data.field('TIME'),soft[1].data.field('RATE'),err=soft[1].data.field('ERROR'),gti=soft_gti,input_counts=False)
soft_bkg = st.Lightcurve(sbkg[1].data.field('TIME'),sbkg[1].data.field('RATE'),err=sbkg[1].data.field('ERROR'),gti=soft_gti,input_counts=False)

hard_lc = st.Lightcurve(hard[1].data.field('TIME'),hard[1].data.field('RATE'),err=hard[1].data.field('ERROR'),gti=hard_gti,input_counts=False)
hard_bkg = st.Lightcurve(hbkg[1].data.field('TIME'),hbkg[1].data.field('RATE'),err=hbkg[1].data.field('ERROR'),gti=hard_gti,input_counts=False)

full_lc.apply_gtis()
full_bkg.apply_gtis()
soft_lc.apply_gtis()
soft_bkg.apply_gtis()
hard_lc.apply_gtis()
hard_bkg.apply_gtis()

full_lc2 = st.Lightcurve(lc2[1].data.field('TIME'),lc2[1].data.field('RATE'),err=lc2[1].data.field('ERROR'),gti=full_gti2,input_counts=False)
full_bkg2 = st.Lightcurve(bkg2[1].data.field('TIME'),bkg2[1].data.field('RATE'),err=bkg2[1].data.field('ERROR'),gti=full_gti2,input_counts=False)

soft_lc2 = st.Lightcurve(soft2[1].data.field('TIME'),soft2[1].data.field('RATE'),err=soft2[1].data.field('ERROR'),gti=soft_gti2,input_counts=False)
soft_bkg2 = st.Lightcurve(sbkg2[1].data.field('TIME'),sbkg2[1].data.field('RATE'),err=sbkg2[1].data.field('ERROR'),gti=soft_gti2,input_counts=False)

hard_lc2 = st.Lightcurve(hard2[1].data.field('TIME'),hard2[1].data.field('RATE'),err=hard2[1].data.field('ERROR'),gti=hard_gti2,input_counts=False)
hard_bkg2 = st.Lightcurve(hbkg2[1].data.field('TIME'),hbkg2[1].data.field('RATE'),err=hbkg2[1].data.field('ERROR'),gti=hard_gti2,input_counts=False)

full_lc2.apply_gtis()
full_bkg2.apply_gtis()
soft_lc2.apply_gtis()
soft_bkg2.apply_gtis()
hard_lc2.apply_gtis()
hard_bkg2.apply_gtis()
# Out:
# /home/rwebbe/.local/lib/python3.8/site-packages/stingray/lightcurve.py:516: UserWarning: There are non-finite points in the data, but they are outside GTIs.
#   warnings.warn("There are non-finite points in the data, but they are outside GTIs. ")
# /home/rwebbe/.local/lib/python3.8/site-packages/stingray/lightcurve.py:516: UserWarning: There are non-finite points in the data, but they are outside GTIs.
#   warnings.warn("There are non-finite points in the data, but they are outside GTIs. ")

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(soft_lc.time,soft_lc.countrate,color='r')
plt.plot(hard_lc.time,hard_lc.countrate,color='b')

# %%
plt.plot(full_lc2.time,full_lc2.countrate,color='k')
plt.plot(soft_lc2.time,soft_lc2.countrate,color='r')
plt.plot(hard_lc2.time,hard_lc2.countrate,color='b')

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='r')
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='b')

# %%
plt.plot(full_lc2.rebin(50).time,full_lc2.rebin(50).countrate,color='k')
plt.plot(soft_lc2.rebin(50).time,soft_lc2.rebin(50).countrate,color='r')
plt.plot(hard_lc2.rebin(50).time,hard_lc2.rebin(50).countrate,color='b')

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='r')
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='b')

# %%
plt.plot(full_lc2.rebin(250).time,full_lc2.rebin(250).countrate,color='k')
plt.plot(soft_lc2.rebin(250).time,soft_lc2.rebin(250).countrate,color='r')
plt.plot(hard_lc2.rebin(250).time,hard_lc2.rebin(250).countrate,color='b')

# %%
os.chdir("0934200401_003/")
spec = Spectrum("0934200401_MOS3grpspec.fits")
# Out:
# ***Warning: Detected response matrix energy bin value = 0 (or neg).
#      XSPEC will instead use small finite value (response file will not be altered).
# Warning: RMF FILTER keyword (UNDEFINED) is not consistent with that in spectrum (Medium)
#
# 1 spectrum  in use
#
# Spectral Data File: 0934200401_MOS3grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  1.134e-02 +/- 1.344e-03 (82.7 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-7
#   Telescope: XMM Instrument: EPIC  Channel Type: PI
#   Exposure Time: 7883 sec
#  Using fit statistic: chi
#  Using Background File                0934200401_MOS3spec_bkg.fits
#   Background Exposure Time: 7883 sec
#  Using Response (RMF) File            0934200401_MOS3spec.rmf for Source 1
# ***Error: Requested ARF extension not found in 0934200401_MOS3spec.arf

# %%
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.000005 0.01")
Plot("data")

# %%
mo1 = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              2.223034e+11     using 7 bins.
#
# Test statistic : Chi-Squared              2.223034e+11     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 4 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 15.5697      1.43298      -1      0.474178       2.78118   1.12864e-05
# 9.56803      262590       -1      0.197547       2.25076   8.90811e-06
# 7.48462      39885.1      -1      0.426429       1.92684   7.38945e-06
# 6.6208       14039.8      -2      0.914239       1.32333   4.48342e-06
# 5.51739      418121       -3       1.03406       1.44653   5.55450e-06
# 5.47841      74536.1      -4       1.12371       1.40200   5.54432e-06
# 5.47767      171.945      -5       1.11751       1.40955   5.57326e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  4.3687E-13| -0.0000  -0.0000   1.0000
#  3.9270E-02| -0.2759  -0.9612  -0.0000
#  7.5884E-01|  0.9612  -0.2759  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    7.041e-01  -1.908e-01  -1.185e-07
#   -1.908e-01   9.403e-02   2.317e-07
#   -1.185e-07   2.317e-07   1.398e-12
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.11751      +/-  0.839092
#    2    2   bbody      kT         keV      1.40955      +/-  0.306643
#    3    2   bbody      norm                5.57326E-06  +/-  1.18230E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    5.48     using 7 bins.
#
# Test statistic : Chi-Squared                    5.48     using 7 bins.
#  Null hypothesis probability of 2.42e-01 with 4 degrees of freedom
#  Model Flux 5.5241e-05 photons (3.9733e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
mo2 = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              6.205021e+10     using 7 bins.
#
# Test statistic : Chi-Squared              6.205021e+10     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 4 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 7.55669      2.61822      -3       1.60718       1.02395   4.02422e-05
# 7.55637      4006.01      -4       2.24562       1.30389   5.98271e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  2.4054E-11| -0.0000  -0.0000   1.0000
#  6.1452E-02|  0.4657  -0.8849  -0.0000
#  1.2763E+00|  0.8849   0.4657   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.013e+00   5.007e-01   3.331e-05
#    5.007e-01   3.249e-01   2.015e-05
#    3.331e-05   2.015e-05   1.295e-09
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    2.24562      +/-  1.00640
#    2    2   powerlaw   PhoIndex            1.30389      +/-  0.570030
#    3    2   powerlaw   norm                5.98271E-05  +/-  3.59893E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    7.56     using 7 bins.
#
# Test statistic : Chi-Squared                    7.56     using 7 bins.
#  Null hypothesis probability of 1.09e-01 with 4 degrees of freedom
#  Model Flux 5.8531e-05 photons (4.9958e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
flux = 1.2275*10**-13
d_pc = 972
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')

d_pc = 782
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')
# Out:
# Luminosity is: 1.3914924475983657e+31 erg s^-1
# Luminosity is: 9.006619793785066e+30 erg s^-1

# %%
d_pc = 7500
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')
# Out:
# Luminosity is: 8.284586760297387e+32 erg s^-1

# %%
g_mag = 18.355202
opt_flux = (10**(0.4*(-26.7 - g_mag))) * (3.828 * 10 ** 33) / (4*np.pi*(1.496*10**13)**2)
print('Optical flux: '+str(opt_flux))
opt_x_ratio = flux / opt_flux
print('The x-ray/optical flux ratio is: '+str(opt_x_ratio))
# Out:
# Optical flux: 1.2936538282153006e-12
# The x-ray/optical flux ratio is: 0.09488628048922755
