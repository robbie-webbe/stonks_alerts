# %% [markdown]
# Obs 0916811401 source 017. Not first X-ray detection. (262.7923, -34.6786, 2.06")
#
# No SIMBAD
#
# Not detected as source in XMM 0916811501.
#
# Vizier - Gaia 5975134867009402112 0.5"
# + Parallax 0.971. Distance 1030 pc.
# + Teff 6710K
# + Rstar 1.01 (1.19 spec)
# + Mstar 0.4
# + GAIA variable eclipsing flag
#
# Vizier - Gaia 5975134867009195136 6.2"
# + Parallax 0.452. Distance 2210 pc.
# + Teff 7180K
# + Rstar 7.06 (5.68 spec)
# + Mstar 2.77

# %%
# %load_ext wurlitzer
import numpy as np
import os
import stingray as st
import matplotlib.pyplot as plt
from astropy.io import fits
from xspec import *
plt.rcParams['figure.figsize'] = [15, 8]

lc = fits.open('0916811401_017/0916811401_PN17_dt1.lc')
bkg = fits.open('0916811401_017/0916811401_PN17_dt1_bkg.lc')
full_gti = []
for j in lc[2].data:
    full_gti.append([j[0],j[1]])
soft = fits.open('0916811401_017/0916811401_PN17_dt1_0.2-2keV.lc')
sbkg = fits.open('0916811401_017/0916811401_PN17_dt1_0.2-2keV_bkg.lc')
soft_gti = []
for j in soft[2].data:
    soft_gti.append([j[0],j[1]])
hard = fits.open('0916811401_017/0916811401_PN17_dt1_2-12keV.lc')
hbkg = fits.open('0916811401_017/0916811401_PN17_dt1_2-12keV_bkg.lc')
hard_gti = []
for j in hard[2].data:
    hard_gti.append([j[0],j[1]])

# %%
full_lc = st.Lightcurve(lc[1].data.field('TIME'),lc[1].data.field('RATE'),err=lc[1].data.field('ERROR'),gti=full_gti,input_counts=False)
full_bkg = st.Lightcurve(bkg[1].data.field('TIME'),bkg[1].data.field('RATE'),err=bkg[1].data.field('ERROR'),gti=full_gti,input_counts=False)

soft_lc = st.Lightcurve(soft[1].data.field('TIME'),soft[1].data.field('RATE'),err=soft[1].data.field('ERROR'),gti=soft_gti,input_counts=False)
soft_bkg = st.Lightcurve(sbkg[1].data.field('TIME'),sbkg[1].data.field('RATE'),err=sbkg[1].data.field('ERROR'),gti=soft_gti,input_counts=False)

hard_lc = st.Lightcurve(hard[1].data.field('TIME'),hard[1].data.field('RATE'),err=hard[1].data.field('ERROR'),gti=hard_gti,input_counts=False)
hard_bkg = st.Lightcurve(hbkg[1].data.field('TIME'),hbkg[1].data.field('RATE'),err=hbkg[1].data.field('ERROR'),gti=hard_gti,input_counts=False)

full_lc.apply_gtis()
full_bkg.apply_gtis()
soft_lc.apply_gtis()
soft_bkg.apply_gtis()
hard_lc.apply_gtis()
hard_bkg.apply_gtis()
# Out:
# /home/rwebbe/.local/lib/python3.8/site-packages/stingray/lightcurve.py:516: UserWarning: There are non-finite points in the data, but they are outside GTIs.
#   warnings.warn("There are non-finite points in the data, but they are outside GTIs. ")
# /home/rwebbe/.local/lib/python3.8/site-packages/stingray/lightcurve.py:516: UserWarning: There are non-finite points in the data, but they are outside GTIs.
#   warnings.warn("There are non-finite points in the data, but they are outside GTIs. ")

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(soft_lc.time,soft_lc.countrate,color='r')
plt.plot(hard_lc.time,hard_lc.countrate,color='b')

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(full_bkg.time,full_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.time,soft_lc.countrate,color='k')
plt.plot(soft_bkg.time,soft_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.time,hard_lc.countrate,color='k')
plt.plot(hard_bkg.time,hard_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='r')
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='b')

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(full_bkg.rebin(50).time,full_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='k')
plt.plot(soft_bkg.rebin(50).time,soft_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='k')
plt.plot(hard_bkg.rebin(50).time,hard_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='r')
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='b')

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(full_bkg.rebin(250).time,full_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='k')
plt.plot(soft_bkg.rebin(250).time,soft_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='k')
plt.plot(hard_bkg.rebin(250).time,hard_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
os.chdir("0916811401_017")
spec = Spectrum("0916811401_PN17grpspec.fits")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0916811401_PN17grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  7.278e-03 +/- 2.496e-03 (29.1 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-6
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 6870 sec
#  Using fit statistic: chi
#  Using Background File                0916811401_PN17spec_bkg.fits
#   Background Exposure Time: 6870 sec
#  Using Response (RMF) File            0916811401_PN17spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0916811401_PN17spec.arf

# %%
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot("data")

# %%
mo1 = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              7.869638e+10     using 6 bins.
#
# Test statistic : Chi-Squared              7.869638e+10     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 10.2762      0.187104      0     0.0448323       3.07468   4.40023e-06
# 9.86878      66834.1       0     0.0157743       2.89194   4.21025e-06
# 9.5272       71349.6       0    0.00460985       2.72518   4.00482e-06
# 9.25903      74179.1       0    0.00229576       2.57915   3.77559e-06
# 9.01466      77611         0   0.000254504       2.44861   3.53621e-06
# 8.7867       83307.1       0   2.46475e-05       2.32753   3.30267e-06
# 8.55881      90293.4       0   1.15468e-05       2.21346   3.08130e-06
# 8.32615      98473.6       0   5.56210e-06       2.10531   2.87533e-06
# 8.0894       107516        0   9.52555e-08       2.00302   2.68538e-06
# 7.85079      117238        0   1.72607e-08       1.90678   2.51121e-06
# Number of trials exceeded: continue fitting? 7.61304      127505        0   8.35868e-09       1.81670   2.35216e-06
# 7.37901      138201        0   2.24698e-10       1.73285   2.20733e-06
# 7.15127      149225        0   1.08405e-10       1.65512   2.07572e-06
# 6.93195      160484        0   1.77720e-12       1.58333   1.95625e-06
# 6.72269      171903        0   2.45613e-13       1.51717   1.84788e-06
# 6.52499      183422        0   6.92485e-14       1.45634   1.74932e-06
# 6.33671      195157        0   2.83129e-14       1.40005   1.66019e-06
# 6.16214      206432        0   9.30087e-15       1.34865   1.57932e-06
# 5.99538      217896        0   4.79330e-16       1.30084   1.50651e-06
# 5.80763      228125        0   2.35882e-16       1.25428   1.45339e-06
# Number of trials exceeded: continue fitting? 5.63821      222255        0   2.43466e-18       1.20942   1.39319e-06
# 4.95208      223748       -1   1.18993e-18       1.00566   1.07548e-06
# 4.28646      311527       -2   5.04140e-20      0.773164   7.49531e-07
# 3.90354      489093       -3   1.77430e-20      0.633831   6.64171e-07
# 3.89472      2081.58      -4   8.37744e-21      0.617614   6.37938e-07
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  4.4264E-14| -0.0000  -0.0000   1.0000
#  7.2057E-02| -0.0004  -1.0000  -0.0000
#  1.7322E+02|  1.0000  -0.0004  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.732e+02  -7.083e-02  -6.100e-08
#   -7.083e-02   7.209e-02   9.787e-08
#   -6.100e-08   9.787e-08   1.771e-13
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    8.37744E-21  +/-  13.1614
#    2    2   bbody      kT         keV      0.617614     +/-  0.268489
#    3    2   bbody      norm                6.37938E-07  +/-  4.20889E-07
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    3.89     using 6 bins.
#
# Test statistic : Chi-Squared                    3.89     using 6 bins.
#  Null hypothesis probability of 2.73e-01 with 3 degrees of freedom
#  Model Flux 1.9605e-05 photons (5.3366e-14 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
mo2 = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              2.530853e+10     using 6 bins.
#
# Test statistic : Chi-Squared              2.530853e+10     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 5.36924      0.608358     -3      0.256888       1.22988   1.03471e-05
# 3.16861      59560.8      -1     0.0621289       1.24382   9.75316e-06
# 3.11219      39895.5
#    -2     0.0142431      0.919610   7.79330e-06
# 3.09118      53310.4      -1    0.00623207      0.884019   7.42323e-06
# 2.8483       61602         0    0.00252742      0.925627   7.74974e-06
# 2.73691      47862.9       0   0.000935967      0.949327   7.90872e-06
# 2.6887       41180.1       0   0.000133831      0.957301   7.94909e-06
# 2.66483      39372.6       0   5.93732e-05      0.965238   8.00929e-06
# 2.64493      37058.3       0   2.32292e-05      0.972824   8.06536e-06
# 2.62787      34921.1       0   5.66581e-06      0.980054   8.11765e-06
# Number of trials exceeded: continue fitting? 2.61325      32934.1       0   1.39092e-06      0.986926   8.16641e-06
# 2.60035      31083.5       0   3.48430e-07      0.993442   8.21190e-06
# 2.5889       29353.9       0   9.38141e-08      0.999611   8.25430e-06
# 2.5787       27736.5       0   3.15406e-08       1.00544   8.29382e-06
# 2.56963      26224.1       0   1.03918e-09       1.01094   8.33063e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  6.8830E-12| -0.0000  -0.0000   1.0000
#  2.3898E-03|  0.9981  -0.0618   0.0000
#  4.3900E-01|  0.0618   0.9981   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    4.058e-03   2.694e-02   1.757e-07
#    2.694e-02   4.373e-01   1.461e-06
#    1.757e-07   1.461e-06   1.483e-11
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.03918E-09  +/-  6.37052E-02
#    2    2   powerlaw   PhoIndex            1.01094      +/-  0.661310
#    3    2   powerlaw   norm                8.33063E-06  +/-  3.85044E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    2.57     using 6 bins.
#
# Test statistic : Chi-Squared                    2.57     using 6 bins.
#  Null hypothesis probability of 4.63e-01 with 3 degrees of freedom
#  Model Flux 3.3948e-05 photons (1.5485e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
flux = 1.5485*10**-13
d_pc = 1030
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')

d_pc = 2210
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')
# Out:
# Luminosity is: 1.9711173559351115e+31 erg s^-1
# Luminosity is: 9.074497387239776e+31 erg s^-1
