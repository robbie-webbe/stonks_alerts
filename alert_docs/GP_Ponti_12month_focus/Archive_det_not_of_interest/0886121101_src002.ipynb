# %% [markdown]
# Obs 0886121101 source 002. First X-ray detection. Spectral alert. (266.75, -27.96 1.01")
#
# SIMBAD? N
#
# Vizier - Gaia 4057693206434583168 8.0"
# + Parallax 1.098. Distance 910 pc.
# + Teff 4630K
# + Rstar 0.60
# + Mstar 0.74

# %%
# %load_ext wurlitzer
import numpy as np
import os
import stingray as st
import matplotlib.pyplot as plt
from astropy.io import fits
from xspec import *
plt.rcParams['figure.figsize'] = [15, 8]

lc = fits.open('0886121101_002/0886121101_PN2_dt1.lc')
bkg = fits.open('0886121101_002/0886121101_PN2_dt1_bkg.lc')
full_gti = []
for j in lc[2].data:
    full_gti.append([j[0],j[1]])
soft = fits.open('0886121101_002/0886121101_PN2_dt1_0.2-2keV.lc')
sbkg = fits.open('0886121101_002/0886121101_PN2_dt1_0.2-2keV_bkg.lc')
soft_gti = []
for j in soft[2].data:
    soft_gti.append([j[0],j[1]])
hard = fits.open('0886121101_002/0886121101_PN2_dt1_2-12keV.lc')
hbkg = fits.open('0886121101_002/0886121101_PN2_dt1_2-12keV_bkg.lc')
hard_gti = []
for j in hard[2].data:
    hard_gti.append([j[0],j[1]])

# %%
full_lc = st.Lightcurve(lc[1].data.field('TIME'),lc[1].data.field('RATE'),err=lc[1].data.field('ERROR'),gti=full_gti,input_counts=False)
full_bkg = st.Lightcurve(bkg[1].data.field('TIME'),bkg[1].data.field('RATE'),err=bkg[1].data.field('ERROR'),gti=full_gti,input_counts=False)

soft_lc = st.Lightcurve(soft[1].data.field('TIME'),soft[1].data.field('RATE'),err=soft[1].data.field('ERROR'),gti=soft_gti,input_counts=False)
soft_bkg = st.Lightcurve(sbkg[1].data.field('TIME'),sbkg[1].data.field('RATE'),err=sbkg[1].data.field('ERROR'),gti=soft_gti,input_counts=False)

hard_lc = st.Lightcurve(hard[1].data.field('TIME'),hard[1].data.field('RATE'),err=hard[1].data.field('ERROR'),gti=hard_gti,input_counts=False)
hard_bkg = st.Lightcurve(hbkg[1].data.field('TIME'),hbkg[1].data.field('RATE'),err=hbkg[1].data.field('ERROR'),gti=hard_gti,input_counts=False)

full_lc.apply_gtis()
full_bkg.apply_gtis()
soft_lc.apply_gtis()
soft_bkg.apply_gtis()
hard_lc.apply_gtis()
hard_bkg.apply_gtis()

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(soft_lc.time,soft_lc.countrate,color='r')
plt.plot(hard_lc.time,hard_lc.countrate,color='b')

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(full_bkg.time,full_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.time,soft_lc.countrate,color='k')
plt.plot(soft_bkg.time,soft_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.time,hard_lc.countrate,color='k')
plt.plot(hard_bkg.time,hard_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='r')
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='b')

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(full_bkg.rebin(50).time,full_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='k')
plt.plot(soft_bkg.rebin(50).time,soft_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='k')
plt.plot(hard_bkg.rebin(50).time,hard_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='r')
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='b')

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(full_bkg.rebin(250).time,full_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='k')
plt.plot(soft_bkg.rebin(250).time,soft_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='k')
plt.plot(hard_bkg.rebin(250).time,hard_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
os.chdir("0886121101_002")
spec = Spectrum("0886121101_PN2grpspec.fits")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0886121101_PN2grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  1.646e-02 +/- 1.998e-03 (61.0 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-13
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 7414 sec
#  Using fit statistic: chi
#  Using Background File                0886121101_PN2spec_bkg.fits
#   Background Exposure Time: 7414 sec
#  Using Response (RMF) File            0886121101_PN2spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0886121101_PN2spec.arf

# %%
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.00005 0.08")
Plot("data")

# %%
spec.ignore("**-0.2 12.0-**")
mo1 = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
#      1 channels (1) ignored in spectrum #     1
#      1 channels (13) ignored in spectrum #     1
#
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              5.135650e+11     using 11 bins.
#
# Test statistic : Chi-Squared              5.135650e+11     using 11 bins.
#  Null hypothesis probability of 0.000000e+00 with 8 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 32.8232      1.28291      -3      0.173422       1.05341   2.48150e-06
# 20.7987      3.72891e+06  -4      0.457343       1.03779   2.24926e-06
# 18.6226      398240       -5      0.956838      0.912119   2.36708e-06
# 18.1908      18862.1      -6       1.31103      0.873988   2.59877e-06
# 18.1769      22216.1      -7       1.38521      0.868142   2.65701e-06
# 18.1769      1189.89      -8       1.38884      0.868059   2.66023e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.1969E-13| -0.0000  -0.0000   1.0000
#  1.0039E-02| -0.1615  -0.9869  -0.0000
#  6.9055E-01|  0.9869  -0.1615   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    6.728e-01  -1.085e-01   3.742e-07
#   -1.085e-01   2.780e-02  -4.448e-08
#    3.742e-07  -4.448e-08   3.523e-13
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.38884      +/-  0.820237
#    2    2   bbody      kT         keV      0.868059     +/-  0.166729
#    3    2   bbody      norm                2.66023E-06  +/-  5.93556E-07
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   18.18     using 11 bins.
#
# Test statistic : Chi-Squared                   18.18     using 11 bins.
#  Null hypothesis probability of 1.99e-02 with 8 degrees of freedom
#  Model Flux 2.9531e-05 photons (1.5565e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
mo2 = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.160268e+11     using 11 bins.
#
# Test statistic : Chi-Squared              1.160268e+11     using 11 bins.
#  Null hypothesis probability of 0.000000e+00 with 8 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 24.7424      1.78094      -1       1.06957       1.22278   2.61410e-05
# 23.7183      37368        -1       1.24742       1.37555   3.29677e-05
# 22.9072      30379.9      -1       1.40453       1.50397   4.05186e-05
# 22.2894      20644.1      -1       1.54813       1.61585   4.84706e-05
# 21.8102      14232.7      -1       1.68014       1.71493   5.67236e-05
# 21.4304      10180.5      -1       1.80170       1.80357   6.52180e-05
# 21.1244      7526.28      -1       1.91379       1.88345   7.38990e-05
# 20.8747      5716.55      -1       2.01725       1.95585   8.27131e-05
# 20.8636      4439.56      -2       2.56895       2.35330   0.000132074
# 19.9623      16094        -2       2.91264       2.55963   0.000192361
# Number of trials exceeded: continue fitting? 19.9362      6750.66      -3       3.34668       2.84269   0.000287344
# 19.5173      5195.11      -4       3.40364       2.85812   0.000323310
# 19.5166      186.051      -5       3.41328       2.86385   0.000327093
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.8242E-09| -0.0001  -0.0003   1.0000
#  9.9189E-02|  0.5249  -0.8512  -0.0002
#  2.6539E+00|  0.8512   0.5249   0.0003
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.950e+00   1.141e+00   5.541e-04
#    1.141e+00   8.031e-01   3.677e-04
#    5.541e-04   3.677e-04   1.732e-07
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    3.41328      +/-  1.39643
#    2    2   powerlaw   PhoIndex            2.86385      +/-  0.896146
#    3    2   powerlaw   norm                3.27093E-04  +/-  4.16157E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   19.52     using 11 bins.
#
# Test statistic : Chi-Squared                   19.52     using 11 bins.
#  Null hypothesis probability of 1.23e-02 with 8 degrees of freedom
#  Model Flux 3.1384e-05 photons (1.8971e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
flux = 1.5565*10**-13
d_pc = 910
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')

d_pc = 7500
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')
# Out:
# Luminosity is: 1.5465313658349965e+31 erg s^-1
# Luminosity is: 1.0505058486682592e+33 erg s^-1

# %%
g_mag = 16.775
opt_flux = (10**(0.4*(-26.7 - g_mag))) * (3.828 * 10 ** 33) / (4*np.pi*(1.496*10**13)**2)
print('Optical flux: '+str(opt_flux))
opt_x_ratio = flux / opt_flux
print('The x-ray/optical flux ratio is: '+str(opt_x_ratio))
# Out:
# Optical flux: 5.5449658785867036e-12
# The x-ray/optical flux ratio is: 0.02807050636706027
