# %% [markdown]
# Obs 0886090801 source 001. Not first X-ray detection. (268.3196, -26.8806, 0.74")
#
# SIMBAD
# Possible match SWIFT J175317.1-265250
#
# ALSO XMM
# + 0932190901 src 2
#
# Vizier - Gaia 4063819096797429760 0.305"
# + Parallax 1.1723. Distance 853 pc.
# + Teff unknown
# + Rstar unknown
# + Mstar unknown

# %%
# %load_ext wurlitzer
import numpy as np
import os
import stingray as st
import matplotlib.pyplot as plt
from astropy.io import fits
from xspec import *
plt.rcParams['figure.figsize'] = [15, 8]

lc = fits.open('0932191101_001/0932191101_M2_dt5.lc')
bkg = fits.open('0932191101_001/0932191101_M2_dt5_bkg.lc')
full_gti = []
for j in lc[2].data:
    full_gti.append([j[0],j[1]])
soft = fits.open('0932191101_001/0932191101_M2_dt5_0.2-2keV.lc')
sbkg = fits.open('0932191101_001/0932191101_M2_dt5_0.2-2keV_bkg.lc')
soft_gti = []
for j in soft[2].data:
    soft_gti.append([j[0],j[1]])
hard = fits.open('0932191101_001/0932191101_M2_dt5_2-12keV.lc')
hbkg = fits.open('0932191101_001/0932191101_M2_dt5_2-12keV_bkg.lc')
hard_gti = []
for j in hard[2].data:
    hard_gti.append([j[0],j[1]])

# %%
full_lc = st.Lightcurve(lc[1].data.field('TIME'),lc[1].data.field('RATE'),err=lc[1].data.field('ERROR'),gti=full_gti,input_counts=False)
full_bkg = st.Lightcurve(bkg[1].data.field('TIME'),bkg[1].data.field('RATE'),err=bkg[1].data.field('ERROR'),gti=full_gti,input_counts=False)

soft_lc = st.Lightcurve(soft[1].data.field('TIME'),soft[1].data.field('RATE'),err=soft[1].data.field('ERROR'),gti=soft_gti,input_counts=False)
soft_bkg = st.Lightcurve(sbkg[1].data.field('TIME'),sbkg[1].data.field('RATE'),err=sbkg[1].data.field('ERROR'),gti=soft_gti,input_counts=False)

hard_lc = st.Lightcurve(hard[1].data.field('TIME'),hard[1].data.field('RATE'),err=hard[1].data.field('ERROR'),gti=hard_gti,input_counts=False)
hard_bkg = st.Lightcurve(hbkg[1].data.field('TIME'),hbkg[1].data.field('RATE'),err=hbkg[1].data.field('ERROR'),gti=hard_gti,input_counts=False)

full_lc.apply_gtis()
full_bkg.apply_gtis()
soft_lc.apply_gtis()
soft_bkg.apply_gtis()
hard_lc.apply_gtis()
hard_bkg.apply_gtis()

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(soft_lc.time,soft_lc.countrate,color='r')
plt.plot(hard_lc.time,hard_lc.countrate,color='b')

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(full_bkg.time,full_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.time,soft_lc.countrate,color='k')
plt.plot(soft_bkg.time,soft_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.time,hard_lc.countrate,color='k')
plt.plot(hard_bkg.time,hard_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='r')
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='b')

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(full_bkg.rebin(50).time,full_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='k')
plt.plot(soft_bkg.rebin(50).time,soft_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='k')
plt.plot(hard_bkg.rebin(50).time,hard_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='r')
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='b')

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(full_bkg.rebin(250).time,full_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='k')
plt.plot(soft_bkg.rebin(250).time,soft_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='k')
plt.plot(hard_bkg.rebin(250).time,hard_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
os.chdir("0932191101_001")
spec = Spectrum("0932191101_M2grpspec.fits")
# Out:
# ***Warning: Detected response matrix energy bin value = 0 (or neg).
#      XSPEC will instead use small finite value (response file will not be altered).
#
# 1 spectrum  in use
#
# Spectral Data File: 0932191101_M2grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  1.581e-02 +/- 1.594e-03 (84.3 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-12
#   Telescope: XMM Instrument: EMOS2  Channel Type: PI
#   Exposure Time: 1.002e+04 sec
#  Using fit statistic: chi
#  Using Background File                0932191101_M2spec_bkg.fits
#   Background Exposure Time: 1.002e+04 sec
#  Using Response (RMF) File            0932191101_M2spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0932191101_M2spec.arf

# %%
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot("data")

# %%
spec.ignore("**-0.2 12.0-**")
mo1 = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
#      1 channels (1) ignored in spectrum #     1
#       No channels ignored (no channels in specified range)
#
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              8.262068e+10     using 11 bins.
#
# Test statistic : Chi-Squared              8.262068e+10     using 11 bins.
#  Null hypothesis probability of 0.000000e+00 with 8 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 83.3862      0.990876      0      0.244568       3.10776   1.55144e-05
# 82.3024      103387        0     0.0231157       3.16614   1.42381e-05
# 80.9656      167209        0    0.00321238       3.11221   1.46299e-05
# 80.1387      150589        0   0.000988164       3.06815   1.49422e-05
# 79.5339      133201        0   0.000474065       3.03183   1.51878e-05
# 79.0767      117299        0   0.000232755       3.00141   1.53797e-05
# 78.7248      103099        0   3.71795e-06       2.97558   1.55281e-05
# 78.4541      90567.5       0   2.92017e-07       2.95335   1.56410e-05
# 78.2409      79562.9       0   8.55638e-08       2.93399   1.57248e-05
# 78.0706      69972.2       0   3.55157e-08       2.91695   1.57847e-05
# Number of trials exceeded: continue fitting? 77.9323      61648.5       0   1.11370e-08       2.90180   1.58246e-05
# 77.8181      54447.8       0   5.17654e-09       2.88819   1.58481e-05
# 77.7224      48234.3       0   2.25259e-09       2.87584   1.58579e-05
# 77.6406      42884         0   8.14377e-10       2.86454   1.58562e-05
# 77.5696      38284         0   1.05374e-10       2.85411   1.58450e-05
# 77.507       34334.4       0   1.78312e-11       2.84440   1.58258e-05
# 77.4508      30946.9       0   7.00413e-12       2.83530   1.58000e-05
# 77.3997      28043.8       0   1.64112e-12       2.82670   1.57685e-05
# 77.3525      25557.5       0   3.11223e-13       2.81852   1.57324e-05
# 77.3086      23429.3       0   1.45899e-13       2.81071   1.56924e-05
# Number of trials exceeded: continue fitting? 77.2672      21610.4       0   6.43125e-14       2.80318   1.56491e-05
# 77.2279      20054.9       0   2.36957e-14       2.79593   1.56028e-05
# 77.1899      18740.9       0   3.47245e-15       2.78885   1.55547e-05
# 77.1545      17585.9       0   6.19838e-16       2.78211   1.55024e-05
# 77.1112      16782.4       0   2.78595e-16       2.77423   1.54607e-05
# 77.0651      14892.9       0   6.91735e-17       2.76593   1.54260e-05
# 76.8423      12413         0   2.87576e-18       2.71982   1.48132e-05
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 2.87576e-18 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 73.4073      29849        -1   2.87576e-18       2.15488   9.37617e-06
# 42.6346      134136       -2   2.87576e-18      0.546824   3.19444e-06
# Number of trials exceeded: continue fitting? 33.7031      3.47157e+06  -3   2.87576e-18      0.450880   2.29098e-06
# 31.3412      1.08931e+06  -4   2.87576e-18      0.391737   2.35790e-06
# 30.9546      315568       -5   2.87576e-18      0.370699   2.38216e-06
# 30.8759      65475.4      -6   2.87576e-18      0.361519   2.38615e-06
# 30.8583      14920.9      -7   2.87576e-18      0.357267   2.38676e-06
# 30.8543      3420.59      -8   2.87576e-18      0.355262   2.38676e-06
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 2.87576e-18 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 30.8534      777.349      -3   2.87576e-18      0.354311   2.38669e-06
# ==============================
#  Variances and Principal Axes
#                  2        3
#  6.9116E-14| -0.0000   1.0000
#  1.4718E-03|  1.0000   0.0000
# ------------------------------
#
# ========================
#   Covariance Matrix
#         1           2
#    1.472e-03   2.718e-10
#    2.718e-10   6.917e-14
# ------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    2.87576E-18  +/-  -1.00000
#    2    2   bbody      kT         keV      0.354311     +/-  3.83635E-02
#    3    2   bbody      norm                2.38669E-06  +/-  2.62995E-07
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   30.85     using 11 bins.
#
# Test statistic : Chi-Squared                   30.85     using 11 bins.
#  Null hypothesis probability of 1.49e-04 with 8 degrees of freedom
#  Model Flux 0.00012328 photons (1.9848e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
mo2 = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              2.393679e+10     using 11 bins.
#
# Test statistic : Chi-Squared              2.393679e+10     using 11 bins.
#  Null hypothesis probability of 0.000000e+00 with 8 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 68.4909      3.41178      -1      0.364253       1.09670   2.29489e-05
# 60.8847      215126       -1     0.0206777      0.947744   1.73712e-05
# 44.6108      350565
#      -2    0.00300426       1.15479   2.80886e-05
# 33.2925      225278       -3    0.00125051       1.43634   4.08672e-05
# 25.7498      142745       -4   0.000570225       1.65746   5.42264e-05
# 22.7444      76662.5      -5   7.80110e-05       1.79611   6.39899e-05
# 21.9441      35181.6      -6   3.54442e-05       1.87646   6.95908e-05
# 21.7809      14116.8      -7   1.43903e-05       1.92153   7.25677e-05
# 21.7657      3785.24      -8    0.00214084       1.94632   7.41497e-05
# 21.7652      65.2384      -9    0.00493440       1.95718   7.48074e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  6.0098E-11| -0.0001  -0.0000   1.0000
#  3.8278E-03|  0.9692  -0.2464   0.0001
#  2.6598E-01|  0.2464   0.9692   0.0001
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.974e-02   6.260e-02   4.193e-06
#    6.260e-02   2.501e-01   1.465e-05
#    4.193e-06   1.465e-05   9.861e-10
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    4.93440E-03  +/-  0.140514
#    2    2   powerlaw   PhoIndex            1.95718      +/-  0.500067
#    3    2   powerlaw   norm                7.48074E-05  +/-  3.14024E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   21.77     using 11 bins.
#
# Test statistic : Chi-Squared                   21.77     using 11 bins.
#  Null hypothesis probability of 5.37e-03 with 8 degrees of freedom
#  Model Flux 0.00032068 photons (4.8338e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
flux = 4.8338*10**-13
d_pc = 853
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')
# Out:
# Luminosity is: 4.2200108014980165e+31 erg s^-1
