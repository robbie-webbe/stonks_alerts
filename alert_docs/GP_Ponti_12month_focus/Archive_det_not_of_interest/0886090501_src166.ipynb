# %% [markdown]
# Obs 0886090501 source 166. First X-ray detection. Spectral alert. (270.14, -24.04 2.13")
#
# SIMBAD? N.
#
# Vizier - Gaia 4069056586083083776 4.4"
# + Parallax 0.6492. Distance 1540 pc.
# + Teff 4280K
# + Rstar 1.06
# + Mstar unknown

# %%
# %load_ext wurlitzer
import numpy as np
import os
import stingray as st
import matplotlib.pyplot as plt
from astropy.io import fits
from xspec import *
plt.rcParams['figure.figsize'] = [15, 8]

lc = fits.open('0886090501_166/0886090501_M2166_dt5.lc')
bkg = fits.open('0886090501_166/0886090501_M2166_dt5_bkg.lc')
full_gti = []
for j in lc[2].data:
    full_gti.append([j[0],j[1]])
soft = fits.open('0886090501_166/0886090501_M2166_dt5_0.2-2keV.lc')
sbkg = fits.open('0886090501_166/0886090501_M2166_dt5_0.2-2keV_bkg.lc')
soft_gti = []
for j in soft[2].data:
    soft_gti.append([j[0],j[1]])
hard = fits.open('0886090501_166/0886090501_M2166_dt5_2-12keV.lc')
hbkg = fits.open('0886090501_166/0886090501_M2166_dt5_2-12keV_bkg.lc')
hard_gti = []
for j in hard[2].data:
    hard_gti.append([j[0],j[1]])

# %%
full_lc = st.Lightcurve(lc[1].data.field('TIME'),lc[1].data.field('RATE'),err=lc[1].data.field('ERROR'),gti=full_gti,input_counts=False)
full_bkg = st.Lightcurve(bkg[1].data.field('TIME'),bkg[1].data.field('RATE'),err=bkg[1].data.field('ERROR'),gti=full_gti,input_counts=False)

soft_lc = st.Lightcurve(soft[1].data.field('TIME'),soft[1].data.field('RATE'),err=soft[1].data.field('ERROR'),gti=soft_gti,input_counts=False)
soft_bkg = st.Lightcurve(sbkg[1].data.field('TIME'),sbkg[1].data.field('RATE'),err=sbkg[1].data.field('ERROR'),gti=soft_gti,input_counts=False)

hard_lc = st.Lightcurve(hard[1].data.field('TIME'),hard[1].data.field('RATE'),err=hard[1].data.field('ERROR'),gti=hard_gti,input_counts=False)
hard_bkg = st.Lightcurve(hbkg[1].data.field('TIME'),hbkg[1].data.field('RATE'),err=hbkg[1].data.field('ERROR'),gti=hard_gti,input_counts=False)

full_lc.apply_gtis()
full_bkg.apply_gtis()
soft_lc.apply_gtis()
soft_bkg.apply_gtis()
hard_lc.apply_gtis()
hard_bkg.apply_gtis()
# Out:
# /home/rwebbe/.local/lib/python3.8/site-packages/stingray/lightcurve.py:516: UserWarning: There are non-finite points in the data, but they are outside GTIs.
#   warnings.warn("There are non-finite points in the data, but they are outside GTIs. ")
# /home/rwebbe/.local/lib/python3.8/site-packages/stingray/lightcurve.py:516: UserWarning: There are non-finite points in the data, but they are outside GTIs.
#   warnings.warn("There are non-finite points in the data, but they are outside GTIs. ")

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(soft_lc.time,soft_lc.countrate,color='r')
plt.plot(hard_lc.time,hard_lc.countrate,color='b')

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(full_bkg.time,full_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.time,soft_lc.countrate,color='k')
plt.plot(soft_bkg.time,soft_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.time,hard_lc.countrate,color='k')
plt.plot(hard_bkg.time,hard_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='r')
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='b')

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(full_bkg.rebin(50).time,full_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='k')
plt.plot(soft_bkg.rebin(50).time,soft_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='k')
plt.plot(hard_bkg.rebin(50).time,hard_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='r')
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='b')

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(full_bkg.rebin(250).time,full_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='k')
plt.plot(soft_bkg.rebin(250).time,soft_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='k')
plt.plot(hard_bkg.rebin(250).time,hard_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
os.chdir("0886090501_166")
spec = Spectrum("0886090501_M2166grpspec.fits")
# Out:
# ***Warning: Detected response matrix energy bin value = 0 (or neg).
#      XSPEC will instead use small finite value (response file will not be altered).
#
# 1 spectrum  in use
#
# Spectral Data File: 0886090501_M2166grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  2.956e-03 +/- 6.641e-04 (57.2 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-6
#   Telescope: XMM Instrument: EMOS2  Channel Type: PI
#   Exposure Time: 1.295e+04 sec
#  Using fit statistic: chi
#  Using Background File                0886090501_M2166spec_bkg.fits
#   Background Exposure Time: 1.295e+04 sec
#  Using Response (RMF) File            0886090501_M2166spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0886090501_M2166spec.arf

# %%
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.00001 0.005")
Plot("data")

# %%
mo1 = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared
#               2.444780e+11     using 6 bins.
#
# Test statistic : Chi-Squared              2.444780e+11     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 4.5876       0.523427     -2      0.258290       1.59554   2.33615e-06
# 1.13057      501733       -1      0.572735      0.940668   1.82646e-06
# 0.390332     44801.9      -2       1.26383      0.826369   2.16302e-06
# 0.363464     64400.7      -3       1.42177      0.812931   2.29730e-06
# 0.362936     4934         -4       1.38890      0.818007   2.28285e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  2.1484E-13| -0.0000  -0.0000   1.0000
#  2.4990E-02| -0.1678  -0.9858  -0.0000
#  1.9030E+00|  0.9858  -0.1678   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.850e+00  -3.107e-01   9.600e-07
#   -3.107e-01   7.789e-02  -1.278e-07
#    9.600e-07  -1.278e-07   7.565e-13
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.38890      +/-  1.36018
#    2    2   bbody      kT         keV      0.818007     +/-  0.279088
#    3    2   bbody      norm                2.28285E-06  +/-  8.69796E-07
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    0.36     using 6 bins.
#
# Test statistic : Chi-Squared                    0.36     using 6 bins.
#  Null hypothesis probability of 9.48e-01 with 3 degrees of freedom
#  Model Flux 2.5397e-05 photons (1.2864e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
mo2 = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              5.952549e+10     using 6 bins.
#
# Test statistic : Chi-Squared              5.952549e+10     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 2.15388      0.638138     -1       1.04473       1.18760   2.33219e-05
# 1.81836      13716.2      -1       1.21263       1.32422   2.85662e-05
# 1.53638      12570        -1       1.35200       1.44499   3.43954e-05
# 1.30895      9081.15      -1       1.48154       1.55311   4.06128e-05
# 1.12408      6602.81      -1       1.60093       1.65109   4.71480e-05
# 0.972308     4912.39      -1       1.71108       1.74036   5.39488e-05
# 0.84667      3736.99      -1       1.81278       1.82198   6.09645e-05
# 0.741974     2897.93      -1       1.90673       1.89682   6.81455e-05
# 0.65425      2284.93      -1       1.99361       1.96563   7.54437e-05
# 0.580401     1828.07      -1       2.07403       2.02901   8.28139e-05
# Number of trials exceeded: continue fitting? 0.553698     1481.61      -2       2.55592       2.39684   0.000127126
# 0.265831     6194.54      -2       2.81065       2.59795   0.000177342
# 0.163242     2556.93      -2       2.95739       2.71121   0.000215751
# 0.153355     784.104      -3       3.18333       2.88207   0.000271463
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.9543E-09| -0.0001  -0.0002   1.0000
#  2.3512E-01|  0.5717  -0.8205  -0.0001
#  5.9004E+00|  0.8205   0.5717   0.0002
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    4.049e+00   2.657e+00   8.330e-04
#    2.657e+00   2.087e+00   6.179e-04
#    8.330e-04   6.179e-04   1.881e-07
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    3.18333      +/-  2.01213
#    2    2   powerlaw   PhoIndex            2.88207      +/-  1.44459
#    3    2   powerlaw   norm                2.71463E-04  +/-  4.33718E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    0.15     using 6 bins.
#
# Test statistic : Chi-Squared                    0.15     using 6 bins.
#  Null hypothesis probability of 9.85e-01 with 3 degrees of freedom
#  Model Flux 2.6901e-05 photons (1.5838e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
flux = 1.58*10**-13
d_pc = 1540
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')

d_pc = 7500
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')
# Out:
# Luminosity is: 4.495990154216193e+31 erg s^-1
# Luminosity is: 1.0663663609995821e+33 erg s^-1

# %%
g_mag = 18.16
opt_flux = (10**(0.4*(-26.7 - g_mag))) * (3.828 * 10 ** 33) / (4*np.pi*(1.496*10**13)**2)
print('Optical flux: '+str(opt_flux))
opt_x_ratio = flux / opt_flux
print('The x-ray/optical flux ratio is: '+str(opt_x_ratio))
# Out:
# Optical flux: 1.5484560314118412e-12
# The x-ray/optical flux ratio is: 0.10203712394464297
