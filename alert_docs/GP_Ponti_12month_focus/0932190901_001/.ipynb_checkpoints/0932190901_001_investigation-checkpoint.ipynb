# %%
# %load_ext wurlitzer
import numpy as np
import os
import stingray as st
import matplotlib.pyplot as plt
from astropy.io import fits
from xspec import *
plt.rcParams['figure.figsize'] = [15, 8]

lc = fits.open('0932190901_PN1_dt1.lc')
bkg = fits.open('0932190901_PN1_dt1_bkg.lc')
full_gti = []
for j in lc[2].data:
    full_gti.append([j[0],j[1]])
soft = fits.open('0932190901_PN1_dt1_0.2-2keV.lc')
sbkg = fits.open('0932190901_PN1_dt1_0.2-2keV_bkg.lc')
soft_gti = []
for j in soft[2].data:
    soft_gti.append([j[0],j[1]])
hard = fits.open('0932190901_PN1_dt1_2-12keV.lc')
hbkg = fits.open('0932190901_PN1_dt1_2-12keV_bkg.lc')
hard_gti = []
for j in hard[2].data:
    hard_gti.append([j[0],j[1]])
    
lc1 = fits.open('0932190601_PN2_dt1.lc')
bkg1 = fits.open('0932190601_PN2_dt1_bkg.lc')
full_gti1 = []
for j in lc1[2].data:
    full_gti1.append([j[0],j[1]])
soft1 = fits.open('0932190601_PN2_dt1_0.2-2keV.lc')
sbkg1 = fits.open('0932190601_PN2_dt1_0.2-2keV_bkg.lc')
soft_gti1 = []
for j in soft1[2].data:
    soft_gti1.append([j[0],j[1]])
hard1 = fits.open('0932190601_PN2_dt1_2-12keV.lc')
hbkg1 = fits.open('0932190601_PN2_dt1_2-12keV_bkg.lc')
hard_gti1 = []
for j in hard1[2].data:
    hard_gti1.append([j[0],j[1]])
# Out:
# The wurlitzer extension is already loaded. To reload it, use:
#   %reload_ext wurlitzer

# %%
full_lc = st.Lightcurve(lc[1].data.field('TIME'),lc[1].data.field('RATE'),err=lc[1].data.field('ERROR'),gti=full_gti,input_counts=False)
full_bkg = st.Lightcurve(bkg[1].data.field('TIME'),bkg[1].data.field('RATE'),err=bkg[1].data.field('ERROR'),gti=full_gti,input_counts=False)

soft_lc = st.Lightcurve(soft[1].data.field('TIME'),soft[1].data.field('RATE'),err=soft[1].data.field('ERROR'),gti=soft_gti,input_counts=False)
soft_bkg = st.Lightcurve(sbkg[1].data.field('TIME'),sbkg[1].data.field('RATE'),err=sbkg[1].data.field('ERROR'),gti=soft_gti,input_counts=False)

hard_lc = st.Lightcurve(hard[1].data.field('TIME'),hard[1].data.field('RATE'),err=hard[1].data.field('ERROR'),gti=hard_gti,input_counts=False)
hard_bkg = st.Lightcurve(hbkg[1].data.field('TIME'),hbkg[1].data.field('RATE'),err=hbkg[1].data.field('ERROR'),gti=hard_gti,input_counts=False)

full_lc.apply_gtis()
full_bkg.apply_gtis()
soft_lc.apply_gtis()
soft_bkg.apply_gtis()
hard_lc.apply_gtis()
hard_bkg.apply_gtis()

full_lc1 = st.Lightcurve(lc1[1].data.field('TIME'),lc1[1].data.field('RATE'),err=lc1[1].data.field('ERROR'),gti=full_gti1,input_counts=False)
full_bkg1 = st.Lightcurve(bkg1[1].data.field('TIME'),bkg1[1].data.field('RATE'),err=bkg1[1].data.field('ERROR'),gti=full_gti1,input_counts=False)

soft_lc1 = st.Lightcurve(soft1[1].data.field('TIME'),soft1[1].data.field('RATE'),err=soft1[1].data.field('ERROR'),gti=soft_gti1,input_counts=False)
soft_bkg1 = st.Lightcurve(sbkg1[1].data.field('TIME'),sbkg1[1].data.field('RATE'),err=sbkg1[1].data.field('ERROR'),gti=soft_gti1,input_counts=False)

hard_lc1 = st.Lightcurve(hard1[1].data.field('TIME'),hard1[1].data.field('RATE'),err=hard1[1].data.field('ERROR'),gti=hard_gti1,input_counts=False)
hard_bkg1 = st.Lightcurve(hbkg1[1].data.field('TIME'),hbkg1[1].data.field('RATE'),err=hbkg1[1].data.field('ERROR'),gti=hard_gti1,input_counts=False)

full_lc1.apply_gtis()
full_bkg1.apply_gtis()
soft_lc1.apply_gtis()
soft_bkg1.apply_gtis()
hard_lc1.apply_gtis()
hard_bkg1.apply_gtis()
# Out:
# /home/rwebbe/.local/lib/python3.8/site-packages/stingray/lightcurve.py:516: UserWarning: There are non-finite points in the data, but they are outside GTIs.
#   warnings.warn("There are non-finite points in the data, but they are outside GTIs. ")
# /home/rwebbe/.local/lib/python3.8/site-packages/stingray/lightcurve.py:516: UserWarning: There are non-finite points in the data, but they are outside GTIs.
#   warnings.warn("There are non-finite points in the data, but they are outside GTIs. ")

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(soft_lc.time,soft_lc.countrate,color='r')
plt.plot(hard_lc.time,hard_lc.countrate,color='b')

# %%
plt.plot(full_lc1.time,full_lc1.countrate,color='k')
plt.plot(soft_lc1.time,soft_lc1.countrate,color='r')
plt.plot(hard_lc1.time,hard_lc1.countrate,color='b')

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='r')
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='b')

# %%
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='k')
plt.plot(hard_bkg.rebin(50).time,hard_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(full_lc1.rebin(50).time,full_lc1.rebin(50).countrate,color='k')
plt.plot(soft_lc1.rebin(50).time,soft_lc1.rebin(50).countrate,color='r')
plt.plot(hard_lc1.rebin(50).time,hard_lc1.rebin(50).countrate,color='b')

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='r')
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='b')

# %%
plt.plot(full_lc1.rebin(250).time,full_lc1.rebin(250).countrate,color='k')
plt.plot(soft_lc1.rebin(250).time,soft_lc1.rebin(250).countrate,color='r')
plt.plot(hard_lc1.rebin(250).time,hard_lc1.rebin(250).countrate,color='b')

# %%
spec = Spectrum("0932190601_PN2grpspec.fits")
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.00005 0.1")
Plot("data")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0932190601_PN2grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  2.873e-02 +/- 2.057e-03 (87.5 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-18
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 8738 sec
#  Using fit statistic: chi
#  Using Background File                0932190601_PN2spec_bkg.fits
#   Background Exposure Time: 8738 sec
#  Using Response (RMF) File            0932190601_PN2spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0932190601_PN2spec.arf

# %%
spec.ignore("**-0.2 12.0-**")
mo1 = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
#      1 channels (1) ignored in spectrum #     1
#      1 channels (18) ignored in spectrum #     1
#
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared
#               3.915966e+11     using 16 bins.
#
# Test statistic : Chi-Squared              3.915966e+11     using 16 bins.
#  Null hypothesis probability of 0.000000e+00 with 13 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 199.979      0.456526      0      0.375908       3.26078   3.14598e-06
# 198.366      235250        0      0.175582       3.19556   3.26422e-06
# 197.019      266984        0     0.0763451       3.13713   3.36959e-06
# 196.009      285604        0     0.0292386       3.08457   3.46345e-06
# 195.289      289117        0    0.00754273       3.03792   3.54527e-06
# 194.86       281310        0    0.00254450       2.99730   3.61402e-06
# 194.537      264295        0   0.000202261       2.96287   3.66858e-06
# 194.306      247093        0   6.34020e-05       2.93346   3.71106e-06
# 194.122      230174        0   3.01327e-05       2.90818   3.74318e-06
# 193.973      215073        0   1.40759e-05       2.88618   3.76682e-06
# Number of trials exceeded: continue fitting? 193.85       201769        0   6.28203e-06       2.86678   3.78349e-06
# 193.748      190134        0   2.48131e-06       2.84950   3.79440e-06
# 193.662      180020        0   6.20825e-07       2.83394   3.80053e-06
# 193.589      171271        0   1.64041e-07       2.81978   3.80269e-06
# 193.526      163736        0   5.16015e-08       2.80678   3.80154e-06
# 193.47       157272        0   2.38647e-08       2.79473   3.79763e-06
# 193.421      151748        0   1.01558e-08       2.78348   3.79140e-06
# 193.378      147043        0   3.36999e-09       2.77288   3.78324e-06
# 193.338      143053        0   6.89804e-12       2.76283   3.77345e-06
# 193.302      139681        0   3.80062e-13       2.75323   3.76231e-06
# Number of trials exceeded: continue fitting? 193.269      136847        0   1.78251e-13       2.74406   3.74987e-06
# 193.238      134539        0   7.78020e-14       2.73514   3.73668e-06
# 193.208      132543        0   2.75238e-14       2.72646   3.72280e-06
# 193.182      130840        0   3.71683e-15       2.71815   3.70767e-06
# 193.149      129686        0   3.50552e-16       2.70914   3.69506e-06
# 193.123      127347        0   1.46887e-16       2.70082   3.67909e-06
# 193.08       126376        0   3.93187e-17       2.69015   3.67076e-06
# 192.73       121565        0   9.71715e-18       2.59841   3.58242e-06
# 190.357      79367.8      -1   2.58839e-18       1.91907   1.77823e-06
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 2.58839e-18 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 187.555      818751        0   2.58839e-18       1.67650   1.78973e-06
# Number of trials exceeded: continue fitting? 125.349      144003       -1   2.58839e-18      0.549462   8.47553e-07
# 62.1944      1.03165e+07   0   2.58839e-18      0.322617   9.05885e-07
# 37.0432      1.86281e+07  -1   2.58839e-18      0.197053   1.22221e-06
# 24.6112      2.95033e+06  -2   2.58839e-18      0.240242   1.31119e-06
# 24.4315      2.11548e+06  -3   2.58839e-18      0.239890   1.35330e-06
# 24.4315      1923.76      -2   2.58839e-18      0.239897   1.35334e-06
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 2.58839e-18 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 24.4315      22.8289      -3   2.58839e-18      0.239897   1.35334e-06
# ==============================
#  Variances and Principal Axes
#                  2        3
#  1.0001E-14| -0.0000   1.0000
#  1.7492E-04|  1.0000   0.0000
# ------------------------------
#
# ========================
#   Covariance Matrix
#         1           2
#    1.749e-04   8.975e-11
#    8.975e-11   1.005e-14
# ------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    2.58839E-18  +/-  -1.00000
#    2    2   bbody      kT         keV      0.239897     +/-  1.32257E-02
#    3    2   bbody      norm                1.35334E-06  +/-  1.00236E-07
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   24.43     using 16 bins.
#
# Test statistic : Chi-Squared                   24.43     using 16 bins.
#  Null hypothesis probability of 2.74e-02 with 13 degrees of freedom
#  Model Flux 9.7359e-05 photons (1.1095e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
mo2 = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.428435e+11     using 16 bins.
#
# Test statistic : Chi-Squared              1.428435e+11     using 16 bins.
#  Null hypothesis probability of 0.000000e+00 with 13 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 180.048      2.707         0      0.455084       1.26992   9.28974e-06
# 156.564      311882        0      0.141423       1.60008   9.83689e-06
# 70.7175      693904       -1     0.0588221       2.93289   2.23905e-05
# 46.9104      525667       -2      0.205695       3.01679   5.53060e-05
# 30.5457      184566       -3      0.311949       4.15373   9.38037e-05
# 28.894       45871        -4      0.386717       4.50421   0.000126808
# 28.5663      18638.6      -5      0.401188       4.61324   0.000137767
# 28.5643      1084.96      -6      0.404556       4.63311   0.000139600
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.0657E-10| -0.0006   0.0000   1.0000
#  8.0427E-04|  0.9888  -0.1493   0.0006
#  7.5613E-01|  0.1493   0.9888   0.0001
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.765e-02   1.115e-01   7.640e-06
#    1.115e-01   7.393e-01   4.761e-05
#    7.640e-06   4.761e-05   3.427e-09
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.404556     +/-  0.132850
#    2    2   powerlaw   PhoIndex            4.63311      +/-  0.859819
#    3    2   powerlaw   norm                1.39600E-04  +/-  5.85411E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   28.56     using 16 bins.
#
# Test statistic : Chi-Squared                   28.56     using 16 bins.
#  Null hypothesis probability of 7.54e-03 with 13 degrees of freedom
#  Model Flux 7.4848e-05 photons (1.0786e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
flux = 1.1095*10**-13
d_pc = 241
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')

d_pc = 229
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')
# Out:
# Luminosity is: 7.731935359590879e+29 erg s^-1
# Luminosity is: 6.981119853175831e+29 erg s^-1
