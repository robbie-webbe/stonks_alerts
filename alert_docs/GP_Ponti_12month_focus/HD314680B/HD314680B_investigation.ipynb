# %%
# %load_ext wurlitzer
import numpy as np
import os
import stingray as st
import matplotlib.pyplot as plt
from astropy.io import fits
from xspec import *
plt.rcParams['figure.figsize'] = [15, 8]
    
lc1 = fits.open('0932190601_PN2_dt1.lc')
bkg1 = fits.open('0932190601_PN2_dt1_bkg.lc')
full_gti1 = []
for j in lc1[2].data:
    full_gti1.append([j[0],j[1]])
soft1 = fits.open('0932190601_PN2_dt1_0.2-2keV.lc')
sbkg1 = fits.open('0932190601_PN2_dt1_0.2-2keV_bkg.lc')
soft_gti1 = []
for j in soft1[2].data:
    soft_gti1.append([j[0],j[1]])
hard1 = fits.open('0932190601_PN2_dt1_2-12keV.lc')
hbkg1 = fits.open('0932190601_PN2_dt1_2-12keV_bkg.lc')
hard_gti1 = []
for j in hard1[2].data:
    hard_gti1.append([j[0],j[1]])

lc2 = fits.open('0932190901_PN1_dt1.lc')
bkg2 = fits.open('0932190901_PN1_dt1_bkg.lc')
full_gti2 = []
for j in lc2[2].data:
    full_gti2.append([j[0],j[1]])
soft2 = fits.open('0932190901_PN1_dt1_0.2-2keV.lc')
sbkg2 = fits.open('0932190901_PN1_dt1_0.2-2keV_bkg.lc')
soft_gti2 = []
for j in soft2[2].data:
    soft_gti2.append([j[0],j[1]])
hard2 = fits.open('0932190901_PN1_dt1_2-12keV.lc')
hbkg2 = fits.open('0932190901_PN1_dt1_2-12keV_bkg.lc')
hard_gti2 = []
for j in hard2[2].data:
    hard_gti2.append([j[0],j[1]])

# %%
full_lc1 = st.Lightcurve(lc1[1].data.field('TIME'),lc1[1].data.field('RATE'),err=lc1[1].data.field('ERROR'),gti=full_gti1,input_counts=False)
full_bkg1 = st.Lightcurve(bkg1[1].data.field('TIME'),bkg1[1].data.field('RATE'),err=bkg1[1].data.field('ERROR'),gti=full_gti1,input_counts=False)

soft_lc1 = st.Lightcurve(soft1[1].data.field('TIME'),soft1[1].data.field('RATE'),err=soft1[1].data.field('ERROR'),gti=soft_gti1,input_counts=False)
soft_bkg1 = st.Lightcurve(sbkg1[1].data.field('TIME'),sbkg1[1].data.field('RATE'),err=sbkg1[1].data.field('ERROR'),gti=soft_gti1,input_counts=False)

hard_lc1 = st.Lightcurve(hard1[1].data.field('TIME'),hard1[1].data.field('RATE'),err=hard1[1].data.field('ERROR'),gti=hard_gti1,input_counts=False)
hard_bkg1 = st.Lightcurve(hbkg1[1].data.field('TIME'),hbkg1[1].data.field('RATE'),err=hbkg1[1].data.field('ERROR'),gti=hard_gti1,input_counts=False)

full_lc1.apply_gtis()
full_bkg1.apply_gtis()
soft_lc1.apply_gtis()
soft_bkg1.apply_gtis()
hard_lc1.apply_gtis()
hard_bkg1.apply_gtis()

full_lc2 = st.Lightcurve(lc2[1].data.field('TIME'),lc2[1].data.field('RATE'),err=lc2[1].data.field('ERROR'),gti=full_gti2,input_counts=False)
full_bkg2 = st.Lightcurve(bkg2[1].data.field('TIME'),bkg2[1].data.field('RATE'),err=bkg2[1].data.field('ERROR'),gti=full_gti2,input_counts=False)

soft_lc2 = st.Lightcurve(soft2[1].data.field('TIME'),soft2[1].data.field('RATE'),err=soft2[1].data.field('ERROR'),gti=soft_gti2,input_counts=False)
soft_bkg2 = st.Lightcurve(sbkg2[1].data.field('TIME'),sbkg2[1].data.field('RATE'),err=sbkg2[1].data.field('ERROR'),gti=soft_gti2,input_counts=False)

hard_lc2 = st.Lightcurve(hard2[1].data.field('TIME'),hard2[1].data.field('RATE'),err=hard2[1].data.field('ERROR'),gti=hard_gti2,input_counts=False)
hard_bkg2 = st.Lightcurve(hbkg2[1].data.field('TIME'),hbkg2[1].data.field('RATE'),err=hbkg2[1].data.field('ERROR'),gti=hard_gti2,input_counts=False)

full_lc2.apply_gtis()
full_bkg2.apply_gtis()
soft_lc2.apply_gtis()
soft_bkg2.apply_gtis()
hard_lc2.apply_gtis()
hard_bkg2.apply_gtis()
# Out:
# /home/rwebbe/.local/lib/python3.8/site-packages/stingray/lightcurve.py:516: UserWarning: There are non-finite points in the data, but they are outside GTIs.
#   warnings.warn("There are non-finite points in the data, but they are outside GTIs. ")

# %%
plt.plot(full_lc1.time,full_lc1.countrate,color='k')
plt.plot(soft_lc1.time,soft_lc1.countrate,color='r')
plt.plot(hard_lc1.time,hard_lc1.countrate,color='b')

# %%
plt.plot(full_lc2.time,full_lc2.countrate,color='k')
plt.plot(soft_lc2.time,soft_lc2.countrate,color='r')
plt.plot(hard_lc2.time,hard_lc2.countrate,color='b')

# %%
plt.plot(full_lc1.rebin(50).time,full_lc1.rebin(50).countrate,color='k')
plt.plot(soft_lc1.rebin(50).time,soft_lc1.rebin(50).countrate,color='r')
plt.plot(hard_lc1.rebin(50).time,hard_lc1.rebin(50).countrate,color='b')

# %%
plt.plot(full_lc2.rebin(50).time,full_lc2.rebin(50).countrate,color='k')
plt.plot(soft_lc2.rebin(50).time,soft_lc2.rebin(50).countrate,color='r')
plt.plot(hard_lc2.rebin(50).time,hard_lc2.rebin(50).countrate,color='b')

# %%
plt.plot(hard_lc2.rebin(50).time,hard_lc2.rebin(50).countrate,color='k')
plt.plot(hard_bkg2.rebin(50).time,hard_bkg2.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(full_lc1.rebin(250).time,full_lc1.rebin(250).countrate,color='k')
plt.plot(soft_lc1.rebin(250).time,soft_lc1.rebin(250).countrate,color='r')
plt.plot(hard_lc1.rebin(250).time,hard_lc1.rebin(250).countrate,color='b')

# %%
plt.plot(full_lc2.rebin(250).time,full_lc2.rebin(250).countrate,color='k')
plt.plot(soft_lc2.rebin(250).time,soft_lc2.rebin(250).countrate,color='r')
plt.plot(hard_lc2.rebin(250).time,hard_lc2.rebin(250).countrate,color='b')

# %%
AllData.clear()
AllModels.clear()
spec = Spectrum("0932190601_PN2grpspec.fits")
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.00005 0.1")
Plot("data")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0932190601_PN2grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  2.779e-02 +/- 2.008e-03 (84.6 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-18
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 8738 sec
#  Using fit statistic: chi
#  Using Background File                0932190601_PN2spec_bkg.fits
#   Background Exposure Time: 8738 sec
#  Using Response (RMF) File            0932190601_PN2spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0932190601_PN2spec.arf

# %%
spec.ignore("**-0.2 12.0-**")
mo1 = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
#      1 channels (1) ignored in spectrum #     1
#      1 channels (18) ignored in spectrum #     1
#
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              4.466781e+11     using 16 bins.
#
# Test statistic : Chi-Squared              4.466781e+11     using 16 bins.
#  Null hypothesis probability of 0.000000e+00 with 13 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 197.628      0.313011      0      0.313602       3.28481   2.34166e-06
# 195.949      229117        0     0.0595848       3.21107   2.44042e-06
# 195.224      293136        0     0.0265231       3.13916   2.53662e-06
# 194.688      293398        0     0.0116352       3.07891   2.61687e-06
# 194.29       284547        0    0.00485604       3.02855   2.68225e-06
# 193.989      271255        0    0.00171927       2.98632   2.73447e-06
# 193.756      256478        0   0.000247104       2.95061   2.77545e-06
# 193.581      241815        0   7.23944e-05       2.92007   2.80704e-06
# 193.44       227693        0   3.05367e-05       2.89372   2.83073e-06
# 193.324      215010        0   1.03369e-05       2.87069   2.84793e-06
# Number of trials exceeded: continue fitting? 193.228      203800        0   5.33260e-07       2.85031   2.85979e-06
# 193.147      193978        0   2.34514e-07       2.83208   2.86724e-06
# 193.079      185427        0   8.83044e-08       2.81560   2.87103e-06
# 193.02       178032        0   1.65262e-08       2.80054   2.87177e-06
# 192.968      171669        0   7.69407e-09       2.78665   2.86998e-06
# 192.923      166222        0   3.33774e-09       2.77374   2.86605e-06
# 192.883      161581        0   1.18522e-09       2.76163   2.86036e-06
# 192.847      157647        0   1.20039e-10       2.75019   2.85317e-06
# 192.814      154330        0   5.40695e-11       2.73931   2.84473e-06
# 192.784      151551        0   2.13503e-11       2.72889   2.83525e-06
# Number of trials exceeded: continue fitting? 192.756      149240        0   5.10797e-12       2.71885   2.82488e-06
# 192.73       147335        0   1.07332e-12       2.70914   2.81378e-06
# 192.706      145778        0   6.96980e-14       2.69969   2.80207e-06
# 192.682      144521        0   7.66409e-15       2.69046   2.78984e-06
# 192.656      143530        0   3.68440e-15       2.68089   2.77856e-06
# 192.638      142008        0   2.60875e-17       2.67255   2.76400e-06
# 192.198      142262        0   1.78187e-18       2.53922   2.74246e-06
# 189.922      58844.3      -1   7.45467e-19       1.74600   1.14017e-06
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 7.45467e-19 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 160.49       1.18182e+06  -2   7.45467e-19      0.675503   5.42469e-07
# Number of trials exceeded: continue fitting? 108.581      1.228e+07    -1   7.45467e-19      0.157945   4.84481e-07
# 62.7465      3.52183e+07  -2   7.45467e-19      0.342639   1.12219e-06
# 37.392       5.11424e+06  -3   7.45467e-19      0.190447   1.14963e-06
# 24.2171      5.20384e+06  -4   7.45467e-19      0.237727   1.28509e-06
# 23.8508      2.31333e+06  -5   7.45467e-19      0.232215   1.32752e-06
# 23.8498      16734.3      -6   7.45467e-19      0.232638   1.32814e-06
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 7.45467e-19 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 23.8498      166.49       -3   7.45467e-19      0.232623   1.32813e-06
# ==============================
#  Variances and Principal Axes
#                  2        3
#  9.8575E-15| -0.0000   1.0000
#  1.6993E-04|  1.0000   0.0000
# ------------------------------
#
# ========================
#   Covariance Matrix
#         1           2
#    1.699e-04   1.158e-10
#    1.158e-10   9.936e-15
# ------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    7.45467E-19  +/-  -1.00000
#    2    2   bbody      kT         keV      0.232623     +/-  1.30357E-02
#    3    2   bbody      norm                1.32813E-06  +/-  9.96817E-08
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   23.85     using 16 bins.
#
# Test statistic : Chi-Squared                   23.85     using 16 bins.
#  Null hypothesis probability of 3.25e-02 with 13 degrees of freedom
#  Model Flux 9.7887e-05 photons (1.0868e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
mo2 = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.596755e+11     using 16 bins.
#
# Test statistic : Chi-Squared              1.596755e+11     using 16 bins.
#  Null hypothesis probability of 0.000000e+00 with 13 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 180.003      1.98888       0      0.352856       1.29382   7.10894e-06
# 165.935      376531        0      0.167054       1.71415   7.93679e-06
# 77.9025      655786       -1     0.0434130       3.36444   1.99732e-05
# 47.4907      168943       -1     0.0691347       2.44444   3.54731e-05
# 36.5877      182278       -2      0.226240       3.63220   6.26929e-05
# 33.2334      118136       -3      0.391181       4.64627   0.000110019
# 29.5132      66718.1      -4      0.469280       5.13901   0.000156484
# 29.0255      18353.8      -5      0.486404       5.24899   0.000173315
# 29.0221      1271.43      -6      0.490557       5.27557   0.000176171
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.7419E-10| -0.0007   0.0000   1.0000
#  9.1125E-04|  0.9889  -0.1488   0.0007
#  1.1075E+00|  0.1488   0.9889   0.0001
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.543e-02   1.629e-01   1.341e-05
#    1.629e-01   1.083e+00   8.471e-05
#    1.341e-05   8.471e-05   7.286e-09
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.490557     +/-  0.159460
#    2    2   powerlaw   PhoIndex            5.27557      +/-  1.04065
#    3    2   powerlaw   norm                1.76171E-04  +/-  8.53605E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   29.02     using 16 bins.
#
# Test statistic : Chi-Squared                   29.02     using 16 bins.
#  Null hypothesis probability of 6.50e-03 with 13 degrees of freedom
#  Model Flux 7.2365e-05 photons (1.0067e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
mo3 = Model("tbabs*(bbody+powerlaw)")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>(bbody<2> + powerlaw<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
#    4    3   powerlaw   PhoIndex            1.00000      +/-  0.0
#    5    3   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.123433e+12     using 16 bins.
#
# Test statistic : Chi-Squared              1.123433e+12     using 16 bins.
#  Null hypothesis probability of 0.000000e+00 with 11 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm    4:PhoIndex        5:norm
# 195.581      86214.3      -1      0.126522       4.13361   6.09101e-07       2.89623   9.78719e-07
# 144.029      640861        0     0.0529115       2.64710   1.12540e-06       5.41569   5.26382e-06
# 125.533      1.20915e+06   0     0.0633703       1.85193   1.58927e-06       5.24763   5.20437e-06
# 107.528      108058       -1     0.0902446       1.06840   2.96603e-07       4.37653   9.62272e-06
# 76.3353      2.37005e+06  -1      0.114396      0.379774   5.10018e-08       3.14924   2.31202e-05
# 49.1445      7.69105e+06  -1      0.100852     0.0164245   2.23380e-07       2.53490   3.88040e-05
# 35.0811      119668       -2      0.243427    0.00993968      0.250426       3.76134   6.79658e-05
# 35.081       57995.9       4      0.243427    0.00995799       2.49788       3.76134   6.79659e-05
# ============================================================
#  Variances and Principal Axes
#                  1        2        3        4        5
#  3.6005E-11| -0.0003   0.0000   0.0000   0.0000   1.0000
#  8.6700E-04|  0.9898  -0.0000  -0.0000  -0.1425   0.0003
#  5.9915E-01|  0.1425  -0.0006  -0.0000   0.9898   0.0000
#  6.1813E+05|  0.0001   1.0000   0.0013   0.0006   0.0000
#  7.4257E+16|  0.0000   0.0013  -1.0000   0.0000   0.0000
# ------------------------------------------------------------
#
# ============================================================
#   Covariance Matrix
#         1           2           3           4           5
#    2.538e-02   2.497e+04  -1.906e+07   1.388e-01   5.477e-06
#    2.497e+04   1.268e+11  -9.703e+13   7.346e+04   4.484e+00
#   -1.906e+07  -9.703e+13   7.426e+16  -5.595e+07  -3.420e+03
#    1.388e-01   7.346e+04  -5.595e+07   8.442e-01   3.003e-05
#    5.477e-06   4.484e+00  -3.420e+03   3.003e-05   1.235e-09
# ------------------------------------------------------------
#
# ========================================================================
# Model TBabs<1>(bbody<2> + powerlaw<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.243427     +/-  0.159297
#    2    2   bbody      kT         keV      9.95799E-03  +/-  3.56056E+05
#    3    2   bbody      norm                2.49788      +/-  2.72501E+08
#    4    3   powerlaw   PhoIndex            3.76134      +/-  0.918781
#    5    3   powerlaw   norm                6.79659E-05  +/-  3.51401E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   35.08     using 16 bins.
#
# Test statistic : Chi-Squared                   35.08     using 16 bins.
#  Null hypothesis probability of 2.40e-04 with 11 degrees of freedom
#  Model Flux 6.8466e-05 photons (9.7624e-14 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
Plot.device = "/svg"
mo4 = Model("tbabs*(apec+apec)")
mo4.apec.kT = 0.5
#mo4.apec.kT.frozen = True
mo4.apec_3.kT = 4.0
#mo4.apec_3.kT.frozen = True
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              1.049931e+10     using 16 bins.
#
# Test statistic : Chi-Squared              1.049931e+10     using 16 bins.
#  Null hypothesis probability of 0.000000e+00 with 11 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              5.508304e+09     using 16 bins.
#
# Test statistic : Chi-Squared              5.508304e+09     using 16 bins.
#  Null hypothesis probability of 0.000000e+00 with 11 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              5.652563e+09     using 16 bins.
#
# Test statistic : Chi-Squared              5.652563e+09     using 16 bins.
#  Null hypothesis probability of 0.000000e+00 with 11 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm          6:kT        9:norm
# 79.4187      33209.5      -3      0.238519       1.07565   4.36246e-05       18.7556   3.29913e-05
# 54.3986      67657.3       0      0.164717      0.963573   4.28324e-05       13.6187   2.62772e-05
# 34.8123      15746.9      -1   0.000993911      0.916914   2.25685e-05       6.22643   1.63883e-05
# 27.1431      188235        0   7.65498e-05      0.913560   2.23575e-05       3.06225   2.46864e-05
# 24.3225      107872        0   2.65493e-05      0.907270   2.17100e-05       2.29853   2.94465e-05
# 23.6164      60802.7       0   3.52311e-06      0.898584   2.09393e-05       2.38925   3.19736e-05
# 23.1644      63962.2       0   6.55526e-07      0.891184   2.02807e-05       2.40401   3.39000e-05
# 22.9013      66251.1       0   2.96480e-07      0.885374   1.97259e-05       2.39652   3.53434e-05
# 22.7431      69360.1       0   1.16151e-07      0.880508   1.92610e-05       2.37831   3.64259e-05
# 22.6446      72626.1       0   2.55464e-08      0.876286   1.88720e-05       2.35518   3.72433e-05
# Number of trials exceeded: continue fitting? 22.5814      75684.3       0   2.79685e-09      0.872560   1.85463e-05       2.33027   3.78658e-05
# 22.5397      78393.4       0   1.36995e-09      0.869255   1.82729e-05       2.30539   3.83445e-05
# 22.5148      80730.8       0   6.54239e-10      0.866207   1.80456e-05       2.28980   3.87318e-05
# 22.4941      82880.1       0   2.95743e-10      0.863266   1.78565e-05       2.28161   3.90618e-05
# 22.4733      84537.1       0   1.16519e-10      0.860559   1.76953e-05       2.27377   3.93390e-05
# 22.4545      85973.9       0   2.69576e-11      0.858204   1.75595e-05       2.26638   3.95711e-05
# 22.439       87292.5       0   4.58494e-12      0.856246   1.74470e-05       2.25815   3.97600e-05
# 22.4267      88227.8       0   1.79097e-12      0.854607   1.73518e-05       2.24888   3.99081e-05
# 22.4184      88928.2       0   3.95072e-13      0.853226   1.72707e-05       2.23966   4.00226e-05
# ============================================================
#  Variances and Principal Axes
#                  1        2        5        6        9
#  4.5995E-12| -0.0001  -0.0000   0.9761  -0.0000   0.2174
#  9.2257E-11| -0.0001   0.0001  -0.2174  -0.0000   0.9761
#  1.3108E-03| -0.9546  -0.2977  -0.0001   0.0108  -0.0001
#  4.3307E-03|  0.2979  -0.9538  -0.0000   0.0378   0.0001
#  8.9936E-01|  0.0009  -0.0393  -0.0000  -0.9992  -0.0000
# ------------------------------------------------------------
#
# ============================================================
#   Covariance Matrix
#         1           2           3           4           5
#    1.580e-03  -8.901e-04   8.927e-08  -7.768e-04   1.593e-07
#   -8.901e-04   5.446e-03   1.269e-07   3.516e-02  -1.243e-07
#    8.927e-08   1.269e-07   2.071e-11   1.814e-06  -7.435e-12
#   -7.768e-04   3.516e-02   1.814e-06   8.980e-01   3.297e-06
#    1.593e-07  -1.243e-07  -7.435e-12   3.297e-06   1.244e-10
# ------------------------------------------------------------
#
# ========================================================================
# Model TBabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    3.95072E-13  +/-  3.97439E-02
#    2    2   apec       kT         keV      0.853226     +/-  7.37936E-02
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.72707E-05  +/-  4.55111E-06
#    6    3   apec       kT         keV      2.23966      +/-  0.947614
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                4.00226E-05  +/-  1.11556E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   22.42     using 16 bins.
#
# Test statistic : Chi-Squared                   22.42     using 16 bins.
#  Null hypothesis probability of 2.13e-02 with 11 degrees of freedom
#  Model Flux 9.0834e-05 photons (1.253e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
flux = 1.13398*10**-13
d_pc = 241
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')

d_pc = 229
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')
# Out:
# Luminosity is: 7.90253272561412e+29 erg s^-1
# Luminosity is: 7.135151231279252e+29 erg s^-1

# %%
AllData.clear()
AllModels.clear()
spec = Spectrum("0932190901_PN1grpspec.fits")
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.00005 0.1")
Plot("data")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0932190901_PN1grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  3.299e-02 +/- 3.472e-03 (75.6 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-24
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 8713 sec
#  Using fit statistic: chi
#  Using Background File                0932190901_PN1spec_bkg.fits
#   Background Exposure Time: 8713 sec
#  Using Response (RMF) File            0932190901_PN1spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0932190901_PN1spec.arf

# %%
spec.ignore("**-0.2 12.0-**")
mo1 = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
#      1 channels (1) ignored in spectrum #     1
#      1 channels (24) ignored in spectrum #     1
#
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              5.597799e+11     using 22 bins.
#
# Test statistic : Chi-Squared              5.597799e+11     using 22 bins.
#  Null hypothesis probability of 0.000000e+00 with 19 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 190.639      0.595477      0      0.133987       3.08887   5.94405e-06
# 188.289      229928        0    0.00915429       3.06502   5.99992e-06
# 187.827      250983        0    0.00196154       3.03935   6.05785e-06
# 187.541      227709        0   0.000251498       3.01679   6.10381e-06
# 187.34       204568        0   4.51041e-05       2.99708   6.13875e-06
# 187.183      183669        0   1.99952e-05       2.97979   6.16427e-06
# 187.055      165501        0   7.72163e-06       2.96445   6.18196e-06
# 186.95       149835        0   1.70159e-06       2.95072   6.19315e-06
# 186.862      136366        0   2.21049e-07       2.93830   6.19894e-06
# 186.787      124809        0   3.85665e-08       2.92697   6.20023e-06
# Number of trials exceeded: continue fitting? 186.723      114912        0   1.60313e-08       2.91652   6.19777e-06
# 186.667      106449        0   4.88176e-09       2.90683   6.19215e-06
# 186.616      99220.4       0   2.11987e-09       2.89774   6.18391e-06
# 186.571      93052         0   7.50014e-10       2.88917   6.17347e-06
# 186.53       87792.7       0   6.99547e-11       2.88103   6.16117e-06
# 186.491      83311.9       0   2.77196e-11       2.87324   6.14733e-06
# 186.455      79496.1       0   6.72151e-12       2.86574   6.13219e-06
# 186.422      76248         0   1.49917e-12       2.85849   6.11596e-06
# 186.389      73486.1       0   1.99518e-13       2.85145   6.09881e-06
# 186.359      71137.1       0   3.79600e-14       2.84462   6.08070e-06
# Number of trials exceeded: continue fitting? 186.328      69235.5       0   1.75379e-14       2.83783   6.06245e-06
# 186.3        67397.2       0   7.50234e-15       2.83137   6.04244e-06
# 186.272      66362         0   2.38264e-15       2.82492   6.02245e-06
# 186.236      65325.7       0   2.29565e-16       2.81740   6.00750e-06
# 186.177      61784.6       0   7.64913e-17       2.80631   6.00500e-06
# 185.884      50918         0   5.62600e-18       2.74198   5.83612e-06
# 182.783      30226        -1   1.91536e-18       2.16562   3.67035e-06
# 172.982      283825       -1   5.77493e-20       1.34501   1.88577e-06
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 5.77493e-20 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 132.92       2.15276e+06  -2   5.77493e-20      0.522229   1.11400e-06
# Number of trials exceeded: continue fitting? 105.238      6.44616e+06  -1   5.77493e-20      0.151803   9.68327e-07
# 67.172       1.05643e+06  -2   5.77493e-20      0.270407   1.05133e-06
# 53.3967      1.58974e+07  -3   5.77493e-20      0.251371   1.43239e-06
# 53.272       496391       -4   5.77493e-20      0.256655   1.43431e-06
# 53.272       9778.88      -5   5.77493e-20      0.256656   1.43455e-06
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 5.77493e-20 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 53.272       4.53611      -3   5.77493e-20      0.256656   1.43455e-06
# ==============================
#  Variances and Principal Axes
#                  2        3
#  1.2432E-14| -0.0000   1.0000
#  2.5203E-04|  1.0000   0.0000
# ------------------------------
#
# ========================
#   Covariance Matrix
#         1           2
#    2.520e-04   6.508e-10
#    6.508e-10   1.411e-14
# ------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    5.77493E-20  +/-  -1.00000
#    2    2   bbody      kT         keV      0.256656     +/-  1.58755E-02
#    3    2   bbody      norm                1.43455E-06  +/-  1.18796E-07
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   53.27     using 22 bins.
#
# Test statistic : Chi-Squared                   53.27     using 22 bins.
#  Null hypothesis probability of 4.26e-05 with 19 degrees of freedom
#  Model Flux 9.7747e-05 photons (1.1804e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
mo2 = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.117341e+11     using 22 bins.
#
# Test statistic : Chi-Squared              1.117341e+11     using 22 bins.
#  Null hypothesis probability of 0.000000e+00 with 19 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 180.883      2.29317      -1      0.349171      0.933243   8.41419e-06
# 148.469      503162        0     0.0218373      0.920131   9.34303e-06
# 106.281      869523       -1    0.00209689       1.35356   1.70926e-05
# 64.4965      672312       -2     0.0508425       2.29446   3.90917e-05
# 56.8998      73916.6      -3      0.164785       2.73019   6.28462e-05
# 54.0487      72762.6      -4      0.239379       3.22591   8.63817e-05
# 52.7209      28434.6      -5      0.306270       3.67770   0.000110337
# 51.9547      14113.2      -6      0.369096       4.09925   0.000136259
# 51.4989      8698.06      -7      0.423907       4.46818   0.000162834
# 51.2546      5228.97      -8      0.468039       4.76577   0.000187472
# Number of trials exceeded: continue fitting? 51.1389      2847.32      -9      0.500932       4.98799   0.000207891
# 51.0891      1380.79     -10      0.524048       5.14434   0.000223279
# 51.0688      610.661     -11      0.539620       5.24973   0.000234093
# 51.0608      253.831     -12      0.549807       5.31870   0.000241347
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  3.2739E-10| -0.0010   0.0000   1.0000
#  1.0733E-03|  0.9883  -0.1528   0.0010
#  1.0408E+00|  0.1528   0.9883   0.0001
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.535e-02   1.570e-01   1.806e-05
#    1.570e-01   1.017e+00   1.100e-04
#    1.806e-05   1.100e-04   1.328e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.549807     +/-  0.159224
#    2    2   powerlaw   PhoIndex            5.31870      +/-  1.00825
#    3    2   powerlaw   norm                2.41347E-04  +/-  1.15239E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   51.06     using 22 bins.
#
# Test statistic : Chi-Squared                   51.06     using 22 bins.
#  Null hypothesis probability of 9.13e-05 with 19 degrees of freedom
#  Model Flux 7.6231e-05 photons (1.1283e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
mo3 = Model("tbabs*(bbody+powerlaw)")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>(bbody<2> + powerlaw<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
#    4    3   powerlaw   PhoIndex            1.00000      +/-  0.0
#    5    3   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.131139e+12     using 22 bins.
#
# Test statistic : Chi-Squared              1.131139e+12     using 22 bins.
#  Null hypothesis probability of 0.000000e+00 with 17 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm    4:PhoIndex        5:norm
# 186.776      78498.2      -1      0.219356       3.19649   5.50977e-06       1.46458   1.91009e-06
# 165.877      354399       -1     0.0577296       2.86542   8.30628e-06       6.94084   7.24948e-07
# 141.645      1.34662e+06  -2     0.0308160      0.916782   1.67614e-06       2.69180   3.13308e-06
# 109.331      597728        0     0.0150483      0.935102   1.53892e-06       3.71260   9.65212e-06
# 86.7182      273891       -1     0.0336841      0.946211   1.39495e-06       2.80895   1.64741e-05
# 81.5476      416137       -1     0.0604762       1.18958   8.44061e-07       1.79369   3.69514e-05
# 78.5759      2.18137e+06  -2      0.182738       3.66666   3.69569e-07       2.31810   8.33125e-05
# 53.5346      137197       -3      0.387789       1.66169   5.87443e-08       4.42037   0.000126633
# 52.8966      1.47397e+06  -2      0.505602       31.5728   3.09068e-06       5.11138   0.000187419
# 44.4529      16041.5       1      0.505449       9.65258   2.81148e-05       5.11188   0.000187621
# Number of trials exceeded: continue fitting? 41.4996      28487.1       0      0.504262       9.01039   3.31778e-05       5.11740   0.000189202
# 36.0976      26596.7       0      0.501779       7.64622   4.65433e-05       5.12894   0.000194985
# 35.8378      4111.31      -1      0.512235       7.57869   4.63234e-05       5.18330   0.000205459
# 34.9754      1070.52      -2      0.586744       6.95446   3.77567e-05       5.65431   0.000252992
# 34.4011      3356.72      -2      0.640825       6.22230   2.85262e-05       6.00879   0.000299253
# 34.0377      3217.02      -2      0.682451       5.39671   1.99424e-05       6.28155   0.000339813
# 33.7587      6233         -2      0.716617       4.49414   1.27009e-05       6.50792   0.000375666
# 33.4926      15151.2      -2      0.747116       3.53392   7.23334e-06       6.71346   0.000409375
# 33.1521      40306.3      -2      0.778060       2.58496   3.81812e-06       6.92798   0.000444761
# 32.5733      98796.5      -2      0.814511       1.90874   2.53081e-06       7.18812   0.000487893
# Number of trials exceeded: continue fitting? 32.2989      76131.5      -2      0.854568       1.73818   2.38919e-06       7.46646   0.000541066
# 32.131       2215.82      -2      0.890381       1.66582   2.29289e-06       7.70034   0.000597547
# 32.001       3169.65      -2      0.921859       1.60590   2.22010e-06       7.90614   0.000652360
# 31.9011      2448.54      -2      0.949695       1.55825   2.16667e-06       8.08739   0.000704826
# 31.8759      1774.9       -3       1.06499       1.39804   2.00361e-06       8.83715   0.000929605
# 31.8677      27076.3      -3       1.12547       1.34837   1.98677e-06       9.13787    0.00112213
# ============================================================
#  Variances and Principal Axes
#                  1        2        3        4        5
#  1.8607E-13|  0.0000   0.0000  -1.0000   0.0000  -0.0003
#  5.9164E-09| -0.0040  -0.0000  -0.0003   0.0002   1.0000
#  1.8167E-03|  0.9880  -0.0139  -0.0000  -0.1535   0.0040
#  2.0827E-01|  0.0347   0.9904   0.0000   0.1338   0.0001
#  6.4058E+00| -0.1502   0.1375   0.0000  -0.9791  -0.0004
# ------------------------------------------------------------
#
# ============================================================
#   Covariance Matrix
#         1           2           3           4           5
#    1.465e-01  -1.251e-01  -7.659e-08   9.425e-01   3.702e-04
#   -1.251e-01   3.254e-01   3.376e-07  -8.347e-01  -3.055e-04
#   -7.659e-08   3.376e-07   5.684e-13  -5.157e-07  -1.852e-10
#    9.425e-01  -8.347e-01  -5.157e-07   6.144e+00   2.363e-03
#    3.702e-04  -3.055e-04  -1.852e-10   2.363e-03   9.458e-07
# ------------------------------------------------------------
#
# ========================================================================
# Model TBabs<1>(bbody<2> + powerlaw<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.12547      +/-  0.382719
#    2    2   bbody      kT         keV      1.34837      +/-  0.570418
#    3    2   bbody      norm                1.98677E-06  +/-  7.53893E-07
#    4    3   powerlaw   PhoIndex            9.13787      +/-  2.47872
#    5    3   powerlaw   norm                1.12213E-03  +/-  9.72519E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   31.87     using 22 bins.
#
# Test statistic : Chi-Squared                   31.87     using 22 bins.
#  Null hypothesis probability of 1.56e-02 with 17 degrees of freedom
#  Model Flux 8.6468e-05 photons (2.3179e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
mo4 = Model("tbabs*(apec+apec)")
mo4.apec.kT = 0.5
#mo4.apec.kT.frozen = True
mo4.apec_3.kT = 4.0
#mo4.apec_3.kT.frozen = True
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              7.752449e+09     using 22 bins.
#
# Test statistic : Chi-Squared              7.752449e+09     using 22 bins.
#  Null hypothesis probability of 0.000000e+00 with 17 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              3.889003e+09     using 22 bins.
#
# Test statistic : Chi-Squared              3.889003e+09     using 22 bins.
#  Null hypothesis probability of 0.000000e+00 with 17 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              3.379268e+09     using 22 bins.
#
# Test statistic : Chi-Squared              3.379268e+09     using 22 bins.
#  Null hypothesis probability of 0.000000e+00 with 17 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm          6:kT        9:norm
# 148.784      20431.1      -3     0.0714461       1.01407   5.97259e-05       10.6041   6.34881e-05
# 46.6087      602996       -4     0.0306589      0.991974   2.70458e-05       24.9432   8.30101e-05
# 44.8824      87273        -1     0.0123930      0.923208   1.52352e-05       43.1145   8.88456e-05
# 36.293       215421       -2   0.000461798      0.831394   1.39945e-05       56.0624   0.000132414
# 33.7365      112245       -2   0.000140236      0.805695   1.59032e-05       63.4824   0.000133131
# 32.1078      34722.7      -1   2.48021e-05      0.795017   1.61343e-05       63.7795   0.000119085
# 32.0823      62725.5      -1   9.94353e-06      0.795578   1.61060e-05       63.9309   0.000112680
# 31.6223      85153.4       0   4.31789e-06      0.787933   1.65854e-05       63.9759   0.000110633
# 31.4345      66315.3       0   1.74606e-06      0.785062   1.68851e-05       63.9951   0.000109051
# 31.3493      56085.5       0   5.24074e-07      0.784151   1.70795e-05       63.9990   0.000107851
# Number of trials exceeded: continue fitting? 31.3084      50460.1       0   2.27412e-07      0.784025   1.72095e-05       63.9997   0.000106949
# 31.2882      47289         0   8.16199e-08      0.784182   1.72985e-05       63.9999   0.000106277
# 31.2782      45440.3       0   9.48429e-09      0.784413   1.73606e-05       64.0000   0.000105779
# 31.2732      44323.7       0   5.26527e-10      0.784637   1.74044e-05       64.0000   0.000105411
# ============================================================
#  Variances and Principal Axes
#                  1        2        5        6        9
#  4.2728E-12|  0.0001   0.0000  -0.9975   0.0000  -0.0706
#  3.3401E-10| -0.0002   0.0000  -0.0706  -0.0000   0.9975
#  8.6383E-04|  0.9780   0.2088   0.0001   0.0000   0.0002
#  3.3200E-03|  0.2088  -0.9780   0.0000   0.0000   0.0001
#  3.3751E+05| -0.0000   0.0000   0.0000   1.0000   0.0000
# ------------------------------------------------------------
#
# ============================================================
#   Covariance Matrix
#         1           2           3           4           5
#    1.541e-03  -7.711e-04   7.251e-08  -1.387e+01  -2.554e-06
#   -7.711e-04   3.340e-03   9.240e-09   6.560e+00   1.101e-06
#    7.251e-08   9.240e-09   1.233e-11   4.065e-05  -2.590e-12
#   -1.387e+01   6.560e+00   4.065e-05   3.375e+05   6.667e-02
#   -2.554e-06   1.101e-06  -2.590e-12   6.667e-02   1.354e-08
# ------------------------------------------------------------
#
# ========================================================================
# Model TBabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    5.26527E-10  +/-  3.92545E-02
#    2    2   apec       kT         keV      0.784637     +/-  5.77961E-02
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.74044E-05  +/-  3.51168E-06
#    6    3   apec       kT         keV      64.0000      +/-  580.957
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.05411E-04  +/-  1.16372E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   31.27     using 22 bins.
#
# Test statistic : Chi-Squared                   31.27     using 22 bins.
#  Null hypothesis probability of 1.85e-02 with 17 degrees of freedom
#  Model Flux 0.00011201 photons (2.7275e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
from matplotlib.ticker import StrMethodFormatter, NullFormatter
emin = 0.2
emax = 10
fig, (ax1,ax2) = plt.subplots(2, 1, sharex=True, gridspec_kw={'height_ratios': [3, 1], 'hspace':0},figsize=(12,8))
ax1.set_xscale('log')
ax1.set_yscale('log')
ax1.set_xlim(emin, emax)
ax1.set_ylabel('counts s$^{-1}$ keV$^{-1}$')
ax1.errorbar(Plot.x(), Plot.y(),Plot.yErr(), Plot.xErr(),ls=' ', color='k')
ax1.plot(Plot.x(),Plot.model(), color='r')
ax2.set_xscale('log')
ax2.set_xlim(emin, emax)
ax2.set_xlabel('Energy (keV)')
ax2.set_ylabel('Norm. Residual')
ax2.xaxis.set_major_formatter(StrMethodFormatter('{x:.0f}'))
ax2.xaxis.set_minor_formatter(NullFormatter())
ax2.errorbar(Plot.x(), (np.asarray(Plot.y())-np.asarray(Plot.model()))/Plot.yErr(),1,Plot.xErr(), ls=' ', color='k')
ax2.hlines(0,emin, emax,color='k', lw=0.5)
plt.savefig('HD314680B_model_fit_plot.png')

# %%
flux = 5.7068*10**-13
d_pc = 241
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')

d_pc = 229
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')
# Out:
# Luminosity is: 3.9769814069502695e+30 erg s^-1
# Luminosity is: 3.5907935807213914e+30 erg s^-1
