# %% [markdown]
# Obs 0934200101 source 030. Not first X-ray detection. (262.7402, -33.5135, 0.88")
#
# No SIMBAD
#
# ALSO XMM
# + 0916800801 src 2
# + 0916800701 src 1
# + 0916800401 src 7
#
#
# Vizier - Gaia 4054449990740365696 1.44"
# + Parallax 1.30. Distance 770 pc.
# + Teff unknown
# + Rstar unknown
# + Mstar unknown
#
# Vizier - Gaia 4054449990732887168 3.0"
# + Parallax 2.15. Distance 464 pc.
# + Teff unknown
# + Rstar unknown
# + Mstar unknown

# %%
# %load_ext wurlitzer
import numpy as np
import os
import stingray as st
import matplotlib.pyplot as plt
from astropy.io import fits
from xspec import *
plt.rcParams['figure.figsize'] = [15, 8]

lc = fits.open('0934200101_030/0934200101_PN30_dt1.lc')
bkg = fits.open('0934200101_030/0934200101_PN30_dt1_bkg.lc')
full_gti = []
for j in lc[2].data:
    full_gti.append([j[0],j[1]])
soft = fits.open('0934200101_030/0934200101_PN30_dt1_0.2-2keV.lc')
sbkg = fits.open('0934200101_030/0934200101_PN30_dt1_0.2-2keV_bkg.lc')
soft_gti = []
for j in soft[2].data:
    soft_gti.append([j[0],j[1]])
hard = fits.open('0934200101_030/0934200101_PN30_dt1_2-12keV.lc')
hbkg = fits.open('0934200101_030/0934200101_PN30_dt1_2-12keV_bkg.lc')
hard_gti = []
for j in hard[2].data:
    hard_gti.append([j[0],j[1]])

# %%
full_lc = st.Lightcurve(lc[1].data.field('TIME'),lc[1].data.field('RATE'),err=lc[1].data.field('ERROR'),gti=full_gti,input_counts=False)
full_bkg = st.Lightcurve(bkg[1].data.field('TIME'),bkg[1].data.field('RATE'),err=bkg[1].data.field('ERROR'),gti=full_gti,input_counts=False)

soft_lc = st.Lightcurve(soft[1].data.field('TIME'),soft[1].data.field('RATE'),err=soft[1].data.field('ERROR'),gti=soft_gti,input_counts=False)
soft_bkg = st.Lightcurve(sbkg[1].data.field('TIME'),sbkg[1].data.field('RATE'),err=sbkg[1].data.field('ERROR'),gti=soft_gti,input_counts=False)

hard_lc = st.Lightcurve(hard[1].data.field('TIME'),hard[1].data.field('RATE'),err=hard[1].data.field('ERROR'),gti=hard_gti,input_counts=False)
hard_bkg = st.Lightcurve(hbkg[1].data.field('TIME'),hbkg[1].data.field('RATE'),err=hbkg[1].data.field('ERROR'),gti=hard_gti,input_counts=False)

full_lc.apply_gtis()
full_bkg.apply_gtis()
soft_lc.apply_gtis()
soft_bkg.apply_gtis()
hard_lc.apply_gtis()
hard_bkg.apply_gtis()
# Out:
# /home/rwebbe/.local/lib/python3.8/site-packages/stingray/lightcurve.py:516: UserWarning: There are non-finite points in the data, but they are outside GTIs.
#   warnings.warn("There are non-finite points in the data, but they are outside GTIs. ")
# /home/rwebbe/.local/lib/python3.8/site-packages/stingray/lightcurve.py:516: UserWarning: There are non-finite points in the data, but they are outside GTIs.
#   warnings.warn("There are non-finite points in the data, but they are outside GTIs. ")

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(soft_lc.time,soft_lc.countrate,color='r')
plt.plot(hard_lc.time,hard_lc.countrate,color='b')

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(full_bkg.time,full_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.time,soft_lc.countrate,color='k')
plt.plot(soft_bkg.time,soft_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.time,hard_lc.countrate,color='k')
plt.plot(hard_bkg.time,hard_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='r')
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='b')

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(full_bkg.rebin(50).time,full_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='k')
plt.plot(soft_bkg.rebin(50).time,soft_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='k')
plt.plot(hard_bkg.rebin(50).time,hard_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='r')
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='b')

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(full_bkg.rebin(250).time,full_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='k')
plt.plot(soft_bkg.rebin(250).time,soft_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='k')
plt.plot(hard_bkg.rebin(250).time,hard_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
os.chdir("0934200101_030")
spec = Spectrum("0934200101_PN30grpspec.fits")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0934200101_PN30grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  3.006e-02 +/- 4.530e-03 (19.3 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-81
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 1.374e+04 sec
#  Using fit statistic: chi
#  Using Background File                0934200101_PN30spec_bkg.fits
#   Background Exposure Time: 1.374e+04 sec
#  Using Response (RMF) File            0934200101_PN30spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0934200101_PN30spec.arf

# %%
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.0001 0.05")
Plot("data")

# %%
spec.ignore("**-0.2 12.0-**")
mo1 = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
#      2 channels (1-2) ignored in spectrum #     1
#      7 channels (75-81) ignored in spectrum #     1
#
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              2.550918e+10     using 72 bins.
#
# Test statistic : Chi-Squared              2.550918e+10     using 72 bins.
#  Null hypothesis probability of 0.000000e+00 with 69 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 133.613      0.58572       0      0.316606       3.30818   1.26606e-05
# 132.698      64176.7       0      0.110882       3.40912   1.20493e-05
# 130.33       86812.4       0     0.0325362       3.22986   1.30358e-05
# 128.141      92261.3       0     0.0111232       3.01734   1.39515e-05
# 126.97       85090.9       0    0.00415775       2.88019   1.41270e-05
# 126.293      78605.4       0    0.00135336       2.77947   1.38974e-05
# 125.824      75876.4       0   0.000110061       2.69418   1.34752e-05
# 125.447      76066.4       0   3.81817e-05       2.61495   1.29633e-05
# 125.093      78066.7       0   4.16059e-06       2.53819   1.24058e-05
# 124.725      81609.3       0   1.11581e-07       2.46092   1.18331e-05
# Number of trials exceeded: continue fitting? 124.323      86130.6       0   5.13519e-08       2.38189   1.12568e-05
# 123.872      91446.2       0   2.27714e-08       2.30049   1.06823e-05
# 123.36       97526.7       0   9.27389e-09       2.21638   1.01120e-05
# 122.774      104430        0   2.93801e-09       2.12936   9.54754e-06
# 122.097      112265        0   1.46177e-09       2.03929   8.99043e-06
# 121.31       121177        0   9.78177e-11       1.94613   8.44222e-06
# 120.387      131334        0   1.98575e-11       1.84994   7.90486e-06
# 119.302      142918        0   2.24786e-12       1.75095   7.38073e-06
# 118.021      156089        0   2.86844e-13       1.64962   6.87251e-06
# 116.506      170965        0   7.25148e-14       1.54648   6.38470e-06
# Number of trials exceeded: continue fitting? 114.713      187183        0   2.65950e-14       1.44230   5.92162e-06
# 112.669      203758        0   7.29559e-15       1.33999   5.47897e-06
# 111.598      222171       -1   3.46679e-15       1.01941   2.49831e-06
# 85.3286      1.26572e+06  -1   1.17495e-15      0.438183   1.64142e-06
# 80.6528      812574       -2      0.179824      0.304383   2.07980e-06
# 79.9008      1.02113e+06  -2      0.343689      0.251519   3.13094e-06
# 78.5991      820119       -3      0.362132      0.242495   3.85584e-06
# 78.5788      76579.8      -4      0.374747      0.237945   4.07907e-06
# 78.5762      12636.2      -5      0.377949      0.236154   4.14594e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  2.6503E-13| -0.0000   0.0000   1.0000
#  6.9309E-04| -0.2484  -0.9687   0.0000
#  5.4257E-02|  0.9687  -0.2484   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    5.095e-02  -1.289e-02   6.590e-07
#   -1.289e-02   3.998e-03  -1.783e-07
#    6.590e-07  -1.783e-07   8.970e-12
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.377949     +/-  0.225726
#    2    2   bbody      kT         keV      0.236154     +/-  6.32281E-02
#    3    2   bbody      norm                4.14594E-06  +/-  2.99493E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   78.58     using 72 bins.
#
# Test statistic : Chi-Squared                   78.58     using 72 bins.
#  Null hypothesis probability of 2.01e-01 with 69 degrees of freedom
#  Model Flux 5.7116e-05 photons (1.0662e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
mo2 = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              8.006296e+09     using 72 bins.
#
# Test statistic : Chi-Squared              8.006296e+09     using 72 bins.
#  Null hypothesis probability of 0.000000e+00 with 69 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 107.67       3.64636       0      0.490232       1.19600   4.41089e-05
# 97.8997      58109.1      -1      0.181046       1.51009   3.38919e-05
# 96.9936      134275       -2      0.599348       3.40460   0.000108636
# 83.1172      47639.4      -3      0.761344       4.96370   0.000300863
# 80.1742      13868.5      -4      0.971318       5.56454   0.000579641
# 79.6905      5312.67      -5      0.692904       4.52024   0.000289545
# 79.2803      8911.92      -3      0.898742       5.23987   0.000497830
# 77.9892      5210.02      -4      0.760424       4.75989   0.000404866
# 77.9529      111.814      -5      0.867575       5.15650   0.000521152
# 77.8772      1252.73      -6      0.810281       4.94627   0.000460641
# Number of trials exceeded: continue fitting? 77.8676      278.39       -7      0.846070       5.07815   0.000506808
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  3.3668E-09| -0.0010  -0.0001   1.0000
#  8.6458E-03|  0.9827  -0.1851   0.0010
#  3.1761E+00|  0.1851   0.9827   0.0002
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.172e-01   5.761e-01   1.500e-04
#    5.761e-01   3.068e+00   7.506e-04
#    1.500e-04   7.506e-04   1.961e-07
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.846070     +/-  0.342273
#    2    2   powerlaw   PhoIndex            5.07815      +/-  1.75146
#    3    2   powerlaw   norm                5.06808E-04  +/-  4.42802E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   77.87     using 72 bins.
#
# Test statistic : Chi-Squared                   77.87     using 72 bins.
#  Null hypothesis probability of 2.17e-01 with 69 degrees of freedom
#  Model Flux 6.1028e-05 photons (1.2493e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
flux = 1.2493*10**-13
d_pc = 770
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')

d_pc = 464
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')
# Out:
# Luminosity is: 8.887405853896028e+30 erg s^-1
# Luminosity is: 3.227227071547309e+30 erg s^-1

# %%
d_pc = 7500
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')
# Out:
# Luminosity is: 8.431718321498594e+32 erg s^-1
