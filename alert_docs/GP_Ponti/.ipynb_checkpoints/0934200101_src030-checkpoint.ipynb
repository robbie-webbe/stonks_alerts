# %% [markdown]
# Obs 0934200101 source 030. Not first X-ray detection. (262.7402, -33.5135, 0.88")
#
# No SIMBAD
#
# ALSO XMM
# + 0916800801 src 2
# + 0916800701 src 1
# + 0916800401 src 7
#
#
# Vizier - Gaia 4054449990740365696 1.44"
# + Parallax 1.30. Distance 770 pc.
# + Teff unknown
# + Rstar unknown
# + Mstar unknown
#
# Vizier - Gaia 4054449990732887168 3.0"
# + Parallax 2.15. Distance 464 pc.
# + Teff unknown
# + Rstar unknown
# + Mstar unknown

# %%
# %load_ext wurlitzer
import numpy as np
import os
import stingray as st
import matplotlib.pyplot as plt
from astropy.io import fits
from xspec import *
plt.rcParams['figure.figsize'] = [15, 8]

lc = fits.open('0934200101_030/0934200101_PN30_dt1.lc')
bkg = fits.open('0934200101_030/0934200101_PN30_dt1_bkg.lc')
full_gti = []
for j in lc[2].data:
    full_gti.append([j[0],j[1]])
soft = fits.open('0934200101_030/0934200101_PN30_dt1_0.2-2keV.lc')
sbkg = fits.open('0934200101_030/0934200101_PN30_dt1_0.2-2keV_bkg.lc')
soft_gti = []
for j in soft[2].data:
    soft_gti.append([j[0],j[1]])
hard = fits.open('0934200101_030/0934200101_PN30_dt1_2-12keV.lc')
hbkg = fits.open('0934200101_030/0934200101_PN30_dt1_2-12keV_bkg.lc')
hard_gti = []
for j in hard[2].data:
    hard_gti.append([j[0],j[1]])

# %%
full_lc = st.Lightcurve(lc[1].data.field('TIME'),lc[1].data.field('RATE'),err=lc[1].data.field('ERROR'),gti=full_gti,input_counts=False)
full_bkg = st.Lightcurve(bkg[1].data.field('TIME'),bkg[1].data.field('RATE'),err=bkg[1].data.field('ERROR'),gti=full_gti,input_counts=False)

soft_lc = st.Lightcurve(soft[1].data.field('TIME'),soft[1].data.field('RATE'),err=soft[1].data.field('ERROR'),gti=soft_gti,input_counts=False)
soft_bkg = st.Lightcurve(sbkg[1].data.field('TIME'),sbkg[1].data.field('RATE'),err=sbkg[1].data.field('ERROR'),gti=soft_gti,input_counts=False)

hard_lc = st.Lightcurve(hard[1].data.field('TIME'),hard[1].data.field('RATE'),err=hard[1].data.field('ERROR'),gti=hard_gti,input_counts=False)
hard_bkg = st.Lightcurve(hbkg[1].data.field('TIME'),hbkg[1].data.field('RATE'),err=hbkg[1].data.field('ERROR'),gti=hard_gti,input_counts=False)

full_lc.apply_gtis()
full_bkg.apply_gtis()
soft_lc.apply_gtis()
soft_bkg.apply_gtis()
hard_lc.apply_gtis()
hard_bkg.apply_gtis()
# Out:
# /home/rwebbe/.local/lib/python3.8/site-packages/stingray/lightcurve.py:516: UserWarning: There are non-finite points in the data, but they are outside GTIs.
#   warnings.warn("There are non-finite points in the data, but they are outside GTIs. ")
# /home/rwebbe/.local/lib/python3.8/site-packages/stingray/lightcurve.py:516: UserWarning: There are non-finite points in the data, but they are outside GTIs.
#   warnings.warn("There are non-finite points in the data, but they are outside GTIs. ")

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(soft_lc.time,soft_lc.countrate,color='r')
plt.plot(hard_lc.time,hard_lc.countrate,color='b')

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(full_bkg.time,full_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.time,soft_lc.countrate,color='k')
plt.plot(soft_bkg.time,soft_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.time,hard_lc.countrate,color='k')
plt.plot(hard_bkg.time,hard_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='r')
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='b')

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(full_bkg.rebin(50).time,full_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='k')
plt.plot(soft_bkg.rebin(50).time,soft_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='k')
plt.plot(hard_bkg.rebin(50).time,hard_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='r')
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='b')

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(full_bkg.rebin(250).time,full_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='k')
plt.plot(soft_bkg.rebin(250).time,soft_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='k')
plt.plot(hard_bkg.rebin(250).time,hard_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
os.chdir("0934200101_030")
spec = Spectrum("0934200101_PN30grpspec.fits")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0934200101_PN30grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  3.849e-02 +/- 3.900e-03 (24.7 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-131
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 1.374e+04 sec
#  Using fit statistic: chi
#  Using Background File                0934200101_PN30spec_bkg.fits
#   Background Exposure Time: 1.374e+04 sec
#  Using Response (RMF) File            0934200101_PN30spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0934200101_PN30spec.arf

# %%
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.0001 0.05")
Plot("data")

# %%
spec.ignore("**-0.2 12.0-**")
mo1 = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
#      3 channels (1-3) ignored in spectrum #     1
#     11 channels (121-131) ignored in spectrum #     1
#
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross secti
# on setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              3.624771e+10     using 117 bins.
#
# Test statistic : Chi-Squared              3.624771e+10     using 117 bins.
#  Null hypothesis probability of 0.000000e+00 with 114 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 161.993      0.959905     -1      0.133127       4.06971   2.47482e-05
# 155.198      97798.7       0     0.0162786       3.80180   2.89036e-05
# 152.476      84332.3       0    0.00433296       3.65002   3.11602e-05
# 151.676      62774.7       0    0.00212451       3.58825   3.18099e-05
# 151.35       52768.6       0   0.000118284       3.55573   3.18705e-05
# 151.213      49024.6       0   5.85772e-05       3.53228   3.17288e-05
# 151.143      47420.7       0   2.92320e-05       3.51362   3.14861e-05
# 151.095      47107.4       0   1.52207e-07       3.49664   3.12070e-05
# 151.056      47284.9       0   3.93244e-08       3.48022   3.09152e-05
# 151.02       47646.8       0   1.12452e-08       3.46398   3.06186e-05
# Number of trials exceeded: continue fitting? 150.985      48090.5       0   4.25814e-09       3.44776   3.03208e-05
# 150.95       48570.1       0   7.80544e-10       3.43148   3.00228e-05
# 150.914      49068.8       0   3.47834e-10       3.41515   2.97252e-05
# 150.878      49580.7       0   1.32478e-10       3.39873   2.94280e-05
# 150.841      50103.5       0   2.53038e-11       3.38223   2.91315e-05
# 150.804      50636.6       0   1.19709e-11       3.36564   2.88355e-05
# 150.766      51179.7       0   5.33598e-12       3.34896   2.85402e-05
# 150.727      51732.9       0   2.03492e-12       3.33216   2.82458e-05
# 150.688      52286.9       0   3.92709e-13       3.31531   2.79512e-05
# 150.647      52868.3       0   1.88379e-13       3.29833   2.76580e-05
# Number of trials exceeded: continue fitting? 150.609      53443.7       0   8.67252e-14       3.28160   2.73638e-05
# 150.571      54101.5       0   3.64315e-14       3.26459   2.70656e-05
# 150.527      54795.1       0   1.11531e-14       3.24728   2.67761e-05
# 150.449      55381.1       0   4.97895e-15       3.22757   2.65323e-05
# 150.375      55098.6       0   2.04527e-15       3.20731   2.62622e-05
# 150.32       55029.5       0   6.76802e-16       3.18578   2.59045e-05
# 150.186      55828         0   3.65401e-17       3.16024   2.56893e-05
# 148.502      54198.6      -1   1.23431e-19       2.80026   2.23467e-05
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.23431e-19 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 146.749      36877.4      -1   1.23431e-19       2.39327   1.72106e-05
# Number of trials exceeded: continue fitting? 144.515      14862.7      -1   1.23431e-19       2.01573   1.25254e-05
# 141.164      45078.2      -1   1.23431e-19       1.63996   8.89499e-06
# 135.975      90490.1      -2   1.23431e-19      0.969000   2.94384e-06
# 123.455      2.00777e+06  -3   1.23431e-19      0.557732   2.47495e-06
# 122.178      1.98008e+06  -4   1.23431e-19      0.539083   2.06894e-06
# 122.165      105974       -5   1.23431e-19      0.531873   2.05044e-06
# 122.165      702.775      -6   1.23431e-19      0.530198   2.04278e-06
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.23431e-19 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 122.165      133.061      -3   1.23431e-19      0.529799   2.04096e-06
# ==============================
#  Variances and Principal Axes
#                  2        3
#  6.7870E-14| -0.0000   1.0000
#  6.3899E-03|  1.0000   0.0000
# ------------------------------
#
# ========================
#   Covariance Matrix
#         1           2
#    6.390e-03   2.949e-08
#    2.949e-08   2.040e-13
# ------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.23431E-19  +/-  -1.00000
#    2    2   bbody      kT         keV      0.529799     +/-  7.99366E-02
#    3    2   bbody      norm                2.04096E-06  +/-  4.51647E-07
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  122.16     using 117 bins.
#
# Test statistic : Chi-Squared                  122.16     using 117 bins.
#  Null hypothesis probability of 2.84e-01 with 114 degrees of freedom
#  Model Flux 7.2633e-05 photons (1.7059e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
mo2 = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.108901e+10     using 117 bins.
#
# Test statistic : Chi-Squared              1.108901e+10     using 117 bins.
#  Null hypothesis probability of 0.000000e+00 with 114 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 135.643      3.41542      -1      0.172193      0.907073   2.25163e-05
# 120.705      232970       -2     0.0614582       1.14584   4.13391e-05
# 117.053      20100        -3      0.191312       1.42940   5.77032e-05
# 116.876      13358.7      -4      0.220232       1.55394   6.54916e-05
# 116.847      2440.89      -5      0.227600       1.60966   6.80922e-05
# 116.838      216.875      -6      0.235209       1.64711   6.99364e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  6.9498E-11| -0.0001  -0.0000   1.0000
#  3.9399E-03|  0.9770  -0.2134   0.0001
#  2.7440E-01|  0.2134   0.9770   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.626e-02   5.638e-02   3.322e-06
#    5.638e-02   2.621e-01   1.299e-05
#    3.322e-06   1.299e-05   7.807e-10
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.235209     +/-  0.127497
#    2    2   powerlaw   PhoIndex            1.64711      +/-  0.511943
#    3    2   powerlaw   norm                6.99364E-05  +/-  2.79417E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  116.84     using 117 bins.
#
# Test statistic : Chi-Squared                  116.84     using 117 bins.
#  Null hypothesis probability of 4.09e-01 with 114 degrees of freedom
#  Model Flux 9.6484e-05 photons (4.4319e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
mo4 = Model("tbabs*(apec+apec)")
mo4.apec.kT = 0.5
mo4.apec_3.kT = 4.0
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              2.700645e+09     using 117 bins.
#
# Test statistic : Chi-S
# quared              2.700645e+09     using 117 bins.
#  Null hypothesis probability of 0.000000e+00 with 112 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              1.545272e+09     using 117 bins.
#
# Test statistic : Chi-Squared              1.545272e+09     using 117 bins.
#  Null hypothesis probability of 0.000000e+00 with 112 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              8.169714e+08     using 117 bins.
#
# Test statistic : Chi-Squared              8.169714e+08     using 117 bins.
#  Null hypothesis probability of 0.000000e+00 with 112 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm          6:kT        9:norm
# 115.59       3359.93      -2      0.534108      0.668296   0.000110143       7.62605   0.000157285
# 111.992      26644.5      -2      0.462733      0.889165   2.70680e-05       4.49525   0.000186171
# 106.504      45684.9      -3      0.155712       1.20908   3.20033e-05       7.86081   0.000143683
# 104.013      4313.02      -4      0.247960       1.01668   3.27358e-05       7.36881   0.000154885
# 103.669      2654.46      -5      0.294870       1.04555   4.28615e-05       9.41557   0.000157541
# 103.651      1700.79      -6      0.306275       1.02614   4.34935e-05       8.38482   0.000158366
# 103.65       203.888      -7      0.303033       1.02862   4.31274e-05       8.69217   0.000158864
# ============================================================
#  Variances and Principal Axes
#                  1        2        5        6        9
#  7.1748E-11| -0.0002  -0.0001   0.9851  -0.0000   0.1718
#  1.8901E-09|  0.0000   0.0001  -0.1718  -0.0000   0.9851
#  1.0305E-02|  0.6362   0.7715   0.0002  -0.0013  -0.0001
#  3.6375E-02|  0.7715  -0.6362   0.0001   0.0063   0.0001
#  1.8084E+02| -0.0040   0.0050   0.0000   1.0000   0.0000
# ------------------------------------------------------------
#
# ============================================================
#   Covariance Matrix
#         1           2           3           4           5
#    2.876e-02  -1.642e-02   3.412e-06  -7.283e-01   7.598e-07
#   -1.642e-02   2.533e-02  -5.749e-07   8.995e-01  -1.341e-06
#    3.412e-06  -5.749e-07   6.828e-10   2.643e-05  -2.056e-10
#   -7.283e-01   8.995e-01   2.643e-05   1.808e+02   1.403e-04
#    7.598e-07  -1.341e-06  -2.056e-10   1.403e-04   2.145e-09
# ------------------------------------------------------------
#
# ========================================================================
# Model TBabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.303033     +/-  0.169577
#    2    2   apec       kT         keV      1.02862      +/-  0.159164
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                4.31274E-05  +/-  2.61296E-05
#    6    3   apec       kT         keV      8.69217      +/-  13.4474
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.58864E-04  +/-  4.63126E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  103.65     using 117 bins.
#
# Test statistic : Chi-Squared                  103.65     using 117 bins.
#  Null hypothesis probability of 7.01e-01 with 112 degrees of freedom
#  Model Flux 8.7054e-05 photons (3.4535e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
flux = 1.2493*10**-13
d_pc = 770
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')

d_pc = 464
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')
# Out:
# Luminosity is: 8.887405853896028e+30 erg s^-1
# Luminosity is: 3.227227071547309e+30 erg s^-1

# %%
d_pc = 7500
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')
# Out:
# Luminosity is: 8.431718321498594e+32 erg s^-1

# %%
g_mag = 11.329752
opt_flux = (10**(0.4*(-26.7 - g_mag))) * (3.828 * 10 ** 33) / (4*np.pi*(1.496*10**13)**2)
print('Optical flux: '+str(opt_flux))
opt_x_ratio = flux / opt_flux
print('The x-ray/optical flux ratio is: '+str(opt_x_ratio))
# Out:
# Optical flux: 8.355993202706773e-10
# The x-ray/optical flux ratio is: 0.00014950945623020754
