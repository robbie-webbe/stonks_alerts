# %% [markdown]
# Obs 0916811401 source 001. Not first X-ray detection. (262.6274, -34.5386, 0.25")
#
# SIMBAD: V* V1017 Sco
# + RS CVn Variable
# + Parallax 2.5845 mas. 387 pc.
#
# ALSO XMM
# + 0916811501 src 1
# + 0916810801 src 1
#
#
# Vizier - Gaia 5975889887888213248 2.2"
# + Parallax 2.585. Distance 387 pc.
# + Teff 4896K (DR2)
# + Rstar 14.91 (DR2)
# + Mstar unknown

# %%
# %load_ext wurlitzer
import numpy as np
import os
import stingray as st
import matplotlib.pyplot as plt
from astropy.io import fits
from xspec import *
plt.rcParams['figure.figsize'] = [15, 8]

lc = fits.open('0916811401_001/0916811401_PN1_dt1.lc')
bkg = fits.open('0916811401_001/0916811401_PN1_dt1_bkg.lc')
full_gti = []
for j in lc[2].data:
    full_gti.append([j[0],j[1]])
soft = fits.open('0916811401_001/0916811401_PN1_dt1_0.2-2keV.lc')
sbkg = fits.open('0916811401_001/0916811401_PN1_dt1_0.2-2keV_bkg.lc')
soft_gti = []
for j in soft[2].data:
    soft_gti.append([j[0],j[1]])
hard = fits.open('0916811401_001/0916811401_PN1_dt1_2-12keV.lc')
hbkg = fits.open('0916811401_001/0916811401_PN1_dt1_2-12keV_bkg.lc')
hard_gti = []
for j in hard[2].data:
    hard_gti.append([j[0],j[1]])

# %%
full_lc = st.Lightcurve(lc[1].data.field('TIME'),lc[1].data.field('RATE'),err=lc[1].data.field('ERROR'),gti=full_gti,input_counts=False)
full_bkg = st.Lightcurve(bkg[1].data.field('TIME'),bkg[1].data.field('RATE'),err=bkg[1].data.field('ERROR'),gti=full_gti,input_counts=False)

soft_lc = st.Lightcurve(soft[1].data.field('TIME'),soft[1].data.field('RATE'),err=soft[1].data.field('ERROR'),gti=soft_gti,input_counts=False)
soft_bkg = st.Lightcurve(sbkg[1].data.field('TIME'),sbkg[1].data.field('RATE'),err=sbkg[1].data.field('ERROR'),gti=soft_gti,input_counts=False)

hard_lc = st.Lightcurve(hard[1].data.field('TIME'),hard[1].data.field('RATE'),err=hard[1].data.field('ERROR'),gti=hard_gti,input_counts=False)
hard_bkg = st.Lightcurve(hbkg[1].data.field('TIME'),hbkg[1].data.field('RATE'),err=hbkg[1].data.field('ERROR'),gti=hard_gti,input_counts=False)

full_lc.apply_gtis()
full_bkg.apply_gtis()
soft_lc.apply_gtis()
soft_bkg.apply_gtis()
hard_lc.apply_gtis()
hard_bkg.apply_gtis()
# Out:
# /home/rwebbe/.local/lib/python3.8/site-packages/stingray/lightcurve.py:516: UserWarning: There are non-finite points in the data, but they are outside GTIs.
#   warnings.warn("There are non-finite points in the data, but they are outside GTIs. ")
# /home/rwebbe/.local/lib/python3.8/site-packages/stingray/lightcurve.py:516: UserWarning: There are non-finite points in the data, but they are outside GTIs.
#   warnings.warn("There are non-finite points in the data, but they are outside GTIs. ")

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(soft_lc.time,soft_lc.countrate,color='r')
plt.plot(hard_lc.time,hard_lc.countrate,color='b')

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(full_bkg.time,full_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.time,soft_lc.countrate,color='k')
plt.plot(soft_bkg.time,soft_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.time,hard_lc.countrate,color='k')
plt.plot(hard_bkg.time,hard_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='r')
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='b')

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(full_bkg.rebin(50).time,full_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='k')
plt.plot(soft_bkg.rebin(50).time,soft_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='k')
plt.plot(hard_bkg.rebin(50).time,hard_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='r')
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='b')

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(full_bkg.rebin(250).time,full_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='k')
plt.plot(soft_bkg.rebin(250).time,soft_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='k')
plt.plot(hard_bkg.rebin(250).time,hard_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
os.chdir("0916811401_001")
spec = Spectrum("0916811401_PN1grpspec.fits")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0916811401_PN1grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  7.251e-02 +/- 4.066e-03 (72.4 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-40
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 6871 sec
#  Using fit statistic: chi
#  Using Background File                0916811401_PN1spec_bkg.fits
#   Background Exposure Time: 6870 sec
#  Using Response (RMF) File            0916811401_PN1spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0916811401_PN1spec.arf

# %%
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.0001 0.5")
Plot("data")

# %%
spec.ignore("**-0.2 12.0-**")
mo1 = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
#      2 channels (1-2) ignored in spectrum #     1
#      1 channels (40) ignored in spectrum #     1
#
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              6.782557e+09     using 37 bins.
#
# Test statistic : Chi-Squared              6.782557e+09     using 37 bins.
#  Null hypothesis probability of 0.000000e+00 with 34 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 409.076      0.31315       0      0.386651       2.98492   1.51926e-05
# 406.63       15897.4       0     0.0142810       2.91564   1.51406e-05
# 405.633      40016.1       0    0.00453240       2.76270   1.56738e-05
# 404.637      42563.4       0   0.000622494       2.62451   1.61142e-05
# 403.648      44183         0   0.000217274       2.49929   1.64593e-05
# 402.621      45061.4       0   4.44297e-05       2.38479   1.67151e-05
# 401.532      45771.4       0   7.10315e-06       2.27795   1.68989e-05
# 400.351      46456.4       0   3.03939e-06       2.17656   1.70243e-05
# 399.041      47267.3       0   1.26141e-06       2.07890   1.71030e-05
# 397.561      48357.2       0   4.82049e-07       1.98369   1.71448e-05
# Number of trials exceeded: continue fitting? 395.855      49901.6       0   1.40578e-07       1.88992   1.71584e-05
# 393.855      52124         0   6.59629e-08       1.79689   1.71515e-05
# 391.474      55317.5       0   1.03810e-09       1.70415   1.71315e-05
# 388.608      59868.2       0   1.60891e-10       1.61158   1.71054e-05
# 388.563      66269.5       0   2.73727e-11       1.46040   1.07434e-05
# 371.637      236553        0   7.01916e-12       1.00443   7.24075e-06
# 314.425      742459       -1   1.69520e-12      0.342109   3.44180e-06
# 222.406      4.34418e+06  -1      0.107101      0.137190   2.01327e-05
# 115.233      699804       -1      0.106462      0.265578   1.75142e-05
# 62.9908      1.73024e+06  -2      0.182227      0.197337   3.61204e-05
# Number of trials exceeded: continue fitting? 36.2375      588469       -3      0.211510      0.216444   4.83336e-05
# 35.6542      18057        -4      0.219800      0.208343   5.14414e-05
# 35.6317      12276.9      -5      0.225978      0.206657   5.31207e-05
# 35.6306      1588.63      -6      0.227628      0.206182   5.35577e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  7.5026E-12| -0.0002   0.0002   1.0000
#  5.1630E-05| -0.2640  -0.9645   0.0002
#  4.0579E-03|  0.9645  -0.2640   0.0002
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    3.779e-03  -1.020e-03   9.025e-07
#   -1.020e-03   3.309e-04  -2.569e-07
#    9.025e-07  -2.569e-07   2.262e-10
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.227628     +/-  6.14702E-02
#    2    2   bbody      kT         keV      0.206182     +/-  1.81916E-02
#    3    2   bbody      norm                5.35577E-05  +/-  1.50407E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   35.63     using 37 bins.
#
# Test statistic : Chi-Squared                   35.63     using 37 bins.
#  Null hypothesis probability of 3.92e-01 with 34 degrees of freedom
#  Model Flux 0.0010576 photons (1.6163e-12 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
mo2 = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.230127e+09     using 37 bins.
#
# Test statistic : Chi-Squared              1.230127e+09     using 37 bins.
#  Null hypothesis probability of 0.000000e+00 with 34 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 394.796      5.44207      -1      0.317767       1.21141   3.33296e-05
# 386.461      81442.9      -1      0.152903       2.85348   3.60021e-05
# 255.932      116837        0     0.0734202       1.23128   0.000395135
# 153.982      26080        -1     0.0239814       2.01353   0.000514646
# 95.6709      26897.8      -2      0.152131       2.74570   0.000803645
# 83.2319      10557.9      -3      0.452930       4.39748    0.00183941
# 55.0916      14606        -2      0.644231       5.36609    0.00385247
# 44.2998      5911.38      -3      0.840249       6.56902    0.00731985
# 30.7749      2683.2       -4      0.894185       6.89236     0.0101911
# 30.2733      435.851      -5      0.898099       6.91989     0.0106866
# Number of trials exceeded: continue fitting? 30.2732      5.38506      -6      0.899144       6.92631     0.0107235
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  2.9891E-07| -0.0339   0.0005   0.9994
#  7.0935E-04|  0.9864  -0.1612   0.0335
#  7.0288E-01|  0.1611   0.9869   0.0049
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.893e-02   1.116e-01   5.839e-04
#    1.116e-01   6.846e-01   3.430e-03
#    5.839e-04   3.430e-03   1.832e-05
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.899144     +/-  0.137586
#    2    2   powerlaw   PhoIndex            6.92631      +/-  0.827429
#    3    2   powerlaw   norm                1.07235E-02  +/-  4.27990E-03
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   30.27     using 37 bins.
#
# Test statistic : Chi-Squared                   30.27     using 37 bins.
#  Null hypothesis probability of 6.51e-01 with 34 degrees of freedom
#  Model Flux 0.0010682 photons (1.6609e-12 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
flux = 1.7919*10**-12
d_pc = 387
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')
# Out:
# Luminosity is: 3.220049310677547e+31 erg s^-1

# %%
g_mag = 7.601333
opt_flux = (10**(0.4*(-26.7 - g_mag))) * (3.828 * 10 ** 33) / (4*np.pi*(1.496*10**13)**2)
print('Optical flux: '+str(opt_flux))
opt_x_ratio = flux / opt_flux
print('The x-ray/optical flux ratio is: '+str(opt_x_ratio))
# Out:
# Optical flux: 2.590393120519121e-08
# The x-ray/optical flux ratio is: 6.917482855424272e-05
