# %% [markdown]
# Obs 0934200801 source 011. Not first X-ray detection. (264.8503, -29.5503, 1.07")
#
# No SIMBAD
#
# ALSO XMM
# + 0886010101 src 7
#
# Vizier - Gaia 4057030162253566336 1.3"
# + Parallax 0.1666. Distance 6000 pc. (4150 pc spec)
# + Teff 7186K
# + Rstar 18.1
# + Mstar 3.94
#
# Vizier - Gaia 4057030166551252864 5.9"
# + Parallax 1.478. Distance 676 pc. (709 pc spec)
# + Teff 4255K
# + Rstar 0.61
# + Mstar 0.65

# %%
# %load_ext wurlitzer
import numpy as np
import os
import stingray as st
import matplotlib.pyplot as plt
from astropy.io import fits
from xspec import *
plt.rcParams['figure.figsize'] = [15, 8]

lc = fits.open('0934200801_011/0934200801_PN11_dt1.lc')
bkg = fits.open('0934200801_011/0934200801_PN11_dt1_bkg.lc')
full_gti = []
for j in lc[2].data:
    full_gti.append([j[0],j[1]])
soft = fits.open('0934200801_011/0934200801_PN11_dt1_0.2-2keV.lc')
sbkg = fits.open('0934200801_011/0934200801_PN11_dt1_0.2-2keV_bkg.lc')
soft_gti = []
for j in soft[2].data:
    soft_gti.append([j[0],j[1]])
hard = fits.open('0934200801_011/0934200801_PN11_dt1_2-12keV.lc')
hbkg = fits.open('0934200801_011/0934200801_PN11_dt1_2-12keV_bkg.lc')
hard_gti = []
for j in hard[2].data:
    hard_gti.append([j[0],j[1]])

# %%
full_lc = st.Lightcurve(lc[1].data.field('TIME'),lc[1].data.field('RATE'),err=lc[1].data.field('ERROR'),gti=full_gti,input_counts=False)
full_bkg = st.Lightcurve(bkg[1].data.field('TIME'),bkg[1].data.field('RATE'),err=bkg[1].data.field('ERROR'),gti=full_gti,input_counts=False)

soft_lc = st.Lightcurve(soft[1].data.field('TIME'),soft[1].data.field('RATE'),err=soft[1].data.field('ERROR'),gti=soft_gti,input_counts=False)
soft_bkg = st.Lightcurve(sbkg[1].data.field('TIME'),sbkg[1].data.field('RATE'),err=sbkg[1].data.field('ERROR'),gti=soft_gti,input_counts=False)

hard_lc = st.Lightcurve(hard[1].data.field('TIME'),hard[1].data.field('RATE'),err=hard[1].data.field('ERROR'),gti=hard_gti,input_counts=False)
hard_bkg = st.Lightcurve(hbkg[1].data.field('TIME'),hbkg[1].data.field('RATE'),err=hbkg[1].data.field('ERROR'),gti=hard_gti,input_counts=False)

full_lc.apply_gtis()
full_bkg.apply_gtis()
soft_lc.apply_gtis()
soft_bkg.apply_gtis()
hard_lc.apply_gtis()
hard_bkg.apply_gtis()

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(soft_lc.time,soft_lc.countrate,color='r')
plt.plot(hard_lc.time,hard_lc.countrate,color='b')

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(full_bkg.time,full_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.time,soft_lc.countrate,color='k')
plt.plot(soft_bkg.time,soft_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.time,hard_lc.countrate,color='k')
plt.plot(hard_bkg.time,hard_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='r')
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='b')

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(full_bkg.rebin(50).time,full_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='k')
plt.plot(soft_bkg.rebin(50).time,soft_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='k')
plt.plot(hard_bkg.rebin(50).time,hard_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='r')
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='b')

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(full_bkg.rebin(250).time,full_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='k')
plt.plot(soft_bkg.rebin(250).time,soft_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='k')
plt.plot(hard_bkg.rebin(250).time,hard_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
os.chdir("0934200801_011")
spec = Spectrum("0934200801_PN11grpspec.fits")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0934200801_PN11grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  4.780e-03 +/- 9.376e-04 (67.8 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-5
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 1.135e+04 sec
#  Using fit statistic: chi
#  Using Background File                0934200801_PN11spec_bkg.fits
#   Background Exposure Time: 1.135e+04 sec
#  Using Response (RMF) File            0934200801_PN11spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0934200801_PN11spec.arf

# %%
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot("data")

# %%
mo1 = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              1.600103e+12     using 5 bins.
#
# Test statistic : Chi-Squared              1.600103e+12     using 5 bins.
#  Null hypothesis probability of 0.000000e+00 with 2 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 22.7094      0.481959      0      0.341449       3.10457   2.33662e-06
# 21.5785      322491        0      0.100324       3.02423   2.22876e-06
# 21.2486      391788       -1     0.0371972       2.51807   1.36519e-06
# 12.5551      965415       -1     0.0185320       1.30025   6.93212e-07
# 10.6221      2.95199e+06  -1     0.0318223      0.744800   7.28701e-07
# 6.54888      4.77209e+06  -2     0.0837368      0.872212   7.55056e-07
# 6.32042      356874       -3      0.179309      0.881740   7.99356e-07
# 6.31828      28493.3      -4      0.198951      0.877933   8.03640e-07
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  2.1671E-14| -0.0000  -0.0000   1.0000
#  2.3084E-02| -0.3863  -0.9224  -0.0000
#  2.1329E-01|  0.9224  -0.3863   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.849e-01  -6.778e-02   2.644e-08
#   -6.778e-02   5.147e-02   1.644e-08
#    2.644e-08   1.644e-08   5.109e-14
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.198951     +/-  0.430006
#    2    2   bbody      kT         keV      0.877933     +/-  0.226874
#    3    2   bbody      norm                8.03640E-07  +/-  2.26020E-07
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    6.32     using 5 bins.
#
# Test statistic : Chi-Squared                    6.32     using 5 bins.
#  Null hypothesis probability of 4.25e-02 with 2 degrees of freedom
#  Model Flux 1.4167e-05 photons (6.1768e-14 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
mo2 = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              2.996967e+11     using 5 bins.
#
# Test statistic : Chi-Squared              2.996967e+11     using 5 bins.
#  Null hypothesis probability of 0.000000e+00 with 2 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 6.97318      2.15409      -2      0.422798       1.44489   1.14434e-05
# 6.78224      58618        -3      0.772549       1.88092   1.91939e-05
# 6.30066      60101.6      -4       1.01329       2.09423   2.83489e-05
# 6.15671      22504.1      -5       1.04025       2.11633   3.14195e-05
# 6.15648      860.751      -6       1.04098       2.11707   3.15381e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  3.3636E-11| -0.0000  -0.0000   1.0000
#  9.5892E-02|  0.7229  -0.6910  -0.0000
#  2.0761E+00|  0.6910   0.7229   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.041e+00   9.891e-01   4.366e-05
#    9.891e-01   1.131e+00   4.609e-05
#    4.366e-05   4.609e-05   1.976e-09
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.04098      +/-  1.02050
#    2    2   powerlaw   PhoIndex            2.11707      +/-  1.06329
#    3    2   powerlaw   norm                3.15381E-05  +/-  4.44535E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    6.16     using 5 bins.
#
# Test statistic : Chi-Squared                    6.16     using 5 bins.
#  Null hypothesis probability of 4.60e-02 with 2 degrees of freedom
#  Model Flux 1.466e-05 photons (8.0121e-14 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
flux = 8.0121*10**-14
d_pc = 6000
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')

d_pc = 676
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')
# Out:
# Luminosity is: 3.460793486973065e+32 erg s^-1
# Luminosity is: 4.393054345841674e+30 erg s^-1

# %%
d_pc = 7500
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')
# Out:
# Luminosity is: 5.407489823395413e+32 erg s^-1
