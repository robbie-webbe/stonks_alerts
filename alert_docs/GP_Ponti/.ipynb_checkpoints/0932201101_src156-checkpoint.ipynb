# %% [markdown]
# Obs 0886110501 source 019. Not first X-ray detection.
#
# No SIMBAD
#
# Vizier - Gaia 4069071433795086592
# Distance estimate 102 pc.
# Teff 3680K
# Rstar 0.4
# Mstar 0.4
#
# Vizier - Gaia 4069071433795086208
# Distance estimate 571 pc
# Teff 3870K
# Rstar 0.368
# Mstar unknown

# %%
# %load_ext wurlitzer
import numpy as np
import os
import stingray as st
import matplotlib.pyplot as plt
from astropy.io import fits
from xspec import *
plt.rcParams['figure.figsize'] = [15, 8]

lc = fits.open('0932201101/0932201101_PN156_dt1.lc')
bkg = fits.open('0932201101/0932201101_PN156_dt1_bkg.lc')
full_gti = []
for j in lc[2].data:
    full_gti.append([j[0],j[1]])
soft = fits.open('0932201101/0932201101_PN156_dt1_0.2-2keV.lc')
sbkg = fits.open('0932201101/0932201101_PN156_dt1_0.2-2keV_bkg.lc')
soft_gti = []
for j in soft[2].data:
    soft_gti.append([j[0],j[1]])
hard = fits.open('0932201101/0932201101_PN156_dt1_2-12keV.lc')
hbkg = fits.open('0932201101/0932201101_PN156_dt1_2-12keV_bkg.lc')
hard_gti = []
for j in hard[2].data:
    hard_gti.append([j[0],j[1]])

# %%
full_lc = st.Lightcurve(lc[1].data.field('TIME'),lc[1].data.field('RATE'),err=lc[1].data.field('ERROR'),gti=full_gti,input_counts=False)
full_bkg = st.Lightcurve(bkg[1].data.field('TIME'),bkg[1].data.field('RATE'),err=bkg[1].data.field('ERROR'),gti=full_gti,input_counts=False)

soft_lc = st.Lightcurve(soft[1].data.field('TIME'),soft[1].data.field('RATE'),err=soft[1].data.field('ERROR'),gti=soft_gti,input_counts=False)
soft_bkg = st.Lightcurve(sbkg[1].data.field('TIME'),sbkg[1].data.field('RATE'),err=sbkg[1].data.field('ERROR'),gti=soft_gti,input_counts=False)

hard_lc = st.Lightcurve(hard[1].data.field('TIME'),hard[1].data.field('RATE'),err=hard[1].data.field('ERROR'),gti=hard_gti,input_counts=False)
hard_bkg = st.Lightcurve(hbkg[1].data.field('TIME'),hbkg[1].data.field('RATE'),err=hbkg[1].data.field('ERROR'),gti=hard_gti,input_counts=False)

full_lc.apply_gtis()
full_bkg.apply_gtis()
soft_lc.apply_gtis()
soft_bkg.apply_gtis()
hard_lc.apply_gtis()
hard_bkg.apply_gtis()
# Out:
# /home/rwebbe/.local/lib/python3.8/site-packages/stingray/lightcurve.py:516: UserWarning: There are non-finite points in the data, but they are outside GTIs.
#   warnings.warn("There are non-finite points in the data, but they are outside GTIs. ")
# /home/rwebbe/.local/lib/python3.8/site-packages/stingray/lightcurve.py:516: UserWarning: There are non-finite points in the data, but they are outside GTIs.
#   warnings.warn("There are non-finite points in the data, but they are outside GTIs. ")

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(soft_lc.time,soft_lc.countrate,color='r')
plt.plot(hard_lc.time,hard_lc.countrate,color='b')

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(full_bkg.time,full_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.time,soft_lc.countrate,color='k')
plt.plot(soft_bkg.time,soft_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.time,hard_lc.countrate,color='k')
plt.plot(hard_bkg.time,hard_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='r')
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='b')

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(full_bkg.rebin(50).time,full_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='k')
plt.plot(soft_bkg.rebin(50).time,soft_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='k')
plt.plot(hard_bkg.rebin(50).time,hard_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='r')
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='b')

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(full_bkg.rebin(250).time,full_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='k')
plt.plot(soft_bkg.rebin(250).time,soft_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='k')
plt.plot(hard_bkg.rebin(250).time,hard_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
os.chdir("0932201101")
spec = Spectrum("0932201101_PN156grpspec.fits")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0932201101_PN156grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  7.862e-03 +/- 1.685e-03 (53.5 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-7
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 7423 sec
#  Using fit statistic: chi
#  Using Background File                0932201101_PN156spec_bkg.fits
#   Background Exposure Time: 7421 sec
#  Using Response (RMF) File            0932201101_PN156spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0932201101_PN156spec.arf

# %%
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot("data")

# %%
spec.ignore("**-0.2 12.0-**")
mo1 = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
#      1 channels (1) ignored in spectrum #     1
#      1 channels (7) ignored in spectrum #     1
#
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              1.294583e+11     using 5 bins.
#
# Test statistic : Chi-Squared              1.294583e+11     using 5 bins.
#  Null hypothesis probability of 0.000000e+00 with 2 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 10.2616      0.678073      0      0.115006       3.07665   1.25740e-05
# 10.0665      64726.8       0     0.0473990       3.08854   1.21654e-05
# 9.9305       88566.6       0     0.0143557       3.08210   1.19320e-05
# 9.88637      97560.5       0    0.00628989       3.06862   1.17635e-05
# 9.84422      101186        0    0.00228819       3.05291   1.16154e-05
# 9.80647      103123        0   0.000302247       3.03640   1.14748e-05
# 9.77739      104477        0   5.56427e-05       3.01959   1.13371e-05
# 9.74876      105659        0   2.49694e-05       3.00268   1.12007e-05
# 9.71963      106816        0   9.70710e-06       2.98570   1.10652e-05
# 9.69004      107978        0   2.11366e-06       2.96866   1.09305e-05
# Number of trials exceeded: continue fitting? 9.66002      109153        0   2.24840e-07       2.95157   1.07967e-05
# 9.62954      110344        0   1.07392e-07       2.93442   1.06636e-05
# 9.59859      111554        0   4.89730e-08       2.91722   1.05313e-05
# 9.56716      112781        0   1.99178e-08       2.89996   1.03998e-05
# 9.53524      114028        0   5.46827e-09       2.88264   1.02690e-05
# 9.50281      115295        0   1.87563e-09       2.86527   1.01391e-05
# 9.46986      116581        0   8.93078e-11       2.84785   1.00099e-05
# 9.43638      117887        0   3.38013e-11       2.83036   9.88149e-06
# 9.40233      119213        0   6.20671e-12       2.81281   9.75390e-06
# 9.36789      120558        0   2.77796e-12       2.79521   9.62696e-06
# Number of trials exceeded: continue fitting? 9.33265      121940        0   1.07390e-12       2.77754   9.50094e-06
# 9.29838      123323        0   2.27247e-13       2.75990   9.37467e-06
# 9.26606      124870        0   1.73879e-14       2.74235   9.24726e-06
# 9.22771      126688        0   4.36703e-15       2.72409   9.12158e-06
# 9.13535      128122        0   1.14661e-15       2.70225   9.03297e-06
# 9.11088      124310        0   4.96882e-17       2.68226   8.87302e-06
# 8.20133      128161       -1   1.84165e-17       2.45554   8.02781e-06
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.84165e-17 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 7.34989      97705.5      -1   1.84165e-17       2.16703   6.60917e-06
# 6.50367      4288.66      -1   1.84165e-17       1.91141   5.18028e-06
# Number of trials exceeded: continue fitting? 5.41022      35620.8      -1   1.84165e-17       1.64700   3.99475e-06
# 4.15535      67774.8      -1   1.84165e-17       1.39480   3.08679e-06
# 3.40295      104368       -2   1.84165e-17      0.931992   1.57167e-06
# 2.37812      1.60257e+06  -3   1.84165e-17      0.953424   1.92840e-06
# 2.37722      44921.5      -4   1.84165e-17      0.954848   1.94103e-06
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.84165e-17 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 2.37722      102.192      -3   1.84165e-17      0.955126   1.94170e-06
# ==============================
#  Variances and Principal Axes
#                  2        3
#  1.0435E-13| -0.0000   1.0000
#  4.1194E-02|  1.0000   0.0000
# ------------------------------
#
# ========================
#   Covariance Matrix
#         1           2
#    4.119e-02   9.570e-08
#    9.570e-08   3.267e-13
# ------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.84165E-17  +/-  -1.00000
#    2    2   bbody      kT         keV      0.955126     +/-  0.202964
#    3    2   bbody      norm                1.94170E-06  +/-  5.71555E-07
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    2.38     using 5 bins.
#
# Test statistic : Chi-Squared                    2.38     using 5 bins.
#  Null hypothesis probability of 3.05e-01 with 2 degrees of freedom

# %%
mo2 = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              4.519430e+10     using 5 bins.
#
# Test statistic : Chi-Squared              4.519430e+10     using 5 bins.
#  Null hypothesis probability of 0.000000e+00 with 2 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 4.29894      1.36316      -2      0.409092      0.913830   1.62328e-05
# 1.74118      138486       -3      0.108973      0.788857   1.58567e-05
# 1.41989      51266.1      -4     0.0271064      0.868332   1.75979e-05
# 1.41725      16.12        -5     0.0708256      0.900089   1.84556e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  8.3559E-12| -0.0000  -0.0000   1.0000
#  7.5689E-02|  0.7418  -0.6706  -0.0000
#  2.5153E+00|  0.6706   0.7418   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.173e+00   1.214e+00   2.827e-05
#    1.214e+00   1.418e+00   3.162e-05
#    2.827e-05   3.162e-05   7.243e-10
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    7.08256E-02  +/-  1.08302
#    2    2   powerlaw   PhoIndex            0.900089     +/-  1.19081
#    3    2   powerlaw   norm                1.84556E-05  +/-  2.69125E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    1.42     using 5 bins.
#
# Test statistic : Chi-Squared                    1.42     using 5 bins.
#  Null hypothesis probability of 4.92e-01 with 2 degrees of freedom

# %%
AllModels.calcFlux("0.2 12.0")
# Out:
#  Model Flux 6.2671e-05 photons (3.9546e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
flux = 8.9923*10**-14
d_pc = 102
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')

d_pc = 571
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')
# Out:
# Luminosity is: 1.1225299928695821e+29 erg s^-1
# Luminosity is: 3.517789325309412e+30 erg s^-1
