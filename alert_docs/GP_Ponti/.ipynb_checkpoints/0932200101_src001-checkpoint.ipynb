# %% [markdown]
# Obs 0932200101 source 001. First X-ray detection. (268.0909, -26.4698, 0.39")
#
# No SIMBAD
#
# Vizier - Gaia 4063891428343382400 4.99
# + Parallax 1.52. Distance 656 pc.
# + Teff unknown
# + Rstar unknown
# + Mstar unknown

# %%
# %load_ext wurlitzer
import numpy as np
import os
import stingray as st
import matplotlib.pyplot as plt
from astropy.io import fits
from xspec import *
plt.rcParams['figure.figsize'] = [15, 8]

lc = fits.open('0932200101/0932200101_PN1_dt1.lc')
bkg = fits.open('0932200101/0932200101_PN1_dt1_bkg.lc')
full_gti = []
for j in lc[2].data:
    full_gti.append([j[0],j[1]])
soft = fits.open('0932200101/0932200101_PN1_dt1_0.2-2keV.lc')
sbkg = fits.open('0932200101/0932200101_PN1_dt1_0.2-2keV_bkg.lc')
soft_gti = []
for j in soft[2].data:
    soft_gti.append([j[0],j[1]])
hard = fits.open('0932200101/0932200101_PN1_dt1_2-12keV.lc')
hbkg = fits.open('0932200101/0932200101_PN1_dt1_2-12keV_bkg.lc')
hard_gti = []
for j in hard[2].data:
    hard_gti.append([j[0],j[1]])

# %%
full_lc = st.Lightcurve(lc[1].data.field('TIME'),lc[1].data.field('RATE'),err=lc[1].data.field('ERROR'),gti=full_gti,input_counts=False)
full_bkg = st.Lightcurve(bkg[1].data.field('TIME'),bkg[1].data.field('RATE'),err=bkg[1].data.field('ERROR'),gti=full_gti,input_counts=False)

soft_lc = st.Lightcurve(soft[1].data.field('TIME'),soft[1].data.field('RATE'),err=soft[1].data.field('ERROR'),gti=soft_gti,input_counts=False)
soft_bkg = st.Lightcurve(sbkg[1].data.field('TIME'),sbkg[1].data.field('RATE'),err=sbkg[1].data.field('ERROR'),gti=soft_gti,input_counts=False)

hard_lc = st.Lightcurve(hard[1].data.field('TIME'),hard[1].data.field('RATE'),err=hard[1].data.field('ERROR'),gti=hard_gti,input_counts=False)
hard_bkg = st.Lightcurve(hbkg[1].data.field('TIME'),hbkg[1].data.field('RATE'),err=hbkg[1].data.field('ERROR'),gti=hard_gti,input_counts=False)

full_lc.apply_gtis()
full_bkg.apply_gtis()
soft_lc.apply_gtis()
soft_bkg.apply_gtis()
hard_lc.apply_gtis()
hard_bkg.apply_gtis()

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(soft_lc.time,soft_lc.countrate,color='r')
plt.plot(hard_lc.time,hard_lc.countrate,color='b')

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(full_bkg.time,full_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.time,soft_lc.countrate,color='k')
plt.plot(soft_bkg.time,soft_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.time,hard_lc.countrate,color='k')
plt.plot(hard_bkg.time,hard_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='r')
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='b')

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(full_bkg.rebin(50).time,full_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='k')
plt.plot(soft_bkg.rebin(50).time,soft_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='k')
plt.plot(hard_bkg.rebin(50).time,hard_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='r')
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='b')

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(full_bkg.rebin(250).time,full_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='k')
plt.plot(soft_bkg.rebin(250).time,soft_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='k')
plt.plot(hard_bkg.rebin(250).time,hard_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
os.chdir("0932200101")
spec = Spectrum("0932200101_PN1grpspec.fits")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0932200101_PN1grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  1.158e-02 +/- 1.833e-03 (69.9 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-4
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 7426 sec
#  Using fit statistic: chi
#  Using Background File                0932200101_PN1spec_bkg.fits
#   Background Exposure Time: 7425 sec
#  Using Response (RMF) File            0932200101_PN1spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0932200101_PN1spec.arf

# %%
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot("data")

# %%
mo1 = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              2.620423e+11     using 4 bins.
#
# Test statistic : Chi-Squared              2.620423e+11     using 4 bins.
#  Null hypothesis probability of 0.000000e+00 with 1 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 23.464       0.668994     -1      0.144083       3.50335   9.91240e-06
# 20.9189      259781       -1     0.0106468       3.55006   1.10035e-05
# 20.6473      222367       -2    0.00513683       3.82026   1.33211e-05
# 20.5467      163071       -2    0.00243739       3.92024   1.42765e-05
# 20.4878      144515       -2    0.00111344       3.93823   1.44900e-05
# 20.3975      140140       -2   0.000462987       3.91051   1.43306e-05
# 20.3716      140936       -3   0.000140714       3.89529   1.42157e-05
# 20.2376      142415       -4   6.10372e-05       3.82190   1.37009e-05
# 20.1141      148468       -5   2.20810e-05       3.76587   1.33361e-05
# 20.0301      152505       -6   2.95825e-06       3.72941   1.31045e-05
# Number of trials exceeded: continue fitting? 19.9781      155133       -7   5.96832e-07       3.70723   1.29653e-05
# 19.9516      156751       -8   1.07068e-08       3.69628   1.28976e-05
# 19.9387      157527       -9   1.58165e-09       3.69098   1.28648e-05
# 19.9326      157908      -10   4.42988e-10       3.68847   1.28493e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  7.1190E-12| -0.0000  -0.0000   1.0000
#  3.7296E-01|  0.9909   0.1342   0.0000
#  2.1993E+01| -0.1342   0.9909   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    7.625e-01  -2.876e+00  -1.885e-05
#   -2.876e+00   2.160e+01   1.456e-04
#   -1.885e-05   1.456e-04   9.886e-10
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    4.42988E-10  +/-  0.873222
#    2    2   bbody      kT         keV      3.68847      +/-  4.64798
#    3    2   bbody      norm                1.28493E-05  +/-  3.14423E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   19.93     using 4 bins.
#
# Test statistic : Chi-Squared                   19.93     using 4 bins.
#  Null hypothesis probability of 8.02e-06 with 1 degrees of freedom

# %%
mo2 = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              4.509810e+10     using 4 bins.
#
# Test statistic : Chi-Squared              4.509810e+10     using 4 bins.
#  Null hypothesis probability of 0.000000e+00 with 1 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 8.00036      2.13774      -2     0.0742566      0.223037   7.73912e-06
# 6.4525       193515       -3     0.0201798      0.259364   7.68061e-06
# 3.03867      276047       -4    0.00753071      0.495323   1.08651e-05
# 2.48761      134718       -5   3.93075e-05      0.542632   1.23540e-05
# 2.47895      1820.14      -6    0.00622134      0.555351   1.26482e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  2.8931E-12| -0.0000  -0.0000   1.0000
#  1.3456E-03|  0.9879  -0.1548   0.0000
#  6.0187E-02|  0.1548   0.9879   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.755e-03   8.998e-03   1.601e-07
#    8.998e-03   5.878e-02   8.407e-07
#    1.601e-07   8.407e-07   1.563e-11
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    6.22134E-03  +/-  5.24924E-02
#    2    2   powerlaw   PhoIndex            0.555351     +/-  0.242439
#    3    2   powerlaw   norm                1.26482E-05  +/-  3.95404E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    2.48     using 4 bins.
#
# Test statistic : Chi-Squared                    2.48     using 4 bins.
#  Null hypothesis probability of 1.15e-01 with 1 degrees of freedom

# %%
AllModels.calcFlux("0.2 12.0")
# Out:
#  Model Flux 7.0512e-05 photons (5.0576e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
flux = 5.0576*10**-13
d_pc = 656
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')
# Out:
# Luminosity is: 2.611433554647339e+31 erg s^-1
