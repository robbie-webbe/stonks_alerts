# %% [markdown]
# Obs 0886090801 source 001. Not first X-ray detection. (268.3681, -24.7743 0.05")
#
# SIMBAD HD 162718
# + Be Star.
# + Parallax 0.5548 mas. Distance 1800 pc.
#
# Vizier - Gaia 4067633238255477248
# + Parallax 0.5548. Distance 1800 pc.
# + Teff unknown
# + Rstar unknown
# + Mstar unknown

# %%
# %load_ext wurlitzer
import numpy as np
import os
import stingray as st
import matplotlib.pyplot as plt
from astropy.io import fits
from xspec import *
plt.rcParams['figure.figsize'] = [15, 8]

lc = fits.open('0886090801_001/0886090801_PN1_dt1.lc')
bkg = fits.open('0886090801_001/0886090801_PN1_dt1_bkg.lc')
full_gti = []
for j in lc[2].data:
    full_gti.append([j[0],j[1]])
soft = fits.open('0886090801_001/0886090801_PN1_dt1_0.2-2keV.lc')
sbkg = fits.open('0886090801_001/0886090801_PN1_dt1_0.2-2keV_bkg.lc')
soft_gti = []
for j in soft[2].data:
    soft_gti.append([j[0],j[1]])
hard = fits.open('0886090801_001/0886090801_PN1_dt1_2-12keV.lc')
hbkg = fits.open('0886090801_001/0886090801_PN1_dt1_2-12keV_bkg.lc')
hard_gti = []
for j in hard[2].data:
    hard_gti.append([j[0],j[1]])

# %%
full_lc = st.Lightcurve(lc[1].data.field('TIME'),lc[1].data.field('RATE'),err=lc[1].data.field('ERROR'),gti=full_gti,input_counts=False)
full_bkg = st.Lightcurve(bkg[1].data.field('TIME'),bkg[1].data.field('RATE'),err=bkg[1].data.field('ERROR'),gti=full_gti,input_counts=False)

soft_lc = st.Lightcurve(soft[1].data.field('TIME'),soft[1].data.field('RATE'),err=soft[1].data.field('ERROR'),gti=soft_gti,input_counts=False)
soft_bkg = st.Lightcurve(sbkg[1].data.field('TIME'),sbkg[1].data.field('RATE'),err=sbkg[1].data.field('ERROR'),gti=soft_gti,input_counts=False)

hard_lc = st.Lightcurve(hard[1].data.field('TIME'),hard[1].data.field('RATE'),err=hard[1].data.field('ERROR'),gti=hard_gti,input_counts=False)
hard_bkg = st.Lightcurve(hbkg[1].data.field('TIME'),hbkg[1].data.field('RATE'),err=hbkg[1].data.field('ERROR'),gti=hard_gti,input_counts=False)

full_lc.apply_gtis()
full_bkg.apply_gtis()
soft_lc.apply_gtis()
soft_bkg.apply_gtis()
hard_lc.apply_gtis()
hard_bkg.apply_gtis()
# Out:
# /home/rwebbe/.local/lib/python3.8/site-packages/stingray/lightcurve.py:516: UserWarning: There are non-finite points in the data, but they are outside GTIs.
#   warnings.warn("There are non-finite points in the data, but they are outside GTIs. ")
# /home/rwebbe/.local/lib/python3.8/site-packages/stingray/lightcurve.py:516: UserWarning: There are non-finite points in the data, but they are outside GTIs.
#   warnings.warn("There are non-finite points in the data, but they are outside GTIs. ")

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(soft_lc.time,soft_lc.countrate,color='r')
plt.plot(hard_lc.time,hard_lc.countrate,color='b')

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(full_bkg.time,full_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.time,soft_lc.countrate,color='k')
plt.plot(soft_bkg.time,soft_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.time,hard_lc.countrate,color='k')
plt.plot(hard_bkg.time,hard_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='r')
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='b')
plt.xlabel('Time (s)')
plt.ylabel('Count rate /s)')
plt.savefig('0886090801_001/0886090801_001_dt50lc.png')

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(full_bkg.rebin(50).time,full_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='k')
plt.plot(soft_bkg.rebin(50).time,soft_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='k')
plt.plot(hard_bkg.rebin(50).time,hard_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='r')
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='b')

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(full_bkg.rebin(250).time,full_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='k')
plt.plot(soft_bkg.rebin(250).time,soft_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='k')
plt.plot(hard_bkg.rebin(250).time,hard_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
os.chdir("0886090801_001")
spec = Spectrum("0886090801_PN1grpspec.fits")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0886090801_PN1grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  1.040e+00 +/- 8.015e-03 (95.1 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-104
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 1.768e+04 sec
#  Using fit statistic: chi
#  Using Background File                0886090801_PN1spec_bkg.fits
#   Background Exposure Time: 1.768e+04 sec
#  Using Response (RMF) File            0886090801_PN1spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0886090801_PN1spec.arf

# %%
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.0005 0.5")
Plot("data")

# %%
spec.ignore("**-0.2 12.0-**")
mo1 = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
#      2 channels (1-2) ignored in spectrum #     1
#      1 channels (104) ignored in spectrum #     1
#
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              1.557147e+11     using 101 bins.
#
# Test statistic : Chi-Squared              1.557147e+11     using 101 bins.
#  Null hypothesis probability of 0.000000e+00 with 98 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 8188.55      273.949       0      0.381454       3.05248   0.000197013
# 7535.94      1.89992e+06   0      0.152916       2.96783   0.000187593
# 6496.98      2.38202e+06  -1     0.0545678       2.36422   0.000118512
# 2392.18      6.36226e+06  -1     0.0219123       1.44294   8.14030e-05
# 1174.88      8.36728e+06  -2    0.00656796       1.13980   7.50782e-05
# 1148.61      100056       -3     0.0370640       1.10408   7.41160e-05
# 1147.48      39108.6      -4     0.0347308       1.09815   7.34692e-05
# 1147.36      1298.85      -5     0.0365002       1.09522   7.33432e-05
# 1147.35      106.104      -6     0.0363658       1.09453   7.32807e-05
# 1147.35      21.485       -7     0.0365213       1.09422   7.32657e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  3.4922E-13| -0.0001  -0.0001   1.0000
#  2.5520E-05| -0.8853  -0.4651  -0.0001
#  1.1235E-04|  0.4651  -0.8853  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    4.430e-05  -3.575e-05  -2.146e-10
#   -3.575e-05   9.357e-05   5.291e-09
#   -2.146e-10   5.291e-09   7.550e-13
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    3.65213E-02  +/-  6.65598E-03
#    2    2   bbody      kT         keV      1.09422      +/-  9.67292E-03
#    3    2   bbody      norm                7.32657E-05  +/-  8.68894E-07
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 1147.35     using 101 bins.
#
# Test statistic : Chi-Squared                 1147.35     using 101 bins.
#  Null hypothesis probability of 1.64e-178 with 98 degrees of freedom
#  Model Flux 0.0012325 photons (6.0317e-12 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
mo2 = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              2.504448e+10     using 101 bins.
#
# Test statistic : Chi-Squared              2.504448e+10     using 101 bins.
#  Null hypothesis probability of 0.000000e+00 with 98 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 1941.54      988.932      -3      0.126136      0.942367   0.000432155
# 533.219      828815       -4      0.343967       1.27763   0.000743271
# 196.384      791291       -5      0.438384       1.37266   0.000973815
# 185.253      141576       -6      0.434718       1.36669   0.000992068
# 185.252      988.44       -7      0.434961       1.36699   0.000992329
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  6.0213E-11| -0.0008  -0.0008   1.0000
#  4.1587E-05|  0.9009  -0.4340   0.0003
#  5.2060E-04|  0.4340   0.9009   0.0011
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.318e-04   1.873e-04   2.608e-07
#    1.873e-04   4.304e-04   5.084e-07
#    2.608e-07   5.084e-07   6.919e-10
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.434961     +/-  1.14812E-02
#    2    2   powerlaw   PhoIndex            1.36699      +/-  2.07452E-02
#    3    2   powerlaw   norm                9.92329E-04  +/-  2.63044E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  185.25     using 101 bins.
#
# Test statistic : Chi-Squared                  185.25     using 101 bins.
#  Null hypothesis probability of 2.45e-07 with 98 degrees of freedom
#  Model Flux 0.0014324 photons (8.99e-12 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
mo3 = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              8.783979e+08     using 101 bins.
#
# Test statistic : Chi-Squared              8.783979e+08     using 101 bins.
#  Null hypothesis probability of 0.000000e+00 with 98 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 7049.47      1335.31      -3       1.66705      0.863679    0.00687586
# 5709.22      103319       -4       1.59133       1.30964    0.00580131
# 3320.7       137217       -5      0.957270       2.11618    0.00536428
# 2566.34      28526.7      -2      0.383660       3.96042    0.00371998
# 734.8        133202       -3      0.427996       6.70475    0.00390201
# 285.659      6658.02      -4      0.423522       10.9242    0.00402885
# 188.707      21243.6      -5      0.431159       15.5637    0.00427499
# 168.472      19573.6      -6      0.427466       19.4921    0.00444707
# 164.099      1291.74      -7      0.421318       22.6428    0.00452662
# 162.992      90.9224      -8      0.417769       24.5670    0.00457170
# Number of trials exceeded: continue fitting? 162.732      190.745      -9      0.415693       25.9344    0.00460345
# 162.711      41.5211     -10      0.415074       26.3345    0.00461298
# 162.71       0.364253    -11      0.415012       26.3830    0.00461417
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  1.3005E-09| -0.0036  -0.0000   1.0000
#  5.0191E-05|  1.0000   0.0017   0.0036
#  9.5756E+00| -0.0017   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    7.789e-05  -1.629e-02  -1.902e-07
#   -1.629e-02   9.576e+00   2.193e-04
#   -1.902e-07   2.193e-04   6.991e-09
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.415012     +/-  8.82559E-03
#    2    2   apec       kT         keV      26.3830      +/-  3.09445
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                4.61417E-03  +/-  8.36140E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  162.71     using 101 bins.
#
# Test statistic : Chi-Squared                  162.71     using 101 bins.
#  Null hypothesis probability of 4.40e-05 with 98 degrees of freedom
#  Model Flux 0.0014128 photons (8.6354e-12 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
mo4 = Model("tbabs*(apec+apec)")
mo4.apec.kT = 0.5
mo4.apec_3.kT = 4.0
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              3.524234e+09     using 101 bins.
#
# Test statistic : Chi-Squared              3.524234e+09     using 101 bins.
#  Null hypothesis probability of 0.000000e+00 with 96 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              2.066519e+09     using 101 bins.
#
# Test statistic : Chi-Squared              2.066519e+09     using 101 bins.
#  Null hypothesis probability of 0.000000e+00 with 96 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              1.061531e+09     using 101 bins.
#
# Test statistic : Chi-Squared              1.061531e+09     using 101 bins.
#  Null hypothesis probability of 0.000000e+00 with 96 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm          6:kT        9:norm
# 562.925      94670.9      -3      0.937498      0.483790    0.00166869       6.58463    0.00450878
# 495.529      26394.6      -4      0.610386      0.548590   0.000531844       10.1820    0.00427072
# 350.944      188716       -5      0.463853      0.641196   0.000153181       13.9278    0.00428803
# 156.477      292663       -6      0.467786      0.730387   5.29376e-05       18.2406    0.00443009
# 148.748      15004.3      -7      0.468899      0.875409   6.71872e-05       21.0913    0.00450797
# 146.047      7115.75      -8      0.463768      0.856415   6.99919e-05       23.6424    0.00456408
# 145.333      1372.88      -9      0.459425      0.867121   6.88125e-05       25.5741    0.00460667
# 145.225      382.57      -10      0.457843      0.872983   6.85705e-05       26.3222    0.00462276
# 145.205      180.28      -11      0.456943      0.875984   6.84382e-05       26.7802    0.00463272
# 145.205      13.523      -12      0.456922      0.876015   6.84170e-05       26.7805    0.00463273
# ============================================================
#  Variances and Principal Axes
#                  1        2        5        6        9
#  7.3454E-11| -0.0013  -0.0000   0.9941  -0.0000   0.1081
#  1.7659E-09| -0.0011   0.0001  -0.1081  -0.0000   0.9941
#  1.9754E-04|  0.9983   0.0575   0.0012   0.0018   0.0012
#  5.5177E-03|  0.0575  -0.9983   0.0000   0.0061   0.0002
#  1.0320E+01| -0.0021   0.0060  -0.0000   1.0000   0.0000
# ------------------------------------------------------------
#
# ============================================================
#   Covariance Matrix
#         1           2           3           4           5
#    2.625e-04  -4.384e-04   2.428e-07  -2.212e-02  -1.835e-07
#   -4.384e-04   5.874e-03  -8.198e-08   6.211e-02   4.075e-07
#    2.428e-07  -8.198e-08   3.652e-10  -3.837e-06   3.060e-11
#   -2.212e-02   6.211e-02  -3.837e-06   1.032e+01   2.242e-04
#   -1.835e-07   4.075e-07   3.060e-11   2.242e-04   7.081e-09
# ------------------------------------------------------------
#
# ========================================================================
# Model TBabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.456922     +/-  1.62029E-02
#    2    2   apec       kT         keV      0.876015     +/-  7.66425E-02
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                6.84170E-05  +/-  1.91101E-05
#    6    3   apec       kT         keV      26.7805      +/-  3.21238
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                4.63273E-03  +/-  8.41484E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  145.20     using 101 bins.
#
# Test statistic : Chi-Squared                  145.20     using 101 bins.
#  Null hypothesis probability of 8.88e-04 with 96 degrees of freedom
#  Model Flux 0.0014123 photons (8.651e-12 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
mo4.apec_3.kT.error
# Out:
# (0.0, 0.0, 'FFFFFFFFF')

# %%
mo5 = Model("tbabs*(powerlaw+gaussian)")
mo5.gaussian.LineE = 6.7
mo5.gaussian.LineE.frozen=True
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>(powerlaw<2> + gaussian<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
#    4    3   gaussian   LineE      keV      6.50000      +/-  0.0
#    5    3   gaussian   Sigma      keV      0.100000     +/-  0.0
#    6    3   gaussian   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              2.289262e+11     using 101 bins.
#
# Test statistic : Chi-Squared              2.289262e+11     using 101 bins.
#  Null hypothesis probability of 0.000000e+00 with 95 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              2.227956e+11     using 101 bins.
#
# Test statistic : Chi-Squared              2.227956e+11     using 101 bins.
#  Null hypothesis probability of 0.000000e+00 with 95 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              2.227956e+11     using 101 bins.
#
# Test statistic : Chi-Squared              2.227956e+11     using 101 bins.
#  Null hypothesis probability of 0.000000e+00 with 96 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm       5:Sigma        6:norm
# 1667.86      3.81531e+06  -3      0.356213      0.895885   0.000463079      0.122187   4.76282e-07
# 792.318      1.08373e+06  -4      0.445208       1.50570   0.000907488       7.53314   2.77183e-05
# 455.497      553566       -5      0.461616       1.36058    0.00112808       2.22443   7.90540e-06
# 321.62       451537       -6      0.423187       1.26038   0.000958844      0.486628   5.13949e-07
# 131.747      265229       -7      0.449160       1.40895    0.00103074      0.216562   2.76144e-05
# 124.453      71728.7      -8      0.455384       1.43394    0.00105258      0.325936   3.13806e-05
# 124.423      7759.48      -9      0.455922       1.43607    0.00105457      0.328782   3.22113e-05
# 124.423      39.0856     -10      0.455868       1.43592    0.00105442      0.327926   3.21666e-05
# ============================================================
#  Variances and Principal Axes
#                  1        2        3        5        6
#  1.3550E-11| -0.0000  -0.0002   0.1029  -0.0000   0.9947
#  7.3175E-11|  0.0009   0.0008  -0.9947  -0.0000   0.1029
#  4.5385E-05|  0.9110  -0.4119   0.0005   0.0187  -0.0001
#  6.3147E-04|  0.4087   0.8960   0.0011  -0.1738   0.0001
#  3.5367E-03|  0.0548   0.1660   0.0002   0.9846   0.0001
# ------------------------------------------------------------
#
# ============================================================
#   Covariance Matrix
#         1           2           3           4           5
#    1.538e-04   2.464e-04   3.350e-07   1.469e-04   1.950e-08
#    2.464e-04   6.121e-04   7.092e-07   4.794e-04   6.316e-08
#    3.350e-07   7.092e-07   9.409e-10   4.424e-07   5.865e-11
#    1.469e-04   4.794e-04   4.424e-07   3.448e-03   1.843e-07
#    1.950e-08   6.316e-08   5.865e-11   1.843e-07   2.690e-11
# ------------------------------------------------------------
#
# ========================================================================
# Model TBabs<1>(powerlaw<2> + gaussian<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.455868     +/-  1.24011E-02
#    2    2   powerlaw   PhoIndex            1.43592      +/-  2.47406E-02
#    3    2   powerlaw   norm                1.05442E-03  +/-  3.06743E-05
#    4    3   gaussian   LineE      keV      6.70000      frozen
#    5    3   gaussian   Sigma      keV      0.327926     +/-  5.87168E-02
#    6    3   gaussian   norm                3.21666E-05  +/-  5.18665E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  124.42     using 101 bins.
#
# Test statistic : Chi-Squared                  124.42     using 101 bins.
#  Null hypothesis probability of 2.71e-02 with 96 degrees of freedom
#  Model Flux 0.0014245 photons (8.8598e-12 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
flux = 8.99*10**-12
d_pc = 1800
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')
# Out:
# Luminosity is: 3.4948740159382747e+33 erg s^-1

# %%
g_mag = 8.396587
opt_flux = (10**(0.4*(-26.7 - g_mag))) * (3.828 * 10 ** 33) / (4*np.pi*(1.496*10**13)**2)
print('Optical flux: '+str(opt_flux))
opt_x_ratio = flux / opt_flux
print('The x-ray/optical flux ratio is: '+str(opt_x_ratio))
# Out:
# Optical flux: 1.2452715840913964e-08
# The x-ray/optical flux ratio is: 0.0007219308715342999
