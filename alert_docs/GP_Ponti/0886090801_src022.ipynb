# %% [markdown]
# Obs 0886090801 source 022. First X-ray detection. (268.5359, -24.6404, 1.18")
#
# No SIMBAD
#
# Vizier - Gaia 4067641690762865024 2.69"
# + Parallax 0.6018. Distance 1660 pc.
# + Teff unknown
# + Rstar unknown
# + Mstar unknown
#
# Vizier - Gaia 4067641690720946432 4.23"
# + Parallax unknown.
# + Teff unknown
# + Rstar unknown
# + Mstar unknown

# %%
# %load_ext wurlitzer
import numpy as np
import os
import stingray as st
import matplotlib.pyplot as plt
from astropy.io import fits
from xspec import *
plt.rcParams['figure.figsize'] = [15, 8]

lc = fits.open('0886090801/0886090801_PN22_dt1.lc')
bkg = fits.open('0886090801/0886090801_PN22_dt1_bkg.lc')
full_gti = []
for j in lc[2].data:
    full_gti.append([j[0],j[1]])
soft = fits.open('0886090801/0886090801_PN22_dt1_0.2-2keV.lc')
sbkg = fits.open('0886090801/0886090801_PN22_dt1_0.2-2keV_bkg.lc')
soft_gti = []
for j in soft[2].data:
    soft_gti.append([j[0],j[1]])
hard = fits.open('0886090801/0886090801_PN22_dt1_2-12keV.lc')
hbkg = fits.open('0886090801/0886090801_PN22_dt1_2-12keV_bkg.lc')
hard_gti = []
for j in hard[2].data:
    hard_gti.append([j[0],j[1]])

# %%
full_lc = st.Lightcurve(lc[1].data.field('TIME'),lc[1].data.field('RATE'),err=lc[1].data.field('ERROR'),gti=full_gti,input_counts=False)
full_bkg = st.Lightcurve(bkg[1].data.field('TIME'),bkg[1].data.field('RATE'),err=bkg[1].data.field('ERROR'),gti=full_gti,input_counts=False)

soft_lc = st.Lightcurve(soft[1].data.field('TIME'),soft[1].data.field('RATE'),err=soft[1].data.field('ERROR'),gti=soft_gti,input_counts=False)
soft_bkg = st.Lightcurve(sbkg[1].data.field('TIME'),sbkg[1].data.field('RATE'),err=sbkg[1].data.field('ERROR'),gti=soft_gti,input_counts=False)

hard_lc = st.Lightcurve(hard[1].data.field('TIME'),hard[1].data.field('RATE'),err=hard[1].data.field('ERROR'),gti=hard_gti,input_counts=False)
hard_bkg = st.Lightcurve(hbkg[1].data.field('TIME'),hbkg[1].data.field('RATE'),err=hbkg[1].data.field('ERROR'),gti=hard_gti,input_counts=False)

full_lc.apply_gtis()
full_bkg.apply_gtis()
soft_lc.apply_gtis()
soft_bkg.apply_gtis()
hard_lc.apply_gtis()
hard_bkg.apply_gtis()
# Out:
# /home/rwebbe/.local/lib/python3.8/site-packages/stingray/lightcurve.py:516: UserWarning: There are non-finite points in the data, but they are outside GTIs.
#   warnings.warn("There are non-finite points in the data, but they are outside GTIs. ")
# /home/rwebbe/.local/lib/python3.8/site-packages/stingray/lightcurve.py:516: UserWarning: There are non-finite points in the data, but they are outside GTIs.
#   warnings.warn("There are non-finite points in the data, but they are outside GTIs. ")

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(soft_lc.time,soft_lc.countrate,color='r')
plt.plot(hard_lc.time,hard_lc.countrate,color='b')

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(full_bkg.time,full_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.time,soft_lc.countrate,color='k')
plt.plot(soft_bkg.time,soft_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.time,hard_lc.countrate,color='k')
plt.plot(hard_bkg.time,hard_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='r')
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='b')

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(full_bkg.rebin(50).time,full_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='k')
plt.plot(soft_bkg.rebin(50).time,soft_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='k')
plt.plot(hard_bkg.rebin(50).time,hard_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='r')
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='b')

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(full_bkg.rebin(250).time,full_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='k')
plt.plot(soft_bkg.rebin(250).time,soft_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='k')
plt.plot(hard_bkg.rebin(250).time,hard_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
os.chdir("0886090801")
spec = Spectrum("0886090801_PN22grpspec.fits")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0886090801_PN22grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  2.958e-03 +/- 8.896e-04 (40.9 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-6
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 1.768e+04 sec
#  Using fit statistic: chi
#  Using Background File                0886090801_PN22spec_bkg.fits
#   Background Exposure Time: 1.768e+04 sec
#  Using Response (RMF) File            0886090801_PN22spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0886090801_PN22spec.arf

# %%
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot("data")

# %%
spec.ignore("**-0.2 12.0-**")
mo1 = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
#      1 channels (1) ignored in spectrum #     1
#      1 channels (6) ignored in spectrum #     1
#
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setti
# ng
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              1.959063e+11     using 4 bins.
#
# Test statistic : Chi-Squared              1.959063e+11     using 4 bins.
#  Null hypothesis probability of 0.000000e+00 with 1 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 7.59646      0.449081      0      0.190371       3.07620   6.19166e-06
# 6.13918      78054.4       0   0.000602216       3.06001   6.01053e-06
# 5.94682      97140         0   0.000289539       3.00518   6.00910e-06
# 5.86369      77239.7       0   0.000144152       2.96803   5.92978e-06
# 5.81146      70223.7       0   3.46708e-06       2.93685   5.82428e-06
# 5.77058      68188.6       0   1.31121e-06       2.90777   5.71019e-06
# 5.73289      68090.2       0   2.47947e-07       2.87943   5.59373e-06
# 5.69588      68775.9       0   1.16629e-07       2.85133   5.47727e-06
# 5.65859      69780.8       0   5.17250e-08       2.82325   5.36170e-06
# 5.62064      70924.9       0   1.96467e-08       2.79514   5.24732e-06
# Number of trials exceeded: continue fitting? 5.58188      72138.4       0   3.79541e-09       2.76695   5.13428e-06
# 5.54223      73394.3       0   1.83773e-09       2.73869   5.02260e-06
# 5.50164      74682.4       0   8.70915e-10       2.71034   4.91230e-06
# 5.46006      75998.6       0   3.93609e-10       2.68191   4.80340e-06
# 5.41747      77341.1       0   1.58050e-10       2.65339   4.69589e-06
# 5.37384      78709.3       0   4.18405e-11       2.62479   4.58978e-06
# 5.32911      80103.3       0   1.31865e-11       2.59610   4.48508e-06
# 5.28328      81520.6       0   6.12414e-12       2.56733   4.38177e-06
# 5.23629      82965.1       0   2.64424e-12       2.53847   4.27987e-06
# 5.18815      84431.3       0   9.30332e-13       2.50954   4.17935e-06
# Number of trials exceeded: continue fitting? 5.13858      85934.6       0   8.64373e-14       2.48049   4.08040e-06
# 5.08781      87394.1       0   3.45090e-14       2.45137   3.98279e-06
# 5.03335      88897         0   9.07583e-15       2.42174   3.88817e-06
# 4.97826      89610.5       0   2.93598e-15       2.39206   3.79380e-06
# 4.92939      90635.9       0   1.41394e-15       2.36379   3.69674e-06
# 4.85259      94256.4       0   6.70450e-16       2.33048   3.61652e-06
# 4.85135      88265.3       0   2.86225e-16       2.31071   3.49316e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.0124E-12| -0.0000  -0.0000   1.0000
#  1.1841E-01|  0.9934   0.1148   0.0000
#  1.0605E+01| -0.1148   0.9934   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.566e-01  -1.196e+00  -3.620e-06
#   -1.196e+00   1.047e+01   3.386e-05
#   -3.620e-06   3.386e-05   1.111e-10
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    2.86225E-16  +/-  0.506525
#    2    2   bbody      kT         keV      2.31071      +/-  3.23522
#    3    2   bbody      norm                3.49316E-06  +/-  1.05381E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    4.85     using 4 bins.
#
# Test statistic : Chi-Squared                    4.85     using 4 bins.
#  Null hypothesis probability of 2.76e-02 with 1 degrees of freedom
#  Model Flux 2.6554e-05 photons (2.2791e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
mo2 = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              9.277828e+10     using 4 bins.
#
# Test statistic : Chi-Squared              9.277828e+10     using 4 bins.
#  Null hypothesis probability of 0.000000e+00 with 1 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 2.25071      0.719857     -2      0.188600       1.03433   8.98563e-06
# 1.84571      94440.7      -3      0.128851      0.657242   5.62704e-06
# 1.73682      75223.3      -4      0.154762      0.736116   6.53955e-06
# 1.73535      7385.25      -5      0.150670      0.718502   6.49433e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  2.4216E-12| -0.0000  -0.0000   1.0000
#  2.3737E-02|  0.9557  -0.2942   0.0000
#  1.1482E+00|  0.2942   0.9557   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.211e-01   3.162e-01   2.199e-06
#    3.162e-01   1.051e+00   6.540e-06
#    2.199e-06   6.540e-06   4.517e-11
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.150670     +/-  0.347972
#    2    2   powerlaw   PhoIndex            0.718502     +/-  1.02511
#    3    2   powerlaw   norm                6.49433E-06  +/-  6.72101E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    1.74     using 4 bins.
#
# Test statistic : Chi-Squared                    1.74     using 4 bins.
#  Null hypothesis probability of 1.88e-01 with 1 degrees of freedom
#  Model Flux 2.4633e-05 photons (1.8773e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
flux = 2.2791*10**-13
d_pc = 1660
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')
# Out:
# Luminosity is: 7.535401201614275e+31 erg s^-1

# %%
d_pc = 7500
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')
# Out:
# Luminosity is: 1.5381997299709797e+33 erg s^-1
