# %%
# %load_ext wurlitzer
import numpy as np
import os
import stingray as st
import matplotlib.pyplot as plt
from astropy.io import fits
from xspec import *
plt.rcParams['figure.figsize'] = [15, 8]

lc = fits.open('0934201001_M1_dt5.lc')
bkg = fits.open('0934201001_M1_dt5_bkg.lc')
full_gti = []
for j in lc[2].data:
    full_gti.append([j[0],j[1]])
soft = fits.open('0934201001_M1_dt5_0.2-2keV.lc')
sbkg = fits.open('0934201001_M1_dt5_0.2-2keV_bkg.lc')
soft_gti = []
for j in soft[2].data:
    soft_gti.append([j[0],j[1]])
hard = fits.open('0934201001_M1_dt5_2-12keV.lc')
hbkg = fits.open('0934201001_M1_dt5_2-12keV_bkg.lc')
hard_gti = []
for j in hard[2].data:
    hard_gti.append([j[0],j[1]])
    
lc1 = fits.open('0886040201_PN20_dt1.lc')
bkg1 = fits.open('0886040201_PN20_dt1_bkg.lc')
full_gti1 = []
for j in lc1[2].data:
    full_gti1.append([j[0],j[1]])
soft1 = fits.open('0886040201_PN20_dt1_0.2-2keV.lc')
sbkg1 = fits.open('0886040201_PN20_dt1_0.2-2keV_bkg.lc')
soft_gti1 = []
for j in soft1[2].data:
    soft_gti1.append([j[0],j[1]])
hard1 = fits.open('0886040201_PN20_dt1_2-12keV.lc')
hbkg1 = fits.open('0886040201_PN20_dt1_2-12keV_bkg.lc')
hard_gti1 = []
for j in hard1[2].data:
    hard_gti1.append([j[0],j[1]])
    
lc2 = fits.open('0934200401_M1_dt5.lc')
bkg2 = fits.open('0934200401_M1_dt5_bkg.lc')
full_gti2 = []
for j in lc2[2].data:
    full_gti2.append([j[0],j[1]])
soft2 = fits.open('0934200401_M1_dt5_0.2-2keV.lc')
sbkg2 = fits.open('0934200401_M1_dt5_0.2-2keV_bkg.lc')
soft_gti2 = []
for j in soft2[2].data:
    soft_gti2.append([j[0],j[1]])
hard2 = fits.open('0934200401_M1_dt5_2-12keV.lc')
hbkg2 = fits.open('0934200401_M1_dt5_2-12keV_bkg.lc')
hard_gti2 = []
for j in hard2[2].data:
    hard_gti2.append([j[0],j[1]])
    
lc3 = fits.open('0934200401_M2_dt5.lc')
bkg3 = fits.open('0934200401_M2_dt5_bkg.lc')
full_gti3 = []
for j in lc3[2].data:
    full_gti3.append([j[0],j[1]])
soft3 = fits.open('0934200401_M2_dt5_0.2-2keV.lc')
sbkg3 = fits.open('0934200401_M2_dt5_0.2-2keV_bkg.lc')
soft_gti3 = []
for j in soft3[2].data:
    soft_gti3.append([j[0],j[1]])
hard3 = fits.open('0934200401_M2_dt5_2-12keV.lc')
hbkg3 = fits.open('0934200401_M2_dt5_2-12keV_bkg.lc')
hard_gti3 = []
for j in hard3[2].data:
    hard_gti3.append([j[0],j[1]])

# %%
full_lc = st.Lightcurve(lc[1].data.field('TIME'),lc[1].data.field('RATE'),err=lc[1].data.field('ERROR'),gti=full_gti,input_counts=False)
full_bkg = st.Lightcurve(bkg[1].data.field('TIME'),bkg[1].data.field('RATE'),err=bkg[1].data.field('ERROR'),gti=full_gti,input_counts=False)

soft_lc = st.Lightcurve(soft[1].data.field('TIME'),soft[1].data.field('RATE'),err=soft[1].data.field('ERROR'),gti=soft_gti,input_counts=False)
soft_bkg = st.Lightcurve(sbkg[1].data.field('TIME'),sbkg[1].data.field('RATE'),err=sbkg[1].data.field('ERROR'),gti=soft_gti,input_counts=False)

hard_lc = st.Lightcurve(hard[1].data.field('TIME'),hard[1].data.field('RATE'),err=hard[1].data.field('ERROR'),gti=hard_gti,input_counts=False)
hard_bkg = st.Lightcurve(hbkg[1].data.field('TIME'),hbkg[1].data.field('RATE'),err=hbkg[1].data.field('ERROR'),gti=hard_gti,input_counts=False)

full_lc.apply_gtis()
full_bkg.apply_gtis()
soft_lc.apply_gtis()
soft_bkg.apply_gtis()
hard_lc.apply_gtis()
hard_bkg.apply_gtis()

full_lc1 = st.Lightcurve(lc1[1].data.field('TIME'),lc1[1].data.field('RATE'),err=lc1[1].data.field('ERROR'),gti=full_gti1,input_counts=False)
full_bkg1 = st.Lightcurve(bkg1[1].data.field('TIME'),bkg1[1].data.field('RATE'),err=bkg1[1].data.field('ERROR'),gti=full_gti1,input_counts=False)

soft_lc1 = st.Lightcurve(soft1[1].data.field('TIME'),soft1[1].data.field('RATE'),err=soft1[1].data.field('ERROR'),gti=soft_gti1,input_counts=False)
soft_bkg1 = st.Lightcurve(sbkg1[1].data.field('TIME'),sbkg1[1].data.field('RATE'),err=sbkg1[1].data.field('ERROR'),gti=soft_gti1,input_counts=False)

hard_lc1 = st.Lightcurve(hard1[1].data.field('TIME'),hard1[1].data.field('RATE'),err=hard1[1].data.field('ERROR'),gti=hard_gti1,input_counts=False)
hard_bkg1 = st.Lightcurve(hbkg1[1].data.field('TIME'),hbkg1[1].data.field('RATE'),err=hbkg1[1].data.field('ERROR'),gti=hard_gti1,input_counts=False)

full_lc1.apply_gtis()
full_bkg1.apply_gtis()
soft_lc1.apply_gtis()
soft_bkg1.apply_gtis()
hard_lc1.apply_gtis()
hard_bkg1.apply_gtis()

full_lc2 = st.Lightcurve(lc2[1].data.field('TIME'),lc2[1].data.field('RATE'),err=lc2[1].data.field('ERROR'),gti=full_gti2,input_counts=False)
full_bkg2 = st.Lightcurve(bkg2[1].data.field('TIME'),bkg2[1].data.field('RATE'),err=bkg2[1].data.field('ERROR'),gti=full_gti2,input_counts=False)

soft_lc2 = st.Lightcurve(soft2[1].data.field('TIME'),soft2[1].data.field('RATE'),err=soft2[1].data.field('ERROR'),gti=soft_gti2,input_counts=False)
soft_bkg2 = st.Lightcurve(sbkg2[1].data.field('TIME'),sbkg2[1].data.field('RATE'),err=sbkg2[1].data.field('ERROR'),gti=soft_gti2,input_counts=False)

hard_lc2 = st.Lightcurve(hard2[1].data.field('TIME'),hard2[1].data.field('RATE'),err=hard2[1].data.field('ERROR'),gti=hard_gti2,input_counts=False)
hard_bkg2 = st.Lightcurve(hbkg2[1].data.field('TIME'),hbkg2[1].data.field('RATE'),err=hbkg2[1].data.field('ERROR'),gti=hard_gti2,input_counts=False)

full_lc2.apply_gtis()
full_bkg2.apply_gtis()
soft_lc2.apply_gtis()
soft_bkg2.apply_gtis()
hard_lc2.apply_gtis()
hard_bkg2.apply_gtis()

full_lc3 = st.Lightcurve(lc3[1].data.field('TIME'),lc3[1].data.field('RATE'),err=lc3[1].data.field('ERROR'),gti=full_gti3,input_counts=False)
full_bkg3 = st.Lightcurve(bkg3[1].data.field('TIME'),bkg3[1].data.field('RATE'),err=bkg3[1].data.field('ERROR'),gti=full_gti3,input_counts=False)

soft_lc3 = st.Lightcurve(soft3[1].data.field('TIME'),soft3[1].data.field('RATE'),err=soft3[1].data.field('ERROR'),gti=soft_gti3,input_counts=False)
soft_bkg3 = st.Lightcurve(sbkg3[1].data.field('TIME'),sbkg3[1].data.field('RATE'),err=sbkg3[1].data.field('ERROR'),gti=soft_gti3,input_counts=False)

hard_lc3 = st.Lightcurve(hard3[1].data.field('TIME'),hard3[1].data.field('RATE'),err=hard3[1].data.field('ERROR'),gti=hard_gti3,input_counts=False)
hard_bkg3 = st.Lightcurve(hbkg3[1].data.field('TIME'),hbkg3[1].data.field('RATE'),err=hbkg3[1].data.field('ERROR'),gti=hard_gti3,input_counts=False)

full_lc3.apply_gtis()
full_bkg3.apply_gtis()
soft_lc3.apply_gtis()
soft_bkg3.apply_gtis()
hard_lc3.apply_gtis()
hard_bkg3.apply_gtis()
# Out:
# /home/rwebbe/.local/lib/python3.8/site-packages/stingray/lightcurve.py:516: UserWarning: There are non-finite points in the data, but they are outside GTIs.
#   warnings.warn("There are non-finite points in the data, but they are outside GTIs. ")
# /home/rwebbe/.local/lib/python3.8/site-packages/stingray/lightcurve.py:516: UserWarning: There are non-finite points in the data, but they are outside GTIs.
#   warnings.warn("There are non-finite points in the data, but they are outside GTIs. ")

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(soft_lc.time,soft_lc.countrate,color='r')
plt.plot(hard_lc.time,hard_lc.countrate,color='b')

# %%
plt.plot(full_lc1.time,full_lc1.countrate,color='k')
plt.plot(soft_lc1.time,soft_lc1.countrate,color='r')
plt.plot(hard_lc1.time,hard_lc1.countrate,color='b')

# %%
plt.plot(full_lc2.time,full_lc2.countrate,color='k')
plt.plot(soft_lc2.time,soft_lc2.countrate,color='r')
plt.plot(hard_lc2.time,hard_lc2.countrate,color='b')

# %%
plt.plot(full_lc3.time,full_lc3.countrate,color='k')
plt.plot(soft_lc3.time,soft_lc3.countrate,color='r')
plt.plot(hard_lc3.time,hard_lc3.countrate,color='b')

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='r')
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='b')

# %%
plt.plot(full_lc1.rebin(50).time,full_lc1.rebin(50).countrate,color='k')
plt.plot(soft_lc1.rebin(50).time,soft_lc1.rebin(50).countrate,color='r')
plt.plot(hard_lc1.rebin(50).time,hard_lc1.rebin(50).countrate,color='b')

# %%
plt.plot(full_lc2.rebin(50).time,full_lc2.rebin(50).countrate,color='k')
plt.plot(soft_lc2.rebin(50).time,soft_lc2.rebin(50).countrate,color='r')
plt.plot(hard_lc2.rebin(50).time,hard_lc2.rebin(50).countrate,color='b')

# %%
plt.plot(full_lc3.rebin(50).time,full_lc3.rebin(50).countrate,color='k')
plt.plot(soft_lc3.rebin(50).time,soft_lc3.rebin(50).countrate,color='r')
plt.plot(hard_lc3.rebin(50).time,hard_lc3.rebin(50).countrate,color='b')

# %%
plt.plot(hard_lc1.rebin(50).time,hard_lc1.rebin(50).countrate,color='k')
plt.plot(hard_bkg1.rebin(50).time,hard_bkg1.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='r')
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='b')

# %%
plt.plot(full_lc1.rebin(250).time,full_lc1.rebin(250).countrate,color='k')
plt.plot(soft_lc1.rebin(250).time,soft_lc1.rebin(250).countrate,color='r')
plt.plot(hard_lc1.rebin(250).time,hard_lc1.rebin(250).countrate,color='b')

# %%
plt.plot(full_lc2.rebin(250).time,full_lc2.rebin(250).countrate,color='k')
plt.plot(soft_lc2.rebin(250).time,soft_lc2.rebin(250).countrate,color='r')
plt.plot(hard_lc2.rebin(250).time,hard_lc2.rebin(250).countrate,color='b')

# %%
plt.plot(full_lc3.rebin(250).time,full_lc3.rebin(250).countrate,color='k')
plt.plot(soft_lc3.rebin(250).time,soft_lc3.rebin(250).countrate,color='r')
plt.plot(hard_lc3.rebin(250).time,hard_lc3.rebin(250).countrate,color='b')

# %%
spec = Spectrum("0886040201_PN20grpspec.fits")
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.000005 0.01")
Plot("data")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0886040201_PN20grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  -2.307e+04 +/- 6.010e+02 (-96306204.8 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-23
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 1.808e+04 sec
#  Using fit statistic: chi
#  Using Background File                0886040201_PN20spec_bkg.fits
#   Background Exposure Time: 1.808e+04 sec
#  Using Response (RMF) File            0886040201_PN20spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0886040201_PN20spec.arf

# %%
#Plot.device = "/png"
mo1 = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ...
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# ...

# %%
mo2 = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ...
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 1535.15     using 23 bins.
#
# Test statistic : Chi-Squared                 1535.15     using 23 bins.
#  Null hypothesis probability of 1.14e-313 with 20 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
#  Due to zero model norms, the following fit parameters are temporarily frozen:1 2
# 1473         15.2405      -3       1.00000       1.00000       0.00000
# ...

# %%
mo3 = Model("tbabs*(bbody+powerlaw)")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ...
# Model TBabs<1>(bbody<2> + powerlaw<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
#    4    3   powerlaw   PhoIndex            1.00000      +/-  0.0
#    5    3   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 1661.36     using 23 bins.
#
# Test statistic : Chi-Squared                 1661.36     using 23 bins.
#  Null hypothesis probability of 0.00e+00 with 18 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm    4:PhoIndex        5:norm
# ...

# %%
flux = 1.9253*10**-13
d_pc = 972
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')

d_pc = 7500
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')
# Out:
# Luminosity is: 2.1825176451007197e+31 erg s^-1
# Luminosity is: 1.2994146549572759e+33 erg s^-1

# %%
AllData.clear()
AllModels.clear()
spec = Spectrum("0934200401_MOSgrpspec.fits")
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.000005 0.01")
Plot("data")
# Out:
# ***Warning: Detected response matrix energy bin value = 0 (or neg).
#      XSPEC will instead use small finite value (response file will not be altered).
# ...
#
# 1 spectrum  in use
#
# Spectral Data File: 0934200401_MOSgrpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  1.139e-02 +/- 1.456e-03 (83.9 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-7
#   Telescope: XMM Instrument: EPIC  Channel Type: PI
#   Exposure Time: 7883 sec
#  Using fit statistic: chi
#  Using Background File                0934200401_MOSspec_bkg.fits
#   Background Exposure Time: 7883 sec
#  Using Response (RMF) File            0934200401_MOSspec.rmf for Source 1

# %%
mo1 = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ...
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.960797e+11     using 7 bins.
#
# Test statistic : Chi-Squared              1.960797e+11     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 4 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 8.29199      1.10905      -1     0.0677427       2.84294   1.29991e-05
# 6.59261      119164       -1      0.140684       2.49261   1.13410e-05
# 5.75277      11016.6      -1      0.239183       2.26379   9.71813e-06
# ...

# %%
mo2 = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ...
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              5.196407e+10     using 7 bins.
#
# Test statistic : Chi-Squared              5.196407e+10     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 4 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 6.24159      2.58373      -3       1.18275      0.641203   2.29755e-05
# 6.18942      34162        -3       1.65847      0.888184   3.33314e-05
# ...

# %%
mo3 = Model("tbabs*(powerlaw+bbody)")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ...
# Model TBabs<1>(powerlaw<2> + bbody<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
#    4    3   bbody      kT         keV      3.00000      +/-  0.0
#    5    3   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              4.228274e+11     using 7 bins.
#
# Test statistic : Chi-Squared              4.228274e+11     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 2 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm          4:kT        5:norm
# ...

# %%
flux = 4.8105*10**-13
d_pc = 972
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')

d_pc = 7500
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')
# Out:
# Luminosity is: 5.453176716229685e+31 erg s^-1
# Luminosity is: 3.246680619992715e+33 erg s^-1

# %%
AllData.clear()
AllModels.clear()
spec = Spectrum("0934201001_M1grpspec.fits")
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.000005 0.01")
Plot("data")
# Out:
# ***Warning: Detected response matrix energy bin value = 0 (or neg).
#      XSPEC will instead use small finite value (response file will not be altered).
#
# 1 spectrum  in use
#
# Spectral Data File: 0934201001_M1grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  3.342e-03 +/- 8.836e-04 (40.8 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-7
#   Telescope: XMM Instrument: EMOS1  Channel Type: PI
#   Exposure Time: 1.32e+04 sec
#  Using fit statistic: chi
#  Using Background File                0934201001_M1spec_bkg.fits
#   Background Exposure Time: 1.32e+04 sec
#  Using Response (RMF) File            0934201001_M1spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0934201001_M1spec.arf

# %%
mo1 = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ...
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.464779e+11     using 7 bins.
#
# Test statistic : Chi-Squared              1.464779e+11     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 4 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 11.0588      0.327861     -1      0.485979       2.76644   5.91453e-06
# 9.32651      125371       -1     0.0167967       2.23815   4.50598e-06
# 8.87208      33133.4      -1      0.175866       1.93507   3.74197e-06
# ...

# %%
mo2 = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ...
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              4.851729e+10     using 7 bins.
#
# Test statistic : Chi-Squared              4.851729e+10     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 4 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 9.07964      0.371803     -3       1.57282       1.05418   2.14055e-05
# 8.97459      3901.42      -2       2.05761       1.23654   2.86767e-05
# ...

# %%
mo3 = Model("tbabs*(bbody+powerlaw)")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ...
# Model TBabs<1>(bbody<2> + powerlaw<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
#    4    3   powerlaw   PhoIndex            1.00000      +/-  0.0
#    5    3   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              3.424810e+11     using 7 bins.
#
# Test statistic : Chi-Squared              3.424810e+11     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 2 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm    4:PhoIndex        5:norm
# ...

# %%
flux = 1.036*10**-13
d_pc = 972
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')

d_pc = 7500
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')
# Out:
# Luminosity is: 1.1744082897856674e+31 erg s^-1
# Luminosity is: 6.992123734149158e+32 erg s^-1
