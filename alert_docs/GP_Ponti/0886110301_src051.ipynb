# %% [markdown]
# Obs 0886110301 source 033. First X-ray detection. (269.5514, -23.7165, 2.76")
#
# No SIMBAD.
#
# Vizier - Gaia 4069293255959020544 2.2"
# + Parallax unknown.
# + Teff unknown
# + Rstar unknown
# + Mstar unknown
#
# Vizier - Gaia 4069293260248516480 5.1"
# + Parallax 2.6453. Distance 378 pc.
# + Teff unknown
# + Rstar unknown
# + Mstar unknown
#
# Vizier - Gaia 4069293255959019904 8.5"
# + Parallax 0.1044. Distance 9579 pc.
# + Teff unknown
# + Rstar unknown
# + Mstar unknown

# %%
# %load_ext wurlitzer
import numpy as np
import os
import stingray as st
import matplotlib.pyplot as plt
from astropy.io import fits
from xspec import *
plt.rcParams['figure.figsize'] = [15, 8]

lc = fits.open('0886110301/0886110301_M2_dt5.lc')
bkg = fits.open('0886110301/0886110301_M2_dt5_bkg.lc')
full_gti = []
for j in lc[2].data:
    full_gti.append([j[0],j[1]])
soft = fits.open('0886110301/0886110301_M2_dt5_0.2-2keV.lc')
sbkg = fits.open('0886110301/0886110301_M2_dt5_0.2-2keV_bkg.lc')
soft_gti = []
for j in soft[2].data:
    soft_gti.append([j[0],j[1]])
hard = fits.open('0886110301/0886110301_M2_dt5_2-12keV.lc')
hbkg = fits.open('0886110301/0886110301_M2_dt5_2-12keV_bkg.lc')
hard_gti = []
for j in hard[2].data:
    hard_gti.append([j[0],j[1]])

# %%
full_lc = st.Lightcurve(lc[1].data.field('TIME'),lc[1].data.field('RATE'),err=lc[1].data.field('ERROR'),gti=full_gti,input_counts=False)
full_bkg = st.Lightcurve(bkg[1].data.field('TIME'),bkg[1].data.field('RATE'),err=bkg[1].data.field('ERROR'),gti=full_gti,input_counts=False)

soft_lc = st.Lightcurve(soft[1].data.field('TIME'),soft[1].data.field('RATE'),err=soft[1].data.field('ERROR'),gti=soft_gti,input_counts=False)
soft_bkg = st.Lightcurve(sbkg[1].data.field('TIME'),sbkg[1].data.field('RATE'),err=sbkg[1].data.field('ERROR'),gti=soft_gti,input_counts=False)

hard_lc = st.Lightcurve(hard[1].data.field('TIME'),hard[1].data.field('RATE'),err=hard[1].data.field('ERROR'),gti=hard_gti,input_counts=False)
hard_bkg = st.Lightcurve(hbkg[1].data.field('TIME'),hbkg[1].data.field('RATE'),err=hbkg[1].data.field('ERROR'),gti=hard_gti,input_counts=False)

full_lc.apply_gtis()
full_bkg.apply_gtis()
soft_lc.apply_gtis()
soft_bkg.apply_gtis()
hard_lc.apply_gtis()
hard_bkg.apply_gtis()
# Out:
# /home/rwebbe/.local/lib/python3.8/site-packages/stingray/lightcurve.py:516: UserWarning: There are non-finite points in the data, but they are outside GTIs.
#   warnings.warn("There are non-finite points in the data, but they are outside GTIs. ")
# /home/rwebbe/.local/lib/python3.8/site-packages/stingray/lightcurve.py:516: UserWarning: There are non-finite points in the data, but they are outside GTIs.
#   warnings.warn("There are non-finite points in the data, but they are outside GTIs. ")

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(soft_lc.time,soft_lc.countrate,color='r')
plt.plot(hard_lc.time,hard_lc.countrate,color='b')

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(full_bkg.time,full_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.time,soft_lc.countrate,color='k')
plt.plot(soft_bkg.time,soft_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.time,hard_lc.countrate,color='k')
plt.plot(hard_bkg.time,hard_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='r')
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='b')

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(full_bkg.rebin(50).time,full_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='k')
plt.plot(soft_bkg.rebin(50).time,soft_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='k')
plt.plot(hard_bkg.rebin(50).time,hard_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='r')
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='b')

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(full_bkg.rebin(250).time,full_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='k')
plt.plot(soft_bkg.rebin(250).time,soft_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='k')
plt.plot(hard_bkg.rebin(250).time,hard_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
os.chdir("0886110301")
spec = Spectrum("0886110301_M2grpspec.fits")
# Out:
# ***Warning: Detected response matrix energy bin value = 0 (or neg).
#      XSPEC will instead use small finite value (response file will not be altered).
#
# 1 spectrum  in use
#
# Spectral Data File: 0886110301_M2grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  1.665e-03 +/- 5.412e-04 (42.0 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-5
#   Telescope: XMM Instrument: EMOS2  Channel Type: PI
#   Exposure Time: 2.144e+04 sec
#  Using fit statistic: chi
#  Using Background File                0886110301_M2spec_bkg.fits
#   Background Exposure Time: 2.144e+04 sec
#  Using Response (RMF) File            0886110301_M2spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0886110301_M2spec.arf

# %%
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot("data")

# %%
spec.ignore("**-0.2 12.0-**")
mo1 = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
#      1 channels (1) ignored in spectrum #     1
#       No channels ignored (no channels in specified range)
#
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              4.552122e+11     using 4 bins.
#
# Test statistic : Chi-Squared              4.552122e+11     using 4 bins.
#  Null hypothesis probability of 0.000000e+00 with 1 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 1.6844       0.0916473    -1      0.292612       3.30508   5.75105e-06
# 1.56219      59969.6      -1      0.143256       3.47298   6.40854e-06
# 1.46888      46834.7      -1     0.0376951       3.61686   7.06362e-06
# 1.42827      33711.2      -1     0.0185417       3.74803   7.69420e-06
# 1.39978      28673.6      -1    0.00906000       3.87371   8.31408e-06
# 1.37763      26201.6      -1    0.00418783       3.99392   8.93327e-06
# 1.3597       24543.2      -1    0.00165041       4.10931   9.55427e-06
# 1.34485      23266.8      -1   0.000323964       4.22042   1.01781e-05
# 1.3326       22207.4      -1   0.000150687       4.32772   1.08052e-05
# 1.3221       21309.3      -1   6.01633e-05       4.43161   1.14361e-05
# Number of trials exceeded: continue fitting? 1.31301      20500.8      -1   1.30476e-05       4.53238   1.20709e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.0326E-11| -0.0000  -0.0000   1.0000
#  2.3150E+00|  0.9839   0.1789   0.0000
#  6.1652E+01| -0.1789   0.9839   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    4.215e+00  -1.045e+01  -5.915e-05
#   -1.045e+01   5.975e+01   3.584e-04
#   -5.915e-05   3.584e-04   2.165e-09
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.30476E-05  +/-  2.05296
#    2    2   bbody      kT         keV      4.53238      +/-  7.72993
#    3    2   bbody      norm                1.20709E-05  +/-  4.65324E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    1.31     using 4 bins.
#
# Test statistic : Chi-Squared                    1.31     using 4 bins.
#  Null hypothesis probability of 2.52e-01 with 1 degrees of freedom

# %%
mo2 = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.372105e+11     using 4 bins.
#
# Test statistic : Chi-Squared              1.372105e+11     using 4 bins.
#  Null hypothesis probability of 0.000000e+00 with 1 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 2.35923      0.439837     -1       1.28473      0.778433   8.08169e-06
# 2.1319       759.017      -1       1.30952      0.625962   6.77201e-06
# 1.95886      2395.74      -1       1.19494      0.494081   5.67156e-06
# 1.80462      3214.42      -1       1.03739      0.373807   4.78040e-06
# 1.66668      3004.27      -1      0.878391      0.262578   4.06875e-06
# 1.54513      2180.16      -1      0.730896      0.159774   3.50121e-06
# 1.43954      940.141      -1      0.597478     0.0651941   3.04680e-06
# 1.34889      585.117      -1      0.477710    -0.0213950   2.68075e-06
# 1.27184      2283.71      -1      0.370473     -0.100340   2.38383e-06
# 1.2069       4049.91      -1      0.274556     -0.172079   2.14125e-06
# Number of trials exceeded: continue fitting? 1.15251      5786.81      -1      0.188800     -0.237110   1.94162e-06
# 1.1072       7412.75      -1      0.112127     -0.295952   1.77614e-06
# 1.06962      8865.68      -1     0.0435595     -0.349124   1.63803e-06
# 1.04009      10104.4      -1     0.0128863     -0.397129   1.52200e-06
# 1.0201       3536.89      -1    0.00208754     -0.440670   1.42326e-06
# 1.00951      25408.3      -1   7.44093e-05     -0.480300   1.33820e-06
# 1.00615      51091.8      -1   3.06285e-05     -0.516525   1.26415e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.2815E-13| -0.0000  -0.0000   1.0000
#  3.9260E-01|  0.4371  -0.8994  -0.0000
#  5.9647E+00|  0.8994   0.4371   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    4.900e+00   2.191e+00   4.997e-06
#    2.191e+00   1.457e+00   3.123e-06
#    4.997e-06   3.123e-06   6.877e-12
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    3.06285E-05  +/-  2.21360
#    2    2   powerlaw   PhoIndex            -0.516525    +/-  1.20718
#    3    2   powerlaw   norm                1.26415E-06  +/-  2.62250E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    1.01     using 4 bins.
#
# Test statistic : Chi-Squared                    1.01     using 4 bins.
#  Null hypothesis probability of 3.16e-01 with 1 degrees of freedom

# %%
AllModels.calcFlux("0.2 12.0")
# Out:
#  Model Flux 3.6031e-05 photons (4.183e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
flux = 4.183*10**-13
d_pc = 378
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')

d_pc = 9579
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')
# Out:
# Luminosity is: 7.171306542628904e+30 erg s^-1
# Luminosity is: 4.605269328384403e+33 erg s^-1
