# %% [markdown]
# Obs 0886090801 source 001. Not first X-ray detection. (268.3681, -24.7743 0.05")
#
# SIMBAD HD 162718
# + Be Star.
# + Parallax 0.5548 mas. Distance 1800 pc.
#
# Vizier - Gaia 4067633238255477248
# + Parallax 0.5548. Distance 1800 pc.
# + Teff unknown
# + Rstar unknown
# + Mstar unknown

# %%
# %load_ext wurlitzer
import numpy as np
import os
import stingray as st
import matplotlib.pyplot as plt
from astropy.io import fits
from xspec import *
plt.rcParams['figure.figsize'] = [15, 8]

lc = fits.open('0886090801_001/0886090801_PN1_dt1.lc')
bkg = fits.open('0886090801_001/0886090801_PN1_dt1_bkg.lc')
full_gti = []
for j in lc[2].data:
    full_gti.append([j[0],j[1]])
soft = fits.open('0886090801_001/0886090801_PN1_dt1_0.2-2keV.lc')
sbkg = fits.open('0886090801_001/0886090801_PN1_dt1_0.2-2keV_bkg.lc')
soft_gti = []
for j in soft[2].data:
    soft_gti.append([j[0],j[1]])
hard = fits.open('0886090801_001/0886090801_PN1_dt1_2-12keV.lc')
hbkg = fits.open('0886090801_001/0886090801_PN1_dt1_2-12keV_bkg.lc')
hard_gti = []
for j in hard[2].data:
    hard_gti.append([j[0],j[1]])

# %%
full_lc = st.Lightcurve(lc[1].data.field('TIME'),lc[1].data.field('RATE'),err=lc[1].data.field('ERROR'),gti=full_gti,input_counts=False)
full_bkg = st.Lightcurve(bkg[1].data.field('TIME'),bkg[1].data.field('RATE'),err=bkg[1].data.field('ERROR'),gti=full_gti,input_counts=False)

soft_lc = st.Lightcurve(soft[1].data.field('TIME'),soft[1].data.field('RATE'),err=soft[1].data.field('ERROR'),gti=soft_gti,input_counts=False)
soft_bkg = st.Lightcurve(sbkg[1].data.field('TIME'),sbkg[1].data.field('RATE'),err=sbkg[1].data.field('ERROR'),gti=soft_gti,input_counts=False)

hard_lc = st.Lightcurve(hard[1].data.field('TIME'),hard[1].data.field('RATE'),err=hard[1].data.field('ERROR'),gti=hard_gti,input_counts=False)
hard_bkg = st.Lightcurve(hbkg[1].data.field('TIME'),hbkg[1].data.field('RATE'),err=hbkg[1].data.field('ERROR'),gti=hard_gti,input_counts=False)

full_lc.apply_gtis()
full_bkg.apply_gtis()
soft_lc.apply_gtis()
soft_bkg.apply_gtis()
hard_lc.apply_gtis()
hard_bkg.apply_gtis()
# Out:
# /home/rwebbe/.local/lib/python3.8/site-packages/stingray/lightcurve.py:516: UserWarning: There are non-finite points in the data, but they are outside GTIs.
#   warnings.warn("There are non-finite points in the data, but they are outside GTIs. ")
# /home/rwebbe/.local/lib/python3.8/site-packages/stingray/lightcurve.py:516: UserWarning: There are non-finite points in the data, but they are outside GTIs.
#   warnings.warn("There are non-finite points in the data, but they are outside GTIs. ")

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(soft_lc.time,soft_lc.countrate,color='r')
plt.plot(hard_lc.time,hard_lc.countrate,color='b')

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(full_bkg.time,full_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.time,soft_lc.countrate,color='k')
plt.plot(soft_bkg.time,soft_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.time,hard_lc.countrate,color='k')
plt.plot(hard_bkg.time,hard_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='r')
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='b')

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(full_bkg.rebin(50).time,full_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='k')
plt.plot(soft_bkg.rebin(50).time,soft_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='k')
plt.plot(hard_bkg.rebin(50).time,hard_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='r')
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='b')

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(full_bkg.rebin(250).time,full_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='k')
plt.plot(soft_bkg.rebin(250).time,soft_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='k')
plt.plot(hard_bkg.rebin(250).time,hard_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
os.chdir("0886090801_001")
spec = Spectrum("0886090801_PN1grpspec.fits")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0886090801_PN1grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  1.020e+00 +/- 9.487e-03 (93.2 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-157
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 1.768e+04 sec
#  Using fit statistic: chi
#  Using Background File                0886090801_PN1spec_bkg.fits
#   Background Exposure Time: 1.768e+04 sec
#  Using Response (RMF) File            0886090801_PN1spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0886090801_PN1spec.arf

# %%
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.0005 0.5")
Plot("data")

# %%
spec.ignore("**-0.2 12.0-**")
mo1 = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
#      2 channels (1-2) ignored in spectrum #     1
#      2 channels (156-157) ignored in spectrum #     1
#
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              1.398740e+11     using 153 bins.
#
# Test statistic : Chi-Squared              1.398740e+11     using 153 bins.
#  Null hypothesis probability of 0.000000e+00 with 150 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 7000.56      245.053       0      0.387512       3.04491   0.000195997
# 6461.83      1.62711e+06   0      0.157171       2.95799   0.000186109
# 5760.36      2.0537e+06   -1     0.0437804       2.43773   0.000122029
# 3664.56      5.38431e+06  -2    0.00195839      0.895826   3.37240e-05
# 1410.68      2.94323e+07  -3     0.0322551       1.11129   6.61663e-05
# 1233.89      6.52559e+06  -4    0.00895783       1.12745   7.35489e-05
# 1229.09      801001       -5    0.00251422       1.12830   7.39650e-05
# 1228.6       263110       -6    0.00115288       1.12814   7.39910e-05
# 1228.37      175215       -7   0.000168348       1.12803   7.39889e-05
# 1228.34      128011       -8   7.84401e-05       1.12797   7.39875e-05
# Number of trials exceeded: continue fitting? 1228.33      121435       -9   3.51085e-05       1.12795   7.39862e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  4.1813E-13| -0.0001  -0.0001   1.0000
#  3.2579E-05| -0.8949  -0.4462  -0.0001
#  1.3865E-04|  0.4462  -0.8949  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    5.370e-05  -4.236e-05  -3.845e-10
#   -4.236e-05   1.175e-04   6.899e-09
#   -3.845e-10   6.899e-09   9.380e-13
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    3.51085E-05  +/-  7.32790E-03
#    2    2   bbody      kT         keV      1.12795      +/-  1.08411E-02
#    3    2   bbody      norm                7.39862E-05  +/-  9.68509E-07
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 1228.33     using 153 bins.
#
# Test statistic : Chi-Squared                 1228.33     using 153 bins.
#  Null hypothesis probability of 1.38e-168 with 150 degrees of freedom
#  Model Flux 0.0012602 photons (6.1601e-12 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
mo2 = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              2.223301e+10     using 153 bins.
#
# Test statistic : Chi-Squared              2.223301e+10     using 153 bins.
#  Null hypothesis probability of 0.000000e+00 with 150 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 1308.22      837.533      -3      0.150095      0.953269   0.000449270
# 600.292      1.19887e+06  -4      0.371963       1.30592   0.000776861
# 329.148      697351       -5      0.430062       1.34777   0.000960409
# 326.913      57405.6      -6      0.423654       1.34281   0.000963461
# 326.911      381.495      -7      0.424093       1.34320   0.000964014
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  6.6070E-11| -0.0007  -0.0009   1.0000
#  5.8349E-05|  0.8775  -0.4796   0.0002
#  6.2878E-04|  0.4796   0.8775   0.0011
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.896e-04   2.401e-04   3.336e-07
#    2.401e-04   4.976e-04   5.871e-07
#    3.336e-07   5.871e-07   7.932e-10
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.424093     +/-  1.37681E-02
#    2    2   powerlaw   PhoIndex            1.34320      +/-  2.23063E-02
#    3    2   powerlaw   norm                9.64014E-04  +/-  2.81641E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  326.91     using 153 bins.
#
# Test statistic : Chi-Squared                  326.91     using 153 bins.
#  Null hypothesis probability of 3.48e-15 with 150 degrees of freedom
#  Model Flux 0.0014389 photons (9.0962e-12 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
mo3 = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              7.211443e+08     using 153 bins.
#
# Test statistic : Chi-Squared              7.211443e+08     using 153 bins.
#  Null hypothesis probability of 0.000000e+00 with 150 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 6170.44      1145.85      -3       1.65726      0.881821    0.00682834
# 4947.06      84601.2      -4       1.63524       1.30671    0.00621545
# 3080.52      102466       -5      0.991740       2.10693    0.00537842
# 2349.08      39242.5      -2      0.389432       4.00317    0.00371902
# 856.13       77470.1      -3      0.422019       6.86745    0.00387744
# 438.378      14468.4      -4      0.416082       11.5691    0.00401682
# 341.047      23364.4      -5      0.422737       17.4052    0.00430162
# 319.029      17248.3      -6      0.420674       22.4391    0.00451141
# 312.838      1444.21      -7      0.411588       27.2323    0.00462918
# 310.245      393.158      -8      0.404235       32.3142    0.00474672
# Number of trials exceeded: continue fitting? 310.033      639.147      -9      0.402913       34.2330    0.00479127
# 310.032      137.822     -10      0.403035       34.2741    0.00479210
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  1.6318E-09| -0.0034  -0.0000   1.0000
#  7.3132E-05|  1.0000   0.0013   0.0034
#  2.4893E+01| -0.0013   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.158e-04  -3.259e-02  -4.742e-07
#   -3.259e-02   2.489e+01   5.517e-04
#   -4.742e-07   5.517e-04   1.470e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.403035     +/-  1.07612E-02
#    2    2   apec       kT         keV      34.2741      +/-  4.98926
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                4.79210E-03  +/-  1.21242E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  310.03     using 153 bins.
#
# Test statistic : Chi-Squared                  310.03     using 153 bins.
#  Null hypothesis probability of 3.33e-13 with 150 degrees of freedom
#  Model Flux 0.0014251 photons (8.8323e-12 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
flux = 9.0962*10**-12
d_pc = 1800
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')
# Out:
# Luminosity is: 3.5361594019775016e+33 erg s^-1

# %%
g_mag = 8.396587
opt_flux = (10**(0.4*(-26.7 - g_mag))) * (3.828 * 10 ** 33) / (4*np.pi*(1.496*10**13)**2)
print('Optical flux: '+str(opt_flux))
opt_x_ratio = flux / opt_flux
print('The x-ray/optical flux ratio is: '+str(opt_x_ratio))
# Out:
# Optical flux: 1.2452715840913964e-08
# The x-ray/optical flux ratio is: 0.0007304591316629921
