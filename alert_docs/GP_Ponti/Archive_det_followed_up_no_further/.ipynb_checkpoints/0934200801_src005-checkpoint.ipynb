# %% [markdown]
# Obs 0934200801 source 005. First X-ray detection. (264.9209, -29.4936, 0.56")
#
# No SIMBAD
#
# ALSO XMM
# + 0886010101 src 41
#
# Vizier - Gaia 4057036553166169600 0.85"
# + Parallax -0.1737. Distance 5760 pc.
# + Teff unknown
# + Rstar unknown
# + Mstar unknown

# %%
# %load_ext wurlitzer
import numpy as np
import os
import stingray as st
import matplotlib.pyplot as plt
from astropy.io import fits
from xspec import *
plt.rcParams['figure.figsize'] = [15, 8]

lc = fits.open('0934200801_005/0934200801_PN5_dt1.lc')
bkg = fits.open('0934200801_005/0934200801_PN5_dt1_bkg.lc')
full_gti = []
for j in lc[2].data:
    full_gti.append([j[0],j[1]])
soft = fits.open('0934200801_005/0934200801_PN5_dt1_0.2-2keV.lc')
sbkg = fits.open('0934200801_005/0934200801_PN5_dt1_0.2-2keV_bkg.lc')
soft_gti = []
for j in soft[2].data:
    soft_gti.append([j[0],j[1]])
hard = fits.open('0934200801_005/0934200801_PN5_dt1_2-12keV.lc')
hbkg = fits.open('0934200801_005/0934200801_PN5_dt1_2-12keV_bkg.lc')
hard_gti = []
for j in hard[2].data:
    hard_gti.append([j[0],j[1]])

# %%
full_lc = st.Lightcurve(lc[1].data.field('TIME'),lc[1].data.field('RATE'),err=lc[1].data.field('ERROR'),gti=full_gti,input_counts=False)
full_bkg = st.Lightcurve(bkg[1].data.field('TIME'),bkg[1].data.field('RATE'),err=bkg[1].data.field('ERROR'),gti=full_gti,input_counts=False)

soft_lc = st.Lightcurve(soft[1].data.field('TIME'),soft[1].data.field('RATE'),err=soft[1].data.field('ERROR'),gti=soft_gti,input_counts=False)
soft_bkg = st.Lightcurve(sbkg[1].data.field('TIME'),sbkg[1].data.field('RATE'),err=sbkg[1].data.field('ERROR'),gti=soft_gti,input_counts=False)

hard_lc = st.Lightcurve(hard[1].data.field('TIME'),hard[1].data.field('RATE'),err=hard[1].data.field('ERROR'),gti=hard_gti,input_counts=False)
hard_bkg = st.Lightcurve(hbkg[1].data.field('TIME'),hbkg[1].data.field('RATE'),err=hbkg[1].data.field('ERROR'),gti=hard_gti,input_counts=False)

full_lc.apply_gtis()
full_bkg.apply_gtis()
soft_lc.apply_gtis()
soft_bkg.apply_gtis()
hard_lc.apply_gtis()
hard_bkg.apply_gtis()

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(soft_lc.time,soft_lc.countrate,color='r')
plt.plot(hard_lc.time,hard_lc.countrate,color='b')

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(full_bkg.time,full_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.time,soft_lc.countrate,color='k')
plt.plot(soft_bkg.time,soft_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.time,hard_lc.countrate,color='k')
plt.plot(hard_bkg.time,hard_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='r')
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='b')

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(full_bkg.rebin(50).time,full_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='k')
plt.plot(soft_bkg.rebin(50).time,soft_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='k')
plt.plot(hard_bkg.rebin(50).time,hard_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='r')
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='b')

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(full_bkg.rebin(250).time,full_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='k')
plt.plot(soft_bkg.rebin(250).time,soft_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='k')
plt.plot(hard_bkg.rebin(250).time,hard_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
os.chdir("0934200801_005")
spec = Spectrum("0934200801_PN5grpspec.fits")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0934200801_PN5grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  1.803e-02 +/- 1.904e-03 (60.9 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-11
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 1.136e+04 sec
#  Using fit statistic: chi
#  Using Background File                0934200801_PN5spec_bkg.fits
#   Background Exposure Time: 1.136e+04 sec
#  Using Response (RMF) File            0934200801_PN5spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0934200801_PN5spec.arf

# %%
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.0005 0.1")
Plot("data")

# %%
spec.ignore("**-0.2 12.0-**")
mo1 = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
#      2 channels (1-2) ignored in spectrum #     1
#      1 channels (11) ignored in spectrum #     1
#
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              7.827124e+11     using 8 bins.
#
# Test statistic : Chi-Squared              7.827124e+11     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 5 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 27.2979      2.07088      -1     0.0540965       3.15394   7.19605e-06
# 16.4176      857511       -1    0.00678653       2.61847   7.14401e-06
# 15.073       217608       -1     0.0226400       2.42956   5.85480e-06
# 13.481       10649        -1     0.0511233       2.19881   4.84965e-06
# 11.5717      16537.6      -1     0.0915510       1.96362   3.97125e-06
# 9.33851      38258.9      -1      0.146700       1.72762   3.23364e-06
# 6.9512       70001.6      -1      0.222945       1.50152   2.65829e-06
# 4.88358      98855.7      -1      0.322889       1.30592   2.26622e-06
# 3.4934       89993.3      -2      0.568651      0.986470   1.71461e-06
# 2.97938      944629       -3      0.662236       1.00475   1.89627e-06
# Number of trials exceeded: continue fitting? 2.97821      49359        -4      0.669769       1.00137   1.90024e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  3.4744E-14| -0.0000  -0.0000   1.0000
#  1.2126E-02| -0.3384  -0.9410  -0.0000
#  1.8583E-01|  0.9410  -0.3384   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.659e-01  -5.532e-02   8.102e-09
#   -5.532e-02   3.202e-02   2.168e-08
#    8.102e-09   2.168e-08   7.891e-14
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.669769     +/-  0.407356
#    2    2   bbody      kT         keV      1.00137      +/-  0.178948
#    3    2   bbody      norm                1.90024E-06  +/-  2.80904E-07
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    2.98     using 8 bins.
#
# Test statistic : Chi-Squared                    2.98     using 8 bins.
#  Null hypothesis probability of 7.03e-01 with 5 degrees of freedom
#  Model Flux 2.4971e-05 photons (1.3424e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
mo2 = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              2.532623e+11     using 8 bins.
#
# Test statistic : Chi-Squared              2.532623e+11     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 5 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 3.91309      1.11158      -2       1.19676       1.31163   2.77975e-05
# 3.76966      70511.5      -3       1.49762       1.60239   4.04533e-05
# 3.1888       58775.9      -4       1.60665       1.68020   4.82569e-05
# 3.16969      9361.82      -5       1.62721       1.69440   4.99019e-05
# 3.16963      328.064      -6       1.63143       1.69732   5.01377e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  2.3998E-11| -0.0000  -0.0000   1.0000
#  4.3955E-02|  0.6419  -0.7668  -0.0000
#  9.2471E-01|  0.7668   0.6419   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    5.618e-01   4.335e-01   3.042e-05
#    4.335e-01   4.068e-01   2.701e-05
#    3.042e-05   2.701e-05   1.844e-09
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.63143      +/-  0.749553
#    2    2   powerlaw   PhoIndex            1.69732      +/-  0.637836
#    3    2   powerlaw   norm                5.01377E-05  +/-  4.29389E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    3.17     using 8 bins.
#
# Test statistic : Chi-Squared                    3.17     using 8 bins.
#  Null hypothesis probability of 6.74e-01 with 5 degrees of freedom
#  Model Flux 3.1271e-05 photons (2.2267e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
flux = 2.2267*10**-13
d_pc = 5760
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')
# Out:
# Luminosity is: 8.864076567965195e+32 erg s^-1
