# %%
# %load_ext wurlitzer
import numpy as np
import matplotlib.pyplot as plt
import stingray as st
from astropy.io import fits
from xspec import *
plt.rcParams['figure.figsize'] = [15, 8]

lc = fits.open('0886110501_PN19_dt1.lc')
bkg = fits.open('0886110501_PN19_dt1_bkg.lc')
full_gti = []
for j in lc[2].data:
    full_gti.append([j[0],j[1]])
soft = fits.open('0886110501_PN19_dt1_0.2-2keV.lc')
sbkg = fits.open('0886110501_PN19_dt1_0.2-2keV_bkg.lc')
soft_gti = []
for j in soft[2].data:
    soft_gti.append([j[0],j[1]])
hard = fits.open('0886110501_PN19_dt1_2-12keV.lc')
hbkg = fits.open('0886110501_PN19_dt1_2-12keV_bkg.lc')
hard_gti = []
for j in hard[2].data:
    hard_gti.append([j[0],j[1]])
    
lc2 = fits.open('0886090501_PN143_dt1.lc')
bkg2 = fits.open('0886090501_PN143_dt1_bkg.lc')
full_gti2 = []
for j in lc2[2].data:
    full_gti2.append([j[0],j[1]])
soft2 = fits.open('0886090501_PN143_dt1_0.2-2keV.lc')
sbkg2 = fits.open('0886090501_PN143_dt1_0.2-2keV_bkg.lc')
soft_gti2 = []
for j in soft2[2].data:
    soft_gti2.append([j[0],j[1]])
hard2 = fits.open('0886090501_PN143_dt1_2-12keV.lc')
hbkg2 = fits.open('0886090501_PN143_dt1_2-12keV_bkg.lc')
hard_gti2 = []
for j in hard2[2].data:
    hard_gti2.append([j[0],j[1]])

# %%
full_lc = st.Lightcurve(lc[1].data.field('TIME'),lc[1].data.field('RATE'),err=lc[1].data.field('ERROR'),gti=full_gti,input_counts=False)
full_bkg = st.Lightcurve(bkg[1].data.field('TIME'),bkg[1].data.field('RATE'),err=bkg[1].data.field('ERROR'),gti=full_gti,input_counts=False)

soft_lc = st.Lightcurve(soft[1].data.field('TIME'),soft[1].data.field('RATE'),err=soft[1].data.field('ERROR'),gti=soft_gti,input_counts=False)
soft_bkg = st.Lightcurve(sbkg[1].data.field('TIME'),sbkg[1].data.field('RATE'),err=sbkg[1].data.field('ERROR'),gti=soft_gti,input_counts=False)

hard_lc = st.Lightcurve(hard[1].data.field('TIME'),hard[1].data.field('RATE'),err=hard[1].data.field('ERROR'),gti=hard_gti,input_counts=False)
hard_bkg = st.Lightcurve(hbkg[1].data.field('TIME'),hbkg[1].data.field('RATE'),err=hbkg[1].data.field('ERROR'),gti=hard_gti,input_counts=False)

full_lc.apply_gtis()
full_bkg.apply_gtis()
soft_lc.apply_gtis()
soft_bkg.apply_gtis()
hard_lc.apply_gtis()
hard_bkg.apply_gtis()

full_lc2 = st.Lightcurve(lc2[1].data.field('TIME'),lc2[1].data.field('RATE'),err=lc2[1].data.field('ERROR'),gti=full_gti2,input_counts=False)
full_bkg2 = st.Lightcurve(bkg2[1].data.field('TIME'),bkg2[1].data.field('RATE'),err=bkg2[1].data.field('ERROR'),gti=full_gti2,input_counts=False)

soft_lc2 = st.Lightcurve(soft2[1].data.field('TIME'),soft2[1].data.field('RATE'),err=soft2[1].data.field('ERROR'),gti=soft_gti2,input_counts=False)
soft_bkg2 = st.Lightcurve(sbkg2[1].data.field('TIME'),sbkg2[1].data.field('RATE'),err=sbkg2[1].data.field('ERROR'),gti=soft_gti2,input_counts=False)

hard_lc2 = st.Lightcurve(hard2[1].data.field('TIME'),hard2[1].data.field('RATE'),err=hard2[1].data.field('ERROR'),gti=hard_gti2,input_counts=False)
hard_bkg2 = st.Lightcurve(hbkg2[1].data.field('TIME'),hbkg2[1].data.field('RATE'),err=hbkg2[1].data.field('ERROR'),gti=hard_gti2,input_counts=False)

full_lc2.apply_gtis()
full_bkg2.apply_gtis()
soft_lc2.apply_gtis()
soft_bkg2.apply_gtis()
hard_lc2.apply_gtis()
hard_bkg2.apply_gtis()
# Out:
# /home/rwebbe/.local/lib/python3.8/site-packages/stingray/lightcurve.py:516: UserWarning: There are non-finite points in the data, but they are outside GTIs.
#   warnings.warn("There are non-finite points in the data, but they are outside GTIs. ")
# /home/rwebbe/.local/lib/python3.8/site-packages/stingray/lightcurve.py:516: UserWarning: There are non-finite points in the data, but they are outside GTIs.
#   warnings.warn("There are non-finite points in the data, but they are outside GTIs. ")

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(soft_lc.time,soft_lc.countrate,color='r')
plt.plot(hard_lc.time,hard_lc.countrate,color='b')

# %%
plt.plot(full_lc2.time,full_lc2.countrate,color='k')
plt.plot(soft_lc2.time,soft_lc2.countrate,color='r')
plt.plot(hard_lc2.time,hard_lc2.countrate,color='b')

# %%
plt.plot(full_lc2.rebin(50).time,full_lc2.rebin(50).countrate,color='k')
plt.plot(soft_lc2.rebin(50).time,soft_lc2.rebin(50).countrate,color='r')
plt.plot(hard_lc2.rebin(50).time,hard_lc2.rebin(50).countrate,color='b')

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='r')
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='b')

# %%
spec = Spectrum("0886090501_PN143grpspec.fits")
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.00005 0.01")
Plot("data")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0886090501_PN143grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  4.658e-03 +/- 1.386e-03 (38.8 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-8
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 1.008e+04 sec
#  Using fit statistic: chi
#  Using Background File                0886090501_PN143spec_bkg.fits
#   Background Exposure Time: 1.008e+04 sec
#  Using Response (RMF) File            0886090501_PN143spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0886090501_PN143spec.arf

# %%
spec.ignore("**-0.2 12.0-**")
mo1 = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
#      1 channels (1) ignored in spectrum #     1
#      1 channels (8) ignored in spectrum #     1
#
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              1.357623e+11     using 6 bins.
#
# Test statistic : Chi-Squared              1.357623e+11     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 14.9685      0.0472878     0      0.111151       3.06649   3.36763e-06
# 14.9586      27547.1       0     0.0331347       3.17046   3.04806e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  6.4249E-12| -0.0000  -0.0000   1.0000
#  6.5001E+00|  0.9894   0.1454   0.0000
#  4.1517E+02| -0.1454   0.9894   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.514e+01  -5.880e+01  -1.380e-04
#   -5.880e+01   4.065e+02   9.800e-04
#   -1.380e-04   9.800e-04   2.371e-09
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    3.31347E-02  +/-  3.89153
#    2    2   bbody      kT         keV      3.17046      +/-  20.1625
#    3    2   bbody      norm                3.04806E-06  +/-  4.86948E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   14.96     using 6 bins.
#
# Test statistic : Chi-Squared                   14.96     using 6 bins.
#  Null hypothesis probability of 1.85e-03 with 3 degrees of freedom
#  Model Flux 1.4233e-05 photons (1.418e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
mo2 = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              4.316342e+10     using 6 bins.
#
# Test statistic : Chi-Squared              4.316342e+10     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 11.6488      0.101419     -1      0.151694       1.04389   6.27444e-06
# 9.2097       54306.6       0     0.0662256       1.21424   6.29762e-06
# 6.24861      108271        0     0.0227617       1.46436   6.99125e-06
# 3.86473      126717        0    0.00523947       1.74475   7.73434e-06
# 2.82425      104662        0    0.00172041       1.95155   8.11353e-06
# 2.38851      73599.6       0   0.000780934       2.08614   8.25355e-06
# 2.18983      49104.1       0   0.000181546       2.17582   8.27087e-06
# 2.10027      32004.3       0   7.50840e-05       2.23797   8.22611e-06
# 2.05103      22449.3       0   3.29234e-05       2.28433   8.15828e-06
# 2.02105      16803         0   1.51499e-05       2.32047   8.08332e-06
# Number of trials exceeded: continue fitting? 2.00128      13545.2       0   7.31769e-06       2.34962   8.00910e-06
# 1.98742      11704.9       0   1.98658e-07       2.37377   7.93924e-06
# 1.97738      10676         0   9.54095e-08       2.39417   7.87512e-06
# 1.96982      10150.3       0   4.67480e-08       2.41167   7.81716e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  4.1810E-12| -0.0001   0.0000   1.0000
#  7.9098E-03|  0.9933  -0.1156   0.0001
#  7.9663E+00|  0.1156   0.9933   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.143e-01   9.140e-01   3.075e-06
#    9.140e-01   7.860e+00   2.257e-05
#    3.075e-06   2.257e-05   9.431e-11
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    4.67480E-08  +/-  0.338086
#    2    2   powerlaw   PhoIndex            2.41167      +/-  2.80356
#    3    2   powerlaw   norm                7.81716E-06  +/-  9.71146E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    1.97     using 6 bins.
#
# Test statistic : Chi-Squared                    1.97     using 6 bins.
#  Null hypothesis probability of 5.79e-01 with 3 degrees of freedom
#  Model Flux 5.3541e-05 photons (4.8077e-14 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
flux = 4.8077*10**-14
d_pc = 107
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')
# Out:
# Luminosity is: 6.604375203510637e+28 erg s^-1
