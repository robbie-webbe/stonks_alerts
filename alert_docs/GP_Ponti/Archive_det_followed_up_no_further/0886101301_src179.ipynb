# %% [markdown]
# Obs 0886101301 source 179. Not first X-ray detection. (270.1806, -24.0309, 0.84")
#
# SEE ALSO
# + 0886090501 src 097
# + 0932201101 src 336
#
# No SIMBAD
#
# Vizier - Gaia 4069056723517706368 1.8"
# + Parallax 0.653. Distance 1530 pc. (929 pc spec)
# + Teff 5640K.
# + Rstar 2.45. (1.90 spec)
# + Mstar 1.77
#
# Vizier - Gaia 4069056727811793280 2.0"
# + Parallax unknown.
# + Teff unknown
# + Rstar unknown
# + Mstar unknown

# %%
# %load_ext wurlitzer
import numpy as np
import os
import stingray as st
import matplotlib.pyplot as plt
from astropy.io import fits
from xspec import *
plt.rcParams['figure.figsize'] = [15, 8]

lc = fits.open('0886101301_179/0886101301_PN179_dt1.lc')
bkg = fits.open('0886101301_179/0886101301_PN179_dt1_bkg.lc')
full_gti = []
for j in lc[2].data:
    full_gti.append([j[0],j[1]])
soft = fits.open('0886101301_179/0886101301_PN179_dt1_0.2-2keV.lc')
sbkg = fits.open('0886101301_179/0886101301_PN179_dt1_0.2-2keV_bkg.lc')
soft_gti = []
for j in soft[2].data:
    soft_gti.append([j[0],j[1]])
hard = fits.open('0886101301_179/0886101301_PN179_dt1_2-12keV.lc')
hbkg = fits.open('0886101301_179/0886101301_PN179_dt1_2-12keV_bkg.lc')
hard_gti = []
for j in hard[2].data:
    hard_gti.append([j[0],j[1]])

# %%
full_lc = st.Lightcurve(lc[1].data.field('TIME'),lc[1].data.field('RATE'),err=lc[1].data.field('ERROR'),gti=full_gti,input_counts=False)
full_bkg = st.Lightcurve(bkg[1].data.field('TIME'),bkg[1].data.field('RATE'),err=bkg[1].data.field('ERROR'),gti=full_gti,input_counts=False)

soft_lc = st.Lightcurve(soft[1].data.field('TIME'),soft[1].data.field('RATE'),err=soft[1].data.field('ERROR'),gti=soft_gti,input_counts=False)
soft_bkg = st.Lightcurve(sbkg[1].data.field('TIME'),sbkg[1].data.field('RATE'),err=sbkg[1].data.field('ERROR'),gti=soft_gti,input_counts=False)

hard_lc = st.Lightcurve(hard[1].data.field('TIME'),hard[1].data.field('RATE'),err=hard[1].data.field('ERROR'),gti=hard_gti,input_counts=False)
hard_bkg = st.Lightcurve(hbkg[1].data.field('TIME'),hbkg[1].data.field('RATE'),err=hbkg[1].data.field('ERROR'),gti=hard_gti,input_counts=False)

full_lc.apply_gtis()
full_bkg.apply_gtis()
soft_lc.apply_gtis()
soft_bkg.apply_gtis()
hard_lc.apply_gtis()
hard_bkg.apply_gtis()
# Out:
# /home/rwebbe/.local/lib/python3.8/site-packages/stingray/lightcurve.py:516: UserWarning: There are non-finite points in the data, but they are outside GTIs.
#   warnings.warn("There are non-finite points in the data, but they are outside GTIs. ")
# /home/rwebbe/.local/lib/python3.8/site-packages/stingray/lightcurve.py:516: UserWarning: There are non-finite points in the data, but they are outside GTIs.
#   warnings.warn("There are non-finite points in the data, but they are outside GTIs. ")

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(soft_lc.time,soft_lc.countrate,color='r')
plt.plot(hard_lc.time,hard_lc.countrate,color='b')

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(full_bkg.time,full_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.time,soft_lc.countrate,color='k')
plt.plot(soft_bkg.time,soft_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.time,hard_lc.countrate,color='k')
plt.plot(hard_bkg.time,hard_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='r')
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='b')

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(full_bkg.rebin(50).time,full_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='k')
plt.plot(soft_bkg.rebin(50).time,soft_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='k')
plt.plot(hard_bkg.rebin(50).time,hard_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='r')
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='b')

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(full_bkg.rebin(250).time,full_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='k')
plt.plot(soft_bkg.rebin(250).time,soft_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='k')
plt.plot(hard_bkg.rebin(250).time,hard_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
os.chdir("0886101301_179")
spec = Spectrum("0886101301_PN179grpspec.fits")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0886101301_PN179grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  2.033e-02 +/- 2.037e-03 (81.5 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-8
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 7131 sec
#  Using fit statistic: chi
#  Using Background File                0886101301_PN179spec_bkg.fits
#   Background Exposure Time: 7131 sec
#  Using Response (RMF) File            0886101301_PN179spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0886101301_PN179spec.arf

# %%
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot("data")

# %%
spec.ignore("**-0.2 12.0-**")
mo1 = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
#      1 channels (1) ignored in spectrum #     1
#      1 channels (8) ignored in spectrum #     1
#
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              2.402043e+10     using 6 bins.
#
# Test statistic : Chi-Squared              2.402043e+10     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 51.562       1.64082       0      0.172468       3.13129   3.07258e-05
# 47.5784      78274.2       0    0.00794537       3.16194   2.90298e-05
# 46.2664      114194        0   0.000955881       3.10982   2.92208e-05
# 45.7558      104876        0   0.000158105       3.07495   2.90385e-05
# 45.5187      100842        0   6.17297e-05       3.04802   2.86795e-05
# 45.3777      100042        0   1.42866e-05       3.02419   2.82520e-05
# 45.2731      100684        0   2.53239e-06       3.00151   2.78005e-05
# 45.1817      101932        0   1.07257e-06       2.97923   2.73417e-05
# 45.0943      103452        0   3.46668e-07       2.95706   2.68824e-05
# 45.0075      105108        0   1.66136e-07       2.93487   2.64251e-05
# Number of trials exceeded: continue fitting? 44.9197      106846        0   7.63335e-08       2.91262   2.59708e-05
# 44.8303      108644        0   3.16653e-08       2.89028   2.55200e-05
# 44.739       110495        0   9.44887e-09       2.86786   2.50727e-05
# 44.6458      112396        0   3.92463e-09       2.84533   2.46291e-05
# 44.5504      114349        0   1.17768e-09       2.82271   2.41890e-05
# 44.4528      116353        0   4.94796e-10       2.79998   2.37526e-05
# 44.3529      118412        0   1.55313e-10       2.77715   2.33199e-05
# 44.2507      120525        0   7.09411e-11       2.75421   2.28907e-05
# 44.1459      122697        0   2.90087e-11       2.73115   2.24651e-05
# 44.0385      124929        0   8.17141e-12       2.70798   2.20431e-05
# Number of trials exceeded: continue fitting? 43.9285      127222        0   2.99498e-12       2.68469   2.16247e-05
# 43.8163      129580        0   4.23806e-13       2.66130   2.12095e-05
# 43.7013      132021        0   1.04371e-13       2.63780   2.07978e-05
# 43.5736      134536        0   2.49627e-14       2.61387   2.03949e-05
# 43.49        136886        0   5.40682e-15       2.59110   1.99683e-05
# 43.2133      140513        0   4.71823e-16       2.56238   1.96371e-05
# 42.6673      139446        0   5.41964e-18       2.52465   1.94307e-05
# 39.0978      130613       -1   2.64365e-18       2.17956   1.63502e-05
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 2.64365e-18 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 34.0358      62400.7      -2   2.64365e-18      0.991224   6.38818e-06
# Number of trials exceeded: continue fitting? 31.931       3.9749e+06   -3   2.64365e-18      0.418537   2.60348e-06
# 2.57781      1.27124e+07  -4   2.64365e-18      0.511265   2.22402e-06
# 1.58447      671617       -5   2.64365e-18      0.564893   2.38862e-06
# 1.58251      82633.3      -6   2.64365e-18      0.565937   2.40357e-06
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 2.64365e-18 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 1.58251      205.338      -3   2.64365e-18      0.565865   2.40327e-06
# ==============================
#  Variances and Principal Axes
#                  2        3
#  6.2723E-14| -0.0000   1.0000
#  3.9837E-03|  1.0000   0.0000
# ------------------------------
#
# ========================
#   Covariance Matrix
#         1           2
#    3.984e-03   1.773e-08
#    1.773e-08   1.416e-13
# ------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    2.64365E-18  +/-  -1.00000
#    2    2   bbody      kT         keV      0.565865     +/-  6.31165E-02
#    3    2   bbody      norm                2.40327E-06  +/-  3.76322E-07
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    1.58     using 6 bins.
#
# Test statistic : Chi-Squared                    1.58     using 6 bins.
#  Null hypothesis probability of 6.63e-01 with 3 degrees of freedom
#  Model Flux 8.0324e-05 photons (2.0096e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
mo2 = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.521865e+10     using 6 bins.
#
# Test statistic : Chi-Squared              1.521865e+10     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 9.6061       5.35434      -1     0.0420009       1.49096   4.43967e-05
# 4.08513      9892.84      -2      0.329335       1.97429   7.85484e-05
# 3.16635      52650.9      -3      0.541272       2.62197   0.000137936
# 0.935523     29362.2      -4      0.512374       2.53007   0.000152910
# 0.926067     1983.91      -5      0.518404       2.54909   0.000153834
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  2.4723E-10| -0.0002  -0.0001   1.0000
#  7.5195E-03|  0.9600  -0.2800   0.0002
#  5.6424E-01|  0.2800   0.9600   0.0001
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    5.117e-02   1.497e-01   1.968e-05
#    1.497e-01   5.206e-01   6.213e-05
#    1.968e-05   6.213e-05   8.068e-09
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.518404     +/-  0.226207
#    2    2   powerlaw   PhoIndex            2.54909      +/-  0.721520
#    3    2   powerlaw   norm                1.53834E-04  +/-  8.98242E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    0.93     using 6 bins.
#
# Test statistic : Chi-Squared                    0.93     using 6 bins.
#  Null hypothesis probability of 8.19e-01 with 3 degrees of freedom
#  Model Flux 7.7709e-05 photons (2.7679e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
flux = 2.7679*10**-13
d_pc = 1530
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')
# Out:
# Luminosity is: 7.774278245102322e+31 erg s^-1

# %%
d_pc = 7500
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')
# Out:
# Luminosity is: 1.8680983864624958e+33 erg s^-1
