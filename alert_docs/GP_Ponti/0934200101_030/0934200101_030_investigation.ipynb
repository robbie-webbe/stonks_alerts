# %%
# %load_ext wurlitzer
import numpy as np
import os
import stingray as st
import matplotlib.pyplot as plt
from astropy.io import fits
from xspec import *
plt.rcParams['figure.figsize'] = [15, 8]

lc = fits.open('0934200101_PN30_dt1.lc')
bkg = fits.open('0934200101_PN30_dt1_bkg.lc')
full_gti = []
for j in lc[2].data:
    full_gti.append([j[0],j[1]])
soft = fits.open('0934200101_PN30_dt1_0.2-2keV.lc')
sbkg = fits.open('0934200101_PN30_dt1_0.2-2keV_bkg.lc')
soft_gti = []
for j in soft[2].data:
    soft_gti.append([j[0],j[1]])
hard = fits.open('0934200101_PN30_dt1_2-12keV.lc')
hbkg = fits.open('0934200101_PN30_dt1_2-12keV_bkg.lc')
hard_gti = []
for j in hard[2].data:
    hard_gti.append([j[0],j[1]])
    
lc1 = fits.open('0916800701_PN1_dt1.lc')
bkg1 = fits.open('0916800701_PN1_dt1_bkg.lc')
full_gti1 = []
for j in lc1[2].data:
    full_gti1.append([j[0],j[1]])
soft1 = fits.open('0916800701_PN1_dt1_0.2-2keV.lc')
sbkg1 = fits.open('0916800701_PN1_dt1_0.2-2keV_bkg.lc')
soft_gti1 = []
for j in soft1[2].data:
    soft_gti1.append([j[0],j[1]])
hard1 = fits.open('0916800701_PN1_dt1_2-12keV.lc')
hbkg1 = fits.open('0916800701_PN1_dt1_2-12keV_bkg.lc')
hard_gti1 = []
for j in hard1[2].data:
    hard_gti1.append([j[0],j[1]])
    
lc2 = fits.open('0916800801_PN2_dt1.lc')
bkg2 = fits.open('0916800801_PN2_dt1_bkg.lc')
full_gti2 = []
for j in lc2[2].data:
    full_gti2.append([j[0],j[1]])
soft2 = fits.open('0916800801_PN2_dt1_0.2-2keV.lc')
sbkg2 = fits.open('0916800801_PN2_dt1_0.2-2keV_bkg.lc')
soft_gti2 = []
for j in soft2[2].data:
    soft_gti2.append([j[0],j[1]])
hard2 = fits.open('0916800801_PN2_dt1_2-12keV.lc')
hbkg2 = fits.open('0916800801_PN2_dt1_2-12keV_bkg.lc')
hard_gti2 = []
for j in hard2[2].data:
    hard_gti2.append([j[0],j[1]])
    
lc3 = fits.open('0916800401_PN7_dt1.lc')
bkg3 = fits.open('0916800401_PN7_dt1_bkg.lc')
full_gti3 = []
for j in lc3[2].data:
    full_gti3.append([j[0],j[1]])
soft3 = fits.open('0916800401_PN7_dt1_0.2-2keV.lc')
sbkg3 = fits.open('0916800401_PN7_dt1_0.2-2keV_bkg.lc')
soft_gti3 = []
for j in soft3[2].data:
    soft_gti3.append([j[0],j[1]])
hard3 = fits.open('0916800401_PN7_dt1_2-12keV.lc')
hbkg3 = fits.open('0916800401_PN7_dt1_2-12keV_bkg.lc')
hard_gti3 = []
for j in hard3[2].data:
    hard_gti3.append([j[0],j[1]])

# %%
full_lc = st.Lightcurve(lc[1].data.field('TIME'),lc[1].data.field('RATE'),err=lc[1].data.field('ERROR'),gti=full_gti,input_counts=False)
full_bkg = st.Lightcurve(bkg[1].data.field('TIME'),bkg[1].data.field('RATE'),err=bkg[1].data.field('ERROR'),gti=full_gti,input_counts=False)

soft_lc = st.Lightcurve(soft[1].data.field('TIME'),soft[1].data.field('RATE'),err=soft[1].data.field('ERROR'),gti=soft_gti,input_counts=False)
soft_bkg = st.Lightcurve(sbkg[1].data.field('TIME'),sbkg[1].data.field('RATE'),err=sbkg[1].data.field('ERROR'),gti=soft_gti,input_counts=False)

hard_lc = st.Lightcurve(hard[1].data.field('TIME'),hard[1].data.field('RATE'),err=hard[1].data.field('ERROR'),gti=hard_gti,input_counts=False)
hard_bkg = st.Lightcurve(hbkg[1].data.field('TIME'),hbkg[1].data.field('RATE'),err=hbkg[1].data.field('ERROR'),gti=hard_gti,input_counts=False)

full_lc.apply_gtis()
full_bkg.apply_gtis()
soft_lc.apply_gtis()
soft_bkg.apply_gtis()
hard_lc.apply_gtis()
hard_bkg.apply_gtis()

full_lc1 = st.Lightcurve(lc1[1].data.field('TIME'),lc1[1].data.field('RATE'),err=lc1[1].data.field('ERROR'),gti=full_gti1,input_counts=False)
full_bkg1 = st.Lightcurve(bkg1[1].data.field('TIME'),bkg1[1].data.field('RATE'),err=bkg1[1].data.field('ERROR'),gti=full_gti1,input_counts=False)

soft_lc1 = st.Lightcurve(soft1[1].data.field('TIME'),soft1[1].data.field('RATE'),err=soft1[1].data.field('ERROR'),gti=soft_gti1,input_counts=False)
soft_bkg1 = st.Lightcurve(sbkg1[1].data.field('TIME'),sbkg1[1].data.field('RATE'),err=sbkg1[1].data.field('ERROR'),gti=soft_gti1,input_counts=False)

hard_lc1 = st.Lightcurve(hard1[1].data.field('TIME'),hard1[1].data.field('RATE'),err=hard1[1].data.field('ERROR'),gti=hard_gti1,input_counts=False)
hard_bkg1 = st.Lightcurve(hbkg1[1].data.field('TIME'),hbkg1[1].data.field('RATE'),err=hbkg1[1].data.field('ERROR'),gti=hard_gti1,input_counts=False)

full_lc1.apply_gtis()
full_bkg1.apply_gtis()
soft_lc1.apply_gtis()
soft_bkg1.apply_gtis()
hard_lc1.apply_gtis()
hard_bkg1.apply_gtis()

full_lc2 = st.Lightcurve(lc2[1].data.field('TIME'),lc2[1].data.field('RATE'),err=lc2[1].data.field('ERROR'),gti=full_gti2,input_counts=False)
full_bkg2 = st.Lightcurve(bkg2[1].data.field('TIME'),bkg2[1].data.field('RATE'),err=bkg2[1].data.field('ERROR'),gti=full_gti2,input_counts=False)

soft_lc2 = st.Lightcurve(soft2[1].data.field('TIME'),soft2[1].data.field('RATE'),err=soft2[1].data.field('ERROR'),gti=soft_gti2,input_counts=False)
soft_bkg2 = st.Lightcurve(sbkg2[1].data.field('TIME'),sbkg2[1].data.field('RATE'),err=sbkg2[1].data.field('ERROR'),gti=soft_gti2,input_counts=False)

hard_lc2 = st.Lightcurve(hard2[1].data.field('TIME'),hard2[1].data.field('RATE'),err=hard2[1].data.field('ERROR'),gti=hard_gti2,input_counts=False)
hard_bkg2 = st.Lightcurve(hbkg2[1].data.field('TIME'),hbkg2[1].data.field('RATE'),err=hbkg2[1].data.field('ERROR'),gti=hard_gti2,input_counts=False)

full_lc2.apply_gtis()
full_bkg2.apply_gtis()
soft_lc2.apply_gtis()
soft_bkg2.apply_gtis()
hard_lc2.apply_gtis()
hard_bkg2.apply_gtis()

full_lc3 = st.Lightcurve(lc3[1].data.field('TIME'),lc3[1].data.field('RATE'),err=lc3[1].data.field('ERROR'),gti=full_gti3,input_counts=False)
full_bkg3 = st.Lightcurve(bkg3[1].data.field('TIME'),bkg3[1].data.field('RATE'),err=bkg3[1].data.field('ERROR'),gti=full_gti3,input_counts=False)

soft_lc3 = st.Lightcurve(soft3[1].data.field('TIME'),soft3[1].data.field('RATE'),err=soft3[1].data.field('ERROR'),gti=soft_gti3,input_counts=False)
soft_bkg3 = st.Lightcurve(sbkg3[1].data.field('TIME'),sbkg3[1].data.field('RATE'),err=sbkg3[1].data.field('ERROR'),gti=soft_gti3,input_counts=False)

hard_lc3 = st.Lightcurve(hard3[1].data.field('TIME'),hard3[1].data.field('RATE'),err=hard3[1].data.field('ERROR'),gti=hard_gti3,input_counts=False)
hard_bkg3 = st.Lightcurve(hbkg3[1].data.field('TIME'),hbkg3[1].data.field('RATE'),err=hbkg3[1].data.field('ERROR'),gti=hard_gti3,input_counts=False)

full_lc3.apply_gtis()
full_bkg3.apply_gtis()
soft_lc3.apply_gtis()
soft_bkg3.apply_gtis()
hard_lc3.apply_gtis()
hard_bkg3.apply_gtis()
# Out:
# /home/rwebbe/.local/lib/python3.8/site-packages/stingray/lightcurve.py:516: UserWarning: There are non-finite points in the data, but they are outside GTIs.
#   warnings.warn("There are non-finite points in the data, but they are outside GTIs. ")
# /home/rwebbe/.local/lib/python3.8/site-packages/stingray/lightcurve.py:516: UserWarning: There are non-finite points in the data, but they are outside GTIs.
#   warnings.warn("There are non-finite points in the data, but they are outside GTIs. ")

# %%
plt.plot(full_lc1.time,full_lc1.countrate,color='k')
plt.plot(soft_lc1.time,soft_lc1.countrate,color='r')
plt.plot(hard_lc1.time,hard_lc1.countrate,color='b')

# %%
plt.plot(full_lc2.time,full_lc2.countrate,color='k')
plt.plot(soft_lc2.time,soft_lc2.countrate,color='r')
plt.plot(hard_lc2.time,hard_lc2.countrate,color='b')

# %%
plt.plot(full_lc3.time,full_lc3.countrate,color='k')
plt.plot(soft_lc3.time,soft_lc3.countrate,color='r')
plt.plot(hard_lc3.time,hard_lc3.countrate,color='b')

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(soft_lc.time,soft_lc.countrate,color='r')
plt.plot(hard_lc.time,hard_lc.countrate,color='b')

# %%
plt.plot(full_lc1.rebin(50).time,full_lc1.rebin(50).countrate,color='k')
plt.plot(soft_lc1.rebin(50).time,soft_lc1.rebin(50).countrate,color='r')
plt.plot(hard_lc1.rebin(50).time,hard_lc1.rebin(50).countrate,color='b')

# %%
plt.plot(full_lc2.rebin(50).time,full_lc2.rebin(50).countrate,color='k')
plt.plot(soft_lc2.rebin(50).time,soft_lc2.rebin(50).countrate,color='r')
plt.plot(hard_lc2.rebin(50).time,hard_lc2.rebin(50).countrate,color='b')

# %%
plt.plot(full_lc3.rebin(50).time,full_lc3.rebin(50).countrate,color='k')
plt.plot(soft_lc3.rebin(50).time,soft_lc3.rebin(50).countrate,color='r')
plt.plot(hard_lc3.rebin(50).time,hard_lc3.rebin(50).countrate,color='b')

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='r')
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='b')

# %%
plt.plot(full_lc1.rebin(250).time,full_lc1.rebin(250).countrate,color='k')
plt.plot(soft_lc1.rebin(250).time,soft_lc1.rebin(250).countrate,color='r')
plt.plot(hard_lc1.rebin(250).time,hard_lc1.rebin(250).countrate,color='b')

# %%
plt.plot(full_lc2.rebin(250).time,full_lc2.rebin(250).countrate,color='k')
plt.plot(soft_lc2.rebin(250).time,soft_lc2.rebin(250).countrate,color='r')
plt.plot(hard_lc2.rebin(250).time,hard_lc2.rebin(250).countrate,color='b')

# %%
plt.plot(full_lc3.rebin(250).time,full_lc3.rebin(250).countrate,color='k')
plt.plot(soft_lc3.rebin(250).time,soft_lc3.rebin(250).countrate,color='r')
plt.plot(hard_lc3.rebin(250).time,hard_lc3.rebin(250).countrate,color='b')

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='r')
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='b')

# %%
spec1 = Spectrum("0916800701_PN1grpspec.fits")
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot("data")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0916800701_PN1grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  5.672e-02 +/- 3.094e-03 (84.2 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-37
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 8717 sec
#  Using fit statistic: chi
#  Using Background File                0916800701_PN1spec_bkg.fits
#   Background Exposure Time: 8717 sec
#  Using Response (RMF) File            0916800701_PN1spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0916800701_PN1spec.arf

# %%
spec1.ignore("**-0.2 12.0-**")
mo1 = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
#      2 channels (1-2) ignored in spectrum #     1
#      1 channels (37) ignored in spectrum #     1
#
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              5.887604e+11     using 34 bins.
#
# Test statistic : Chi-Squared              5.887604e+11     using 34 bins.
#  Null hypothesis probability of 0.000000e+00 with 31 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 364.971      2.38359       0      0.378288       3.21426   6.66970e-06
# 354.549      592149        0     0.0639975       3.13708   6.87650e-06
# 348.906      708876        0     0.0106421       2.97149   6.56101e-06
# 340.611      790373        0    0.00227229       2.72234   6.45488e-06
# 334.302      735117        0   0.000748221       2.51906   6.13080e-06
# 328.066      717986        0   0.000123350       2.32965   5.70149e-06
# 320.442      751965        0   5.76590e-05       2.13388   5.23169e-06
# 309.72       832904        0   3.21886e-06       1.91979   4.74689e-06
# 292.696      981089        0   5.41173e-07       1.67603   4.26285e-06
# 270.99       1.26433e+06  -1   1.28307e-07      0.744541   9.52676e-07
# Number of trials exceeded: continue fitting? 152.193      2.07143e+07   0   2.23157e-08      0.357113   1.95851e-06
# 68.8554      1.25849e+07  -1     0.0578612      0.424731   2.49759e-06
# 59.2277      2.08603e+06  -2      0.138799      0.411719   3.10497e-06
# 59.1589      450432       -3      0.137940      0.409793   3.13091e-06
# 59.1546      900.885      -4      0.140079      0.408119   3.13830e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  2.7934E-14| -0.0000  -0.0000   1.0000
#  2.8076E-04| -0.5391  -0.8423  -0.0000
#  2.6699E-03|  0.8423  -0.5391   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.976e-03  -1.085e-03   8.542e-09
#   -1.085e-03   9.751e-04  -3.334e-09
#    8.542e-09  -3.334e-09   6.972e-14
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.140079     +/-  4.44473E-02
#    2    2   bbody      kT         keV      0.408119     +/-  3.12261E-02
#    3    2   bbody      norm                3.13830E-06  +/-  2.64043E-07
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   59.15     using 34 bins.
#
# Test statistic : Chi-Squared                   59.15     using 34 bins.
#  Null hypothesis probability of 1.70e-03 with 31 degrees of freedom
#  Model Flux 8.8924e-05 photons (2.03e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
mo2 = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.047749e+11     using 34 bins.
#
# Test statistic : Chi-Squared              1.047749e+11     using 34 bins.
#  Null hypothesis probability of 0.000000e+00 with 31 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 278.933      17.2982      -1      0.376496       1.21925   1.87077e-05
# 151.651      909867       -1      0.101556       1.86230   4.39362e-05
# 82.2462      204228       -2      0.413995       2.51931   0.000113084
# 43.8084      245632       -3      0.533197       3.04658   0.000217183
# 35.8536      71152.9      -4      0.502359       2.95772   0.000235979
# 35.7897      5357.11      -5      0.510548       2.97333   0.000238402
# 35.7889      30.0628      -6      0.509028       2.97002   0.000237474
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.5184E-10| -0.0005  -0.0001   1.0000
#  8.1254E-04|  0.9761  -0.2172   0.0004
#  6.7379E-02|  0.2172   0.9761   0.0002
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    3.953e-03   1.411e-02   2.755e-06
#    1.411e-02   6.424e-02   1.079e-05
#    2.755e-06   1.079e-05   2.138e-09
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.509028     +/-  6.28732E-02
#    2    2   powerlaw   PhoIndex            2.97002      +/-  0.253452
#    3    2   powerlaw   norm                2.37474E-04  +/-  4.62335E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   35.79     using 34 bins.
#
# Test statistic : Chi-Squared                   35.79     using 34 bins.
#  Null hypothesis probability of 2.54e-01 with 31 degrees of freedom
#  Model Flux 9.9866e-05 photons (2.9006e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
flux = 2.9006*10**-13
d_pc = 770
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')

d_pc = 7500
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')
# Out:
# Luminosity is: 2.0634602913480205e+31 erg s^-1
# Luminosity is: 1.9576596624780936e+33 erg s^-1

# %%
AllData.clear()
spec2 = Spectrum("0916800801_PN2grpspec.fits")
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot("data")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0916800801_PN2grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  7.109e-02 +/- 3.673e-03 (83.5 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-37
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 7345 sec
#  Using fit statistic: chi
#  Using Background File                0916800801_PN2spec_bkg.fits
#   Background Exposure Time: 7345 sec
#  Using Response (RMF) File            0916800801_PN2spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0916800801_PN2spec.arf
#
#
# Fit statistic  : Chi-Squared                   94.51     using 37 bins.
#
# Test statistic : Chi-Squared                   94.51     using 37 bins.
#  Null hypothesis probability of 1.32e-07 with 34 degrees of freedom
#  Current data and model not fit yet.
# ***Warning: Fit is not current.

# %%
spec2.ignore("**-0.2 12.0-**")
mo3 = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
#      1 channels (1) ignored in spectrum #     1
#      1 channels (37) ignored in spectrum #     1
#
# Fit statistic  : Chi-Squared                   93.67     using 35 bins.
#
# Test statistic : Chi-Squared                   93.67     using 35 bins.
#  Null hypothesis probability of 5.80e-08 with 32 degrees of freedom
#  Current data and model not fit yet.
#
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.031808e+12     using 35 bins.
#
# Test statistic : Chi-Squared              1.031808e+12     using 35 bins.
#  Null hypothesis probability of 0.000000e+00 with 32 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 387.82       1.44851       0      0.199225       3.30811   3.31334e-06
# 383.404      766145        0     0.0852800       3.18723   3.48775e-06
# 378.891      812133        0     0.0100782       3.07596   3.65114e-06
# 376.319      838790        0    0.00254300       2.88876   3.42295e-06
# 373.009      928344        0   0.000963700       2.67956   3.20714e-06
# 369.204      1.01695e+06   0   0.000296898       2.46693   2.96527e-06
# 364.205      1.14385e+06   0   1.61242e-05       2.23937   2.70819e-06
# 356.651      1.33396e+06   0   1.76062e-06       1.98323   2.44206e-06
# 343.018      1.64743e+06   0   3.82003e-07       1.67892   2.17093e-06
# 311.377      2.28044e+06   0   1.51419e-07       1.29816   1.91033e-06
# Number of trials exceeded: continue fitting? 202.661      4.03605e+06  -1   5.42457e-08      0.409743   6.83229e-07
# 94.0052      3.81348e+07  -2      0.254630      0.321786   2.16628e-06
# 74.423       1.06745e+07  -3     0.0944746      0.344915   2.32510e-06
# 62.216       6.37756e+06  -4      0.166864      0.332212   2.53792e-06
# 62.0866      376818       -5      0.181570      0.327947   2.60057e-06
# 62.0835      13890.4      -6      0.180936      0.327436   2.59729e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.9370E-14| -0.0000  -0.0000   1.0000
#  1.8557E-04| -0.4307  -0.9025  -0.0000
#  3.0648E-03|  0.9025  -0.4307   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.531e-03  -1.119e-03   1.434e-08
#   -1.119e-03   7.196e-04  -6.198e-09
#    1.434e-08  -6.198e-09   1.007e-13
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.180936     +/-  5.03069E-02
#    2    2   bbody      kT         keV      0.327436     +/-  2.68247E-02
#    3    2   bbody      norm                2.59729E-06  +/-  3.17285E-07
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   62.08     using 35 bins.
#
# Test statistic : Chi-Squared                   62.08     using 35 bins.
#  Null hypothesis probability of 1.12e-03 with 32 degrees of freedom
#  Model Flux 6.9276e-05 photons (1.3937e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
mo4 = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.848026e+11     using 35 bins.
#
# Test statistic : Chi-Squared              1.848026e+11     using 35 bins.
#  Null hypothesis probability of 0.000000e+00 with 32 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 326.588      12.8339      -1      0.156370       1.23925   7.25676e-06
# 189.795      1.72707e+06   0     0.0114538       1.27882   1.90701e-05
# 140.993      826656       -1      0.131952       1.71083   3.58422e-05
# 126.417      534646       -2      0.469012       3.10467   9.83773e-05
# 70.832       298120       -3      0.630789       3.87509   0.000229157
# 52.9681      90600.5      -4      0.566163       3.63775   0.000253657
# 52.4814      15688.6      -5      0.585498       3.68877   0.000259007
# 52.4793      242.777      -6      0.583196       3.68421   0.000257355
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.8669E-10| -0.0006  -0.0000   1.0000
#  8.3795E-04|  0.9809  -0.1945   0.0005
#  1.2900E-01|  0.1945   0.9809   0.0002
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    5.687e-03   2.445e-02   4.380e-06
#    2.445e-02   1.241e-01   1.974e-05
#    4.380e-06   1.974e-05   3.603e-09
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.583196     +/-  7.54141E-02
#    2    2   powerlaw   PhoIndex            3.68421      +/-  0.352347
#    3    2   powerlaw   norm                2.57355E-04  +/-  6.00280E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   52.48     using 35 bins.
#
# Test statistic : Chi-Squared                   52.48     using 35 bins.
#  Null hypothesis probability of 1.27e-02 with 32 degrees of freedom
#  Model Flux 7.4412e-05 photons (1.7608e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
flux = 1.7608*10**-13
d_pc = 770
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')

d_pc = 7500
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')
# Out:
# Luminosity is: 1.2526170037252961e+31 erg s^-1
# Luminosity is: 1.1883910686380153e+33 erg s^-1

# %%
AllData.clear()
spec3 = Spectrum("0916800401_PN7grpspec.fits")
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot("data")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0916800401_PN7grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  1.181e-02 +/- 1.885e-03 (65.6 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-8
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 7331 sec
#  Using fit statistic: chi
#  Using Background File                0916800401_PN7spec_bkg.fits
#   Background Exposure Time: 7331 sec
#  Using Response (RMF) File            0916800401_PN7spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0916800401_PN7spec.arf
#
#
# Fit statistic  : Chi-Squared                   62.70     using 8 bins.
#
# Test statistic : Chi-Squared                   62.70     using 8 bins.
#  Null hypothesis probability of 3.37e-12 with 5 degrees of freedom
#  Current data and model not fit yet.
# ***Warning: Fit is not current.

# %%
spec3.ignore("**-0.2 12.0-**")
mo5 = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
#      1 channels (1) ignored in spectrum #     1
#      1 channels (8) ignored in spectrum #     1
#
# Fit statistic  : Chi-Squared                   51.65     using 6 bins.
#
# Test statistic : Chi-Squared                   51.65     using 6 bins.
#  Null hypothesis probability of 3.56e-11 with 3 degrees of freedom
#  Current data and model not fit yet.
#
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              3.668450e+10     using 6 bins.
#
# Test statistic : Chi-Squared              3.668450e+10     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 38.0582      0.420308      0      0.283854       3.22243   9.24913e-06
# 37.5887      68888.8       0     0.0546244       3.32146   8.03597e-06
# 35.7656      105625        0     0.0178503       3.09580   8.78989e-06
# 34.8441      99034         0    0.00717599       2.96545   9.09751e-06
# 34.4262      88165.6       0    0.00302412       2.88729   9.08810e-06
# 34.2087      82174.6       0    0.00117559       2.83027   8.93687e-06
# 34.0753      80002.7       0   0.000305205       2.78229   8.72335e-06
# 33.9812      80046.5       0   9.51559e-05       2.73822   8.48322e-06
# 33.9033      81271.6       0   4.38087e-05       2.69594   8.23155e-06
# 33.8301      83248.2       0   1.85790e-05       2.65423   7.97685e-06
# Number of trials exceeded: continue fitting? 33.7569      85659.3       0   6.16289e-06       2.61249   7.72305e-06
# 33.6815      88336.4       0   5.09933e-08       2.57048   7.47169e-06
# 33.6028      91213.2       0   3.99799e-09       2.52807   7.22337e-06
# 33.5202      94266.5       0   1.10877e-09       2.48522   6.97833e-06
# 33.4332      97495.2       0   3.98787e-10       2.44187   6.73665e-06
# 33.3411      100903        0   5.01506e-11       2.39798   6.49838e-06
# 33.2435      104501        0   7.39168e-12       2.35351   6.26349e-06
# 33.1399      108302        0   2.15288e-12       2.30843   6.03197e-06
# 33.0297      112322        0   8.70927e-13       2.26271   5.80363e-06
# 32.9118      116595        0   2.44001e-13       2.21627   5.57881e-06
# Number of trials exceeded: continue fitting? 32.7825      121102        0   9.05356e-14       2.16883   5.35940e-06
# 32.6466      125607        0   1.58273e-14       2.12082   5.14140e-06
# 32.5104      130633        0   6.78243e-15       2.07281   4.92121e-06
# 32.3628      136944        0   2.32612e-15       2.02432   4.70831e-06
# 32.1313      143462        0   1.58056e-16       1.96872   4.53069e-06
# 31.9066      143079        0   7.82785e-17       1.90626   4.28045e-06
# 30.9292      150989       -1   2.48724e-17       1.50455   2.39935e-06
# 24.7045      447548       -1   4.59372e-18      0.867239   1.06983e-06
# 14.7954      1.73464e+06   0   2.21123e-18      0.608183   1.18007e-06
# 13.3101      525842       -1   5.96162e-19      0.491452   1.00969e-06
# Number of trials exceeded: continue fitting? 13.3001      86237.7      -1   2.17148e-19      0.508253   1.04107e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  3.2758E-14| -0.0000  -0.0000   1.0000
#  8.0873E-03| -0.0003  -1.0000  -0.0000
#  1.7587E+02|  1.0000  -0.0003  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.759e+02  -4.638e-02  -3.058e-08
#   -4.638e-02   8.100e-03   1.818e-08
#   -3.058e-08   1.818e-08   7.360e-14
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    2.17148E-19  +/-  13.2615
#    2    2   bbody      kT         keV      0.508253     +/-  8.99976E-02
#    3    2   bbody      norm                1.04107E-06  +/-  2.71290E-07
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   13.30     using 6 bins.
#
# Test statistic : Chi-Squared                   13.30     using 6 bins.
#  Null hypothesis probability of 4.03e-03 with 3 degrees of freedom
#  Model Flux 3.8536e-05 photons (8.699e-14 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
mo6 = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              2.148808e+10     using 6 bins.
#
# Test statistic : Chi-Squared              2.148808e+10     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 25.4128      1.93277      -1      0.170787       1.76885   1.31080e-05
# 15.8918      179888       -1      0.360514       1.88213   3.52353e-05
# 12.1327      55878.5      -1      0.375894       2.57475   5.64635e-05
# 10.6039      16970.7      -1      0.484464       2.76105   7.61723e-05
# 9.74805      11098.1      -1      0.556325       3.09916   9.75824e-05
# 9.69697      7214.37      -2      0.832463       4.20373   0.000179650
# 9.13637      11171        -3       1.05177       5.17532   0.000334841
# 7.83202      5609.57      -4       1.05192       5.27416   0.000419304
# 7.82998      118.58       -5       1.07200       5.33712   0.000441092
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  4.7746E-09| -0.0007  -0.0001   1.0000
#  2.8819E-02|  0.9762  -0.2170   0.0007
#  4.9564E+00|  0.2170   0.9762   0.0002
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.608e-01   1.044e+00   2.814e-04
#    1.044e+00   4.724e+00   1.176e-03
#    2.814e-04   1.176e-03   3.130e-07
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.07200      +/-  0.510682
#    2    2   powerlaw   PhoIndex            5.33712      +/-  2.17358
#    3    2   powerlaw   norm                4.41092E-04  +/-  5.59457E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    7.83     using 6 bins.
#
# Test statistic : Chi-Squared                    7.83     using 6 bins.
#  Null hypothesis probability of 4.97e-02 with 3 degrees of freedom
#  Model Flux 3.139e-05 photons (7.0052e-14 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
flux = 7.0052*10**-14
d_pc = 770
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')

d_pc = 7500
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')
# Out:
# Luminosity is: 4.983435162708114e+30 erg s^-1
# Luminosity is: 4.7279174886546034e+32 erg s^-1
