# %%
# %load_ext wurlitzer
import numpy as np
import os
import stingray as st
import matplotlib.pyplot as plt
from astropy.io import fits
from xspec import *
plt.rcParams['figure.figsize'] = [15, 8]

lc1 = fits.open('0916811501_PN1_dt1.lc')
bkg1 = fits.open('0916811501_PN1_dt1_bkg.lc')
full_gti1 = []
for j in lc1[2].data:
    full_gti1.append([j[0],j[1]])
soft1 = fits.open('0916811501_PN1_dt1_0.2-2keV.lc')
sbkg1 = fits.open('0916811501_PN1_dt1_0.2-2keV_bkg.lc')
soft_gti1 = []
for j in soft1[2].data:
    soft_gti1.append([j[0],j[1]])
hard1 = fits.open('0916811501_PN1_dt1_2-12keV.lc')
hbkg1 = fits.open('0916811501_PN1_dt1_2-12keV_bkg.lc')
hard_gti1 = []
for j in hard1[2].data:
    hard_gti1.append([j[0],j[1]])
    
lc2 = fits.open('0916810801_PN1_dt1.lc')
bkg2 = fits.open('0916810801_PN1_dt1_bkg.lc')
full_gti2 = []
for j in lc2[2].data:
    full_gti2.append([j[0],j[1]])
soft2 = fits.open('0916810801_PN1_dt1_0.2-2keV.lc')
sbkg2 = fits.open('0916810801_PN1_dt1_0.2-2keV_bkg.lc')
soft_gti2 = []
for j in soft2[2].data:
    soft_gti2.append([j[0],j[1]])
hard2 = fits.open('0916810801_PN1_dt1_2-12keV.lc')
hbkg2 = fits.open('0916810801_PN1_dt1_2-12keV_bkg.lc')
hard_gti2 = []
for j in hard2[2].data:
    hard_gti2.append([j[0],j[1]])
    
lc3 = fits.open('0916811401_PN1_dt1.lc')
bkg3 = fits.open('0916811401_PN1_dt1_bkg.lc')
full_gti3 = []
for j in lc3[2].data:
    full_gti3.append([j[0],j[1]])
soft3 = fits.open('0916811401_PN1_dt1_0.2-2keV.lc')
sbkg3 = fits.open('0916811401_PN1_dt1_0.2-2keV_bkg.lc')
soft_gti3 = []
for j in soft3[2].data:
    soft_gti3.append([j[0],j[1]])
hard3 = fits.open('0916811401_PN1_dt1_2-12keV.lc')
hbkg3 = fits.open('0916811401_PN1_dt1_2-12keV_bkg.lc')
hard_gti3 = []
for j in hard3[2].data:
    hard_gti3.append([j[0],j[1]])
    
lc4 = fits.open('0916811901_PN1_dt1.lc')
bkg4 = fits.open('0916811901_PN1_dt1_bkg.lc')
full_gti4 = []
for j in lc4[2].data:
    full_gti4.append([j[0],j[1]])
soft4 = fits.open('0916811901_PN1_dt1_0.2-2keV.lc')
sbkg4 = fits.open('0916811901_PN1_dt1_0.2-2keV_bkg.lc')
soft_gti4 = []
for j in soft4[2].data:
    soft_gti4.append([j[0],j[1]])
hard4 = fits.open('0916811901_PN1_dt1_2-12keV.lc')
hbkg4 = fits.open('0916811901_PN1_dt1_2-12keV_bkg.lc')
hard_gti4 = []
for j in hard4[2].data:
    hard_gti4.append([j[0],j[1]])

# %%
full_lc1 = st.Lightcurve(lc1[1].data.field('TIME'),lc1[1].data.field('RATE'),err=lc1[1].data.field('ERROR'),gti=full_gti1,input_counts=False)
full_bkg1 = st.Lightcurve(bkg1[1].data.field('TIME'),bkg1[1].data.field('RATE'),err=bkg1[1].data.field('ERROR'),gti=full_gti1,input_counts=False)
soft_lc1 = st.Lightcurve(soft1[1].data.field('TIME'),soft1[1].data.field('RATE'),err=soft1[1].data.field('ERROR'),gti=soft_gti1,input_counts=False)
soft_bkg1 = st.Lightcurve(sbkg1[1].data.field('TIME'),sbkg1[1].data.field('RATE'),err=sbkg1[1].data.field('ERROR'),gti=soft_gti1,input_counts=False)
hard_lc1 = st.Lightcurve(hard1[1].data.field('TIME'),hard1[1].data.field('RATE'),err=hard1[1].data.field('ERROR'),gti=hard_gti1,input_counts=False)
hard_bkg1 = st.Lightcurve(hbkg1[1].data.field('TIME'),hbkg1[1].data.field('RATE'),err=hbkg1[1].data.field('ERROR'),gti=hard_gti1,input_counts=False)
full_lc1.apply_gtis()
full_bkg1.apply_gtis()
soft_lc1.apply_gtis()
soft_bkg1.apply_gtis()
hard_lc1.apply_gtis()
hard_bkg1.apply_gtis()

full_lc2 = st.Lightcurve(lc2[1].data.field('TIME'),lc2[1].data.field('RATE'),err=lc2[1].data.field('ERROR'),gti=full_gti2,input_counts=False)
full_bkg2 = st.Lightcurve(bkg2[1].data.field('TIME'),bkg2[1].data.field('RATE'),err=bkg2[1].data.field('ERROR'),gti=full_gti2,input_counts=False)
soft_lc2 = st.Lightcurve(soft2[1].data.field('TIME'),soft2[1].data.field('RATE'),err=soft2[1].data.field('ERROR'),gti=soft_gti2,input_counts=False)
soft_bkg2 = st.Lightcurve(sbkg2[1].data.field('TIME'),sbkg2[1].data.field('RATE'),err=sbkg2[1].data.field('ERROR'),gti=soft_gti2,input_counts=False)
hard_lc2 = st.Lightcurve(hard2[1].data.field('TIME'),hard2[1].data.field('RATE'),err=hard2[1].data.field('ERROR'),gti=hard_gti2,input_counts=False)
hard_bkg2 = st.Lightcurve(hbkg2[1].data.field('TIME'),hbkg2[1].data.field('RATE'),err=hbkg2[1].data.field('ERROR'),gti=hard_gti2,input_counts=False)
full_lc2.apply_gtis()
full_bkg2.apply_gtis()
soft_lc2.apply_gtis()
soft_bkg2.apply_gtis()
hard_lc2.apply_gtis()
hard_bkg2.apply_gtis()

full_lc3 = st.Lightcurve(lc3[1].data.field('TIME'),lc3[1].data.field('RATE'),err=lc3[1].data.field('ERROR'),gti=full_gti3,input_counts=False)
full_bkg3 = st.Lightcurve(bkg3[1].data.field('TIME'),bkg3[1].data.field('RATE'),err=bkg3[1].data.field('ERROR'),gti=full_gti3,input_counts=False)
soft_lc3 = st.Lightcurve(soft3[1].data.field('TIME'),soft3[1].data.field('RATE'),err=soft3[1].data.field('ERROR'),gti=soft_gti3,input_counts=False)
soft_bkg3 = st.Lightcurve(sbkg3[1].data.field('TIME'),sbkg3[1].data.field('RATE'),err=sbkg3[1].data.field('ERROR'),gti=soft_gti3,input_counts=False)
hard_lc3 = st.Lightcurve(hard3[1].data.field('TIME'),hard3[1].data.field('RATE'),err=hard3[1].data.field('ERROR'),gti=hard_gti3,input_counts=False)
hard_bkg3 = st.Lightcurve(hbkg3[1].data.field('TIME'),hbkg3[1].data.field('RATE'),err=hbkg3[1].data.field('ERROR'),gti=hard_gti3,input_counts=False)
full_lc3.apply_gtis()
full_bkg3.apply_gtis()
soft_lc3.apply_gtis()
soft_bkg3.apply_gtis()
hard_lc3.apply_gtis()
hard_bkg3.apply_gtis()

full_lc4 = st.Lightcurve(lc4[1].data.field('TIME'),lc4[1].data.field('RATE'),err=lc4[1].data.field('ERROR'),gti=full_gti4,input_counts=False)
full_bkg4 = st.Lightcurve(bkg4[1].data.field('TIME'),bkg4[1].data.field('RATE'),err=bkg4[1].data.field('ERROR'),gti=full_gti4,input_counts=False)
soft_lc4 = st.Lightcurve(soft4[1].data.field('TIME'),soft4[1].data.field('RATE'),err=soft4[1].data.field('ERROR'),gti=soft_gti4,input_counts=False)
soft_bkg4 = st.Lightcurve(sbkg4[1].data.field('TIME'),sbkg4[1].data.field('RATE'),err=sbkg4[1].data.field('ERROR'),gti=soft_gti4,input_counts=False)
hard_lc4 = st.Lightcurve(hard4[1].data.field('TIME'),hard4[1].data.field('RATE'),err=hard4[1].data.field('ERROR'),gti=hard_gti4,input_counts=False)
hard_bkg4 = st.Lightcurve(hbkg4[1].data.field('TIME'),hbkg4[1].data.field('RATE'),err=hbkg4[1].data.field('ERROR'),gti=hard_gti4,input_counts=False)
full_lc4.apply_gtis()
full_bkg4.apply_gtis()
soft_lc4.apply_gtis()
soft_bkg4.apply_gtis()
hard_lc4.apply_gtis()
hard_bkg4.apply_gtis()

full_bkg1 = full_bkg1.shift(-full_lc1.time[0])
soft_lc1 = soft_lc1.shift(-full_lc1.time[0])
soft_bkg1 = soft_bkg1.shift(-full_lc1.time[0])
hard_lc1 = hard_lc1.shift(-full_lc1.time[0])
hard_bkg1 = hard_bkg1.shift(-full_lc1.time[0])
full_lc1 = full_lc1.shift(-full_lc1.time[0])
full_bkg2 = full_bkg2.shift(-full_lc2.time[0])
soft_lc2 = soft_lc2.shift(-full_lc2.time[0])
soft_bkg2 = soft_bkg2.shift(-full_lc2.time[0])
hard_lc2 = hard_lc2.shift(-full_lc2.time[0])
hard_bkg2 = hard_bkg2.shift(-full_lc2.time[0])
full_lc2 = full_lc2.shift(-full_lc2.time[0])
full_bkg3 = full_bkg3.shift(-full_lc3.time[0])
soft_lc3 = soft_lc3.shift(-full_lc3.time[0])
soft_bkg3 = soft_bkg3.shift(-full_lc3.time[0])
hard_lc3 = hard_lc3.shift(-full_lc3.time[0])
hard_bkg3 = hard_bkg3.shift(-full_lc3.time[0])
full_lc3 = full_lc3.shift(-full_lc3.time[0])
full_bkg4 = full_bkg4.shift(-full_lc4.time[0])
soft_lc4 = soft_lc4.shift(-full_lc4.time[0])
soft_bkg4 = soft_bkg4.shift(-full_lc4.time[0])
hard_lc4 = hard_lc4.shift(-full_lc4.time[0])
hard_bkg4 = hard_bkg4.shift(-full_lc4.time[0])
full_lc4 = full_lc4.shift(-full_lc4.time[0])
# Out:
# /home/rwebbe/.local/lib/python3.8/site-packages/stingray/lightcurve.py:516: UserWarning: There are non-finite points in the data, but they are outside GTIs.
#   warnings.warn("There are non-finite points in the data, but they are outside GTIs. ")
# /home/rwebbe/.local/lib/python3.8/site-packages/stingray/lightcurve.py:516: UserWarning: There are non-finite points in the data, but they are outside GTIs.
#   warnings.warn("There are non-finite points in the data, but they are outside GTIs. ")

# %%
plt.plot(full_lc1.time,full_lc1.countrate,color='k')
plt.plot(soft_lc1.time,soft_lc1.countrate,color='r')
plt.plot(hard_lc1.time,hard_lc1.countrate,color='b')

# %%
plt.plot(full_lc2.time,full_lc2.countrate,color='k')
plt.plot(soft_lc2.time,soft_lc2.countrate,color='r')
plt.plot(hard_lc2.time,hard_lc2.countrate,color='b')

# %%
plt.plot(full_lc3.time,full_lc3.countrate,color='k')
plt.plot(soft_lc3.time,soft_lc3.countrate,color='r')
plt.plot(hard_lc3.time,hard_lc3.countrate,color='b')

# %%
plt.plot(full_lc4.time,full_lc4.countrate,color='k')
plt.plot(soft_lc4.time,soft_lc4.countrate,color='r')
plt.plot(hard_lc4.time,hard_lc4.countrate,color='b')

# %%
plt.plot(full_lc1.rebin(50).time,full_lc1.rebin(50).countrate,color='k')
plt.plot(soft_lc1.rebin(50).time,soft_lc1.rebin(50).countrate,color='r')
plt.plot(hard_lc1.rebin(50).time,hard_lc1.rebin(50).countrate,color='b')

# %%
plt.plot(full_lc2.rebin(50).time,full_lc2.rebin(50).countrate,color='k')
plt.plot(soft_lc2.rebin(50).time,soft_lc2.rebin(50).countrate,color='r')
plt.plot(hard_lc2.rebin(50).time,hard_lc2.rebin(50).countrate,color='b')

# %%
plt.plot(full_lc3.rebin(50).time,full_lc3.rebin(50).countrate,color='k')
plt.plot(soft_lc3.rebin(50).time,soft_lc3.rebin(50).countrate,color='r')
plt.plot(hard_lc3.rebin(50).time,hard_lc3.rebin(50).countrate,color='b')

# %%
plt.plot(full_lc4.rebin(50).time,full_lc4.rebin(50).countrate,color='k')
plt.plot(soft_lc4.rebin(50).time,soft_lc4.rebin(50).countrate,color='r')
plt.plot(hard_lc4.rebin(50).time,hard_lc4.rebin(50).countrate,color='b')

# %%
plt.plot(hard_lc1.rebin(50).time,hard_lc1.rebin(50).countrate,color='k')
plt.plot(hard_bkg1.rebin(50).time,hard_bkg1.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(full_lc1.rebin(250).time,full_lc1.rebin(250).countrate,color='k')
plt.plot(soft_lc1.rebin(250).time,soft_lc1.rebin(250).countrate,color='r')
plt.plot(hard_lc1.rebin(250).time,hard_lc1.rebin(250).countrate,color='b')

# %%
plt.plot(full_lc2.rebin(250).time,full_lc2.rebin(250).countrate,color='k')
plt.plot(soft_lc2.rebin(250).time,soft_lc2.rebin(250).countrate,color='r')
plt.plot(hard_lc2.rebin(250).time,hard_lc2.rebin(250).countrate,color='b')

# %%
plt.plot(full_lc3.rebin(250).time,full_lc3.rebin(250).countrate,color='k')
plt.plot(soft_lc3.rebin(250).time,soft_lc3.rebin(250).countrate,color='r')
plt.plot(hard_lc3.rebin(250).time,hard_lc3.rebin(250).countrate,color='b')

# %%
plt.plot(full_lc4.rebin(250).time,full_lc4.rebin(250).countrate,color='k')
plt.plot(soft_lc4.rebin(250).time,soft_lc4.rebin(250).countrate,color='r')
plt.plot(hard_lc4.rebin(250).time,hard_lc4.rebin(250).countrate,color='b')

# %%
spec = Spectrum("0916811501_PN1grpspec.fits")
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.0001 1")
Plot("data")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0916811501_PN1grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  7.486e-01 +/- 1.064e-02 (82.6 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-176
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 1.137e+04 sec
#  Using fit statistic: chi
#  Using Background File                0916811501_PN1spec_bkg.fits
#   Background Exposure Time: 1.135e+04 sec
#  Using Response (RMF) File            0916811501_PN1spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0916811501_PN1spec.arf

# %%
spec.ignore("**-0.2 12.0-**")
mo1 = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
#      2 channels (1-2) ignored in spectrum #     1
#     12 channels (165-176) ignored in spectrum #     1
#
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              4.098165e+10     using 162 bins.
#
# Test statistic : Chi-Squared              4.098165e+10     using 162 bins.
#  Null hypothesis probability of 0.000000e+00 with 159 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 5279.15      139.744       0      0.191433       1.19825   0.000105895
# 3087.24      1.88597e+06  -1     0.0758275       2.10680   0.000212412
# 2383.95      2.02067e+06  -2      0.389582       3.71459   0.000743719
# 1759.56      699260       -3      0.694668       5.52216    0.00231245
# 562.09       226317       -4      0.653163       5.36572    0.00381241
# 540.151      32730.8      -5      0.669998       5.41752    0.00381429
# 540.13       934.149      -6      0.670154       5.42021    0.00380951
# 540.13       0.523901     -7      0.670417       5.42173    0.00381254
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  2.2727E-09| -0.0122   0.0001   0.9999
#  3.3831E-05|  0.9867  -0.1618   0.0121
#  2.4186E-02|  0.1618   0.9868   0.0019
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    6.663e-04   3.857e-03   7.669e-06
#    3.857e-03   2.355e-02   4.424e-05
#    7.669e-06   4.424e-05   9.057e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.670417     +/-  2.58123E-02
#    2    2   powerlaw   PhoIndex            5.42173      +/-  0.153473
#    3    2   powerlaw   norm                3.81254E-03  +/-  3.00953E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  540.13     using 162 bins.
#
# Test statistic : Chi-Squared                  540.13     using 162 bins.
#  Null hypothesis probability of 5.35e-43 with 159 degrees of freedom
#  Model Flux 0.00075721 photons (1.2484e-12 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
mo2 = Model("tbabs*(bbody+powerlaw)")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>(bbody<2> + powerlaw<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
#    4    3   powerlaw   PhoIndex            1.00000      +/-  0.0
#    5    3   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              4.728786e+11     using 162 bins.
#
# Test statistic : Chi-Squared              4.728786e+11     using 162 bins.
#  Null hypothesis probability of 0.000000e+00 with 157 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm    4:PhoIndex        5:norm
# 6454.58      534299        0      0.393690       3.51225   1.52264e-05       1.53978   3.24229e-05
# 5811.3       1.07836e+06  -1      0.119360       3.66730   2.26323e-05       4.32958   3.03886e-05
# 4868.49      2.67376e+06   0     0.0982906       2.78779   2.57081e-05       4.30738   7.13775e-05
# 3724.22      843741       -1      0.139916       1.16395   1.19334e-06       2.75452   0.000195972
# 1726.44      7.72901e+06   0      0.114925      0.366472   2.75593e-06       2.59390   0.000335958
# 1134.74      1.66376e+07  -1      0.143360      0.176339   7.17722e-06       2.03431   0.000403451
# 1038.29      7.17358e+06  -1      0.167259      0.298927   1.33674e-05       2.25679   0.000341013
# 847.723      1.5763e+06   -1      0.176753      0.174711   1.49697e-05       2.17711   0.000338920
# 525.05       4.56307e+06  -2      0.244059      0.208335   2.87078e-05       2.18022   0.000275562
# 435.723      250858       -1      0.246099      0.186634   3.13194e-05       2.15496   0.000274471
# Number of trials exceeded: continue fitting? 421.018      761668       -1      0.258693      0.183623   3.47862e-05       2.14077   0.000269745
# 411.897      328181       -1      0.270298      0.180117   3.77053e-05       2.13257   0.000270148
# 404.762      249030       -1      0.280976      0.177008   4.04014e-05       2.13757   0.000274680
# 398.856      199555       -1      0.290859      0.174181   4.29577e-05       2.15153   0.000281901
# 393.79       165672       -1      0.300075      0.171590   4.54259e-05       2.17094   0.000290833
# 389.345      140876       -1      0.308719      0.169199   4.78396e-05       2.19339   0.000300804
# 385.39       121960       -1      0.316863      0.166985   5.02214e-05       2.21729   0.000311351
# 381.835      107057       -1      0.324564      0.164928   5.25864e-05       2.24161   0.000322154
# 378.619      94997.7      -1      0.331869      0.163011   5.49447e-05       2.26568   0.000332994
# 375.693      85021.7      -1      0.338815      0.161222   5.73029e-05       2.28911   0.000343722
# Number of trials exceeded: continue fitting? 373.019      76633.6      -1      0.345434      0.159546   5.96652e-05       2.31165   0.000354241
# 372.781      69470.6      -2      0.393965      0.146694   7.67749e-05       2.52777   0.000451800
# 354.419      567768       -2      0.428329      0.140359   9.87141e-05       2.60538   0.000507907
# 345.199      293838       -2      0.454802      0.135574   0.000120832       2.66504   0.000550144
# 340.05       159615       -2      0.476306      0.131961   0.000142454       2.71035   0.000583731
# 336.927      91676.6      -2      0.494200      0.129098   0.000163350       2.74694   0.000611888
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  328.82     using 162 bins.
#
# Test statistic : Chi-Squared                  328.82     using 162 bins.
#  Null hypothesis probability of 3.14e-14 with 157 degrees of freedom
#  Model Flux 0.00080286 photons (1.6062e-12 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
flux = 1.6062*10**-12
d_pc = 387
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')
# Out:
# Luminosity is: 2.8863458914059244e+31 erg s^-1

# %%
AllData.clear()
AllModels.clear()
spec = Spectrum("0916810801_PN1grpspec.fits")
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.0001 1")
Plot("data")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0916810801_PN1grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  3.312e-01 +/- 1.032e-02 (98.3 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-47
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 3200 sec
#  Using fit statistic: chi
#  Using Background File                0916810801_PN1spec_bkg.fits
#   Background Exposure Time: 3200 sec
#  Using Response (RMF) File            0916810801_PN1spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0916810801_PN1spec.arf

# %%
spec.ignore("**-0.2 12.0-**")
mo1 = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
#      1 channels (1) ignored in spectrum #     1
#      1 channels (47) ignored in spectrum #     1
#
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              6.171479e+09     using 45 bins.
#
# Test statistic : Chi-Squared              6.171479e+09     using 45 bins.
#  Null hypothesis probability of 0.000000e+00 with 42 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 676.576      17.6022       0      0.169286       1.25308   0.000134437
# 418.056      262767       -1     0.0781628       2.37501   0.000260099
# 273.024      95082.8      -2      0.293282       3.10488   0.000619496
# 238.051      95014.6      -2      0.554882       4.58537    0.00148075
# 175.438      45533.9      -3      0.758808       5.74020    0.00323550
# 119.609      17376.5      -4      0.777846       5.90662    0.00449268
# 119.369      987.393      -5      0.788755       5.95559    0.00470878
# 119.366      61.4401      -6      0.789875       5.96532    0.00472919
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  2.4560E-08| -0.0141  -0.0000   0.9999
#  2.5359E-04|  0.9858  -0.1676   0.0139
#  1.6066E-01|  0.1676   0.9859   0.0024
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    4.758e-03   2.650e-02   6.742e-05
#    2.650e-02   1.562e-01   3.756e-04
#    6.742e-05   3.756e-04   9.800e-07
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.789875     +/-  6.89780E-02
#    2    2   powerlaw   PhoIndex            5.96532      +/-  0.395166
#    3    2   powerlaw   norm                4.72919E-03  +/-  9.89936E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  119.37     using 45 bins.
#
# Test statistic : Chi-Squared                  119.37     using 45 bins.
#  Null hypothesis probability of 2.42e-09 with 42 degrees of freedom
#  Model Flux 0.0006404 photons (1.0634e-12 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
mo2 = Model("tbabs*(bbody+powerlaw)")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>(bbody<2> + powerlaw<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
#    4    3   powerlaw   PhoIndex            1.00000      +/-  0.0
#    5    3   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared
# ============================================================
#  Variances and Principal Axes
#                  1        2        3        4        5
#  1.0252E-07| -0.0293  -0.0000   0.0000   0.0003   0.9996
#  3.1127E-04|  0.9857  -0.0001   0.0013  -0.1657   0.0289
#  2.6769E-01|  0.1630   0.0206  -0.1830   0.9693   0.0044
#  2.3538E+00|  0.0292  -0.1097   0.9768   0.1818   0.0008
#  2.7837E+09| -0.0000   0.9938   0.1116  -0.0000  -0.0000
# ------------------------------------------------------------
#
# ============================================================
#   Covariance Matrix
#         1           2           3           4           5
#    1.487e-02  -3.866e+03  -4.341e+02   9.036e-02   3.946e-04
#   -3.866e+03   2.749e+09   3.087e+08  -2.530e+04  -9.836e+01
#   -4.341e+02   3.087e+08   3.467e+07  -2.841e+03  -1.104e+01
#    9.036e-02  -2.530e+04  -2.841e+03   5.622e-01   2.389e-03
#    3.946e-04  -9.836e+01  -1.104e+01   2.389e-03   1.059e-05
# ------------------------------------------------------------
#
# ========================================================================
# Model TBabs<1>(bbody<2> + powerlaw<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.03276      +/-  0.121943
#    2    2   bbody      kT         keV      188.108      +/-  5.24314E+04
#    3    2   bbody      norm                7.10361      +/-  5888.31
#    4    3   powerlaw   PhoIndex            7.50006      +/-  0.749787
#    5    3   powerlaw   norm                9.44003E-03  +/-  3.25358E-03
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   99.10     using 45 bins.
#
# Test statistic : Chi-Squared                   99.10     using 45 bins.
#  Null hypothesis probability of 6.37e-07 with 40 degrees of freedom
#  Model Flux 0.0011962 photons (8.5486e-12 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
flux = 8.5486*10**-12
d_pc = 387
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')
# Out:
# Luminosity is: 1.5361858104390912e+32 erg s^-1

# %%
AllData.clear()
AllModels.clear()
spec = Spectrum("0916811401_PN1grpspec.fits")
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.0001 0.3")
Plot("data")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0916811401_PN1grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  4.752e-02 +/- 8.646e-03 (47.5 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-25
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 6871 sec
#  Using fit statistic: chi
#  Using Background File                0916811401_PN1spec_bkg.fits
#   Background Exposure Time: 6871 sec
#  Using Response (RMF) File            0916811401_PN1spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0916811401_PN1spec.arf

# %%
spec.ignore("**-0.2 12.0-**")
mo1 = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
#      1 channels (1) ignored in spectrum #     1
#      1 channels (25) ignored in spectrum #     1
#
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              3.303695e+08     using 23 bins.
#
# Test statistic : Chi-Squared              3.303695e+08     using 23 bins.
#  Null hypothesis probability of 0.000000e+00 with 20 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 189.611      8.52782       0     0.0373569       1.26064   0.000285578
# 163.349      65696.5      -1     0.0247023       2.53471   0.000676284
# 72.3656      44039        -2      0.104445       2.23281   0.000954586
# 58.7977      2377.51      -3      0.389768       3.82948    0.00190323
# 45.6713      10184.8      -2      0.586276       5.01314    0.00365436
# 32.0144      4892.74      -2      0.692766       5.63709    0.00574965
# 31.224       1596.28      -3      0.849821       6.53726    0.00897197
# 27.7575      1127.64      -4      0.888892       6.78287     0.0109944
# 27.6755      154.608      -5      0.891595       6.80143     0.0112533
# 27.6755      1.40191      -6      0.892095       6.80456     0.0112708
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  3.8420E-07| -0.0349   0.0005   0.9994
#  1.0523E-03|  0.9852  -0.1679   0.0345
#  9.5181E-01|  0.1679   0.9858   0.0054
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.784e-02   1.573e-01   8.936e-04
#    1.573e-01   9.250e-01   5.032e-03
#    8.936e-04   5.032e-03   2.907e-05
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.892095     +/-  0.166856
#    2    2   powerlaw   PhoIndex            6.80456      +/-  0.961763
#    3    2   powerlaw   norm                1.12708E-02  +/-  5.39200E-03
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   27.68     using 23 bins.
#
# Test statistic : Chi-Squared                   27.68     using 23 bins.
#  Null hypothesis probability of 1.17e-01 with 20 degrees of freedom
#  Model Flux 0.0011377 photons (1.7919e-12 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
mo2 = Model("tbabs*(bbody+powerlaw)")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>(bbody<2> + powerlaw<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
#    4    3   powerlaw   PhoIndex            1.00000      +/-  0.0
#    5    3   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              2.755547e+09     using 23 bins.
#
# Test statistic : Chi-Squared              2.755547e+09     using 23 bins.
#  Null hypothesis probability of 0.000000e+00 with 18 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm    4:PhoIndex        5:norm
# 331.666      11527.8      -1      0.154703       3.65441   7.32941e-05       2.65634   2.94196e-05
# 256.021      50189         0     0.0377283       3.51137   7.77010e-05       3.37689   0.000119256
# 201.775      55723.7       0     0.0458538       2.94915   8.48864e-05       2.88424   0.000229971
# 148.724      40231.2       0     0.0481682       2.91800   7.18699e-05       2.42639   0.000380374
# 138.827      28916.1      -1      0.112162       4.09233   1.48382e-05       1.49257   0.000867298
# 80.4972      28768.6      -1     0.0795477       11.5957   5.94698e-06       2.05046   0.000921503
# 66.5873      6151.46      -1      0.143068       198.454   1.42618e-06       2.34049    0.00106935
# 57.9846      379.514      -1      0.196379       199.191   9.42790e-09       2.70075    0.00127215
# 52.218       1399.92      -1      0.243782       199.347   1.95416e-09       2.99668    0.00150159
# 47.9495      1223.58      -1      0.286251       199.359   8.29361e-10       3.25686    0.00174015
# Number of trials exceeded: continue fitting? 44.6707      962.945      -1      0.324747       199.363   2.77616e-10       3.48987    0.00198342
# 42.078       760.671      -1      0.359893       199.363   6.44270e-11       3.70094    0.00222995
# 40.1682      611.759      -1      0.392151       79.9249      0.117308       3.89351    0.00247884
# 36.2342      404.71       -2      0.573100       71.3712      0.128970       4.94841    0.00389277
# 30.9157      1730.72      -2      0.692874       69.0334      0.112135       5.65300    0.00578634
# 27.9743      864.935      -2      0.764202       64.2943      0.101097       6.07056    0.00750157
# 27.1751      300.161      -2      0.810516       60.2087     0.0872288       6.34116    0.00876981
# 27.0925      103.357      -3      0.891920       20.4136    0.00586252       6.80943     0.0109437
# 26.7143      142.963      -2      0.896444       18.7074    0.00271751       6.84701     0.0113607
# 26.6967      11.6233      -2      0.902396       13.3702    0.00100737       6.88098     0.0115591
# Number of trials exceeded: continue fitting? 26.6473      32.8936      -1      0.902975       12.2564    0.00101955       6.88544     0.0115784
# 26.6421      6.44291      -1      0.903566       11.8775   0.000912874       6.88931     0.0115969
# ============================================================
#  Variances and Principal Axes
#                  1        2        3        4        5
#  4.0826E-07|  0.0360   0.0000  -0.0624  -0.0005  -0.9974
#  9.4137E-07|  0.0042  -0.0002   0.9980  -0.0005  -0.0623
#  1.0712E-03|  0.9852  -0.0000  -0.0020  -0.1675   0.0358
#  9.8737E-01|  0.1674   0.0013   0.0002   0.9859   0.0055
#  1.0006E+05| -0.0002   1.0000   0.0002  -0.0013  -0.0000
# ------------------------------------------------------------
#
# ============================================================
#   Covariance Matrix
#         1           2           3           4           5
#    3.247e-02  -1.939e+01  -4.474e-03   1.877e-01   1.061e-03
#   -1.939e+01   1.001e+05   2.321e+01  -1.286e+02  -5.904e-01
#   -4.474e-03   2.321e+01   5.386e-03  -2.967e-02  -1.362e-04
#    1.877e-01  -1.286e+02  -2.967e-02   1.125e+00   6.105e-03
#    1.061e-03  -5.904e-01  -1.362e-04   6.105e-03   3.512e-05
# ------------------------------------------------------------
#
# ========================================================================
# Model TBabs<1>(bbody<2> + powerlaw<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.903566     +/-  0.180191
#    2    2   bbody      kT         keV      11.8775      +/-  316.315
#    3    2   bbody      norm                9.12874E-04  +/-  7.33897E-02
#    4    3   powerlaw   PhoIndex            6.88931      +/-  1.06060
#    5    3   powerlaw   norm                1.15969E-02  +/-  5.92612E-03
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   26.64     using 23 bins.
#
# Test statistic : Chi-Squared                   26.64     using 23 bins.
#  Null hypothesis probability of 8.60e-02 with 18 degrees of freedom
#  Model Flux 0.0013436 photons (4.434e-12 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
flux = 1.7919*10**-12
d_pc = 387
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')
# Out:
# Luminosity is: 3.220049310677547e+31 erg s^-1

# %%
AllData.clear()
AllModels.clear()
spec = Spectrum("0916811901_PN1grpspec.fits")
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.0001 1")
Plot("data")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0916811901_PN1grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  5.663e-01 +/- 1.149e-02 (79.9 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-90
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 8868 sec
#  Using fit statistic: chi
#  Using Background File                0916811901_PN1spec_bkg.fits
#   Background Exposure Time: 8868 sec
#  Using Response (RMF) File            0916811901_PN1spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0916811901_PN1spec.arf

# %%
spec.ignore("**-0.2 12.0-**")
mo1 = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
#      1 channels (1) ignored in spectrum #     1
#      2 channels (89-90) ignored in spectrum #     1
#
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.040674e+10     using 87 bins.
#
# Test statistic : Chi-Squared              1.040674e+10     using 87 bins.
#  Null hypothesis probability of 0.000000e+00 with 84 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 2466.89      93.572        0      0.315997       1.19371   0.000176525
# 1976.4       566469       -1      0.145648       1.67644   0.000205495
# 1099.17      903338       -2      0.402583       4.33156   0.000955394
# 472.575      237525       -3      0.541392       3.58213    0.00244584
# 351.532      19840        -4      0.358852       3.60678    0.00174779
# 248.574      46613.1      -5      0.495415       4.08688    0.00245403
# 240.47       18694.6      -6      0.532906       4.27692    0.00285941
# 240.023      3836.31      -7      0.537669       4.31413    0.00293333
# 240.016      90.9201      -8      0.539802       4.32673    0.00295347
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  2.7546E-09| -0.0086  -0.0001   1.0000
#  7.0121E-05|  0.9859  -0.1669   0.0084
#  3.1294E-02|  0.1669   0.9860   0.0015
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    9.394e-04   5.137e-03   8.500e-06
#    5.137e-03   3.043e-02   4.669e-05
#    8.500e-06   4.669e-05   7.968e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.539802     +/-  3.06500E-02
#    2    2   powerlaw   PhoIndex            4.32673      +/-  0.174428
#    3    2   powerlaw   norm                2.95347E-03  +/-  2.82284E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  240.02     using 87 bins.
#
# Test statistic : Chi-Squared                  240.02     using 87 bins.
#  Null hypothesis probability of 6.07e-17 with 84 degrees of freedom
#  Model Flux 0.00088998 photons (1.656e-12 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
mo2 = Model("tbabs*(bbody+powerlaw)")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>(bbody<2> + powerlaw<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
#    4    3   powerlaw   PhoIndex            1.00000      +/-  0.0
#    5    3   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.181815e+11     using 87 bins.
#
# Test statistic : Chi-Squared              1.181815e+11     using 87 bins.
#  Null hypothesis probability of 0.000000e+00 with 82 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:n
3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.556511     +/-  6.65553E-02
#    2    2   bbody      kT         keV      0.121605     +/-  1.04816E-02
#    3    2   bbody      norm                2.49283E-04  +/-  1.30459E-04
#    4    3   powerlaw   PhoIndex            2.77397      +/-  0.232969
#    5    3   powerlaw   norm                1.03456E-03  +/-  2.31354E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  141.58     using 87 bins.
#
# Test statistic : Chi-Squared                  141.58     using 87 bins.
#  Null hypothesis probability of 4.89e-05 with 82 degrees of freedom
#  Model Flux 0.00094639 photons (2.1519e-12 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
flux = 2.1519*10**-12
d_pc = 387
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')
# Out:
# Luminosity is: 3.8669703173430505e+31 erg s^-1

# %%
full_psd1 = st.AveragedPowerspectrum(full_lc1,segment_size=2000)
soft_psd1 = st.AveragedPowerspectrum(soft_lc1,segment_size=2000)
hard_psd1 = st.AveragedPowerspectrum(hard_lc1,segment_size=2000)

full_psd2 = st.AveragedPowerspectrum(full_lc2,segment_size=2000)
soft_psd2 = st.AveragedPowerspectrum(soft_lc2,segment_size=2000)
hard_psd2 = st.AveragedPowerspectrum(hard_lc2,segment_size=2000)

full_psd3 = st.AveragedPowerspectrum(full_lc3,segment_size=2000)
soft_psd3 = st.AveragedPowerspectrum(soft_lc3,segment_size=2000)
hard_psd3 = st.AveragedPowerspectrum(hard_lc3,segment_size=2000)

full_psd4 = st.AveragedPowerspectrum(full_lc4,segment_size=2000)
soft_psd4 = st.AveragedPowerspectrum(soft_lc4,segment_size=2000)
hard_psd4 = st.AveragedPowerspectrum(hard_lc4,segment_size=2000)
# Out:
# 6it [00:00, 1162.18it/s]
# 6it [00:00, 1745.81it/s]
# 6it [00:00, 3501.58it/s]
# 1it [00:00, 513.32it/s]
# 1it [00:00, 691.33it/s]
# 1it [00:00, 705.64it/s]
# 3it [00:00, 1492.46it/s]
# 3it [00:00, 1805.81it/s]
# 3it [00:00, 1760.59it/s]
# 4it [00:00, 2501.82it/s]
# 4it [00:00, 2357.68it/s]
# 4it [00:00, 2852.78it/s]

# %%
plt.loglog(full_psd1.freq, full_psd1.power, color='k')
plt.show()
plt.loglog(soft_psd1.freq, soft_psd1.power, color='r')
plt.show()
plt.loglog(hard_psd1.freq, hard_psd1.power, color='b')
plt.show()

# %%
plt.loglog(full_psd2.freq, full_psd2.power, color='k')
plt.show()
plt.loglog(soft_psd2.freq, soft_psd2.power, color='r')
plt.show()
plt.loglog(hard_psd2.freq, hard_psd2.power, color='b')
plt.show()

# %%
plt.loglog(full_psd3.freq, full_psd3.power, color='k')
plt.show()
plt.loglog(soft_psd3.freq, soft_psd3.power, color='r')
plt.show()
plt.loglog(hard_psd3.freq, hard_psd3.power, color='b')
plt.show()

# %%
plt.loglog(full_psd4.freq, full_psd4.power, color='k')
plt.show()
plt.loglog(soft_psd4.freq, soft_psd4.power, color='r')
plt.show()
plt.loglog(hard_psd4.freq, hard_psd4.power, color='b')
plt.show()
