# %% [markdown]
# Obs 0934210301 source 006. Not first X-ray detection. (266.6811, -29.4748, 0.59")
#
# No SIMBAD
#
# Vizier - Gaia 4057256562888695680 6.65"
# + Parallax 0.788. Distance 1270 pc.
# + Teff unknown
# + Rstar unknown
# + Mstar unknown
#
# Vizier - Gaia 4057256558571593216 7.53"
# + Parallax 1.472. Distance 680 pc. (650 pc spec)
# + Teff 4450K
# + Rstar 0.66
# + Mstar 0.72
#
# Vizier - Gaia 4057256562908951168 8.10"
# + Parallax unknown.
# + Teff unknown
# + Rstar unknown
# + Mstar unknown

# %%
# %load_ext wurlitzer
import numpy as np
import os
import stingray as st
import matplotlib.pyplot as plt
from astropy.io import fits
from xspec import *
plt.rcParams['figure.figsize'] = [15, 8]

lc = fits.open('0934210301/0934210301_PN6_dt1.lc')
bkg = fits.open('0934210301/0934210301_PN6_dt1_bkg.lc')
full_gti = []
for j in lc[2].data:
    full_gti.append([j[0],j[1]])
soft = fits.open('0934210301/0934210301_PN6_dt1_0.2-2keV.lc')
sbkg = fits.open('0934210301/0934210301_PN6_dt1_0.2-2keV_bkg.lc')
soft_gti = []
for j in soft[2].data:
    soft_gti.append([j[0],j[1]])
hard = fits.open('0934210301/0934210301_PN6_dt1_2-12keV.lc')
hbkg = fits.open('0934210301/0934210301_PN6_dt1_2-12keV_bkg.lc')
hard_gti = []
for j in hard[2].data:
    hard_gti.append([j[0],j[1]])

# %%
full_lc = st.Lightcurve(lc[1].data.field('TIME'),lc[1].data.field('RATE'),err=lc[1].data.field('ERROR'),gti=full_gti,input_counts=False)
full_bkg = st.Lightcurve(bkg[1].data.field('TIME'),bkg[1].data.field('RATE'),err=bkg[1].data.field('ERROR'),gti=full_gti,input_counts=False)

soft_lc = st.Lightcurve(soft[1].data.field('TIME'),soft[1].data.field('RATE'),err=soft[1].data.field('ERROR'),gti=soft_gti,input_counts=False)
soft_bkg = st.Lightcurve(sbkg[1].data.field('TIME'),sbkg[1].data.field('RATE'),err=sbkg[1].data.field('ERROR'),gti=soft_gti,input_counts=False)

hard_lc = st.Lightcurve(hard[1].data.field('TIME'),hard[1].data.field('RATE'),err=hard[1].data.field('ERROR'),gti=hard_gti,input_counts=False)
hard_bkg = st.Lightcurve(hbkg[1].data.field('TIME'),hbkg[1].data.field('RATE'),err=hbkg[1].data.field('ERROR'),gti=hard_gti,input_counts=False)

full_lc.apply_gtis()
full_bkg.apply_gtis()
soft_lc.apply_gtis()
soft_bkg.apply_gtis()
hard_lc.apply_gtis()
hard_bkg.apply_gtis()
# Out:
# /home/rwebbe/.local/lib/python3.8/site-packages/stingray/lightcurve.py:516: UserWarning: There are non-finite points in the data, but they are outside GTIs.
#   warnings.warn("There are non-finite points in the data, but they are outside GTIs. ")
# /home/rwebbe/.local/lib/python3.8/site-packages/stingray/lightcurve.py:516: UserWarning: There are non-finite points in the data, but they are outside GTIs.
#   warnings.warn("There are non-finite points in the data, but they are outside GTIs. ")

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(soft_lc.time,soft_lc.countrate,color='r')
plt.plot(hard_lc.time,hard_lc.countrate,color='b')

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(full_bkg.time,full_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.time,soft_lc.countrate,color='k')
plt.plot(soft_bkg.time,soft_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.time,hard_lc.countrate,color='k')
plt.plot(hard_bkg.time,hard_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='r')
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='b')

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(full_bkg.rebin(50).time,full_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='k')
plt.plot(soft_bkg.rebin(50).time,soft_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='k')
plt.plot(hard_bkg.rebin(50).time,hard_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='r')
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='b')

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(full_bkg.rebin(250).time,full_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='k')
plt.plot(soft_bkg.rebin(250).time,soft_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='k')
plt.plot(hard_bkg.rebin(250).time,hard_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
os.chdir("0934210301")
spec = Spectrum("0934210301_PN6grpspec.fits")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0934210301_PN6grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  1.068e-02 +/- 2.047e-03 (46.3 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-11
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 7414 sec
#  Using fit statistic: chi
#  Using Background File                0934210301_PN6spec_bkg.fits
#   Background Exposure Time: 7414 sec
#  Using Response (RMF) File            0934210301_PN6spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0934210301_PN6spec.arf

# %%
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot("data")

# %%
spec.ignore("**-0.2 12.0-**")
mo1 = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
#      2 channels (1-2) ignored in spectrum #     1
#      1 channels (11) ignored in spectrum #     1
#
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              8.508476e+11     using 8 bins.
#
# Test statistic : Chi-Squared              8.508476e+11     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 5 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 7.00055      0.229461     -3       3.86833       1.03193   2.50821e-06
# 6.63241      107391       -4       4.21837       1.10796   2.56267e-06
# 6.607        22668.7      -5       3.43544       1.20734   2.42556e-06
# 6.58461      53344.4      -6       4.06595       1.17479   2.57394e-06
# 6.56409      4703.19      -1       3.68695       1.20386   2.51424e-06
# 6.5624       6190.95      -2       3.77311       1.20565   2.53227e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.8068E-13| -0.0000  -0.0000   1.0000
#  6.3937E-02| -0.1047  -0.9945  -0.0000
#  9.6471E+00|  0.9945  -0.1047   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    9.542e+00  -9.980e-01   1.417e-06
#   -9.980e-01   1.690e-01  -9.578e-08
#    1.417e-06  -9.578e-08   4.338e-13
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    3.77311      +/-  3.08902
#    2    2   bbody      kT         keV      1.20565      +/-  0.411114
#    3    2   bbody      norm                2.53227E-06  +/-  6.58626E-07
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    6.56     using 8 bins.
#
# Test statistic : Chi-Squared                    6.56     using 8 bins.
#  Null hypothesis probability of 2.55e-01 with 5 degrees of freedom
#  Model Flux 1.9022e-05 photons (1.4066e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
mo2 = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              2.139927e+11     using 8 bins.
#
# Test statistic : Chi-Squared              2.139927e+11     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 5 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 16.4643      3.23682      -3       4.49807       1.82142   3.16776e-05
# 9.27507      92014.9      -2       7.62710       2.05405   8.94514e-05
# 7.89519      27171.3      -1       4.33783       2.01278   9.83945e-05
# 5.50609      19896.6      -2       6.25597       2.19320   0.000134175
# 5.43923      3040.16      -2       6.61887       2.28086   0.000159872
# 5.41265      1298.52      -2       6.69496       2.34008   0.000176903
# 5.40213      423.992      -2       6.83207       2.38974   0.000192382
# 5.39599      282.767      -2       6.90888       2.42639   0.000204328
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.0359E-09| -0.0000  -0.0003   1.0000
#  3.3589E-01|  0.2737  -0.9618  -0.0003
#  2.2965E+01|  0.9618   0.2737   0.0001
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.127e+01   5.956e+00   1.981e-03
#    5.956e+00   2.031e+00   6.513e-04
#    1.981e-03   6.513e-04   2.112e-07
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    6.90888      +/-  4.61195
#    2    2   powerlaw   PhoIndex            2.42639      +/-  1.42503
#    3    2   powerlaw   norm                2.04328E-04  +/-  4.59604E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    5.40     using 8 bins.
#
# Test statistic : Chi-Squared                    5.40     using 8 bins.
#  Null hypothesis probability of 3.69e-01 with 5 degrees of freedom
#  Model Flux 2.1638e-05 photons (1.7587e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
flux = 1.7587*10**-13
d_pc = 1270
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')

d_pc = 680
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')
# Out:
# Luminosity is: 3.403502142830046e+31 erg s^-1
# Luminosity is: 9.757451738140078e+30 erg s^-1
