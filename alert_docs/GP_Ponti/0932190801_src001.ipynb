# %% [markdown]
# Obs 0932190801 source 001. Not first X-ray detection. (267.6396, -26.8162, 0.25")
#
# SIMBAD: IRAS 17474-2648 possible match (3.78")
# + IR source
# + No parallax.
#
# ALSO XMM
# + 0844101101 src 129
#
# Vizier - Gaia 4066788057368104960 8.26"
# + Parallax 0.9549. Distance 1047 pc.
# + Teff unknown
# + Rstar unknown
# + Mstar unknown

# %%
# %load_ext wurlitzer
import numpy as np
import os
import stingray as st
import matplotlib.pyplot as plt
from astropy.io import fits
from xspec import *
plt.rcParams['figure.figsize'] = [15, 8]

lc = fits.open('0932190801_001/0932190801_PN1_dt1.lc')
bkg = fits.open('0932190801_001/0932190801_PN1_dt1_bkg.lc')
full_gti = []
for j in lc[2].data:
    full_gti.append([j[0],j[1]])
soft = fits.open('0932190801_001/0932190801_PN1_dt1_0.2-2keV.lc')
sbkg = fits.open('0932190801_001/0932190801_PN1_dt1_0.2-2keV_bkg.lc')
soft_gti = []
for j in soft[2].data:
    soft_gti.append([j[0],j[1]])
hard = fits.open('0932190801_001/0932190801_PN1_dt1_2-12keV.lc')
hbkg = fits.open('0932190801_001/0932190801_PN1_dt1_2-12keV_bkg.lc')
hard_gti = []
for j in hard[2].data:
    hard_gti.append([j[0],j[1]])

# %%
full_lc = st.Lightcurve(lc[1].data.field('TIME'),lc[1].data.field('RATE'),err=lc[1].data.field('ERROR'),gti=full_gti,input_counts=False)
full_bkg = st.Lightcurve(bkg[1].data.field('TIME'),bkg[1].data.field('RATE'),err=bkg[1].data.field('ERROR'),gti=full_gti,input_counts=False)

soft_lc = st.Lightcurve(soft[1].data.field('TIME'),soft[1].data.field('RATE'),err=soft[1].data.field('ERROR'),gti=soft_gti,input_counts=False)
soft_bkg = st.Lightcurve(sbkg[1].data.field('TIME'),sbkg[1].data.field('RATE'),err=sbkg[1].data.field('ERROR'),gti=soft_gti,input_counts=False)

hard_lc = st.Lightcurve(hard[1].data.field('TIME'),hard[1].data.field('RATE'),err=hard[1].data.field('ERROR'),gti=hard_gti,input_counts=False)
hard_bkg = st.Lightcurve(hbkg[1].data.field('TIME'),hbkg[1].data.field('RATE'),err=hbkg[1].data.field('ERROR'),gti=hard_gti,input_counts=False)

full_lc.apply_gtis()
full_bkg.apply_gtis()
soft_lc.apply_gtis()
soft_bkg.apply_gtis()
hard_lc.apply_gtis()
hard_bkg.apply_gtis()
# Out:
# /home/rwebbe/.local/lib/python3.8/site-packages/stingray/lightcurve.py:516: UserWarning: There are non-finite points in the data, but they are outside GTIs.
#   warnings.warn("There are non-finite points in the data, but they are outside GTIs. ")
# /home/rwebbe/.local/lib/python3.8/site-packages/stingray/lightcurve.py:516: UserWarning: There are non-finite points in the data, but they are outside GTIs.
#   warnings.warn("There are non-finite points in the data, but they are outside GTIs. ")

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(soft_lc.time,soft_lc.countrate,color='r')
plt.plot(hard_lc.time,hard_lc.countrate,color='b')

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(full_bkg.time,full_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.time,soft_lc.countrate,color='k')
plt.plot(soft_bkg.time,soft_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.time,hard_lc.countrate,color='k')
plt.plot(hard_bkg.time,hard_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='r')
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='b')

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(full_bkg.rebin(50).time,full_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='k')
plt.plot(soft_bkg.rebin(50).time,soft_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='k')
plt.plot(hard_bkg.rebin(50).time,hard_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='r')
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='b')

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(full_bkg.rebin(250).time,full_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='k')
plt.plot(soft_bkg.rebin(250).time,soft_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='k')
plt.plot(hard_bkg.rebin(250).time,hard_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
os.chdir("0932190801_001")
spec = Spectrum("0932190801_PN1grpspec.fits")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0932190801_PN1grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  1.002e-01 +/- 3.837e-03 (85.4 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-58
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 8721 sec
#  Using fit statistic: chi
#  Using Background File                0932190801_PN1spec_bkg.fits
#   Background Exposure Time: 8721 sec
#  Using Response (RMF) File            0932190801_PN1spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0932190801_PN1spec.arf

# %%
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.001 0.5")
Plot("data")

# %%
spec.ignore("**-0.2 12.0-**")
mo1 = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
#      3 channels (1-3) ignored in spectrum #     1
#      1 channels (58) ignored in spectrum #     1
#
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              1.310633e+11     using 54 bins.
#
# Test statistic : Chi-Squared              1.310633e+11     using 54 bins.
#  Null hypothesis probability of 0.000000e+00 with 51 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 302.689      21.9414      -3       3.35374       5.68879   0.000171583
# 109.465      257779       -4       15.7219       1.80376   7.04342e-05
# 81.6247      473734       -5       15.2710       2.03289   9.47040e-05
# 81.1057      60539.9      -6       15.2942       2.02126   9.70623e-05
# 81.1057      239.746      -7       15.3001       2.02059   9.70405e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.5422E-11| -0.0000  -0.0000   1.0000
#  1.9185E-02| -0.0706  -0.9975  -0.0000
#  4.8458E+00|  0.9975  -0.0706   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    4.822e+00  -3.398e-01   1.396e-06
#   -3.398e-01   4.323e-02   8.385e-07
#    1.396e-06   8.385e-07   6.135e-11
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    15.3001      +/-  2.19584
#    2    2   bbody      kT         keV      2.02059      +/-  0.207919
#    3    2   bbody      norm                9.70405E-05  +/-  7.83256E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   81.11     using 54 bins.
#
# Test statistic : Chi-Squared                   81.11     using 54 bins.
#  Null hypothesis probability of 4.63e-03 with 51 degrees of freedom
#  Model Flux 0.00036996 photons (4.0901e-12 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
mo2 = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              8.380114e+10     using 54 bins.
#
# Test statistic : Chi-Squared              8.380114e+10     using 54 bins.
#  Null hypothesis probability of 0.000000e+00 with 51 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 438.298      21.6326      -2      0.479912      -1.06126   2.06199e-06
# 388.669      1.60838e+07  -2       7.48052     -0.436039   9.42497e-06
# 257.295      4.30725
# e+06  -1       3.69632     -0.664671   2.21787e-05
# 137.869      4.51641e+06  -2       7.38911     -0.218261   3.72393e-05
# 125.437      551020       -1       8.86130     -0.190946   4.58244e-05
# 121.655      145921       -1       9.12321     -0.128834   5.24498e-05
# 118.408      91066.9      -1       9.53678    -0.0695743   5.94970e-05
# 115.448      74591.9      -1       9.91039    -0.0126273   6.70593e-05
# 112.743      61828.3      -1       10.2745     0.0417853   7.51647e-05
# 110.268      51842.1      -1       10.6261     0.0938347   8.38149e-05
# Number of trials exceeded: continue fitting? 107.999      43747.7      -1       10.9658      0.143658   9.30087e-05
# 105.917      37143.8      -1       11.2939      0.191386   0.000102743
# 104.003      31717.9      -1       11.6109      0.237140   0.000113011
# 102.242      27231.5      -1       11.9170      0.281028   0.000123807
# 100.621      23499.7      -1       12.2127      0.323156   0.000135121
# 99.1251      20377.9      -1       12.4983      0.363616   0.000146941
# 97.7445      17752.4      -1       12.7742      0.402497   0.000159257
# 96.4688      15532.7      -1       13.0407      0.439882   0.000172054
# 95.2887      13647.2      -1       13.2983      0.475847   0.000185317
# 94.1962      12037.9      -1       13.5472      0.510462   0.000199030
# Number of trials exceeded: continue fitting? 93.1836      10658.4      -1       13.7879      0.543795   0.000213178
# 92.2445      9470.84      -1       14.0205      0.575908   0.000227741
# 92.1099      8444.35      -2       15.9146      0.821193   0.000342524
# 86.8381      52639.4      -2       17.1866      0.999301   0.000500733
# 82.6376      29725.9      -2       18.1708       1.12975   0.000673594
# 80.646       13928.9      -2       18.9326       1.23066   0.000842414
# 79.6817      6695.2       -2       19.5382       1.31045    0.00100006
# 79.1618      3468.4       -2       20.0217       1.37405    0.00114337
# 78.8601      1917.53      -2       20.4094       1.42496    0.00127091
# 78.6772      1114.8       -2       20.7213       1.46585    0.00138246
# Number of trials exceeded: continue fitting? 78.5634      674.232      -2       20.9726       1.49877    0.00147864
# 78.4913      421.214      -2       21.1754       1.52532    0.00156063
# 78.4634      270.512      -3       21.8300       1.60653    0.00181825
# 78.3635      1371.27      -4       22.0474       1.63776    0.00195249
# 78.3596      262.231      -5       22.0371       1.63798    0.00195736
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  6.2451E-09| -0.0001  -0.0033   1.0000
#  2.7109E-02|  0.0933  -0.9956  -0.0033
#  9.1133E+00|  0.9956   0.0933   0.0004
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    9.034e+00   8.444e-01   3.474e-03
#    8.444e-01   1.063e-01   4.152e-04
#    3.474e-03   4.152e-04   1.642e-06
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    22.0371      +/-  3.00569
#    2    2   powerlaw   PhoIndex            1.63798      +/-  0.325984
#    3    2   powerlaw   norm                1.95736E-03  +/-  1.28126E-03
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   78.36     using 54 bins.
#
# Test statistic : Chi-Squared                   78.36     using 54 bins.
#  Null hypothesis probability of 8.21e-03 with 51 degrees of freedom
#  Model Flux 0.00039289 photons (4.4938e-12 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
mo3 = Model("tbabs*(bbody + powerlaw)")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>(bbody<2> + powerlaw<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
#    4    3   powerlaw   PhoIndex            1.00000      +/-  0.0
#    5    3   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              3.961023e+11     using 54 bins.
#
# Test statistic : Chi-Squared              3.961023e+11     using 54 bins.
#  Null hypothesis probability of 0.000000e+00 with 49 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm    4:PhoIndex        5:norm
# 294.929      444864       -1       2.27335       2.95456   6.94947e-05      0.686096   1.06474e-05
# 187.246      422581       -2       4.35962       3.23951   0.000126875     -0.178031   3.87960e-06
# 132.322      767210       -2       8.24255       2.92975   0.000147612      0.647315   5.31204e-07
# 92.5534      279383       -3       13.7581       2.17104   8.56822e-05       8.59473   6.48141e-05
# 83.8074      164189       -1       12.9636       2.07948   9.29488e-05       9.33881   2.93878e-05
# 82.615       29221.7      -1       13.5886       2.08432   9.45790e-05       9.43318     0.0455871
# 82.5164      13845.6      -1       13.6982       2.08325   9.51313e-05       9.49984     0.0558025
# 82.5055      16336        -1       13.7413       2.08283   9.53009e-05       9.49995     0.0626527
# 82.5036      16751.1      -1       13.7481       2.08270   9.53403e-05       9.50000     0.0632789
# ============================================================
#  Variances and Principal Axes
#                  1        2        3        4        5
#  1.4549E-11|  0.0000   0.0001  -1.0000   0.0000  -0.0000
#  2.0098E-02|  0.0842   0.9886   0.0001   0.0080  -0.1250
#  1.4576E-01|  0.1336  -0.1357  -0.0000   0.0514  -0.9804
#  6.9265E+00|  0.9866  -0.0659   0.0000   0.0340   0.1453
#  7.1118E+03| -0.0412   0.0013  -0.0000   0.9981   0.0465
# ------------------------------------------------------------
#
# ============================================================
#   Covariance Matrix
#         1           2           3           4           5
#    1.880e+01  -8.394e-01   1.641e-05  -2.920e+02  -1.265e+01
#   -8.394e-01   6.490e-02   5.123e-07   9.391e+00   3.890e-01
#    1.641e-05   5.123e-07   8.748e-11  -3.628e-04  -1.618e-05
#   -2.920e+02   9.391e+00  -3.628e-04   7.084e+03   3.302e+02
#   -1.265e+01   3.890e-01  -1.618e-05   3.302e+02   1.567e+01
# ------------------------------------------------------------
#
# ========================================================================
# Model TBabs<1>(bbody<2> + powerlaw<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    13.7481      +/-  4.33596
#    2    2   bbody      kT         keV      2.08270      +/-  0.254761
#    3    2   bbody      norm                9.53403E-05  +/-  9.35310E-06
#    4    3   powerlaw   PhoIndex            9.50000      +/-  84.1683
#    5    3   powerlaw   norm                6.32789E-02  +/-  3.95894
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   82.50     using 54 bins.
#
# Test statistic : Chi-Squared                   82.50     using 54 bins.
#  Null hypothesis probability of 1.94e-03 with 49 degrees of freedom
#  Model Flux 0.00037666 photons (4.1576e-12 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
flux = 5.7793*10**-12
d_pc = 1047
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')
# Out:
# Luminosity is: 7.601432182929831e+32 erg s^-1

# %%
d_pc = 7500
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')
# Out:
# Luminosity is: 3.9005386772942304e+34 erg s^-1

# %%
g_mag = 20.126572
opt_flux = (10**(0.4*(-26.7 - g_mag))) * (3.828 * 10 ** 33) / (4*np.pi*(1.496*10**13)**2)
print('Optical flux: '+str(opt_flux))
opt_x_ratio = flux / opt_flux
print('The x-ray/optical flux ratio is: '+str(opt_x_ratio))
# Out:
# Optical flux: 2.5308713994868074e-13
# The x-ray/optical flux ratio is: 22.835217945771113
