# %% [markdown]
# Obs 0916811901 source 001. Not first X-ray detection. (262.627, -34.539, 0.14")
#
# SIMBAD: V* V1017 Sco
# + RS CVn Variable
# + Parallax 2.5845 mas. 387 pc.
#
# ALSO XMM
# + 0916811501 src 1
# + 0916810801 src 1
#
#
# Vizier - Gaia 5975889887888213248 2.2"
# + Parallax 2.585. Distance 387 pc.
# + Teff 4896K (DR2)
# + Rstar 14.91 (DR2)
# + Mstar unknown

# %%
# %load_ext wurlitzer
import numpy as np
import os
import stingray as st
import matplotlib.pyplot as plt
from astropy.io import fits
from xspec import *
plt.rcParams['figure.figsize'] = [15, 8]

lc = fits.open('0916811901_001/0916811901_PN1_dt1.lc')
bkg = fits.open('0916811901_001/0916811901_PN1_dt1_bkg.lc')
full_gti = []
for j in lc[2].data:
    full_gti.append([j[0],j[1]])
soft = fits.open('0916811901_001/0916811901_PN1_dt1_0.2-2keV.lc')
sbkg = fits.open('0916811901_001/0916811901_PN1_dt1_0.2-2keV_bkg.lc')
soft_gti = []
for j in soft[2].data:
    soft_gti.append([j[0],j[1]])
hard = fits.open('0916811901_001/0916811901_PN1_dt1_2-12keV.lc')
hbkg = fits.open('0916811901_001/0916811901_PN1_dt1_2-12keV_bkg.lc')
hard_gti = []
for j in hard[2].data:
    hard_gti.append([j[0],j[1]])

# %%
full_lc = st.Lightcurve(lc[1].data.field('TIME'),lc[1].data.field('RATE'),err=lc[1].data.field('ERROR'),gti=full_gti,input_counts=False)
full_bkg = st.Lightcurve(bkg[1].data.field('TIME'),bkg[1].data.field('RATE'),err=bkg[1].data.field('ERROR'),gti=full_gti,input_counts=False)

soft_lc = st.Lightcurve(soft[1].data.field('TIME'),soft[1].data.field('RATE'),err=soft[1].data.field('ERROR'),gti=soft_gti,input_counts=False)
soft_bkg = st.Lightcurve(sbkg[1].data.field('TIME'),sbkg[1].data.field('RATE'),err=sbkg[1].data.field('ERROR'),gti=soft_gti,input_counts=False)

hard_lc = st.Lightcurve(hard[1].data.field('TIME'),hard[1].data.field('RATE'),err=hard[1].data.field('ERROR'),gti=hard_gti,input_counts=False)
hard_bkg = st.Lightcurve(hbkg[1].data.field('TIME'),hbkg[1].data.field('RATE'),err=hbkg[1].data.field('ERROR'),gti=hard_gti,input_counts=False)

full_lc.apply_gtis()
full_bkg.apply_gtis()
soft_lc.apply_gtis()
soft_bkg.apply_gtis()
hard_lc.apply_gtis()
hard_bkg.apply_gtis()
# Out:
# /home/rwebbe/.local/lib/python3.8/site-packages/stingray/lightcurve.py:516: UserWarning: There are non-finite points in the data, but they are outside GTIs.
#   warnings.warn("There are non-finite points in the data, but they are outside GTIs. ")
# /home/rwebbe/.local/lib/python3.8/site-packages/stingray/lightcurve.py:516: UserWarning: There are non-finite points in the data, but they are outside GTIs.
#   warnings.warn("There are non-finite points in the data, but they are outside GTIs. ")

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(soft_lc.time,soft_lc.countrate,color='r')
plt.plot(hard_lc.time,hard_lc.countrate,color='b')

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(full_bkg.time,full_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.time,soft_lc.countrate,color='k')
plt.plot(soft_bkg.time,soft_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.time,hard_lc.countrate,color='k')
plt.plot(hard_bkg.time,hard_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='r')
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='b')

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(full_bkg.rebin(50).time,full_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='k')
plt.plot(soft_bkg.rebin(50).time,soft_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='k')
plt.plot(hard_bkg.rebin(50).time,hard_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='r')
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='b')

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(full_bkg.rebin(250).time,full_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='k')
plt.plot(soft_bkg.rebin(250).time,soft_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='k')
plt.plot(hard_bkg.rebin(250).time,hard_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
os.chdir("0916811901_001")
spec = Spectrum("0916811901_PN1grpspec.fits")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0916811901_PN1grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  5.657e-01 +/- 9.429e-03 (79.8 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-142
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 8868 sec
#  Using fit statistic: chi
#  Using Background File                0916811901_PN1spec_bkg.fits
#   Background Exposure Time: 8868 sec
#  Using Response (RMF) File            0916811901_PN1spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0916811901_PN1spec.arf

# %%
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.0001 0.8")
Plot("data")

# %%
spec.ignore("**-0.2 12.0-**")
mo1 = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
#      2 channels (1-2) ignored in spectrum #     1
#      3 channels (140-142) ignored in spectrum #     1
#
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              1.370375e+11     using 137 bins.
#
# Test statistic : Chi-Squared              1.370375e+11     using 137 bins.
#  Null hypothesis probability of 0.000000e+00 with 134 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 4088.64      7.27602       0     0.0826538       2.98127   2.17467e-05
# 4071.4       429545        0     0.0242929       2.89997   2.19337e-05
# 4056.99      482609        0    0.00217447       2.80992   2.21978e-05
# 4045.8       491552        0   2.45732e-05       2.71985   2.24527e-05
# 4035.33      464652        0   9.75261e-06       2.63624   2.26289e-05
# 4024.99      432753        0   3.03774e-06       2.55823   2.27319e-05
# 4014.59      400889        0   1.50614e-06       2.48442   2.27745e-05
# 4003.94      369567        0   1.01799e-07       2.41372   2.27671e-05
# 3992.85      339156        0   2.10441e-08       2.34528   2.27183e-05
# 3981.14      309923        0   2.42916e-09       2.27839   2.26350e-05
# Number of trials exceeded: continue fitting? 3968.57      282108        0   2.81434e-10       2.21247   2.25234e-05
# 3954.92      255960        0   3.36283e-11       2.14701   2.23885e-05
# 3939.9       231793        0   5.06198e-12       2.08159   2.22350e-05
# 3933.85      210031        0   4.45139e-13       1.95759   1.60222e-05
# 3899.88      1.35441e+06  -1   1.22479e-13       1.41911   6.91464e-06
# 3661.5       6.2029e+06   -2   4.47548e-14      0.518285   2.08320e-06
# 2718.51      4.22714e+07   0   2.16584e-14      0.243250   3.72616e-06
# 1600.63      5.49913e+07   0   9.55184e-15      0.331971   8.17057e-06
# 506.049      3.72064e+07  -1     0.0653145      0.307324   1.85134e-05
# 377.506      9.4329e+06   -2      0.122837      0.267519   2.49830e-05
# Number of trials exceeded: continue fitting? 359.717      2.84955e+06  -3      0.151830      0.256249   2.90037e-05
# 358.855      551045       -4      0.156831      0.253466   2.99123e-05
# 358.823      26888.9      -5      0.158621      0.252505   3.01329e-05
# 358.819      2307.17      -6      0.159242      0.252164   3.02059e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  2.3531E-13| -0.0001   0.0000   1.0000
#  8.0477E-06| -0.3678  -0.9299  -0.0000
#  2.5749E-04|  0.9299  -0.3678   0.0001
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.237e-04  -8.531e-05   2.437e-08
#   -8.531e-05   4.179e-05  -9.621e-09
#    2.437e-08  -9.621e-09   2.901e-12
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.159242     +/-  1.49580E-02
#    2    2   bbody      kT         keV      0.252164     +/-  6.46458E-03
#    3    2   bbody      norm                3.02059E-05  +/-  1.70327E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  358.82     using 137 bins.
#
# Test statistic : Chi-Squared                  358.82     using 137 bins.
#  Null hypothesis probability of 1.99e-22 with 134 degrees of freedom
#  Model Flux 0.00084661 photons (1.3859e-12 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
mo2 = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              2.102809e+10     using 137 bins.
#
# Test statistic : Chi-Squared              2.102809e+10     using 137 bins.
#  Null hypothesis probability of 0.000000e+00 with 134 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 3617.99      88.7099       0      0.476965       1.22083   0.000110639
# 3224.97      636221        0      0.236335       1.46976   0.000132422
# 2042.66      1.0153e+06    0     0.0998819       1.75043   0.000238560
# 972.6        1.06486e+06  -1      0.189527       2.74315   0.000614433
# 647.009      348484       -2      0.402287       3.51265    0.00135829
# 415.936      185578       -3      0.546321       4.38399    0.00251076
# 320.698      68161.5      -4      0.569755       4.52798    0.00315956
# 320.019      5293.38      -5      0.572445       4.54526    0.00322776
# 320.017      56.2841      -6      0.573134       4.54953    0.00323512
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  2.6733E-09| -0.0097  -0.0001   1.0000
#  5.3475E-05|  0.9859  -0.1670   0.0095
#  2.4454E-02|  0.1670   0.9860   0.0017
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    7.337e-04   4.017e-03   7.323e-06
#    4.017e-03   2.377e-02   4.020e-05
#    7.323e-06   4.020e-05   7.577e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.573134     +/-  2.70871E-02
#    2    2   powerlaw   PhoIndex            4.54953      +/-  0.154187
#    3    2   powerlaw   norm                3.23512E-03  +/-  2.75267E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  320.02     using 137 bins.
#
# Test statistic : Chi-Squared                  320.02     using 137 bins.
#  Null hypothesis probability of 2.98e-17 with 134 degrees of freedom
#  Model Flux 0.00087155 photons (1.5851e-12 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
flux = 1.656*10**-12
d_pc = 387
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')
# Out:
# Luminosity is: 2.9758366306613186e+31 erg s^-1

# %%
g_mag = 7.601333
opt_flux = (10**(0.4*(-26.7 - g_mag))) * (3.828 * 10 ** 33) / (4*np.pi*(1.496*10**13)**2)
print('Optical flux: '+str(opt_flux))
opt_x_ratio = flux / opt_flux
print('The x-ray/optical flux ratio is: '+str(opt_x_ratio))
# Out:
# Optical flux: 2.590393120519121e-08
# The x-ray/optical flux ratio is: 6.392852061266027e-05
