# %% [markdown]
# Obs 0916811401 source 003. Not first X-ray detection. (262.554, -34.5944, 0.62")
#
# No SIMBAD
#
# ALSO XMM
# + 0916811501 src 8
#
# Vizier - Gaia 5975866351469811456 7.3"
# + Parallax -0.4226. Distance 2370 pc.
# + Teff unknown
# + Rstar unknown
# + Mstar unknown

# %%
# %load_ext wurlitzer
import numpy as np
import os
import stingray as st
import matplotlib.pyplot as plt
from astropy.io import fits
from xspec import *
plt.rcParams['figure.figsize'] = [15, 8]

lc = fits.open('0916811401_003/0916811401_PN3_dt1.lc')
bkg = fits.open('0916811401_003/0916811401_PN3_dt1_bkg.lc')
full_gti = []
for j in lc[2].data:
    full_gti.append([j[0],j[1]])
soft = fits.open('0916811401_003/0916811401_PN3_dt1_0.2-2keV.lc')
sbkg = fits.open('0916811401_003/0916811401_PN3_dt1_0.2-2keV_bkg.lc')
soft_gti = []
for j in soft[2].data:
    soft_gti.append([j[0],j[1]])
hard = fits.open('0916811401_003/0916811401_PN3_dt1_2-12keV.lc')
hbkg = fits.open('0916811401_003/0916811401_PN3_dt1_2-12keV_bkg.lc')
hard_gti = []
for j in hard[2].data:
    hard_gti.append([j[0],j[1]])

# %%
full_lc = st.Lightcurve(lc[1].data.field('TIME'),lc[1].data.field('RATE'),err=lc[1].data.field('ERROR'),gti=full_gti,input_counts=False)
full_bkg = st.Lightcurve(bkg[1].data.field('TIME'),bkg[1].data.field('RATE'),err=bkg[1].data.field('ERROR'),gti=full_gti,input_counts=False)

soft_lc = st.Lightcurve(soft[1].data.field('TIME'),soft[1].data.field('RATE'),err=soft[1].data.field('ERROR'),gti=soft_gti,input_counts=False)
soft_bkg = st.Lightcurve(sbkg[1].data.field('TIME'),sbkg[1].data.field('RATE'),err=sbkg[1].data.field('ERROR'),gti=soft_gti,input_counts=False)

hard_lc = st.Lightcurve(hard[1].data.field('TIME'),hard[1].data.field('RATE'),err=hard[1].data.field('ERROR'),gti=hard_gti,input_counts=False)
hard_bkg = st.Lightcurve(hbkg[1].data.field('TIME'),hbkg[1].data.field('RATE'),err=hbkg[1].data.field('ERROR'),gti=hard_gti,input_counts=False)

full_lc.apply_gtis()
full_bkg.apply_gtis()
soft_lc.apply_gtis()
soft_bkg.apply_gtis()
hard_lc.apply_gtis()
hard_bkg.apply_gtis()
# Out:
# /home/rwebbe/.local/lib/python3.8/site-packages/stingray/lightcurve.py:516: UserWarning: There are non-finite points in the data, but they are outside GTIs.
#   warnings.warn("There are non-finite points in the data, but they are outside GTIs. ")
# /home/rwebbe/.local/lib/python3.8/site-packages/stingray/lightcurve.py:516: UserWarning: There are non-finite points in the data, but they are outside GTIs.
#   warnings.warn("There are non-finite points in the data, but they are outside GTIs. ")

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(soft_lc.time,soft_lc.countrate,color='r')
plt.plot(hard_lc.time,hard_lc.countrate,color='b')

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(full_bkg.time,full_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.time,soft_lc.countrate,color='k')
plt.plot(soft_bkg.time,soft_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.time,hard_lc.countrate,color='k')
plt.plot(hard_bkg.time,hard_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='r')
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='b')

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(full_bkg.rebin(50).time,full_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='k')
plt.plot(soft_bkg.rebin(50).time,soft_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='k')
plt.plot(hard_bkg.rebin(50).time,hard_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='r')
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='b')

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(full_bkg.rebin(250).time,full_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='k')
plt.plot(soft_bkg.rebin(250).time,soft_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='k')
plt.plot(hard_bkg.rebin(250).time,hard_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
os.chdir("0916811401_003")
spec = Spectrum("0916811401_PN3grpspec.fits")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0916811401_PN3grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  1.939e-02 +/- 2.416e-03 (65.3 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-13
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 6871 sec
#  Using fit statistic: chi
#  Using Background File                0916811401_PN3spec_bkg.fits
#   Background Exposure Time: 6871 sec
#  Using Response (RMF) File            0916811401_PN3spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0916811401_PN3spec.arf

# %%
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.0001 0.01")
Plot("data")

# %%
spec.ignore("**-0.2 12.0-**")
mo1 = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
#      1 channels (1) ignored in spectrum #     1
#      1 channels (13) ignored in spectrum #     1
#
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              3.006824e+11     using 11 bins.
#
# Test statistic : Chi-Squared              3.006824e+11     using 11 bins.
#  Null hypothesis probability of 0.000000e+00 with 8 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 9.75581      0.474806     -3       1.59980       2.66711   1.44090e-05
# 9.63397      7660.69      -4       1.93415       2.53106   1.35756e-05
# 9.62037      1240.09      -5       2.06431       2.48221   1.32783e-05
# 9.61906      277.531      -6       2.10742       2.46510   1.31707e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  2.0242E-12| -0.0000  -0.0000   1.0000
#  2.8343E-01| -0.4838  -0.8752  -0.0000
#  2.3727E+00|  0.8752  -0.4838  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.884e+00  -8.846e-01  -6.040e-06
#   -8.846e-01   7.724e-01   6.145e-06
#   -6.040e-06   6.145e-06   5.205e-11
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    2.10742      +/-  1.37252
#    2    2   bbody      kT         keV      2.46510      +/-  0.878846
#    3    2   bbody      norm                1.31707E-05  +/-  7.21462E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    9.62     using 11 bins.
#
# Test statistic : Chi-Squared                    9.62     using 11 bins.
#  Null hypothesis probability of 2.93e-01 with 8 degrees of freedom
#  Model Flux 7.288e-05 photons (7.3586e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
mo2 = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.212526e+11     using 11 bins.
#
# Test statistic : Chi-Squared              1.212526e+11     using 11 bins.
#  Null hypothesis probability of 0.000000e+00 with 8 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 15.2926      7.94418      -1       1.81359      0.248856   1.69220e-05
# 10.398       398937       -2       2.40130      0.239962   1.52755e-05
# 10.0754      27994.1      -3       3.01030      0.341007   1.82795e-05
# 10.0126      24769.5      -4       3.48826      0.459060   2.25936e-05
# 9.94778      29237.9      -5       3.75618      0.519246   2.56936e-05
# 9.93624      9184.25      -6       3.89950      0.551062   2.74425e-05
# 9.93418      2269.38      -7       3.97657      0.568070   2.83781e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  8.7128E-12| -0.0000  -0.0000   1.0000
#  1.0011E-01|  0.2488  -0.9686  -0.0000
#  6.0489E+00|  0.9686   0.2488   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    5.681e+00   1.433e+00   7.206e-05
#    1.433e+00   4.683e-01   2.262e-05
#    7.206e-05   2.262e-05   1.107e-09
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    3.97657      +/-  2.38343
#    2    2   powerlaw   PhoIndex            0.568070     +/-  0.684291
#    3    2   powerlaw   norm                2.83781E-05  +/-  3.32745E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    9.93     using 11 bins.
#
# Test statistic : Chi-Squared                    9.93     using 11 bins.
#  Null hypothesis probability of 2.70e-01 with 8 degrees of freedom
#  Model Flux 8.2534e-05 photons (8.9716e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
flux = 8.9716*10**-13
d_pc = 2370
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')
# Out:
# Luminosity is: 6.046351864825313e+32 erg s^-1

# %%
d_pc = 7500
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')
# Out:
# Luminosity is: 6.055071167306235e+33 erg s^-1

# %%
g_mag = 20.073559
opt_flux = (10**(0.4*(-26.7 - g_mag))) * (3.828 * 10 ** 33) / (4*np.pi*(1.496*10**13)**2)
print('Optical flux: '+str(opt_flux))
opt_x_ratio = flux / opt_flux
print('The x-ray/optical flux ratio is: '+str(opt_x_ratio))
# Out:
# Optical flux: 2.657512267826428e-13
# The x-ray/optical flux ratio is: 3.375939260418861
