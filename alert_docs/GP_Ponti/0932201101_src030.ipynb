# %% [markdown]
# Obs 0932201101 source 030. Not first X-ray detection. (270.0506, -24.0665, 0.48")
#
# No SIMBAD
#
# Vizier - Gaia 4069035905818681600 11.0"
# + Parallax unknown..
# + Teff unknown
# + Rstar unknown
# + Mstar unknown

# %%
# %load_ext wurlitzer
import numpy as np
import os
import stingray as st
import matplotlib.pyplot as plt
from astropy.io import fits
from xspec import *
plt.rcParams['figure.figsize'] = [15, 8]

lc = fits.open('0932201101/0932201101_PN30_dt1.lc')
bkg = fits.open('0932201101/0932201101_PN30_dt1_bkg.lc')
full_gti = []
for j in lc[2].data:
    full_gti.append([j[0],j[1]])
soft = fits.open('0932201101/0932201101_PN30_dt1_0.2-2keV.lc')
sbkg = fits.open('0932201101/0932201101_PN30_dt1_0.2-2keV_bkg.lc')
soft_gti = []
for j in soft[2].data:
    soft_gti.append([j[0],j[1]])
hard = fits.open('0932201101/0932201101_PN30_dt1_2-12keV.lc')
hbkg = fits.open('0932201101/0932201101_PN30_dt1_2-12keV_bkg.lc')
hard_gti = []
for j in hard[2].data:
    hard_gti.append([j[0],j[1]])

# %%
full_lc = st.Lightcurve(lc[1].data.field('TIME'),lc[1].data.field('RATE'),err=lc[1].data.field('ERROR'),gti=full_gti,input_counts=False)
full_bkg = st.Lightcurve(bkg[1].data.field('TIME'),bkg[1].data.field('RATE'),err=bkg[1].data.field('ERROR'),gti=full_gti,input_counts=False)

soft_lc = st.Lightcurve(soft[1].data.field('TIME'),soft[1].data.field('RATE'),err=soft[1].data.field('ERROR'),gti=soft_gti,input_counts=False)
soft_bkg = st.Lightcurve(sbkg[1].data.field('TIME'),sbkg[1].data.field('RATE'),err=sbkg[1].data.field('ERROR'),gti=soft_gti,input_counts=False)

hard_lc = st.Lightcurve(hard[1].data.field('TIME'),hard[1].data.field('RATE'),err=hard[1].data.field('ERROR'),gti=hard_gti,input_counts=False)
hard_bkg = st.Lightcurve(hbkg[1].data.field('TIME'),hbkg[1].data.field('RATE'),err=hbkg[1].data.field('ERROR'),gti=hard_gti,input_counts=False)

full_lc.apply_gtis()
full_bkg.apply_gtis()
soft_lc.apply_gtis()
soft_bkg.apply_gtis()
hard_lc.apply_gtis()
hard_bkg.apply_gtis()
# Out:
# /home/rwebbe/.local/lib/python3.8/site-packages/stingray/lightcurve.py:516: UserWarning: There are non-finite points in the data, but they are outside GTIs.
#   warnings.warn("There are non-finite points in the data, but they are outside GTIs. ")
# /home/rwebbe/.local/lib/python3.8/site-packages/stingray/lightcurve.py:516: UserWarning: There are non-finite points in the data, but they are outside GTIs.
#   warnings.warn("There are non-finite points in the data, but they are outside GTIs. ")

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(soft_lc.time,soft_lc.countrate,color='r')
plt.plot(hard_lc.time,hard_lc.countrate,color='b')

# %%
plt.plot(full_lc.time,full_lc.countrate,color='k')
plt.plot(full_bkg.time,full_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.time,soft_lc.countrate,color='k')
plt.plot(soft_bkg.time,soft_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.time,hard_lc.countrate,color='k')
plt.plot(hard_bkg.time,hard_bkg.countrate,color='r')
plt.show()

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='r')
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='b')

# %%
plt.plot(full_lc.rebin(50).time,full_lc.rebin(50).countrate,color='k')
plt.plot(full_bkg.rebin(50).time,full_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.rebin(50).time,soft_lc.rebin(50).countrate,color='k')
plt.plot(soft_bkg.rebin(50).time,soft_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.rebin(50).time,hard_lc.rebin(50).countrate,color='k')
plt.plot(hard_bkg.rebin(50).time,hard_bkg.rebin(50).countrate,color='r')
plt.show()

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='r')
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='b')

# %%
plt.plot(full_lc.rebin(250).time,full_lc.rebin(250).countrate,color='k')
plt.plot(full_bkg.rebin(250).time,full_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
plt.plot(soft_lc.rebin(250).time,soft_lc.rebin(250).countrate,color='k')
plt.plot(soft_bkg.rebin(250).time,soft_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
plt.plot(hard_lc.rebin(250).time,hard_lc.rebin(250).countrate,color='k')
plt.plot(hard_bkg.rebin(250).time,hard_bkg.rebin(250).countrate,color='r')
plt.show()

# %%
os.chdir("0932201101")
spec = Spectrum("0932201101_PN30grpspec.fits")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0932201101_PN30grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  2.542e-02 +/- 2.274e-03 (79.4 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-9
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 7437 sec
#  Using fit statistic: chi
#  Using Background File                0932201101_PN30spec_bkg.fits
#   Background Exposure Time: 7437 sec
#  Using Response (RMF) File            0932201101_PN30spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0932201101_PN30spec.arf

# %%
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot("data")

# %%
spec.ignore("**-0.2 12.0-**")
mo1 = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
#      1 channels (1) ignored in spectrum #     1
#      1 channels (9) ignored in spectrum #     1
#
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              3.388472e+11     using 7 bins.
#
# Test statistic : Chi-Squared              3.388472e+11     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 4 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 46.5312      2.26888       0      0.465480       3.07958   1.19254e-05
# 38.7153      230403        0     0.0562701       3.07211   1.14615e-05
# 36.3865      301598        0    0.00983129       3.01013   1.14650e-05
# 35.5288      242253        0   0.000490591       2.96466   1.13394e-05
# 35.1468      210724        0   0.000219989       2.92773   1.11440e-05
# 34.865       198331        0   8.84476e-05       2.89442   1.09190e-05
# 34.6156      195153        0   2.39307e-05       2.86235   1.06845e-05
# 34.3748      195684        0   8.05812e-06       2.83064   1.04479e-05
# 34.1326      197727        0   2.40113e-07       2.79894   1.02121e-05
# 33.8854      200400        0   1.19770e-07       2.76712   9.97804e-06
# Number of trials exceeded: continue fitting? 33.6312      203347        0   1.24645e-09       2.73513   9.74622e-06
# 33.3693      206420        0   3.34919e-10       2.70292   9.51679e-06
# 33.0989      209557        0   1.10712e-10       2.67050   9.28982e-06
# 32.8196      212728        0   4.83708e-13       2.63785   9.06534e-06
# 32.5297      215921        0   6.13265e-14       2.60490   8.84345e-06
# 32.2202      218987        0   9.24570e-15       2.57138   8.62701e-06
# 31.8141      220506        0   2.81752e-15       2.53413   8.43172e-06
# 31.4687      208694        0   6.59796e-17       2.49913   8.21736e-06
# 29.0238      208074       -1   2.62011e-17       2.22103   6.28458e-06
# 22.2855      401057       -1   3.15992e-18       1.79617   4.52737e-06
# Number of trials exceeded: continue fitting? ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 3.15992e-18 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 14.3118      457619       -1   3.15992e-18       1.39456   3.01649e-06
# 8.3587       869938       -1   3.15992e-18       1.10905   2.27696e-06
# 7.45772      517484       -2   3.15992e-18      0.968835   1.93056e-06
# 7.40093      255558       -3   3.15992e-18      0.995490   2.01854e-06
# 7.40014      25277.2      -4   3.15992e-18      0.992169   2.01158e-06
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 3.15992e-18 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 7.40013      124.08       -3   3.15992e-18      0.992643   2.01286e-06
# ==============================
#  Variances and Principal Axes
#                  2        3
#  3.8587E-14| -0.0000   1.0000
#  1.3904E-02|  1.0000   0.0000
# ------------------------------
#
# ========================
#   Covariance Matrix
#         1           2
#    1.390e-02   3.733e-08
#    3.733e-08   1.388e-13
# ------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    3.15992E-18  +/-  -1.00000
#    2    2   bbody      kT         keV      0.992643     +/-  0.117917
#    3    2   bbody      norm                2.01286E-06  +/-  3.72552E-07
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    7.40     using 7 bins.
#
# Test statistic : Chi-Squared                    7.40     using 7 bins.
#  Null hypothesis probability of 1.16e-01 with 4 degrees of freedom
#  Model Flux 3.8931e-05 photons (1.6824e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
mo2 = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.198844e+11     using 7 bins.
#
# Test statistic : Chi-Squared              1.198844e+11     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 4 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 8.6078       4.74977      -3      0.804142       1.74725   4.82219e-05
# 7.28887      59010.9      -4      0.932264       1.74334   5.65924e-05
# 7.28099      3604.98      -5      0.959328       1.78211   5.94869e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  3.0868E-11| -0.0000  -0.0000   1.0000
#  2.6192E-02|  0.8025  -0.5967  -0.0000
#  4.6726E-01|  0.5967   0.8025   0.0001
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.832e-01   2.112e-01   1.502e-05
#    2.112e-01   3.102e-01   2.033e-05
#    1.502e-05   2.033e-05   1.399e-09
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.959328     +/-  0.428070
#    2    2   powerlaw   PhoIndex            1.78211      +/-  0.556966
#    3    2   powerlaw   norm                5.94869E-05  +/-  3.73972E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    7.28     using 7 bins.
#
# Test statistic : Chi-Squared                    7.28     using 7 bins.
#  Null hypothesis probability of 1.22e-01 with 4 degrees of freedom
#  Model Flux 4.1191e-05 photons (2.5307e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
flux = 2.5307*10**-13
d_pc = 8000
lum = flux * 4 * np.pi * (d_pc * 3.09* 10**18)**2
print('Luminosity is: '+str(lum)+' erg s^-1')
# Out:
# Luminosity is: 1.9433340577893122e+33 erg s^-1
