# %%
# %load_ext wurlitzer
import glob
import os
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12,8]
os.chdir('pps/')

Fit.statMethod = "chi"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4

# %%
spec_fnames = glob.glob('P*PNS*SRSPEC*.FTZ')

spec = Spectrum(spec_fnames[0])
Plot.device="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.0001 0.01")
Plot("data")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: P0916811401PNS003SRSPEC0003.FTZ  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  1.902e-02 +/- 1.865e-03 (80.2 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-8
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 6871 sec
#  Using fit statistic: chi
#  Using Background File                P0916811401PNS003BGSPEC0003.FTZ
#   Background Exposure Time: 6871 sec
#  Using Response (RMF) File            epn_e3_ff20_sdY4.rmf for Source 1
#  Using Auxiliary Response (ARF) File  P0916811401PNS003SRCARF0003.FTZ

# %%
spec.ignore("**-0.2 12.0-**")
mo = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
#       No channels ignored (no channels in specified range)
#      1 channels (8) ignored in spectrum #     1
#
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              3.265111e+11     using 7 bins.
#
# Test statistic : Chi-Squared              3.265111e+11     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 4 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 8.5623       1.98553      -3       3.19506       2.05263   1.08106e-05
# 7.05767      37580.3      -4       4.95553       1.88331   1.09403e-05
# 7.03867      17963.4      -5       5.16554       1.88600   1.10382e-05
# 7.03768      299          -6       5.06205       1.90620   1.11106e-05
# 7.03757      163.603      -7       5.08175       1.90610   1.11242e-05
# 7.03756      1.16673      -8       5.07153       1.90803   1.11312e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.3317E-12| -0.0000  -0.0000   1.0000
#  1.6104E-01| -0.1969  -0.9804  -0.0000
#  8.9809E+00|  0.9804  -0.1969  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    8.639e+00  -1.703e+00  -6.374e-06
#   -1.703e+00   5.029e-01   2.472e-06
#   -6.374e-06   2.472e-06   1.487e-11
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    5.07153      +/-  2.93922
#    2    2   bbody      kT         keV      1.90803      +/-  0.709174
#    3    2   bbody      norm                1.11312E-05  +/-  3.85630E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  7.0376     using 7 bins.
#
# Test statistic : Chi-Squared                  7.0376     using 7 bins.
#  Null hypothesis probability of 1.3392e-01 with 4 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.556530e+11     using 7 bins.
#
# Test statistic : Chi-Squared              1.556530e+11     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 4 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 32.0061      7.40092       0       1.65551      0.559957   1.52597e-05
# 9.62507      162706       -1       3.52702      0.188412   1.75729e-05
# 6.90346      257117       -2       4.98745      0.368972   2.23055e-05
# 6.71715      32683.1      -2       5.61172      0.512290   2.86405e-05
# 6.48883      38507.2      -2       5.95612      0.627216   3.53939e-05
# 6.34289      22344.9      -2       6.28898      0.723555   4.22874e-05
# 6.24545      13551.2      -2       6.56630      0.804607   4.90556e-05
# 6.17986      8329.52      -2       6.80598      0.873161   5.55729e-05
# 6.13462      5318.97      -2       7.01163      0.931299   6.17395e-05
# 6.10291      3494.68      -2       7.18842      0.980720   6.74924e-05
# 6.08042      2355.38      -2       7.34040       1.02281   7.27954e-05
# 6.06433      1622.69      -2       7.47108       1.05872   7.76349e-05
# 6.05273      1139.75      -2       7.58348       1.08939   8.20138e-05
# 6.04433      814.46       -2       7.68016       1.11562   8.59476e-05
# 6.04059      591.124      -3       8.05211       1.20859   0.000100328
# 6.02437      3907.37      -4       8.24779       1.26333   0.000111254
# 6.02144      1519.38      -5       8.26957       1.27227   0.000113535
# 6.02143      52.9502      -6       8.27711       1.27441   0.000113983
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.3726E-10| -0.0000  -0.0002   1.0000
#  1.6124E-01|  0.2014  -0.9795  -0.0002
#  2.1880E+01|  0.9795   0.2014   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.100e+01   4.284e+00   8.931e-04
#    4.284e+00   1.042e+00   2.114e-04
#    8.931e-04   2.114e-04   4.320e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    8.27711      +/-  4.58250
#    2    2   powerlaw   PhoIndex            1.27441      +/-  1.02083
#    3    2   powerlaw   norm                1.13983E-04  +/-  2.07839E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  6.0214     using 7 bins.
#
# Test statistic : Chi-Squared                  6.0214     using 7 bins.
#  Null hypothesis probability of 1.9755e-01 with 4 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              3.988113e+10     using 7 bins.
#
# Test statistic : Chi-Squared              3.988113e+10     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 4 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 78.1767      2.39559       0       1.53930       58.5496   1.84746e-05
# 40.8514      156292       -1       9.57369       24.4980   9.39987e-05
# 34.3777      79222.4
#  -2       3.11088       198.273   0.000206828
# 9.70523      40437.8      -2       5.55599       198.753   0.000266970
# 6.37156      5895.5       -3       7.55082       199.276   0.000317504
# 6.15989      5073.53      -3       8.05788       199.324   0.000323836
# 6.09473      3510.39      -2       8.05957       199.352   0.000320158
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                2.15272E-03  +/-  2.55637E-03
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  0.8483     using 7 bins.
#
# Test statistic : Chi-Squared                  0.8483     using 7 bins.
#  Null hypothesis probability of 9.3186e-01 with 4 degrees of freedom

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 5.5284e-05 photons (4.7217e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
#plx = 1.4843
d_kpc = 8
F_x = 4.7217*10**-13

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 3.614596693110989e+33

# %%
F_opt = 1.05*10**-5 * 10**(-0.4*20.78)
print('Optical Flux: ',F_opt)
print('F_x / F_opt: ', F_x/F_opt)
# Out:
# Optical Flux:  5.119049146085544e-14
# F_x / F_opt:  9.223783295010186

# %%
AllModels.clear()
mo = Model("tbabs*(powerlaw+gauss)")
mo.gaussian.LineE = 7
mo.gaussian.LineE.frozen = True
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>(powerlaw<2> + gaussian<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
#    4    3   gaussian   LineE      keV      6.50000      +/-  0.0
#    5    3   gaussian   Sigma      keV      0.100000     +/-  0.0
#    6    3   gaussian   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              2.996806e+11     using 7 bins.
#
# Test statistic : Chi-Squared              2.996806e+11     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 1 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              2.715567e+11     using 7 bins.
#
# Test statistic : Chi-Squared              2.715567e+11     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 1 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              2.715567e+11     using 7 bins.
#
# Test statistic : Chi-Squared              2.715567e+11     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 2 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm       5:Sigma        6:norm
# 24.7627      29575.3       0       1.64722      0.549336   1.38486e-05      0.145264   1.26616e-05
# 7.78324      94872.6      -1       3.53422      0.209958   1.69659e-05      0.289872   9.83039e-06
# 5.05888      156302       -2       5.24945      0.387546   2.34013e-05     0.0963878   3.04357e-06
# 4.74863      34294.6      -2       5.65503      0.705924   3.46694e-05     0.0343014   4.14024e-06
# 4.38421      66450.6      -2       6.63573      0.976501   5.44867e-05     0.0166033   4.80170e-06
# 3.32727      57194.6      -2       7.33585       1.19881   8.22029e-05    0.00185569   5.37762e-06
# 2.45775      42188.7      -2       7.98685       1.38414   0.000116689   0.000603450   6.16994e-06
# ***Warning: Zero alpha-matrix diagonal element for parameter 5
#  Parameter 5 is pegged at 0.00060345 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 1.85549      34231        -2       8.54860       1.54220   0.000156811   0.000603450   7.39288e-06
# 1.56933      9939.72      -2       9.05002       1.67931   0.000201875   0.000603450   7.67122e-06
# 1.37404      6337.66      -2       9.49778       1.79893   0.000251147   0.000603450   7.89646e-06
# 1.23476      4353.05      -2       9.89873       1.90402   0.000303856   0.000603450   8.09209e-06
3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    13.9557      +/-  7.20505
#    2    2   powerlaw   PhoIndex            2.87858      +/-  1.54617
#    3    2   powerlaw   norm                1.72945E-03  +/-  4.74309E-03
#    4    3   gaussian   LineE      keV      7.00000      frozen
#    5    3   gaussian   Sigma      keV      6.03450E-04  +/-  -1.00000
#    6    3   gaussian   norm                9.84939E-06  +/-  4.60423E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  0.7502     using 7 bins.
#
# Test statistic : Chi-Squared                  0.7502     using 7 bins.
#  Null hypothesis probability of 6.8723e-01 with 2 degrees of freedom

# %%
Fit.error("2")
# Out:
#  Parameter   Confidence Range (2.706)
# ***Warning: Zero alpha-matrix diagonal element for parameter 5
#  Parameter 5 is pegged at 0.00060345 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 5
#  Parameter 5 is pegged at 0.00060345 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 5
#  Parameter 5 is pegged at 0.00060345 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 5
#  Parameter 5 is pegged at 0.00060345 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 5
#  Parameter 5 is pegged at 0.00060345 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 5
#  Parameter 5 is pegged at 0.00060345 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 5
#  Parameter 5 is pegged at 0.00060345 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 5
#  Parameter 5 is pegged at 0.00060345 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 5
#  Parameter 5 is pegged at 0.00060345 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 5
#  Parameter 5 is pegged at 0.00060345 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 5
#  Parameter 5 is pegged at 0.00060345 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 5
#  Parameter 5 is pegged at 0.00060345 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 5
#  Parameter 5 is pegged at 0.00060345 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 5
#  Parameter 5 is pegged at 0.00060345 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 5
#  Parameter 5 is pegged at 0.00060345 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 5
#  Parameter 5 is pegged at 0.00060345 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 5
#  Parameter 5 is pegged at 0.00060345 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 5
#  Parameter 5 is pegged at 0.00060345 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 5
#  Parameter 5 is pegged at 0.00060345 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 5
#  Parameter 5 is pegged at 0.00060345 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
#      2     0.722684      6.36356    (-2.15594,3.48493)

# %%
AllModels.clear()
mo = Model("tbabs*(bbody+gauss)")
mo.gaussian.LineE = 7
mo.gaussian.LineE.frozen = True
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>(bbody<2> + gaussian<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
#    4    3   gaussian   LineE      keV      6.50000      +/-  0.0
#    5    3   gaussian   Sigma      keV      0.100000     +/-  0.0
#    6    3   gaussian   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              5.784862e+11     using 7 bins.
#
# Test statistic : Chi-Squared              5.784862e+11     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 1 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              5.054732e+11     using 7 bins.
#
# Test statistic : Chi-Squared              5.054732e+11     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 1 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              5.054732e+11     using 7 bins.
#
# Test statistic : Chi-Squared              5.054732e+11     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 2 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm       5:Sigma        6:norm
# 4.19198      127882       -2       3.51879       1.71200   8.56694e-06      0.220311   9.20538e-06
# 2.08376      106937       -2       6.26684       1.23265   7.34340e-06      0.351425   1.29193e-05
# 1.28968      141753       -2       9.07516      0.985213   8.74196e-06      0.533640   1.99080e-05
# 0.66469      128536       -3       11.2290      0.885969   1.12190e-05      0.538271   2.38844e-05
# 0.428802     67315.9      -4       12.0064      0.857859   1.27660e-05      0.555713   2.53087e-05
# 0.420868     11289.4      -5       12.1660      0.851191   1.31323e-05      0.559453   2.56265e-05
# 0.42083      590.532      -6       12.1961      0.849899   1.31871e-05      0.560118   2.56783e-05
# ============================================================
#  Variances and Principal Axes
#                  1        2        3        5        6
#  2.3958E-12|  0.0000  -0.0000  -0.9988  -0.0000  -0.0493
#  4.7354E-11|  0.0000   0.0000  -0.0493  -0.0000   0.9988
#  1.1519E-02|  0.0343   0.9269  -0.0000   0.3736  -0.0000
#  6.8477E-02| -0.0367  -0.3724   0.0000   0.9273   0.0000
#  6.3600E+01|  0.9987  -0.0456   0.0000   0.0212   0.0000
# ------------------------------------------------------------
#
# ============================================================
#   Covariance Matrix
#         1           2           3           4           5
#    6.344e+01  -2.893e+00   1.035e-04   1.347e+00   1.057e-04
#   -2.893e+00   1.515e-01  -4.957e-06  -8.122e-02  -5.858e-06
#    1.035e-04  -4.957e-06   1.746e-10   2.338e-06   1.807e-10
#    1.347e+00  -8.122e-02   2.338e-06   8.918e-02   4.160e-06
#    1.057e-04  -5.858e-06   1.807e-10   4.160e-06   2.969e-10
# ------------------------------------------------------------
#
# ========================================================================
# Model TBabs<1>(bbody<2> + gaussian<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    12.1961      +/-  7.96488
#    2    2   bbody      kT         keV      0.849899     +/-  0.389199
#    3    2   bbody      norm                1.31871E-05  +/-  1.32125E-05
#    4    3   gaussian   LineE      keV      7.00000      frozen
#    5    3   gaussian   Sigma      keV      0.560118     +/-  0.298636
#    6    3   gaussian   norm                2.56783E-05  +/-  1.72309E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  0.4208     using 7 bins.
#
# Test statistic : Chi-Squared                  0.4208     using 7 bins.
#  Null hypothesis probability of 8.1025e-01 with 2 degrees of freedom
