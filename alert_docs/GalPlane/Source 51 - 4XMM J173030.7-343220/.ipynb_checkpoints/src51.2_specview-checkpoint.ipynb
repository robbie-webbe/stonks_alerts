# %%
# %load_ext wurlitzer
import glob
import os
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12,8]
os.chdir('pps/')

Fit.statMethod = "chi"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4

# %%
import numpy as np
out_arr = np.full((4,19),-np.inf,dtype=object)

# %%
spec_fnames = glob.glob('P*901PNU*SRSPEC*.FTZ')

spec = Spectrum(spec_fnames[0])
Plot.device="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.0005 1")
Plot("data")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: P0916811901PNU002SRSPEC0001.FTZ  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  5.472e-01 +/- 8.813e-03 (85.2 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-87
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 8867 sec
#  Using fit statistic: chi
#  Using Background File                P0916811901PNU002BGSPEC0001.FTZ
#   Background Exposure Time: 8867 sec
#  Using Response (RMF) File            epn_e3_ff20_sdY3.rmf for Source 1
#  Using Auxiliary Response (ARF) File  P0916811901PNU002SRCARF0001.FTZ

# %%
spec.ignore("**-0.2 12.0-**")
mo = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
#       No channels ignored (no channels in specified range)
#      1 channels (87) ignored in spectrum #     1
#
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              1.675910e+11     using 86 bins.
#
# Test statistic : Chi-Squared              1.675910e+11     using 86 bins.
#  Null hypothesis probability of 0.000000e+00 with 83 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 4071.58      9.27394       0      0.202003       2.98173   2.45489e-05
# 4050.86      330921        0     0.0896851       2.93077   2.45110e-05
# 4035         415166        0     0.0402110       2.86995   2.45657e-05
# 4022.47      448805        0     0.0192956       2.80456   2.46578e-05
# 4009.36      446768        0    0.00108851       2.73918   2.47360e-05
# 4000.07      441561        0   0.000106526       2.67370   2.47998e-05
# 3991.21      405260        0   4.96742e-05       2.61168   2.48097e-05
# 3982.41      368519        0   2.31121e-05       2.55243   2.47723e-05
# 3973.54      333277        0   1.06565e-05       2.49530   2.46952e-05
# 3964.45      299630        0   4.80031e-06       2.43971   2.45849e-05
# 3955.05      267544        0   2.04200e-06       2.38524   2.44468e-05
# 3945.2       237030        0   7.41378e-07       2.33151   2.42853e-05
# 3934.76      208037        0   1.27810e-07       2.27810   2.41044e-05
# 3923.6       180460        0   5.54621e-08       2.22477   2.39075e-05
# 3911.52      154324        0   2.13635e-08       2.17116   2.36973e-05
# 3898.37      129601        0   5.31383e-09       2.11710   2.34766e-05
# 3883.9       106456        0   1.54354e-09       2.06233   2.32476e-05
# 3867.88      85091.7       0   6.59944e-10       2.00667   2.30125e-05
# 3849.98      65910.7       0   2.47046e-10       1.94989   2.27733e-05
# 3844.07      49462.4       0   1.11029e-10       1.85288   1.65584e-05
# 3762.83      1.63026e+06   0   2.96513e-11       1.56508   1.26552e-05
# 3349.12      3.61773e+06   0   1.32992e-11       1.04699   1.05622e-05
# 2558         9.58627e+06  -1   1.88529e-12      0.521143   6.90799e-06
# 984.541      3.28042e+07   0   3.98115e-14      0.269442   1.19645e-05
# 441.681      1.53464e+07  -1     0.0245508      0.341612   1.81567e-05
# 352.06       6.67227e+06  -2     0.0879332      0.291816   2.26861e-05
# 333.034      2.70411e+06  -3      0.126722      0.273203   2.64913e-05
# 330.797      847016       -4      0.137482      0.267284   2.79004e-05
# 330.609      94820.3      -5      0.141518      0.264981   2.83434e-05
# 330.578      11939.6      -6      0.143204      0.264018   2.85173e-05
# 330.572      2065.72      -7      0.143915      0.263611   2.85898e-05
# 330.571      372.412      -8      0.144223      0.263436   2.86210e-05
# 330.571      80.4844      -9      0.144353      0.263361   2.86341e-05
# 330.571      13.1465     -10      0.144409      0.263329   2.86398e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  2.1014E-13| -0.0001   0.0000   1.0000
#  8.7163E-06| -0.3766  -0.9264  -0.0000
#  2.5885E-04|  0.9264  -0.3766   0.0001
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.234e-04  -8.726e-05   2.158e-08
#   -8.726e-05   4.419e-05  -8.677e-09
#    2.158e-08  -8.677e-09   2.300e-12
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.144409     +/-  1.49460E-02
#    2    2   bbody      kT         keV      0.263329     +/-  6.64747E-03
#    3    2   bbody      norm                2.86398E-05  +/-  1.51665E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                330.5712     using 86 bins.
#
# Test statistic : Chi-Squared                330.5712     using 86 bins.
#  Null hypothesis probability of 2.8850e-31 with 83 degrees of freedom

# %%
# Fit.error("1")
# Fit.error("2")

out_arr[0,0] = 'bbody'
out_arr[0,1:4] = mo.TBabs.nH.values[0], np.inf, np.inf
out_arr[0,4:7] = mo.bbody.kT.values[0], np.inf, np.inf
out_arr[0,-2:] = Fit.dof, Fit.statistic / Fit.dof

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              2.484235e+10     using 86 bins.
#
# Test statistic : Chi-Squared              2.484235e+10     using 86 bins.
#  Null hypothesis probability of 0.000000e+00 with 83 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 3547.72      97.1885       0      0.489855       1.19753   0.000114639
# 3508.71      660308       -1     0.0148839       1.39616   4.65303e-05
# 2415.21      2.3975e+06   -1      0.331413       4.45200   0.000400544
# 1391.53      555110        0      0.307260       3.78936   0.000702453
# 886.778      380697       -1      0.313247       2.47677    0.00135464
# 362.289      193867       -2      0.318291       3.04622    0.00144762
# 288.816      36766.7      -3      0.446672       3.72904    0.00203829
# 266.764      34958.3      -4      0.507197       4.08788    0.00256727
# 263.339      12716        -5      0.524281       4.19468    0.00277483
# 263.239      1267.69      -6      0.529285       4.22544    0.00282643
# 263.233      74.6031      -7      0.530730       4.23442    0.00283985
# 263.233      4.93393      -8      0.531156       4.23705    0.00284372
# 263.233      0.410361     -9      0.531279       4.23782    0.00284484
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  2.0373E-09| -0.0081  -0.0001   1.0000
#  5.2248E-05|  0.9851  -0.1717   0.0080
#  1.8666E-02|  0.1716   0.9852   0.0015
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    6.007e-04   3.148e-03   5.340e-06
#    3.148e-03   1.812e-02   2.822e-05
#    5.340e-06   2.822e-05   4.954e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.531279     +/-  2.45082E-02
#    2    2   powerlaw   PhoIndex            4.23782      +/-  0.134602
#    3    2   powerlaw   norm                2.84484E-03  +/-  2.22570E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                263.2325     using 86 bins.
#
# Test statistic : Chi-Squared                263.2325     using 86 bins.
#  Null hypothesis probability of 1.2965e-20 with 83 degrees of freedom

# %%
# Fit.error("1")
# Fit.error("2")

out_arr[1,0] = 'powerlaw'
out_arr[1,1:4] = mo.TBabs.nH.values[0], np.inf, np.inf
out_arr[1,14:17] = mo.powerlaw.PhoIndex.values[0], np.inf, np.inf
out_arr[1,-2:] = Fit.dof, Fit.statistic / Fit.dof

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              2.794210e+09     using 86 bins.
#
# Test statistic : Chi-Squared              2.794210e+09     using 86 bins.
#  Null hypothesis probability of 0.000000e+00 with 83 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 3137.87      117.797      -3      0.260007       24.5539   0.000239003
# 3092.79      561764       -1      0.119199       3.90273   0.000147262
# 923.353      1.15329e+06  -2      0.129213       1.13897   0.000971256
# 709.215      283357       -2      0.261479      0.819994    0.00215371
# 378.77       131542       -3      0.283274      0.666775    0.00376358
# 300.708      42553.3      -4      0.313651      0.624885    0.00506480
# 294.009      10055.1      -5      0.313071      0.618204    0.00535049
# 293.968      198.363      -6      0.315380      0.613485    0.00545257
# 293.959      65.1233      -7      0.316149      0.611346    0.00549515
# 293.957      11.6818      -8      0.316547      0.610323    0.00551581
# 293.957      2.53129      -9      0.316753      0.609790    0.00552655
# 293.956      0.721539    -10      0.316853      0.609532    0.00553174
# 293.956      0.190197    -11      0.316947      0.609299    0.00553649
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  7.7663E-09| -0.0163   0.0138   0.9998
#  4.3308E-05|  0.9114   0.4115   0.0092
#  1.1068E-03| -0.4113   0.9113  -0.0193
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.232e-04  -3.986e-04   9.142e-06
#   -3.986e-04   9.265e-04  -1.929e-05
#    9.142e-06  -1.929e-05   4.230e-07
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.316947     +/-  1.49403E-02
#    2    2   bremss     kT         keV      0.609299     +/-  3.04389E-02
#    3    2   bremss     norm                5.53649E-03  +/-  6.50415E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                293.9564     using 86 bins.
#
# Test statistic : Chi-Squared                293.9564     using 86 bins.
#  Null hypothesis probability of 2.3104e-25 with 83 degrees of freedom

# %%
# Fit.error("1")
# Fit.error("2")

out_arr[3,0] = 'bremss'
out_arr[3,1:4] = mo.TBabs.nH.values[0], np.inf, np.inf
out_arr[3,4:7] = mo.bremss.kT.values[0], np.inf, np.inf
out_arr[3,-2:] = Fit.dof, Fit.statistic / Fit.dof

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              2.457160e+08     using 86 bins.
#
# Test statistic : Chi-Squared              2.457160e+08     using 86 bins.
#  Null hypothesis probability of 0.000000e+00 with 83 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 828.692      404.605      -3      0.649040      0.896063    0.00199603
# 744.028      33999.3      -4      0.684406      0.802188    0.00233897
# 713.783      18162.6      -5      0.699756      0.745319    0.00261084
# 709.094      5906.72      -6      0.703605      0.722406    0.00272486
# 705.379      774.079      -7      0.717450      0.692209    0.00291106
# 705.151      1197.57      -8      0.709911      0.698139    0.00284809
# 705.14       104.37       -9      0.711202      0.696527    0.00286272
# 705.14       6.30792     -10      0.710821      0.696876    0.00285903
# 705.14       0.397367    -11      0.710898      0.696789    0.00285984
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  2.3173E-09| -0.0068   0.0032   1.0000
#  1.0503E-04| -0.5821  -0.8131  -0.0014
#  3.6866E-04|  0.8131  -0.5821   0.0074
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.793e-04  -1.248e-04   2.306e-06
#   -1.248e-04   1.944e-04  -1.473e-06
#    2.306e-06  -1.473e-06   2.277e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.710898     +/-  1.67127E-02
#    2    2   apec       kT         keV      0.696789     +/-  1.39413E-02
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                2.85984E-03  +/-  1.50910E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                705.1397     using 86 bins.
#
# Test statistic : Chi-Squared                705.1397     using 86 bins.
#  Null hypothesis probability of 2.4010e-99 with 83 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*(apec+apec)")
mo.apec.kT = 0.5
mo.apec_3.kT = 4
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              9.861955e+08     using 86 bins.
#
# Test statistic : Chi-Squared              9.861955e+08     using 86 bins.
#  Null hypothesis probability of 0.000000e+00 with 81 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              5.236440e+08     using 86 bins.
#
# Test statistic : Chi-Squared              5.236440e+08     using 86 bins.
#  Null hypothesis probability of 0.000000e+00 with 81 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              5.334380e+08     using 86 bins.
#
# Test statistic : Chi-Squared              5.334380e+08     using 86 bins.
#  Null hypothesis probability of 0.000000e+00 with 81 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm          6:kT        9:norm
# 759.375      56193.8      -2      0.301349      0.372032   0.000719198       3.03233   0.000836602
# 276.112      133553       -2      0.364942      0.262377    0.00120259       1.46662    0.00159421
# 227.17       35488.9      -3      0.454843      0.248762    0.00231092       1.46980    0.00152583
# 221.209      16154.4      -3      0.535798      0.233088    0.00410164       1.45614    0.00159892
# 202.614      13435.9      -4      0.599380      0.221283    0.00675553       1.43878    0.00166314
# 196.166      8552.25      -5      0.653166      0.208853     0.0105398       1.40599    0.00170435
# 176.98       7401.18      -6      0.673834      0.204513     0.0137302       1.40756    0.00172472
# 175.415      2000.57      -7      0.673233      0.205448     0.0139477       1.41243    0.00172201
# 175.41       24.2496      -8      0.675929      0.205020     0.0142255       1.41183    0.00172443
# 175.409      11.8577      -9      0.675889      0.205093     0.0142117       1.41226    0.00172426
# 175.409      0.165766    -10      0.676060      0.205067     0.0142298       1.41223    0.00172441
# ============================================================
#  Variances and Principal Axes
#                  1        2        5        6        9
#  2.1711E-09| -0.0038   0.0158   0.0491  -0.0008   0.9987
#  1.3843E-07| -0.0698   0.2205   0.9715  -0.0046  -0.0515
#  1.8040E-05|  0.1593   0.9645  -0.2079  -0.0322  -0.0044
#  1.0761E-03| -0.5354   0.0488  -0.0536  -0.8415  -0.0009
#  1.6726E-03|  0.8265  -0.1356   0.0876  -0.5393   0.0006
# ------------------------------------------------------------
#
# ============================================================
#   Covariance Matrix
#         1           2           3           4           5
#    1.451e-03  -2.128e-04   1.514e-04  -2.608e-04   1.272e-06
#   -2.128e-04   5.012e-05  -2.627e-05   7.757e-05  -2.524e-07
#    1.514e-04  -2.627e-05   1.684e-05  -3.035e-05   1.429e-07
#   -2.608e-04   7.757e-05  -3.035e-05   1.248e-03   2.901e-07
#    1.272e-06  -2.524e-07   1.429e-07   2.901e-07   4.247e-09
# ------------------------------------------------------------
#
# ========================================================================
# Model TBabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.676060     +/-  3.80981E-02
#    2    2   apec       kT         keV      0.205067     +/-  7.07956E-03
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.42298E-02  +/-  4.10306E-03
#    6    3   apec       kT         keV      1.41223      +/-  3.53335E-02
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.72441E-03  +/-  6.51664E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                175.4094     using 86 bins.
#
# Test statistic : Chi-Squared                175.4094     using 86 bins.
#  Null hypothesis probability of 6.3617e-09 with 81 degrees of freedom

# %%
# Fit.error("1")
# Fit.error("2")
# Fit.error("6")

out_arr[2,0] = 'apec+apec'
out_arr[2,1:4] = mo.TBabs.nH.values[0], np.inf, np.inf
out_arr[2,13] = mo.apec.Abundanc.values[0]
out_arr[2,4:7] = mo.apec.kT.values[0], np.inf, np.inf
out_arr[2,7:10] = mo.apec_3.kT.values[0], np.inf, np.inf
out_arr[2,-2:] = Fit.dof, Fit.statistic / Fit.dof

# %%
np.savetxt('../spec51.2_output.csv',out_arr,fmt=['%s','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.1f','%.2f','%.2f','%.2f','%i','%.2f'],delimiter=',')

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 0.00087826 photons (1.785e-12 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
plx = 2.5845
d_kpc = 1/plx
F_x = 1.785*10**-12

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 3.19644054126418e+31

# %%
import numpy as np
print(d_kpc)
print(np.log10(L_x))
# Out:
# 0.38692203520990526
# 31.504666630296228

# %%
F_opt = 1.05*10**-5 * 10**(-0.4*7.6013)
print('Optical Flux: ',F_opt)
print('F_x / F_opt: ', np.log10(F_x/F_opt))
# Out:
# Optical Flux:  9.564654770019905e-09
# F_x / F_opt:  -3.729031078621726

# %%
AllModels.clear()
mo = Model("tbabs*(apec+apec+apec)")
mo.apec.kT = 0.5
mo.apec_3.kT = 4.0
mo.apec_4.kT = 10.0
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>(apec<2> + apec<3> + apec<4>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
#   10    4   apec       kT         keV      1.00000      +/-  0.0
#   11    4   apec       Abundanc            1.00000      frozen
#   12    4   apec       Redshift            0.0          frozen
#   13    4   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              2.221443e+09     using 86 bins.
#
# Test statistic : Chi-Squared              2.221443e+09     using 86 bins.
#  Null hypothesis probability of 0.000000e+00 with 79 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              1.483792e+09     using 86 bins.
#
# Test statistic : Chi-Squared              1.483792e+09     using 86 bins.
#  Null hypothesis probability of 0.000000e+00 with 79 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              1.376217e+09     using 86 bins.
#
# Test statistic : Chi-Squared              1.376217e+09     using 86 bins.
#  Null hypothesis probability of 0.000000e+00 with 79 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              1.924558e+09     using 86 bins.
#
# Test statistic : Chi-Squared              1.924558e+09     using 86 bins.
#  Null hypothesis probability of 0.000000e+00 with 79 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm          6:kT        9:norm         10:kT       13:norm
# 1156.64      51267.6      -3     0.0489863      0.407552   0.000265063       8.32508   0.000594691       18.9793   2.23307e-07
# 940.13       152609       -3      0.162930      0.442640   0.000260169       3.59253   4.20228e-06       7.97519    0.00164421
# 728.949      78920.9      -2      0.100683      0.586309   9.24426e-05       1.17580   9.52515e-07       5.50466    0.00147607
# 475.505      324270       -3      0.101234      0.563880   9.59885e-05      0.205763   0.000239446       1.80388    0.00101520
# 299.422      146514       -4      0.131687       1.05074   0.000101120      0.236513   0.000161142       1.90096    0.00119276
# 135.429      119110       -5      0.133792      0.925346   0.000306121      0.304175   0.000124595       2.36443    0.00110119
# 88.2823      114028       -6      0.139685      0.955431   0.000244353      0.323935   0.000150241       2.47004    0.00113832
# 87.853       8916.6       -7      0.137797      0.962574   0.000240004      0.326211   0.000145232       2.45614    0.00113767
# 87.8529      56.0711      -8      0.137707      0.962722   0.000239978      0.326365   0.000145122       2.45707    0.00113763
# ================================================================================
#  Variances and Principal Axes
#                  1        2        5        6        9       10       13
#  6.8270E-11|  0.0017   0.0003  -0.7776  -0.0003  -0.6006   0.0000  -0.1861
#  3.6488E-10|  0.0013   0.0004   0.5892  -0.0000  -0.7993  -0.0000   0.1177
#  1.7893E-09| -0.0009   0.0008  -0.2194  -0.0003  -0.0181  -0.0000   0.9755
#  1.5731E-04| -0.9064   0.2221  -0.0002  -0.3583  -0.0016  -0.0267  -0.0012
#  1.0322E-03|  0.3229   0.9099   0.0003  -0.2465   0.0012  -0.0842  -0.0004
#  2.1121E-03|  0.2697  -0.3240   0.0003  -0.8942   0.0006   0.1507   0.0003
#  2.5703E-02| -0.0382   0.1334   0.0000   0.1060  -0.0000   0.9846  -0.0001
# --------------------------------------------------------------------------------
#
# ====================================================================================
#   Covariance Matrix
#         1           2           3           4           5           6           7
#    4.280e-04  -4.398e-05   2.802e-07  -6.445e-04   9.862e-07  -9.054e-04   2.919e-07
#   -4.398e-05   1.541e-03   2.150e-07   7.315e-04   4.764e-07   3.193e-03  -8.598e-07
#    2.802e-07   2.150e-07   5.825e-10  -5.425e-07   6.357e-10   8.214e-07  -3.150e-10
#   -6.445e-04   7.315e-04  -5.425e-07   2.061e-03  -1.396e-06   2.422e-03  -5.961e-07
#    9.862e-07   4.764e-07   6.357e-10  -1.396e-06   2.785e-09  -1.147e-06   2.515e-10
#   -9.054e-04   3.193e-03   8.214e-07   2.422e-03  -1.147e-06   2.497e-02  -1.760e-06
#    2.919e-07  -8.598e-07  -3.150e-10  -5.961e-07   2.515e-10  -1.760e-06   2.430e-09
# ------------------------------------------------------------------------------------
#
# ========================================================================
# Model TBabs<1>(apec<2> + apec<3> + apec<4>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.137707     +/-  2.06878E-02
#    2    2   apec       kT         keV      0.962722     +/-  3.92610E-02
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                2.39978E-04  +/-  2.41346E-05
#    6    3   apec       kT         keV      0.326365     +/-  4.53959E-02
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.45122E-04  +/-  5.27747E-05
#   10    4   apec       kT         keV      2.45707      +/-  0.158034
#   11    4   apec       Abundanc            1.00000      frozen
#   12    4   apec       Redshift            0.0          frozen
#   13    4   apec       norm                1.13763E-03  +/-  4.92956E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 87.8529     using 86 bins.
#
# Test statistic : Chi-Squared                 87.8529     using 86 bins.
#  Null hypothesis probability of 2.3203e-01 with 79 degrees of freedom
