# %%
# %load_ext wurlitzer
import glob
import os
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12,8]
os.chdir('pps/')

Fit.statMethod = "chi"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4

# %%
spec_fnames = glob.glob('P*PNS*SRSPEC*.FTZ')

spec = Spectrum(spec_fnames[0])
Plot.device="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.0001 0.02")
Plot("data")
spec.ignore("**-0.2 12.0-**")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: P0932201101PNS003SRSPEC001E.FTZ  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  2.260e-02 +/- 1.889e-03 (85.7 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-9
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 7436 sec
#  Using fit statistic: chi
#  Using Background File                P0932201101PNS003BGSPEC001E.FTZ
#   Background Exposure Time: 7436 sec
#  Using Response (RMF) File            epn_e3_ff20_sdY5.rmf for Source 1
#  Using Auxiliary Response (ARF) File  P0932201101PNS003SRCARF001E.FTZ
#       No channels ignored (no channels in specified range)
#      1 channels (9) ignored in spectrum #     1

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              1.128083e+11     using 8 bins.
#
# Test statistic : Chi-Squared              1.128083e+11     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 5 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 5.93244      5.42559      -1      0.354808       1.14637   2.82157e-05
# 2.9907       192343       -2      0.410272       1.09210   2.60447e-05
# 2.9395       11063.2      -3      0.433480       1.10492   2.66179e-05
# 2.93927      28.3211      -4      0.436033       1.10863   2.67417e-05
# 2.93927      15.1042      -5      0.436096       1.10868   2.67442e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  5.8254E-12| -0.0000  -0.0000   1.0000
#  7.7689E-03|  0.9271  -0.3748   0.0000
#  2.0306E-01|  0.3748   0.9271   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    3.520e-02   6.786e-02   2.005e-06
#    6.786e-02   1.756e-01   4.666e-06
#    2.005e-06   4.666e-06   1.344e-10
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.436096     +/-  0.187620
#    2    2   powerlaw   PhoIndex            1.10868      +/-  0.419085
#    3    2   powerlaw   norm                2.67442E-05  +/-  1.15910E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  2.9393     using 8 bins.
#
# Test statistic : Chi-Squared                  2.9393     using 8 bins.
#  Null hypothesis probability of 7.0935e-01 with 5 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              2.489663e+10     using 8 bins.
#
# Test statistic : Chi-Squared              2.489663e+10     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 5 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 5.2376       2.77533      -1      0.737524       7.17108   5.97381e-05
# 4.0752       4414.89      -1      0.602492       11.2357   5.19600e-05
# 4.00296      26285.1      -2      0.440600       28.2449   5.10530e-05
# 3.40658      29616.6      -3      0.440340       79.5697   7.02252e-05
# 3.1002       22686.7      -3      0.450652       199.197   9.17060e-05
# 2.99829      12918.1      -1      0.462486       199.265   9.12266e-05
# 2.9863       5573.23      -1      0.465159       199.304   9.10442e-05
# 2.98366      3584.62      -1      0.465679       199.334   9.09570e-05
# 2.98283      2925.63      -1      0.465758       199.359   9.09173e-05
# 2.98267      2678.85      -1      0.465749       199.362   9.09075e-05
# 2.98244      2630.74      -1      0.465758       199.363   9.08932e-05
# 2.98237      2555.5       -1      0.465752       199.363   9.08886e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  6.6566E-11| -0.0001  -0.0000   1.0000
#  9.5404E-03|  1.0000   0.0001   0.0001
#  3.5004E+06| -0.0001   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.808e-02  -2.547e+02  -3.393e-05
#   -2.547e+02   3.500e+06   4.762e-01
#   -3.393e-05   4.762e-01   6.490e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.465752     +/-  0.167567
#    2    2   bremss     kT         keV      199.363      +/-  1870.94
#    3    2   bremss     norm                9.08886E-05  +/-  2.54746E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  2.9824     using 8 bins.
#
# Test statistic : Chi-Squared                  2.9824     using 8 bins.
#  Null hypothesis probability of 7.0270e-01 with 5 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              7.859896e+09     using 8 bins.
#
# Test statistic : Chi-Squared              7.859896e+09     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 5 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 40.4166      12.6641      -2       1.70815      0.800740   0.000224555
# 29.6107      32637.4      -1       1.72962       1.33961   0.000185859
# 18.2545      43999        -2      0.654536       2.60030   0.000134256
# 12.7998      18820.1      -3      0.428131       5.68151   0.000127706
# 5.07928      46770.4      -4      0.465541       10.5838   0.000133105
# 3.83982      8768.8       -5      0.446268       24.8987   0.000149902
# 3.45747      4114.84      -4      0.448747       63.7430   0.000192820
# 3.17233      10035.3      -1      0.473708       63.9605   0.000194222
# 3.15131      6158.63      -1      0.481136       63.9866   0.000195286
# 3.09198      5891.23       0      0.485078       63.9960   0.000193972
# 3.07184      3654.26       0      0.486925       63.9981   0.000193190
# 3.06427      2434.76       0      0.487683       63.9991   0.000192708
# 3.06106      1756.5        0      0.487903       63.9996   0.000192399
# 3.05953      1370.58       0      0.487877       63.9999   0.000192193
# 3.05872      1144.43       0      0.487750       64.0000   0.000192050
# 3.05826      1007.08       0      0.487594       64.0000   0.000191948
# 3.05797      920.289       0      0.487442       64.0000   0.000191872
# 3.05778      863.057       0      0.487307       64.0000   0.000191815
# 3.05766      823.796       0      0.487192       64.0000   0.000191772
# 3.05757      795.905       0      0.487097       64.0000   0.000191738
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  2.9765E-10| -0.0002  -0.0000   1.0000
#  1.0100E-02|  1.0000   0.0002   0.0002
#  3.9534E+05| -0.0002   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.599e-02  -7.927e+01  -2.691e-05
#   -7.927e+01   3.953e+05   1.423e-01
#   -2.691e-05   1.423e-01   5.175e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.487097     +/-  0.161229
#    2    2   apec       kT         keV      64.0000      +/-  628.764
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.91738E-04  +/-  2.27496E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  3.0576     using 8 bins.
#
# Test statistic : Chi-Squared                  3.0576     using 8 bins.
#  Null hypothesis probability of 6.9111e-01 with 5 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              2.340098e+11     using 8 bins.
#
# Test statistic : Chi-Squared              2.340098e+11     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 5 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 36.8371      2.93429       0      0.274297       3.07816   1.61175e-05
# 29.929       186046        0     0.0907516       3.07369   1.57046e-05
# 27.1635      221689       -1     0.0101773       2.96991   1.35627e-05
# 23.9441      351136       -1    0.00504065       2.76095   1.22711e-05
# 22.4205      273435       -1   0.000933015       2.59233   1.07114e-05
# 20.8419      299684       -1   5.27782e-05       2.41969   9.27076e-06
# 19.1226      327235       -1   5.15734e-06       2.24515   7.94198e-06
# 17.137       363299       -1   1.25916e-07       2.06777   6.73703e-06
# 14.8453      400568       -1   3.15211e-10       1.88839   5.66274e-06
# 12.2685      429943       -1   1.37504e-10       1.70951   4.72734e-06
# 9.56598      432297       -1   3.15349e-11       1.53644   3.94270e-06
# 7.11883      369251       -1   1.42475e-11       1.37764   3.32093e-06
# 5.39221      173347       -1     0.0155510       1.24390   2.86513e-06
# 3.80299      5911.52      -2      0.100631      0.914193   1.76573e-06
# 2.78845      1.728e+06    -3      0.132991      0.924188   2.00437e-06
# 2.78625      71789.6      -4      0.130605      0.924458   2.00816e-06
# 2.78625      164.949      -5      0.130767      0.924356   2.00812e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  3.2809E-14| -0.0000  -0.0000   1.0000
#  5.1464E-03| -0.8229  -0.5682  -0.0000
#  3.1554E-02|  0.5682  -0.8229  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.367e-02  -1.235e-02  -1.347e-08
#   -1.235e-02   2.303e-02   4.797e-08
#   -1.347e-08   4.797e-08   1.540e-13
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.130767     +/-  0.116921
#    2    2   bbody      kT         keV      0.924356     +/-  0.151755
#    3    2   bbody      norm                2.00812E-06  +/-  3.92458E-07
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  2.7863     using 8 bins.
#
# Test statistic : Chi-Squared                  2.7863     using 8 bins.
#  Null hypothesis probability of 7.3290e-01 with 5 degrees of freedom

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 3.5935e-05 photons (1.5908e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
#plx = 1.4843
d_kpc = 8
F_x = 1.5908*10**-13

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 1.2178029987930113e+33
