# %%
# %load_ext wurlitzer
import glob
import os
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12,8]
os.chdir('pps/')

Fit.statMethod = "chi"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4

# %%
import numpy as np
out_arr = np.full((4,19),-np.inf,dtype=object)

# %%
spec_fnames = glob.glob('P*PNS*SRSPEC*.FTZ')

spec = Spectrum(spec_fnames[0])
Plot.device="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.0001 0.01")
Plot("data")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: P0934200801PNS003SRSPEC0005.FTZ  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  1.363e-02 +/- 1.215e-03 (81.9 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-9
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 1.136e+04 sec
#  Using fit statistic: chi
#  Using Background File                P0934200801PNS003BGSPEC0005.FTZ
#   Background Exposure Time: 1.136e+04 sec
#  Using Response (RMF) File            epn_e3_ff20_sdY9.rmf for Source 1
#  Using Auxiliary Response (ARF) File  P0934200801PNS003SRCARF0005.FTZ

# %%
spec.ignore("**-0.2 12.0-**")
mo = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
#       No channels ignored (no channels in specified range)
#      1 channels (9) ignored in spectrum #     1
#
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              1.066973e+12     using 8 bins.
#
# Test statistic : Chi-Squared              1.066973e+12     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 5 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 26.9729      2.44089       0    0.00860024       3.05677   7.48253e-06
# 24.4512      290239       -1   0.000553433       2.75865   6.24146e-06
# 22.1593      191732       -1   3.98569e-05       2.47621   5.04553e-06
# 19.4132      185614       -1   4.19423e-06       2.18480   4.00251e-06
# 16.2391      127091       -1     0.0356451       1.89086   3.13407e-06
# 12.3185      124365       -1      0.102259       1.59820   2.43521e-06
# 8.0356       223616       -1      0.201181       1.32501   1.94072e-06
# 6.12758      300400       -2      0.480430      0.853992   1.24150e-06
# 3.14606      2.44518e+06  -3      0.614670      0.923517   1.56254e-06
# 3.07987      381896       -4      0.667747      0.899761   1.58869e-06
# 3.07874      8450.19      -5      0.677924      0.897006   1.59213e-06
# 3.0787       90.0309      -6      0.679694      0.896423   1.59248e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  2.2643E-14| -0.0000  -0.0000   1.0000
#  6.8616E-03| -0.3131  -0.9497  -0.0000
#  1.2408E-01|  0.9497  -0.3131   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.126e-01  -3.486e-02   2.525e-08
#   -3.486e-02   1.835e-02   3.392e-09
#    2.525e-08   3.392e-09   4.492e-14
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.679694     +/-  0.335547
#    2    2   bbody      kT         keV      0.896423     +/-  0.135470
#    3    2   bbody      norm                1.59248E-06  +/-  2.11944E-07
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  3.0787     using 8 bins.
#
# Test statistic : Chi-Squared                  3.0787     using 8 bins.
#  Null hypothesis probability of 6.8785e-01 with 5 degrees of freedom

# %%
Fit.error("1")
Fit.error("2")

out_arr[0,0] = 'bbody'
out_arr[0,1:4] = mo.TBabs.nH.values[0], mo.TBabs.nH.values[0] - mo.TBabs.nH.error[0], mo.TBabs.nH.error[1] - mo.TBabs.nH.values[0]
out_arr[0,4:7] = mo.bbody.kT.values[0], mo.bbody.kT.values[0] - mo.bbody.kT.error[0], mo.bbody.kT.error[1] - mo.bbody.kT.values[0]
out_arr[0,-2:] = Fit.dof, Fit.statistic / Fit.dof
# Out:
#  Parameter   Confidence Range (2.706)
#      1     0.238518      1.56405    (-0.441467,0.884062)
#  Parameter   Confidence Range (2.706)
#      2      0.68171      1.18614    (-0.214595,0.289838)

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              3.306547e+11     using 8 bins.
#
# Test statistic : Chi-Squared              3.306547e+11     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 5 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 5.40322      3.09561      -2       1.13086       1.47051   2.75178e-05
# 4.94312      117522       -3       1.46194       1.81556   4.31549e-05
# 3.7177       80699        -4       1.64193       1.95295   5.68321e-05
# 3.57004      21516.1      -5       1.72248       2.01590   6.39366e-05
# 3.56088      3751.58      -6       1.75908       2.04404   6.69230e-05
# 3.55981      565.295      -7       1.77608       2.05712   6.82383e-05
# 3.5596       101.572      -8       1.78394       2.06316   6.88378e-05
# 3.55956      20.2948      -9       1.78754       2.06593   6.91121e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  4.2514E-11| -0.0000  -0.0001   1.0000
#  3.5879E-02|  0.6693  -0.7430  -0.0000
#  8.0670E-01|  0.7430   0.6693   0.0001
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    4.614e-01   3.833e-01   3.655e-05
#    3.833e-01   3.812e-01   3.430e-05
#    3.655e-05   3.430e-05   3.185e-09
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.78754      +/-  0.679288
#    2    2   powerlaw   PhoIndex            2.06593      +/-  0.617374
#    3    2   powerlaw   norm                6.91121E-05  +/-  5.64331E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  3.5596     using 8 bins.
#
# Test statistic : Chi-Squared                  3.5596     using 8 bins.
#  Null hypothesis probability of 6.1440e-01 with 5 degrees of freedom

# %%
Fit.error("1")
Fit.error("2")

out_arr[1,0] = 'powerlaw'
out_arr[1,1:4] = mo.TBabs.nH.values[0], mo.TBabs.nH.values[0] - mo.TBabs.nH.error[0], mo.TBabs.nH.error[1] - mo.TBabs.nH.values[0]
out_arr[1,14:17] = mo.powerlaw.PhoIndex.values[0], mo.powerlaw.PhoIndex.values[0] - mo.powerlaw.PhoIndex.error[0], mo.powerlaw.PhoIndex.error[1] - mo.powerlaw.PhoIndex.values[0]
out_arr[1,-2:] = Fit.dof, Fit.statistic / Fit.dof
# Out:
#  Parameter   Confidence Range (2.706)
#      1     0.758021      3.72077    (-1.03101,1.93174)
#  Parameter   Confidence Range (2.706)
#      2      1.04356       3.5841    (-1.02409,1.51645)

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              6.453608e+10     using 8 bins.
#
# Test statistic : Chi-Squared              6.453608e+10     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 5 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 3.81797      2.76434      -3       1.18520       9.44025   4.34856e-05
# 3.63396      14949.3      -1       1.26092       8.15086   4.58927e-05
# 3.54782      8829.12      -1       1.31260       7.34699   4.77538e-05
# 3.49171      5823.02      -2       1.41471       5.66283   5.18341e-05
# 3.39438      15552.9      -3       1.49709       5.09067   5.61422e-05
# 3.38206      4925.62      -4       1.52634       4.94951   5.77287e-05
# 3.38158      441.821      -5       1.53292       4.92390   5.80217e-05
# 3.38142      1.62299      -6       1.53750       4.88667   5.82769e-05
# 3.3814       24.5759      -7       1.53880       4.87960   5.83381e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  3.0422E-11| -0.0000   0.0000   1.0000
#  7.0549E-02|  0.9944   0.1055   0.0000
#  1.5064E+01| -0.1055   0.9944  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.373e-01  -1.572e+00   1.194e-05
#   -1.572e+00   1.490e+01  -9.744e-05
#    1.194e-05  -9.744e-05   7.062e-10
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.53880      +/-  0.487130
#    2    2   bremss     kT         keV      4.87960      +/-  3.85964
#    3    2   bremss     norm                5.83381E-05  +/-  2.65747E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  3.3814     using 8 bins.
#
# Test statistic : Chi-Squared                  3.3814     using 8 bins.
#  Null hypothesis probability of 6.4140e-01 with 5 degrees of freedom

# %%
Fit.error("1")
Fit.error("2")

out_arr[3,0] = 'bremss'
out_arr[3,1:4] = mo.TBabs.nH.values[0], mo.TBabs.nH.values[0] - mo.TBabs.nH.error[0], mo.TBabs.nH.error[1] - mo.TBabs.nH.values[0]
out_arr[3,4:7] = mo.bremss.kT.values[0], mo.bremss.kT.values[0] - mo.bremss.kT.error[0], mo.bremss.kT.error[1] - mo.bremss.kT.values[0]
out_arr[3,-2:] = Fit.dof, Fit.statistic / Fit.dof
# Out:
#  Parameter   Confidence Range (2.706)
#      1       0.7793      2.80025    (-0.759614,1.26134)
#  Parameter   Confidence Range (2.706)
#
# ***Warning: Number of trials exceeded before bracketing of delta fit-stat.
# Last attempt: 200, with delta statistic: 1.89944
#
# Continue error search in this direction?
# *** Parameter upper bound is INVALID.
#
#      2      1.73615            0    (-3.14468,-4.88084)

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              2.814779e+10     using 8 bins.
#
# Test statistic : Chi-Squared              2.814779e+10     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 5 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 44.5594      10.4406      -3       2.24307       1.18893   0.000126202
# 10.9378      60610.2      -4       1.65133       2.77167   0.000130710
# 3.23667      49051.4      -5       1.54894       4.26932   0.000149287
# 3.12841      827.77       -6       1.61832       4.32887   0.000153826
# 3.12611      8.81749      -7       1.64673       4.20123   0.000156419
# 3.12569      170.065      -8       1.64387       4.24123   0.000156054
# 3.12569      1.46478      -9       1.64477       4.23625   0.000156149
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  2.1763E-10| -0.0001   0.0000   1.0000
#  6.8813E-02|  0.9871   0.1600   0.0001
#  8.4288E+00| -0.1600   0.9871  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.827e-01  -1.320e+00   2.742e-05
#   -1
# .320e+00   8.215e+00  -1.433e-04
#    2.742e-05  -1.433e-04   2.991e-09
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.64477      +/-  0.531695
#    2    2   apec       kT         keV      4.23625      +/-  2.86617
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.56149E-04  +/-  5.46872E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  3.1257     using 8 bins.
#
# Test statistic : Chi-Squared                  3.1257     using 8 bins.
#  Null hypothesis probability of 6.8062e-01 with 5 degrees of freedom

# %%
Fit.error("1")
Fit.error("2")

out_arr[2,0] = 'apec'
out_arr[2,1:4] = mo.TBabs.nH.values[0], mo.TBabs.nH.values[0] - mo.TBabs.nH.error[0], mo.TBabs.nH.error[1] - mo.TBabs.nH.values[0]
out_arr[2,13] = mo.apec.Abundanc.values[0]
out_arr[2,4:7] = mo.apec.kT.values[0], mo.apec.kT.values[0] - mo.apec.kT.error[0], mo.apec.kT.error[1] - mo.apec.kT.values[0]
out_arr[2,-2:] = Fit.dof, Fit.statistic / Fit.dof
# Out:
#  Parameter   Confidence Range (2.706)
#      1     0.810756       2.6515    (-0.834031,1.00671)
#  Parameter   Confidence Range (2.706)
# ***Warning: Parameter pegged at hard limit: 64
#      2      2.01222            0    (-2.22418,-4.23641)

# %%
np.savetxt('../spec65_output.csv',out_arr,fmt=['%s','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.1f','%.2f','%.2f','%.2f','%i','%.2f'],delimiter=',')

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 2.5761e-05 photons (1.5737e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
plx = 0.1737
d_kpc = 1/plx
F_x = 1.5736*10**-13

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 6.2384427347866826e+32

# %%
import numpy as np
print(d_kpc)
print(np.log10(L_x))
# Out:
# 5.757052389176741
# 32.79507619287252

# %%
F_opt = 1.05*10**-5 * 10**(-0.4*18.41)
print('Optical Flux: ',F_opt)
print('F_x / F_opt: ', np.log10(F_x/F_opt))
# Out:
# Optical Flux:  4.541395225867584e-13
# F_x / F_opt:  -0.460294952158657

# %%
AllModels.clear()
mo = Model("tbabs*(apec+apec)")
mo.apec.kT = 0.5
mo.apec_3.kT = 5.0
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.125952e+11     using 8 bins.
#
# Test statistic : Chi-Squared              1.125952e+11     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              7.227333e+10     using 8 bins.
#
# Test statistic : Chi-Squared              7.227333e+10     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              3.111712e+10     using 8 bins.
#
# Test statistic : Chi-Squared              3.111712e+10     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:nor