# %%
# %load_ext wurlitzer
import numpy as np
import glob
import os
import matplotlib.pyplot as plt
from astropy.io import fits
from xspec import *
plt.rcParams['figure.figsize'] = [9,6]

Fit.statMethod = "cstat"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4

# %%
#spec_file = sorted(glob.glob("*grpspec.fits"))
#spec = Spectrum(spec_file[0])

spec = Spectrum(glob.glob("*cash.fits")[0],backFile=glob.glob("*spec_bkg.fits")[0],respFile=glob.glob("*rmf")[0],arfFile=glob.glob("*.arf")[0])
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0886110301_M251spec_cash.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  2.543e-03 +/- 4.608e-04 (61.2 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-153
#   Telescope: XMM Instrument: EMOS2  Channel Type: PI
#   Exposure Time: 2.144e+04 sec
#  Using fit statistic: cstat
#  Using Background File                0886110301_M251spec_bkg.fits
#   Background Exposure Time: 2.144e+04 sec
#  No response loaded.
#
# ***Warning!  One or more spectra are missing responses,
#                and are not suitable for fit.
# Net count rate (cts/s) for Spectrum:1  2.543e-03 +/- 4.608e-04 (61.2 % total)
# ***Warning!  One or more spectra are missing responses,
#                and are not suitable for fit.
# ***Warning: Detected response matrix energy bin value = 0 (or neg).
#      XSPEC will instead use small finite value (response file will not be altered).
# Response successfully loaded.
# Arf successfully loaded.
# Spectrum 1  Spectral Data File: 0886110301_M251spec_cash.fits
# Net count rate (cts/s) for Spectrum:1  2.543e-03 +/- 4.608e-04 (61.2 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-153
#   Telescope: XMM Instrument: EMOS2  Channel Type: PI
#   Exposure Time: 2.144e+04 sec
#  Using fit statistic: cstat
#  Using Background File                0886110301_M251spec_bkg.fits
#   Background Exposure Time: 2.144e+04 sec
#  Using Response (RMF) File            0886110301_M251spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0886110301_M251spec.arf
#
#  Spectral data counts: 89
#  Model predicted rate: 0.0

# %%
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.00001 0.05")
Plot.addCommand("Rescale X 0.1 15")
Plot("data")
#spec.ignore("**-0.2 12.0-**")

# %%
AllModels.clear()
mo1 = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : C-Statistic              1.174242e+07     using 153 bins.
#
# Test statistic : Chi-Squared              2.520357e+12     using 153 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 0.000000e+00 with 150 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 152.431      2.4088e+06   -3      0.161653       196.895      0.103009
# 122.088      26.1827      -4     0.0640014       199.051      0.404865
# 111.928      9.87968      -4     0.0242862       199.342      0.692692
# 111.586      2.80355      -4    0.00324118       199.357      0.991492
# 111.022      2.36497      -3    0.00141589       199.362      0.756054
# 110.753      1.92172      -4   0.000312911       199.363      0.886676
# 110.67       1.50538       0   0.000110050       199.363      0.839389
# 110.669      1.36872       0   3.68695e-05       199.363      0.838334
# 110.669      1.3676        1   5.04737e-06       199.363      0.838359
# 110.669      1.36681       1   1.07271e-06       199.363      0.838384
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  2.2567E-02| -0.1100  -0.0125   0.9939
#  5.0528E-01|  0.9939  -0.0013   0.1100
#  6.7752E+07| -0.0000   0.9999   0.0126
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    6.633e-01  -3.331e+03  -4.179e+01
#   -3.331e+03   6.774e+07   8.509e+05
#   -4.179e+01   8.509e+05   1.069e+04
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.07271E-06  +/-  0.814417
#    2    2   bbody      kT         keV      199.363      +/-  8230.48
#    3    2   bbody      norm                0.838384     +/-  103.390
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                110.6691     using 153 bins.
#
# Test statistic : Chi-Squared                302.9497     using 153 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 2.1235e-12 with 150 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic              6.941801e+06     using 153 bins.
#
# Test statistic : Chi-Squared              1.019650e+12     using 153 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 0.000000e+00 with 150 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 1.70358e+06  1.74293e+06  -1      0.302185       5.98480      0.387866
# 170.485      1.84667e+06  -2       6530.14      -1.25228     0.0921245
# 170.485      8.02381e-17  -3       1232.20       5.57144     0.0193037
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  4.3820E+36| -0.0007  -0.2222   0.9750
#  1.5134E+44|  0.0223  -0.9748  -0.2222
#  6.6361E+51|  0.9998   0.0216   0.0056
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    6.633e+51   1.434e+50   3.711e+49
#    1.434e+50   3.100e+48   8.023e+47
#    3.711e+49   8.023e+47   2.077e+47
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1232.20      +/-  8.14420E+25
#    2    2   powerlaw   PhoIndex            5.57144      +/-  1.76064E+24
#    3    2   powerlaw   norm                1.93037E-02  +/-  4.55693E+23
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                170.4852     using 153 bins.
#
# Test statistic : Chi-Squared                146.5739     using 153 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 5.6386e-01 with 150 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic              2.893034e+06     using 153 bins.
#
# Test statistic : Chi-Squared              2.075154e+11     using 153 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 0.000000e+00 with 150 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 1.44615e+06  538898       -3     0.0742783       198.150      0.423957
# 4083.1       674779       -1       103.926       199.284      0.171883
# 342.656      4067.79       0       202.700       199.328     0.0837516
# 158.407      518.387       0       207.540       199.362    0.00744617
# 157.263      8.29928       0       193.711       199.363    0.00668381
# 155.975      26.5061       0       180.541       199.363    0.00590648
# 154.516      45.0465       0       167.988       199.363    0.00517644
# 153.572      65.5758      -1       84.0386       199.363   0.000301144
# 121.565      6924.13      -2       5.05494       199.363   0.000121784
# 119.928      24341        -1       3.52790       199.363   0.000105982
# 118.497      29739.6      -1       2.45317       199.363   9.37529e-05
# 117.472      36517.7      -1       1.69403       199.363   8.41990e-05
# 116.791      44980.2      -1       1.23284       199.363   7.67533e-05
# 116.321      52251.4      -1      0.937759       199.363   7.11288e-05
# 116.045      58249.5      -1      0.711016       199.363   6.68129e-05
# 115.93       65455.1      -1      0.520314       199.363   6.31944e-05
# 113.392      75251         0      0.506431       199.363   5.63083e-05
# 112.409      51203.2       0      0.483635       200.000   5.24148e-05
# 111.332      55440.8      -1      0.406806       200.000   4.32318e-05
# 111.204      2891.35      -2      0.345007       200.000   4.21101e-05
# 111.19       80.5791      -3      0.325480       200.000   4.16010e-05
# 111.189      11.8028      -4      0.320612       200.000   4.14737e-05
# 111.189      0.873779     -5      0.319486       200.000   4.14438e-05
# 111.189      0.0360665     1      0.319483       200.000   4.14439e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  4.8409E-11| -0.0000  -0.0000   1.0000
#  3.0687E-02|  1.0000   0.0000   0.0000
#  1.5802E+07| -0.0000   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    6.717e-02  -7.593e+02  -2.156e-05
#   -7.593e+02   1.580e+07   4.658e-01
#   -2.156e-05   4.658e-01   1.380e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.319483     +/-  0.259169
#    2    2   bremss     kT         keV      200.000      +/-  3975.18
#    3    2   bremss     norm                4.14439E-05  +/-  1.17468E-04
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                111.1885     using 153 bins.
#
# Test statistic : Chi-Squared                431.4707     using 153 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 4.7734e-29 with 150 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*apec")
mo.apec.kT = 4.0
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : C-Statistic              1.083299e+06     using 153 bins.
#
# Test statistic : Chi-Squared              2.897853e+10     using 153 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 0.000000e+00 with 150 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic              1.054559e+06     using 153 bins.
#
# Test statistic : Chi-Squared              2.608417e+10     using 153 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 0.000000e+00 with 150 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 316971       202847       -3      0.381329       34.3349      0.231527
# 139800       232612       -4     0.0535293       59.1043     0.0813271
# 43913.7      291435       -1    0.00180602       63.9412     0.0234264
# 1703.53      319375       -1       5.56847       63.9892    0.00568158
# 493.652      54871.5      -2       2.41866       63.9957    0.00122830
# 423.651      76340.3      -1      0.188894       63.9980   0.000469647
# 165.784      180954       -1      0.244887       63.9999   0.000209570
# 131.029      113075       -1      0.221255       64.0000   0.000146593
# 124.421      80973.3      -1      0.254248       64.0000   0.000136651
# 123.311      66901.1      -1      0.252500       64.0000   0.000133601
# 122.733      64523.3      -1      0.254027       64.0000   0.000132294
# 122.503      63100.3      -1      0.254624       64.0000   0.000131763
# 122.408      62521.4      -1      0.254877       64.0000   0.000131543
# 122.369      62280.3      -1      0.254983       64.0000   0.000131452
# 122.352      62179.9      -1      0.255027       64.0000   0.000131414
# 122.346      62138.1      -1      0.255046       64.0000   0.000131398
# 122.343      62120.6      -1      0.255054       64.0000   0.000131391
# 122.342      62113.3      -1      0.255057       64.0000   0.000131388
# 122.341      62110.3      -1      0.255058       64.0000   0.000131387
# 122.341      62109.1      -1      0.255059       64.0000   0.000131387
# 122.341      62108.5      -1      0.255059       64.0000   0.000131387
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  3.6561E-10| -0.0001  -0.0000   1.0000
#  1.4452E-02|  1.0000   0.0002   0.0001
#  3.0566E+05| -0.0002   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.817e-02  -6.477e+01  -1.319e-05
#   -6.477e+01   3.057e+05   6.978e-02
#   -1.319e-05   6.978e-02   1.647e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.255059     +/-  0.167854
#    2    2   apec       kT         keV      64.0000      +/-  552.869
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.31387E-04  +/-  1.28351E-04
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                122.3407     using 153 bins.
#
# Test statistic : Chi-Squared                806.0930     using 153 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 2.1070e-90 with 150 degrees of freedom

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 3.9006e-05 photons (2.302e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
plx = 0.2744
d_kpc = 1/plx
F_x = 1.6234*10**-13

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 2.5789255831167283e+32

# %%
import numpy as np
print(d_kpc)
print(np.log10(L_x))
# Out:
# 3.644314868804665
# 32.411438810417096

# %%
F_opt = 1.05*10**-5 * 10**(-0.4*19.88)
print('Optical Flux: ',F_opt)
print('F_x / F_opt: ', np.log10(F_x/F_opt))
# Out:
# Optical Flux:  1.1727064101695894e-13
# F_x / F_opt:  0.14123624256114856

# %%
AllModels.clear()
mo = Model("tbabs*(bbody+powerlaw)")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>(bbody<2> + powerlaw<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
#    4    3   powerlaw   PhoIndex            1.00000      +/-  0.0
#    5    3   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic              1.868593e+07     using 153 bins.
#
# Test statistic : Chi-Squared              6.438373e+12     using 153 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 0.000000e+00 with 148 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        3:norm    4:PhoIndex        5:norm
# 507210       1.80928e+06  -1      0.446168       199.319     0.0372216       6.32020      0.224447
# 170.487      334047       -2       2181.46       199.352    0.00130489      -1.06942     0.0897385
# 170.485      0.00222913   -3       597.535       199.363   0.000275839       8.95517     0.0172937
# 170.485      0.000168324  -3       144.932       199.363   0.000124186       9.37333    0.00204313
# 170.485      0.362394      5       141.323       199.343   0.000129781       8.91482    0.00485420
# 170.458      0.388522      4       108.949       199.082   0.000183289       7.65088     0.0161656
# 169.771      0.761998      3       97.1793       38.8798   0.000541222       7.45392     0.0218370
# 169.078      117.013       2       93.8406       38.2935   0.000564883       6.70360     0.0503518
# 157.67       130.137       1       72.0657       33.5752   0.000766451       5.96352      0.116270
# 142.332      258.778       0       65.1910       24.4697    0.00136634       5.78286      0.150451
# 131.963      389.338       0       59.1957       21.3771    0.00185858       5.65417      0.183117
# 127.721      142.078      -1       45.4649       21.5271    0.00182465       5.78378      0.169308
# 124.173      6.60105      -2       22.9209       20.8806    0.00157876       6.14127     0.0282030
# 111.944      94.8554      -2       6.81498       21.6022    0.00124431       6.67078    0.00848984
# 108.19       70.606       -2       4.13813       21.3560    0.00115705       6.20714    0.00170741
# 105.328      102.032      -2       2.10988       21.3410    0.00107806       5.66585   0.000410652
# 103.71       1033.45      -2       1.30745       21.3801    0.00103775       4.78327   0.000133998
# 100.606      3537.8       -2      0.481671       21.6317    0.00101598       3.47293   2.04499e-05
# 100.458      9017.72      -3      0.466912       22.9853    0.00117793       3.14620   2.07496e-05
# 100.456      307.626      -3      0.435279       24.3079    0.00137300       3.08099   1.90333e-05
# 100.455      627.824      -3      0.478372       25.2646    0.00154961       3.22076   2.14084e-05
# 100.451      819.687      -2      0.444664       25.3795    0.00157120       3.11835   1.95904e-05
# 100.45       286.189      -3      0.466310       26.4634    0.00176850       3.17373   2.07922e-05
# 100.449      325.938      -3      0.436303       27.6436    0.00199565       3.06864   1.90694e-05
# 100.448      543.492      -3      0.469103       28.5888    0.00221487       3.17860   2.09107e-05
# 100.448      542.672      -3      0.429809       29.7321    0.00246468       3.04070   1.86770e-05
# ============================================================
#  Variances and Principal Axes
#                  1        2        3        4        5
#  4.1985E-11| -0.0000  -0.0000   0.0033  -0.0000   1.0000
#  2.2780E-07|  0.0004  -0.0002   1.0000  -0.0002  -0.0033
#  4.8543E-02|  0.9775  -0.0003  -0.0004  -0.2108   0.0000
#  7.1062E+00|  0.2108   0.0082   0.0001   0.9775   0.0000
#  7.5034E+04| -0.0014   1.0000   0.0002  -0.0081  -0.0000
# ------------------------------------------------------------
#
# ============================================================
#   Covariance Matrix
#         1           2           3           4           5
#    5.129e-01  -1.064e+02  -2.361e-02   2.318e+00   3.139e-05
#   -1.064e+02   7.503e+04   1.678e+01  -6.093e+02  -6.426e-03
#   -2.361e-02   1.678e+01   3.755e-03  -1.353e-01  -1.426e-06
#    2.318e+00  -6.093e+02  -1.353e-01   1.174e+01   1.456e-04
#    3.139e-05  -6.426e-03  -1.426e-06   1.456e-04   1.982e-09
# ------------------------------------------------------------
#
# ========================================================================
# Model TBabs<1>(bbody<2> + powerlaw<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.429809     +/-  0.716177
#    2    2   bbody      kT         keV      29.7321      +/-  273.913
#    3    2   bbody      norm                2.46468E-03  +/-  6.12785E-02
#    4    3   powerlaw   PhoIndex            3.04070      +/-  3.42660
#    5    3   powerlaw   norm                1.86770E-05  +/-  4.45217E-05
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                100.4484     using 153 bins.
#
# Test statistic : Chi-Squared                379.3745     using 153 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 2.9860e-22 with 148 degrees of freedom
