# %%
# %load_ext wurlitzer
import glob
import os
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12,8]

Fit.statMethod = "chi"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4

# %%
spec_fnames = glob.glob('*grpspec*')

spec = Spectrum(spec_fnames[0])
Plot.device="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.00005 0.005")
Plot("data")
#spec.ignore("**-0.2 12.0-**")
# Out:
# ***Warning: Detected response matrix energy bin value = 0 (or neg).
#      XSPEC will instead use small finite value (response file will not be altered).
#
# 1 spectrum  in use
#
# Spectral Data File: 0886110301_M251grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  2.658e-03 +/- 4.563e-04 (64.8 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-5
#   Telescope: XMM Instrument: EMOS2  Channel Type: PI
#   Exposure Time: 2.144e+04 sec
#  Using fit statistic: chi
#  Using Background File                0886110301_M251spec_bkg.fits
#   Background Exposure Time: 2.144e+04 sec
#  Using Response (RMF) File            0886110301_M251spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0886110301_M251spec.arf

# %%
AllModels.clear()
mo = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              5.787521e+11     using 5 bins.
#
# Test statistic : Chi-Squared              5.787521e+11     using 5 bins.
#  Null hypothesis probability of 0.000000e+00 with 2 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 5.62374      0.259383     -1     0.0808103       3.27186   6.88450e-06
# 5.07999      146461        0    0.00394932       3.26813   6.97434e-06
# 5.0149       124367        0   8.15994e-05       3.26923   7.03392e-06
# 4.99908      114674        0   2.29509e-05       3.27336   7.07723e-06
# 4.99395      110289        0   8.34559e-06       3.27894   7.11277e-06
# 4.99257      108384        0   1.04445e-06       3.28503   7.14535e-06
# 4.93869      107391        0   3.92041e-07       3.27600   7.18926e-06
# 4.89972      93058.7       0   7.51061e-08       3.26854   7.22573e-06
# 4.87137      80935         0   3.64342e-08       3.26236   7.25606e-06
# 4.85064      70695.2       0   1.74856e-08       3.25723   7.28130e-06
# 4.83537      62065.7       0   8.17042e-09       3.25296   7.30232e-06
# 4.82404      54795.1       0   3.57857e-09       3.24941   7.31982e-06
# 4.81559      48678.9       0   1.30986e-09       3.24644   7.33439e-06
# 4.80922      43537.6       0   1.86736e-10       3.24396   7.34653e-06
# 4.80438      39218.5       0   4.74591e-11       3.24189   7.35665e-06
# 4.80069      35589.6       0   1.28998e-11       3.24015   7.36506e-06
# 4.79783      32547         0   4.24595e-12       3.23868   7.37208e-06
# 4.79563      29983.9       0   2.10609e-12       3.23746   7.37788e-06
# 4.79391      27847.8       0   1.61839e-14       3.23644   7.38264e-06
# 4.79244      26073.2       0   2.14147e-15       3.23551   7.38706e-06
# 4.78974      24440.6       0   8.11099e-16       3.23361   7.39575e-06
# 4.78477      21155         0   3.30419e-16       3.22890   7.41515e-06
# 4.78354      13327.4       0   1.63295e-16       3.22703   7.42003e-06
# 4.78315      10712.2       0   4.56081e-17       3.22610   7.42009e-06
# 4.78299      9838.45       0   2.19509e-17       3.22549   7.41855e-06
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 2.19509e-17 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 4.77947      14326.4      -1   2.19509e-17       3.20452   7.36870e-06
# 4.77344      1406.98      -2   2.19509e-17       3.12533   6.96519e-06
# 4.77042      1372.33      -3   2.19509e-17       3.04362   6.57074e-06
# 4.77019      2552.13      -4   2.19509e-17       3.02302   6.48120e-06
# 4.77019      122.166      -5   2.19509e-17       3.01877   6.46177e-06
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 2.19509e-17 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 4.77019      7.07194      -3   2.19509e-17       3.01792   6.45783e-06
# ==============================
#  Variances and Principal Axes
#                  2        3
#  1.3574E-12| -0.0000   1.0000
#  2.6547E+00|  1.0000   0.0000
# ------------------------------
#
# ========================
#   Covariance Matrix
#         1           2
#    2.655e+00   1.233e-05
#    1.233e-05   5.863e-11
# ------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    2.19509E-17  +/-  -1.00000
#    2    2   bbody      kT         keV      3.01792      +/-  1.62932
#    3    2   bbody      norm                6.45783E-06  +/-  7.65679E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  4.7702     using 5 bins.
#
# Test statistic : Chi-Squared                  4.7702     using 5 bins.
#  Null hypothesis probability of 9.2080e-02 with 2 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              3.408702e+10     using 5 bins.
#
# Test statistic : Chi-Squared              3.408702e+10     using 5 bins.
#  Null hypothesis probability of 0.000000e+00 with 2 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 11.6879      0.0763639     0       1.00034       12.8929   2.40961e-05
# 10.7435      17995.9       0      0.826005       43.6731   2.45164e-05
# 9.40767      43285        -1      0.512199       198.233   3.48668e-05
# 9.37647      17261.4      -1      0.398245       199.125   3.91646e-05
# 9.25459      24634.6       0      0.386777       199.271   3.81353e-05
# 9.18231      19209.6       0      0.371899       199.321   3.73545e-05
# 9.13132      16013.7       0      0.355312       199.362   3.67257e-05
# 9.09081      14123.6       0      0.338175       199.363   3.61917e-05
# 9.05609      13014.3       0      0.321251       199.363   3.57198e-05
# 9.02537      12344.1       0      0.305034       199.363   3.52917e-05
# 8.99795      11915.6       0      0.289835       199.363   3.48975e-05
# 8.97358      11605.9       0      0.275826       199.363   3.45324e-05
# 8.95215      11348.1       0      0.263089       199.363   3.41943e-05
# 8.93352      11102.5       0      0.251636       199.363   3.38820e-05
# 8.91755      10849.2       0      0.241433       199.363   3.35950e-05
# 8.90401      10580.5       0      0.232412       199.363   3.33326e-05
# 8.89266      10296.6       0      0.224484       199.363   3.30943e-05
# 8.88324      10001.5       0      0.217550       199.363   3.28791e-05
# 8.87548      9701.28       0      0.211511       199.363   3.26859e-05
# 8.86913      9402.22       0      0.206266       199.363   3.25133e-05
# 8.86395      9110.15       0      0.201723       199.363   3.23599e-05
# 8.85975      8829.89       0      0.197796       199.363   3.22241e-05
# 8.85363      8565.08       0      0.194405       200.000   3.21043e-05
# 8.82999      12024.1      -1      0.188304       200.000   3.11564e-05
# 8.82788      1240.44      -2      0.181709       200.000   3.08938e-05
# 8.82739      31.1237      -3      0.178338       200.000   3.08010e-05
# 8.82727      1.80436      -4      0.176716       200.000   3.07569e-05
# 8.82725      0.207344     -5      0.175941       200.000   3.07358e-05
# 8.82725      0.0252587     0      0.175839       200.000   3.07411e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  3.5376E-11| -0.0000  -0.0000   1.0000
#  3.3113E-02|  1.0000   0.0000   0.0000
#  3.5362E+07| -0.0000   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    7.103e-02  -1.158e+03  -2.547e-05
#   -1.158e+03   3.536e+07   8.054e-01
#   -2.547e-05   8.054e-01   1.840e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.175839     +/-  0.266515
#    2    2   bremss     kT         keV      200.000      +/-  5946.64
#    3    2   bremss     norm                3.07411E-05  +/-  1.35662E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  8.8272     using 5 bins.
#
# Test statistic : Chi-Squared                  8.8272     using 5 bins.
#  Null hypothesis probability of 1.2111e-02 with 2 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              5.900400e+09     using 5 bins.
#
# Test statistic : Chi-Squared              5.900400e+09     using 5 bins.
#  Null hypothesis probability of 0.000000e+00 with 2 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 21.558       0.416708     -2       1.21711      0.929847   6.43191e-05
# 21.0784      3295.76      -1       1.20593       1.16758   5.49769e-05
# 19.2818      9246.56      -1      0.914480       1.75331   4.75517e-05
# 18.6489      15844.3      -2      0.438724       8.65785   2.36831e-05
# 11.7261      83249.7      -3     0.0549756       49.6242   3.76013e-05
# 9.59186      42543.4      -1      0.101616       57.8899   5.75565e-05
# 9.48297      2448.75       0      0.114132       61.6300   5.84778e-05
# 9.43056      201.899       0      0.123650       63.2774   5.96346e-05
# 9.40435      72.3305       0      0.131348       63.7029   6.07434e-05
# 9.3891       1031          0      0.138009       63.9350   6.16772e-05
# 9.38156      2002.49       0      0.143825       63.9973   6.24533e-05
# 9.37804      2843.34       0      0.148940       63.9988   6.30900e-05
# 9.37627      3508.93       0      0.153433       63.9997   6.36125e-05
# 9.37554      4009.61       0      0.157361       63.9999   6.40453e-05
# 9.37545      4394.22       0      0.160783       64.0000   6.44065e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  1.4731E-10| -0.0001  -0.0000   1.0000
#  2.5686E-02|  1.0000   0.0002   0.0001
#  1.0795E+06| -0.0002   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    5.344e-02  -1.731e+02  -1.956e-05
#   -1.731e+02   1.079e+06   1.321e-01
#   -1.956e-05   1.321e-01   1.642e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.160783     +/-  0.231173
#    2    2   apec       kT         keV      64.0000      +/-  1038.97
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                6.44065E-05  +/-  1.28154E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  9.3754     using 5 bins.
#
# Test statistic : Chi-Squared                  9.3754     using 5 bins.
#  Null hypothesis probability of 9.2076e-03 with 2 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.809237e+11     using 5 bins.
#
# Test statistic : Chi-Squared              1.809237e+11     using 5 bins.
#  Null hypothesis probability of 0.000000e+00 with 2 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 7.2743       0.714139     -1      0.708731      0.738478   8.21392e-06
# 5.2426       60989.2      -1      0.274701      0.470245   5.55720e-06
# 3.88415      98908.7      -1     0.0626793      0.212055   3.73016e-06
# 3.33662      306943       -1     0.0223461   -0.00227398   2.97552e-06
# 3.26139      322905       -1   0.000818853     -0.130056   2.55332e-06
# 3.12877      353187        0   0.000157542     -0.142957   2.59637e-06
# 3.09942      238702        0   7.78123e-05     -0.147304   2.61062e-06
# 3.09101      198943        0   3.83294e-05     -0.148879   2.61523e-06
# 3.08841      185139        0   1.86526e-05     -0.149509   2.61654e-06
# 3.08768      180357        0   8.82410e-06     -0.149808   2.61671e-06
# 3.0876       178726        0   3.91062e-06     -0.149991   2.61649e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  2.3103E-13| -0.0000  -0.0000   1.0000
#  5.5601E-02|  0.8699  -0.4933  -0.0000
#  3.4713E-01|  0.4933   0.8699   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.265e-01   1.251e-01   5.040e-07
#    1.251e-01   2.762e-01   9.942e-07
#    5.040e-07   9.942e-07   3.851e-12
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    3.91062E-06  +/-  0.355713
#    2    2   powerlaw   PhoIndex            -0.149991    +/-  0.525544
#    3    2   powerlaw   norm                2.61649E-06  +/-  1.96241E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  3.0876     using 5 bins.
#
# Test statistic : Chi-Squared                  3.0876     using 5 bins.
#  Null hypothesis probability of 2.1357e-01 with 2 degrees of freedom

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 3.9277e-05 photons (4.0753e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
#plx = 0.45
d_kpc = 8
F_x = 4.0753*10**-13

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 3.1197589646600196e+33

# %%
F_opt = 1.05*10**-5 * 10**(-0.4*20.78)
print('Optical Flux: ',F_opt)
print('F_x / F_opt: ', F_x/F_opt)
# Out:
# Optical Flux:  5.119049146085544e-14
# F_x / F_opt:  7.961048787969379
