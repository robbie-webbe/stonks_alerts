# %%
# %load_ext wurlitzer
import glob
import os
import numpy as np
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12,8]

Fit.statMethod = "chi"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4
os.chdir('other_obs')

# %%
spec = Spectrum('P0844101101PNS001SRSPEC0081.FTZ',backFile='P0844101101PNS001BGSPEC0081.FTZ')
spec.response.arf='P0844101101PNS001SRCARF0081.FTZ'

Plot.device="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.00001 0.005")
Plot("data")
#spec.ignore("**-0.2 12.0-**")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: P0844101101PNS001SRSPEC0081.FTZ  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  8.132e-03 +/- 8.369e-04 (58.4 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-14
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 2.024e+04 sec
#  Using fit statistic: chi
#  Using Background File                P0844101101PNS001BGSPEC0081.FTZ
#   Background Exposure Time: 2.024e+04 sec
#  Using Response (RMF) File            epn_e3_ff20_sdY1.rmf for Source 1
#  Using Auxiliary Response (ARF) File  P0844101101PNS001SRCARF0081.FTZ
#
# Net count rate (cts/s) for Spectrum:1  8.132e-03 +/- 8.369e-04 (58.4 % total)
# Spectrum 1  Spectral Data File: P0844101101PNS001SRSPEC0081.FTZ
# Net count rate (cts/s) for Spectrum:1  8.132e-03 +/- 8.369e-04 (58.4 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-14
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 2.024e+04 sec
#  Using fit statistic: chi
#  Using Background File                P0844101101PNS001BGSPEC0081.FTZ
#   Background Exposure Time: 2.024e+04 sec
#  Using Response (RMF) File            epn_e3_ff20_sdY1.rmf for Source 1
#  Using Auxiliary Response (ARF) File  P0844101101PNS001SRCARF0081.FTZ
#
#  Spectral data counts: 282
#  Model predicted rate: 0.0
#
# Arf successfully loaded.

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              3.491789e+11     using 14 bins.
#
# Test statistic : Chi-Squared              3.491789e+11     using 14 bins.
#  Null hypothesis probability of 0.000000e+00 with 11 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:n
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    30.6546      +/-  10.2824
#    2    2   powerlaw   PhoIndex            2.61325      +/-  1.04103
#    3    2   powerlaw   norm                2.23919E-03  +/-  4.68942E-03
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 15.8625     using 14 bins.
#
# Test statistic : Chi-Squared                 15.8625     using 14 bins.
#  Null hypothesis probability of 1.4631e-01 with 11 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              7.891250e+10     using 14 bins.
#
# Test statistic : Chi-Squared              7.891250e+10     using 14 bins.
#  Null hypothesis probability of 0.000000e+00 with 11 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 109.812      0.408884      0       1.22749       44.5211   7.44107e-06
# 93.2174      159338       -1       3.24857       199.139   3.81212e-05
# 44.2207      69404.6      -2       18.8095       199.281   0.000202520
# 44.1107      41484.7      -2       22.3538       68.1441   0.000183520
# 32.56        45851         0       20.5990       32.0555   0.000198058
# 29.9487      40675.2       0       19.7147       16.5686   0.000208423
# 20.4524      37296.6       0       18.0665       29.0845   0.000246182
# 18.8489      17395         0       18.1636       22.2558   0.000267690
# 17.7272      9505.93      -1       21.4966       11.1622   0.000330064
# 16.2754      9942.64      -1       22.9137       11.7473   0.000378563
# 16.0826      1647.17      -1       23.6098       9.98411   0.000408723
# 15.9381      1773.63      -1       24.1847       9.16881   0.000436008
# 15.8525      978.418      -1       24.6386       8.57330   0.000458512
# 15.795       670.371      -1       25.0047       8.13213   0.000477834
# 15.7556      484.992      -1       25.3075       7.79491   0.000494559
# 15.7271      367.226      -1       25.5615       7.52703   0.000509246
# 15.7055      295.345      -1       25.7774       7.30943   0.000522407
# 15.6888      233.502      -2       26.8494       6.26555   0.000587339
# 15.6341      1380.78      -3       27.8067       5.65908   0.000662233
# 15.6091      785.771      -4       27.6850       5.76293   0.000659972
# 15.6091      8.43693      -5       27.7344       5.73274   0.000663948
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  4.1932E-09| -0.0000   0.0001   1.0000
#  5.5628E+00| -0.4650  -0.8853   0.0001
#  8.2333E+01|  0.8853  -0.4650   0.0001
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    6.573e+01  -3.160e+01   4.399e-03
#   -3.160e+01   2.216e+01  -2.725e-03
#    4.399e-03  -2.725e-03   3.520e-07
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    27.7344      +/-  8.10767
#    2    2   bremss     kT         keV      5.73274      +/-  4.70755
#    3    2   bremss     norm                6.63948E-04  +/-  5.93323E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 15.6091     using 14 bins.
#
# Test statistic : Chi-Squared                 15.6091     using 14 bins.
#  Null hypothesis probability of 1.5628e-01 with 11 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              1.814837e+10     using 14 bins.
#
# Test statistic : Chi-Squared              1.814837e+10     using 14 bins.
#  Null hypothesis probability of 0.000000e+00 with 11 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 117.739      0.320797     -3      0.111902       45.8632   2.17473e-06
# 109.497      124676       -1       1.73048       62.5665   2.36993e-05
# 45.2005      56749.2      -2       8.16748       63.4746   0.000445573
# 35.5276      1615.43      -3       17.9844       30.4170   0.000464199
# 19.5372      17734.6      -1       20.2103       11.7278   0.000759826
# 17.3306      3830.27      -2       21.3345       19.5200   0.000846015
# 17.0651      1861.16      -3       20.3831       18.7135   0.000859476
# 17.0559      52.6681      -4       20.7640       19.8713   0.000870977
# 17.0557      10.6231      -5       20.6303       18.8309   0.000866171
# 17.0546      7.84218      -6       20.6850       19.8370   0.000868451
# 17.0541      9.44598      -1       20.6682       18.9320   0.000867555
# 17.0537      2.09848      -1       20.6689       19.7491   0.000867874
# 17.0505      9.4864        0       20.6681       19.2987   0.000867802
# 17.0505      2.87314       1       20.6681       19.2943   0.000867801
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  7.3485E-09| -0.0000  -0.0000   1.0000
#  1.5146E+01|  1.0000   0.0080   0.0000
#  1.9197E+02| -0.0080   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.516e+01  -1.417e+00   4.850e-04
#   -1.417e+00   1.920e+02   9.781e-05
#    4.850e-04   9.781e-05   2.297e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    20.6681      +/-  3.89321
#    2    2   apec       kT         keV      19.2943      +/-  13.8548
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                8.67801E-04  +/-  1.51575E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 17.0505     using 14 bins.
#
# Test statistic : Chi-Squared                 17.0505     using 14 bins.
#  Null hypothesis probability of 1.0639e-01 with 11 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              7.386529e+11     using 14 bins.
#
# Test statistic : Chi-Squared              7.386529e+11     using 14 bins.
#  Null hypothesis probability of 0.000000e+00 with 11 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 48.9164      2.5889       -3       3.54142       4.91947   2.46338e-05
# 31.3535      265604       -4       19.4413       1.35878   9.15062e-06
# 16.3211      871098       -5       21.1088       1.70466   1.54781e-05
# 15.248       178492       -6       19.7251       1.60928   1.57023e-05
# 15.2244      6594.12      -7       20.6738       1.59332   1.61457e-05
# 15.2231      703.087      -8       20.3534       1.60526   1.60119e-05
# 15.223       207.376      -9       20.4575       1.60151   1.60582e-05
# 15.223       18.3874     -10       20.4249       1.60268   1.60443e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  2.4726E-12| -0.0000  -0.0000   1.0000
#  5.5507E-02| -0.0430  -0.9991  -0.0000
#  5.5242E+01|  0.9991  -0.0430   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    5.514e+01  -2.369e+00   2.214e-05
#   -2.369e+00   1.574e-01  -6.954e-07
#    2.214e-05  -6.954e-07   1.254e-11
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    20.4249      +/-  7.42566
#    2    2   bbody      kT         keV      1.60268      +/-  0.396739
#    3    2   bbody      norm                1.60443E-05  +/-  3.54115E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 15.2230     using 14 bins.
#
# Test statistic : Chi-Squared                 15.2230     using 14 bins.
#  Null hypothesis probability of 1.7251e-01 with 11 degrees of freedom

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 5.3606e-05 photons (5.6379e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
#plx = 1.4843
d_kpc = 8
F_x = 5.6*10**-13

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 4.2869605187583995e+33

# %%
F_opt = 1.05*10**-5 * 10**(-0.4*20.78)
print('Optical Flux: ',F_opt)
print('F_x / F_opt: ', F_x/F_opt)
# Out:
# Optical Flux:  5.119049146085544e-14
# F_x / F_opt:  10.939531620403042
