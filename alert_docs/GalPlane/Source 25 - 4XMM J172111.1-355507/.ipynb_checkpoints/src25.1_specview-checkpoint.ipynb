# %%
# %load_ext wurlitzer
import glob
import os
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12,8]
os.chdir('pps/')

Fit.statMethod = "chi"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4

# %%
import numpy as np
out_arr = np.full((5,19),-np.inf,dtype=object)

# %%
spec_fnames = glob.glob('P*70901M2S*SRSPEC*.FTZ')

spec = Spectrum(spec_fnames[0])
Plot.device="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.00005 0.002")
Plot("data")
spec.ignore("**-0.2 12.0-**")
# Out:
# ***Warning: Detected response matrix energy bin value = 0 (or neg).
#      XSPEC will instead use small finite value (response file will not be altered).
#
# 1 spectrum  in use
#
# Spectral Data File: P0886070901M2S002SRSPEC001C.FTZ  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  4.199e-03 +/- 4.691e-04 (64.4 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-9
#   Telescope: XMM Instrument: EMOS2  Channel Type: PI
#   Exposure Time: 2.975e+04 sec
#  Using fit statistic: chi
#  Using Background File                P0886070901M2S002BGSPEC001C.FTZ
#   Background Exposure Time: 2.975e+04 sec
#  Using Response (RMF) File            m2_e13_im_pall_o.rmf for Source 1
#  Using Auxiliary Response (ARF) File  P0886070901M2S002SRCARF001C.FTZ
#       No channels ignored (no channels in specified range)
#      1 channels (9) ignored in spectrum #     1

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              1.156087e+11     using 8 bins.
#
# Test statistic : Chi-Squared              1.156087e+11     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 5 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 1.70377      0.429792     -3      0.768378      0.880424   2.07899e-05
# 1.65381      25759.6      -4      0.705937      0.830382   1.97268e-05
# 1.65279      1338.65      -5      0.692629      0.821664   1.94774e-05
# 1.65272      99.3057      -6      0.688886      0.819007   1.94000e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  4.8627E-12| -0.0000  -0.0000   1.0000
#  3.6671E-02|  0.7053  -0.7089  -0.0000
#  5.1066E-01|  0.7089   0.7053   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.749e-01   2.370e-01   6.589e-06
#    2.370e-01   2.725e-01   6.979e-06
#    6.589e-06   6.979e-06   1.875e-10
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.688886     +/-  0.524272
#    2    2   powerlaw   PhoIndex            0.819007     +/-  0.521983
#    3    2   powerlaw   norm                1.94000E-05  +/-  1.36946E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  1.6527     using 8 bins.
#
# Test statistic : Chi-Squared                  1.6527     using 8 bins.
#  Null hypothesis probability of 8.9480e-01 with 5 degrees of freedom

# %%
Fit.error("1")
Fit.error("2")

out_arr[1,0] = 'powerlaw'
out_arr[1,1:4] = mo.TBabs.nH.values[0], mo.TBabs.nH.values[0] - mo.TBabs.nH.error[0], mo.TBabs.nH.error[1] - mo.TBabs.nH.values[0]
out_arr[1,14:17] = mo.powerlaw.PhoIndex.values[0], mo.powerlaw.PhoIndex.values[0] - mo.powerlaw.PhoIndex.error[0], mo.powerlaw.PhoIndex.error[1] - mo.powerlaw.PhoIndex.values[0]
out_arr[1,-2:] = Fit.dof, Fit.statistic / Fit.dof
# Out:
#  Parameter   Confidence Range (2.706)
#      1    0.0643129        2.261    (-0.623587,1.5731)
#  Parameter   Confidence Range (2.706)
#      2    0.0542334      1.97328    (-0.763875,1.15517)

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
mo.bremss.kT = 4.0
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              2.357706e+10     using 8 bins.
#
# Test statistic : Chi-Squared              2.357706e+10     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 5 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              1.840022e+10     using 8 bins.
#
# Test statistic : Chi-Squared              1.840022e+10     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 5 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 8.20177      2.26595      -1       1.14482       7.94404   4.73096e-05
# 5.97643      86126.6      -1       1.00215       22.7130   4.79521e-05
# 3.0324       80817.4      -2      0.831850       93.9771   7.31815e-05
# 2.1854       1043.88      -2      0.984197       199.187   9.51112e-05
# 2.08123      4608.18      -1       1.04876       199.144   9.83495e-05
# 2.05893      2477.74      -1       1.07535       199.165   0.000100368
# 2.05738      167.501       0       1.08005       199.174   0.000100480
# 2.05649      1.19514       0       1.08353       199.181   0.000100597
# 2.05594      36.5879       0       1.08619       199.189   0.000100707
# 2.05558      10.4605       0       1.08827       199.196   0.000100807
# 2.05535      41.4254       0       1.08994       199.205   0.000100893
# 2.0552       99.799        0       1.09130       199.214   0.000100967
# 2.05511      156.356       0       1.09241       199.223   0.000101029
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.3117E-10| -0.0000  -0.0000   1.0000
#  1.0102E-01|  1.0000   0.0002   0.0000
#  5.3674E+06| -0.0002   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    3.554e-01  -1.168e+03  -1.625e-04
#   -1.168e+03   5.367e+06   7.639e-01
#   -1.625e-04   7.639e-01   1.090e-07
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.09241      +/-  0.596140
#    2    2   bremss     kT         keV      199.223      +/-  2316.77
#    3    2   bremss     norm                1.01029E-04  +/-  3.30123E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  2.0551     using 8 bins.
#
# Test statistic : Chi-Squared                  2.0551     using 8 bins.
#  Null hypothesis probability of 8.4147e-01 with 5 degrees of freedom

# %%
Fit.error("1")
Fit.error("2")

out_arr[3,0] = 'bremss'
out_arr[3,1:4] = mo.TBabs.nH.values[0], mo.TBabs.nH.values[0] - mo.TBabs.nH.error[0], mo.TBabs.nH.error[1] - mo.TBabs.nH.values[0]
out_arr[3,4:7] = mo.bremss.kT.values[0], mo.bremss.kT.values[0] - mo.bremss.kT.error[0], mo.bremss.kT.error[1] - mo.bremss.kT.values[0]
out_arr[3,-2:] = Fit.dof, Fit.statistic / Fit.dof
# Out:
#  Parameter   Confidence Range (2.706)
#      1     0.608476      1.83304    (-0.484639,0.739929)
#  Parameter   Confidence Range (2.706)
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 2.05479      0.000639732   0       1.09797       199.232   0.000101157
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.3182E-10| -0.0000  -0.0000   1.0000
#  1.0209E-01|  1.0000   0.0002   0.0000
#  5.3793E+06| -0.0002   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    3.599e-01  -1.178e+03  -1.644e-04
#   -1.178e+03   5.379e+06   7.683e-01
#   -1.644e-04   7.683e-01   1.100e-07
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.09797      +/-  0.599948
#    2    2   bremss     kT         keV      199.232      +/-  2319.34
#    3    2   bremss     norm                1.01157E-04  +/-  3.31662E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  2.0548     using 8 bins.
#
# Test statistic : Chi-Squared                  2.0548     using 8 bins.
#  Null hypothesis probability of 8.4151e-01 with 5 degrees of freedom
# ***Warning: New best fit found, fit parameters will be set to new values.
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
# ***Warning: Zero alpha-matrix diagonal element for parameter 3
#  Parameter 1 is pegged at 1.09797 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
#  Parameter 3 is pegged at 0.000101157 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
#
#  Fit error occurred during lower bound error calculation.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 2.05444      7.87903e-05   0       1.09800       200.000   0.000101272
# 2.05444      0.180321      2       1.09800       200.000   0.000101272
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.3212E-10| -0.0000  -0.0000   1.0000
#  1.0211E-01|  1.0000   0.0001   0.0000
#  2.1924E+07| -0.0001   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    3.634e-01  -2.394e+03  -1.663e-04
#   -2.394e+03   2.192e+07   1.558e+00
#   -1.663e-04   1.558e+00   1.110e-07
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.09800      +/-  0.602858
#    2    2   bremss     kT         keV      200.000      +/-  4682.30
#    3    2   bremss     norm                1.01272E-04  +/-  3.33098E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  2.0544     using 8 bins.
#
# Test statistic : Chi-Squared                  2.0544     using 8 bins.
#  Null hypothesis probability of 8.4156e-01 with 5 degrees of freedom
# ***Warning: New best fit found, fit parameters will be set to new values.
#
# ***Warning: Number of trials exceeded before bracketing of delta fit-stat.
# Last attempt: 199.363, with delta statistic: 0.000289568
#
# Continue error search in this direction?
# *** Parameter lower bound is INVALID.
#
#
# ***Warning: Number of trials exceeded before bracketing of delta fit-stat.
# Last attempt: 200, with delta statistic: 0
#
# Continue error search in this direction?
# *** Parameter upper bound is INVALID.
#
#      2            0            0    (-200,-200)
# ***XSPEC Error:  No variable parameters for fit

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              6.354123e+09     using 8 bins.
#
# Test statistic : Chi-Squared              6.354123e+09     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 5 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 41.6696      6.48303      -1      0.973025       2.63076   5.26083e-05
# 30.2648      91462.8      -2      0.393949       19.1864   5.13451e-05
# 29.2784      107402       -3      0.444982       46.5525   0.000203467
# 7.9095       93325.1      -1      0.616078       63.5266   0.000195663
# 3.92515      26534.1      -1      0.816046       63.8316   0.000203835
# 2.70847      11519.2      -1      0.974458       63.9304   0.000212557
# 2.40185      5995.38      -1       1.07006       63.9707   0.000219169
# 2.34557      4525.71      -1       1.11751       63.9907   0.000223393
# 2.25986      4500.38       0       1.13693       63.9976   0.000221657
# 2.23117      2607.18       0       1.14878       63.9994   0.000220798
# 2.22097      1594.45       0       1.15609       63.9998   0.000220411
# 2.21703      1057.39       0       1.16072       64.0000   0.000220268
# 2.21536      776.878       0       1.16375       64.0000   0.000220249
# 2.2146       634.212       0       1.16582       64.0000   0.000220288
# 2.21423      564.967       0       1.16729       64.0000   0.000220350
# 2.21406      534.345       0       1.16839       64.0000   0.000220417
# 2.21398      523.604       0       1.16922       64.0000   0.000220483
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  6.2160E-10| -0.0001  -0.0000   1.0000
#  1.0700E-01|  1.0000   0.0006   0.0001
#  5.6202E+05| -0.0006   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    3.173e-01  -3.438e+02  -1.161e-04
#   -3.438e+02   5.620e+05   2.037e-01
#   -1.161e-04   2.037e-01   7.516e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.16922      +/-  0.563280
#    2    2   apec       kT         keV      64.0000      +/-  749.682
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                2.20483E-04  +/-  2.74148E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  2.2140     using 8 bins.
#
# Test statistic : Chi-Squared                  2.2140     using 8 bins.
#  Null hypothesis probability of 8.1881e-01 with 5 degrees of freedom

# %%
Fit.error("1")
Fit.error("2")

out_arr[2,0] = 'apec'
out_arr[2,1:4] = mo.TBabs.nH.values[0], mo.TBabs.nH.values[0] - mo.TBabs.nH.error[0], mo.TBabs.nH.error[1] - mo.TBabs.nH.values[0]
out_arr[2,13] = mo.apec.Abundanc.values[0]
out_arr[2,4:7] = mo.apec.kT.values[0], mo.apec.kT.values[0] - mo.apec.kT.error[0], mo.apec.kT.error[1] - mo.apec.kT.values[0]
out_arr[2,-2:] = Fit.dof, Fit.statistic / Fit.dof
# Out:
#  Parameter   Confidence Range (2.706)
#      1     0.660573      2.33433    (-0.508779,1.16498)
#  Parameter   Confidence Range (2.706)
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 2.21223      0.000865731   0       1.17464       63.9974   0.000219946
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  6.2441E-10| -0.0001  -0.0000   1.0000
#  1.0884E-01|  1.0000   0.0012   0.0001
#  1.4202E+05| -0.0012   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    3.231e-01  -1.744e+02  -1.174e-04
#   -1.744e+02   1.420e+05   1.027e-01
#   -1.174e-04   1.027e-01   7.553e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.17464      +/-  0.568402
#    2    2   apec       kT         keV      63.9974      +/-  376.855
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                2.19946E-04  +/-  2.74821E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  2.2122     using 8 bins.
#
# Test statistic : Chi-Squared                  2.2122     using 8 bins.
#  Null hypothesis probability of 8.1907e-01 with 5 degrees of freedom
# ***Warning: New best fit found, fit parameters will be set to new values.
#
# ***Warning: Number of trials exceeded before convergence.
# Current trial values 11.3708, 0.008
# and delta statistic 0.77419, 74.7438
#
# Continue error search in this direction? ***Warning: Parameter pegged at hard limit: 64
#      2      5.68942            0    (-58.3093,-63.9988)

# %%
AllModels.clear()
mo = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              3.465561e+11     using 8 bins.
#
# Test statistic : Chi-Squared              3.465561e+11     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 5 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 0.824264     1.68645      -3      0.175684       1.39774   3.19538e-06
# 0.783358     58838.5      -4      0.181231       1.34896   3.00589e-06
# 0.782999     14375.1      -5      0.180161       1.35224   3.02072e-06
# 0.782999     90.7266      -6      0.180225       1.35211   3.02036e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.1565E-13| -0.0000  -0.0000   1.0000
#  2.7760E-02| -0.7128  -0.7013  -0.0000
#  1.4588E-01|  0.7013  -0.7128  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    8.586e-02  -5.905e-02  -9.707e-08
#   -5.905e-02   8.778e-02   2.282e-07
#   -9.707e-08   2.282e-07   7.780e-13
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.180225     +/-  0.293015
#    2    2   bbody      kT         keV      1.35211      +/-  0.296277
#    3    2   bbody      norm                3.02036E-06  +/-  8.82020E-07
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  0.7830     using 8 bins.
#
# Test statistic : Chi-Squared                  0.7830     using 8 bins.
#  Null hypothesis probability of 9.7811e-01 with 5 degrees of freedom

# %%
Fit.error("1")
Fit.error("2")

out_arr[0,0] = 'bbody'
out_arr[0,1:4] = mo.TBabs.nH.values[0], mo.TBabs.nH.values[0] - mo.TBabs.nH.error[0], mo.TBabs.nH.error[1] - mo.TBabs.nH.values[0]
out_arr[0,4:7] = mo.bbody.kT.values[0], mo.bbody.kT.values[0] - mo.bbody.kT.error[0], mo.bbody.kT.error[1] - mo.bbody.kT.values[0]
out_arr[0,-2:] = Fit.dof, Fit.statistic / Fit.dof
# Out:
#  Parameter   Confidence Range (2.706)
# ***Warning: Parameter pegged at hard limit: 0
#      1            0      1.01247    (-0.180222,0.832252)
#  Parameter   Confidence Range (2.706)
#      2     0.962241      2.00758    (-0.389876,0.655458)

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 3.8531e-05 photons (2.3933e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
plx = 0.9566
d_kpc = 1/plx
F_x = 2.3933*10**-13

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 3.128368257471568e+31

# %%
import numpy as np
print(d_kpc)
print(np.log10(L_x))
# Out:
# 1.0453690152623876
# 31.4953178705944

# %%
F_opt = 1.05*10**-5 * 10**(-0.4*19.68)
print('Optical Flux: ',F_opt)
print('F_x / F_opt: ', np.log10(F_x/F_opt))
# Out:
# Optical Flux:  1.4099032091947575e-13
# F_x / F_opt:  0.22980784174091323

# %%
AllModels.clear()
mo = Model("tbabs*raymond")
mo.raymond.Abundanc=0.3
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*raymond<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   raymond    kT         keV      1.00000      +/-  0.0
#    3    2   raymond    Abundanc            1.00000      frozen
#    4    2   raymond    Redshift            0.0          frozen
#    5    2   raymond    norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              4.319293e+09     using 8 bins.
#
# Test statistic : Chi-Squared              4.319293e+09     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 5 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              9.007537e+08     using 8 bins.
#
# Test statistic : Chi-Squared              9.007537e+08     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 5 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 30.1854      6.7392       -3      0.344007       3.90998   9.67938e-05
# 22.8015      23427.2      -1      0.357856       15.6200   6.98524e-05
# 15.3994      66793.5      -2      0.443863       52.0642   0.000189111
# 6.08559      46233.9      -1      0.649668       58.5178   0.000197729
# 3.27816      15027.4      -1      0.854979       61.9957   0.000212621
# 2.51173      5007.96      -1       1.00476       63.1071   0.000226186
# 2.34951      3080.61      -1       1.08726       63.6408   0.000235413
# 2.31908      3452.11      -1       1.12883       63.9875   0.000240250
# 2.25079      3749.95       0       1.14616       63.9949   0.000238590
# 2.22775      2198.4        0       1.15666       63.9979   0.000237769
# 2.21946      1368.27       0       1.16310       63.9994   0.000237397
# 2.21622      928.085       0       1.16715       63.9998   0.000237259
# 2.21483      698.456       0       1.16980       64.0000   0.000237238
# 2.2142       581.651       0       1.17160       64.0000   0.000237272
# 2.2139       524.968       0       1.17288       64.0000   0.000237329
# 2.21376      499.865       0       1.17383       64.0000   0.000237392
# 2.2137       491.02        0       1.17456       64.0000   0.000237453
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  7.2096E-10| -0.0001  -0.0000   1.0000
#  1.0736E-01|  1.0000   0.0005   0.0001
#  9.7951E+05| -0.0005   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    3.546e-01  -4.921e+02  -1.589e-04
#   -4.921e+02   9.795e+05   3.348e-01
#   -1.589e-04   3.348e-01   1.160e-07
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*raymond<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.17456      +/-  0.595441
#    2    2   raymond    kT         keV      64.0000      +/-  989.702
#    3    2   raymond    Abundanc            0.300000     frozen
#    4    2   raymond    Redshift            0.0          frozen
#    5    2   raymond    norm                2.37453E-04  +/-  3.40514E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  2.2137     using 8 bins.
#
# Test statistic : Chi-Squared                  2.2137     using 8 bins.
#  Null hypothesis probability of 8.1886e-01 with 5 degrees of freedom

# %%
Fit.error("1")
Fit.error("2")

out_arr[4,0] = 'raymond'
out_arr[4,1:4] = mo.TBabs.nH.values[0], mo.TBabs.nH.values[0] - mo.TBabs.nH.error[0], mo.TBabs.nH.error[1] - mo.TBabs.nH.values[0]
out_arr[4,13] = mo.raymond.Abundanc.values[0]
out_arr[4,4:7] = mo.raymond.kT.values[0], mo.raymond.kT.values[0] - mo.raymond.kT.error[0], mo.raymond.kT.error[1] - mo.raymond.kT.values[0]
out_arr[4,-2:] = Fit.dof, Fit.statistic / Fit.dof
# Out:
#  Parameter   Confidence Range (2.706)
#      1     0.664308      2.28207    (-0.510357,1.1074)
#  Parameter   Confidence Range (2.706)
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 2.21195      0.000766802   0       1.17939       63.9980   0.000236815
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  7.2386E-10| -0.0001  -0.0000   1.0000
#  1.0912E-01|  1.0000   0.0010   0.0001
#  2.4760E+05| -0.0010   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    3.608e-01  -2.496e+02  -1.608e-04
#   -2.496e+02   2.476e+05   1.687e-01
#   -1.608e-04   1.687e-01   1.165e-07
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*raymond<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.17939      +/-  0.600671
#    2    2   raymond    kT         keV      63.9980      +/-  497.592
#    3    2   raymond    Abundanc            0.300000     frozen
#    4    2   raymond    Redshift            0.0          frozen
#    5    2   raymond    norm                2.36815E-04  +/-  3.41360E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  2.2120     using 8 bins.
#
# Test statistic : Chi-Squared                  2.2120     using 8 bins.
#  Null hypothesis probability of 8.1911e-01 with 5 degrees of freedom
# ***Warning: New best fit found, fit parameters will be set to new values.
#
# ***Warning: Number of trials exceeded before convergence.
# Current trial values 11.3752, 0.008
# and delta statistic 0.842257, 74.7317
#
# Continue error search in this direction? ***Warning: Parameter pegged at hard limit: 64
#      2       5.6916            0    (-58.308,-63.9996)

# %%
np.savetxt('../spec25.1_output.csv',out_arr,fmt=['%s','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.1f','%.2f','%.2f','%.2f','%i','%.2f'],delimiter=',')
