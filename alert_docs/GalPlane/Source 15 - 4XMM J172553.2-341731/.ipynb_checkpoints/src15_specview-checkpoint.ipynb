# %%
# %load_ext wurlitzer
import glob
import os
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12,8]
os.chdir('pps/')

Fit.statMethod = "chi"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4

# %%
spec_fnames = glob.glob('P*PNS*SRSPEC*.FTZ')

spec = Spectrum(spec_fnames[0])
Plot.device="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.00001 0.005")
Plot("data")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: P0886040401PNS003SRSPEC0035.FTZ  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  4.169e-03 +/- 6.498e-04 (57.8 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-6
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 1.733e+04 sec
#  Using fit statistic: chi
#  Using Background File                P0886040401PNS003BGSPEC0035.FTZ
#   Background Exposure Time: 1.733e+04 sec
#  Using Response (RMF) File            epn_e3_ff20_sdY8.rmf for Source 1
#  Using Auxiliary Response (ARF) File  P0886040401PNS003SRCARF0035.FTZ

# %%
#spec.ignore("**-0.2 12.0-**")
AllModels.clear()
mo = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              4.866054e+12     using 6 bins.
#
# Test statistic : Chi-Squared              4.866054e+12     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 1.4725       0.348337     -2      0.988585       2.29290   1.74393e-06
# 0.813011     894277       -3       1.47825       2.04829   1.74734e-06
# 0.801472     79390.1      -4       1.28588       2.11364   1.78068e-06
# 0.799441     187.674      -5       1.37027       2.09771   1.77552e-06
# 0.799126     474.279      -6       1.33146       2.10783   1.78143e-06
# 0.799051     44.2059      -7       1.34935       2.10360   1.77922e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  6.6243E-14| -0.0000  -0.0000   1.0000
#  2.3096E-01| -0.3188  -0.9478  -0.0000
#  2.7040E+00|  0.9478  -0.3188  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.453e+00  -7.472e-01  -5.131e-07
#   -7.472e-01   4.823e-01   4.766e-07
#   -5.131e-07   4.766e-07   5.763e-13
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.34935      +/-  1.56610
#    2    2   bbody      kT         keV      2.10360      +/-  0.694467
#    3    2   bbody      norm                1.77922E-06  +/-  7.59148E-07
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  0.7991     using 6 bins.
#
# Test statistic : Chi-Squared                  0.7991     using 6 bins.
#  Null hypothesis probability of 8.4969e-01 with 3 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              2.233540e+11     using 6 bins.
#
# Test statistic : Chi-Squared              2.233540e+11     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 22.6646      2.92881      -1       1.42580       35.8262   7.32382e-06
# 2.2102       426497       -2       3.23337       197.426   3.17973e-05
# 0.448681     71472.8      -2       4.02841       197.662   4.14765e-05
# 0.44149      5088.86      -1       3.97457       198.122   4.21313e-05
# 0.440153     2682.69       0       3.98162       198.259   4.20776e-05
# 0.439652     1842.93       0       3.98452       198.360   4.20482e-05
# 0.439432     1407.92       0       3.98545       198.442   4.20319e-05
# 0.439317     1179.93       0       3.98556       198.511   4.20225e-05
# 0.439251     1052.94       0       3.98532       198.572   4.20174e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  3.6386E-11| -0.0000  -0.0000   1.0000
#  1.9540E+00|  1.0000   0.0008   0.0000
#  6.3487E+06| -0.0008   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    6.234e+00  -5.213e+03  -2.751e-04
#   -5.213e+03   6.349e+06   3.450e-01
#   -2.751e-04   3.450e-01   1.882e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    3.98532      +/-  2.49675
#    2    2   bremss     kT         keV      198.572      +/-  2519.66
#    3    2   bremss     norm                4.20174E-05  +/-  1.37172E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  0.4393     using 6 bins.
#
# Test statistic : Chi-Squared                  0.4393     using 6 bins.
#  Null hypothesis probability of 9.3202e-01 with 3 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              8.150389e+10     using 6 bins.
#
# Test statistic : Chi-Squared              8.150389e+10     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 46.2601      0.810867     -2      0.114779       18.1251   1.14676e-06
# 10.445       316056       -2       3.11231       52.6782   4.41823e-05
# 2.43128      88005.1      -3       4.05216       63.1894   0.000110431
# 1.04256      34871.7      -1       4.10974       63.6072   0.000102545
# 0.692036     18387.2      -1       4.13674       63.8855   9.89518e-05
# 0.592869     10966.7      -1       4.14697       63.9889   9.73248e-05
# 0.560046     7692.55      -1       4.15073       63.9997   9.65843e-05
# 0.547303     6245.64      -1       4.15227       64.0000   9.62422e-05
# 0.541891     5584.3       -1       4.15294       64.0000   9.60835e-05
# 0.539486     5278.51      -1       4.15324       64.0000   9.60099e-05
# 0.538393     5136.83      -1       4.15338       64.0000   9.59757e-05
# 0.53789      5071.12      -1       4.15344       64.0000   9.59598e-05
# 0.537658     5040.63      -1       4.15347       64.0000   9.59524e-05
# 0.53755      5026.48      -1       4.15348       64.0000   9.59490e-05
# 0.5375       5019.91      -1       4.15349       64.0000   9.59474e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  1.8031E-10| -0.0000  -0.0000   1.0000
#  1.8899E+00|  1.0000   0.0023   0.0000
#  1.7579E+06| -0.0023   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.101e+01  -4.003e+03  -4.834e-04
#   -4.003e+03   1.758e+06   2.202e-01
#   -4.834e-04   2.202e-01   2.794e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    4.15349      +/-  3.31759
#    2    2   apec       kT         keV      64.0000      +/-  1325.84
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                9.59474E-05  +/-  1.67158E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  0.5375     using 6 bins.
#
# Test statistic : Chi-Squared                  0.5375     using 6 bins.
#  Null hypothesis probability of 9.1058e-01 with 3 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.191129e+12     using 6 bins.
#
# Test statistic : Chi-Squared              1.191129e+12     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 1.00896      3.84116      -3       1.60202      0.439093   3.35202e-06
# 0.751774     102814       -2       2.48224      0.665256   4.87268e-06
# 0.399734     241878       -2       2.78195      0.781935   6.27138e-06
# 0.364283     84087.8      -3       3.21824      0.937796   8.20530e-06
# 0.29376      71945.9      -4       3.22093      0.947593   8.64967e-06
# 0.293737     1217.49      -5       3.22517      0.948612   8.67187e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.5474E-12| -0.0000  -0.0000   1.0000
#  1.4049E-01|  0.2573  -0.9663  -0.0000
#  7.5275E+00|  0.9663   0.2573   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    7.038e+00   1.837e+00   2.930e-05
#    1.837e+00   6.297e-01   9.551e-06
#    2.930e-05   9.551e-06   1.476e-10
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    3.22517      +/-  2.65299
#    2    2   powerlaw   PhoIndex            0.948612     +/-  0.793528
#    3    2   powerlaw   norm                8.67187E-06  +/-  1.21509E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  0.2937     using 6 bins.
#
# Test statistic : Chi-Squared                  0.2937     using 6 bins.
#  Null hypothesis probability of 9.6120e-01 with 3 degrees of freedom

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 1.3586e-05 photons (1.3352e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
#plx = 1.4843
d_kpc = 8
F_x = 1.2824*10**-13

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 9.817139587956737e+32

# %%
import numpy as np
print(d_kpc)
print(np.log10(L_x))
# Out:
# 8
# 32.99198496618541

# %%
F_opt = 1.05*10**-5 * 10**(-0.4*20.78)
print('Optical Flux: ',F_opt)
print('F_x / F_opt: ', F_x/F_opt)
# Out:
# Optical Flux:  5.119049146085544e-14
# F_x / F_opt:  2.5051527410722967

# %%
AllModels.clear()
mo = Model("tbabs*apec")
mo.apec.Abundanc = 0.3
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              8.150389e+10     using 6 bins.
#
# Test statistic : Chi-Squared              8.150389e+10     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              1.449785e+10     using 6 bins.
#
# Test statistic : Chi-Squared              1.449785e+10     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 44.3907      1.12821      -2      0.488947       10.7027   2.43192e-06
# 34.5197      272419        0      0.343608       44.2650   1.17610e-05
# 14.4111      102710       -1       1.64628       62.4186   3.71062e-05
# 1.69749      89661.3      -2       3.63286       63.2701   0.000107792
# 0.904594     23991.4      -1       3.95306       63.6417   0.000106161
# 0.744378     13495.1      -1       4.07364       63.9564   0.000105742
# 0.713317     10253.3      -1       4.10754       63.9935   0.000105676
# 0.706768     9493.17      -1       4.11615       63.9980   0.000105672
# 0.705429     9324.85      -1       4.11827       63.9998   0.000105675
# 0.705233     9290.62      -1       4.11878       63.9999   0.000105678
# 0.601384     9285.99       0       4.18516       64.0000   0.000104171
# 0.565952     5701.9        0       4.21671       64.0000   0.000103267
# 0.552777     3740.76       0       4.22941       64.0000   0.000102708
# 0.5473       2651.93       0       4.23269       64.0000   0.000102349
# 0.544744     2034.83       0       4.23165       64.0000   0.000102110
# 0.543422     1675.5        0       4.22893       64.0000   0.000101945
# 0.542682     1459.18       0       4.22578       64.0000   0.000101827
# 0.542239     1323.91       0       4.22279       64.0000   0.000101741
# 0.541962     1235.86       0       4.22017       64.0000   0.000101676
# 0.54178      1176.27       0       4.21796       64.0000   0.000101627
# 0.541656     1134.48       0       4.21616       64.0000   0.000101590
# 0.54157      1104.31       0       4.21471       64.0000   0.000101561
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  2.1133E-10| -0.0000  -0.0000   1.0000
#  2.0289E+00|  1.0000   0.0025   0.0000
#  1.0263E+06| -0.0025   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    8.680e+00  -2.613e+03  -2.989e-04
#   -2.613e+03   1.026e+06   1.254e-01
#   -2.989e-04   1.254e-01   1.574e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    4.21471      +/-  2.94615
#    2    2   apec       kT         keV      64.0000      +/-  1013.08
#    3    2   apec       Abundanc            0.300000     frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.01561E-04  +/-  1.25476E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  0.5416     using 6 bins.
#
# Test statistic : Chi-Squared                  0.5416     using 6 bins.
#  Null hypothesis probability of 9.0967e-01 with 3 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*raymond")
mo.raymond.Abundanc = 0.3
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*raymond<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   raymond    kT         keV      1.00000      +/-  0.0
#    3    2   raymond    Abundanc            1.00000      frozen
#    4    2   raymond    Redshift            0.0          frozen
#    5    2   raymond    norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              5.201407e+10     using 6 bins.
#
# Test statistic : Chi-Squared              5.201407e+10     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              1.039525e+10     using 6 bins.
#
# Test statistic : Chi-Squared              1.039525e+10     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 42.0523      1.52944      -3      0.497023       19.2357   3.92126e-06
# 36.8054      251551       -4      0.674360       59.6625   5.91510e-05
# 14.5304      193614       -1       1.23754       62.5560   6.77267e-05
# 4.98582      64179.5      -1       2.09862       63.5043   8.01503e-05
# 1.31492      21449.3      -1       3.12997       63.8983   9.06298e-05
# 0.610875     3958.09      -1       3.83651       63.9962   9.80063e-05
# 0.568871     1332.71      -1       4.07552       63.9995   0.000102233
# 0.543907     3964.03       0       4.12987       64.0000   0.000101840
# 0.535617     2398.8        0       4.16133       64.0000   0.000101676
# 0.532616     1614.45       0       4.17977       64.0000   0.000101623
# 0.531432     1230.36       0       4.19086       64.0000   0.000101622
# 0.530939     1049.56       0       4.19777       64.0000   0.000101643
# 0.530735     970.507       0       4.20225       64.0000   0.000101670
# 0.530658     941.211       0       4.20527       64.0000   0.000101697
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  2.1204E-10| -0.0000  -0.0000   1.0000
#  2.0153E+00|  1.0000   0.0019   0.0000
#  1.4343E+06| -0.0019   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    7.202e+00  -2.728e+03  -3.004e-04
#   -2.728e+03   1.434e+06   1.687e-01
#   -3.004e-04   1.687e-01   2.025e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*raymond<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    4.20527      +/-  2.68375
#    2    2   raymond    kT         keV      64.0000      +/-  1197.61
#    3    2   raymond    Abundanc            0.300000     frozen
#    4    2   raymond    Redshift            0.0          frozen
#    5    2   raymond    norm                1.01697E-04  +/-  1.42304E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  0.5307     using 6 bins.
#
# Test statistic : Chi-Squared                  0.5307     using 6 bins.
#  Null hypothesis probability of 9.1211e-01 with 3 degrees of freedom

# %%
#plx = 1.4843
d_kpc = 1.7
F_x = 1.2824*10**-13

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 4.433052095186714e+31

# %%
import numpy as np
print(d_kpc)
print(np.log10(L_x))
# Out:
# 1.7
# 31.646702834958074

# %%
## F_opt = 1.05*10**-5 * 10**(-0.4*20.7)
print('Optical Flux: ',F_opt)
print('F_x / F_opt: ', np.log10(F_x/F_opt))
# Out:
# Optical Flux:  5.119049146085544e-14
# F_x / F_opt:  0.3988342102761514
