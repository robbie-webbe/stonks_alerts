# %%
# %load_ext wurlitzer
import numpy as np
import glob
import os
import matplotlib.pyplot as plt
from astropy.io import fits
from xspec import *
plt.rcParams['figure.figsize'] = [9,6]

Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4

# %%
spec = Spectrum(glob.glob("*grpspec.fits")[0])
# Out:
# Warning: RMF FILTER keyword (UNDEFINED) is not consistent with that in spectrum (Medium)
#
# 1 spectrum  in use
#
# Spectral Data File: 0886011001_MOS10grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  2.032e-03 +/- 5.284e-04 (39.0 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-10
#   Telescope: XMM Instrument: EPIC  Channel Type: PI
#   Exposure Time: 2.13e+04 sec
#  Using fit statistic: chi
#  Using Background File                0886011001_MOS10spec_bkg.fits
#   Background Exposure Time: 2.13e+04 sec
#  Using Response (RMF) File            0886011001_MOS10spec.rmf for Source 1

# %%
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.000001 0.05")
Plot.addCommand("Rescale X 0.1 15")
Plot("data")
#spec.ignore("**-0.2 12.0-**")

# %%
AllModels.clear()
mo1 = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              4.546065e+12     using 10 bins.
#
# Test statistic : Chi-Squared              4.546065e+12     using 10 bins.
#  Null hypothesis probability of 0.000000e+00 with 7 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 28.6673      0.0348589    -3      0.480219      0.407371   3.61224e-08
# 27.9524      2.26811e+06   0      0.231891      0.380325   2.86306e-08
# 25.7316      6.92487e+06   0     0.0874659      0.164329   2.50931e-08
# 11.6412      2.47237e+07   0    0.00770585      0.165011   9.25944e-08
# 8.57955      1.94132e+07  -1    0.00381758      0.160545   1.21000e-07
# 8.05717      1.15178e+07  -1    0.00148303      0.162204   1.26097e-07
# 7.96872      9.47107e+06  -1   0.000440865      0.162126   1.25863e-07
# 7.46367      9.38174e+06   0   0.000215240      0.159046   1.34686e-07
# 7.21062      7.02058e+06   0   4.06369e-05      0.157446   1.40548e-07
# 7.0867       5.39834e+06   0   4.07128e-06      0.156464   1.44325e-07
# 7.02102      4.36942e+06   0   5.27076e-09      0.155822   1.46775e-07
# 6.9839       3.71057e+06   0   1.59996e-09      0.155393   1.48371e-07
# 6.96206      3.28481e+06   0   7.29394e-10      0.155109   1.49412e-07
# 6.94879      3.00829e+06   0   3.09186e-10      0.154919   1.50091e-07
# 6.94056      2.8287e+06    0   1.03941e-10      0.154794   1.50534e-07
# 6.93535      2.71174e+06   0   2.88594e-12      0.154710   1.50823e-07
# 6.93143      2.6357e+06    0   1.33797e-12      0.154653   1.51050e-07
# 6.93007      2.57497e+06   0   5.55696e-13      0.154635   1.51130e-07
# 6.92844      2.55327e+06   0   1.70206e-13      0.154572   1.51211e-07
# 6.91821      2.53669e+06   0   2.93292e-14      0.154438   1.51850e-07
# 6.9134       2.36253e+06   0   5.67512e-15      0.154412   1.52185e-07
# 6.90654      2.26601e+06   0   8.91015e-16      0.154221   1.52616e-07
# 6.89743      2.16111e+06   0   2.80674e-16      0.154951   1.53902e-07
# 6.89405      1.68613e+06   0   1.10929e-17      0.155161   1.54499e-07
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.10929e-17 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 6.84701      2.22106e+06  -1   1.10929e-17      0.151534   1.60303e-07
# 6.84627      318335       -2   1.10929e-17      0.151948   1.60851e-07
# 6.84626      2521.82      -3   1.10929e-17      0.151867   1.60890e-07
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.10929e-17 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 6.84626      45.935       -3   1.10929e-17      0.151883   1.60883e-07
# ==============================
#  Variances and Principal Axes
#                  2        3
#  1.1336E-15|  0.0000   1.0000
#  4.9382E-04|  1.0000  -0.0000
# ------------------------------
#
# ========================
#   Covariance Matrix
#         1           2
#    4.938e-04  -2.033e-10
#   -2.033e-10   1.217e-15
# ------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.10929E-17  +/-  -1.00000
#    2    2   bbody      kT         keV      0.151883     +/-  2.22221E-02
#    3    2   bbody      norm                1.60883E-07  +/-  3.48904E-08
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  6.8463     using 10 bins.
#
# Test statistic : Chi-Squared                  6.8463     using 10 bins.
#  Null hypothesis probability of 4.4506e-01 with 7 degrees of freedom

# %%
Fit.error("1")
Fit.error("2")
# Out:
#  Parameter   Confidence Range (2.706)
# ***Warning: Identical values of the parameter give different values of the statistic.
# Please check your result for the low end of the confidence range.
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.10929e-17 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.10929e-17 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
#
# ***Warning: Number of trials exceeded before bracketing of delta fit-stat.
# Last attempt: 0, with delta statistic: 0
#
# Continue error search in this direction?
# *** Parameter upper bound is INVALID.
#
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.10929e-17 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.10929e-17 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
#      1      1.64499            0    (1.64499,-1.10929e-17)
#  Parameter   Confidence Range (2.706)
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.10929e-17 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.10929e-17 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.10929e-17 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.10929e-17 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.10929e-17 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.10929e-17 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.10929e-17 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.10929e-17 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.10929e-17 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.10929e-17 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.10929e-17 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.10929e-17 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.10929e-17 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.10929e-17 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.10929e-17 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.10929e-17 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.10929e-17 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.10929e-17 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.10929e-17 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.10929e-17 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
#      2     0.119348     0.190713    (-0.0325316,0.0388333)

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.340835e+12     using 10 bins.
#
# Test statistic : Chi-Squared              1.340835e+12     using 10 bins.
#  Null hypothesis probability of 0.000000e+00 with 7 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 27.5517      0.0695128    -1      0.186702       1.02895   5.54929e-07
# 26.6644      416856        0     0.0712524       1.27634   5.45949e-07
# 24.3456      733944
#       0     0.0293135       1.79458   7.59966e-07
# 11.5612      977230       -1    0.00855004       3.14149   1.50020e-06
# 10.7575      943516       -2   0.000896079       2.33596   2.63241e-06
# 9.31002      264673       -3   0.000281783       2.80637   2.52881e-06
# 9.21301      191365       -4   8.56344e-06       2.63950   2.55771e-06
# 9.15493      81512        -5   1.75421e-06       2.70780   2.51235e-06
# 9.15448      18411.5       0   5.40360e-07       2.70771   2.51709e-06
# 9.15432      13438.4       0   2.54309e-07       2.70728   2.52001e-06
# 9.15426      11064.4       0   1.13880e-07       2.70679   2.52194e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  3.1192E-13| -0.0001   0.0000   1.0000
#  1.1424E-04|  0.9997  -0.0228   0.0001
#  4.1896E-01|  0.0228   0.9997  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    3.323e-04   9.555e-03   8.336e-10
#    9.555e-03   4.187e-01  -2.184e-07
#    8.336e-10  -2.184e-07   7.220e-13
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.13880E-07  +/-  1.82302E-02
#    2    2   powerlaw   PhoIndex            2.70679      +/-  0.647103
#    3    2   powerlaw   norm                2.52194E-06  +/-  8.49678E-07
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  9.1543     using 10 bins.
#
# Test statistic : Chi-Squared                  9.1543     using 10 bins.
#  Null hypothesis probability of 2.4177e-01 with 7 degrees of freedom

# %%
Fit.error("2")
Fit.error("1")
Fit.error("2")
# Out:
#  Parameter   Confidence Range (2.706)
#  Due to zero model norms, the following fit parameters are temporarily frozen:1
#  Due to zero model norms, the following fit parameters are temporarily frozen:1
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.11311e-16 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.11311e-16 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# Apparent non-monotonicity in statistic space detected.
# Current bracket values 3.36588, 1.51886
# and delta stat 1.4156, 10.0998
# but latest trial 2.88492 gives 0.592573
# Suggest that you check this result using the steppar command.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  5.6921E-11| -0.0002   0.0000   1.0000
#  1.2443E-02|  0.9901  -0.1406   0.0002
#  1.0186E+02|  0.1406   0.9901   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.025e+00   1.418e+01   1.823e-04
#    1.418e+01   9.984e+01   1.267e-03
#    1.823e-04   1.267e-03   1.658e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.896487     +/-  1.42312
#    2    2   powerlaw   PhoIndex            9.95997      +/-  9.99223
#    3    2   powerlaw   norm                3.46099E-05  +/-  1.28780E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  8.6365     using 10 bins.
#
# Test statistic : Chi-Squared                  8.6365     using 10 bins.
#  Null hypothesis probability of 2.7982e-01 with 7 degrees of freedom
# ***Warning: New best fit found, fit parameters will be set to new values.
#  Due to zero model norms, the following fit parameters are temporarily frozen:1
#  Due to zero model norms, the following fit parameters are temporarily frozen:1
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 5.10007e-16 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 5.10007e-16 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# Apparent non-monotonicity in statistic space detected.
# Current bracket values 4.54259, 1.60564
# and delta stat 1.43762, 11.0774
# but latest trial 2.82058 gives 0.566836
# Suggest that you check this result using the steppar command.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 8.63444      0.00912056   -1      0.901086       10.0000   3.48865e-05
# 8.63428      269.141      -2      0.902288       10.0000   3.51424e-05
# 8.63428      28.9789      -3      0.902333       10.0000   3.51542e-05
# 8.63428      0.0769347     2      0.902333       10.0000   3.51542e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  5.8719E-11| -0.0002   0.0000   1.0000
#  1.2668E-02|  0.9975  -0.0709   0.0002
#  4.0772E+02|  0.0709   0.9975   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.060e+00   2.882e+01   1.883e-04
#    2.882e+01   4.057e+02   2.617e-03
#    1.883e-04   2.617e-03   1.740e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.902333     +/-  1.43532
#    2    2   powerlaw   PhoIndex            10.0000      +/-  20.1413
#    3    2   powerlaw   norm                3.51542E-05  +/-  1.31913E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  8.6343     using 10 bins.
#
# Test statistic : Chi-Squared                  8.6343     using 10 bins.
#  Null hypothesis probability of 2.7999e-01 with 7 degrees of freedom
# ***Warning: New best fit found, fit parameters will be set to new values.
#
# ***Warning: Number of trials exceeded before bracketing of delta fit-stat.
# Last attempt: 10, with delta statistic: 0
#
# Continue error search in this direction?
# *** Parameter lower bound is INVALID.
#
#
# ***Warning: Number of trials exceeded before bracketing of delta fit-stat.
# Last attempt: 10, with delta statistic: 0
#
# Continue error search in this direction?
# *** Parameter upper bound is INVALID.
#
#      2      3.07411            0    (-6.92589,-10)
#  Parameter   Confidence Range (2.706)
#      1     0.698782      1.07869    (-0.203551,0.176353)
#  Parameter   Confidence Range (2.706)
#
# ***Warning: Number of trials exceeded before bracketing of delta fit-stat.
# Last attempt: 10, with delta statistic: 0
#
# Continue error search in this direction?
# *** Parameter lower bound is INVALID.
#
#
# ***Warning: Number of trials exceeded before bracketing of delta fit-stat.
# Last attempt: 10, with delta statistic: 0
#
# Continue error search in this direction?
# *** Parameter upper bound is INVALID.
#
#      2            0            0    (-10,-10)

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              2.443922e+11     using 10 bins.
#
# Test statistic : Chi-Squared              2.443922e+11     using 10 bins.
#  Null hypothesis probability of 0.000000e+00 with 7 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 27.593       0.0748481    -2     0.0492324       56.9536   6.89165e-07
# 26.3699      448045       -3    0.00316863       199.032   8.93753e-06
# 24.4432      348969       -4    0.00135789       12.3522   1.04727e-06
# 24.4258      654114       -2   3.72964e-05       5.64530   9.14035e-07
# 20.3454      790821       -3   4.31590e-06       2.51713   1.85071e-06
# 18.8775      575355       -1   1.55040e-06      0.671741   3.13028e-06
# 10.1473      469946       -1   7.31136e-07      0.605081   8.08671e-06
# 8.67862      174126       -2   6.38544e-08      0.472810   1.15987e-05
# 8.46622      90825.7      -3   2.91160e-08      0.542919   1.09114e-05
# 8.22522      67746.8      -4   1.04883e-09      0.502406   1.20458e-05
# 8.16059      51347.2      -1   3.64262e-10      0.507870   1.22041e-05
# 8.15175      40123.7      -1   3.32167e-11      0.506554   1.22574e-05
# 8.14819      39075.1      -1   1.27487e-11      0.506074   1.22786e-05
# 8.14684      38623.2      -1   2.55479e-12      0.505882   1.22868e-05
# 8.09913      38455.2       0   5.88723e-14      0.506368   1.25193e-05
# 8.07864      28407.2       0   2.21765e-14      0.504425   1.26653e-05
# 8.06272      24204.3       0   6.33751e-15      0.502122   1.27995e-05
# 8.05328      20898.1       0   2.24654e-15      0.499330   1.28967e-05
# 8.05328      19619.6      14   2.25691e-15      0.499330   1.28967e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  8.2711E-12| -0.0001   0.0000   1.0000
#  1.2603E-03|  0.9947   0.1025   0.0001
#  4.6698E-02| -0.1025   0.9947  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.738e-03  -4.633e-03   3.502e-07
#   -4.633e-03   4.622e-02  -1.747e-06
#    3.502e-07  -1.747e-06   9.837e-11
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    2.25691E-15  +/-  4.16862E-02
#    2    2   bremss     kT         keV      0.499330     +/-  0.214991
#    3    2   bremss     norm                1.28967E-05  +/-  9.91835E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  8.0533     using 10 bins.
#
# Test statistic : Chi-Squared                  8.0533     using 10 bins.
#  Null hypothesis probability of 3.2792e-01 with 7 degrees of freedom

# %%
Fit.error("1")
Fit.error("2")
# Out:
#  Parameter   Confidence Range (2.706)
# ***Warning: Parameter pegged at hard limit: 0
#      1            0      4.22815    (-3.03689,1.19126)
#  Parameter   Confidence Range (2.706)
# Apparent non-monotonicity in statistic space detected.
# Current bracket values 0.0264151, 0.0261638
# and delta stat 2.39705, 3.3516
# but latest trial 0.0263433 gives 2.39149
# Suggest that you check this result using the steppar command.
#
# ***Warning: Number of trials exceeded before convergence.
# Current trial values 0.329194, 0.344907
# and delta statistic 1.83351, 21.1521
#
# Continue error search in this direction?      2    0.0262894     0.338318    (-0.00595849,0.30607)

# %%
Fit.show()
# Out:
# Fit statistic  : Chi-Squared                  7.0772     using 10 bins.
#
# Test statistic : Chi-Squared                  7.0772     using 10 bins.
#  Null hypothesis probability of 4.2088e-01 with 7 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              3.991134e+10     using 10 bins.
#
# Test statistic : Chi-Squared              3.991134e+10     using 10 bins.
#  Null hypothesis probability of 0.000000e+00 with 7 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 15.2768      0.978769     -3     0.0481808      0.631878   3.14669e-06
# 12.0047      592059       -1   9.52742e-05      0.495832   1.88289e-06
# 11.3371      698383        0   2.37739e-05      0.429134   2.05555e-06
# 10.2307      741068        0   7.16677e-06      0.379884   2.34394e-06
# 9.38323      702243       -1   5.01948e-07      0.282145   2.78580e-06
# 7.93091      736776       -2   2.00244e-07      0.327321   2.99827e-06
# 7.49238      553908       -1   6.49153e-08      0.304925   3.17038e-06
# 7.06484      555184       -1   6.39720e-09      0.307326   3.29978e-06
# 7.02128      497683       -1   2.88538e-09      0.306758   3.31568e-06
# 7.0052       493303       -1   1.14321e-09      0.306708   3.32123e-06
# 7.00109      491301       -1   2.74101e-10      0.306677   3.32269e-06
# 6.99985      490830       -1   5.69647e-11      0.306669   3.32313e-06
# 6.99936      490684       -1   2.69086e-12      0.306683   3.32327e-06
# 6.98461      490587       -1   9.94225e-13      0.306152   3.32946e-06
# 6.93496      489880       -1   1.47288e-13      0.306632   3.34545e-06
# 6.70482      482117       -2   3.19858e-14      0.293416   3.46076e-06
# 6.25953      478924       -1   9.31720e-15      0.302223   3.60752e-06
# 5.25085      396658       -2   2.52232e-15      0.299185   4.16851e-06
# 5.01323      197593       -3   7.22316e-16      0.295635   4.36901e-06
# 5.00595      139524       -4   2.98995e-16      0.296202   4.38583e-06
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 2.98995e-16 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 4.59919      196071       -5   2.98995e-16      0.272144   5.01805e-06
# 4.59653      16778.2      -6   2.98995e-16      0.272964   5.04329e-06
# 4.59478      23.3999      -7   2.98995e-16      0.274546   5.02587e-06
# 4.59478      30.4413      -8   2.98995e-16      0.274551   5.02587e-06
# 4.59478      31.1396       2   1.48897e-16      0.274551   5.02587e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  1.0069E-12| -0.0002   0.0000   1.0000
#  4.1832E-06|  0.9996   0.0270   0.0002
#  1.9306E-03| -0.0270   0.9996  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    5.585e-06  -5.195e-05   1.842e-09
#   -5.195e-05   1.929e-03  -3.332e-08
#    1.842e-09  -3.332e-08   1.796e-12
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.48897E-16  +/-  2.36325E-03
#    2    2   apec       kT         keV      0.274551     +/-  4.39232E-02
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                5.02587E-06  +/-  1.34005E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  4.5948     using 10 bins.
#
# Test statistic : Chi-Squared                  4.5948     using 10 bins.
#  Null hypothesis probability of 7.0928e-01 with 7 degrees of freedom

# %%
Fit.error("1")
Fit.error("2")
# Out:
#  Parameter   Confidence Range (2.706)
# ***Warning: Parameter pegged at hard limit: 0
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.48897e-16 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.48897e-16 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.48897e-16 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.48897e-16 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
#      1            0       0.1102    (-1.48897e-16,0.1102)
#  Parameter   Confidence Range (2.706)
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.48897e-16 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.48897e-16 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.48897e-16 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.48897e-16 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.48897e-16 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.48897e-16 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
#      2      0.21268     0.368377    (-0.0618717,0.0938256)

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 1.5438e-05 photons (1.2651e-14 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
plx = 18.6994
d_kpc = 1/plx
F_x = 2.0476*10**-14

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 7.004405175785179e+27

# %%
import numpy as np
print(np.log10(L_x))
# Out:
# 27.84537126027237

# %%
F_opt = 1.05*10**-5 * 10**(-0.4*9.6)
print('Optical Flux: ',F_opt)
print('F_x / F_opt: ', np.log10(F_x/F_opt))
# Out:
# Optical Flux:  1.5177117592832245e-09
# F_x / F_opt:  -4.86994417819173
