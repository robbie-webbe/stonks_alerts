# %%
# %load_ext wurlitzer
import glob
import os
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12,8]
os.chdir('pps/')

Fit.statMethod = "chi"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4

# %%
spec_fnames = glob.glob('P*PNU*SRSPEC*.FTZ')

spec = Spectrum(spec_fnames[0])
Plot.device="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.00005 0.001")
Plot("data")
#spec.ignore("**-0.2 12.0-**")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: P0886070601PNU002SRSPEC0009.FTZ  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  4.473e-03 +/- 5.494e-04 (71.8 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-6
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 2.086e+04 sec
#  Using fit statistic: chi
#  Using Background File                P0886070601PNU002BGSPEC0009.FTZ
#   Background Exposure Time: 2.086e+04 sec
#  Using Response (RMF) File            epn_e3_ff20_sdY8.rmf for Source 1
#  Using Auxiliary Response (ARF) File  P0886070601PNU002SRCARF0009.FTZ

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              2.901065e+12     using 6 bins.
#
# Test statistic : Chi-Squared              2.901065e+12     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 1.29953      1.28422      -3       1.15863      0.917849   4.56017e-06
# 1.25027      14201.9      -4       1.31333      0.985763   5.10248e-06
# 1.23975      27412.4      -5       1.37601       1.00647   5.33798e-06
# 1.23848      4092.29      -6       1.40173       1.01537   5.43295e-06
# 1.2383       619.385      -7       1.41187       1.01884   5.46940e-06
# 1.23827      88.0997      -8       1.41586       1.02020   5.48363e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  4.3855E-13| -0.0000  -0.0000   1.0000
#  4.9828E-02|  0.4062  -0.9138  -0.0000
#  1.0177E+00|  0.9138   0.4062   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    8.580e-01   3.593e-01   3.505e-06
#    3.593e-01   2.096e-01   1.889e-06
#    3.505e-06   1.889e-06   1.776e-11
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.41586      +/-  0.926288
#    2    2   powerlaw   PhoIndex            1.02020      +/-  0.457780
#    3    2   powerlaw   norm                5.48363E-06  +/-  4.21385E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  1.2383     using 6 bins.
#
# Test statistic : Chi-Squared                  1.2383     using 6 bins.
#  Null hypothesis probability of 7.4384e-01 with 3 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              4.848957e+11     using 6 bins.
#
# Test statistic : Chi-Squared              4.848957e+11     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 13.5612      2.69122      -1       1.13337       21.6452   8.00357e-06
# 6.96932      582858       -2       1.16423       194.974   1.47872e-05
# 1.55216      278269       -2       1.64283       199.302   2.33402e-05
# 1.39708      38146.5      -1       1.75399       199.351   2.34820e-05
# 1.36883      19632.2      -1       1.80462       199.360   2.36035e-05
# 1.36425      14580.6      -1       1.82548       199.362   2.36812e-05
# 1.355        13790.2       0       1.83558       199.363   2.35996e-05
# 1.35179      8474.74       0       1.84105       199.363   2.35525e-05
# 1.35061      5502.7        0       1.84391       199.363   2.35251e-05
# 1.35015      3840.85       0       1.84535       199.363   2.35090e-05
# 1.34994      2906.34       0       1.84603       199.363   2.34991e-05
# 1.34984      2375.66       0       1.84631       199.363   2.34930e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  8.0688E-12| -0.0000  -0.0000   1.0000
#  3.2841E-01|  1.0000   0.0005   0.0000
#  2.5869E+06| -0.0005   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    9.550e-01  -1.273e+03  -3.780e-05
#   -1.273e+03   2.587e+06   7.976e-02
#   -3.780e-05   7.976e-02   2.474e-09
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.84631      +/-  0.977239
#    2    2   bremss     kT         keV      199.363      +/-  1608.38
#    3    2   bremss     norm                2.34930E-05  +/-  4.97369E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  1.3498     using 6 bins.
#
# Test statistic : Chi-Squared                  1.3498     using 6 bins.
#  Null hypothesis probability of 7.1733e-01 with 3 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              1.583967e+11     using 6 bins.
#
# Test statistic : Chi-Squared              1.583967e+11     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 54.133       3.44261      -3      0.180463       12.3360   2.82397e-06
# 20.4415      743255       -1      0.721247       59.0489   1.88061e-05
# 11.2232      260845       -2       1.31449       63.5954   5.97254e-05
# 4.76247      177993       -1       1.52215       63.9072   5.62299e-05
# 2.74022      95290.2      -1       1.69624       63.9642   5.49983e-05
# 2.0693       56836        -1       1.81484       63.9862   5.46116e-05
# 1.83494      38909.5      -1       1.88352       63.9955   5.45094e-05
# 1.74725      30685.3      -1       1.91924       63.9980   5.44920e-05
# 1.71215      26978.7      -1       1.93669       63.9996   5.44956e-05
# 1.69747      25326.7      -1       1.94495       63.9998   5.45021e-05
# 1.69117      24598.4      -1       1.94879       63.9999   5.45070e-05
# 1.68844      24278.5      -1       1.95057       64.0000   5.45102e-05
# 1.68725      24138.5      -1       1.95138       64.0000   5.45120e-05
# 1.68673      24077.6      -1       1.95175       64.0000   5.45130e-05
# 1.6865       24051.1      -1       1.95193       64.0000   5.45135e-05
# 1.6864       24039.7      -1       1.95200       64.0000   5.45138e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  3.9293E-11| -0.0000  -0.0000   1.0000
#  3.0924E-01|  1.0000   0.0013   0.0000
#  4.6443E+05| -0.0013   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.154e+00  -6.262e+02  -4.435e-05
#   -6.262e+02   4.644e+05   3.527e-02
#   -4.435e-05   3.527e-02   2.751e-09
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.95200      +/-  1.07409
#    2    2   apec       kT         keV      64.0000      +/-  681.489
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                5.45138E-05  +/-  5.24542E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  1.6864     using 6 bins.
#
# Test statistic : Chi-Squared                  1.6864     using 6 bins.
#  Null hypothesis probability of 6.3996e-01 with 3 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.455603e+13     using 6 bins.
#
# Test statistic : Chi-Squared              1.455603e+13     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 12.7102      1.48473      -3      0.356457       1.38725   9.08748e-07
# 0.55785      1.30243e+07  -4      0.301599       1.62202   8.37192e-07
# 0.133168     1.0633e+06   -5      0.315440       1.73722   8.90396e-07
# 0.130634     19899.7      -6      0.323807       1.74445   8.97866e-07
# 0.130633     583.125      -7      0.324115       1.74432   8.97858e-07
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.1630E-14| -0.0000  -0.0000   1.0000
#  4.6895E-02| -0.5322  -0.8466  -0.0000
#  2.1987E-01|  0.8466  -0.5322  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.709e-01  -7.794e-02  -2.021e-08
#   -7.794e-02   9.588e-02   5.171e-08
#   -2.021e-08   5.171e-08   4.395e-14
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.324115     +/-  0.413374
#    2    2   bbody      kT         keV      1.74432      +/-  0.309653
#    3    2   bbody      norm                8.97858E-07  +/-  2.09641E-07
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  0.1306     using 6 bins.
#
# Test statistic : Chi-Squared                  0.1306     using 6 bins.
#  Null hypothesis probability of 9.8792e-01 with 3 degrees of freedom

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 8.6747e-06 photons (6.6693e-14 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
#plx = 0.5317
d_kpc = 8
F_x = 6.6383*10**-14

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 5.081808930656052e+32

# %%
import numpy as np
print(d_kpc)
print(np.log10(L_x))
# Out:
# 8
# 32.70601833211897

# %%
F_opt = 1.05*10**-5 * 10**(-0.4*20.7)
print('Optical Flux: ',F_opt)
print('F_x / F_opt: ', np.log10(F_x/F_opt))
# Out:
# Optical Flux:  5.510478332622621e-14
# F_x / F_opt:  0.08086757620971363
