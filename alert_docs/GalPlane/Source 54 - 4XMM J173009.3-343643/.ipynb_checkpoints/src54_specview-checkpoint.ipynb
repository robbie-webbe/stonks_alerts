# %%
# %load_ext wurlitzer
import glob
import os
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12,8]
os.chdir('pps/')

Fit.statMethod = "chi"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4

# %%
spec_fnames = glob.glob('P*PNS*SRSPEC*.FTZ')

spec = Spectrum(spec_fnames[0])
Plot.device="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.00001 0.05")
Plot("data")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: P0916811501PNS003SRSPEC0002.FTZ  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  7.482e-02 +/- 3.713e-03 (52.4 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-76
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 1.119e+04 sec
#  Using fit statistic: chi
#  Using Background File                P0916811501PNS003BGSPEC0002.FTZ
#   Background Exposure Time: 1.119e+04 sec
#  Using Response (RMF) File            epn_e3_ff20_sdY6.rmf for Source 1
#  Using Auxiliary Response (ARF) File  P0916811501PNS003SRCARF0002.FTZ

# %%
spec.ignore("**-0.2 12.0-**")
mo = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
#       No channels ignored (no channels in specified range)
#      1 channels (76) ignored in spectrum #     1
#
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              2.320494e+11     using 75 bins.
#
# Test statistic : Chi-Squared              2.320494e+11     using 75 bins.
#  Null hypothesis probability of 0.000000e+00 with 72 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 81.8065      6.79456      -3       2.19457       3.41844   5.91232e-05
# 75.8519      110932       -4       4.40205       2.32780   3.28376e-05
# 66.0815      400455       -5       6.34880       2.30111   3.96490e-05
# 65.5641      31923.3      -6       7.34628       2.14991   3.82527e-05
# 65.5352      6363.62      -7       7.60302       2.12828   3.82888e-05
# 65.5345      57.1736      -8       7.64706       2.12317   3.82531e-05
# 65.5345      14.6758      -9       7.65453       2.12217   3.82442e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  3.2523E-12| -0.0000  -0.0000   1.0000
#  3.2433E-02| -0.1134  -0.9935  -0.0000
#  3.2060E+00|  0.9935  -0.1134  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    3.165e+00  -3.576e-01  -2.369e-06
#   -3.576e-01   7.324e-02   1.004e-06
#   -2.369e-06   1.004e-06   2.153e-11
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    7.65453      +/-  1.77911
#    2    2   bbody      kT         keV      2.12217      +/-  0.270635
#    3    2   bbody      norm                3.82442E-05  +/-  4.64034E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 65.5345     using 75 bins.
#
# Test statistic : Chi-Squared                 65.5345     using 75 bins.
#  Null hypothesis probability of 6.9139e-01 with 72 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              8.339745e+10     using 75 bins.
#
# Test statistic : Chi-Squared              8.339745e+10     using 75 bins.
#  Null hypothesis probability of 0.000000e+00 with 72 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 116.365      35.7926      -1       1.70927    0.00262432   2.07709e-05
# 85.7636      702461       -2       3.34804    -0.0333397   2.60028e-05
# 82.17        26545.4      -2       5.31314      0.228360   4.02992e-05
# 78.5122      365626       -2       7.07459      0.467000   6.49127e-05
# 72.3013      252199       -2       8.28570      0.650171   9.76262e-05
# 68.5343      123654       -2       9.17364      0.787102   0.000133144
# 66.8522      55711.4      -2       9.87467      0.893683   0.000168076
# 66.0415      26537.1      -2       10.4386      0.978451   0.000201084
# 65.6005      13759.2      -2       10.8947       1.04645   0.000231500
# 65.3414      7647.03      -2       11.2648       1.10129   0.000258951
# 65.1821      4476.64      -2       11.5658       1.14567   0.000283294
# 65.0814      2728.3       -2       11.8109       1.18168   0.000304575
# 65.0642      1718.1       -3       12.4809       1.28376   0.000366190
# 64.9098      7278.78      -4       12.8363       1.33337   0.000408775
# 64.8925      2222.19      -5       12.8992       1.34063   0.000417335
# 64.8924      70.9447      -6       12.9085       1.34166   0.000418297
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  3.8670E-10| -0.0000  -0.0007   1.0000
#  3.1617E-02|  0.1186  -0.9929  -0.0007
#  7.1233E+00|  0.9929   0.1186   0.0001
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    7.023e+00   8.354e-01   7.071e-04
#    8.354e-01   1.314e-01   1.061e-04
#    7.071e-04   1.061e-04   8.665e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    12.9085      +/-  2.65019
#    2    2   powerlaw   PhoIndex            1.34166      +/-  0.362547
#    3    2   powerlaw   norm                4.18297E-04  +/-  2.94362E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 64.8924     using 75 bins.
#
# Test statistic : Chi-Squared                 64.8924     using 75 bins.
#  Null hypothesis probability of 7.1121e-01 with 72 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.912508e+10     using 75 bins.
#
# Test statistic : Chi-Squared              1.912508e+10     using 75 bins.
#  Null hypothesis probability of 0.000000e+00 with 72 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 396.043      10.3957       0       1.28820       36.5702   5.87470e-05
# 255.481      230418       -1       3.07262       199.347   0.000241034
# 84.0785      103726       -2       7.58577       199.360   0.000773784
# 66.9903      2671.59      -2       10.4734       199.362   0.000933669
# 65.0682      2108.09      -3       11.9333       199.285   0.000978670
# 65.0184      2046.51      -1       12.1102       199.208   0.000988070
# 64.985       1820.75      -1       12.1607       199.139   0.000993519
# 64.968       1333.37      -1       12.1766       199.079   0.000996591
# 64.9607      971.289      -1       12.1830       199.024   0.000998202
# 64.9569      763.696      -1       12.1854       198.974   0.000999157
# 64.9559      627.83       -1       12.1875       198.922   0.000999460
# 64.9548      587.139      -1       12.1880       198.868   0.000999713
# 64.9548      541.724      -1       12.1889       198.808   0.000999687
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  2.2346E-09| -0.0000  -0.0000   1.0000
#  1.6591E+00|  1.0000   0.0019   0.0000
#  9.2354E+05| -0.0019   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    4.996e+00  -1.755e+03  -2.080e-03
#   -1.755e+03   9.235e+05   1.134e+00
#   -2.080e-03   1.134e+00   1.399e-06
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    12.1889      +/-  2.23510
#    2    2   bremss     kT         keV      198.808      +/-  961.010
#    3    2   bremss     norm                9.99687E-04  +/-  1.18264E-03
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 64.9548     using 75 bins.
#
# Test statistic : Chi-Squared                 64.9548     using 75 bins.
#  Null hypothesis probability of 7.0931e-01 with 72 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              8.538873e+09     using 75 bins.
#
# Test statistic : Chi-Squared              8.538873e+09     using 75 bins.
#  Null hypothesis probability of 0.000000e+00 with 72 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 509.927      1.87796      -3       2.76363      0.588595   0.000110855
# 500.871      7160.31      -4       1.17239       7.72462   1.46819e-05
# 346.95       159991       -5       4.60633       54.4779   0.000303754
# 117.807      78276.4      -6       16.9418       59.2847    0.00179563
# 101.084      18073.6      -7       10.2096       11.3717    0.00196302
# 69.3641      14985.6      -8       12.1755       17.4960    0.00185974
# 64.1555      2474.74      -9       12.9982       26.7972    0.00201303
# 63.2002      1322.95     -10       12.7435       44.2163    0.00212769
# 63.0071      568.216       0       12.7816       40.5915    0.00212588
# 62.9814      56.6219       0       12.8199       39.4168    0.00212280
# 62.9642      100.748       0       12.8524       38.4376    0.00211947
# 62.9637      110.116       0       12.8548       38.5426    0.00211927
# 62.9636      70.5932       0       12.8573       38.4335    0.00211903
# 62.9631      79.9416       0       12.8591       38.5307    0.00211889
# 62.9629      46.6223       1       12.8593       38.5185    0.00211888
# 62.9627      48.3643       1       12.8595       38.5064    0.00211886
# 62.9626      50.0607       1       12.8597       38.4944    0.00211885
# 62.9625      51.7126       2       12.8597       38.4938    0.00211884
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  9.9072E-09| -0.0001  -0.0000   1.0000
#  1.6754E+00|  0.9999   0.0126   0.0001
#  8.0794E+02| -0.0126   0.9999   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.803e+00  -1.015e+01   1.047e-04
#   -1.015e+01   8.078e+02   4.624e-03
#    1.047e-04   4.624e-03   5.218e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    12.8597      +/-  1.34280
#    2    2   apec       kT         keV      38.4938      +/-  28.4221
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                2.11884E-03  +/-  2.28425E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 62.9625     using 75 bins.
#
# Test statistic : Chi-Squared                 62.9625     using 75 bins.
#  Null hypothesis probability of 7.6760e-01 with 72 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*(apec+apec)")
mo.apec.kT = 0.5
mo.apec_3.kT = 4.0
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              3.415635e+10     using 75 bins.
#
# Test statistic : Chi-Squared              3.415635e+10     using 75 bins.
#  Null hypothesis probability of 0.000000e+00 with 70 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              1.940429e+10     using 75 bins.
#
# Test statistic : Chi-Squared              1.940429e+10     using 75 bins.
#  Null hypothesis probability of 0.000000e+00 with 70 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              8.418748e+09     using 75 bins.
#
# Test statistic : Chi-Squared              8.418748e+09     using 75 bins.
#  Null hypothesis probability of 0.000000e+00 with 70 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm          6:kT        9:norm
# 464.535      42448.3      -3       2.22471      0.236823   0.000617344       41.2247   6.25558e-05
# 193.73       72668        -4       25.7930     0.0112805     0.0639694       53.5050    0.00178854
# 193.73       11426.9      -5       25.7930     0.0112805     0.0639694       53.5050    0.00178854
# ============================================================
#  Variances and Principal Axes
#                  1        2        5        6        9
#  -NAN      |  1.0000   0.0000   0.0000   0.0000   0.0000
#  NAN       |  0.0000     -nan     -nan     -nan     -nan
#  NAN       |  0.0000      nan      nan      nan      nan
#  NAN       |  0.0000      nan      nan      nan      nan
#  NAN       |  0.0000      nan      nan      nan      nan
# ------------------------------------------------------------
#
# ============================================================
#   Covariance Matrix
#         1           2           3           4           5
#         -nan        -nan        -nan        -nan        -nan
#         -nan        -nan        -nan        -nan        -nan
#         -nan        -nan        -nan        -nan        -nan
#         -nan        -nan        -nan        -nan        -nan
#         -nan        -nan        -nan        -nan        -nan
# ------------------------------------------------------------
#
# ========================================================================
# Model TBabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    25.7930      +/-  -nan
#    2    2   apec       kT         keV      1.12805E-02  +/-  -nan
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                6.39694E-02  +/-  -nan
#    6    3   apec       kT         keV      53.5050      +/-  -nan
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.78854E-03  +/-  -nan
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                193.7304     using 75 bins.
#
# Test statistic : Chi-Squared                193.7304     using 75 bins.
#  Null hypothesis probability of 1.4987e-13 with 70 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*(bbody+powerlaw)")
mo.bbody.kT = 1.0
mo.powerlaw.PhoIndex = 2.5
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>(bbody<2> + powerlaw<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
#    4    3   powerlaw   PhoIndex            1.00000      +/-  0.0
#    5    3   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              5.481219e+11     using 75 bins.
#
# Test statistic : Chi-Squared              5.481219e+11     using 75 bins.
#  Null hypothesis probability of 0.000000e+00 with 70 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              8.833454e+12     using 75 bins.
#
# Test statistic : Chi-Squared              8.833454e+12     using 75 bins.
#  Null hypothesis probability of 0.000000e+00 with 70 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              7.716477e+12     using 75 bins.
#
# Test statistic : Chi-Squared              7.716477e+12     using 75 bins.
#  Null hypothesis probability of 0.000000e+00 with 70 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:nor
#   Covariance Matrix
#         1           2           3           4           5
#    1.598e+01  -4.495e+00  -1.011e-04   3.994e+01   3.977e-06
#   -4.495e+00   1.638e+00   4.103e-05  -1.629e+01  -1.611e-06
#   -1.011e-04   4.103e-05   1.076e-09  -4.319e-04  -4.256e-11
#    3.994e+01  -1.629e+01  -4.319e-04   1.772e+02   1.741e-05
#    3.977e-06  -1.611e-06  -4.256e-11   1.741e-05   1.711e-12
# ------------------------------------------------------------
#
# ========================================================================
# Model TBabs<1>(bbody<2> + powerlaw<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    9.52318      +/-  3.99804
#    2    2   bbody      kT         keV      1.64895      +/-  1.27988
#    3    2   bbody      norm                2.95797E-05  +/-  3.28005E-05
#    4    3   powerlaw   PhoIndex            -2.49998     +/-  13.3128
#    5    3   powerlaw   norm                4.08382E-08  +/-  1.30804E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 64.4408     using 75 bins.
#
# Test statistic : Chi-Squared                 64.4408     using 75 bins.
#  Null hypothesis probability of 6.6499e-01 with 70 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*(bbody+powerlaw+gaussian)")
mo.gaussian.LineE = 6.4
mo.gaussian.LineE.frozen = True
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>(bbody<2> + powerlaw<3> + gaussian<4>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
#    4    3   powerlaw   PhoIndex            1.00000      +/-  0.0
#    5    3   powerlaw   norm                1.00000      +/-  0.0
#    6    4   gaussian   LineE      keV      6.50000      +/-  0.0
#    7    4   gaussian   Sigma      keV      0.100000     +/-  0.0
#    8    4   gaussian   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              9.048136e+11     using 75 bins.
#
# Test statistic : Chi-Squared              9.048136e+11     using 75 bins.
#  Null hypothesis probability of 0.000000e+00 with 67 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              8.998928e+11     using 75 bins.
#
# Test statistic : Chi-Squared              8.998928e+11     using 75 bins.
#  Null hypothesis probability of 0.000000e+00 with 67 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              8.998928e+11     using 75 bins.
#
# Test statistic : Chi-Squared              8.998928e+11     using 75 bins.
#  Null hypothesis probability of 0.000000e+00 with 68 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm    4:PhoIndex        5:norm       7:Sigma        8:norm
# 116.762      413794       -1       1.62381       2.61035   3.50493e-05      0.751452   8.08765e-06      0.109012   6.76600e-06
# 80.5815      370572       -1       2.62159       2.70504   3.83396e-05      0.420282   3.94481e-06     0.0755984   3.39404e-06
# 77.4302      84219.2      -2       4.05029       2.57778   4.55401e-05      0.225968   1.49063e-06     0.0335737   1.79379e-06
# 70.0874      288354       -2       5.50283       2.43639   4.50731e-05       1.05228   6.60972e-07    0.00773272   1.87408e-06
# 67.2281      155466       -2       6.45677       2.26083   4.17155e-05       6.49379
#    3.12891e-07    0.00172086   1.74955e-06
# 63.7981      120174       -2       7.13130       2.11047   3.70792e-05       9.48858     0.0144705   0.000499357   2.13037e-06
# ***Warning: Zero alpha-matrix diagonal element for parameter 7
#  Parameter 7 is pegged at 0.000499357 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
#
#         1           2           3           4           5           6
#    7.800e+00  -6.394e-01  -1.634e-06  -5.726e+00   1.078e-01  -2.901e-07
#   -6.394e-01   9.226e-02   9.840e-07   8.080e-02  -2.191e-02  -4.913e-08
#   -1.634e-06   9.840e-07   2.214e-11  -4.647e-06  -2.177e-07  -2.473e-12
#   -5.726e+00   8.080e-02  -4.647e-06   3.907e+01   1.218e+00   2.867e-07
#    1.078e-01  -2.191e-02  -2.177e-07   1.218e+00   5.149e-02  -1.893e-09
#   -2.901e-07  -4.913e-08  -2.473e-12   2.867e-07  -1.893e-09   4.519e-12
# ------------------------------------------------------------------------
#
# ========================================================================
# Model TBabs<1>(bbody<2> + powerlaw<3> + gaussian<4>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    7.78496      +/-  2.79277
#    2    2   bbody      kT         keV      2.10808      +/-  0.303748
#    3    2   bbody      norm                3.74821E-05  +/-  4.70529E-06
#    4    3   powerlaw   PhoIndex            9.50000      +/-  6.25028
#    5    3   powerlaw   norm                5.70155E-02  +/-  0.226908
#    6    4   gaussian   LineE      keV      6.40000      frozen
#    7    4   gaussian   Sigma      keV      4.99357E-04  +/-  -1.00000
#    8    4   gaussian   norm                2.22867E-06  +/-  2.12571E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 63.1000     using 75 bins.
#
# Test statistic : Chi-Squared                 63.1000     using 75 bins.
#  Null hypothesis probability of 6.4548e-01 with 68 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*(powerlaw+gaussian)")
mo.gaussian.LineE = 6.4
mo.gaussian.LineE.frozen = True
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>(powerlaw<2> + gaussian<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
#    4    3   gaussian   LineE      keV      6.50000      +/-  0.0
#    5    3   gaussian   Sigma      keV      0.100000     +/-  0.0
#    6    3   gaussian   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              3.268440e+11     using 75 bins.
#
# Test statistic : Chi-Squared              3.268440e+11     using 75 bins.
#  Null hypothesis probability of 0.000000e+00 with 69 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              3.230877e+11     using 75 bins.
#
# Test statistic : Chi-Squared              3.230877e+11     using 75 bins.
#  Null hypothesis probability of 0.000000e+00 with 69 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              3.230877e+11     using 75 bins.
#
# Test statistic : Chi-Squared              3.230877e+11     using 75 bins.
#  Null hypothesis probability of 0.000000e+00 with 70 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm       5:Sigma        6:norm
# 146.477      508245        0       1.58352      0.203915   2.82576e-05      0.133819   1.79909e-05
# 89.371       378283       -1       2.84339     0.0641853   2.88225e-05      0.126011   5.47161e-06
# 78.2949      66956.9      -2       4.80566      0.212986   4.01934e-05     0.0140057   1.31465e-06
# 75.5937      150760       -2       6.66232      0.442843   6.16685e-05    0.00199894   2.29917e-06
# 71.2978      144519       -2       7.98713      0.634234   9.23705e-05   4.80934e-05   2.42473e-06
# ***Warning: Zero alpha-matrix diagonal element for parameter 5
#  Parameter 5 is pegged at 4.80934e-05 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 67.6115      108727       -2       8.91311      0.780058   0.000127616   4.80934e-05   2.45427e-06
# 65.7436      55491.3      -2       9.63839      0.892532   0.000163169   4.80934e-05   2.47737e-06
# 64.8374      28355.1      -2       10.2202      0.981833   0.000197137   4.80934e-05   2.50265e-06
# 64.3498      15481.1      -2       10.6910       1.05353   0.000228689   4.80934e-05   2.52736e-06
# 64.065       8986.87      -2       11.0735       1.11145   0.000257372   4.80934e-05   2.55008e-06
# 63.8903      5450.08      -2       11.3850       1.15842   0.000282984   4.80934e-05   2.57026e-06
# 63.7797      3408.12      -2       11.6393       1.19662   0.000305517   4.80934e-05   2.58783e-06
# 63.7744      2179.87      -3       12.3350       1.30489   0.000370859   4.80934e-05   2.64907e-06
# 63.5931      12380        -4       12.7140       1.35925   0.000418019   4.80934e-05   2.67689e-06
# 63.5695      4378.38      -5       12.7850       1.36795   0.000428399   4.80934e-05   2.67952e-06
# 63.5694      166.077      -6       12.7959       1.36923   0.000429633   4.80934e-05   2.67973e-06
# ***Warning: Zero alpha-matrix diagonal element for parameter 5
#  Parameter 5 is pegged at 4.80934e-05 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 63.5694      2.46163      -3       12.7972       1.36937   0.000429759   4.80934e-05   2.67972e-06
# ==================================================
#  Variances and Principal Axes
#                  1        2        3        6
#  4.9342E-12| -0.0000  -0.0000   0.0253   0.9997
#  4.4464E-10|  0.0000   0.0007  -0.9997   0.0253
#  3.3490E-02|  0.1204  -0.9927  -0.0007  -0.0000
#  7.1147E+00|  0.9927   0.1204   0.0001   0.0000
# --------------------------------------------------
#
# ================================================
#   Covariance Matrix
#         1           2           3           4
#    7.012e+00   8.462e-01   7.359e-04   1.839e-07
#    8.462e-01   1.361e-01   1.125e-04   1.059e-07
#    7.359e-04   1.125e-04   9.423e-08   6.659e-11
#    1.839e-07   1.059e-07   6.659e-11   5.426e-12
# ------------------------------------------------
#
# ========================================================================
# Model TBabs<1>(powerlaw<2> + gaussian<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    12.7972      +/-  2.64804
#    2    2   powerlaw   PhoIndex            1.36937      +/-  0.368928
#    3    2   powerlaw   norm                4.29759E-04  +/-  3.06973E-04
#    4    3   gaussian   LineE      keV      6.40000      frozen
#    5    3   gaussian   Sigma      keV      4.80934E-05  +/-  -1.00000
#    6    3   gaussian   norm                2.67972E-06  +/-  2.32939E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 63.5694     using 75 bins.
#
# Test statistic : Chi-Squared                 63.5694     using 75 bins.
#  Null hypothesis probability of 6.9296e-01 with 70 degrees of freedom

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 0.00019634 photons (2.1484e-12 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
#plx = 0.9586
d_kpc = 8
F_x = 2.1484*10**-12

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 1.6446617818750977e+34

# %%
import numpy as np
print(d_kpc)
print(np.log10(L_x))
# Out:
# 8
# 34.216076600542785

# %%
F_opt = 1.05*10**-5 * 10**(-0.4*20.7)
print('Optical Flux: ',F_opt)
print('F_x / F_opt: ', np.log10(F_x/F_opt))
# Out:
# Optical Flux:  5.510478332622621e-14
# F_x / F_opt:  1.5909258446335235
