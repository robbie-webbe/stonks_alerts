# %%
# %load_ext wurlitzer
import glob
import os
import numpy as np
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12,8]

Fit.statMethod = "chi"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4
os.chdir('other_obs')

# %%
spec = Spectrum('0679810401_MOS13grpspec.fits')

Plot.device="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.00001 0.005")
Plot("data")
#spec.ignore("**-0.2 12.0-**")
# Out:
# ...
#
# 1 spectrum  in use
#
# Spectral Data File: 0679810401_MOS13grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  1.650e-03 +/- 4.375e-04 (60.2 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-4
#   Telescope: XMM Instrument: EPIC  Channel Type: PI
#   Exposure Time: 1.497e+04 sec
#  Using fit statistic: chi
#  Using Background File                0679810401_MOS13spec_bkg.fits
#   Background Exposure Time: 1.497e+04 sec
#  Using Response (RMF) File            0679810401_MOS13spec.rmf for Source 1

# %%
AllModels.clear()
mo = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
# ...
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# ...

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ...
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              9.170812e+11     using 4 bins.
#
# Test statistic : Chi-Squared              9.170812e+11     using 4 bins.
#  Null hypothesis probability of 0.000000e+00 with 1 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 4.3718       0.86166      -1       2.08006      0.934589   4.44140e-06
# 4.06407      2015.97      -1       2.61842       1.08475   5.59535e-06
# ...

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ...
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.832322e+11     using 4 bins.
#
# Test statistic : Chi-Squared              1.832322e+11     using 4 bins.
#  Null hypothesis probability of 0.000000e+00 with 1 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 4.8521       0.84581      -3       6.65353       2.72792   3.27328e-05
# 3.82087      39232        -1       3.84835       2.69465   5.11675e-05
# ...

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
# Out:
# ...
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              5.596291e+10     using 4 bins.
#
# Test statistic : Chi-Squared              5.596291e+10     using 4 bins.
#  Null hypothesis probability of 0.000000e+00 with 1 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# ...

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 5.9674e-06 photons (3.5381e-14 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
AllData.clear()
AllModels.clear()
spec = Spectrum('P0744600101PNS003SRSPEC0037.FTZ',backFile='P0744600101PNS003BGSPEC0037.FTZ')
spec.response.arf='P0744600101PNS003SRCARF0037.FTZ'

Plot.device="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.000001 0.001")
Plot("data")
spec.ignore("**-0.2 12.0-**")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: P0744600101PNS003SRSPEC0037.FTZ  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  1.090e-03 +/- 2.429e-04 (16.2 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-38
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 1.152e+05 sec
#  Using fit statistic: chi
#  Using Background File                P0744600101PNS003BGSPEC0037.FTZ
#   Background Exposure Time: 1.152e+05 sec
#  Using Response (RMF) File            epn_e3_ff20_sdY9.rmf for Source 1
#  Using Auxiliary Response (ARF) File  P0744600101PNS003SRCARF0037.FTZ
#
# Net count rate (cts/s) for Spectrum:1  1.090e-03 +/- 2.429e-04 (16.2 % total)
# Spectrum 1  Spectral Data File: P0744600101PNS003SRSPEC0037.FTZ
# Net count rate (cts/s) for Spectrum:1  1.090e-03 +/- 2.429e-04 (16.2 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-38
#   Telescope: XMM Instrument: EPN  Channel Type: PI
# ...

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ...
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.014953e+13     using 37 bins.
#
# Test statistic : Chi-Squared              1.014953e+13     using 37 bins.
#  Null hypothesis probability of 0.000000e+00 with 34 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 49.9949      0.466391     -3       1.75009      0.964325   1.09450e-06
# 49.9246      3536.54      -2       2.71039       1.29210   1.73490e-06
# ...

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ...
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.899858e+12     using 37 bins.
#
# Test statistic : Chi-Squared              1.899858e+12     using 37 bins.
#  Null hypothesis probability of 0.000000e+00 with 34 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 52.981       0.51989      -2       1.27492       28.7843   1.27403e-06
# 50.7654      533089       -3       2.74769       198.290   3.70896e-06
# ...

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
# Out:
# ...
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              6.864538e+11     using 37 bins.
#
# Test statistic : Chi-Squared              6.864538e+11     using 37 bins.
#  Null hypothesis probability of 0.000000e+00 with 34 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 58.6314      0.302359      0       1.01065      0.780034   8.12543e-07
# ...

# %%
AllModels.clear()
mo = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
# ...
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              4.166555e+13     using 37 bins.
#
# Test statistic : Chi-Squared              4.166555e+13     using 37 bins.
#  Null hypothesis probability of 0.000000e+00 with 34 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 50.4037      0.18495      -1      0.353124       2.56598   2.92438e-07
# 49.8686      924020       -1      0.189422       2.12006   2.31648e-07
# ...

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 1.8465e-06 photons (1.4558e-14 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
#plx = 1.4843
d_kpc = 8
F_x = 2*10**-14

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 1.5310573281280003e+32

# %%
F_opt = 1.05*10**-5 * 10**(-0.4*20.78)
print('Optical Flux: ',F_opt)
print('F_x / F_opt: ', F_x/F_opt)
# Out:
# Optical Flux:  5.119049146085544e-14
# F_x / F_opt:  0.3906975578715372
