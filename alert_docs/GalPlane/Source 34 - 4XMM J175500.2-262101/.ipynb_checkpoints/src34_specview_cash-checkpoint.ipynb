# %%
# %load_ext wurlitzer
import numpy as np
import glob
import os
import matplotlib.pyplot as plt
from astropy.io import fits
from xspec import *
plt.rcParams['figure.figsize'] = [9,6]

Fit.statMethod = "cstat"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4

# %%
spec = Spectrum(glob.glob("*cash.fits")[0],backFile=glob.glob("*bkg.fits")[0],respFile=glob.glob("*.rmf")[0])
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0886081201_PN60spec_cash.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  5.660e-04 +/- 7.544e-04 (7.8 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-496
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 1.753e+04 sec
#  Using fit statistic: cstat
#  Using Background File                0886081201_PN60spec_bkg.fits
#   Background Exposure Time: 1.753e+04 sec
#  No response loaded.
#
# ***Warning!  One or more spectra are missing responses,
#                and are not suitable for fit.
# Net count rate (cts/s) for Spectrum:1  5.660e-04 +/- 7.544e-04 (7.8 % total)
# ***Warning!  One or more spectra are missing responses,
#                and are not suitable for fit.
# Response successfully loaded.
# Spectrum 1  Spectral Data File: 0886081201_PN60spec_cash.fits
# Net count rate (cts/s) for Spectrum:1  5.660e-04 +/- 7.544e-04 (7.8 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-496
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 1.753e+04 sec
#  Using fit statistic: cstat
#  Using Background File                0886081201_PN60spec_bkg.fits
#   Background Exposure Time: 1.753e+04 sec
#  Using Response (RMF) File            0886081201_PN60spec.rmf for Source 1
#
#  Spectral data counts: 128
#  Model predicted rate: 0.0

# %%
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.00001 0.05")
Plot.addCommand("Rescale X 0.1 15")
Plot("data")
#spec.ignore("**-0.2 12.0-**")

# %%
AllModels.clear()
mo = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : C-Statistic                185973.1     using 496 bins.
#
# Test statistic : Chi-Squared              3.279202e+08     using 496 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 0.000000e+00 with 493 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        3:norm
#
# 223.455      22.0052       0       2.35011       5.52942    0.00270161
# 223.12       25.4972       0       3.93500       4.27483    0.00365909
# 222.053      35.0779      -1       16.0732       15.1878    0.00495424
# 220.503      53.7961      -1       79.9010       4.68969     0.0201408
# 218.766      27.0756       0       65.4995       4.85181     0.0240243
# 214.465      27.9981       0       27.9888       3.50670     0.0330989
# 213.961      19.1015       0       27.6937       3.54087     0.0387336
# 213.744      9.55933       0       29.0787       3.45037     0.0431578
# 213.587      6.9397        0       29.8757       3.31221     0.0473447
# 213.586      5.70126      -1       37.3622       2.39251     0.0745644
# 212.706      9.55609      -1       32.7302       2.24881      0.103015
# 212.497      1.94303      -1       42.0091       2.10574      0.143315
# 212.327      1.98347      -1       36.4532       1.89587      0.171653
# 212.193      0.849539     -1       43.2485       1.83739      0.218096
# 212.104      0.772107     -1       40.4260       1.71868      0.251517
# 212.06       0.427543     -1       43.7659       1.69755      0.286735
# 212.032      0.236328     -1       42.8355       1.64912      0.308592
# 212.01       0.130656     -1       44.1085       1.61528      0.338536
# 211.997      0.13976      -1       44.2487       1.58867      0.360064
# 211.986      0.07983      -1       44.7462       1.56509      0.382505
# 211.976      0.073218     -1       45.0652       1.54350      0.404100
# 211.969      0.0623394    -1       45.4348       1.52476      0.425481
# 211.969      0.0474562    -2       47.6826       1.44592      0.523080
# 211.959      0.353319     -3       45.7315       1.46855      0.491468
# 211.955      0.0116677    -1       46.8701       1.46584      0.506922
# 211.953      0.021157     -2       47.3449       1.43905      0.547797
# 211.953      0.0460132    -2       47.0004       1.44435      0.538819
# 211.953      0.00356923   -1       47.1704       1.44492      0.540240
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  1.2041E-02| -0.0074   0.8070   0.5905
#  9.2869E-01| -0.0442  -0.5902   0.8061
#  1.6325E+03|  0.9990  -0.0202   0.0400
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.629e+03  -3.284e+01   6.524e+01
#   -3.284e+01   9.944e-01  -1.753e+00
#    6.524e+01  -1.753e+00   3.223e+00
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    47.1704      +/-  40.3631
#    2    2   apec       kT         keV      1.44492      +/-  0.997190
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                0.540240     +/-  1.79528
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                211.9526     using 496 bins.
#
# Test statistic : Chi-Squared                279.1969     using 496 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 1.0000e+00 with 493 degrees of freedom

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux   0.00112 photons (1.0696e-11 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
plx = 18.6994
d_kpc = 1/plx
F_x = 2.0476*10**-14

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 7.004405175785179e+27

# %%
import numpy as np
print(np.log10(L_x))
# Out:
# 27.84537126027237

# %%
F_opt = 1.05*10**-5 * 10**(-0.4*9.6)
print('Optical Flux: ',F_opt)
print('F_x / F_opt: ', np.log10(F_x/F_opt))
# Out:
# Optical Flux:  1.5177117592832245e-09
# F_x / F_opt:  -4.86994417819173
