# %%
# %load_ext wurlitzer
import glob
import os
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12,8]
os.chdir('pps/')

Fit.statMethod = "chi"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4

# %%
import numpy as np
out_arr = np.full((4,19),-np.inf,dtype=object)

# %%
spec_fnames = glob.glob('P*PNS*SRSPEC*.FTZ')

spec = Spectrum(spec_fnames[0])
Plot.device="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.0001 0.01")
Plot("data")
spec.ignore("**-0.2 12.0-**")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: P0916791201PNS003SRSPEC0001.FTZ  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  2.232e-02 +/- 1.914e-03 (86.1 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-9
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 7101 sec
#  Using fit statistic: chi
#  Using Background File                P0916791201PNS003BGSPEC0001.FTZ
#   Background Exposure Time: 7101 sec
#  Using Response (RMF) File            epn_e3_ff20_sdY0.rmf for Source 1
#  Using Auxiliary Response (ARF) File  P0916791201PNS003SRCARF0001.FTZ
#       No channels ignored (no channels in specified range)
#      1 channels (9) ignored in spectrum #     1

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squa
# red              4.332455e+10     using 8 bins.
#
# Test statistic : Chi-Squared              4.332455e+10     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 5 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 32.8435      8.26902      -2       2.73572      -1.44559   2.53139e-06
# 23.721       2.88952e+06  -2       1.18349     -0.809969   4.70796e-06
# 16.323       1.42525e+06  -1       2.04472     -0.806275   6.39104e-06
# 15.3382      219059       -1       2.15106     -0.726365   7.43357e-06
# 14.4809      151706       -1       2.40135     -0.651920   8.58347e-06
# 13.6998      124548       -1       2.62234     -0.580599   9.83787e-06
# 12.9889      101391       -1       2.84201     -0.512681   1.12011e-05
# 12.3412      83445.3      -1       3.05665     -0.447922   1.26739e-05
# 11.7506      69138.8      -1       3.26652     -0.386146   1.42567e-05
# 11.2116      57674.3      -1       3.47152     -0.327181   1.59494e-05
# 10.7191      48420.9      -1       3.67163     -0.270866   1.77513e-05
# 10.2687      40903.1      -1       3.86687     -0.217051   1.96613e-05
# 9.85628      34756.4      -1       4.05727     -0.165591   2.16779e-05
# 9.47828      29700.1      -1       4.24291     -0.116354   2.37993e-05
# 9.13136      25516.4      -1       4.42387    -0.0692133   2.60233e-05
# 8.8126       22035.1      -1       4.60025    -0.0240505   2.83476e-05
# 8.51935      19122.6      -1       4.77215     0.0192451   3.07695e-05
# 8.24922      16673.3      -1       4.93970     0.0607776   3.32864e-05
# 8.00007      14603.2      -1       5.10300      0.100645   3.58952e-05
# 7.76999      12845.2      -1       5.26218      0.138938   3.85930e-05
# 7.55724      11345.2      -1       5.41735      0.175744   4.13767e-05
# 7.55626      10059.8      -2       6.62128      0.454784   6.30466e-05
# 6.43072      61020.5      -2       7.60983      0.656710   9.40674e-05
# 5.43965      35131.4      -2       8.40147      0.807164   0.000129568
# 4.93471      16858.2      -2       9.06469      0.927092   0.000166418
# 4.66435      8478.15      -2       9.63418       1.02600   0.000203552
# 4.49973      4675.87      -2       10.1284       1.10908   0.000240471
# 4.39018      2791.18      -2       10.5602       1.17980   0.000276792
# 4.31319      1769.48      -2       10.9395       1.24063   0.000312202
# 4.25713      1175         -2       11.2744       1.29340   0.000346456
# 4.21527      809.562      -2       11.5712       1.33951   0.000379373
# 4.18345      574.838      -2       11.8351       1.38003   0.000410824
# 4.15892      418.545      -2       12.0705       1.41582   0.000440726
# 4.1398       311.294      -2       12.2810       1.44756   0.000469032
# 4.12476      235.788      -2       12.4696       1.47579   0.000495727
# 4.11285      181.449      -2       12.6390       1.50099   0.000520817
# 4.10335      141.588      -2       12.7914       1.52353   0.000544329
# 4.10098      111.854      -3       13.3563       1.61516   0.000640330
# 4.08114      896.302      -4       13.8697       1.68944   0.000742120
# 4.06362      623.073      -5       14.0909       1.71583   0.000790258
# 4.06275      102.039      -6       14.1882       1.72745   0.000810383
# 4.06266      16.1798      -7       14.2306       1.73249   0.000818920
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  5.2727E-09| -0.0000  -0.0013   1.0000
#  1.2697E-01|  0.1400  -0.9901  -0.0013
#  3.8210E+01|  0.9901   0.1400   0.0002
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    3.746e+01   5.280e+00   8.368e-03
#    5.280e+00   8.737e-01   1.345e-03
#    8.368e-03   1.345e-03   2.085e-06
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    14.2306      +/-  6.12073
#    2    2   powerlaw   PhoIndex            1.73249      +/-  0.934730
#    3    2   powerlaw   norm                8.18920E-04  +/-  1.44400E-03
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  4.0627     using 8 bins.
#
# Test statistic : Chi-Squared                  4.0627     using 8 bins.
#  Null hypothesis probability of 5.4043e-01 with 5 degrees of freedom

# %%
Fit.error("1")
Fit.error("2")

out_arr[1,0] = 'powerlaw'
out_arr[1,1:4] = mo.TBabs.nH.values[0], mo.TBabs.nH.values[0] - mo.TBabs.nH.error[0], mo.TBabs.nH.error[1] - mo.TBabs.nH.values[0]
out_arr[1,14:17] = mo.powerlaw.PhoIndex.values[0], mo.powerlaw.PhoIndex.values[0] - mo.powerlaw.PhoIndex.error[0], mo.powerlaw.PhoIndex.error[1] - mo.powerlaw.PhoIndex.values[0]
out_arr[1,-2:] = Fit.dof, Fit.statistic / Fit.dof
# Out:
#  Parameter   Confidence Range (2.706)
#      1      5.68805      31.6982    (-8.55534,17.4548)
#  Parameter   Confidence Range (2.706)
#      2     0.324056      3.93359    (-1.4107,2.19883)

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.139771e+10     using 8 bins.
#
# Test statistic : Chi-Squared              1.139771e+10     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 5 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 104.158      2.48875       0       1.52130       64.0528   3.71583e-05
# 61.2176      87996.4      -1       9.84995       25.8666   0.000197990
# 10.6835      45669.3      -2       12.6964       88.6340   0.000649670
# 4.8825       11036.4      -2       11.8736       28.8193   0.000634571
# 4.64614      4834.4       -2       12.9271       12.4648   0.000712464
# 4.07781      3456.23      -3       13.4070       15.0210   0.000751184
# 3.95594      1616.66      -4       13.7510       13.8068   0.000797699
# 3.95413      168.47       -1       13.7825       13.8439   0.000800927
# 3.95375      21.2631      -1       13.8090       13.7544   0.000803123
# 3.95343      15.1517      -1       13.8309       13.6628   0.000805098
# 3.9534       13.6939       0       13.8336       13.6547   0.000805307
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  5.1991E-09| -0.0000   0.0000   1.0000
#  5.4772E+00|  0.9854   0.1701   0.0000
#  6.7732E+02| -0.1701   0.9854  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.492e+01  -1.126e+02   2.328e-03
#   -1.126e+02   6.579e+02  -1.218e-02
#    2.328e-03  -1.218e-02   2.410e-07
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    13.8336      +/-  4.99246
#    2    2   bremss     kT         keV      13.6547      +/-  25.6491
#    3    2   bremss     norm                8.05307E-04  +/-  4.90958E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  3.9534     using 8 bins.
#
# Test statistic : Chi-Squared                  3.9534     using 8 bins.
#  Null hypothesis probability of 5.5614e-01 with 5 degrees of freedom

# %%
Fit.error("1")
Fit.error("2")

out_arr[3,0] = 'bremss'
out_arr[3,1:4] = mo.TBabs.nH.values[0], mo.TBabs.nH.values[0] - mo.TBabs.nH.error[0], mo.TBabs.nH.error[1] - mo.TBabs.nH.values[0]
out_arr[3,4:7] = mo.bremss.kT.values[0], mo.bremss.kT.values[0] - mo.bremss.kT.error[0], mo.bremss.kT.error[1] - mo.bremss.kT.values[0]
out_arr[3,-2:] = Fit.dof, Fit.statistic / Fit.dof
# Out:
#  Parameter   Confidence Range (2.706)
# Apparent non-monotonicity in statistic space detected.
# Current bracket values 8.28683, 8.19593
# and delta stat 2.69445, 2.87814
# but latest trial 8.28096 gives 2.66962
# Suggest that you check this result using the steppar command.
#      1      8.24138      27.4291    (-5.59549,13.5922)
#  Parameter   Confidence Range (2.706)
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 3.95319      0.000431142   0       13.8570       13.6039   0.000806966
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  5.2187E-09| -0.0000   0.0000   1.0000
#  5.4901E+00|  0.9852   0.1711   0.0000
#  6.7401E+02| -0.1711   0.9852  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.507e+01  -1.127e+02   2.351e-03
#   -1.127e+02   6.544e+02  -1.223e-02
#    2.351e-03  -1.223e-02   2.444e-07
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    13.8570      +/-  5.00678
#    2    2   bremss     kT         keV      13.6039      +/-  25.5818
#    3    2   bremss     norm                8.06966E-04  +/-  4.94403E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  3.9532     using 8 bins.
#
# Test statistic : Chi-Squared                  3.9532     using 8 bins.
#  Null hypothesis probability of 5.5618e-01 with 5 degrees of freedom
# ***Warning: New best fit found, fit parameters will be set to new values.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 3.95172      0.000700361  -3       14.0957       11.9987   0.000815911
# 3.94986      162.502      -4       14.1094       12.1768   0.000816441
# 3.94986      3.37095      -5       14.1211       12.1390   0.000817552
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  5.3443E-09| -0.0000   0.0000   1.0000
#  5.5311E+00|  0.9791   0.2034   0.0000
#  4.6743E+02| -0.2034   0.9791  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.465e+01  -9.200e+01   2.405e-03
#   -9.200e+01   4.483e+02  -1.050e-02
#    2.405e-03  -1.050e-02   2.620e-07
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    14.1211      +/-  4.96456
#    2    2   bremss     kT         keV      12.1390      +/-  21.1735
#    3    2   bremss     norm                8.17552E-04  +/-  5.11876E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  3.9499     using 8 bins.
#
# Test statistic : Chi-Squared                  3.9499     using 8 bins.
#  Null hypothesis probability of 5.5666e-01 with 5 degrees of freedom
# ***Warning: New best fit found, fit parameters will be set to new values.
#
# ***Warning: Number of trials exceeded before bracketing of delta fit-stat.
# Last attempt: 200, with delta statistic: 0.323879
#
# Continue error search in this direction?
# *** Parameter upper bound is INVALID.
#
#      2      2.45845            0    (-9.68669,-12.1451)

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              4.135040e+09     using 8 bins.
#
# Test statistic : Chi-Squared              4.135040e+09     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 5 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 122.648      0.393923     -3      0.482860       46.5113   1.61042e-05
# 43.7617      56875.7      -3       22.6145       59.0705    0.00157895
# 4.66482      5907.57      -1       10.8596       62.9611    0.00196789
# 4.61436      446.89        0       10.8639       63.4906    0.00199309
# 4.59356      226.556       0       10.8903       63.7493    0.00201185
# 4.58378      82.3293       0       10.9260       63.9202    0.00202616
# 4.57937      10.0557       0       10.9638       63.9698    0.00203743
# 4.57692      76.0401       0       11.0007       63.9971    0.00204638
# 4.57572      120.859       0       11.0348       63.9996    0.00205366
# 4.57507      153.474       0       11.0654       63.9999    0.00205963
# 4.57478      177.202       0       11.0924       64.0000    0.00206460
# 4.57475      195.155       0       11.1157       64.0000    0.00206876
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  3.3687E-08| -0.0001  -0.0000   1.0000
#  4.1634E+00|  1.0000   0.0032   0.0001
#  4.9185E+05| -0.0032   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    9.242e+00  -1.581e+03  -3.804e-03
#   -1.581e+03   4.918e+05   1.333e+00
#   -3.804e-03   1.333e+00   3.704e-06
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    11.1157      +/-  3.04013
#    2    2   apec       kT         keV      64.0000      +/-  701.318
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                2.06876E-03  +/-  1.92451E-03
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  4.5748     using 8 bins.
#
# Test statistic : Chi-Squared                  4.5748     using 8 bins.
#  Null hypothesis probability of 4.6994e-01 with 5 degrees of freedom

# %%
Fit.error("1")
Fit.error("2")

out_arr[2,0] = 'apec'
out_arr[2,1:4] = mo.TBabs.nH.values[0], mo.TBabs.nH.values[0] - mo.TBabs.nH.error[0], mo.TBabs.nH.error[1] - mo.TBabs.nH.values[0]
out_arr[2,13] = mo.apec.Abundanc.values[0]
out_arr[2,4:7] = mo.apec.kT.values[0], mo.apec.kT.values[0] - mo.apec.kT.error[0], mo.apec.kT.error[1] - mo.apec.kT.values[0]
out_arr[2,-2:] = Fit.dof, Fit.statistic / Fit.dof
# Out:
#  Parameter   Confidence Range (2.706)
#      1      8.19949      15.6231    (-3.08627,4.33735)
#  Parameter   Confidence Range (2.706)
# ***Warning: Parameter pegged at hard limit: 64
#      2      15.3684            0    (-48.6316,-64)

# %%
AllModels.clear()
mo = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              7.779993e+10     using 8 bins.
#
# Test statistic : Chi-Squared              7.779993e+10     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 5 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 9.08556      3.19887      -3       3.38983       2.28754   3.41488e-05
# 4.31191      115875       -4       5.62853       2.01565   3.12740e-05
# 3.45237      7713.24      -5       7.52728       1.81832   3.08839e-05
# 3.3026       3106.33      -6       8.52345       1.74828   3.14670e-05
# 3.28393      994.905      -7       8.94373       1.71635   3.16715e-05
# 3.2818       284.045      -8       9.09069       1.70581   3.17555e-05
# 3.28157      41.3221      -9       9.14095       1.70205   3.17806e-05
# 3.28155      5.11912     -10       9.15754       1.70081   3.17889e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  8.0537E-12| -0.0000  -0.0000   1.0000
#  5.8585E-02| -0.0929  -0.9957  -0.0000
#  1.6069E+01|  0.9957  -0.0929   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.593e+01  -1.481e+00   2.902e-06
#   -1.481e+00   1.967e-01   7.186e-07
#    2.902e-06   7.186e-07   2.511e-11
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    9.15754      +/-  3.99133
#    2    2   bbody      kT         keV      1.70081      +/-  0.443511
#    3    2   bbody      norm                3.17889E-05  +/-  5.01099E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  3.2815     using 8 bins.
#
# Test statistic : Chi-Squared                  3.2815     using 8 bins.
#  Null hypothesis probability of 6.5667e-01 with 5 degrees of freedom

# %%
Fit.error("1")
Fit.error("2")

out_arr[0,0] = 'bbody'
out_arr[0,1:4] = mo.TBabs.nH.values[0], mo.TBabs.nH.values[0] - mo.TBabs.nH.error[0], mo.TBabs.nH.error[1] - mo.TBabs.nH.values[0]
out_arr[0,4:7] = mo.bbody.kT.values[0], mo.bbody.kT.values[0] - mo.bbody.kT.error[0], mo.bbody.kT.error[1] - mo.bbody.kT.values[0]
out_arr[0,-2:] = Fit.dof, Fit.statistic / Fit.dof
# Out:
#  Parameter   Confidence Range (2.706)
#      1      3.90776      20.6102    (-5.25451,11.4479)
#  Parameter   Confidence Range (2.706)
#      2      1.09888      2.87421    (-0.601437,1.17389)

# %%
np.savetxt('../spec48_output.csv',out_arr,fmt=['%s','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.1f','%.2f','%.2f','%.2f','%i','%.2f'],delimiter=',')

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 0.0001611 photons (1.5815e-12 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
#plx = 0.0353
d_kpc = 8
F_x = 1.5817*10**-12

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 1.2108366879500288e+34

# %%
import numpy as np
print(d_kpc)
print(np.log10(L_x))
# Out:
# 8
# 34.08308557146265

# %%
F_opt = 1.05*10**-5 * 10**(-0.4*18.91)
print('Optical Flux: ',F_opt)
print('F_x / F_opt: ', np.log10(F_x/F_opt))
# Out:
# Optical Flux:  2.865426671948443e-13
# F_x / F_opt:  0.741934815553387

# %%
AllModels.clear()
mo = Model("tbabs*(bbody+powerlaw)")
mo.bbody.kT = 1.0
mo.powerlaw.PhoIndex = 3
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>(bbody<2> + powerlaw<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
#    4    3   powerlaw   PhoIndex            1.00000      +/-  0.0
#    5    3   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              2.194155e+11     using 8 bins.
#
# Test statistic : Chi-Squared              2.194155e+11     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              4.501131e+12     using 8 bins.
#
# Test statistic : Chi-Squared              4.501131e+12     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              3.904063e+12     using 8 bins.
#
# Test statistic : Chi-Squared              3.904063e+12     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm    4:PhoIndex        5:norm
# 69.3242      45535.4      -1       1.70257       2.28737   6.89790e-06    -0.0579085   9.67670e-07
# 28.4981      933443        0       1.62820       2.12570   8.07872e-06     -0.833041   1.92750e-06
# 12.3157      1.31196e+06   0       2.28341       1.99486   9.85684e-06      -1.01919   2.51582e-06
# 6.89643      260686       -1       4.45530       1.64485   1.39161e-05     -0.937131   2.53952e-06
# 5.11975      52525.2      -2       6.31656       2.07977   2.60551e-05     -0.538173   2.52036e-06
# 4.85305      55077.6      -2       8.14406       1.84288   3.44668e-05    0.00544726   1.71969e-06
# 3.69641      111618       -1       8.41107       1.82998   3.44171e-05      0.721630   1.45959e-07
# 3.55317      41059.6       0       8.44670       1.82955   3.40932e-05       9.20890   4.36785e-08
# 3.55317      29549.7       5       8.44670       1.82955   3.40932e-05       8.49912   7.29295e-08
# ============================================================
#  Variances and Principal Axes
#                  1        2        3        4        5
#  4.2683E-13| -0.0898  -0.9958   0.0000  -0.0000   0.0184
#  4.2683E-11|  0.0000   0.0000   1.0000   0.0000  -0.0000
#  5.5340E-03| -0.0141   0.0197   0.0000  -0.0000   0.9997
#  3.4994E+01|  0.9959  -0.0896  -0.0000   0.0000   0.0158
#  2.0687E+16| -0.0000   0.0000  -0.0000   1.0000   0.0000
# ------------------------------------------------------------
#
# ============================================================
#   Covariance Matrix
#         1           2           3           4           5
#    3.816e+02  -1.771e+01   1.473e-04  -2.679e+09  -7.489e+01
#   -1.771e+01   9.765e-01  -4.572e-06   1.124e+08   3.122e+00
#    1.473e-04  -4.572e-06   1.019e-10  -1.153e+03  -3.240e-05
#   -2.679e+09   1.124e+08  -1.153e+03   2.069e+16   5.825e+08
#   -7.489e+01   3.122e+00  -3.240e-05   5.825e+08   1.642e+01
# ------------------------------------------------------------
#
# ========================================================================
# Model TBabs<1>(bbody<2> + powerlaw<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    8.44670      +/-  19.5358
#    2    2   bbody      kT         keV      1.82955      +/-  0.988165
#    3    2   bbody      norm                3.40932E-05  +/-  1.00960E-05
#    4    3   powerlaw   PhoIndex            8.49912      +/-  1.43828E+08
#    5    3   powerlaw   norm                7.29295E-08  +/-  4.05165
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  3.5532     using 8 bins.
#
# Test statistic : Chi-Squared                  3.5532     using 8 bins.
#  Null hypothesis probability of 3.1393e-01 with 3 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*(bbody+bbody)")
mo.bbody.kT = 0.5
mo.bbody_3.kT = 3
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>(bbody<2> + bbody<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
#    4    3   bbody      kT         keV      3.00000      +/-  0.0
#    5    3   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              3.112112e+11     using 8 bins.
#
# Test statistic : Chi-Squared              3.112112e+11     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              1.341802e+13     using 8 bins.
#
# Test statistic : Chi-Squared              1.341802e+13     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              1.341802e+13     using 8 bins.
#
# Test statistic : Chi-Squared              1.341802e+13     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm          4:kT        5:norm
# 81.58        640699       -2       3.12691      0.248342   4.18523e-07       1.35357   2.23390e-05
# 5.43154      1.08376e+06  -3       6.04204       2.74304   5.97849e-06       1.77204   2.63874e-05
# 3.59434      83581.4      -1       7.02649       2.48529   5.93381e-06       1.82323   2.64173e-05
# 3.40777      5440.62      -1       7.68592       2.16957   5.55022e-06       1.80173   2.65327e-05
# 3.33606      293.013      -1       8.13086       1.90572   5.24428e-06       1.78022   2.64816e-05
# 3.30546      201.907      -1       8.45509       1.74928   5.18778e-06       1.76758   2.64630e-05
# 3.28549      215.583      -2       8.87815       1.70557   5.19239e-06       1.72575   2.64624e-05
# 3.28286      450.384      -2       9.04132       1.76933   5.23425e-06       1.69832   2.65034e-05
# 3.28186      180.82       -1       9.09017       1.72072   5.23961e-06       1.70256   2.65105e-05
# 3.28165      47.7328      -1       9.11671       1.70652   5.25047e-06       1.70361   2.65214e-05
# 3.2816       38.5651      -2       9.14783       1.68729   5.25625e-06       1.70431   2.65272e-05
# ============================================================
#  Variances and Principal Axes
#                  1        2        3        4        5
#  2.6631E-07|  0.0008   0.0014   0.9826   0.0073   0.1856
#  2.6631E-05| -0.0012  -0.0021  -0.1855  -0.0107   0.9826
#  1.5837E+01|  1.0000  -0.0014  -0.0011   0.0056   0.0011
#  2.7160E+06|  0.0058   0.3045   0.0082  -0.9524  -0.0082
#  5.0618E+07| -0.0004   0.9525  -0.0045   0.3044   0.0045
# ------------------------------------------------------------
#
# ============================================================
#   Covariance Matrix
#         1           2           3           4           5
#    1.147e+02  -1.354e+04   2.153e+02  -2.088e+04  -2.153e+02
#   -1.354e+04   4.618e+07  -2.102e+05   1.389e+07   2.102e+05
#    2.153e+02  -2.102e+05   1.206e+03  -9.044e+04  -1.206e+03
#   -2.088e+04   1.389e+07  -9.044e+04   7.154e+06   9.044e+04
#   -2.153e+02   2.102e+05  -1.206e+03   9.044e+04   1.206e+03
# ------------------------------------------------------------
#
# ========================================================================
# Model TBabs<1>(bbody<2> + bbody<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    9.14783      +/-  10.7091
#    2    2   bbody      kT         keV      1.68729      +/-  6795.37
#    3    2   bbody      norm                5.25625E-06  +/-  34.7216
#    4    3   bbody      kT         keV      1.70431      +/-  2674.74
#    5    3   bbody      norm                2.65272E-05  +/-  34.7216
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  3.2816     using 8 bins.
#
# Test statistic : Chi-Squared                  3.2816     using 8 bins.
#  Null hypothesis probability of 3.5021e-01 with 3 degrees of freedom
