# %%
# %load_ext wurlitzer
import glob
import os
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12,8]
os.chdir('pps/')

Fit.statMethod = "chi"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4

# %%
spec_fnames = glob.glob('P*M2S*SRSPEC*.FTZ')

spec = Spectrum(spec_fnames[0])
Plot.device="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.00001 0.05")
Plot("data")
# Out:
# ***Warning: Detected response matrix energy bin value = 0 (or neg).
#      XSPEC will instead use small finite value (response file will not be altered).
#
# 1 spectrum  in use
#
# Spectral Data File: P0932191101M2S002SRSPEC0001.FTZ  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  1.336e-02 +/- 1.232e-03 (88.0 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-7
#   Telescope: XMM Instrument: EMOS2  Channel Type: PI
#   Exposure Time: 1.002e+04 sec
#  Using fit statistic: chi
#  Using Background File                P0932191101M2S002BGSPEC0001.FTZ
#   Background Exposure Time: 1.002e+04 sec
#  Using Response (RMF) File            m2_e13_im_pall_o.rmf for Source 1
#  Using Auxiliary Response (ARF) File  P0932191101M2S002SRCARF0001.FTZ

# %%
spec.ignore("**-0.2 12.0-**")
mo = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
#       No channels ignored (no channels in specified range)
#      1 channels (7) ignored in spectrum #     1
#
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              3.506036e+09     using 6 bins.
#
# Test statistic : Chi-Squared              3.506036e+09     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 73.6974      1.43532       0      0.637769       3.06446   8.92947e-05
# 65.7063      1037.23       0      0.222448       3.14661   8.23332e-05
# 62.8438      2461.04       0     0.0970822       3.25036   7.43245e-05
# 61.5789      28338.4       0     0.0194676       3.32321   6.90133e-05
# 60.043       46171.2       0    0.00563629       3.29449   7.05016e-05
# 59.2716      41123         0    0.00252232       3.27162   7.17009e-05
# 58.7483      36426.5       0    0.00106964       3.25305   7.26783e-05
# 58.3819      32294.1       0   0.000382226       3.23780   7.34773e-05
# 58.1189      28703.4       0   5.35550e-05       3.22519   7.41313e-05
# 57.9326      25608.1       0   1.39574e-05       3.21465   7.46665e-05
# 57.7928      22952.7       0   4.35395e-06       3.20581   7.51040e-05
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    4.86359E-17  +/-  -1.00000
#    2    2   bbody      kT         keV      0.314129     +/-  2.87932E-02
#    3    2   bbody      norm                2.26193E-06  +/-  2.31284E-07
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 11.0043     using 6 bins.
#
# Test statistic : Chi-Squared                 11.0043     using 6 bins.
#  Null hypothesis probability of 1.1703e-02 with 3 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.813362e+09     using 6 bins.
#
# Test statistic : Chi-Squared              1.813362e+09     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 57.2644      3.51287      -2      0.260219       47.9483   7.13146e-05
# 46.5843      83163.1      -3     0.0552438       197.478   8.92000e-05
# 18.3749      81839.1      -2     0.0190819       24.5301   8.97294e-05
# 14.9879      39605.3      -1    0.00916333       8.75841   8.40608e-05
# 14.1383      6674.3        0    0.00910625       5.29341   8.32149e-05
# 13.7617      2766.19       0     0.0136388       3.34907   8.40966e-05
# 13.2497      14989.4      -1     0.0439253       2.08936   9.81129e-05
# 12.1153      25654.2      -1     0.0648273       1.89662   0.000114766
# 11.7239      8386.63      -1     0.0790252       1.63106   0.000128008
# 11.408       7719.97      -1     0.0911044       1.48818   0.000140841
# 11.1895      4575.01      -1      0.101235       1.37554   0.000152566
# 11.0226      3431.49      -1      0.110068       1.28924   0.000163688
# 10.8902      2853.24      -1      0.117631       1.22442   0.000174203
# 10.7858      2029.67      -1      0.124365       1.17017   0.000184091
# 10.7026      1642.79      -1      0.130349       1.12576   0.000193380
# 10.6363      1326.66      -1      0.135682       1.08865   0.000202080
# 10.5838      1090.15      -1      0.140425       1.05759   0.000210161
# 10.576       895.874      -2      0.165375      0.903268   0.000252180
# 10.4399      5305.54      -3      0.187615      0.814297   0.000304344
# 10.3553      3075.61      -4      0.188162      0.813872   0.000314138
# 10.3553      6.8741       -5      0.187930      0.814564   0.000313652
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  9.9709E-10| -0.0008   0.0004   1.0000
#  2.1298E-03|  0.9699   0.2434   0.0007
#  1.7458E-01| -0.2434   0.9699  -0.0006
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.235e-02  -4.071e-02   2.870e-05
#   -4.071e-02   1.644e-01  -1.082e-04
#    2.870e-05  -1.082e-04   7.379e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.187930     +/-  0.111114
#    2    2   bremss     kT         keV      0.814564     +/-  0.405412
#    3    2   bremss     norm                3.13652E-04  +/-  2.71650E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 10.3553     using 6 bins.
#
# Test statistic : Chi-Squared                 10.3553     using 6 bins.
#  Null hypothesis probability of 1.5775e-02 with 3 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              4.772288e+08     using 6 bins.
#
# Test statistic : Chi-Squared              4.772288e+08     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 22.1747      9.18535       0      0.945857      0.755484   0.000414607
# 12.2236      9355.64      -1      0.718240      0.700723   0.000375330
# 11.2044      2779.95      -2      0.632760      0.717254   0.000290684
# 11.0229      2787.84      -3      0.607062      0.710642   0.000283717
# 11.0142      55.1441      -4      0.600830      0.708184   0.000280269
# 11.0134      5.69892      -5      0.598851      0.707693   0.000279140
# 11.0134      0.67026      -6      0.598331      0.707462   0.000278874
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  7.9247E-10| -0.0007   0.0003   1.0000
#  6.0270E-03| -0.7462  -0.6657  -0.0003
#  2.3527E-02|  0.6657  -0.7462   0.0007
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.378e-02  -8.693e-03   1.168e-05
#   -8.693e-03   1.577e-02  -1.054e-05
#    1.168e-05  -1.054e-05   1.167e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.598331     +/-  0.117401
#    2    2   apec       kT         keV      0.707462     +/-  0.125581
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                2.78874E-04  +/-  1.08047E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 11.0134     using 6 bins.
#
# Test statistic : Chi-Squared                 11.0134     using 6 bins.
#  Null hypothesis probability of 1.1654e-02 with 3 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              5.870746e+09     using 6 bins.
#
# Test statistic : Chi-Squared              5.870746e+09     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 39.5555      3.19606      -1      0.260887       1.98913   6.18181e-05
# 30.8054      114337       -2     0.0886060       2.78895   9.63546e-05
# 11.3248      109710       -3      0.304575       3.49391   0.000160597
# 10.3029      13607.1      -4      0.385375       3.74692   0.000213353
# 10.1668      5160.82      -5      0.359402       3.62463   0.000204287
# 10.1657      7.36884      -6      0.364140       3.64355   0.000207185
# 10.1657      13.968       -7      0.363132       3.63906   0.000206573
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  4.3291E-10| -0.0006  -0.0000   1.0000
#  2.3135E-03|  0.9863  -0.1651   0.0005
#  1.2450E+00|  0.1651   0.9863   0.0001
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    3.618e-02   2.023e-01   2.326e-05
#    2.023e-01   1.211e+00   1.314e-04
#    2.326e-05   1.314e-04   1.541e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.363132     +/-  0.190223
#    2    2   powerlaw   PhoIndex            3.63906      +/-  1.10052
#    3    2   powerlaw   norm                2.06573E-04  +/-  1.24138E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 10.1657     using 6 bins.
#
# Test statistic : Chi-Squared                 10.1657     using 6 bins.
#  Null hypothesis probability of 1.7209e-02 with 3 degrees of freedom

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 0.00011643 photons (2.1407e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
plx = 1.1723
d_kpc = 1/plx
F_x = 2.1407*10**-13

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 1.8632012287913393e+31
