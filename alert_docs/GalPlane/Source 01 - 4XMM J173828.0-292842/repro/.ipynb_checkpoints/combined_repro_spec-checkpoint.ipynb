# %%
# %load_ext wurlitzer
import glob
import os
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12,8]

Fit.statMethod = "chi"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4

# %%
spec = Spectrum('0886010101_ALL12grpspec.fits')
Plot.device="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.00001 0.005")
Plot("data")
# Out:
# Warning: RMF FILTER keyword (UNDEFINED) is not consistent with that in spectrum (Medium)
#
# 1 spectrum  in use
#
# Spectral Data File: 0886010101_ALL12grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  3.997e-03 +/- 9.722e-04 (14.8 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-14
#   Telescope: XMM Instrument: EPIC  Channel Type: PI
#   Exposure Time: 2.928e+04 sec
#  Using fit statistic: chi
#  Using Background File                0886010101_ALL12spec_bkg.fits
#   Background Exposure Time: 2.928e+04 sec
#  Using Response (RMF) File            0886010101_ALL12spec.rmf for Source 1

# %%
spec.ignore("**-0.2 12.0-**")
mo = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
#      3 channels (1-3) ignored in spectrum #     1
#      1 channels (14) ignored in spectrum #     1
#
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              5.034380e+12     using 10 bins.
#
# Test statistic : Chi-Squared              5.034380e+12     using 10 bins.
#  Null hypothesis probability of 0.000000e+00 with 7 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 14.3186      0.888057     -2       1.10004       4.50184   7.23616e-06
# 11.4915      507882       -2       1.72067       5.28969   1.23636e-05
# 10.2788      197463       -2       2.24334       5.59217   1.61535e-05
# 10.1167      41769.3      -2       2.63048       5.76437   1.82145e-05
# 10.0831      9260.31      -3       2.78887       6.27505   2.24786e-05
# 10.0548      16870.2      -4       2.96328       6.25714   2.29026e-05
# 10.0461      12.2893      -5       3.18995       5.97872   2.06168e-05
# 10.0339      3738.76      -6       3.44552       5.75895   1.90747e-05
# 10.0195      1941.16      -7       3.74479       5.51973   1.74446e-05
# 10.0009      2939.05      -8       4.11010       5.25123   1.57357e-05
# 9.97592      4345.89      -9       4.55289       4.97962   1.41703e-05
# 9.94317      4767.68     -10       5.10149       4.68656   1.26145e-05
# 9.89961      6728.37     -11       5.78034       4.38544   1.11864e-05
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.11253      +/-  2.11475
#    2    2   powerlaw   PhoIndex            -0.793627    +/-  0.550727
#    3    2   powerlaw   norm                5.96665E-07  +/-  5.98899E-07
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 10.4438     using 10 bins.
#
# Test statistic : Chi-Squared                 10.4438     using 10 bins.
#  Null hypothesis probability of 1.6479e-01 with 7 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              9.623004e+10     using 10 bins.
#
# Test statistic : Chi-Squared              9.623004e+10     using 10 bins.
#  Null hypothesis probability of 0.000000e+00 with 7 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 75.8092      0.918318     -3      0.300992       7.82112   1.51039e-06
# 56.8525      369577       -4      0.468806       38.6883   2.28547e-05
# 45.6618      42187.8      -1       1.05583       61.5682   4.06703e-05
# 38.1653      19456        -1       1.88737       62.8173   6.12969e-05
# 32.7753      32047.6      -1       2.92882       63.9720   8.29376e-05
# 28.9003      37341.2      -1       4.15426       63.9889   0.000103975
# 25.3849      38056        -1       5.62190       63.9967   0.000124085
# 21.6315      33251        -1       7.48426       63.9990   0.000144449
# 17.9052      24512.6      -1       9.85844       63.9995   0.000166697
# 14.7743      15016.1      -1       12.7128       63.9999   0.000191922
# 12.5834      7469.44      -1       15.7912       64.0000   0.000219886
# 11.2856      3005.61      -1       18.6763       64.0000   0.000248818
# 10.609       1332.2       -1       21.0420       64.0000   0.000276160
# 10.304       1400.83      -1       22.8070       64.0000   0.000299809
# 10.2046      2213.71      -1       24.0611       64.0000   0.000318849
# 10.0705      3165.21       0       24.4814       64.0000   0.000317455
# 10.0196      1572.87       0       24.7845       64.0000   0.000317677
# 9.99471      768.02        0       25.0174       64.0000   0.000318720
# 9.97906      372.218       0       25.2079       64.0000   0.000320150
# 9.96738      188.112       0       25.3718       64.0000   0.000321734
# 9.9579       112.851       0       25.5176       64.0000   0.000323352
# 9.94991      92.8869       0       25.6504       64.0000   0.000324943
# 9.94305      100.393       0       25.7730       64.0000   0.000326475
# 9.93713      120.954       0       25.8870       64.0000   0.000327937
# 9.93198      147.149       0       25.9936       64.0000   0.000329323
# 9.92749      175.195       0       26.0935       64.0000   0.000330633
# 9.92357      203.202       0       26.1872       64.0000   0.000331868
# 9.92015      230.262       0       26.2752       64.0000   0.000333032
# 9.91716      255.972       0       26.3579       64.0000   0.000334128
# 9.90179      420.277      -1       26.8262       64.0000   0.000337906
# 9.8931       124.473      -2       27.3249       64.0000   0.000344114
# 9.89131      32.9924      -3       27.5679       64.0000   0.000347104
# 9.89103      3.94022      -4       27.6658       64.0000   0.000348283
# 9.89099      0.495752     -5       27.7041       64.0000   0.000348740
# 9.89099      0.0468207     1       27.7041       64.0000   0.000348741
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  1.7483E-09| -0.0000  -0.0000   1.0000
#  4.7701E+01|  1.0000   0.0064   0.0000
#  1.7428E+06| -0.0064   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.186e+02  -1.111e+04  -3.794e-03
#   -1.111e+04   1.743e+06   6.842e-01
#   -3.794e-03   6.842e-01   2.772e-07
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    27.7041      +/-  10.8890
#    2    2   apec       kT         keV      64.0000      +/-  1320.13
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                3.48741E-04  +/-  5.26463E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  9.8910     using 10 bins.
#
# Test statistic : Chi-Squared                  9.8910     using 10 bins.
#  Null hypothesis probability of 1.9484e-01 with 7 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              3.029490e+11     using 10 bins.
#
# Test statistic : Chi-Squared              3.029490e+11     using 10 bins.
#  Null hypothesis probability of 0.000000e+00 with 7 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 50.2526      1.9489        0       1.26676       23.9710   7.86320e-06
# 49.3592      320287       -1      0.861556       199.252   2.15581e-05
# 38.5507      198141       -1       1.58675       199.329   2.56049e-05
# 31.0189      49678.7      -1       2.71953       199.359   3.17771e-05
# 25.4685      4524.46      -1       4.31550       199.361   3.95741e-05
# 21.1618      20907.2      -1       6.45262       199.246   4.88043e-05
# 17.5417      26171.6      -1       9.34134       198.540   5.97879e-05
# 14.3195      30668.9      -2       13.9824       199.346   0.000100538
# 12.9291      34939        -2       17.9310       199.359   0.000124677
# 11.307       34525        -2       21.1978       199.363   0.000138744
# 10.3171      23366.1      -2       23.6399       199.363   0.000146611
# 9.88956      13826.1      -2       25.2489       199.363   0.000150625
# 9.74273      7552.65      -2       26.1883       199.363   0.000152425
# 9.69563      3839.98      -2       26.6988       199.363   0.000152648
# 9.69286      1228.29      -3       26.9842       199.324   0.000151774
# 9.69208      1144.42      -2       27.0920       199.282   0.000152399
# 9.69159      1070.18      -2       27.1386       199.237   0.000152706
# 9.69023      997.595      -2       27.1541       199.201   0.000153042
# 9.68901      739.3        -1       27.1417       199.182   0.000153332
# 9.6887       386.281      -1       27.1392       199.171   0.000153490
# 9.68862      215.978      -1       27.1407       199.163   0.000153574
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  3.3865E-10| -0.0000  -0.0000   1.0000
#  4.7673E+01|  1.0000   0.0032   0.0000
#  1.2301E+07| -0.0032   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.761e+02  -3.974e+04  -6.980e-03
#   -3.974e+04   1.230e+07   2.238e+00
#   -6.980e-03   2.238e+00   4.088e-07
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    27.1407      +/-  13.2687
#    2    2   bremss     kT         keV      199.163      +/-  3507.32
#    3    2   bremss     norm                1.53574E-04  +/-  6.39413E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  9.6886     using 10 bins.
#
# Test statistic : Chi-Squared                  9.6886     using 10 bins.
#  Null hypothesis probability of 2.0692e-01 with 7 degrees of freedom
