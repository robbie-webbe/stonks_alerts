# %%
# %load_ext wurlitzer
import glob
import os
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12,8]
os.chdir('pps/')

Fit.statMethod = "chi"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4

# %%
spec_fnames = glob.glob('P*PNS*SRSPEC*.FTZ')

spec = Spectrum(spec_fnames[0])
Plot.device="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.00001 0.005")
Plot("data")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: P0886040701PNS003SRSPEC0008.FTZ  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  4.372e-03 +/- 7.054e-04 (39.9 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-12
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 2.243e+04 sec
#  Using fit statistic: chi
#  Using Background File                P0886040701PNS003BGSPEC0008.FTZ
#   Background Exposure Time: 2.243e+04 sec
#  Using Response (RMF) File            epn_e3_ff20_sdY9.rmf for Source 1
#  Using Auxiliary Response (ARF) File  P0886040701PNS003SRCARF0008.FTZ

# %%
spec.ignore("**-0.2 12.0-**")
mo = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
#       No channels ignored (no channels in specified range)
#      1 channels (12) ignored in spectrum #     1
#
# Fit statistic  : Chi-Squared                  4.4931     using 10 bins.
#
# Test statistic : Chi-Squared                  4.4931     using 10 bins.
#  Null hypothesis probability of 7.2155e-01 with 7 degrees of freedom
#  Current data and model not fit yet.
#
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              4.020036e+12     using 10 bins.
#
# Test statistic : Chi-Squared              4.020036e+12     using 10 bins.
#  Null hypothesis probability of 0.000000e+00 with 7 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 11.1193      0.407014     -1       2.62852       2.56991   2.63899e-06
# 9.56259      20657.3      -1       3.69792       2.10893   2.07736e-06
# 7.50716      154026       -1       4.88153       1.59969   1.65551e-06
# 6.13868      438434       -1       6.98623       1.16955   1.62690e-06
# 5.75366      782208       -2       10.4465      0.945566   2.19426e-06
# 5.10747      704404       -3       11.6999      0.913131   2.74147e-06
# 5.08636      107652       -4       11.3453      0.920794   2.71217e-06
# 5.08607      171.054      -5       11.4628      0.917935   2.74123e-06
# 5.08605      415.56       -6       11.4301      0.918729   2.73323e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.7106E-13| -0.0000   0.0000   1.0000
#  1.8897E-02| -0.0360  -0.9994   0.0000
#  4.8649E+01|  0.9994  -0.0360   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    4.859e+01  -1.749e+00   1.373e-05
#   -1.749e+00   8.188e-02  -5.450e-07
#    1.373e-05  -5.450e-07   4.189e-12
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    11.4301      +/-  6.97035
#    2    2   bbody      kT         keV      0.918729     +/-  0.286146
#    3    2   bbody      norm                2.73323E-06  +/-  2.04669E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  5.0861     using 10 bins.
#
# Test statistic : Chi-Squared                  5.0861     using 10 bins.
#  Null hypothesis probability of 6.4946e-01 with 7 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              2.573723e+11     using 10 bins.
#
# Test statistic : Chi-Squared              2.573723e+11     using 10 bins.
#  Null hypothesis probability of 0.000000e+00 with 7 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
#
# 6.22397      2152.46      -1       9.53776       2.02803   7.45492e-05
# 6.15543      1939.1       -1       9.68044       2.06497   7.97010e-05
# 6.09048      1751.46      -1       9.82003       2.10093   8.50551e-05
# 6.02887      1585.96      -1       9.95663       2.13595   9.06123e-05
# 5.97038      1439.56      -1       10.0903       2.17007   9.63733e-05
# 5.91481      1309.7       -1       10.2212       2.20332   0.000102338
# 5.86197      1194.19      -1       10.3494       2.23574   0.000108508
# 5.85285      1091.18      -2       11.5191       2.50319   0.000161277
# 5.53899      7639.24      -2       12.3527       2.71849   0.000238445
# 5.22446      4795.68      -2       13.1028       2.89473   0.000334826
# 5.01248      2627.16      -2       13.7348       3.04416   0.000445667
# 4.8763       1454.23      -2       14.2915       3.17328   0.000568540
# 4.78337      853.866      -2       14.7810       3.28606   0.000701471
# 4.71687      528.121      -2       15.2151       3.38529   0.000842560
# 4.66759      341.299      -2       15.6014       3.47307   0.000989861
# 4.6302       228.532      -2       15.9464       3.55108    0.00114147
# 4.60132      157.614      -2       16.2555       3.62067    0.00129557
# 4.57872      111.46       -2       16.5331       3.68293    0.00145053
# 4.56085      80.5396      -2       16.7829       3.73879    0.00160485
# 4.54661      59.3007      -2       17.0081       3.78901    0.00175725
# 4.53518      44.391       -2       17.2114       3.83426    0.00190663
# 4.52596      33.7217      -2       17.3953       3.87508    0.00205208
# 4.51849      25.9557      -2       17.5618       3.91198    0.00219286
# 4.51242      20.2161      -2       17.7127       3.94537    0.00232841
# 4.50746      15.9156      -2       17.8496       3.97561    0.00245830
# 4.5034       12.6531      -2       17.9739       4.00304    0.00258224
# 4.50007      10.15        -2       18.0868       4.02794    0.00270004
# 4.49733      8.2095       -2       18.1895       4.05055    0.00281163
# 4.49507      6.69086      -2       18.2829       4.07111    0.00291700
# 4.49321      5.49193      -2       18.3680       4.08981    0.00301621
# 4.49312      4.53771      -3       18.7997       4.17947    0.00350457
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  2.0469E-07| -0.0002  -0.0044   1.0000
#  4.2379E-01|  0.1812  -0.9834  -0.0043
#  9.7440E+01|  0.9835   0.1812   0.0010
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    9.426e+01   1.728e+01   9.596e-02
#    1.728e+01   3.608e+00   1.954e-02
#    9.596e-02   1.954e-02   1.065e-04
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    18.7997      +/-  9.70857
#    2    2   powerlaw   PhoIndex            4.17947      +/-  1.89943
#    3    2   powerlaw   norm                3.50457E-03  +/-  1.03206E-02
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  4.4931     using 10 bins.
#
# Test statistic : Chi-Squared                  4.4931     using 10 bins.
#  Null hypothesis probability of 7.2155e-01 with 7 degrees of freedom

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 1.0024e-05 photons (8.0464e-14 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
#plx = 0.1944
d_kpc = 8
F_x = 8.0482*10**-14

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 6.1611277941198844e+32

# %%
import numpy as np
print(d_kpc)
print(np.log10(L_x))
# Out:
# 8
# 32.78966021702348

# %%
F_opt = 1.05*10**-5 * 10**(-0.4*20.7)
print('Optical Flux: ',F_opt)
print('F_x / F_opt: ', np.log10(F_x/F_opt))
# Out:
# Optical Flux:  5.510478332622621e-14
# F_x / F_opt:  0.16450946111422177
