# %%
# %load_ext wurlitzer
import glob
import os
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12,8]
os.chdir('pps/')

Fit.statMethod = "chi"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4

# %%
spec_fnames = glob.glob('P*PNS*SRSPEC*.FTZ')

spec = Spectrum(spec_fnames[0])
Plot.device="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.0001 0.01")
Plot("data")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: P0886110501PNS003SRSPEC0013.FTZ  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  3.239e-03 +/- 6.132e-04 (39.5 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-8
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 2.221e+04 sec
#  Using fit statistic: chi
#  Using Background File                P0886110501PNS003BGSPEC0013.FTZ
#   Background Exposure Time: 2.221e+04 sec
#  Using Response (RMF) File            epn_e3_ff20_sdY0.rmf for Source 1
#  Using Auxiliary Response (ARF) File  P0886110501PNS003SRCARF0013.FTZ

# %%
spec.ignore("**-0.2 12.0-**")
mo = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
#       No channels ignored (no channels in specified range)
#      1 channels (8) ignored in spectrum #     1
#
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              1.481036e+11     using 7 bins.
#
# Test statistic : Chi-Squared              1.481036e+11     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 4 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
#  Due to zero model norms, the following fit parameters are temporarily frozen:1 2
# 56.8471      168320       -3       1.00000       3.00000       0.00000
#  Due to zero model norms, the following fit parameters are temporarily frozen:1 2
# 56.8471      168320       -3       1.00000       3.00000       0.00000
# ====================
#  Variances and Principal Axes
#                  3
#  2.7008E-11|  1.0000
# --------------------
#
# ============
#   Covariance Matrix
#         1
#    2.701e-11
# ------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  -1.00000
#    2    2   bbody      kT         keV      3.00000      +/-  -1.00000
#    3    2   bbody      norm                0.0          +/-  5.19695E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   56.85     using 7 bins.
#
# Test statistic : Chi-Squared                   56.85     using 7 bins.
#  Null hypothesis probability of 1.33e-11 with 4 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              2.680468e+11     using 7 bins.
#
# Test statistic : Chi-Squared              2.680468e+11     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 4 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
#  Due to zero model norms, the following fit parameters are temporarily frozen:1 2
# 56.8471      191646       -3       1.00000       1.00000       0.00000
#  Due to zero model norms, the following fit parameters are temporarily frozen:1 2
# 56.8471      191646       -3       1.00000       1.00000       0.00000
# ====================
#  Variances and Principal Axes
#                  3
#  1.4923E-11|  1.0000
# --------------------
#
# ============
#   Covariance Matrix
#         1
#    1.492e-11
# ------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  -1.00000
#    2    2   powerlaw   PhoIndex            1.00000      +/-  -1.00000
#    3    2   powerlaw   norm                0.0          +/-  3.86301E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   56.85     using 7 bins.
#
# Test statistic : Chi-Squared                   56.85     using 7 bins.
#  Null hypothesis probability of 1.33e-11 with 4 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              8.407127e+10     using 7 bins.
#
# Test statistic : Chi-Squared              8.407127e+10     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 4 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
#  Due to zero model norms, the following fit parameters are temporarily frozen:1 2
# 56.8471      97130.3      -3       1.00000       7.00000       0.00000
#  Due to zero model norms, the following fit parameters are temporarily frozen:1 2
# 56.8471      97130.3      -3       1.00000       7.00000       0.00000
# ====================
#  Variances and Principal Axes
#                  3
#  4.7579E-11|  1.0000
# --------------------
#
# ============
#   Covariance Matrix
#         1
#    4.758e-11
# ------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  -1.00000
#    2    2   bremss     kT         keV      7.00000      +/-  -1.00000
#    3    2   bremss     norm                0.0          +/-  6.89775E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   56.85     using 7 bins.
#
# Test statistic : Chi-Squared                   56.85     using 7 bins.
#  Null hypothesis probability of 1.33e-11 with 4 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              2.067967e+10     using 7 bins.
#
# Test statistic : Chi-Squared              2.067967e+10     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 4 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 51.9498      0.890596     -3      0.329479      0.398987   2.08699e-06
# 12.8405      347714       -1     0.0173727      0.162035   1.16936e-05
# 12.0581      71121.9      -1    0.00157633      0.153814   1.06678e-05
# 11.9688      7391.22       0   1.42037e-05      0.152140   1.06581e-05
# 11.9419      20160.6       0   5.73270e-07      0.150385   1.06939e-05
# 11.9226      46921.1       0   7.48375e-08      0.148998   1.07916e-05
# 11.8969      59164.7       0   9.01737e-09      0.147883   1.09177e-05
# 11.8667      63481.4       0   6.98822e-10      0.146925   1.10553e-05
# 11.8351      64109.8       0   1.83711e-10      0.146067   1.11960e-05
# 11.8043      63051.6       0   5.72007e-11      0.145271   1.13362e-05
# 11.7729      61346.5       0   2.58444e-11      0.144418   1.14809e-05
# 11.7352      60778.2       0   1.01731e-11      0.143514   1.16345e-05
# 11.6958      61348.4       0   2.26899e-12      0.142563   1.18017e-05
# 11.6549      61781.7       0   3.01745e-13      0.141655   1.19766e-05
# 11.6138      61142.8       0   6.04084e-14      0.140814   1.21535e-05
# 11.574       59565.1       0   1.41999e-15      0.140023   1.23293e-05
# 11.5187      57621.9       0   1.93353e-16      0.139406   1.25481e-05
# 11.2706      49184.9      -1   5.30334e-17      0.134049   1.38614e-05
# 11.2637      41787.8       0   2.10241e-17      0.134030   1.38912e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  4.5637E-12| -0.0000   0.0003   1.0000
#  6.7384E-04| -0.1833  -0.9831   0.0002
#  2.1435E-02|  0.9831  -0.1833   0.0001
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.074e-02  -3.741e-03   1.538e-06
#   -3.741e-03   1.371e-03  -4.573e-07
#    1.538e-06  -4.573e-07   1.651e-10
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    2.10241E-17  +/-  0.144006
#    2    2   apec       kT         keV      0.134030     +/-  3.70333E-02
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.38912E-05  +/-  1.28476E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   11.26     using 7 bins.
#
# Test statistic : Chi-Squared                   11.26     using 7 bins.
#  Null hypothesis probability of 2.38e-02 with 4 degrees of freedom

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 5.1482e-05 photons (2.6954e-14 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
plx = 9.3764
d_kpc = 1/plx
F_x = 1.8223*10**-13

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 2.4793001439987456e+29
