# %%
# %load_ext wurlitzer
import numpy as np
import glob
import os
import matplotlib.pyplot as plt
from astropy.io import fits
from xspec import *
plt.rcParams['figure.figsize'] = [9,6]

# %%
spec_file = sorted(glob.glob("*grpspec.fits"))
spec = Spectrum(spec_file[0])
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0916811401_PN17grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  7.278e-03 +/- 2.496e-03 (29.1 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-6
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 6870 sec
#  Using fit statistic: chi
#  Using Background File                0916811401_PN17spec_bkg.fits
#   Background Exposure Time: 6870 sec
#  Using Response (RMF) File            0916811401_PN17spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0916811401_PN17spec.arf

# %%
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.00001 0.05")
Plot("data")

# %%
spec.ignore("**-0.175 12.0-**")
AllModels.clear()
mo1 = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
#      2 channels (1-2) ignored in spectrum #     1
#      1 channels (6) ignored in spectrum #     1
#
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              3.254727e+10     using 3 bins.
#
# Test statistic : Chi-Squared              3.254727e+10     using 3 bins.
#  Cannot calculate null hypothesis probability.
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 5.73949      0.186579      0      0.416963       3.09083   1.04348e-05
# 5.17354      16351.4       0      0.164523       3.14294   9.78869e-06
# 4.79246      30496.1       0     0.0506938       3.16487   9.41546e-06
# 4.52292      40184.4       0    0.00306317       3.15369   9.29050e-06
# 4.44694      43300.3       0   0.000639601       3.12503   9.28470e-06
# 4.41388      41311.3       0   6.04343e-05       3.10401   9.22391e-06
# 4.39826      40582.7       0   2.49157e-05       3.08652   9.13764e-06
# 4.38869      40515         0   7.30547e-06       3.07058   9.04052e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.9704E-11| -0.0000  -0.0000   1.0000
#  4.9987E-01|  0.9988   0.0480   0.0000
#  3.5664E+02| -0.0480   0.9988   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.322e+00  -1.709e+01  -1.212e-04
#   -1.709e+01   3.558e+02   2.567e-03
#   -1.212e-04   2.567e-03   1.856e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    7.30547E-06  +/-  1.14965
#    2    2   bbody      kT         keV      3.07058      +/-  18.8632
#    3    2   bbody      norm                9.04052E-06  +/-  1.36217E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    4.39     using 3 bins.
#
# Test statistic : Chi-Squared                    4.39     using 3 bins.
#  Cannot calculate null hypothesis probability.
# GammQ: A <=  0
# GammQ: A <=  0
#  Model Flux 4.491e-05 photons (4.3924e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
AllModels.clear()
mo1 = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              4.887982e+09     using 3 bins.
#
# Test statistic : Chi-Squared              4.887982e+09     using 3 bins.
#  Cannot calculate null hypothesis probability.
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 3.41851      0.287016     -1      0.610309       1.92804   3.25084e-05
# 0.740092     16421.9      -1      0.149390       2.79177   2.03120e-05
# 0.553305     6075.48      -1     0.0919564       4.74258   1.53760e-05
# 0.409296     19955.2      -1     0.0363395       12.2712   1.38606e-05
# 0.260791     21334.1      -2     0.0160499       55.8240   2.09372e-05
# 0.168771     7223.79      -1     0.0326046       60.8856   2.20115e-05
# 0.157097     369.616      -1     0.0386580       65.8603   2.29517e-05
# 0.153047     667.669      -1     0.0400569       71.9549   2.36873e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  4.9659E-11| -0.0001  -0.0000   1.0000
#  1.0150E-02|  1.0000   0.0001   0.0001
#  2.4632E+06| -0.0001   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    4.390e-02  -2.883e+02  -2.497e-05
#   -2.883e+02   2.463e+06   2.201e-01
#   -2.497e-05   2.201e-01   1.977e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    4.00569E-02  +/-  0.209513
#    2    2   bremss     kT         keV      71.9549      +/-  1569.44
#    3    2   bremss     norm                2.36873E-05  +/-  1.40623E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    0.15     using 3 bins.
#
# Test statistic : Chi-Squared                    0.15     using 3 bins.
#  Cannot calculate null hypothesis probability.
# GammQ: A <=  0
# GammQ: A <=  0

# %%
AllModels.clear()
mo1 = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              1.680041e+09     using 3 bins.
#
# Test statistic : Chi-Squared              1.680041e+09     using 3 bins.
#  Cannot calculate null hypothesis probability.
#  Current data and model not fit yet.
# GammQ: A <=  0
# GammQ: A <=  0
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 3.57593      0.303709      0      0.993520      0.720206   6.62467e-05
# 2.27658      6867.14      -1      0.738831      0.567370   7.17518e-05
# 2.15945      140.151      -1      0.676223      0.552416   6.39845e-05
# 2.12032      173.121      -1      0.642166      0.556076   5.83657e-05
# 2.10108      192.238      -1      0.620275      0.567751   5.39682e-05
# 2.0891       188.342      -1      0.604182      0.581982   5.04433e-05
# 2.08161      152.873      -1      0.590675      0.591391   4.79664e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  2.8868E-10| -0.0001   0.0001   1.0000
#  6.3646E-02|  0.7675   0.6410   0.0001
#  4.6197E+01| -0.6410   0.7675  -0.0001
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.902e+01  -2.270e+01   4.430e-03
#   -2.270e+01   2.724e+01  -5.300e-03
#    4.430e-03  -5.300e-03   1.033e-06
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.590675     +/-  4.36104
#    2    2   apec       kT         keV      0.591391     +/-  5.21937
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                4.79664E-05  +/-  1.01647E-03
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    2.08     using 3 bins.
#
# Test statistic : Chi-Squared                    2.08     using 3 bins.
#  Cannot calculate null hypothesis probability.

# %%
AllModels.clear()
mo1 = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# GammQ: A <=  0
# GammQ: A <=  0
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              2.050857e+10     using 3 bins.
#
# Test statistic : Chi-Squared              2.050857e+10     using 3 bins.
#  Cannot calculate null hypothesis probability.
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 0.876738     0.420259     -1      0.153238       1.28336   1.55137e-05
# 0.225708     36067.1      -1     0.0825388       1.30961   1.20540e-05
# 0.132334     2983.49      -1     0.0482968       1.18070   1.06535e-05
# 0.0799646    1238.94      -1     0.0258590       1.05450   9.75311e-06
# 0.0476694    1545.3       -1    0.00969705      0.956423   9.10921e-06
# 0.0407432    1699         -1    0.00384382      0.881905   8.64042e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  7.6111E-12| -0.0000  -0.0000   1.0000
#  7.7976E-03|  0.9893  -0.1456   0.0000
#  2.3749E+00|  0.1456   0.9893   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    5.800e-02   3.410e-01   2.321e-06
#    3.410e-01   2.325e+00   1.412e-05
#    2.321e-06   1.412e-05   1.012e-10
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    3.84382E-03  +/-  0.240828
#    2    2   powerlaw   PhoIndex            0.881905     +/-  1.52468
#    3    2   powerlaw   norm                8.64042E-06  +/-  1.00600E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    0.04     using 3 bins.
#
# Test statistic : Chi-Squared                    0.04     using 3 bins.
#  Cannot calculate null hypothesis probability.

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 3.6707e-05 photons (1.9664e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
plx = 0.9706
d_kpc = 1/plx
F_x = 1.9664*10**-13

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 2.4967368687386064e+31

# %%
F_opt = 1.05*10**-5 * 10**(-0.4*16.23)
print('Optical Flux: ',F_opt)
print('F_x / F_opt: ', F_x/F_opt)
# Out:
# Optical Flux:  3.3821222308476e-12
# F_x / F_opt:  0.05814100927710105
