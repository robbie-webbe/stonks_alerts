# %%
# %load_ext wurlitzer
import numpy as np
import glob
import os
import matplotlib.pyplot as plt
from astropy.io import fits
from xspec import *
plt.rcParams['figure.figsize'] = [9,6]

Fit.statMethod = "chi"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4

# %%
spec_file = sorted(glob.glob("*grpspec.fits"))
spec = Spectrum(spec_file[0])
#spec = Spectrum(spec_file[0],backFile=glob.glob("*spec_bkg.fits")[0],respFile=glob.glob("*.rmf")[0],arfFile=glob.glob("*.arf")[0])
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0916811401_PN17grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  7.278e-03 +/- 2.496e-03 (29.1 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-6
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 6870 sec
#  Using fit statistic: chi
#  Using Background File                0916811401_PN17spec_bkg.fits
#   Background Exposure Time: 6870 sec
#  Using Response (RMF) File            0916811401_PN17spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0916811401_PN17spec.arf

# %%
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.00001 0.05")
Plot("data")

# %%
spec.ignore("**-0.15")
AllModels.clear()
mo1 = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
#      1 channels (1) ignored in spectrum #     1
#
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              7.869636e+10     using 5 bins.
#
# Test statistic : Chi-Squared              7.869636e+10     using 5 bins.
#  Null hypothesis probability of 0.000000e+00 with 2 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 7.32229      0.186692      0     0.0455162       3.07465   4.39816e-06
# 6.91186      66532.9       0     0.0168683       2.88886   4.21476e-06
# 6.56434      70433.6       0    0.00606276       2.71843   4.01587e-06
# 6.27492      72298.4       0    0.00166889       2.56883   3.79164e-06
# 6.02391      74933.4       0   0.000725220       2.43463   3.55747e-06
# 5.78627      78930.4       0   0.000304748       2.31148   3.32487e-06
# 5.55066      84648         0   0.000115026       2.19616   3.10304e-06
# 5.31312      91567.5       0   2.90155e-05       2.08747   2.89574e-06
# 5.07335      99343.3       0   9.49053e-06       1.98503   2.70419e-06
# 4.83271      107725        0   6.22208e-07       1.88882   2.52836e-06
# 4.59411      116547        0   1.18594e-07       1.79899   2.36777e-06
# 4.35943      125691        0   4.09661e-09       1.71533   2.22154e-06
# 4.13201      134975        0   8.38950e-10       1.63794   2.08869e-06
# 3.91319      144381        0   9.59194e-11       1.56641   1.96812e-06
# 3.70472      153770        0   1.09617e-11       1.50050   1.85879e-06
# 3.50701      163089        0   1.23568e-12       1.43978   1.75989e-06
# 3.31851      172095        0   1.14772e-13       1.38369   1.67139e-06
# 3.16025      179828        0   5.70293e-14       1.33498   1.58827e-06
# 2.99829      192397        0   2.71218e-14       1.28629   1.50811e-06
# 2.8169       204860        0   1.10310e-14       1.24017   1.45490e-06
# 2.686        196141        0   1.08975e-16       1.20249   1.39682e-06
# 1.54136      202881       -1   2.51659e-18      0.877507   9.77229e-07
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 2.51659e-18 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 1.12278      176655       -2   2.51659e-18      0.662242   6.60044e-07
# 1.07143      385415       -3   2.51659e-18      0.625711   6.50061e-07
# 1.0688       10477.7      -4   2.51659e-18      0.614341   6.33956e-07
# 1.06832      2770.55      -5   2.51659e-18      0.609567   6.27908e-07
# 1.06822      398.563      -6   2.51659e-18      0.607494   6.25231e-07
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 2.51659e-18 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 1.0682       88.8709      -3   2.51659e-18      0.606550   6.24010e-07
# ==============================
#  Variances and Principal Axes
#                  2        3
#  3.9710E-14| -0.0000   1.0000
#  6.7155E-02|  1.0000   0.0000
# ------------------------------
#
# ========================
#   Covariance Matrix
#         1           2
#    6.716e-02   8.748e-08
#    8.748e-08   1.537e-13
# ------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    2.51659E-18  +/-  -1.00000
#    2    2   bbody      kT         keV      0.606550     +/-  0.259144
#    3    2   bbody      norm                6.24010E-07  +/-  3.92000E-07
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  1.0682     using 5 bins.
#
# Test statistic : Chi-Squared                  1.0682     using 5 bins.
#  Null hypothesis probability of 5.8620e-01 with 2 degrees of freedom
#  Model Flux 1.9514e-05 photons (5.2197e-14 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
AllModels.clear()
mo1 = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              5.130352e+09     using 5 bins.
#
# Test statistic : Chi-Squared              5.130352e+09     using 5 bins.
#  Null hypothesis probability of 0.000000e+00 with 2 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 0.586311     0.31664      -2      0.112058       9.90759   1.62579e-05
# 0.366807     23216        -3     0.0555056       28.8393   1.72727e-05
# 0.285641     20498.4      -4     0.0240284       76.4895   2.42007e-05
# 0.215462     11304        -5     0.0269213       199.097   3.14885e-05
# 0.210399     2864.25      -2     0.0309103       199.221   3.17546e-05
# 0.207619     2146.15      -1     0.0315267       199.270   3.15452e-05
# 0.206985     1121.68      -1     0.0316111       199.298   3.14397e-05
# 0.206787     697.506      -1     0.0316038       199.317   3.13846e-05
# 0.206718     495.211      -1     0.0315857       199.332   3.13578e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  9.1211E-11| -0.0001  -0.0000   1.0000
#  9.2875E-03|  1.0000   0.0000   0.0001
#  2.9986E+07| -0.0000   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.852e-02  -7.594e+02  -3.602e-05
#   -7.594e+02   2.999e+07   1.461e+00
#   -3.602e-05   1.461e+00   7.141e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    3.15857E-02  +/-  0.168873
#    2    2   bremss     kT         keV      199.332      +/-  5475.99
#    3    2   bremss     norm                3.13578E-05  +/-  2.67223E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  0.2067     using 5 bins.
#
# Test statistic : Chi-Squared                  0.2067     using 5 bins.
#  Null hypothesis probability of 9.0180e-01 with 2 degrees of freedom

# %%
AllModels.clear()
mo1 = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              1.680111e+09     using 5 bins.
#
# Test statistic : Chi-Squared              1.680111e+09     using 5 bins.
#  Null hypothesis probability of 0.000000e+00 with 2 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 3.61801      0.299457      0      0.993810      0.724985   6.62601e-05
# 2.34059      6737.59      -1      0.741235      0.575375   7.11852e-05
# 2.21562      261.055      -1      0.676744      0.556851   6.35099e-05
# 2.17468      172.406      -1      0.641724      0.558908   5.79978e-05
# 2.15532      198.265      -1      0.619550      0.569802   5.36722e-05
# 2.14362      192.621      -1      0.603401      0.583653   5.01965e-05
# 2.13618      144.887      -1      0.589837      0.592735   4.77590e-05
# 2.13085      193.709      -1      0.579010      0.602208   4.57083e-05
# 2.12695      188.179      -1      0.569844      0.611165   4.39844e-05
# 2.125        171.944      -1      0.562617      0.613575   4.29667e-05
# 2.12362      134.498      -1      0.556719      0.617540   4.20517e-05
# 2.12255      126.566      -1      0.551639      0.621515   4.12478e-05
# 2.1217       117.576      -1      0.547166      0.625175   4.05444e-05
# 2.12103      108.451      -1      0.543192      0.628475   3.99276e-05
# 2.1205       99.7023      -1      0.539646      0.631438   3.93848e-05
# 2.12007      91.4917      -1      0.536474      0.634099   3.89054e-05
# 2.11972      83.8577      -1      0.533630      0.636490   3.84807e-05
# 2.11944      76.7947      -1      0.531075      0.638643   3.81032e-05
# 2.11922      70.2799      -1      0.528776      0.640583   3.77669e-05
# 2.11904      64.2839      -1      0.526706      0.642333   3.74665e-05
# 2.11889      58.7744      -1      0.524838      0.643914   3.71976e-05
# 2.11877      53.7184      -1      0.523151      0.645344   3.69565e-05
# 2.11871      49.0831      -1      0.521626      0.646637   3.67400e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  1.5512E-10| -0.0001   0.0000   1.0000
#  5.8097E-02|  0.7106   0.7036   0.0000
#  3.4244E+03| -0.7036   0.7106  -0.0001
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.695e+03  -1.712e+03   2.521e-01
#   -1.712e+03   1.729e+03  -2.546e-01
#    2.521e-01  -2.546e-01   3.749e-05
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.521626     +/-  41.1725
#    2    2   apec       kT         keV      0.646637     +/-  41.5841
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                3.67400E-05  +/-  6.12321E-03
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  2.1187     using 5 bins.
#
# Test statistic : Chi-Squared                  2.1187     using 5 bins.
#  Null hypothesis probability of 3.4668e-01 with 2 degrees of freedom

# %%
AllModels.clear()
mo1 = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              2.530849e+10     using 5 bins.
#
# Test statistic : Chi-Squared              2.530849e+10     using 5 bins.
#  Null hypothesis probability of 0.000000e+00 with 2 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 2.44181      0.606709     -3      0.258049       1.23063   1.03619e-05
# 0.41185      58925        -1     0.0672005       1.24847   9.85308e-06
# 0.216213     37452.4      -2     0.0190389       1.12340   9.58409e-06
# 0.209274     7443.86      -3     0.0252331       1.13414   9.63113e-06
# 0.209259     195.625      -4     0.0254745       1.13366   9.63341e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  8.6572E-12| -0.0000  -0.0000   1.0000
#  8.4961E-03|  0.9877  -0.1566   0.0000
#  1.4909E+00|  0.1566   0.9877   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    4.485e-02   2.293e-01   1.846e-06
#    2.293e-01   1.455e+00   9.862e-06
#    1.846e-06   9.862e-06   8.527e-11
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    2.54745E-02  +/-  0.211783
#    2    2   powerlaw   PhoIndex            1.13366      +/-  1.20603
#    3    2   powerlaw   norm                9.63341E-06  +/-  9.23433E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  0.2093     using 5 bins.
#
# Test statistic : Chi-Squared                  0.2093     using 5 bins.
#  Null hypothesis probability of 9.0066e-01 with 2 degrees of freedom

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 3.1375e-05 photons (1.4502e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
plx = 0.9706
d_kpc = 1/plx
F_x = 1.9664*10**-13

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 2.4967368687386064e+31

# %%
import numpy as np
print(d_kpc)
print(np.log10(L_x))
# Out:
# 1.030290541932825
# 31.397372774439283

# %%
F_opt = 1.05*10**-5 * 10**(-0.4*16.23)
print('Optical Flux: ',F_opt)
print('F_x / F_opt: ', np.log10(F_x/F_opt))
# Out:
# Optical Flux:  3.3821222308476e-12
# F_x / F_opt:  -1.2355174335275585
