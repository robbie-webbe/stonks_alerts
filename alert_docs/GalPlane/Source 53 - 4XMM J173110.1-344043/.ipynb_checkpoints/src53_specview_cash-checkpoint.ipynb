# %%
# %load_ext wurlitzer
import numpy as np
import glob
import os
import matplotlib.pyplot as plt
from astropy.io import fits
from xspec import *
plt.rcParams['figure.figsize'] = [9,6]

Fit.statMethod = "cstat10"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4

# %%
#spec_file = sorted(glob.glob("*grpspec.fits"))
#spec = Spectrum(spec_file[0])
spec = Spectrum(glob.glob("*cash.fits")[0],backFile=glob.glob("*spec_bkg.fits")[0],respFile=glob.glob("*.rmf")[0],arfFile=glob.glob("*.arf")[0])
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0916811401_PN17spec_cash.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  2.518e-02 +/- 1.915e-03
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-1126
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 6870 sec
#  Using fit statistic: cstat10
#  No response loaded.
#
# ***Warning!  One or more spectra are missing responses,
#                and are not suitable for fit.
# Net count rate (cts/s) for Spectrum:1  7.133e-03 +/- 2.509e-03 (28.3 % total)
# ***Warning!  One or more spectra are missing responses,
#                and are not suitable for fit.
# Response successfully loaded.
# Arf successfully loaded.
# Spectrum 1  Spectral Data File: 0916811401_PN17spec_cash.fits
# Net count rate (cts/s) for Spectrum:1  7.133e-03 +/- 2.509e-03 (28.3 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-1126
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 6870 sec
#  Using fit statistic: cstat10
#  Using Background File                0916811401_PN17spec_bkg.fits
#   Background Exposure Time: 6870 sec
#  Using Response (RMF) File            0916811401_PN17spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0916811401_PN17spec.arf
#
#  Spectral data counts: 173
#  Model predicted rate: 0.0

# %%
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.00001 0.05")
Plot.addCommand("Rescale X 0.1 15")
Plot("data")

# %%
#spec.ignore("**-0.175 12.0-**")
AllModels.clear()
mo1 = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : C-Statistic (10)         6.420142e+06     using 1126 bins.
#
# Test statistic : Chi-Squared              1.518633e+11     using 1126 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 0.000000e+00 with 1123 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic (10)|beta|/N    Lvl          1:nH          2:kT        3:norm
# 129.208      1.29602e+06  -3      0.336441       193.489     0.0922308
# 129.164      0.636577      0      0.118513       195.131     0.0861897
# 129.109      0.78503       1     0.0580492       193.952     0.0895296
# 129.043      0.846416      1    0.00593935       192.046     0.0929907
# 128.989      0.922253      1   0.000343095       188.547     0.0965333
# 128.901      0.962713      1   2.99782e-05       181.265     0.0998688
# 128.663      1.0384        1   1.33831e-05       163.025      0.102762
# 128.052      1.24646       1   1.71451e-06       128.490      0.104705
# 127.839      1.38626       1   3.33129e-07       114.186      0.105304
# 127.839      0.752479      2   1.63878e-07       114.191      0.105304
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  2.1479E-03| -0.0077  -0.0027   1.0000
#  5.7243E+00|  1.0000   0.0002   0.0077
#  2.3155E+07| -0.0002   1.0000   0.0027
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    6.552e+00  -4.378e+03  -1.196e+01
#   -4.378e+03   2.315e+07   6.350e+04
#   -1.196e+01   6.350e+04   1.742e+02
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.63878E-07  +/-  2.55966
#    2    2   bbody      kT         keV      114.191      +/-  4811.90
#    3    2   bbody      norm                0.105304     +/-  13.1966
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic (10)           127.8391     using 1126 bins.
#
# Test statistic : Chi-Squared                102.5105     using 1126 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 1.0000e+00 with 1123 degrees of freedom
#  Model Flux 3.9574e-05 photons (5.0513e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
AllModels.clear()
mo1 = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic (10)         3.691550e+06     using 1126 bins.
#
# Test statistic : Chi-Squared              4.587332e+10     using 1126 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 0.000000e+00 with 1123 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic (10)|beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 129.621      939339        0       153.728       7.45866     0.0544608
# 129.208      0.00577635   -1       11.3459       8.97046     0.0203593
# 128.807      3.29834       1       10.9671       8.57426     0.0251849
# 124.694      5.17806       0       9.66349       6.79099     0.0503479
# 123.786      16.6937       0       10.2358       6.85856     0.0446335
# 123.56       2.38466      -1       11.1885       6.67292     0.0424332
# 123.418      0.368574     -2       12.0212       6.11161     0.0249852
# 123.299      7.52632      -2       12.6365       5.87081     0.0243194
# 123.291      0.588971     -2       13.0922       5.88221     0.0267587
# 123.287      0.362311     -2       13.4358       5.95977     0.0307241
# 123.283      0.612844     -2       13.7410       6.04560     0.0355167
# 123.28       0.579953     -2       14.0296       6.13123     0.0409856
# 123.276      0.49019      -2       14.3063       6.21488     0.0471108
# 123.273      0.403414     -2       14.5715       6.29596     0.0538962
# 123.27       0.329427     -2       14.8251       6.37421     0.0613439
# 123.267      0.268281     -2       15.0670       6.44946     0.0694485
# 123.264      0.218333     -2       15.2971       6.52160     0.0781952
# 123.262      0.177779     -2       15.5156       6.59059     0.0875606
# 123.26       0.144965     -2       15.7227       6.65642     0.0975132
# 123.259      0.118461     -2       15.9186       6.71913      0.108014
# 123.257      0.0970628    -2       16.1038       6.77876      0.119018
# 123.256      0.0797766    -2       16.2787       6.83538      0.130477
# 123.254      0.0657927    -2       16.4437       6.88909      0.142335
# 123.253      0.0544568    -2       16.5992       6.93999      0.154537
# 123.252      0.045244     -2       16.7458       6.98817      0.167027
# 123.251      0.0377347    -2       16.8838       7.03376      0.179746
# 123.251      0.031594     -2       17.0138       7.07686      0.192637
# 123.25       0.0265553    -2       17.1362       7.11759      0.205645
# 123.249      0.022406     -2       17.2513       7.15606      0.218717
# 123.249      0.0189766    -2       17.3596       7.19238      0.231800
# 123.248      0.0161317    -2       17.4616       7.22667      0.244849
# 123.248      0.013763     -2       17.5574       7.25902      0.257817
# 123.247      0.0117834    -2       17.6476       7.28955      0.270665
# 123.247      0.0101231    -2       17.7325       7.31834      0.283355
# 123.247      0.00872559   -2       17.8123       7.34550      0.295854
# 123.247      0.00754514   -2       17.8874       7.37110      0.308133
# 123.246      0.00654467   -2       17.9581       7.39525      0.320166
# 123.246      0.00569393   -2       18.0245       7.41802      0.331931
# 123.246      0.00496819   -2       18.0871       7.43948      0.343408
# 123.246      0.00434717   -2       18.1459       7.45972      0.354582
# 123.246      0.00381415   -2       18.2013       7.47879      0.365440
# 123.245      0.00335534   -2       18.2534       7.49678      0.375973
# 123.245      0.00295929   -2       18.3025       7.51373      0.386174
# 123.245      0.0026165    -2       18.3487       7.52971      0.396036
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  2.7182E-02| -0.0586  -0.3892   0.9193
#  1.2988E+01|  0.4346  -0.8389  -0.3275
#  1.2155E+03|  0.8987   0.3804   0.2183
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    9.841e+02   4.107e+02   2.366e+02
#    4.107e+02   1.850e+02   1.045e+02
#    2.366e+02   1.045e+02   5.936e+01
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    18.3487      +/-  31.3709
#    2    2   powerlaw   PhoIndex            7.52971      +/-  13.6010
#    3    2   powerlaw   norm                0.396036     +/-  7.70456
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic (10)           123.2453     using 1126 bins.
#
# Test statistic : Chi-Squared                 97.5200     using 1126 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 1.0000e+00 with 1123 degrees of freedom

# %%
AllModels.clear()
mo1 = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic (10)         1.522719e+06     using 1126 bins.
#
# Test statistic : Chi-Squared              9.057417e+09     using 1126 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 0.000000e+00 with 1123 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic (10)|beta|/N    Lvl          1:nH          2:kT        3:norm
# 530361       290305       -3      0.463143       199.194      0.406914
# 34622.7      229218       -1      0.212357       199.320     0.0209941
# 22115.9      282093       -1     0.0702881       199.351     0.0104033
# 9584.34      368063       -1     0.0264284       199.359    0.00408958
# 4650.9       418118       -1    0.00524027       199.363    0.00188468
# 1998.89      458068       -1   0.000575446       199.363   0.000857904
# 754.697      458119       -1   6.85974e-05       199.363   0.000379829
# 301.195      413187       -1   2.86629e-06       199.363   0.000180248
# 140.421      329732       -1   6.50947e-07       199.363   8.22274e-05
# 121.558      191961       -2   2.67203e-07       199.363   6.31675e-05
# 114.05       135160       -2   9.26581e-08       199.363   5.22655e-05
# 111.711      92505.1      -2   7.79220e-09       199.363   4.74649e-05
# 109.304      69438.5      -1   2.94722e-09       199.363   3.97009e-05
# 108.746      33100.3      -1   5.32240e-11       199.363   3.56256e-05
# 108.666      12261.2      -1   2.89243e-12       199.363   3.37756e-05
# 108.665      2205.6        0   1.16085e-12       199.363   3.30652e-05
# 108.665      1626.6        1   5.94016e-14       199.363   3.30678e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  6.1075E-11| -0.0009  -0.0000   1.0000
#  7.2204E-06|  1.0000   0.0000   0.0009
#  4.9200E+06| -0.0000   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    9.191e-06  -3.114e+00  -1.621e-07
#   -3.114e+00   4.920e+06   2.662e-01
#   -1.621e-07   2.662e-01   1.446e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    5.94016E-14  +/-  3.03172E-03
#    2    2   bremss     kT         keV      199.363      +/-  2218.12
#    3    2   bremss     norm                3.30678E-05  +/-  1.20268E-04
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic (10)           108.6650     using 1126 bins.
#
# Test statistic : Chi-Squared                 90.0228     using 1126 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 1.0000e+00 with 1123 degrees of freedom

# %%
AllModels.clear()
mo1 = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : C-Statistic (10)           659998.0     using 1126 bins.
#
# Test statistic : Chi-Squared              3.186760e+09     using 1126 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 0.000000e+00 with 1123 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic (10)|beta|/N    Lvl          1:nH          2:kT        5:norm
# 363416       202763       -3      0.233173       32.5173      0.390917
# 127862       178899       -4    0.00961309       50.5450     0.0878833
# 38070.6      285720       -1    0.00388001       58.9751     0.0267549
# 4659.21      251500       -1    0.00170927       61.7098    0.00367449
# 1944.7       235819       -1   0.000415921       63.3102    0.00168726
# 819.841      227161       -1   0.000193842       63.6886   0.000824087
# 341.581      206009       -1   1.50905e-05       63.8771   0.000404640
# 143.314      170116       -1   4.56440e-06       63.9703   0.000171134
# 122.931      98073.8      -2   1.36116e-06       63.9948   0.000131016
# 116.594      69769.8      -2   6.62202e-07       63.9996   0.000114096
# 113.18       54646.7      -2   5.45759e-09       63.9999   0.000102400
# 112.51       42284.7      -2   4.45508e-10       64.0000   9.96589e-05
# 110.611      39095.9      -2   1.34502e-10       64.0000   9.01985e-05
# 109.036      28006.2      -1   5.86217e-11       64.0000   7.75489e-05
# 108.703      13168.3      -1   1.60925e-11       64.0000   7.17076e-05
# 108.641      5724.99      -1   4.68232e-12       64.0000   6.90925e-05
# 108.632      2139.19      -1   1.71488e-12       64.0000   6.79491e-05
# 108.632      667.873      -1   2.00652e-13       64.0000   6.70215e-05
# 108.631      558.957       0   6.13535e-14       63.8897   6.69997e-05
# 108.631      544.551       0   2.65278e-14       63.8374   6.69771e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  2.6366E-10| -0.0021  -0.0000   1.0000
#  6.2718E-06|  1.0000   0.0000   0.0021
#  2.0425E+05| -0.0000   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    7.792e-06  -5.572e-01  -1.571e-07
#   -5.572e-01   2.042e+05   6.246e-02
#   -1.571e-07   6.246e-02   1.939e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    2.65278E-14  +/-  2.79135E-03
#    2    2   apec       kT         keV      63.8374      +/-  451.935
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                6.69771E-05  +/-  1.39252E-04
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic (10)           108.6314     using 1126 bins.
#
# Test statistic : Chi-Squared                 89.9848     using 1126 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 1.0000e+00 with 1123 degrees of freedom

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 3.9429e-05 photons (1.3514e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
plx = 0.9706
d_kpc = 1/plx
F_x = 1.9664*10**-13

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 2.4967368687386064e+31

# %%
import numpy as np
print(d_kpc)
print(np.log10(L_x))
# Out:
# 1.030290541932825
# 31.397372774439283

# %%
F_opt = 1.05*10**-5 * 10**(-0.4*16.23)
print('Optical Flux: ',F_opt)
print('F_x / F_opt: ', np.log10(F_x/F_opt))
# Out:
# Optical Flux:  3.3821222308476e-12
# F_x / F_opt:  -1.2355174335275585

# %%
AllModels.clear()
mo = Model("tbabs*(apec+apec)")
mo.apec.kT = 0.5
mo.apec_3.kT = 4.0
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic (10)         1.321484e+06     using 1126 bins.
#
# Test statistic : Chi-Squared              1.274750e+10     using 1126 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 0.000000e+00 with 1121 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic (10)         1.000034e+06     using 1126 bins.
#
# Test statistic : Chi-Squared              7.340644e+09     using 1126 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 0.000000e+00 with 1121 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic (10)           900838.5     using 1126 bins.
#
# Test statistic : Chi-Squared              3.532432e+09     using 1126 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 0.000000e+00 with 1121 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic (10)|beta|/N    Lvl          1:nH          2:kT        5:norm          6:kT        9:norm
# 593083       160086       -3      0.447375       59.2267      0.404220       35.3607      0.464143
# 245774       109694       -2      0.160869       63.4308      0.116404       62.2885      0.159812
# 133159       133981       -1     0.0267017       63.9744     0.0320771       63.8720     0.0749398
# 44913.5      187361       -1    0.00398909       63.9987    0.00715067       63.9554     0.0250285
# 1855.37      206842       -1    0.00112300       63.9996    0.00104601       63.9960   0.000604417
# 709.023      188222       -1   0.000173074       64.0000   0.000434972       63.9990   0.000298892
# 155.102      170416       -1   8.30520e-05       64.0000   0.000163239       63.9998   2.71583e-05
# 135.737      91498.6      -2   1.68057e-05       64.0000   0.000146905       63.9999   1.08244e-05
# 131.226      75997.6      -2   4.44010e-06       64.0000   0.000142558       64.0000   6.47776e-06
# 129.925      70882.3      -2   1.56295e-06       64.0000   0.000141245       64.0000   5.16417e-06
# 129.518      69231.8      -2   1.53124e-07       64.0000   0.000140827       64.0000   4.74632e-06
# 124.013      68708.3      -2   6.65561e-08       64.0000   0.000131222       64.0000   2.34506e-06
# 121.891      60936.9      -2   2.14072e-08       64.0000   0.000127842       64.0000   6.55360e-07
# 121.151      57438        -2   1.04032e-08       64.0000   0.000126368       64.0000   2.86753e-07
# 120.758      56109.8      -2   4.94870e-09       64.0000   0.000125570       64.0000   8.73436e-08
# 120.567      55378.1      -2   2.23388e-09       64.0000   0.000125135       64.0000   3.29388e-08
# 120.454      55015.3      -2   8.79449e-10       64.0000   0.000124877       64.0000   6.57477e-10
# 120.394      54799        -2   2.03112e-10       64.0000   0.000124723       64.0000   5.77970e-11
# 120.357      54683.9      -2   3.41420e-11       64.0000   0.000124625       64.0000   9.84356e-12
# 120.332      54610.5      -2   1.30301e-11       64.0000   0.000124562       64.0000   2.36959e-12
# 120.316      54563.2      -2   2.47735e-12       64.0000   0.000124521       64.0000   1.09304e-12
# 120.306      54532.8      -2   1.15881e-12       64.0000   0.000124494       64.0000   4.85297e-13
# 114.582      54512.4      -1   6.36051e-14       64.0000   0.000107573       64.0000   2.33175e-13
# 113.558      50937.2      -2   2.52887e-14       64.0000   0.000103863       64.0000   1.05539e-14
# 112.883      46611.6      -2   6.19829e-15       64.0000   0.000101213       64.0000   3.06569e-15
# 111.7        57855.7      -3   1.75274e-15       64.0000   9.60011e-05       64.0000   8.39239e-16
# 109.219      49169.6      -2   5.99049e-16       64.0000   7.96659e-05       64.0000   1.95608e-16
# 108.862      22071        -2   2.95182e-16       64.0000   5.90502e-05       64.0000   5.86244e-07
# 108.821      14238        -3   8.49365e-17       64.0000   5.93999e-05       64.0000   9.35955e-07
# 108.809      12930.7      -4   1.85694e-17       64.0000   5.95103e-05       64.0000   1.04635e-06
# 108.784      12500.7      -1   4.43729e-18       64.0000   5.97583e-05       64.0000   1.29438e-06
# 108.769      11545.6      -1   5.19446e-19       64.0000   5.99113e-05       64.0000   1.44735e-06
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 5.19446e-19 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 108.632      16407.5      -2   5.19446e-19       64.0000   6.27427e-05       64.0000   4.27876e-06
# 108.631      1112.21      -3   5.19446e-19       64.0000   6.29501e-05       64.0000   4.48617e-06
# 108.631      5.78614      -4   5.19446e-19       64.0000   6.29512e-05       64.0000   4.48726e-06
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 5.19446e-19 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 108.63       0.000227106  -2   5.19446e-19       31.4007   5.34490e-05       6.83351   2.11170e-06
# 108.603      4281.38       0   5.19446e-19       31.5938   5.37284e-05       21.1671   1.95886e-06
# 108.598      1338.44       0   5.19446e-19       31.9773   5.40047e-05       44.3005   2.11735e-06
# 108.597      837.67        0   5.19446e-19       32.1500   5.39732e-05       43.8560   2.08326e-06
# 108.596      582.283       0   5.19446e-19       32.3012   5.39515e-05       42.6024   2.06008e-06
# 108.596      399.884       0   5.19446e-19       32.4361   5.39373e-05       41.3715   2.04536e-06
# 108.596      261.834       0   5.19446e-19       32.5360   5.39274e-05       39.8110   2.03545e-06
# 108.595      182.003       0   5.19446e-19       33.2579   5.39447e-05       28.6697   2.06281e-06
# 108.595      45.9553       0   5.19446e-19       33.3155   5.39529e-05       32.7660   2.06870e-06
# 108.594      142.684       0   5.19446e-19       33.7258   5.40966e-05       43.4670   2.21042e-06
# 108.594      245.669       0   5.19446e-19       33.7788   5.41058e-05       39.8825   2.22007e-06
# 108.594      169.268       0   5.19446e-19       33.8354   5.41134e-05       38.4354   2.22848e-06
# 108.593      147.998       0   5.19446e-19       34.3542   5.42043e-05       36.9162   2.32827e-06
# 108.592      173.387      -1   5.19446e-19       37.2238   5.47298e-05       28.3653   2.89311e-06
# 108.591      69.545        0   5.19446e-19       37.2213   5.47351e-05       31.2108   2.89553e-06
# 108.591      78.2192       0   5.19446e-19       37.0440   5.48419e-05       44.1916   2.98621e-06
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 5.19446e-19 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 108.591      95.2538       0   5.19446e-19       37.0494   5.48435e-05       41.7986   2.98671e-06
# 108.591      21.3549       0   5.19446e-19       37.0617   5.48423e-05       40.0506   2.98499e-06
# 108.591      24.024        0   5.19446e-19       37.0757   5.48405e-05       39.2771   2.98291e-06
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 5.19446e-19 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 108.591      34.4051       0   5.19446e-19       37.0909   5.48381e-05       38.5255   2.98048e-06
# ***Warning: LevMarq::invertCorrelationMatrix:
#             Negative diagonal element for parameter 2
# ***Warning: LevMarq::invertCorrelationMatrix:
#             Negative diagonal element for parameter 5
# ***Warning: LevMarq::invertCorrelationMatrix:
#             Negative diagonal element for parameter 6
# ***Warning: LevMarq::invertCorrelationMatrix:
#             Negative diagonal element for parameter 9
# ==================================================
#  Variances and Principal Axes
#                  2        5        6        9
#  3.7781E-07|  0.0977   0.0000   0.9952  -0.0000
#  3.7781E-07|  0.0000  -1.0000   0.0000   0.0003
#  3.7781E-05| -0.0000  -0.0003  -0.0000  -1.0000
#  9.9428E+07|  0.9952   0.0000  -0.0977  -0.0000
# --------------------------------------------------
#
# ================================================
#   Covariance Matrix
#         1           2           3           4
#   -3.400e+14  -1.316e+10  -3.462e+15   1.316e+10
#   -1.316e+10  -5.095e+05  -1.340e+11   5.095e+05
#   -3.462e+15  -1.340e+11  -3.525e+16   1.340e+11
#    1.316e+10   5.095e+05   1.340e+11  -5.095e+05
# ------------------------------------------------
#
# ========================================================================
# Model TBabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    5.19446E-19  +/-  -1.00000
#    2    2   apec       kT         keV      37.0909      +/-  -1.00000
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                5.48381E-05  +/-  -1.00000
#    6    3   apec       kT         keV      38.5255      +/-  -1.00000
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                2.98048E-06  +/-  -1.00000
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic (10)           108.5909     using 1126 bins.
#
# Test statistic : Chi-Squared                 90.0117     using 1126 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 1.0000e+00 with 1121 degrees of freedom
