# %%
# %load_ext wurlitzer
import numpy as np
import glob
import os
import matplotlib.pyplot as plt
from astropy.io import fits
from xspec import *
plt.rcParams['figure.figsize'] = [9,6]

# %%
spec_file = sorted(glob.glob("*grpspec.fits"))
spec = Spectrum(spec_file[0])
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0886090501_PN141grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  1.037e-02 +/- 1.891e-03 (33.5 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-19
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 1.01e+04 sec
#  Using fit statistic: chi
#  Using Background File                0886090501_PN141spec_bkg.fits
#   Background Exposure Time: 1.01e+04 sec
#  Using Response (RMF) File            0886090501_PN141spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0886090501_PN141spec.arf

# %%
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.00001 0.05")
Plot("data")

# %%
spec.ignore("**-0.2 12.0-**")
AllModels.clear()
mo1 = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
#      2 channels (1-2) ignored in spectrum #     1
#      1 channels (19) ignored in spectrum #     1
#
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              7.436603e+11     using 16 bins.
#
# Test statistic : Chi-Squared              7.436603e+11     using 16 bins.
#  Null hypothesis probability of 0.000000e+00 with 13 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 35.9093      0.0842879    -3      0.403085       1.16334   1.74905e-07
# 35.8007      2.13344e+06  -2      0.113251      0.145991   6.22082e-08
# 32.7119      5.95447e+06   0     0.0520813      0.205229   9.44648e-08
# 31.0989      4.71532e+06   0    0.00675901      0.257688   1.03544e-07
# 30.5172      3.53658e+06   0    0.00148374      0.307150   1.09142e-07
# 30.075       4.63869e+06   0   0.000627055      0.358493   1.20474e-07
# 29.6584      4.98282e+06   0   0.000114569      0.405843   1.36705e-07
# 29.2844      4.65751e+06   0   4.42634e-05      0.446935   1.55453e-07
# 28.9654      4.10512e+06   0   7.53369e-06      0.482683   1.74941e-07
# 28.7079      3.55232e+06   0   2.83599e-06      0.514391   1.94104e-07
# Number of trials exceeded: continue fitting? 28.5056      3.07974e+06   0   4.46059e-07      0.542891   2.12435e-07
# 28.3495      2.69566e+06   0   1.42191e-07      0.568616   2.29687e-07
# 28.2305      2.38726e+06   0   6.48645e-08      0.591798   2.45729e-07
# 28.1412      2.13884e+06   0   2.54938e-08      0.612588   2.60481e-07
# 28.0753      1.9373e+06    0   5.45185e-09      0.631122   2.73903e-07
# 28.0277      1.77271e+06   0   3.53874e-10      0.647538   2.85989e-07
# 27.9941      1.63763e+06   0   3.00000e-11      0.661988   2.96766e-07
# 27.971       1.52643e+06   0   9.44810e-12      0.674632   3.06291e-07
# 27.9558      1.43471e+06   0   4.23798e-12      0.685635   3.14639e-07
# 27.9463      1.35898e+06   0   1.59976e-12      0.695164   3.21906e-07
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.2333E-14| -0.0000  -0.0000   1.0000
#  3.7234E-02| -0.8069  -0.5907  -0.0000
#  1.7958E-01|  0.5907  -0.8069  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    8.690e-02  -6.785e-02  -1.616e-09
#   -6.785e-02   1.299e-01   4.829e-08
#   -1.616e-09   4.829e-08   4.111e-14
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.59976E-12  +/-  0.294789
#    2    2   bbody      kT         keV      0.695164     +/-  0.360434
#    3    2   bbody      norm                3.21906E-07  +/-  2.02750E-07
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   27.95     using 16 bins.
#
# Test statistic : Chi-Squared                   27.95     using 16 bins.
#  Null hypothesis probability of 9.21e-03 with 13 degrees of freedom
#  Model Flux 8.8244e-06 photons (2.694e-14 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.565859e+11     using 16 bins.
#
# Test statistic : Chi-Squared              1.565859e+11     using 16 bins.
#  Null hypothesis probability of 0.000000e+00 with 13 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 29.4105      0.890474     -3      0.429523       2.89500   1.40988e-05
# 28.8106      19938.3      -1      0.327063       2.10405   1.09623e-05
# 28.5589      451.161      -2      0.183651       1.71352   6.96134e-06
# 27.9284      35917.3      -3     0.0710258       1.51510   5.54802e-06
# 27.1996      9570.23      -1     0.0138016       1.40589   4.67713e-06
# 26.9595      8873.39       0    0.00435796       1.41300   4.52416e-06
# 26.9174      12304.1       0    0.00188876       1.40160   4.35943e-06
# 26.9144      36467.8       0   0.000525871       1.38927   4.24335e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.7799E-12| -0.0000   0.0000   1.0000
#  5.1965E-03|  0.9930  -0.1185   0.0000
#  9.3229E-01|  0.1185   0.9930   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.820e-02   1.090e-01   3.436e-07
#    1.090e-01   9.193e-01   2.024e-06
#    3.436e-07   2.024e-06   8.269e-12
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    5.25871E-04  +/-  0.134923
#    2    2   powerlaw   PhoIndex            1.38927      +/-  0.958794
#    3    2   powerlaw   norm                4.24335E-06  +/-  2.87561E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   26.91     using 16 bins.
#
# Test statistic : Chi-Squared                   26.91     using 16 bins.
#  Null hypothesis probability of 1.28e-02 with 13 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              2.630434e+10     using 16 bins.
#
# Test statistic : Chi-Squared              2.630434e+10     using 16 bins.
#  Null hypothesis probability of 0.000000e+00 with 13 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 31.2659      0.536745      0      0.950892       5.86269   1.61544e-05
# 30.3412      5211.97       0      0.691766       2.01395   1.64011e-05
# 28.8438      39103.8      -1      0.363047       2.62367   1.54491e-05
# 28.6491      9933.11      -1      0.293357       3.06924   1.25937e-05
# 28.4081      4008.06      -2      0.156289       4.82310   8.15291e-06
# 27.5471      50113.6      -3     0.0451956       8.07358   7.15115e-06
# 27.2894      15438.2      -1     0.0135576       14.1873   6.45990e-06
# 26.8224      62191.1       0   0.000343866       12.8062   6.52661e-06
# 26.805       28072.8       0   0.000108281       12.4835   6.54527e-06
# 26.7958      24012.4       0   5.12432e-05       12.2153   6.55983e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  3.9665E-12| -0.0000  -0.0000   1.0000
#  5.6860E-03|  1.0000   0.0012   0.0000
#  3.0248E+03| -0.0012   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    9.960e-03  -3.596e+00  -3.233e-08
#   -3.596e+00   3.025e+03   1.612e-04
#   -3.233e-08   1.612e-04   1.702e-11
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    5.12432E-05  +/-  9.98002E-02
#    2    2   bremss     kT         keV      12.2153      +/-  54.9985
#    3    2   bremss     norm                6.55983E-06  +/-  4.12565E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   26.80     using 16 bins.
#
# Test statistic : Chi-Squared                   26.80     using 16 bins.
#  Null hypothesis probability of 1.33e-02 with 13 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              7.689840e+09     using 16 bins.
#
# Test statistic : Chi-Squared              7.689840e+09     using 16 bins.
#  Null hypothesis probability of 0.000000e+00 with 13 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 31.0148      0.705893     -2       1.53511      0.766019   6.13527e-05
# 30.3714      9573.01      -1       1.45573       1.11137   5.21313e-05
# 30.148       7025.64       0       1.43203       1.00480   5.64819e-05
# 30.0835      4179.65      -1       1.48606      0.896721   6.78960e-05
# 30.0424      2151.92       0       1.48595      0.937970   6.84443e-05
# 30.0354      523.624      -1       1.49894      0.967304   6.87494e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  5.6502E-10| -0.0001   0.0001   1.0000
#  2.1674E-01| -0.9065  -0.4223  -0.0000
#  1.0455E+00|  0.4223  -0.9065   0.0001
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    3.645e-01  -3.173e-01   4.626e-05
#   -3.173e-01   8.977e-01  -7.391e-05
#    4.626e-05  -7.391e-05   8.258e-09
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.49894      +/-  0.603778
#    2    2   apec       kT         keV      0.967304     +/-  0.947471
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                6.87494E-05  +/-  9.08722E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   30.04     using 16 bins.
#
# Test statistic : Chi-Squared                   30.04     using 16 bins.
#  Null hypothesis probability of 4.65e-03 with 13 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*(apec+apec)")
mo.apec.kT = 0.25
mo.apec_3.kT = 4.0
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              3.076032e+10     using 16 bins.
#
# Test statistic : Chi-Squared              3.076032e+10     using 16 bins.
#  Null hypothesis probability of 0.000000e+00 with 11 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              9.492329e+09     using 16 bins.
#
# Test statistic : Chi-Squared              9.492329e+09     using 16 bins.
#  Null hypothesis probability of 0.000000e+00 with 11 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              4.334859e+09     using 16 bins.
#
# Test statistic : Chi-Squared              4.334859e+09     using 16 bins.
#  Null hypothesis probability of 0.000000e+00 with 11 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm          6:kT        9:norm
# 30.0132      1812.93      -1      0.932095      0.221195   7.66066e-05       1.91497   4.09078e-05
# 29.7457      2825.75      -2      0.595021     0.0854407   0.000292064       2.67683   3.97581e-05
# 28.2598      7997.37      -3     0.0788896     0.0139685     0.0236749       4.54191   2.01811e-05
# 28.126       7359.76       3     0.0788883     0.0187410      0.147343       4.54211   2.01810e-05
# 28.0848      7454.24       2     0.0788627     0.0189564      0.168696       4.54411   2.01797e-05
# 27.1611      7470.78       1     0.0785886     0.0207989      0.351448       4.56420   2.01665e-05
# 22.1275      8125.55       0     0.0732737     0.0226590      0.790359       4.77752   1.99924e-05
# 19.2754      13603.8       0     0.0651177     0.0233141       1.06076       6.13054   1.87006e-05
# 18.5976      12724.8      -1     0.0561026     0.0226850       1.04544       9.26655   1.82365e-05
# 17.7396      3169.94      -2     0.0143759     0.0192010       1.09006       16.2672   1.88446e-05
# Number of trials exceeded: continue fitting? 17.1384      1069.7       -2    0.00719417     0.0179825       1.77844       31.8138   2.13804e-05
# 16.9988      1294.77      -2    0.00616655     0.0174519       2.43179       35.8011   2.13063e-05
# 16.888       981.663      -2    0.00508830     0.0169788       3.32859       36.7636   2.14805e-05
# 16.8743      275.098      -2    0.00596791     0.0166969       4.11767       38.0604   2.17164e-05
# 16.8616      524.967      -2    0.00678938     0.0164186       5.20653       36.3627   2.15766e-05
# 16.8238      646.712      -2    0.00781626     0.0161627       6.82103       32.1923   2.10892e-05
# 16.7961      331.297      -2    0.00979626     0.0159634       8.72411       26.2538   2.02307e-05
# 16.7861      23.1273      -2     0.0121817     0.0158252       10.7503       23.9128   1.99076e-05
# 16.7724      374.54       -2     0.0142134     0.0156705       13.3781       25.6751   2.03796e-05
# 16.7588      464.694      -2     0.0160804     0.0154995       16.9128       22.2322   1.98922e-05
# Number of trials exceeded: continue fitting? 16.7434      443.923      -2     0.0178698     0.0153298       21.8073       22.4931   2.00685e-05
# 16.7032      678.012      -2     0.0200550     0.0151818       28.1445       20.8280   1.99039e-05
# 16.6933      25.7829      -2     0.0226223     0.0150901       33.7811       19.9082   1.98420e-05
# ==========================================
# ==================
#  Variances and Principal Axes
#                  1        2        5        6        9
#  4.5399E-11| -0.0002   0.0018   0.0000  -0.0000   1.0000
#  2.1162E-07| -0.0791   0.9969   0.0001  -0.0000  -0.0018
#  1.1211E-02|  0.9969   0.0791  -0.0002   0.0002   0.0000
#  1.3944E+04| -0.0002  -0.0000   0.1854   0.9827   0.0000
#  4.9872E+05| -0.0003   0.0000  -0.9827   0.1854   0.0000
# ------------------------------------------------------------
#
# ============================================================
#   Covariance Matrix
#         1           2           3           4           5
#    5.299e-02  -3.312e-03   1.408e+02  -2.904e+01  -3.149e-06
#   -3.312e-03   5.146e-04  -1.456e+01   2.418e+00   2.872e-07
#    1.408e+02  -1.456e+01   4.821e+05  -8.833e+04  -1.004e-02
#   -2.904e+01   2.418e+00  -8.833e+04   3.061e+04   4.714e-03
#   -3.149e-06   2.872e-07  -1.004e-02   4.714e-03   8.446e-10
# ------------------------------------------------------------
#
# ========================================================================
# Model TBabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    2.26223E-02  +/-  0.230198
#    2    2   apec       kT         keV      1.50901E-02  +/-  2.26857E-02
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                33.7811      +/-  694.301
#    6    3   apec       kT         keV      19.9082      +/-  174.956
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.98420E-05  +/-  2.90619E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   16.69     using 16 bins.
#
# Test statistic : Chi-Squared                   16.69     using 16 bins.
#  Null hypothesis probability of 1.17e-01 with 11 degrees of freedom

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 6.4775e-06 photons (1.908e-14 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
plx = 0.6016
d_kpc = 1/plx
F_x = 1.8223*10**-13

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 6.022623339834022e+31
