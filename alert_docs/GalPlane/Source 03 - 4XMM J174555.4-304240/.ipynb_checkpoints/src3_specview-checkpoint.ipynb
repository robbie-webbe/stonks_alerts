# %%
# %load_ext wurlitzer
import glob
import os
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12,8]
os.chdir('pps/')

Fit.statMethod = "chi"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4

# %%
spec_fnames = glob.glob('P*PNS*SRSPEC*.FTZ')

spec = Spectrum(spec_fnames[0])
Plot.device="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.00005 0.005")
Plot("data")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: P0886010401PNS003SRSPEC0004.FTZ  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  9.387e-03 +/- 8.507e-04 (76.3 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-10
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 1.706e+04 sec
#  Using fit statistic: chi
#  Using Background File                P0886010401PNS003BGSPEC0004.FTZ
#   Background Exposure Time: 1.706e+04 sec
#  Using Response (RMF) File            epn_e3_ff20_sdY8.rmf for Source 1
#  Using Auxiliary Response (ARF) File  P0886010401PNS003SRCARF0004.FTZ

# %%
spec.ignore("**-0.2 12.0-**")
mo = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
#       No channels ignored (no channels in specified range)
#      1 channels (10) ignored in spectrum #     1
#
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              7.931161e+12     using 9 bins.
#
# Test statistic : Chi-Squared              7.931161e+12     using 9 bins.
#  Null hypothesis probability of 0.000000e+00 with 6 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 59.9867      1.73494       0      0.440630       3.07911   2.10611e-06
# 56.4727      1.1639e+06    0      0.199449       3.04070   1.99704e-06
# 50.8723      1.56668e+06   0     0.0386585       2.92622   1.96406e-06
# 45.7281      1.59551e+06  -1    0.00483718       2.37328   1.25205e-06
# 25.2799      3.71793e+06  -1    0.00234601       1.53525   7.43175e-07
# 5.96114      8.11915e+06  -2    0.00113323      0.858225   5.04094e-07
# 4.15769      2.39359e+06  -3   0.000269759       1.01529   6.08178e-07
# 3.97767      3.78163e+06  -1   5.41705e-05       1.03421   6.36069e-07
# 3.78247      2.60055e+06   0   3.11779e-06       1.02738   6.42933e-07
# 3.72242      1.66363e+06   0   2.48046e-07       1.02425   6.45603e-07
# 3.70011      1.26149e+06   0   7.71290e-08       1.02267   6.46537e-07
# 3.69056      1.08935e+06   0   3.53578e-08       1.02178   6.46759e-07
# 3.68599      1.01634e+06   0   1.47056e-08       1.02122   6.46702e-07
# 3.68355      986164        0   4.44154e-09       1.02083   6.46547e-07
# 3.68208      974345        0   1.88468e-09       1.02053   6.46371e-07
# 3.6811       970274        0   6.09250e-10       1.02030   6.46202e-07
# 3.68038      969441        0   2.90955e-10       1.02011   6.46051e-07
# 3.67983      969754        0   1.32011e-10       1.01995   6.45920e-07
# 3.6794       970655        0   5.26037e-11       1.01982   6.45807e-07
# 3.67896      971590        0   1.29605e-11       1.01970   6.45713e-07
# 3.67877      971858        0   3.05083e-12       1.01962   6.45628e-07
# 3.67869      973598        0   5.51055e-13       1.01958   6.45586e-07
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  4.1063E-15| -0.0000  -0.0000   1.0000
#  4.1215E-03| -0.8487  -0.5289  -0.0000
#  1.8001E-02|  0.5289  -0.8487  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    8.004e-03  -6.230e-03  -4.796e-10
#   -6.230e-03   1.412e-02   7.767e-09
#   -4.796e-10   7.767e-09   1.003e-14
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    5.51055E-13  +/-  8.94640E-02
#    2    2   bbody      kT         keV      1.01958      +/-  0.118823
#    3    2   bbody      norm                6.45586E-07  +/-  1.00163E-07
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  3.6787     using 9 bins.
#
# Test statistic : Chi-Squared                  3.6787     using 9 bins.
#  Null hypothesis probability of 7.2006e-01 with 6 degrees of freedom

# %%
Fit.error("1")
Fit.error("2")
# Out:
#  Parameter   Confidence Range (2.706)
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 3.60728      2.98424       1   2.69143e-13       1.00026   6.42021e-07
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  3.9125E-15| -0.0000  -0.0000   1.0000
#  3.8093E-03| -0.8439  -0.5365  -0.0000
#  1.7352E-02|  0.5365  -0.8439  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    7.707e-03  -6.131e-03  -4.084e-10
#   -6.131e-03   1.345e-02   7.271e-09
#   -4.084e-10   7.271e-09   9.559e-15
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    2.69143E-13  +/-  8.77905E-02
#    2    2   bbody      kT         keV      1.00026      +/-  0.115992
#    3    2   bbody      norm                6.42021E-07  +/-  9.77725E-08
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  3.6073     using 9 bins.
#
# Test statistic : Chi-Squared                  3.6073     using 9 bins.
#  Null hypothesis probability of 7.2965e-01 with 6 degrees of freedom
# ***Warning: New best fit found, fit parameters will be set to new values.
# ***Warning: Parameter pegged at hard limit: 0
#      1            0     0.109006    (-1.49671e-16,0.109006)
#  Parameter   Confidence Range (2.706)
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.49671e-16 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.49671e-16 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.49671e-16 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.49671e-16 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.49671e-16 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.49671e-16 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.49671e-16 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.49671e-16 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.49671e-16 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.49671e-16 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.49671e-16 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 1.49671e-16 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
#      2      0.84471      1.18348    (-0.155549,0.183218)

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.550694e+12     using 9 bins.
#
# Test statistic : Chi-Squared              1.550694e+12     using 9 bins.
#  Null hypothesis probability of 0.000000e+00 with 6 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 12.6482      6.45122      -3     0.0856469      0.904924   3.53458e-06
# 6.36018      1.80019e+06  -4      0.309127       1.37329   7.07214e-06
# 2.21673      787824       -5      0.294157       1.26647   8.15895e-06
# 2.17307      72358.3      -6      0.300045       1.29580   8.25023e-06
# 2.17305      622.943      -7      0.299711       1.29480   8.24033e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  6.3722E-13| -0.0000  -0.0000   1.0000
#  4.8052E-03|  0.9306  -0.3661   0.0000
#  9.2322E-02|  0.3661   0.9306   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.653e-02   2.981e-02   3.156e-07
#    2.981e-02   8.059e-02   7.268e-07
#    3.156e-07   7.268e-07   7.588e-12
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.299711     +/-  0.128579
#    2    2   powerlaw   PhoIndex            1.29480      +/-  0.283891
#    3    2   powerlaw   norm                8.24033E-06  +/-  2.75466E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  2.1731     using 9 bins.
#
# Test statistic : Chi-Squared                  2.1731     using 9 bins.
#  Null hypothesis probability of 9.0311e-01 with 6 degrees of freedom

# %%
Fit.error("1")
Fit.error("2")
# Out:
#  Parameter   Confidence Range (2.706)
#      1     0.117615     0.584413    (-0.182096,0.284701)
#  Parameter   Confidence Range (2.706)
#      2     0.859713       1.8076    (-0.435116,0.51277)

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              2.323891e+11     using 9 bins.
#
# Test statistic : Chi-Squared              2.323891e+11     using 9 bins.
#  Null hypothesis probability of 0.000000e+00 with 6 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 4.63305      3.24219      -1      0.501150       8.59437   1.55536e-05
# 3.71866      22965.7      -2      0.272913       16.9984   1.22272e-05
# 2.21834      206409       -3      0.282684       32.2339   1.45667e-05
# 2.09084      37916        -4      0.287714       44.6086   1.59089e-05
# 2.08687      3152.31      -5      0.288122       49.0544   1.62328e-05
# 2.08685      797.588      -6      0.288245       49.3160   1.62482e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  2.4638E-12| -0.0000  -0.0000   1.0000
#  5.4997E-03|  1.0000   0.0006   0.0000
#  1.5958E+04| -0.0006   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.110e-02  -9.453e+00  -5.102e-07
#   -9.453e+00   1.596e+04   1.017e-03
#   -5.102e-07   1.017e-03   6.876e-11
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.288245     +/-  0.105350
#    2    2   bremss     kT         keV      49.3160      +/-  126.327
#    3    2   bremss     norm                1.62482E-05  +/-  8.29227E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  2.0868     using 9 bins.
#
# Test statistic : Chi-Squared                  2.0868     using 9 bins.
#  Null hypothesis probability of 9.1154e-01 with 6 degrees of freedom

# %%
Fit.error("1")
Fit.error("2")
# Out:
#  Parameter   Confidence Range (2.706)
#      1     0.172098     0.517267    (-0.116235,0.228935)
#  Parameter   Confidence Range (2.706)
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
# ***Warning: Zero alpha-matrix diagonal element for parameter 3
#  Parameter 1 is pegged at 0.288333 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
#  Parameter 3 is pegged at 1.62399e-05 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
#
#  Fit error occurred during lower bound error calculation.
#
# ***Warning: Number of trials exceeded before bracketing of delta fit-stat.
# Last attempt: 200, with delta statistic: 0.134558
#
# Continue error search in this direction?
# *** Parameter upper bound is INVALID.
#
#      2            0            0    (-49.1822,-49.1822)
# ***XSPEC Error:  No variable parameters for fit

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              5.993177e+10     using 9 bins.
#
# Test statistic : Chi-Squared              5.993177e+10     using 9 bins.
#  Null hypothesis probability of 0.000000e+00 with 6 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 35.548       8.32673      -3       1.55934      0.995828   6.42623e-05
# 32.3726      60075.7      -1       1.45705       1.66674   4.97236e-05
# 16.931       134805       -1      0.609160       2.91237   5.08016e-05
# 10.4681      139151       -2      0.240030       6.02367   2.91936e-05
# 3.65708      12739.6      -3      0.274073       12.2907   3.52364e-05
# 2.40423      7246.72      -4      0.271617       26.0075   3.98208e-05
# 2.10743      734.665      -5      0.280858       43.5122   4.50933e-05
# 2.08569      6072.18      -6      0.289399       43.8093   4.52297e-05
# 2.08558      78.2005      -7      0.290457       43.1752   4.51292e-05
# 2.08557      2.80967      -1      0.290437       43.2521   4.51453e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  1.9057E-11| -0.0000  -0.0000   1.0000
#  5.5571E-03|  1.0000   0.0007   0.0000
#  1.0782E+04| -0.0007   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.105e-02  -7.696e+00  -1.332e-06
#   -7.696e+00   1.078e+04   2.227e-03
#   -1.332e-06   2.227e-03   4.912e-10
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.290437     +/-  0.105124
#    2    2   apec       kT         keV      43.2521      +/-  103.835
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                4.51453E-05  +/-  2.21622E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  2.0856     using 9 bins.
#
# Test statistic : Chi-Squared                  2.0856     using 9 bins.
#  Null hypothesis probability of 9.1166e-01 with 6 degrees of freedom

# %%
Fit.error("1")
Fit.error("2")
# Out:
#  Parameter   Confidence Range (2.706)
#      1      0.17806     0.515277    (-0.112411,0.224806)
#  Parameter   Confidence Range (2.706)
#
# ***Warning: Number of trials exceeded before convergence.
# Current trial values 8.06038, 0.008
# and delta statistic 1.75565, 98.7719
#
# Continue error search in this direction? ***Warning: Parameter pegged at hard limit: 64
#      2      4.18171            0    (-39.0341,-43.2158)

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 1.4085e-05 photons (8.3354e-14 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
#plx = 1.2338
d_kpc = 8
F_x = 8.3356*10**-14

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 6.3811407321718784e+32

# %%
import numpy as np
print(np.log10(L_x))
# Out:
# 32.804898322828265

# %%
F_opt = 1.05*10**-5 * 10**(-0.4*20.7)
print('Optical Flux: ',F_opt)
print('F_x / F_opt: ', np.log10(F_x/F_opt))
# Out:
# Optical Flux:  5.510478332622621e-14
# F_x / F_opt:  0.17974756691900523

# %%
AllModels.clear()
mo = Model("tbabs*(apec+apec)")
mo.apec.kT = 0.5
mo.apec_3.kT = 4.0
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              2.397347e+11     using 9 bins.
#
# Test statistic : Chi-Squared              2.397347e+11     using 9 bins.
#  Null hypothesis probability of 0.000000e+00 with 4 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              1.364046e+11     using 9 bins.
#
# Test statistic : Chi-Squared              1.364046e+11     using 9 bins.
#  Null hypothesis probability of 0.000000e+00 with 4 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              7.090300e+10     using 9 bins.
#
# Test statistic : Chi-Squared              7.090300e+10     using 9 bins.
#  Null hypothesis probability of 0.000000e+00 with 4 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm          6:kT        9:norm
# 6.33077      39234.8      -2      0.797216      0.185590   3.14234e-05       6.70863   4.83553e-05
# 5.42592      8851.54      -3      0.510735      0.146888   8.94199e-05       10.9953   3.81186e-05
# 2.33501      22306        -3      0.508962      0.178986   3.02030e-05       15.2061   4.16315e-05
# 1.89613      10473.4      -4      0.424055      0.217689   5.61867e-06       21.0919   4.22906e-05
# 1.88553      2758.87      -5      0.473165      0.231503   8.11263e-06       18.9104   4.27057e-05
# 1.88428      637.14       -6      0.464309      0.223151   8.19487e-06       19.7579   4.27849e-05
# 1.88421      275.832      -7      0.476953      0.225879   8.93591e-06       18.8697   4.27484e-05
# ============================================================
#  Variances and Principal Axes
#                  1        2        5        6        9
#  1.6763E-11| -0.0001   0.0000   0.5055  -0.0000   0.8628
#  3.2697E-11| -0.0001   0.0001   0.8628   0.0000  -0.5055
#  4.9462E-02|  0.6638  -0.7478   0.0001   0.0063   0.0000
#  2.7656E-01|  0.7478   0.6639   0.0000   0.0112   0.0000
#  2.7116E+03|  0.0126   0.0027   0.0000  -0.9999  -0.0000
# ------------------------------------------------------------
#
# ============================================================
#   Covariance Matrix
#         1           2           3           4           5
#    6.074e-01   2.054e-01   2.841e-05  -3.418e+01   3.536e-07
#    2.054e-01   1.695e-01   1.830e-06  -7.350e+00   5.708e-07
#    2.841e-05   1.830e-06   1.966e-09  -1.876e-03  -1.205e-11
#   -3.418e+01  -7.350e+00  -1.876e-03   2.711e+03   1.623e-04
#    3.536e-07   5.708e-07  -1.205e-11   1.623e-04   6.671e-11
# ------------------------------------------------------------
#
# ========================================================================
# Model TBabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.476953     +/-  0.779372
#    2    2   apec       kT         keV      0.225879     +/-  0.411686
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                8.93591E-06  +/-  4.43406E-05
#    6    3   apec       kT         keV      18.8697      +/-  52.0686
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                4.27484E-05  +/-  8.16763E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  1.8842     using 9 bins.
#
# Test statistic : Chi-Squared                  1.8842     using 9 bins.
#  Null hypothesis probability of 7.5704e-01 with 4 degrees of freedom

# %%
Fit.error("1")
Fit.error("2")
Fit.error("6")
# Out:
#  Parameter   Confidence Range (2.706)
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm          6:kT        9:norm
# 1.88401      0.0117548    -2      0.474137      0.225937   8.74855e-06       19.2849   4.28067e-05
# ============================================================
#  Variances and Principal Axes
#                  1        2        5        6        9
#  1.7087E-11| -0.0001   0.0000   0.4819  -0.0000   0.8762
#  3.4049E-11| -0.0001   0.0001   0.8762   0.0000  -0.4819
#  5.3681E-02|  0.6395  -0.7687   0.0001   0.0073   0.0000
#  2.6982E-01|  0.7686   0.6396   0.0000   0.0122   0.0000
#  2.3049E+03|  0.0140   0.0022   0.0000  -0.9999  -0.0000
# ------------------------------------------------------------
#
# ============================================================
#   Covariance Matrix
#         1           2           3           4           5
#    6.355e-01   1.775e-01   3.321e-05  -3.235e+01   1.312e-06
#    1.775e-01   1.533e-01   6.715e-07  -5.077e+00   7.287e-07
#    3.321e-05   6.715e-07   2.484e-09  -1.971e-03   4.386e-11
#   -3.235e+01  -5.077e+00  -1.971e-03   2.304e+03   8.065e-05
#    1.312e-06   7.287e-07   4.386e-11   8.065e-05   6.022e-11
# ------------------------------------------------------------
#
# ========================================================================
# Model TBabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.474137     +/-  0.797172
#    2    2   apec       kT         keV      0.225937     +/-  0.391521
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                8.74855E-06  +/-  4.98424E-05
#    6    3   apec       kT         keV      19.2849      +/-  48.0041
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                4.28067E-05  +/-  7.75993E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  1.8840     using 9 bins.
#
# Test statistic : Chi-Squared                  1.8840     using 9 bins.
#  Null hypothesis probability of 7.5708e-01 with 4 degrees of freedom
# ***Warning: New best fit found, fit parameters will be set to new values.
# ***Warning: Zero alpha-matrix diagonal element for parameter 5
#  Parameter 5 is pegged at 6.32396e-13 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 5
#  Parameter 5 is pegged at 6.32396e-13 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 5
#  Parameter 5 is pegged at 1.4989e-12 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 5
#  Parameter 5 is pegged at 1.4989e-12 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 5
#  Parameter 5 is pegged at 2.9593e-13 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 5
#  Parameter 5 is pegged at 2.53847e-12 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 5
#  Parameter 5 is pegged at 2.53847e-12 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 5
#  Parameter 5 is pegged at 2.69165e-12 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
#      1     0.180774      1.46351    (-0.293087,0.989648)
#  Parameter   Confidence Range (2.706)
# ***Warning: Parameter pegged at hard limit: 0.008
# ***Warning: Zero alpha-matrix diagonal element for parameter 5
#  Parameter 5 is pegged at 1.21678e-20 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Zero alpha-matrix diagonal element for parameter 5
#  Parameter 5 is pegged at 1.21678e-20 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# ***Warning: Parameter pegged at hard limit: 64
#      2            0            0    (-0.225819,-0.225819)
#  Parameter   Confidence Range (2.706)
# ***Warning: Parameter pegged at hard limit: 0.008
# ***Warning: Parameter pegged at hard limit: 64
#      6            0            0    (-19.2998,-19.2998)
