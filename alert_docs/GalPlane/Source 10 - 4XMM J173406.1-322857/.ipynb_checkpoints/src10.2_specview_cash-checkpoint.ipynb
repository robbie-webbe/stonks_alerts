# %%
# %load_ext wurlitzer
import numpy as np
import glob
import os
import matplotlib.pyplot as plt
from astropy.io import fits
from xspec import *
plt.rcParams['figure.figsize'] = [9,6]

Fit.statMethod = "cstat"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4

# %%
#spec_file = sorted(glob.glob("*grpspec.fits"))
#spec = Spectrum(spec_file[0])

spec = Spectrum(glob.glob("*M119*cash.fits")[0],backFile=glob.glob("*M119*spec_bkg.fits")[0],respFile=glob.glob("*M119*.rmf")[0],arfFile=glob.glob("*M119*.arf")[0])
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0934201001_M119spec_cash.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  2.261e-03 +/- 8.810e-04 (26.2 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-327
#   Telescope: XMM Instrument: EMOS1  Channel Type: PI
#   Exposure Time: 1.32e+04 sec
#  Using fit statistic: cstat
#  Using Background File                0934201001_M119spec_bkg.fits
#   Background Exposure Time: 1.32e+04 sec
#  No response loaded.
#
# ***Warning!  One or more spectra are missing responses,
#                and are not suitable for fit.
# Net count rate (cts/s) for Spectrum:1  2.261e-03 +/- 8.810e-04 (26.2 % total)
# ***Warning!  One or more spectra are missing responses,
#                and are not suitable for fit.
# ***Warning: Detected response matrix energy bin value = 0 (or neg).
#      XSPEC will instead use small finite value (response file will not be altered).
# Response successfully loaded.
# Arf successfully loaded.
# Spectrum 1  Spectral Data File: 0934201001_M119spec_cash.fits
# Net count rate (cts/s) for Spectrum:1  2.261e-03 +/- 8.810e-04 (26.2 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-327
#   Telescope: XMM Instrument: EMOS1  Channel Type: PI
#   Exposure Time: 1.32e+04 sec
#  Using fit statistic: cstat
#  Using Background File                0934201001_M119spec_bkg.fits
#   Background Exposure Time: 1.32e+04 sec
#  Using Response (RMF) File            0934201001_M119spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0934201001_M119spec.arf
#
#  Spectral data counts: 114
#  Model predicted rate: 0.0

# %%
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.00001 0.05")
Plot.addCommand("Rescale X 0.1 15")
Plot("data")
#spec.ignore("**-0.2 12.0-**")

# %%
AllModels.clear()
mo1 = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : C-Statistic              7.683284e+06     using 327 bins.
#
# Test statistic : Chi-Squared              7.041899e+11     using 327 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of
# 232.864      3385.56      -3       8.52169       7.43891   0.000410490
# 232.741      1081.05      -1       7.91442       12.6642   0.000356675
# 232.568      1832.31       0       7.75259       9.78008   0.000374641
# 232.487      1055.04      -1       8.12477       11.8865   0.000398213
# 232.477      239.362       0       8.12283       9.66228   0.000402817
# 232.46       317.748       0       8.16599       11.2691   0.000402897
# 232.45       152.062       0       8.17348       10.2954   0.000405919
# 232.446      153.826      -1       8.29483       10.5273   0.000412014
# 232.446      27.6736      -2       8.33076       10.4833   0.000413945
# 232.446      0.988778     -3       8.32534       10.4805   0.000413806
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  8.1279E-09| -0.0000   0.0000   1.0000
#  1.3256E+01|  0.9984   0.0558   0.0000
#  1.5320E+02| -0.0558   0.9984  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.369e+01  -7.799e+00   4.600e-04
#   -7.799e+00   1.528e+02  -7.550e-04
#    4.600e-04  -7.550e-04   2.522e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    8.32534      +/-  3.70026
#    2    2   apec       kT         keV      10.4805      +/-  12.3599
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                4.13806E-04  +/-  1.58812E-04
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                232.4459     using 327 bins.
#
# Test statistic : Chi-Squared                521.5981     using 327 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 1.9586e-11 with 324 degrees of freedom

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 0.00010161 photons (1.7403e-12 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
plx = 0.2744
d_kpc = 1/plx
F_x = 1.6234*10**-13

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 2.5789255831167283e+32

# %%
import numpy as np
print(d_kpc)
print(np.log10(L_x))
# Out:
# 3.644314868804665
# 32.411438810417096

# %%
F_opt = 1.05*10**-5 * 10**(-0.4*19.88)
print('Optical Flux: ',F_opt)
print('F_x / F_opt: ', np.log10(F_x/F_opt))
# Out:
# Optical Flux:  1.1727064101695894e-13
# F_x / F_opt:  0.14123624256114856

# %%
AllModels.clear()
mo = Model("tbabs*(apec+apec)")
mo.apec.kT = 0.5
mo.apec_3.kT = 4.0
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic              1.381237e+06     using 327 bins.
#
# Test statistic : Chi-Squared              8.310138e+10     using 327 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 0.000000e+00 with 322 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic              1.018668e+06     using 327 bins.
#
# Test statistic : Chi-Squared              4.765232e+10     using 327 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 0.000000e+00 with 322 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                999936.8     using 327 bins.
#
# Test statistic : Chi-Squared              2.277985e+10     using 327 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 0.000000e+00 with 322 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# 231.005      74.8923       0       8.62487       9.88792   0.000410839      0.180457      0.847624
# 230.975      123.852       0       8.67306       11.0006   0.000411511      0.181177      0.889336
# 230.971      42.0846       0       8.71124       10.3439   0.000413680      0.181415      0.915414
# 230.958      63.2701      -1       8.98662       10.9328   0.000421343      0.181180       1.08817
# 230.956      30.3541       0       8.98227       10.8054   0.000421481      0.181151       1.09035
# 230.954      32.425        0       8.95689       10.8443   0.000421749      0.180682       1.10342
# 230.943      5.51799      -1       8.85316       10.8785   0.000419389      0.176381       1.23910
# 230.942      1.79493       0       8.85311       10.7542   0.000419407      0.176401       1.24447
# 230.939      6.08826       0       8.86879       10.8322   0.000419570      0.176326       1.27993
# 230.923      4.2718       -1       8.98401       10.8816   0.000422681      0.174047       1.53429
# 230.922      15.9367       0       8.98122       10.7523   0.000422764      0.174043       1.54065
# 230.919      20.854        0       8.97484       10.7951   0.000423015      0.173772       1.58189
# 230.907      5.64253      -1       8.98628       10.8107   0.000423787      0.170495       1.91839
# 230.903      1.6673        0       9.01578       10.8200   0.000424136      0.171046       1.94099
# 230.901      8.4754        0       9.04088       10.8247   0.000424639      0.171421       1.95000
# 230.9        11.8187       0       9.06060       10.8234   0.000425170      0.171707       1.95302
# 230.9        12.2775       0       9.07579       10.8179   0.000425661      0.171940       1.95282
# 230.9        11.2778       2       9.07580       10.8179   0.000425662      0.171939       1.95282
# ============================================================
#  Variances and Principal Axes
#                  1        2        5        6        9
#  8.9626E-09| -0.0000   0.0000   1.0000   0.0006   0.0000
#  2.1556E-04|  0.0105   0.0001   0.0006  -0.9999  -0.0089
#  2.4387E+01|  0.9988   0.0437   0.0000   0.0107  -0.0210
#  1.4815E+02|  0.0411  -0.9933   0.0000   0.0013  -0.1078
#  3.7523E+02| -0.0257   0.1069  -0.0000   0.0086  -0.9939
# ------------------------------------------------------------
#
# ============================================================
#   Covariance Matrix
#         1           2           3           4           5
#    2.482e+01  -6.020e+00   7.171e-04   1.851e-01   8.406e+00
#   -6.020e+00   1.505e+02  -7.260e-04   1.592e-01  -2.400e+01
#    7.171e-04  -7.260e-04   3.207e-08   1.633e-06   6.436e-04
#    1.851e-01   1.592e-01   1.633e-06   3.071e-02  -3.218e+00
#    8.406e+00  -2.400e+01   6.436e-04  -3.218e+00   3.724e+02
# ------------------------------------------------------------
#
# ========================================================================
# Model TBabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    9.07580      +/-  4.98244
#    2    2   apec       kT         keV      10.8179      +/-  12.2680
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                4.25662E-04  +/-  1.79081E-04
#    6    3   apec       kT         keV      0.171939     +/-  0.175249
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.95282      +/-  19.2979
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                230.8996     using 327 bins.
#
# Test statistic : Chi-Squared                544.9329     using 327 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 1.0593e-13 with 322 degrees of freedom
