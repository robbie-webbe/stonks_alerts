# %%
# %load_ext wurlitzer
import numpy as np
import glob
import os
import matplotlib.pyplot as plt
from astropy.io import fits
from xspec import *
plt.rcParams['figure.figsize'] = [9,6]

Fit.statMethod = "cstat"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4

# %%
#spec_file = sorted(glob.glob("*grpspec.fits"))
#spec = Spectrum(spec_file[0])

spec = Spectrum(glob.glob("*cash.fits")[0],backFile=glob.glob("*spec_bkg.fits")[0],respFile=glob.glob("*.rmf")[0],arfFile=glob.glob("*.arf")[0])
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0886090501_M2166spec_cash.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  5.250e-03 +/- 6.367e-04
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-175
#   Telescope: XMM Instrument: EMOS2  Channel Type: PI
#   Exposure Time: 1.295e+04 sec
#  Using fit statistic: cstat
#  No response loaded.
#
# ***Warning!  One or more spectra are missing responses,
#                and are not suitable for fit.
# Net count rate (cts/s) for Spectrum:1  3.410e-03 +/- 6.633e-04 (64.9 % total)
# ***Warning!  One or more spectra are missing responses,
#                and are not suitable for fit.
# ***Warning: Detected response matrix energy bin value = 0 (or neg).
#      XSPEC will instead use small finite value (response file will not be altered).
# Response successfully loaded.
# Arf successfully loaded.
# Spectrum 1  Spectral Data File: 0886090501_M2166spec_cash.fits
# Net count rate (cts/s) for Spectrum:1  3.410e-03 +/- 6.633e-04 (64.9 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-175
#   Telescope: XMM Instrument: EMOS2  Channel Type: PI
#   Exposure Time: 1.295e+04 sec
#  Using fit statistic: cstat
#  Using Background File                0886090501_M2166spec_bkg.fits
#   Background Exposure Time: 1.295e+04 sec
#  Using Response (RMF) File            0886090501_M2166spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0886090501_M2166spec.arf
#
#  Spectral data counts: 68
#  Model predicted rate: 0.0

# %%
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.00001 0.05")
Plot.addCommand("Rescale X 0.1 15")
Plot("data")

# %%
spec.ignore("**-0.2 12.0-**")
AllModels.clear()
mo1 = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
#      2 channels (1-2) ignored in spectrum #     1
#      1 channels (175) ignored in spectrum #     1
#
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : C-Statistic              6.633504e+06     using 172 bins.
#
# Test statistic : Chi-Squared              5.687583e+11     using 172 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 0.000000e+00 with 169 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 98.8642      1.3611e+06   -3      0.475381       198.475      0.442968
# 96.871       3.91196       0      0.211942       198.157      0.490338
# 95.9861      3.70945      -1     0.0600845       197.960      0.504814
# 94.8287      3.70696      -2    0.00900195       196.460      0.538855
# 92.9642      3.44284      -2    0.00258575       189.251      0.574771
# 91.3552      2.91984       0   0.000407862       180.581      0.599061
# 90.1481      2.1958        0   0.000199157       167.115      0.612970
# 90.1187      0.771938      0   7.63521e-05       165.384      0.613996
# 90.1181      0.677029      1   2.52792e-05       165.310      0.614033
# 90.1177      0.675325      1   1.25406e-05       165.246      0.614061
# 90.1174      0.674033      1   6.18328e-06       165.193      0.614082
# 90.1173      0.672898      1   7.78447e-07       165.154      0.614096
# 90.1171      0.672148      1   1.03652e-07       165.118      0.614106
# 90.117       0.671528      1   1.93931e-08       165.088      0.614112
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  2.0690E-02| -0.1179  -0.0110   0.9930
#  8.7106E-01|  0.9930  -0.0012   0.1179
#  4.3840E+07| -0.0001   0.9999   0.0111
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.289e+00  -4.341e+03  -4.810e+01
#   -4.341e+03   4.383e+07   4.868e+05
#   -4.810e+01   4.868e+05   5.405e+03
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.93931E-08  +/-  1.13536
#    2    2   bbody      kT         keV      165.088      +/-  6620.74
#    3    2   bbody      norm                0.614112     +/-  73.5218
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                 90.1170     using 172 bins.
#
# Test statistic : Chi-Squared                 79.6905     using 172 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 1.0000e+00 with 169 degrees of freedom
#  Model Flux 7.7212e-05 photons (9.8691e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic              3.943848e+06     using 172 bins.
#
# Test statistic : Chi-Squared              1.197063e+11     using 172 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 0.000000e+00 with 169 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 118.318      988661       -1       5147.92       7.90403      0.433399
# 118.318      1.80811e-22  -2       1348.39       9.03938      0.208700
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  3.9693E+46| -0.0022  -0.7297   0.6837
#  3.7072E+52|  0.0349  -0.6834  -0.7293
#  6.4768E+61|  0.9994   0.0223   0.0270
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    6.469e+61   1.442e+60   1.749e+60
#    1.442e+60   3.213e+58   3.898e+58
#    1.749e+60   3.898e+58   4.729e+58
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1348.39      +/-  8.04292E+30
#    2    2   powerlaw   PhoIndex            9.03938      +/-  1.79246E+29
#    3    2   powerlaw   norm                0.208700     +/-  2.17458E+29
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                118.3179     using 172 bins.
#
# Test statistic : Chi-Squared                 48.5692     using 172 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 1.0000e+00 with 169 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic              1.649142e+06     using 172 bins.
#
# Test statistic : Chi-Squared              1.920069e+10     using 172 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 0.000000e+00 with 169 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 118.314      307707       -3       1202.01       198.475     0.0953866
# 118.101      0.00332431    2       858.131       39.1293      0.419966
# 118.056      0.0837876     1       840.823       198.278      0.500307
# 116.957      0.0846268     0       729.645       63.0032       1.13215
# 116.952      0.0398836     0       728.571       62.7305       1.14231
# 116.949      0.0334619     0       727.648       65.9338       1.15106
# 116.946      0.0284985     0       726.863       65.6947       1.15848
# 116.944      0.0237827     0       726.192       67.0499       1.16480
# 116.943      0.0200651     0       725.613       68.8094       1.17021
# 116.942      0.0170288     0       725.112       70.2039       1.17482
# 116.941      0.0144219     0       724.677       71.7330       1.17878
# 116.941      0.0122768     0       724.296       73.2565       1.18218
# 116.938      0.0104921     0       722.007       99.9051       1.19987
# 116.934      0.00782117   -1       711.635       199.343       1.24484
# 116.934      0.00245543    0       710.827       199.356       1.24720
# 116.934      0.000654552   0       710.263       199.361       1.24696
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.1980E+00| -0.0110  -0.0013   0.9999
#  5.3382E+05|  0.9996   0.0243   0.0111
#  7.4254E+09| -0.0243   0.9997   0.0010
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    4.913e+06  -1.803e+08  -1.744e+05
#   -1.803e+08   7.421e+09   7.421e+06
#   -1.744e+05   7.421e+06   7.488e+03
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    710.263      +/-  2216.42
#    2    2   bremss     kT         keV      199.361      +/-  8.61455E+04
#    3    2   bremss     norm                1.24696      +/-  86.5311
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                116.9337     using 172 bins.
#
# Test statistic : Chi-Squared                 48.3812     using 172 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 1.0000e+00 with 169 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*apec")
mo.apec.kT = 0.5
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : C-Statistic                622014.3     using 172 bins.
#
# Test statistic : Chi-Squared              7.492191e+09     using 172 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 0.000000e+00 with 169 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                293479.5     using 172 bins.
#
# Test statistic : Chi-Squared              2.591718e+09     using 172 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 0.000000e+00 with 169 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 118.318      183014       -3       3423.09       44.2074      0.253186
# 118.318      5.23963e-11  -4       999999.       63.7315     0.0580460
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  2.3369E+22| -0.0021   0.0004   1.0000
#  1.8175E+31|  0.9867  -0.1624   0.0021
#  3.8261E+35|  0.1624   0.9867  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.011e+34   6.131e+34  -2.661e+30
#    6.131e+34   3.725e+35  -1.640e+31
#   -2.661e+30  -1.640e+31   8.026e+26
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    9.99999E+05  +/-  1.00551E+17
#    2    2   apec       kT         keV      63.7315      +/-  6.10343E+17
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                5.80460E-02  +/-  2.83309E+13
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                118.3179     using 172 bins.
#
# Test statistic : Chi-Squared                 48.5692     using 172 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 1.0000e+00 with 169 degrees of freedom

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux         0 photons (0 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
#plx = 0.6016
d_kpc = 8
F_x = 2.3418*10**-13

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 1.7927150255050755e+33

# %%
import numpy as np
print(d_kpc)
print(np.log10(L_x))
# Out:
# 8
# 33.25351125850422

# %%
F_opt = 1.05*10**-5 * 10**(-0.4*21.05)
print('Optical Flux: ',F_opt)
print('F_x / F_opt: ', np.log10(F_x/F_opt))
# Out:
# Optical Flux:  3.9919886613658934e-14
# F_x / F_opt:  0.7683605025949543

# %%
AllModels.clear()
mo = Model("tbabs*apec")
mo.apec.Abundanc = 0.3
mo.apec.kT = 9
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                622014.3     using 172 bins.
#
# Test statistic : Chi-Squared              7.492191e+09     using 172 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 0.000000e+00 with 169 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                279211.2     using 172 bins.
#
# Test statistic : Chi-Squared              1.189740e+09     using 172 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 0.000000e+00 with 169 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                571353.7     using 172 bins.
#
# Test statistic : Chi-Squared              2.289555e+09     using 172 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 0.000000e+00 with 169 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 51424.9      105756       -3       10.2978       45.1755      0.403733
# 48629.1      21452.4      -2       2.32990       59.5254      0.159512
# 17036.1      51498.1      -3      0.211864       62.5383     0.0238558
# 5081.34      122520       -1      0.693648       63.3780     0.0106317
# 261.577      85224.7      -2       5.44258       63.8784    0.00207034
# 221.296      23644.3      -3      0.921736       63.9593   0.000818928
# 71.8817      55785.4      -4       1.80732       26.6772   0.000263292
# 69.6452      12952.6       0       1.86125       25.9718   0.000224998
# 68.9492      5631.42       0       1.82848       17.5076   0.000204962
# 67.9546      3312.1        0       1.82617       7.13910   0.000194101
# 67.8424      722.32        0       1.81793       6.23144   0.000197571
# 67.7304      1119.66       0       1.82844       5.50978   0.000202711
# 67.6157      1521.04      -1       2.09669       3.28741   0.000242192
# 66.8914      5049.35      -1       2.32407       3.22295   0.000290318
# 66.7198      1430.17      -1       2.49611       2.97264   0.000326204
# 66.6045      721.386      -2       2.95747       2.19354   0.000426580
# 66.1883      2177.87      -3       3.45546       1.94726   0.000569802
# 66.0947      946.38       -4       3.85026       1.72267   0.000723227
# 66.014       641.638      -5       3.96417       1.71113   0.000785704
# 66.0131      58.2215      -6       3.96261       1.71849   0.000785331
# 66.0131      0.335506     -7       3.96266       1.71854   0.000785338
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  2.1784E-08| -0.0002   0.0005   1.0000
#  2.0500E-01| -0.3993  -0.9168   0.0004
#  4.4431E+00|  0.9168  -0.3993   0.0004
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    3.767e+00  -1.551e+00   1.568e-03
#   -1.551e+00   8.806e-01  -7.720e-04
#    1.568e-03  -7.720e-04   7.402e-07
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    3.96266      +/-  1.94100
#    2    2   apec       kT         keV      1.71854      +/-  0.938415
#    3    2   apec       Abundanc            0.300000     frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                7.85338E-04  +/-  8.60366E-04
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                 66.0131     using 172 bins.
#
# Test statistic : Chi-Squared                 47.6177     using 172 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 1.0000e+00 with 169 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*raymond")
mo.raymond.Abundanc = 0.3
mo.raymond.kT = 9
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*raymond<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   raymond    kT         keV      1.00000      +/-  0.0
#    3    2   raymond    Abundanc            1.00000      frozen
#    4    2   raymond    Redshift            0.0          frozen
#    5    2   raymond    norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                529441.6     using 172 bins.
#
# Test statistic : Chi-Squared              4.301855e+09     using 172 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 0.000000e+00 with 169 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                248066.6     using 172 bins.
#
# Test statistic : Chi-Squared              7.985130e+08     using 172 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 0.000000e+00 with 169 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                565725.5     using 172 bins.
#
# Test statistic : Chi-Squared              2.245682e+09     using 172 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 0.000000e+00 with 169 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 291932       104731       -3      0.305212       43.6333      0.397484
# 100303       129953       -4      0.118132       59.8219      0.121180
# 3874.49      140713       -1       14.3270       62.0071     0.0446595
# 641.19       15155.8      -2       5.01158       63.4837    0.00431333
# 96.5048      28788.9      -3       1.03085       63.7502   3.91942e-05
# 91.1661      77328        -2       2.52245       15.1418   6.28302e-05
# 74.0567      54718.4      -1      0.742778       7.54232   0.000100978
# 73.9302      16019.5      -2       2.61571       2.49244   0.000220824
# 71.8998      16121.2      -3       3.44401       1.59675   0.000453246
# 66.4825      7118.76      -4       3.28244       2.14740   0.000478429
# 66.0966      2134.88      -2       3.63123       1.80108   0.000638689
# 65.9166      1034.3       -2       3.98996       1.63321   0.000812517
# 65.8477      520.033      -3       4.26762       1.53390   0.000969076
# 65.8331      209.314      -4       4.28115       1.54235   0.000986364
# 65.8331      3.7635       -5       4.28720       1.54104   0.000989365
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  3.4408E-08| -0.0003   0.0008   1.0000
#  1.3312E-01| -0.3066  -0.9518   0.0007
#  4.0588E+00|  0.9518  -0.3066   0.0005
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    3.690e+00  -1.146e+00   1.885e-03
#   -1.146e+00   5.021e-01  -7.078e-04
#    1.885e-03  -7.078e-04   1.100e-06
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*raymond<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    4.28720      +/-  1.92087
#    2    2   raymond    kT         keV      1.54104      +/-  0.708625
#    3    2   raymond    Abundanc            0.300000     frozen
#    4    2   raymond    Redshift            0.0          frozen
#    5    2   raymond    norm                9.89365E-04  +/-  1.04881E-03
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                 65.8331     using 172 bins.
#
# Test statistic : Chi-Squared                 46.9584     using 172 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 1.0000e+00 with 169 degrees of freedom
