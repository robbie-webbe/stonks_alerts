# %%
# %load_ext wurlitzer
import glob
import os
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12,8]
os.chdir('pps/')

Fit.statMethod = "chi"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4

# %%
spec_fnames = glob.glob('P*PNS*SRSPEC*.FTZ')

spec = Spectrum(spec_fnames[0])
Plot.device="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.0001 0.05")
Plot("data")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: P0934200101PNS003SRSPEC001E.FTZ  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  1.720e-02 +/- 2.315e-03 (27.4 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-38
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 1.247e+04 sec
#  Using fit statistic: chi
#  Using Background File                P0934200101PNS003BGSPEC001E.FTZ
#   Background Exposure Time: 1.247e+04 sec
#  Using Response (RMF) File            epn_e3_ff20_sdY5.rmf for Source 1
#  Using Auxiliary Response (ARF) File  P0934200101PNS003SRCARF001E.FTZ

# %%
spec.ignore("**-0.2 12.0-**")
mo = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
#       No channels ignored (no channels in specified range)
#      1 channels (38) ignored in spectrum #     1
#
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              7.954442e+10     using 37 bins.
#
# Test statistic : Chi-Squared              7.954442e+10     using 37 bins.
#  Null hypothesis probability of 0.000000e+00 with 34 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 89.9177      0.625629      0      0.210523       3.20312   7.12303e-06
# 89.1822      129940        0      0.104630       3.13478   6.48876e-06
# 86.6273      167454        0     0.0204832       2.89460   6.39692e-06
# 83.5809      201295        0    0.00892600       2.58701   6.47516e-06
# 81.5168      200947        0    0.00139985       2.38023   6.21150e-06
# 79.8027      206972        0   0.000679675       2.20492   5.84005e-06
# 78.1422      217613        0   8.04320e-05       2.04793   5.42072e-06
# 76.3575      238169        0   1.68325e-05       1.89873   5.00216e-06
# 74.3444      266113        0   3.31530e-06       1.75454   4.60252e-06
# 72.0471      300933        0   4.73900e-07       1.61530   4.23116e-06
# 69.4437      341663        0   1.79975e-07       1.48218   3.89258e-06
# 66.551       386561        0   6.05092e-08       1.35690   3.58837e-06
# 63.4421      432545        0   1.27991e-08       1.24153   3.31812e-06
# 62.4379      475518       -1   3.59493e-09      0.974118   1.71169e-06
# 39.2396      2.17248e+06  -2   7.46597e-11      0.442802   9.83257e-07
# 34.122       4.40034e+06  -3      0.216307      0.268685   1.53896e-06
degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 15.9556      7.92766      -3      0.750204      0.936967   0.000171464
# 15.6025      9855.3       -4      0.747261      0.940441   0.000182291
# 15.6025      57.7953      -5      0.747497      0.940155   0.000182313
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  3.9761E-10| -0.0004   0.0000   1.0000
#  4.5827E-03| -0.4548  -0.8906  -0.0002
#  2.8613E-02|  0.8906  -0.4548   0.0003
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.364e-02  -9.733e-03   9.136e-06
#   -9.733e-03   9.553e-03  -3.778e-06
#    9.136e-06  -3.778e-06   3.928e-09
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.747497     +/-  0.153761
#    2    2   apec       kT         keV      0.940155     +/-  9.77393E-02
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.82313E-04  +/-  6.26724E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 15.6025     using 37 bins.
#
# Test statistic : Chi-Squared                 15.6025     using 37 bins.
#  Null hypothesis probability of 9.9709e-01 with 34 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*(apec+apec)")
mo.apec.kT = 0.5
mo.apec_3.kT = 4
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              4.025292e+09     using 37 bins.
#
# Test statistic : Chi-Squared              4.025292e+09     using 37 bins.
#  Null hypothesis probability of 0.000000e+00 with 32 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              2.292445e+09     using 37 bins.
#
# Test statistic : Chi-Squared              2.292445e+09     using 37 bins.
#  Null hypothesis probability of 0.000000e+00 with 32 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              1.351753e+09     using 37 bins.
#
# Test statistic : Chi-Squared              1.351753e+09     using 37 bins.
#  Null hypothesis probability of 0.000000e+00 with 32 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm          6:kT        9:norm
# 17.2332      9130.45      -3      0.801342      0.814855   0.000182027       5.61946   2.08743e-05
# 14.6412      9432.04      -2      0.658325      0.933811   0.000114820       2.02739   6.46802e-05
# 14.0197      5880.02      -2      0.510890      0.966221   7.50245e-05       2.46222   8.37661e-05
# 13.868       5826.47      -3      0.400313       1.00958   5.63157e-05       3.00085   8.80300e-05
# 13.7565      5679.83      -4      0.411917       1.02158   6.39799e-05       3.36877   8.26936e-05
# 13.7457      173.915      -5      0.405065       1.02400   6.33191e-05       3.66911   8.26953e-05
# 13.7438      142.139      -6      0.403760       1.02566   6.34215e-05       3.84172   8.25130e-05
# 13.743       56.4311      -7      0.401276       1.02953   6.34687e-05       3.90594   8.20386e-05
# 13.743       19.5799      -8      0.400562       1.03030   6.34646e-05       3.95089   8.19474e-05
# ============================================================
#  Variances and Principal Axes
#                  1        2        5        6        9
#  8.2470E-11|  0.0002   0.0001  -0.9663   0.0000  -0.2573
#  1.3334E-09| -0.0002  -0.0002   0.2573  -0.0000  -0.9663
#  1.0187E-02|  0.4200   0.9074   0.0002  -0.0104  -0.0002
#  6.1591E-02|  0.9074  -0.4198   0.0002   0.0215  -0.0000
#  2.7408E+01| -0.0152   0.0185   0.0000   0.9997  -0.0000
# ------------------------------------------------------------
#
# ============================================================
#   Covariance Matrix
#         1           2           3           4           5
#    5.883e-02  -2.726e-02   9.136e-06  -4.149e-01  -1.029e-06
#   -2.726e-02   2.858e-02  -1.902e-06   5.051e-01  -2.325e-06
#    9.136e-06  -1.902e-06   1.969e-09   9.677e-06  -8.949e-10
#   -4.149e-01   5.051e-01   9.677e-06   2.739e+01  -5.705e-05
#   -1.029e-06  -2.325e-06  -8.949e-10  -5.705e-05   1.765e-09
# ------------------------------------------------------------
#
# ========================================================================
# Model TBabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.400562     +/-  0.242540
#    2    2   apec       kT         keV      1.03030      +/-  0.169058
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                6.34646E-05  +/-  4.43698E-05
#    6    3   apec       kT         keV      3.95089      +/-  5.23377
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                8.19474E-05  +/-  4.20178E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 13.7430     using 37 bins.
#
# Test statistic : Chi-Squared                 13.7430     using 37 bins.
#  Null hypothesis probability of 9.9799e-01 with 32 degrees of freedom

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 5.8621e-05 photons (1.7227e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
plx = 1.298
d_kpc = 1/plx
F_x = 1.7227*10**-13

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 1.2230430713148355e+31

# %%
import numpy as np
print(d_kpc)
print(np.log10(L_x))
# Out:
# 0.7704160246533127
# 31.087441751643794

# %%
F_opt = 1.05*10**-5 * 10**(-0.4*11.33)
print('Optical Flux: ',F_opt)
print('F_x / F_opt: ', np.log10(F_x/F_opt))
# Out:
# Optical Flux:  3.0845321345596074e-10
# F_x / F_opt:  -3.252979645352879

# %%
AllModels.clear()
mo = Model("tbabs*(apec+apec+apec)")
mo.apec.kT = 0.5
mo.apec_3.kT = 4.0
mo.apec_4.kT = 10.0
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>(apec<2> + apec<3> + apec<4>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
#   10    4   apec       kT         keV      1.00000      +/-  0.0
#   11    4   apec       Abundanc            1.00000      frozen
#   12    4   apec       Redshift            0.0          frozen
#   13    4   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              9.057746e+09     using 37 bins.
#
# Test statistic : Chi-Squared              9.057746e+09     using 37 bins.
#  Null hypothesis probability of 0.000000e+00 with 30 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              6.306560e+09     using 37 bins.
#
# Test statistic : Chi-Squared              6.306560e+09     using 37 bins.
#  Null hypothesis probability of 0.000000e+00 with 30 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              4.481816e+09     using 37 bins.
#
# Test statistic : Chi-Squared              4.481816e+09     using 37 bins.
#  Null hypothesis probability of 0.000000e+00 with 30 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              3.545525e+09     using 37 bins.
#
# Test statistic : Chi-Squared              3.545525e+09     using 37 bins.
#  Null hypothesis probability of 0.000000e+00 with 30 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT
# 13.9684      86.2209       0      0.478272       1.01852   8.70393e-05       63.9789   2.06267e-07       64.0000   9.80572e-05
# 13.9684      94.4527       0      0.478271       1.01853   8.70369e-05       63.9908   1.73036e-07       64.0000   9.80240e-05
# ***Warning: LevMarq::invertCorrelationMatrix:
#             Negative diagonal element for parameter 6
# ***Warning: LevMarq::invertCorrelationMatrix:
#             Negative diagonal element for parameter 9
# ***Warning: LevMarq::invertCorrelationMatrix:
#             Negative diagonal element for parameter 10
# ***Warning: LevMarq::invertCorrelationMatrix:
#             Negative diagonal element for parameter 13
# ================================================================================
#  Variances and Principal Axes
#                  1        2        5        6        9       10       13
#  1.2014E-03|  0.0000  -0.0000   0.0000   1.0000  -0.0000  -0.0042   0.0000
#  1.2014E-03| -0.0000   0.0000  -0.0000   0.0000  -1.0000   0.0023   0.0000
#  1.2014E-03| -0.0000   0.0000   0.0000   0.0000  -0.0000   0.0000  -1.0000
#  1.2014E-03|  0.0002   0.0000  -1.0000   0.0000   0.0000   0.0000  -0.0000
#  1.2014E-01|  1.0000   0.0000   0.0002  -0.0000  -0.0000  -0.0000  -0.0000
#  2.0233E+09|  0.0000  -1.0000  -0.0000  -0.0000  -0.0000  -0.0000  -0.0000
#  1.1776E+16|  0.0000  -0.0000  -0.0000   0.0042   0.0023   1.0000   0.0000
# --------------------------------------------------------------------------------
#
# ====================================================================================
#   Covariance Matrix
#         1           2           3           4           5           6           7
#    1.201e-01  -3.655e-02   2.879e-05  -1.664e+10  -2.626e+00   6.999e+07   2.626e+00
#   -3.655e-02   1.714e-02  -8.116e-06  -7.812e+08  -3.147e-01   3.286e+06   3.147e-01
#    2.879e-05  -8.116e-06   7.210e-09  -3.629e+06  -6.073e-04   1.527e+04   6.073e-04
#   -1.570e+10  -1.237e+09  -3.514e+06  -3.472e+25  -6.233e+15   1.461e+23   6.233e+15
#    4.789e-01  -1.652e-01   7.055e-05   2.613e+14  -2.440e+06  -1.100e+12   2.440e+06
#    6.603e+07   5.203e+06   1.478e+04   1.461e+23   2.622e+13  -6.146e+20  -2.622e+13
#   -4.789e-01   1.652e-01  -7.054e-05  -2.613e+14   2.440e+06   1.100e+12  -2.440e+06
# ------------------------------------------------------------------------------------
#
# ========================================================================
# Model TBabs<1>(apec<2> + apec<3> + apec<4>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.478271     +/-  0.346597
#    2    2   apec       kT         keV      1.01853      +/-  0.130912
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                8.70369E-05  +/-  8.49109E-05
#    6    3   apec       kT         keV      63.9908      +/-  -1.00000
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.73036E-07  +/-  -1.00000
#   10    4   apec       kT         keV      64.0000      +/-  -1.00000
#   11    4   apec       Abundanc            1.00000      frozen
#   12    4   apec       Redshift            0.0          frozen
#   13    4   apec       norm                9.80240E-05  +/-  -1.00000
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 13.9684     using 37 bins.
#
# Test statistic : Chi-Squared                 13.9684     using 37 bins.
#  Null hypothesis probability of 9.9439e-01 with 30 degrees of freedom
