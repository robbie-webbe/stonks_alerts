# %%
# %load_ext wurlitzer
import glob
import os
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12,8]
os.chdir('pps/')

Fit.statMethod = "chi"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4

# %%
spec_fnames = glob.glob('P*PNS*SRSPEC*.FTZ')

spec = Spectrum(spec_fnames[0])
Plot.device="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.0001 0.005")
Plot("data")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: P0886100201PNS003SRSPEC004F.FTZ  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  1.255e-02 +/- 1.254e-03 (83.0 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-7
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 9658 sec
#  Using fit statistic: chi
#  Using Background File                P0886100201PNS003BGSPEC004F.FTZ
#   Background Exposure Time: 9658 sec
#  Using Response (RMF) File            epn_e3_ff20_sdY5.rmf for Source 1
#  Using Auxiliary Response (ARF) File  P0886100201PNS003SRCARF004F.FTZ

# %%
#spec.ignore("**-0.2 12.0-**")
mo = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              1.932186e+12     using 7 bins.
#
# Test statistic : Chi-Squared              1.932186e+12     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 4 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 40.6537      2.15681      -3      0.199526      0.884483   1.69176e-06
# 5.16442      9.84349e+06  -4      0.438294       1.05315   2.04959e-06
# 2.02195      1.04325e+06  -5      0.769809       1.02768   2.21508e-06
# 1.92489      201164       -6      0.860683       1.02092   2.24163e-06
# 1.9243       9379.76      -7      0.850396       1.02346   2.23715e-06
# 1.92428      36.6762      -8      0.851692       1.02338   2.23792e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  4.9571E-14| -0.0000  -0.0000   1.0000
#  7.8491E-03| -0.2343  -0.9722  -0.0000
#  1.7645E-01|  0.9722  -0.2343   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.672e-01  -3.840e-02   5.481e-08
#   -3.840e-02   1.710e-02   2.352e-10
#    5.481e-08   2.352e-10   8.738e-14
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.851692     +/-  0.408893
#    2    2   bbody      kT         keV      1.02338      +/-  0.130773
#    3    2   bbody      norm                2.23792E-06  +/-  2.95608E-07
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  1.9243     using 7 bins.
#
# Test statistic : Chi-Squared                  1.9243     using 7 bins.
#  Null hypothesis probability of 7.4968e-01 with 4 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              4.486565e+10     using 7 bins.
#
# Test statistic : Chi-Squared              4.486565e+10     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 4 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 2.22175      5.19227      -3       1.64478       4.98765   6.53038e-05
# 1.07194      32340.5      -4       1.95471       4.57717   7.93931e-05
# 1.04066      7084.6       -5       1.97769       4.54052   8.16103e-05
# 1.04066      109.528      -6       1.97760       4.54105   8.16249e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  6.5429E-11| -0.0000   0.0000   1.0000
#  1.1477E-01|  0.9814   0.1918   0.0000
#  4.8339E+00| -0.1918   0.9814  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.884e-01  -8.883e-01   1.493e-05
#   -8.883e-01   4.660e+00  -6.336e-05
#    1.493e-05  -6.336e-05   9.955e-10
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.97760      +/-  0.536987
#    2    2   bremss     kT         keV      4.54105      +/-  2.15877
#    3    2   bremss     norm                8.16249E-05  +/-  3.15509E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  1.0407     using 7 bins.
#
# Test statistic : Chi-Squared                  1.0407     using 7 bins.
#  Null hypothesis probability of 9.0357e-01 with 4 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              2.131121e+10     using 7 bins.
#
# Test statistic : Chi-Squared              2.131121e+10     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 4 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 73.5663      5.2594       -3      0.233803       10.8594   1.39102e-05
# 31.9467      269472       -4       2.42904       60.2082   0.000114889
# 28.9984      55538.7      -1      0.583517       12.1361   0.000101335
# 10.7904      84348.9      -2       1.15271       4.59269   0.000129161
# 3.86134      3030         -3       1.92014       3.05809   0.000194443
# 1.57622      15244.4      -4       2.23749       3.18337   0.000236173
# 1.56387      774.937      -5       2.27860       3.08259   0.000243751
# 1.56381      92.5898      -6       2.27912       3.08412   0.000243897
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  5.8716E-10| -0.0001   0.0000   1.0000
#  1.0207E-01|  0.8962   0.4436   0.0000
#  1.2068E+00| -0.4436   0.8962  -0.0001
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    3.195e-01  -4.392e-01   3.864e-05
#   -4.392e-01   9.894e-01  -6.687e-05
#    3.864e-05  -6.687e-05   5.751e-09
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    2.27912      +/-  0.565226
#    2    2   apec       kT         keV      3.08412      +/-  0.994673
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                2.43897E-04  +/-  7.58353E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  1.5638     using 7 bins.
#
# Test statistic : Chi-Squared                  1.5638     using 7 bins.
#  Null hypothesis probability of 8.1528e-01 with 4 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              3.108162e+11     using 7 bins.
#
# Test statistic : Chi-Squared              3.108162e+11     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 4 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 9.58908      4.56898      -1      0.969405       1.21837   2.12804e-05
# 7.42356      78347.2      -1       1.16077       1.37016   2.72116e-05
# 5.74373      71919.8      -1       1.30787       1.49741   3.38176e-05
# 4.54867      47466.4      -1       1.43672       1.60459   4.05715e-05
# 4.25645      30886.2      -2       1.97690       2.03431   6.87053e-05
# 3.02332      64824.3      -3       2.45043       2.35535   0.000115238
# 1.26134      33578.8      -4       2.46320       2.34641   0.000132034
# 1.26118      194.925      -5       2.46540       2.34990   0.000132507
# 1.26118      1.42772      -6       2.46515       2.34970   0.000132470
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.7277E-10| -0.0000  -0.0001   1.0000
#  3.9900E-02|  0.5125  -0.8587  -0.0001
#  7.6901E-01|  0.8587   0.5125   0.0001
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    5.775e-01   3.209e-01   6.747e-05
#    3.209e-01   2.314e-01   4.497e-05
#    6.747e-05   4.497e-05   9.108e-09
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    2.46515      +/-  0.759934
#    2    2   powerlaw   PhoIndex            2.34970      +/-  0.481054
#    3    2   powerlaw   norm                1.32470E-04  +/-  9.54375E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  1.2612     using 7 bins.
#
# Test statistic : Chi-Squared                  1.2612     using 7 bins.
#  Null hypothesis probability of 8.6793e-01 with 4 degrees of freedom

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 2.9559e-05 photons (1.8801e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
plx = 0.8111
d_kpc = 1/plx
F_x = 2.269*10**-13

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 4.1254105600512295e+31

# %%
import numpy as np
print(d_kpc)
print(np.log10(L_x))
# Out:
# 1.2328936012822094
# 31.615467175938566

# %%
F_opt = 1.05*10**-5 * 10**(-0.4*19.715)
print('Optical Flux: ',F_opt)
print('F_x / F_opt: ', np.log10(F_x/F_opt))
# Out:
# Optical Flux:  1.3651780569349547e-13
# F_x / F_opt:  0.220645196814998
