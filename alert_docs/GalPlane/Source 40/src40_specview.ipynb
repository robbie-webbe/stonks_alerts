# %%
# %load_ext wurlitzer
import glob
import os
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12,8]
os.chdir('pps/')

Fit.statMethod = "chi"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4

# %%
spec_fnames = glob.glob('P*PNS*SRSPEC*.FTZ')

spec = Spectrum(spec_fnames[0])
Plot.device="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.0001 0.005")
Plot("data")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: P0886100201PNS003SRSPEC004F.FTZ  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  1.255e-02 +/- 1.254e-03 (83.0 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-7
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 9658 sec
#  Using fit statistic: chi
#  Using Background File                P0886100201PNS003BGSPEC004F.FTZ
#   Background Exposure Time: 9658 sec
#  Using Response (RMF) File            epn_e3_ff20_sdY5.rmf for Source 1
#  Using Auxiliary Response (ARF) File  P0886100201PNS003SRCARF004F.FTZ

# %%
spec.ignore("**-0.2 12.0-**")
mo = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
#       No channels ignored (no channels in specified range)
#      1 channels (7) ignored in spectrum #     1
#
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              5.155108e+11     using 6 bins.
#
# Test statistic : Chi-Squared              5.155108e+11     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 20.167       1.87867      -1      0.277527       3.12251   8.81986e-06
# 12.4969      554892       -1     0.0130854       2.77453   8.62696e-06
# 11.6682      58121.5      -1     0.0956445       2.60755   7.73193e-06
# 11.0076      24038.5      -1      0.120447       2.44139   6.75863e-06
# 10.2307      10825.5      -1      0.147558       2.26829   5.86554e-06
# 9.31829      9754.83      -1      0.182371       2.08982   5.04785e-06
# 8.24389      6669.8       -1      0.227042       1.90624   4.30956e-06
# 6.98726      531.999      -1      0.285890       1.71844   3.65825e-06
# 5.56622      9595.62      -1      0.364600       1.52987   3.10667e-06
# 4.09439      24977.2      -1      0.469116       1.34858   2.67358e-06
# 3.30659      42284.2      -2      0.836727      0.896155   1.73987e-06
# 1.58473      1.62617e+06  -3       1.04509      0.918564   2.13351e-06
# 1.57308      133272       -4       1.01640      0.922526   2.14074e-06
# 1.57301      867.447      -5       1.02081      0.921689   2.14229e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  5.1044E-14| -0.0000  -0.0000   1.0000
#  1.1292E-02| -0.2786  -0.9604  -0.0000
#  3.1427E-01|  0.9604  -0.2786   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.907e-01  -8.108e-02   6.488e-08
#   -8.108e-02   3.482e-02   3.837e-09
#    6.488e-08   3.837e-09   1.049e-13
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.02081      +/-  0.539206
#    2    2   bbody      kT         keV      0.921689     +/-  0.186590
#    3    2   bbody      norm                2.14229E-06  +/-  3.23910E-07
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  1.5730     using 6 bins.
#
# Test statistic : Chi-Squared                  1.5730     using 6 bins.
#  Null hypothesis probability of 6.6553e-01 with 3 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              4.039224e+10     using 6 bins.
#
# Test statistic : Chi-Squared              4.039224e+10     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 1.40764      4.89725      -3       1.47488       10.8178   5.61141e-05
# 1.04729      15699        -1       1.60659       10.2191   6.03365e-05
# 0.987751     4826.47      -1       1.67547       8.52987   6.27180e-05
# 0.98773      5222.88      -2       1.79225       6.32590   6.77709e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  4.4503E-11| -0.0000   0.0000   1.0000
#  1.1088E-01|  0.9992   0.0397   0.0000
#  1.9506E+02| -0.0397   0.9992  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    4.180e-01  -7.732e+00   1.564e-05
#   -7.732e+00   1.947e+02  -3.343e-04
#    1.564e-05  -3.343e-04   6.687e-10
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.79225      +/-  0.646568
#    2    2   bremss     kT         keV      6.32590      +/-  13.9552
#    3    2   bremss     norm                6.77709E-05  +/-  2.58589E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  0.9877     using 6 bins.
#
# Test statistic : Chi-Squared                  0.9877     using 6 bins.
#  Null hypothesis probability of 8.0422e-01 with 3 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              2.131087e+10     using 6 bins.
#
# Test statistic : Chi-Squared              2.131087e+10     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 67.8804      5.14715      -2      0.160191       7.68645   1.15676e-05
# 15.1745      228801       -3       1.01369       49.8376   0.000103156
# 8.22493      64592.3      -2       1.74852       10.4963   0.000124881
# 1.62         48536.8      -3       1.89899       4.84437   0.000178454
# 0.904135     13084.1      -4       1.84398       5.86795   0.000184247
# 0.897        1323.94      -5       1.91628       5.31024   0.000192486
# 0.895738     511.407      -6       1.85782       5.86848   0.000185987
# 0.892727     550.839      -2       1.89929       5.47495   0.000190765
# 0.89204      260.554      -3       1.89126       5.59420   0.000189977
# 0.89204      2.31324      -4       1.89106       5.59707   0.000189953
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  3.9903E-10| -0.0001   0.0000   1.0000
#  1.2059E-01|  0.9948   0.1015   0.0001
#  5.1341E+01| -0.1015   0.9948  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    6.480e-01  -5.171e+00   6.638e-05
#   -5.171e+00   5.081e+01  -5.772e-04
#    6.638e-05  -5.772e-04   7.436e-09
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.89106      +/-  0.804970
#    2    2   apec       kT         keV      5.59707      +/-  7.12837
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.89953E-04  +/-  8.62307E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  0.8920     using 6 bins.
#
# Test statistic : Chi-Squared                  0.8920     using 6 bins.
#  Null hypothesis probability of 8.2735e-01 with 3 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.887746e+11     using 6 bins.
#
# Test statistic : Chi-Squared              1.887746e+11     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 2.49436      0.935072     -2       1.45714       1.37890   3.34186e-05
# 1.44039      85758.4      -2       1.70286       1.60325   4.75052e-05
# 1.34402      38773.3      -3       2.00824       1.89170   6.90978e-05
# 0.851458     29820.5      -4       2.05907       1.93460   7.86284e-05
# 0.848546     2163.04      -5       2.05786       1.93393   7.89946e-05
# 0.848546     2.04812      -6       2.05787       1.93393   7.89947e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  6.8956E-11| -0.0000  -0.0001   1.0000
#  5.5767E-02|  0.6380  -0.7700  -0.0000
#  1.2892E+00|  0.7700   0.6380   0.0001
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    7.872e-01   6.060e-01   6.675e-05
#    6.060e-01   5.578e-01   5.837e-05
#    6.675e-05   5.837e-05   6.264e-09
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    2.05787      +/-  0.887226
#    2    2   powerlaw   PhoIndex            1.93393      +/-  0.746869
#    3    2   powerlaw   norm                7.89947E-05  +/-  7.91436E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  0.8485     using 6 bins.
#
# Test statistic : Chi-Squared                  0.8485     using 6 bins.
#  Null hypothesis probability of 8.3782e-01 with 3 degrees of freedom

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 3.2767e-05 photons (2.269e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
#plx = 0.45
d_kpc = 8
F_x = 2.269*10**-13

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 1.7369845387612162e+33
