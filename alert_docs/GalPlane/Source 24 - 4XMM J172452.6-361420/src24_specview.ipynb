# %%
# %load_ext wurlitzer
import glob
import os
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12,8]

Fit.statMethod = "chi"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4

# %%
spec_fnames = glob.glob('*grpspec*')

spec = Spectrum(spec_fnames[0])
Plot.device="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.00001 0.005")
Plot("data")
spec.ignore("**-0.2 12.0-**")
# Out:
# ***Warning: Detected response matrix energy bin value = 0 (or neg).
#      XSPEC will instead use small finite value (response file will not be altered).
#
# 1 spectrum  in use
#
# Spectral Data File: 0886070601_M225grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  1.958e-03 +/- 3.639e-04 (61.5 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-5
#   Telescope: XMM Instrument: EMOS2  Channel Type: PI
#   Exposure Time: 2.636e+04 sec
#  Using fit statistic: chi
#  Using Background File                0886070601_M225spec_bkg.fits
#   Background Exposure Time: 2.636e+04 sec
#  Using Response (RMF) File            0886070601_M225spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0886070601_M225spec.arf
#      1 channels (1) ignored in spectrum #     1
#       No channels ignored (no channels in specified range)

# %%
AllModels.clear()
mo = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              6.654989e+12     using 4 bins.
#
# Test statistic : Chi-Squared              6.654989e+12     using 4 bins.
#  Null hypothesis probability of 0.000000e+00 with 1 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 19.6123      0.258187      0      0.321285       3.14385   8.36935e-07
# 19.4999      566356        0      0.135285       3.16391   7.67028e-07
# 19.2181      786252        0     0.0441104       3.10390   7.34353e-07
# 18.8985      878112        0    0.00268882       3.01381   7.12775e-07
# 18.6809      919314        0   0.000346134       2.92059   6.90876e-07
# 18.5095      939113        0   7.09564e-05       2.83414   6.65095e-07
# 18.3481      973694        0   5.41199e-06       2.74922   6.37729e-07
# 18.1801      1.0189e+06    0   1.49553e-06       2.66316   6.09838e-07
# 17.9958      1.07218e+06   0   5.60517e-07       2.57452   5.81846e-07
# 17.7883      1.1329e+06    0   1.15701e-07       2.48252   5.53923e-07
# 17.5509      1.20154e+06   0   1.04504e-08       2.38654   5.26133e-07
# 17.2743      1.27936e+06   0   4.26636e-09       2.28572   4.98504e-07
# 16.9477      1.36806e+06   0   1.38500e-09       2.17944   4.71053e-07
# 16.5547      1.47036e+06   0   5.70689e-11       2.06667   4.43802e-07
# 16.0732      1.58985e+06   0   1.93443e-11       1.94655   4.16848e-07
# 15.4746      1.73129e+06   0   2.54474e-12       1.81824   3.90133e-07
# 14.7208      1.90444e+06   0   6.98729e-13       1.68183   3.64031e-07
# 13.7447      2.11895e+06   0   3.06438e-13       1.53773   3.40132e-07
# 12.533       2.35815e+06   0   1.45611e-13       1.38848   3.16695e-07
# 11.3301      2.67447e+06  -1   6.33764e-14       1.12525   2.24741e-07
# 11.3214      5.98697e+06  -2   2.27693e-14      0.986970   1.76355e-07
# 5.65299      8.97804e+06  -3   1.08171e-14      0.473924   2.11862e-07
# 5.22001      6.67418e+06  -2   6.70289e-16      0.522089   1.69570e-07
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 6.70289e-16 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 4.88048      6.73877e+06  -3   6.70289e-16      0.541344   1.96361e-07
# 4.86541      234143       -4   6.70289e-16      0.553946   2.00297e-07
# 4.85783      35845.8      -5   6.70289e-16      0.563175   2.02783e-07
# 4.85406      16519.5      -6   6.70289e-16      0.569791   2.04569e-07
# 4.85226      8073         -7   6.70289e-16      0.574410   2.05821e-07
# 4.85143      3695.2       -8   6.70289e-16      0.577585   2.06684e-07
# 4.85104      1526.89      -9   6.70289e-16      0.579739   2.07269e-07
# 4.85087      716.989     -10   6.70289e-16      0.581181   2.07661e-07
# 4.8508       274.308     -11   6.70289e-16      0.582157   2.07926e-07
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 6.70289e-16 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 4.85076      127.904      -3   6.70289e-16      0.582810   2.08104e-07
# ==============================
#  Variances and Principal Axes
#                  2        3
#  1.9736E-15| -0.0000   1.0000
#  2.0575E-02|  1.0000   0.0000
# ------------------------------
#
# ========================
#   Covariance Matrix
#         1           2
#    2.058e-02   5.576e-09
#    5.576e-09   3.484e-15
# ------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    6.70289E-16  +/-  -1.00000
#    2    2   bbody      kT         keV      0.582810     +/-  0.143440
#    3    2   bbody      norm                2.08104E-07  +/-  5.90295E-08
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  4.8508     using 4 bins.
#
# Test statistic : Chi-Squared                  4.8508     using 4 bins.
#  Null hypothesis probability of 2.7634e-02 with 1 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.940079e+11     using 4 bins.
#
# Test statistic : Chi-Squared              1.940079e+11     using 4 bins.
#  Null hypothesis probability of 0.000000e+00 with 1 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 7.17217      1.02721      -1      0.405037       6.43148   5.73558e-06
# 6.39304      252247       -1      0.192712       9.25060   4.64867e-06
# 4.78291      363783       -1     0.0219258       15.2843   4.52126e-06
# 4.34761      372193       -1    0.00846636       20.2294   4.83725e-06
# 4.20042      319729       -1    0.00223495       22.1114   4.94657e-06
# 2.64496      303278        0    0.00101541       8.94705   5.23626e-06
# 2.36467      195695        0   0.000261178       7.69575   5.43867e-06
# 2.23208      155480        0   0.000100208       7.26034   5.57611e-06
# 2.15786      128741        0   2.75524e-05       6.98335   5.66791e-06
# 2.11372      111505        0   1.06333e-05       6.79058   5.73000e-06
# 2.08475      100303        0   2.59527e-06       6.62017   5.77371e-06
# 2.06527      93090.7       0   6.59255e-07       6.49328   5.80533e-06
# 2.05156      88104         0   1.88520e-07       6.39306   5.82876e-06
# 2.04165      84610.8       0   7.32808e-08       6.31518   5.84646e-06
# 2.03437      82077.7       0   1.65745e-08       6.25577   5.85996e-06
# 2.02894      80190.1       0   2.57127e-09       6.20962   5.87033e-06
# 2.02478      78776.2       0   8.37602e-10       6.17210   5.87844e-06
# 2.02159      77713         0   4.07437e-10       6.14341   5.88477e-06
# 2.01909      76883         0   1.93621e-10       6.11915   5.88981e-06
# 2.01714      76256.3       0   8.72460e-11       6.10151   5.89380e-06
# 2.01558      75734.7       0   3.42736e-11       6.08663   5.89703e-06
# 2.01447      75328.6       0   7.81662e-12       6.07562   5.89934e-06
# 2.01324      75045.5       0   1.22827e-12       6.06507   5.90192e-06
# 2.01151      74697.4       0   4.17089e-13       6.05312   5.90565e-06
# 2.00024      74134.9       0   7.86735e-14       6.03862   5.93167e-06
# 1.99054      68913.5       0   1.90055e-14       6.02111   5.95559e-06
# 1.9835       64202.2       0   8.64514e-15       5.66484   5.97318e-06
# 1.97434      68183.1       0   2.00152e-15       5.67936   5.99615e-06
# 1.96651      63048.5       0   8.77319e-16       5.69177   6.01750e-06
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 8.77319e-16 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 1.9265       87448.1       0   8.77319e-16       5.54819   6.16516e-06
# 1.90233      46701.9      -1   8.77319e-16       5.06179   6.35702e-06
# 1.90095      10757.3      -2   8.77319e-16       4.94996   6.41201e-06
# 1.90094      462.022       0   8.77319e-16       4.94163   6.41230e-06
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
#  Parameter 1 is pegged at 8.77319e-16 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 1.90094      865.864      -3   8.77319e-16       4.93491   6.41648e-06
# ==============================
#  Variances and Principal Axes
#                  2        3
#  1.6557E-12|  0.0000   1.0000
#  2.5361E+01|  1.0000  -0.0000
# ------------------------------
#
# ========================
#   Covariance Matrix
#         1           2
#    2.536e+01  -4.969e-06
#   -4.969e-06   2.629e-12
# ------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    8.77319E-16  +/-  -1.00000
#    2    2   bremss     kT         keV      4.93491      +/-  5.03598
#    3    2   bremss     norm                6.41648E-06  +/-  1.62152E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  1.9009     using 4 bins.
#
# Test statistic : Chi-Squared                  1.9009     using 4 bins.
#  Null hypothesis probability of 1.6797e-01 with 1 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              2.696664e+10     using 4 bins.
#
# Test statistic : Chi-Squared              2.696664e+10     using 4 bins.
#  Null hypothesis probability of 0.000000e+00 with 1 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 3.08833      0.282881     -1      0.954079       1.04871   2.72630e-05
# 2.91796      1271.26      -1      0.884279       1.19060   2.44934e-05
# 2.5034       11915.3      -1      0.744429       1.40252   2.28323e-05
# 2.14309      13283.6      -1      0.598644       1.59551   2.20263e-05
# 1.96872      143.802      -1      0.497842       1.74378   2.10140e-05
# 1.80971      3585.89      -1      0.405018       1.93539   2.00096e-05
# 1.65744      1957.62      -1      0.312894       2.17900   1.90379e-05
# 1.5145       2326.92      -1      0.224418       2.48144   1.80253e-05
# 1.39617      3754.33      -1      0.147709       2.81845   1.70474e-05
# 1.29201      4088.71      -1     0.0789614       3.20285   1.61471e-05
# 1.19924      4050.19      -1     0.0151896       3.65503   1.53302e-05
# 1.18507      4431.06       0    0.00959879       3.77263   1.52598e-05
# 1.17504      2437.83       0    0.00313583       3.85635   1.51958e-05
# 1.17005      2271.64       0    0.00140636       3.94744   1.51288e-05
# 1.16926      1255.12       0   0.000356037       4.00538   1.50848e-05
# 1.16853      3554.64       0   6.39248e-06       4.00386   1.50911e-05
# 1.16841      3049.87       0   1.14020e-06       4.00293   1.50962e-05
# 1.16833      2834.25       0   4.93669e-07       4.00219   1.51008e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  8.9963E-12| -0.0000  -0.0000   1.0000
#  6.4060E-02|  0.9944   0.1057   0.0000
#  5.6473E+01| -0.1057   0.9944  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    6.945e-01  -5.930e+00   9.268e-06
#   -5.930e+00   5.584e+01  -7.577e-05
#    9.268e-06  -7.577e-05   1.349e-10
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    4.93669E-07  +/-  0.833348
#    2    2   apec       kT         keV      4.00219      +/-  7.47277
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.51008E-05  +/-  1.16129E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  1.1683     using 4 bins.
#
# Test statistic : Chi-Squared                  1.1683     using 4 bins.
#  Null hypothesis probability of 2.7975e-01 with 1 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.367176e+12     using 4 bins.
#
# Test statistic : Chi-Squared              1.367176e+12     using 4 bins.
#  Null hypothesis probability of 0.000000e+00 with 1 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 11.4212      1.3366       -2     0.0403749      0.624720   1.18268e-06
# 10.6688      1.07238e+06  -1     0.0145325      0.820711   1.32930e-06
# 9.77581      1.20038e+06  -2    0.00275326      0.918607   1.49181e-06
# 9.616        1.13278e+06  -3   0.000154202      0.905068   1.50231e-06
# 9.61448      1.1094e+06   -3   7.42833e-05      0.907026   1.50353e-06
# 9.6053       1.11029e+06  -3   3.43715e-05      0.907466   1.50509e-06
# 9.60252      1.10916e+06  -3   1.44398e-05      0.907612   1.50556e-06
# 9.60144      1.10884e+06  -3   4.47781e-06      0.907668   1.50573e-06
# 9.601        1.10872e+06  -3   1.98771e-06      0.907694   1.50581e-06
# 9.60083      1.10867e+06  -3   7.42738e-07      0.907702   1.50584e-06
# 9.60077      1.10865e+06  -3   1.20265e-07      0.907705   1.50585e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  3.1760E-13| -0.0000  -0.0000   1.0000
#  2.0992E-01|  0.7834  -0.6216  -0.0000
#  3.4954E+00|  0.6216   0.7834   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.479e+00   1.600e+00   3.509e-06
#    1.600e+00   2.226e+00   4.512e-06
#    3.509e-06   4.512e-06   9.680e-12
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.20265E-07  +/-  1.21624
#    2    2   powerlaw   PhoIndex            0.907705     +/-  1.49200
#    3    2   powerlaw   norm                1.50585E-06  +/-  3.11119E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  9.6008     using 4 bins.
#
# Test statistic : Chi-Squared                  9.6008     using 4 bins.
#  Null hypothesis probability of 1.9450e-03 with 1 degrees of freedom

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 6.4579e-06 photons (3.2957e-14 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
plx = 2.3643
d_kpc = 1/plx
F_x = 3.0597*10**-14

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 6.547193324767156e+29

# %%
import numpy as np
print(d_kpc)
print(np.log10(L_x))
# Out:
# 0.4229581694370427
# 29.816055164908555

# %%
F_opt = 1.05*10**-5 * 10**(-0.4*13.65)
print('Optical Flux: ',F_opt)
print('F_x / F_opt: ', np.log10(F_x/F_opt))
# Out:
# Optical Flux:  3.6407369297515754e-11
# F_x / F_opt:  -3.0755104525660277
