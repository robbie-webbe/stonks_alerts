# %%
# %load_ext wurlitzer
import glob
import os
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12,8]
os.chdir('pps/')

Fit.statMethod = "chi"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4

# %%
import numpy as np
out_arr = np.full((4,19),-np.inf,dtype=object)

# %%
spec_fnames = glob.glob('P*PNS*SRSPEC*.FTZ')

spec = Spectrum(spec_fnames[0])
Plot.device="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.0001 0.005")
Plot("data")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: P0886121101PNS003SRSPEC0002.FTZ  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  1.368e-02 +/- 1.593e-03 (75.1 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-6
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 7414 sec
#  Using fit statistic: chi
#  Using Background File                P0886121101PNS003BGSPEC0002.FTZ
#   Background Exposure Time: 7414 sec
#  Using Response (RMF) File            epn_e3_ff20_sdY1.rmf for Source 1
#  Using Auxiliary Response (ARF) File  P0886121101PNS003SRCARF0002.FTZ

# %%
#spec.ignore("**-0.2 12.0-**")
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              1.415900e+11     using 6 bins.
#
# Test statistic : Chi-Squared              1.415900e+11     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 7.95838      2.36389      -2       1.25452       1.43673   3.51280e-05
# 7.25889      70894.4      -3       1.75979       1.74038   5.75790e-05
# 7.24038      45169.5      -4       2.49230       2.10530   0.000101843
# 6.73368      32945.4      -5       3.24082       2.45040   0.000182221
# 4.82347      18558        -6       3.58799       2.59094   0.000263454
# 4.5895       4881.88      -7       3.66855       2.62339   0.000293835
# 4.58773      360.988      -8       3.69018       2.63195   0.000299457
# 4.58769      13.5717      -9       3.69686       2.63460   0.000300870
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.2373E-09| -0.0001  -0.0003   1.0000
#  7.2650E-02|  0.4421  -0.8970  -0.0003
#  2.3504E+00|  0.8970   0.4421   0.0002
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.905e+00   9.032e-01   4.374e-04
#    9.032e-01   5.178e-01   2.373e-04
#    4.374e-04   2.373e-04   1.117e-07
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    3.69686      +/-  1.38030
#    2    2   powerlaw   PhoIndex            2.63460      +/-  0.719603
#    3    2   powerlaw   norm                3.00870E-04  +/-  3.34148E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  4.5877     using 6 bins.
#
# Test statistic : Chi-Squared                  4.5877     using 6 bins.
#  Null hypothesis probability of 2.0460e-01 with 3 degrees of freedom

# %%
Fit.error("1")
Fit.error("2")

out_arr[1,0] = 'powerlaw'
out_arr[1,1:4] = mo.TBabs.nH.values[0], mo.TBabs.nH.values[0] - mo.TBabs.nH.error[0], mo.TBabs.nH.error[1] - mo.TBabs.nH.values[0]
out_arr[1,14:17] = mo.powerlaw.PhoIndex.values[0], mo.powerlaw.PhoIndex.values[0] - mo.powerlaw.PhoIndex.error[0], mo.powerlaw.PhoIndex.error[1] - mo.powerlaw.PhoIndex.values[0]
out_arr[1,-2:] = Fit.dof, Fit.statistic / Fit.dof
# Out:
#  Parameter   Confidence Range (2.706)
#      1      1.05314      7.02715    (-2.64556,3.32845)
#  Parameter   Confidence Range (2.706)
#      2      1.29269      4.11184    (-1.34291,1.47623)

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              2.241195e+10     using 6 bins.
#
# Test statistic : Chi-Squared              2.241195e+10     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 8.75063      2.07535      -3       1.10938       14.3709   4.82579e-05
# 5.7378       63142.1      -4       1.50970       11.1515   6.50630e-05
# 5.38995      5252.21      -1       1.70901       8.33786   7.09769e-05
# 5.0229       10323        -1       1.88715       7.30422   7.81465e-05
# 4.77185      6206.04      -1       2.04248       6.37946   8.51477e-05
# 4.5832       5521.32      -1       2.17485       5.79083   9.18887e-05
# 4.45108      3962.35      -1       2.28621       5.35790   9.80588e-05
# 4.41957      2964.76      -2       2.57630       4.12412   0.000116288
# 4.13835      10102        -3       2.78233       3.89880   0.000132620
# 4.12183      1681.98      -4       2.87079       3.74354   0.000140206
# 4.12015      459.383      -5       2.89770       3.71173   0.000142317
# 4.12006      27.1447      -6       2.90773       3.69565   0.000143113
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  2.7767E-10| -0.0000   0.0000   1.0000
#  2.6111E-01|  0.9252   0.3795   0.0000
#  5.1863E+00| -0.3795   0.9252  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    9.706e-01  -1.729e+00   7.941e-05
#   -1.729e+00   4.477e+00  -1.784e-04
#    7.941e-05  -1.784e-04   7.751e-09
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    2.90773      +/-  0.985176
#    2    2   bremss     kT         keV      3.69565      +/-  2.11585
#    3    2   bremss     norm                1.43113E-04  +/-  8.80414E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  4.1201     using 6 bins.
#
# Test statistic : Chi-Squared                  4.1201     using 6 bins.
#  Null hypothesis probability of 2.4879e-01 with 3 degrees of freedom

# %%
Fit.error("1")
Fit.error("2")

out_arr[3,0] = 'bremss'
out_arr[3,1:4] = mo.TBabs.nH.values[0], mo.TBabs.nH.values[0] - mo.TBabs.nH.error[0], mo.TBabs.nH.error[1] - mo.TBabs.nH.values[0]
out_arr[3,4:7] = mo.bremss.kT.values[0], mo.bremss.kT.values[0] - mo.bremss.kT.error[0], mo.bremss.kT.error[1] - mo.bremss.kT.values[0]
out_arr[3,-2:] = Fit.dof, Fit.statistic / Fit.dof
# Out:
#  Parameter   Confidence Range (2.706)
#      1      1.07594       5.3375    (-1.83462,2.42694)
#  Parameter   Confidence Range (2.706)
#      2      1.66697      44.2648    (-2.02303,40.5748)

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              6.823759e+09     using 6 bins.
#
# Test statistic : Chi-Squared              6.823759e+09     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 50.9825      5.32846      -3      0.199018       10.3952   1.98462e-05
# 28.987       170605       -2      0.214979       57.0378   0.000113764
# 21.2425      54998.6      -2      0.448115       61.7597   0.000179880
# 19.1752      57382.5      -2      0.608872       62.9621   0.000210196
# 13.5287      54827.3      -3      0.746100       63.8073   0.000213120
# 7.44324      37853        -4      0.918629       51.1698   0.000175004
# 7.08429      2168.84      -1       1.04914       40.9551   0.000173980
# 6.8407       335.224      -1       1.16056       25.3938   0.000168843
# 6.66709      1253.99      -1       1.30691       12.5650   0.000164966
# 6.49426      1318.65      -2       1.56170       6.89295   0.000174947
# 6.03815      5076.34      -1       1.74404       6.22049   0.000192970
# 5.7027       2241.22      -1       1.93710       4.99307   0.000212719
# 5.36092      3400.93      -1       2.11523       4.53024   0.000234270
# 5.11604      1870.57      -1       2.27524       4.11776   0.000254678
# 5.03496      1444.83      -2       2.67324       3.09361   0.000309369
# 4.6113       3880.02      -3       2.88048       3.13198   0.000342722
# 4.59073      174.333      -4       3.00657       2.97878   0.000362876
# 4.58725      188.321      -5       3.03520       2.97613   0.000366662
# 4.58694      2.11739      -6       3.04949       2.96226   0.000368870
# 4.58688      1.47329      -7       3.05584       2.95626   0.000369850
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  1.8768E-09| -0.0001   0.0001   1.0000
#  1.9727E-01|  0.7858   0.6185   0.0000
#  2.1745E+00| -0.6185   0.7858  -0.0001
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    9.536e-01  -9.610e-01   1.499e-04
#   -9.610e-01   1.418e+00  -1.807e-04
#    1.499e-04  -1.807e-04   2.739e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    3.05584      +/-  0.976545
#    2    2   apec       kT         keV      2.95626      +/-  1.19085
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                3.69850E-04  +/-  1.65503E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  4.5869     using 6 bins.
#
# Test statistic : Chi-Squared                  4.5869     using 6 bins.
#  Null hypothesis probability of 2.0467e-01 with 3 degrees of freedom

# %%
Fit.error("1")
Fit.error("2")

out_arr[2,0] = 'apec'
out_arr[2,1:4] = mo.TBabs.nH.values[0], mo.TBabs.nH.values[0] - mo.TBabs.nH.error[0], mo.TBabs.nH.error[1] - mo.TBabs.nH.values[0]
out_arr[2,13] = mo.apec.Abundanc.values[0]
out_arr[2,4:7] = mo.apec.kT.values[0], mo.apec.kT.values[0] - mo.apec.kT.error[0], mo.apec.kT.error[1] - mo.apec.kT.values[0]
out_arr[2,-2:] = Fit.dof, Fit.statistic / Fit.dof
# Out:
#  Parameter   Confidence Range (2.706)
#      1     0.961608      5.65982    (-2.09698,2.60123)
#  Parameter   Confidence Range (2.706)
# ***Warning: Parameter pegged at hard limit: 64
#      2      1.65985            0    (-1.29263,-2.95247)

# %%
AllModels.clear()
mo = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              7.765709e+11     using 6 bins.
#
# Test statistic : Chi-Squared              7.765709e+11     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 34.096       1.59934      -1      0.167410       2.78679   4.00797e-06
# 5.11199      1.02825e+06  -1     0.0657952       1.23698   2.28449e-06
# 3.04249      493059       -2      0.211852       1.27544   2.73273e-06
# 2.72768      52543.6      -3      0.335322       1.21574   2.74299e-06
# 2.63761      7481.09      -4      0.410857       1.19869   2.77875e-06
# 2.60664      1962.7       -5      0.462763       1.18394   2.79370e-06
# 2.59425      325.938      -6      0.497691       1.17491   2.80540e-06
# 2.58889      21.6126      -7      0.521757       1.16873   2.81334e-06
# 2.58644      28.1048      -8      0.538500       1.16451   2.81891e-06
# 2.58529      12.0786      -9      0.550184       1.16161   2.82285e-06
# 2.58474      23.8615     -10      0.558414       1.15957   2.82560e-06
# 2.58447      12.7051     -11      0.564209       1.15814   2.82756e-06
# 2.58433      6.31689     -12      0.568295       1.15714   2.82895e-06
# 2.58427      1.59768     -13      0.571172       1.15645   2.82993e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.0742E-13| -0.0000  -0.0000   1.0000
#  1.4437E-02| -0.2917  -0.9565  -0.0000
#  2.4018E-01|  0.9565  -0.2917   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.210e-01  -6.298e-02   5.283e-08
#   -6.298e-02   3.364e-02   2.324e-08
#    5.283e-08   2.324e-08   2.135e-13
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.571172     +/-  0.470078
#    2    2   bbody      kT         keV      1.15645      +/-  0.183416
#    3    2   bbody      norm                2.82993E-06  +/-  4.62069E-07
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  2.5843     using 6 bins.
#
# Test statistic : Chi-Squared                  2.5843     using 6 bins.
#  Null hypothesis probability of 4.6025e-01 with 3 degrees of freedom

# %%
Fit.error("1")
Fit.error("2")

out_arr[0,0] = 'bbody'
out_arr[0,1:4] = mo.TBabs.nH.values[0], mo.TBabs.nH.values[0] - mo.TBabs.nH.error[0], mo.TBabs.nH.error[1] - mo.TBabs.nH.values[0]
out_arr[0,4:7] = mo.bbody.kT.values[0], mo.bbody.kT.values[0] - mo.bbody.kT.error[0], mo.bbody.kT.error[1] - mo.bbody.kT.values[0]
out_arr[0,-2:] = Fit.dof, Fit.statistic / Fit.dof
# Out:
#  Parameter   Confidence Range (2.706)
# ***Warning: Parameter pegged at hard limit: 0
#      1            0      2.91936    (-0.57322,2.34614)
#  Parameter   Confidence Range (2.706)
#      2     0.784071      1.53535    (-0.371518,0.379763)

# %%
np.savetxt('../spec46_output.csv',out_arr,fmt=['%s','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.1f','%.2f','%.2f','%.2f','%i','%.2f'],delimiter=',')

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 3.5507e-05 photons (2.0975e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
plx = 0.6536
d_kpc = 1/plx
F_x = 5.1228*10**-13

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 1.4343819009604648e+32

# %%
import numpy as np
print(d_kpc)
print(np.log10(L_x))
# Out:
# 1.5299877600979193
# 32.15666479665829

# %%
F_opt = 1.05*10**-5 * 10**(-0.4*19.94)
print('Optical Flux: ',F_opt)
print('F_x / F_opt: ', np.log10(F_x/F_opt))
# Out:
# Optical Flux:  1.1096583846743392e-13
# F_x / F_opt:  0.6643181017816344
