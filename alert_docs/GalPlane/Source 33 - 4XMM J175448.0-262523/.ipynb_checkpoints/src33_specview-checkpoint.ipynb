# %%
# %load_ext wurlitzer
import glob
import os
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12,8]

Fit.statMethod = "chi"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4

# %%
import numpy as np
out_arr = np.full((4,19),-np.inf,dtype=object)

# %%
spec_fnames = glob.glob('*grpspec*')

spec = Spectrum(spec_fnames[0])
Plot.device="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.000001 0.005")
Plot("data")
spec.ignore("**-0.2 12.0-**")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0886081201_PN49grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  2.703e-03 +/- 7.991e-04 (29.4 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-10
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 1.753e+04 sec
#  Using fit statistic: chi
#  Using Background File                0886081201_PN49spec_bkg.fits
#   Background Exposure Time: 1.753e+04 sec
#  Using Response (RMF) File            0886081201_PN49spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0886081201_PN49spec.arf
#      2 channels (1-2) ignored in spectrum #     1
#      1 channels (10) ignored in spectrum #     1

# %%
AllModels.clear()
mo = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              9.487817e+11     using 7 bins.
#
# Test statistic : Chi-Squared              9.487817e+11     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 4 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 8.74085      0.179223      0      0.334092       3.06615   1.78313e-06
# 8.1007       124702        0     0.0428768       3.05359   1.67067e-06
# 7.72783      203069        0    0.00104923       2.94120   1.65807e-06
# 7.53519      185687        0   0.000144083       2.83612   1.63342e-06
# 7.42355      157366        0   4.31254e-05       2.75639   1.58217e-06
# 7.33507      148392        0   1.94132e-05       2.68550   1.52240e-06
# 7.25224      148108        0   8.09232e-06       2.61769   1.46056e-06
# 7.16887      151644        0   2.66095e-06       2.55093   1.39906e-06
# 7.08245      156963        0   5.34368e-08       2.48446   1.33879e-06
# 6.99214      163203        0   1.43593e-08       2.41814   1.28011e-06
# 6.89715      170090        0   5.00503e-09       2.35182   1.22318e-06
# 6.79719      177405        0   5.36509e-10       2.28555   1.16806e-06
# 6.69214      185086        0   4.14588e-12       2.21943   1.11482e-06
# 6.57868      193109        0   1.66179e-13       2.15292   1.06475e-06
# 6.48101      198705        0   5.23049e-14       2.09147   1.01010e-06
# 6.33869      221230       -1   4.81847e-16       1.83343   6.95913e-07
# 4.07639      655095       -1    0.00697099       1.07539   4.34239e-07
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    2.79738E-06  +/-  0.296105
#    2    2   bbody      kT         keV      0.843968     +/-  0.420768
#    3    2   bbody      norm                3.12767E-07  +/-  1.96281E-07
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  3.7660     using 7 bins.
#
# Test statistic : Chi-Squared                  3.7660     using 7 bins.
#  Null hypothesis probability of 4.3859e-01 with 4 degrees of freedom
# ***Warning: New best fit found, fit parameters will be set to new values.
# ***Warning: Parameter pegged at hard limit: 0
#      1            0     0.973931    (-1.2096e-06,0.97393)
#  Parameter   Confidence Range (2.706)
#      2     0.226137      2.13364    (-0.617839,1.28967)

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              5.540481e+10     using 7 bins.
#
# Test statistic : Chi-Squared              5.540481e+10     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 4 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 5.07465      0.294321     -2      0.207787       26.6888   4.82479e-06
# 3.32306      168481       -3     0.0725983       198.695   1.06808e-05
# 3.18185      16825.5      -3      0.129339       199.167   1.36446e-05
# 3.15038      19040        -1      0.125042       199.286   1.32291e-05
# 3.13773      12335        -1      0.124698       199.347   1.30149e-05
# 3.13341      7931.63      -1      0.124548       199.358   1.29061e-05
# 3.13179      5688.99      -1      0.124468       199.362   1.28519e-05
# 3.13099      4573.83      -1      0.124454       199.363   1.28200e-05
# 3.13062      3904.03      -1      0.124434       199.363   1.28033e-05
# 3.13049      3558.55      -1      0.124414       199.363   1.27965e-05
# 3.13042      3423.15      -1      0.124410       199.363   1.27930e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.5703E-11| -0.0000  -0.0000   1.0000
#  2.6043E-02|  1.0000   0.0000   0.0000
#  2.1126E+07| -0.0000   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    6.194e-02  -8.708e+02  -1.634e-05
#   -8.708e+02   2.113e+07   4.100e-01
#   -1.634e-05   4.100e-01   7.983e-09
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.124410     +/-  0.248870
#    2    2   bremss     kT         keV      199.363      +/-  4596.35
#    3    2   bremss     norm                1.27930E-05  +/-  8.93494E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  3.1304     using 7 bins.
#
# Test statistic : Chi-Squared                  3.1304     using 7 bins.
#  Null hypothesis probability of 5.3624e-01 with 4 degrees of freedom

# %%
Fit.error("1")
Fit.error("2")

out_arr[3,0] = 'bremss'
out_arr[3,1:4] = mo.TBabs.nH.values[0], mo.TBabs.nH.values[0] - mo.TBabs.nH.error[0], mo.TBabs.nH.error[1] - mo.TBabs.nH.values[0]
out_arr[3,4:7] = mo.bremss.kT.values[0], mo.bremss.kT.values[0] - mo.bremss.kT.error[0], mo.bremss.kT.error[1] - mo.bremss.kT.values[0]
out_arr[3,-2:] = Fit.dof, Fit.statistic / Fit.dof
# Out:
#  Parameter   Confidence Range (2.706)
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 3.12883      0.0040753     0      0.124412       199.363   1.26351e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.5703E-11| -0.0000  -0.0000   1.0000
#  2.6708E-02|  1.0000   0.0000   0.0000
#  2.1732E+07| -0.0000   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    6.367e-02  -8.962e+02  -1.664e-05
#   -8.962e+02   2.173e+07   4.171e-01
#   -1.664e-05   4.171e-01   8.034e-09
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.124412     +/-  0.252320
#    2    2   bremss
# ***XSPEC Error:  No variable parameters for fit
#   kT         keV      199.363      +/-  4661.71
#    3    2   bremss     norm                1.26351E-05  +/-  8.96319E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  3.1288     using 7 bins.
#
# Test statistic : Chi-Squared                  3.1288     using 7 bins.
#  Null hypothesis probability of 5.3650e-01 with 4 degrees of freedom
# ***Warning: New best fit found, fit parameters will be set to new values.
# ***Warning: Parameter pegged at hard limit: 0
#      1            0      0.80364    (-0.124426,0.679214)
#  Parameter   Confidence Range (2.706)
# ***Warning: Zero alpha-matrix diagonal element for parameter 1
# ***Warning: Zero alpha-matrix diagonal element for parameter 3
#  Parameter 1 is pegged at 0.124426 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
#  Parameter 3 is pegged at 1.26354e-05 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
#
#  Fit error occurred during lower bound error calculation.
#
# ***Warning: Number of trials exceeded before bracketing of delta fit-stat.
# Last attempt: 200, with delta statistic: 0
#
# Continue error search in this direction?
# *** Parameter upper bound is INVALID.
#
#      2            0            0    (-199.363,-199.363)

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              1.251556e+10     using 7 bins.
#
# Test statistic : Chi-Squared              1.251556e+10     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 4 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 4.77881      0.039747     -1      0.970618       1.07241   2.48216e-05
# 4.77615      1195.58      -1      0.956530       1.08026   2.45905e-05
# 4.77224      96.2101      -2      0.915072       1.12180   2.31799e-05
# 4.77147      1199.49      -3      0.866437       1.16887   2.21316e-05
# 4.77104      628.267      -1      0.861393       1.17767   2.21867e-05
# 4.77104      38.3501      -1      0.861956       1.17687   2.22001e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  5.7780E-11| -0.0000  -0.0000   1.0000
#  8.2229E-02| -0.6858  -0.7278  -0.0000
#  2.0374E+01|  0.7278  -0.6858   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.083e+01  -1.013e+01   2.318e-04
#   -1.013e+01   9.626e+00  -2.144e-04
#    2.318e-04  -2.144e-04   5.052e-09
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.861956     +/-  3.29088
#    2    2   apec       kT         keV      1.17687      +/-  3.10260
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                2.22001E-05  +/-  7.10783E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  4.7710     using 7 bins.
#
# Test statistic : Chi-Squared                  4.7710     using 7 bins.
#  Null hypothesis probability of 3.1161e-01 with 4 degrees of freedom

# %%
Fit.error("1")
Fit.error("2")

out_arr[2,0] = 'apec'
out_arr[2,1:4] = mo.TBabs.nH.values[0], mo.TBabs.nH.values[0] - mo.TBabs.nH.error[0], mo.TBabs.nH.error[1] - mo.TBabs.nH.values[0]
out_arr[2,13] = mo.apec.Abundanc.values[0]
out_arr[2,4:7] = mo.apec.kT.values[0], mo.apec.kT.values[0] - mo.apec.kT.error[0], mo.apec.kT.error[1] - mo.apec.kT.values[0]
out_arr[2,-2:] = Fit.dof, Fit.statistic / Fit.dof
# Out:
#  Parameter   Confidence Range (2.706)
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 3.15519      0.271549      0      0.146535       63.9999   2.71967e-05
# 3.15187      1244.33       0      0.141715       64.0000   2.70666e-05
# 3.1504       1598.77       0      0.138988       64.0000   2.69457e-05
# 3.14955      1590.36       0      0.137336       64.0000   2.68442e-05
# 3.14901      1453.73       0      0.136279       64.0000   2.67631e-05
# 3.14866      1289.36       0      0.135572       64.0000   2.67001e-05
# 3.14843      1136.78       0      0.135083       64.0000   2.66517e-05
# 3.14828      1008.55       0      0.134736       64.0000   2.66151e-05
# 3.14818      905.942       0      0.134486       64.0000   2.65875e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  6.8828E-11| -0.0000  -0.0000   1.0000
#  2.7624E-02|  1.0000   0.0001   0.0000
#  2.9859E+06| -0.0001   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    6.307e-02  -3.253e+02  -1.569e-05
#   -3.253e+02   2.986e+06   1.553e-01
#   -1.569e-05   1.553e-01   8.198e-09
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.134486     +/-  0.251133
#    2    2   apec       kT         keV      64.0000      +/-  1727.99
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                2.65875E-05  +/-  9.05427E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  3.1482     using 7 bins.
#
# Test statistic : Chi-Squared                  3.1482     using 7 bins.
#  Null hypothesis probability of 5.3334e-01 with 4 degrees of freedom
# ***Warning: New best fit found, fit parameters will be set to new values.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 3.14776      0.00720562    0      0.134432       64.0000   2.64173e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  6.8767E-11| -0.0000  -0.0000   1.0000
#  2.7949E-02|  1.0000   0.0001   0.0000
#  3.0285E+06| -0.0001   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    6.382e-02  -3.296e+02  -1.578e-05
#   -3.296e+02   3.028e+06   1.563e-01
#   -1.578e-05   1.563e-01   8.193e-09
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.134432     +/-  0.252621
#    2    2   apec       kT         keV      64.0000      +/-  1740.26
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                2.64173E-05  +/-  9.05133E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  3.1478     using 7 bins.
#
# Test statistic : Chi-Squared                  3.1478     using 7 bins.
#  Null hypothesis probability of 5.3341e-01 with 4 degrees of freedom
# ***Warning: New best fit found, fit parameters will be set to new values.
# ***Warning: Parameter pegged at hard limit: 0
#      1            0      1.57386    (-0.134393,1.43947)
#  Parameter   Confidence Range (2.706)
#
# ***Warning: Number of trials exceeded before convergence.
# Current trial values 4.73544, 0.008
# and delta statistic 0.591664, 9.94538
#
# Continue error search in this direction? ***Warning: Parameter pegged at hard limit: 64
#      2      2.37172            0    (-61.6283,-64)

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              2.883918e+11     using 7 bins.
#
# Test statistic : Chi-Squared              2.883918e+11     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 4 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 5.02632      0.435122     -1      0.440589       1.10383   3.79570e-06
# 3.39121      123042       -1      0.118961       1.03368   3.12967e-06
# 3.12964      139299       -2     0.0954453       1.08999   3.67584e-06
# 3.12198      3265.72      -3      0.123284       1.15030   3.94541e-06
# 3.12109      1308.74      -4      0.110367       1.11693   3.80560e-06
# 3.12081      386.385      -5      0.116958       1.13308   3.87842e-06
# 3.12075      109.143      -6      0.113659       1.12484   3.84258e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.4788E-12| -0.0000  -0.0000   1.0000
#  2.4514E-02|  0.9711  -0.2387   0.0000
#  1.1547E+00|  0.2387   0.9711   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    8.894e-02   2.620e-01   1.053e-06
#    2.620e-01   1.090e+00   3.693e-06
#    1.053e-06   3.693e-06   1.505e-11
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.113659     +/-  0.298223
#    2    2   powerlaw   PhoIndex            1.12484      +/-  1.04417
#    3    2   powerlaw   norm                3.84258E-06  +/-  3.87887E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  3.1207     using 7 bins.
#
# Test statistic : Chi-Squared                  3.1207     using 7 bins.
#  Null hypothesis probability of 5.3783e-01 with 4 degrees of freedom

# %%
Fit.error("1")
Fit.error("2")

out_arr[1,0] = 'powerlaw'
out_arr[1,1:4] = mo.TBabs.nH.values[0], mo.TBabs.nH.values[0] - mo.TBabs.nH.error[0], mo.TBabs.nH.error[1] - mo.TBabs.nH.values[0]
out_arr[1,14:17] = mo.powerlaw.PhoIndex.values[0], mo.powerlaw.PhoIndex.values[0] - mo.powerlaw.PhoIndex.error[0], mo.powerlaw.PhoIndex.error[1] - mo.powerlaw.PhoIndex.values[0]
out_arr[1,-2:] = Fit.dof, Fit.statistic / Fit.dof
# Out:
#  Parameter   Confidence Range (2.706)
# ***Warning: Parameter pegged at hard limit: 0
#      1            0      1.09437    (-0.115307,0.979059)
#  Parameter   Confidence Range (2.706)
#      2   -0.0366828      4.90411    (-1.16364,3.77715)

# %%
np.savetxt('../spec11_output.csv',out_arr,fmt=['%s','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.1f','%.2f','%.2f','%.2f','%i','%.2f'],delimiter=',')

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 9.8191e-06 photons (5.5954e-14 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
plx = 0.45
d_kpc = 1/plx
F_x = 5.6024*10**-14

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 3.309257552123576e+31

# %%
import numpy as np
print(d_kpc)
print(np.log10(L_x))
# Out:
# 2.2222222222222223
# 31.519730568644686

# %%
F_opt = 1.05*10**-5 * 10**(-0.4*17.58)
print('Optical Flux: ',F_opt)
print('F_x / F_opt: ', np.log10(F_x/F_opt))
# Out:
# Optical Flux:  9.754147061189331e-13
# F_x / F_opt:  -1.240815185730003

# %%
AllModels.clear()
mo = Model("tbabs*(apec+apec)")
mo.apec.kT = 0.5
mo.apec.kT = 4.0
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              5.006353e+10     using 7 bins.
#
# Test statistic : Chi-Squared              5.006353e+10     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 2 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              2.984200e+10     using 7 bins.
#
# Test statistic : Chi-Squared              2.984200e+10     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 2 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared