# %%
# %load_ext wurlitzer
import numpy as np
import glob
import os
import matplotlib.pyplot as plt
from astropy.io import fits
from xspec import *
plt.rcParams['figure.figsize'] = [9,6]

# %%
spec_file = sorted(glob.glob("*grpspec.fits"))
spec = Spectrum(spec_file[0])
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0932200101_PN17grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  8.219e-03 +/- 1.418e-03 (71.0 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-8
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 7427 sec
#  Using fit statistic: chi
#  Using Background File                0932200101_PN17spec_bkg.fits
#   Background Exposure Time: 7427 sec
#  Using Response (RMF) File            0932200101_PN17spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0932200101_PN17spec.arf

# %%
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.00001 0.05")
Plot("data")

# %%
#spec.ignore("**-0.2 12.0-**")
AllModels.clear()
mo1 = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              9.345729e+11     using 8 bins.
#
# Test statistic : Chi-Squared              9.345729e+11     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 5 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 11.4102      0.290194     -2      0.519350       2.21029   2.43898e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.0700E-12| -0.0000  -0.0000   1.0000
#  1.2296E+00| -0.7650  -0.6440  -0.0000
#  6.0908E+00|  0.6440  -0.7650  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    3.246e+00  -2.395e+00  -6.882e-06
#   -2.395e+00   4.075e+00   1.322e-05
#   -6.882e-06   1.322e-05   4.437e-11
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.519350     +/-  1.80161
#    2    2   bbody      kT         keV      2.21029      +/-  2.01856
#    3    2   bbody      norm                2.43898E-06  +/-  6.66139E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   11.41     using 8 bins.
#
# Test statistic : Chi-Squared                   11.41     using 8 bins.
#  Null hypothesis probability of 4.38e-02 with 5 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              5.442177e+10     using 8 bins.
#
# Test statistic : Chi-Squared              5.442177e+10     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 5 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 15.5375      1.59979      -3       2.08117       33.1133   2.28151e-05
# 9.8691       94036.5      -4       3.87784       58.6750   4.89589e-05
# 9.42343      20017.4      -5       3.32630       54.2082   5.17163e-05
# 9.40638      2739.67      -2       3.46631       56.0620   5.25205e-05
# 9.40577      529.17       -3       3.53047       40.0668   5.02073e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  9.2887E-11| -0.0000  -0.0000   1.0000
#  1.9129E+00|  1.0000   0.0044   0.0000
#  2.0443E+05| -0.0044   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    5.828e+00  -8.946e+02  -1.073e-04
#   -8.946e+02   2.044e+05   2.724e-02
#   -1.073e-04   2.724e-02   3.798e-09
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    3.53047      +/-  2.41408
#    2    2   bremss     kT         keV      40.0668      +/-  452.136
#    3    2   bremss     norm                5.02073E-05  +/-  6.16296E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    9.41     using 8 bins.
#
# Test statistic : Chi-Squared                    9.41     using 8 bins.
#  Null hypothesis probability of 9.39e-02 with 5 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              1.946595e+10     using 8 bins.
#
# Test statistic : Chi-Squared              1.946595e+10     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 5 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 34.2849
# 0.456329     -2      0.816623       14.6943   6.49035e-06
# 22.973       109797       -3       13.7051       52.5340   0.000110950
# 22.2538      16660.9      -4       6.73934       60.5852   0.000307604
# 10.2901      29657.1      -5       2.85845       63.8529   0.000162125
# 9.31433      10635.1      -2       3.47491       23.6188   0.000129993
# 9.23438      1255.52      -1       3.99979       10.7427   0.000130057
# 9.16298      4763.62      -1       4.23325       6.57718   0.000146416
# 8.98944      4216.72      -2       4.63684       5.95989   0.000167850
# 8.98419      739.75       -3       4.68264       5.91391   0.000171335
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  9.6480E-10| -0.0000   0.0000   1.0000
#  2.4567E+00|  0.9718   0.2358   0.0000
#  1.3533E+02| -0.2358   0.9718  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    9.842e+00  -3.044e+01   4.911e-04
#   -3.044e+01   1.279e+02  -1.850e-03
#    4.911e-04  -1.850e-03   2.872e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    4.68264      +/-  3.13714
#    2    2   apec       kT         keV      5.91391      +/-  11.3114
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.71335E-04  +/-  1.69461E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    8.98     using 8 bins.
#
# Test statistic : Chi-Squared                    8.98     using 8 bins.
#  Null hypothesis probability of 1.10e-01 with 5 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              2.611434e+11     using 8 bins.
#
# Test statistic : Chi-Squared              2.611434e+11     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 5 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 10.05        2.21621      -3       2.58164       1.19643   1.78694e-05
# 9.95239      48632.6      -4       3.84823       1.49313   3.03848e-05
# 9.37094      39123.3      -5       3.93546       1.51579   3.66011e-05
# 9.3697       1704.02      -6       3.92124       1.51357   3.66632e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  4.5892E-11| -0.0000  -0.0001   1.0000
#  2.7702E-01|  0.3294  -0.9442  -0.0000
#  1.1759E+01|  0.9442   0.3294   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.051e+01   3.571e+00   2.242e-04
#    3.571e+00   1.523e+00   9.169e-05
#    2.242e-04   9.169e-05   5.606e-09
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    3.92124      +/-  3.24232
#    2    2   powerlaw   PhoIndex            1.51357      +/-  1.23410
#    3    2   powerlaw   norm                3.66632E-05  +/-  7.48730E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    9.37     using 8 bins.
#
# Test statistic : Chi-Squared                    9.37     using 8 bins.
#  Null hypothesis probability of 9.52e-02 with 5 degrees of freedom

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 2.1353e-05 photons (1.8924e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
#plx = 1.4843
d_kpc = 8
F_x = 1.8924*10**-13

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 1.4486864438747137e+33

# %%
F_opt = 1.05*10**-5 * 10**(-0.4*20.78)
print('Optical Flux: ',F_opt)
print('F_x / F_opt: ', F_x/F_opt)
# Out:
# Optical Flux:  5.119049146085544e-14
# F_x / F_opt:  3.6967802925804856
