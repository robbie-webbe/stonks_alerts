# %%
# %load_ext wurlitzer
import numpy as np
import glob
import os
import matplotlib.pyplot as plt
from astropy.io import fits
from xspec import *
plt.rcParams['figure.figsize'] = [9,6]

# %%
spec_file = sorted(glob.glob("*grpspec.fits"))
spec = Spectrum(spec_file[0])
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0932200101_PN17grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  8.219e-03 +/- 1.418e-03 (71.0 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-8
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 7427 sec
#  Using fit statistic: chi
#  Using Background File                0932200101_PN17spec_bkg.fits
#   Background Exposure Time: 7427 sec
#  Using Response (RMF) File            0932200101_PN17spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0932200101_PN17spec.arf

# %%
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.00001 0.05")
Plot("data")

# %%
spec.ignore("**-0.2 12.0-**")
AllModels.clear()
mo1 = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
#      1 channels (1) ignored in spectrum #     1
#      1 channels (8) ignored in spectrum #     1
#
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setti
# ng
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              8.227247e+11     using 6 bins.
#
# Test statistic : Chi-Squared              8.227247e+11     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 8.46434      0.262811     -1      0.285480       2.87360   4.71317e-06
# 8.20261      47819.8      -1      0.527756       2.70660   4.29772e-06
# 8.02562      15825.1      -1      0.648282       2.53080   3.83287e-06
# 7.82441      7535.86      -1      0.750355       2.34824   3.39134e-06
# 7.59446      6103.89      -1      0.879195       2.15966   2.98923e-06
# 7.33589      4562.18      -1       1.04629       1.96626   2.63223e-06
# 7.0576       1521.85      -1       1.26457       1.77150   2.33008e-06
# 6.78784      3639.05      -1       1.54415       1.58417   2.09750e-06
# 6.64275      10718.9      -2       2.41737       1.15027   1.65884e-06
# 6.4062       364660       -3       2.75072       1.17595   1.88937e-06
# Number of trials exceeded: continue fitting? 6.40569      19543.2      -4       2.73681       1.17625   1.89404e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.3197E-13| -0.0000  -0.0000   1.0000
#  8.0145E-02| -0.1533  -0.9882  -0.0000
#  7.4558E+00|  0.9882  -0.1533   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    7.282e+00  -1.118e+00   7.570e-07
#   -1.118e+00   2.536e-01  -4.355e-08
#    7.570e-07  -4.355e-08   2.749e-13
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    2.73681      +/-  2.69859
#    2    2   bbody      kT         keV      1.17625      +/-  0.503562
#    3    2   bbody      norm                1.89404E-06  +/-  5.24337E-07
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    6.41     using 6 bins.
#
# Test statistic : Chi-Squared                    6.41     using 6 bins.
#  Null hypothesis probability of 9.35e-02 with 3 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              5.423585e+10     using 6 bins.
#
# Test statistic : Chi-Squared              5.423585e+10     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 8.9536       1.49503      -3       2.55379       25.4699   2.97272e-05
# 7.39857      54769        -2       4.46527       9.54256   4.43881e-05
# 6.65323      31282.9      -2       4.35651       5.71058   5.79429e-05
# 6.34724      13784.2      -3       4.65538       5.98427   6.52421e-05
# 6.34694      256.219      -4       4.64779       5.92198   6.56093e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.5632E-10| -0.0000   0.0000   1.0000
#  2.6039E+00|  0.9735   0.2285   0.0000
#  1.4162E+02| -0.2285   0.9735  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    9.863e+00  -3.093e+01   2.330e-04
#   -3.093e+01   1.344e+02  -9.158e-04
#    2.330e-04  -9.158e-04   6.578e-09
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    4.64779      +/-  3.14052
#    2    2   bremss     kT         keV      5.92198      +/-  11.5916
#    3    2   bremss     norm                6.56093E-05  +/-  8.11029E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    6.35     using 6 bins.
#
# Test statistic : Chi-Squared                    6.35     using 6 bins.
#  Null hypothesis probability of 9.59e-02 with 3 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              1.946576e+10     using 6 bins.
#
# Test statistic : Chi-Squared              1.946576e+10     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 29.082       0.452811     -2      0.843413       14.6302   6.78636e-06
# 18.232       103224       -3       11.9351       41.0893   0.000107209
# 8.98037      16125.4      -2       1.85352       61.8015   0.000113048
# 6.76753      4361.55      -2       3.16732       20.0654   0.000114445
# 6.63877      4851.14       0       3.26944       18.7292   0.000119173
# 6.57133      2912.43       0       3.36650       18.0265   0.000122426
# 6.5311       1952.94       0       3.45183       17.2428   0.000124819
# 6.50407      1394.24       0       3.52895       15.9847   0.000126660
# 6.48441      1097.23       0       3.59534       15.0318   0.000128254
# 6.46932      907.321       0       3.65325       14.1465   0.000129669
# Number of trials exceeded: continue fitting? 6.44971      796.416      -1       3.99557       7.62956   0.000138202
# 6.36457      2615.94      -2       4.47930       6.05303   0.000159313
# 6.34286
#    1439.7       -3       4.65346       5.62511   0.000170790
# 6.34249      193.074      -4       4.65661       5.63178   0.000171407
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  1.0749E-09| -0.0000   0.0000   1.0000
#  2.5340E+00|  0.9656   0.2601   0.0000
#  1.0743E+02| -0.2601   0.9656  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    9.628e+00  -2.634e+01   4.930e-04
#   -2.634e+01   1.003e+02  -1.657e-03
#    4.930e-04  -1.657e-03   2.968e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    4.65661      +/-  3.10287
#    2    2   apec       kT         keV      5.63178      +/-  10.0167
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.71407E-04  +/-  1.72290E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    6.34     using 6 bins.
#
# Test statistic : Chi-Squared                    6.34     using 6 bins.
#  Null hypothesis probability of 9.61e-02 with 3 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              2.528693e+11     using 6 bins.
#
# Test statistic : Chi-Squared              2.528693e+11     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 10.2357      1.9215       -3       3.08746       1.61104   2.33088e-05
# 6.56325      86111.3      -2       4.28487       1.58891   3.98362e-05
# 6.43216      8620.35      -2       4.23072       1.73627   4.90640e-05
# 6.3929       4279.18      -2       4.49940       1.83779   5.84150e-05
# 6.36876      2738.38      -2       4.67785       1.91669   6.67871e-05
# 6.35568      1455.85      -2       4.81851       1.97787   7.40028e-05
# 6.3483       802.71       -2       4.92875       2.02546   8.00836e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  2.0310E-10| -0.0000  -0.0001   1.0000
#  3.6722E-01|  0.3537  -0.9353  -0.0001
#  1.9252E+01|  0.9353   0.3537   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.689e+01   6.248e+00   7.645e-04
#    6.248e+00   2.730e+00   3.236e-04
#    7.645e-04   3.236e-04   3.878e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    4.92875      +/-  4.10957
#    2    2   powerlaw   PhoIndex            2.02546      +/-  1.65237
#    3    2   powerlaw   norm                8.00836E-05  +/-  1.96914E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    6.35     using 6 bins.
#
# Test statistic : Chi-Squared                    6.35     using 6 bins.
#  Null hypothesis probability of 9.58e-02 with 3 degrees of freedom

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 1.9012e-05 photons (1.5611e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
#plx = 1.4843
d_kpc = 8
F_x = 1.8924*10**-13

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 1.4486864438747137e+33

# %%
import numpy as np
print(d_kpc)
print(np.log10(L_x))
# Out:
# 8
# 33.16097439621585

# %%
F_opt = 1.05*10**-5 * 10**(-0.4*20.7)
print('Optical Flux: ',F_opt)
print('F_x / F_opt: ', np.log10(F_x/F_opt))
# Out:
# Optical Flux:  5.510478332622621e-14
# F_x / F_opt:  0.5358236403065889

# %%
AllModels.clear()
mo = Model("tbabs*(bbody+bbody)")
mo.bbody.kT = 0.2
mo.bbody_3.kT = 3.0
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>(bbody<2> + bbody<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
#    4    3   bbody      kT         keV      3.00000      +/-  0.0
#    5    3   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              3.290917e+12     using 6 bins.
#
# Test statistic : Chi-Squared              3.290917e+12     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 1 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              9.469856e+12     using 6 bins.
#
# Test statistic : Chi-Squared              9.469856e+12     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 1 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              9.469856e+12     using 6 bins.
#
# Test statistic : Chi-Squared              9.469856e+12     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 1 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm          4:kT        5:norm
# 19.834       880947        0       1.02420      0.197132   9.06148e-07       2.50816   1.26794e-06
# 9.67901      901790        0       1.14019      0.182586   7.10212e-07       1.61940   2.08199e-06
# 7.16593      654861       -1       1.27495      0.147021   2.43408e-07       1.47496   1.94094e-06
# 7.10478      199647       -1       1.30885     0.0371267   4.60058e-08       1.38738   1.85458e-06
# 6.51013      214813       -1       1.97285     0.0102408     0.0266422       1.33960   1.87467e-06
# 6.51013      4661.58      13       1.97285     0.0137977      0.465027       1.33960   1.87467e-06
# ============================================================
#  Variances and Principal Axes
#                  1        2        3        4        5
#  2.3878E-13|  0.0000  -0.0000  -0.0000  -0.0000   1.0000
#  3.9210E-01|  0.0000  -0.0000  -0.0000  -1.0000  -0.0000
#  1.0983E+02|  1.0000   0.0000   0.0000   0.0000   0.0000
#  1.6293E+26|  0.0000  -1.0000  -0.0087   0.0000  -0.0000
#  1.6556E+34|  0.0000  -0.0087   1.0000   0.0000  -0.0000
# ------------------------------------------------------------
#
# ============================================================
#   Covariance Matrix
#         1           2           3           4           5
#    1.098e+02   8.091e+15  -9.153e+17  -1.194e+01   5.264e-06
#    8.091e+15   1.264e+30  -1.446e+32  -8.329e+14   4.170e+08
#   -9.153e+17  -1.446e+32   1.655e+34   9.423e+16  -4.718e+10
#   -1.194e+01  -8.329e+14   9.423e+16   1.503e+00  -3.645e-07
#    5.264e-06   4.170e+08  -4.718e+10  -3.645e-07   6.116e-13
# ------------------------------------------------------------
#
# ========================================================================
# Model TBabs<1>(bbody<2> + bbody<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.97285      +/-  10.4801
#    2    2   bbody      kT         keV      1.37977E-02  +/-  1.12415E+15
#    3    2   bbody      norm                0.465027     +/-  1.28664E+17
#    4    3   bbody      kT         keV      1.33960      +/-  1.22606
#    5    3   bbody      norm                1.87467E-06  +/-  7.82074E-07
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    6.51     using 6 bins.
#
# Test statistic : Chi-Squared                    6.51     using 6 bins.
#  Null hypothesis probability of 1.07e-02 with 1 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*(bbody+powerlaw)")
mo.bbody.kT = 0.5
mo.powerlaw.PhoIndex = 3.0
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>(bbody<2> + powerlaw<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
#    4    3   powerlaw   PhoIndex            1.00000      +/-  0.0
#    5    3   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.856978e+12     using 6 bins.
#
# Test statistic : Chi-Squared              1.856978e+12     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 1 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              5.900049e+13     using 6 bins.
#
# Test statistic : Chi-Squared              5.9
# 00049e+13     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 1 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              5.482561e+13     using 6 bins.
#
# Test statistic : Chi-Squared              5.482561e+13     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 1 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm    4:PhoIndex        5:norm
# 13.9626      2697.67      -2       2.07249      0.798335   1.33464e-07     -0.144201   3.65354e-06
# 7.03493      961016       -3       4.55348      0.746871   1.23337e-06     0.0891153   2.94327e-06
# 6.33682      129638       -4       4.17076      0.682600   1.40547e-06      0.179914   2.68907e-06
# 6.33583      6680.07      -5       4.34626      0.681504   1.42431e-06      0.336780   3.37892e-06
# ============================================================
#  Variances and Principal Axes
#                  1        2        3        4        5
#  1.9409E-13| -0.0000   0.0000   0.9416  -0.0000   0.3367
#  2.2404E-12|  0.0000   0.0000  -0.3367  -0.0000   0.9416
#  1.3970E-01|  0.1323   0.9904   0.0000   0.0398  -0.0000
#  4.5513E+01|  0.9541  -0.1163   0.0000  -0.2760  -0.0000
#  1.7854E+09| -0.2688   0.0745   0.0000  -0.9603  -0.0000
# ------------------------------------------------------------
#
# ============================================================
#   Covariance Matrix
#         1           2           3           4           5
#    1.290e+08  -3.575e+07  -1.219e+02   4.608e+08   2.335e+03
#   -3.575e+07   9.908e+06   3.379e+01  -1.277e+08  -6.473e+02
#   -1.219e+02   3.379e+01   1.152e-04  -4.355e+02  -2.207e-03
#    4.608e+08  -1.277e+08  -4.355e+02   1.647e+09   8.344e+03
#    2.335e+03  -6.473e+02  -2.207e-03   8.344e+03   4.229e-02
# ------------------------------------------------------------
#
# ========================================================================
# Model TBabs<1>(bbody<2> + powerlaw<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    4.34626      +/-  1.13567E+04
#    2    2   bbody      kT         keV      0.681504     +/-  3147.77
#    3    2   bbody      norm                1.42431E-06  +/-  1.07334E-02
#    4    3   powerlaw   PhoIndex            0.336780     +/-  4.05775E+04
#    5    3   powerlaw   norm                3.37892E-06  +/-  0.205642
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    6.34     using 6 bins.
#
# Test statistic : Chi-Squared                    6.34     using 6 bins.
#  Null hypothesis probability of 1.18e-02 with 1 degrees of freedom
