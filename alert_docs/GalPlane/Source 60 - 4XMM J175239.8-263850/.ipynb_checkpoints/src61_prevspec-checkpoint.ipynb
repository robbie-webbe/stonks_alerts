# %%
# %load_ext wurlitzer
import glob
import os
import numpy as np
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12,8]

Fit.statMethod = "chi"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4
os.chdir('other_obs')

# %%
spec = Spectrum('0932191101_MOS33grpspec.fits')

Plot.device="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.00001 0.005")
Plot("data")
#spec.ignore("**-0.2 12.0-**")
# Out:
# Warning: RMF FILTER keyword (UNDEFINED) is not consistent with that in spectrum (Medium)
#
# 1 spectrum  in use
#
# Spectral Data File: 0932191101_MOS33grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  2.169e-03 +/- 5.826e-04 (68.0 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-3
#   Telescope: XMM Instrument: EPIC  Channel Type: PI
#   Exposure Time: 1.003e+04 sec
#  Using fit statistic: chi
#  Using Background File                0932191101_MOS33spec_bkg.fits
#   Background Exposure Time: 1.003e+04 sec
#  Using Response (RMF) File            0932191101_MOS33spec.rmf for Source 1

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              2.892189e+11     using 3 bins.
#
# Test statistic : Chi-Squared              2.892189e+11     using 3 bins.
#  Cannot calculate null hypothesis probability.
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 5.96559      0.875679      0       1.69914      0.658834   4.71818e-06
# 1.94708      63186.6      -1       4.64484     0.0341526   5.40839e-06
# 0.170237     378538       -2       6.98605      0.151800   6.01600e-06
# 0.0987911    28796.7      -2       8.54775      0.257436   7.35736e-06
# 0.0771091    15335.6      -2       9.14066      0.354264   8.88015e-06
# 0.0588592    12014.1      -2       9.61746      0.438167   1.04681e-05
# 0.0454352    7889.87      -2       10.0444      0.511446   1.20826e-05
# 0.0354254    5291.1       -2       10.4243      0.575835   1.36993e-05
# 0.0278438    3643.63      -2       10.7633      0.632628   1.52991e-05
# 0.0220263    2571.7       -2       11.0663      0.682884   1.68662e-05
# 0.0175165    1854.5       -2       11.3375      0.727478   1.83880e-05
# 0.0139913    1362.68      -2       11.5807      0.767144   1.98545e-05
# 0.0112169    1018.07      -2       11.7990      0.802503   2.12585e-05
# 0.00902112   771.944      -2       11.9951      0.834080   2.25949e-05
# 0.0072749    593.143      -2       12.1716      0.862327   2.38604e-05
# 0.00588054   461.253      -2       12.3304      0.887633   2.50535e-05
# 0.00476322   362.619      -2       12.4735      0.910334   2.61739e-05
# 0.00386517   287.927      -2       12.6026      0.930721   2.72223e-05
# 0.00314143   230.72       -2       12.7190      0.949051   2.82003e-05
# 0.00255681   186.444      -2       12.8241      0.965545   2.91102e-05
# 0.0024022    151.845      -3       13.3356       1.04509   3.35695e-05
# 0.00135217   1653.41      -4       13.7847       1.11421   3.83845e-05
# 6.24189e-07  1250.92      -5       13.8295       1.12088   3.92372e-05
# 4.96052e-15  26.576       -6       13.8297       1.12092   3.92478e-05
# =====================
# GammQ: A <=  0
# GammQ: A <=  0
# ===================
#  Variances and Principal Axes
#                  1        2        3
#  9.8176E-11| -0.0000  -0.0001   1.0000
#  1.4209E+00|  0.1319  -0.9913  -0.0001
#  4.8478E+02|  0.9913   0.1319   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    4.764e+02   6.319e+01   4.883e-03
#    6.319e+01   9.828e+00   7.377e-04
#    4.883e-03   7.377e-04   5.575e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    13.8297      +/-  21.8261
#    2    2   powerlaw   PhoIndex            1.12092      +/-  3.13496
#    3    2   powerlaw   norm                3.92478E-05  +/-  2.36112E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   5e-15     using 3 bins.
#
# Test statistic : Chi-Squared                   5e-15     using 3 bins.
#  Cannot calculate null hypothesis probability.

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              6.599681e+10     using 3 bins.
#
# Test statistic : Chi-Squared              6.599681e+10     using 3 bins.
#  Cannot calculate null hypothesis probability.
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 11.2938      0.275223      0       1.57987       42.2317   6.69285e-06
# 5.87471      77568.4      -1       8.40834       18.9315   2.87394e-05
# 3.44806      40647.7      -2       10.9529       199.197   6.37465e-05
# 0.351637     20049.4      -3       16.4528       198.547   0.000135625
# 0.214774     4640.07      -3       13.9737       199.232   0.000156049
# 0.0519185    4308.4       -2       14.3990       199.309   0.000151111
# 0.0213953    2062.71      -2       14.4937       199.353   0.000148831
# 0.013324     1288.62      -2       14.5106       199.361   0.000147782
# 0.0104615    989.82       -2       14.5149       199.363   0.000147299
# 0.00924677   859.484      -2       14.5166       199.363   0.000147068
# 0.00874856   797.794      -2       14.5173       199.363   0.000146968
# 0.00850823   771.073      -2       14.5177       199.363   0.000146918
# 0.00839888   757.847      -2       14.5178       199.363   0.000146895
# 0.00834869   751.753      -2       14.5179       199.363   0.000146884
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.3204E-09| -0.0000  -0.0000   1.0000
#  7.1064E+01|  1.0000   0.0020   0.0000
#  7.9392E+07| -0.0020   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    3.781e+02  -1.561e+05  -2.777e-02
#   -1.561e+05   7.939e+07   1.439e+01
#   -2.777e-02   1.439e+01   2.613e-06
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    14.5179      +/-  19.4440
#    2    2   bremss     kT         keV      199.363      +/-  8910.18
#    3    2   bremss     norm                1.46884E-04  +/-  1.61658E-03
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  0.0083     using 3 bins.
#
# Test statistic : Chi-Squared                  0.0083     using 3 bins.
#  Cannot calculate null hypothesis probability.
# GammQ: A <=  0
# GammQ: A <=  0

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
# Out:
# GammQ: A <=  0
# GammQ: A <=  0
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              1.447169e+10     using 3 bins.
#
# Test statistic : Chi-Squared              1.447169e+10     using 3 bins.
#  Cannot calculate null hypothesis probability.
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 14.0591      0.0611309     0       1.08865       1.90471   8.83442e-06
# 13.9259      18047.2      -1      0.524144       41.0949   3.29380e-05
# 4.33852      51260.5      -2       4.36235       48.0503   0.000118620
# 2.22654      1622.7       -3       8.86383       59.6547   0.000282175
# 0.345586     7004.27      -2       11.9695       62.8861   0.000304349
# 0.0310685    2102.52      -2       14.1330       63.4839   0.000320950
# 0.00867009   555.201      -2       14.8348       63.8728   0.000328193
# 0.00450978   279.95       -1       14.9495       63.9494   0.000326971
# 0.00390447   118.787      -1       14.9827       63.9950   0.000326541
# 0.00379018   67.9841      -1       14.9915       63.9999   0.000326384
# 0.00375869   52.8699      -1       14.9936       64.0000   0.000326318
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  6.7475E-09| -0.0000  -0.0000   1.0000
#  7.5789E+01|  1.0000   0.0045   0.0000
#  8.8583E+07| -0.0045   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.832e+03  -3.945e+05  -1.570e-01
#   -3.945e+05   8.858e+07   3.553e+01
#   -1.570e-01   3.553e+01   1.428e-05
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    14.9936      +/-  42.8063
#    2    2   apec       kT         keV      64.0000      +/-  9411.75
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                3.26318E-04  +/-  3.77846E-03
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  0.0038     using 3 bins.
#
# Test statistic : Chi-Squared                  0.0038     using 3 bins.
#  Cannot calculate null hypothesis probability.

# %%
AllModels.clear()
mo = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              6.087745e+11     using 3 bins.
#
# Test statistic : Chi-Squared              6.087745e+11     using 3 bins.
#  Cannot calculate null hypothesis probability.
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 0.368571     0.355981     -3       4.26817       3.01574   7.22150e-06
# 0.113491     13470.9      -4       8.03477       2.10724   4.67556e-06
# 0.00183803   46448.7      -5       9.82794       2.15156   5.51074e-06
# 1.05558e-06  8773.69      -6       10.1668       2.10457   5.49029e-06
# 4.61177e-12  51.2796      -7       10.1688       2.10557   5.49471e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.9216E-12| -0.0000  -0.0000   1.0000
#  1.6241E+00| -0.1353  -0.9908  -0.0000
#  2.5922E+02|  0.9908  -0.1353  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.545e+02  -3.453e+01  -5.070e-05
#   -3.453e+01   6.338e+00   1.272e-05
#   -5.070e-05   1.272e-05   3.265e-11
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    10.1688      +/-  15.9534
#    2    2   bbody      kT         keV      2.10557      +/-  2.51749
#    3    2   bbody      norm                5.49471E-06  +/-  5.71430E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   5e-12     using 3 bins.
#
# Test statistic : Chi-Squared                   5e-12     using 3 bins.
#  Cannot calculate null hypothesis probability.
# GammQ: A <=  0
# GammQ: A <=  0

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 2.4328e-05 photons (2.6202e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
#plx = 1.4843
d_kpc = 8
F_x = 5.6*10**-13

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 4.2869605187583995e+33

# %%
F_opt = 1.05*10**-5 * 10**(-0.4*20.78)
print('Optical Flux: ',F_opt)
print('F_x / F_opt: ', F_x/F_opt)
# Out:
# Optical Flux:  5.119049146085544e-14
# F_x / F_opt:  10.939531620403042
