# %%
# %load_ext wurlitzer
import numpy as np
import glob
import os
import matplotlib.pyplot as plt
from astropy.io import fits
from xspec import *
plt.rcParams['figure.figsize'] = [9,6]

# %%
spec_file = sorted(glob.glob("*grpspec.fits"))
spec = Spectrum(spec_file[0])
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0932200101_PN17grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  8.219e-03 +/- 1.418e-03 (71.0 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-5
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 7427 sec
#  Using fit statistic: chi
#  Using Background File                0932200101_PN17spec_bkg.fits
#   Background Exposure Time: 7427 sec
#  Using Response (RMF) File            0932200101_PN17spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0932200101_PN17spec.arf

# %%
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.00001 0.05")
Plot("data")

# %%
spec.ignore("**-0.2 12.0-**")
AllModels.clear()
mo1 = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
AllModels.calcFlux("0.2 12.0")
# Out:
# GammQ: A <=  0
# GammQ: A <=  0
#      1 channels (1) ignored in spectrum #     1
#      1 channels (5) ignored in spectrum #     1
#
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              3.895329e+11     using 3 bins.
#
# Test statistic : Chi-Squared              3.895329e+11     using 3 bins.
#  Cannot calculate null hypothesis probability.
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 6.58304      0.178491     -3      0.491836       3.09744   6.25565e-06
# 6.35484      81684.2      -4     0.0707307       3.61142   8.65137e-06
# 6.34043      5542.14      -2      0.112834       3.67556   9.25942e-06
# 6.33814      1412.19      -2      0.126606       3.72286   9.62568e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  4.4121E-12| -0.0000  -0.0000   1.0000
#  3.2938E-01|  0.9941   0.1082   0.0000
#  7.6450E+04| -0.1082   0.9941   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    8.950e+02  -8.222e+03  -4.879e-02
#   -8.222e+03   7.556e+04   4.483e-01
#   -4.879e-02   4.483e-01   2.660e-06
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.126606     +/-  29.9173
#    2    2   bbody      kT         keV      3.72286      +/-  274.873
#    3    2   bbody      norm                9.62568E-06  +/-  1.63108E-03
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    6.34     using 3 bins.
#
# Test statistic : Chi-Squared                    6.34     using 3 bins.
#  Cannot calculate null hypothesis probability.
#  Model Flux 3.3411e-05 photons (3.5372e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)
