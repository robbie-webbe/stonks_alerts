# %%
# %load_ext wurlitzer
import glob
import os
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12,8]
os.chdir('pps/')

Fit.statMethod = "chi"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4

# %%
spec_fnames = glob.glob('P*601PNS*SRSPEC*.FTZ')

spec = Spectrum(spec_fnames[0])
Plot.device="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.0001 0.1")
Plot("data")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: P0932190601PNS003SRSPEC0002.FTZ  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  3.143e-02 +/- 2.149e-03 (79.6 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-17
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 8738 sec
#  Using fit statistic: chi
#  Using Background File                P0932190601PNS003BGSPEC0002.FTZ
#   Background Exposure Time: 8738 sec
#  Using Response (RMF) File            epn_e3_ff20_sdY2.rmf for Source 1
#  Using Auxiliary Response (ARF) File  P0932190601PNS003SRCARF0002.FTZ

# %%
spec.ignore("**-0.2 12.0-**")
mo = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
#       No channels ignored (no channels in specified range)
#      1 channels (17) ignored in spectrum #     1
#
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross s
# ection setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              5.510380e+11     using 16 bins.
#
# Test statistic : Chi-Squared              5.510380e+11     using 16 bins.
#  Null hypothesis probability of 0.000000e+00 with 13 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 204.889      0.907228      0      0.400577       3.13744   5.68361e-06
# 201.801      276446        0     0.0147301       3.21586   5.20461e-06
# 200.047      498975        0    0.00533262       3.13933   5.40234e-06
# 198.758      455742        0    0.00120809       3.07801   5.55827e-06
# 197.821      410723        0   0.000274698       3.02792   5.68068e-06
# 197.115      366647        0   5.85014e-05       2.98631   5.77590e-06
# 196.569      325948        0   7.67803e-06       2.95121   5.84923e-06
# 196.142      289271        0   1.63928e-06       2.92109   5.90486e-06
# 195.801      256609        0   1.92231e-07       2.89491   5.94604e-06
# 195.525      227787        0   1.76960e-08       2.87186   5.97539e-06
# 195.298      202499        0   7.11343e-09       2.85134   5.99497e-06
# 195.108      180411        0   1.95761e-09       2.83286   6.00647e-06
# 194.947      161177        0   6.97174e-10       2.81605   6.01126e-06
# 194.806      144470        0   7.90635e-11       2.80059   6.01045e-06
# 194.683      129974        0   3.10534e-12       2.78626   6.00494e-06
# 194.58       117431        0   8.42687e-13       2.77350   5.99223e-06
# 194.479      108223        0   2.63172e-13       2.76081   5.97985e-06
# 194.371      98713.8       0   1.20448e-13       2.74746   5.97152e-06
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.221756     +/-  8.55579E-02
#    2    2   powerlaw   PhoIndex            3.20389      +/-  0.558046
#    3    2   powerlaw   norm                7.92128E-05  +/-  2.40442E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 48.3567     using 16 bins.
#
# Test statistic : Chi-Squared                 48.3567     using 16 bins.
#  Null hypothesis probability of 5.6906e-06 with 13 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.782459e+10     using 16 bins.
#
# Test statistic : Chi-Squared              1.782459e+10     using 16 bins.
#  Null hypothesis probability of 0.000000e+00 with 13 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 139.147      4.28908      -3     0.0176578       40.7812   2.10583e-05
# 134.051      557677       -2    0.00206813       7.33154   1.55758e-05
# 58.6527      816282       -3   0.000916033       2.94075   4.22420e-05
# 55.8693      154264       -4     0.0298339       1.83601   5.62240e-05
# 54.2943      87798.8      -5     0.0545896       1.35868   7.29748e-05
# 53.7988      55730.5      -6     0.0813782       1.02501   9.64714e-05
# 53.2322      50705.8      -7      0.112040      0.810298   0.000133520
# 52.1593      38029.1      -8      0.138365      0.686262   0.000181469
# 51.42        22001.6      -9      0.159938      0.606625   0.000235468
# 51.0036      12204.3     -10      0.178286      0.551412   0.000293074
# 50.6948      7041.71     -11      0.194326      0.510256   0.000353801
# 50.568       4407.07     -12      0.210751      0.474139   0.000425673
# 50.4312      3561.61     -13      0.223375      0.450158   0.000494442
# 50.3651      1930.8      -14      0.232992      0.433359   0.000555077
# 50.3352      1009.92     -15      0.239814      0.422131   0.000602593
# 50.3231      467.807     -16      0.244729      0.414353   0.000638745
# 50.3176      224.099     -17      0.248210      0.408991   0.000665422
# 50.315       107.386     -18      0.250666      0.405281   0.000684768
# 50.3137      51.4333     -19      0.252397      0.402703   0.000698666
# 50.313       24.3839     -20      0.253639      0.400870   0.000708767
# 50.3128      12.1801     -21      0.254387      0.399761   0.000714971
# 50.3125      4.56019     -22      0.255097      0.398743   0.000720748
# 50.3124      3.73645     -23      0.255558      0.398068   0.000724597
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  2.8822E-09| -0.0030   0.0036   1.0000
#  5.5077E-04|  0.7870   0.6170   0.0001
#  1.6441E-02| -0.6170   0.7870  -0.0047
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    6.599e-03  -7.715e-03   4.759e-05
#   -7.715e-03   1.039e-02  -6.062e-05
#    4.759e-05  -6.062e-05   3.642e-07
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.255558     +/-  8.12349E-02
#    2    2   bremss     kT         keV      0.398068     +/-  0.101942
#    3    2   bremss     norm                7.24597E-04  +/-  6.03496E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 50.3124     using 16 bins.
#
# Test statistic : Chi-Squared                 50.3124     using 16 bins.
#  Null hypothesis probability of 2.6351e-06 with 13 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              2.382543e+09     using 16 bins.
#
# Test statistic : Chi-Squared              2.382543e+09     using 16 bins.
#  Null hypothesis probability of 0.000000e+00 with 13 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.474e-03  -2.259e-03   2.908e-07
#   -2.259e-03   3.218e-03  -2.265e-07
#    2.908e-07  -2.265e-07   4.081e-11
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    8.18641E-15  +/-  4.97344E-02
#    2    2   apec       kT         keV      0.908056     +/-  5.67259E-02
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                3.00911E-05  +/-  6.38818E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 57.8594     using 16 bins.
#
# Test statistic : Chi-Squared                 57.8594     using 16 bins.
#  Null hypothesis probability of 1.2642e-07 with 13 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*(apec+apec)")
mo.apec.kT = 0.25
mo.apec_3.kT = 4.0
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              9.532124e+09     using 16 bins.
#
# Test statistic : Chi-Squared              9.532124e+09     using 16 bins.
#  Null hypothesis probability of 0.000000e+00 with 11 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              2.798622e+09     using 16 bins.
#
# Test statistic : Chi-Squared              2.798622e+09     using 16 bins.
#  Null hypothesis probability of 0.000000e+00 with 11 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              2.525584e+09     using 16 bins.
#
# Test statistic : Chi-Squared              2.525584e+09     using 16 bins.
#  Null hypothesis probability of 0.000000e+00 with 11 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm          6:kT        9:norm
# 144.863      11140.7      -1      0.865287      0.285489    0.00199506       8.12239   3.99049e-05
# 43.1039      26180.6      -2      0.782656      0.205367    0.00199772       4.58944   0.000110859
# 40.6977      7649.18      -2      0.685900      0.155289    0.00384279       7.34917   9.52882e-05
# 19.1336      13916.2      -2      0.772449      0.157863    0.00763454       10.4323   9.92797e-05
# 16.2324      1609.83      -2      0.773419      0.149902     0.0106308       13.2027   0.000100161
# 15.7859      2204.04      -2      0.792535      0.145782     0.0136066       9.50793   9.29830e-05
# 15.096       5714.04      -2      0.809804      0.142854     0.0167211       11.8301   0.000101338
# 14.9615      530.185      -2      0.819452      0.139457     0.0195589       10.1948   0.000101908
# 14.8013      616.769      -2      0.831503      0.137081     0.0227639       10.1678   0.000102860
# 14.6609      433.825      -2      0.842865      0.135035     0.0262128       9.25973   0.000103640
# 14.6007      137.288      -2      0.849474      0.132945     0.0290474       9.48663   0.000103927
# 14.5348      224.898      -2      0.857050      0.131250     0.0322148       8.93732   0.000104512
# 14.4737      208.171      -2      0.864765      0.129839     0.0355245       8.90237   0.000105087
# 14.418       179.062      -2      0.872134      0.128540     0.0390127       8.37851   0.000105719
# 14.3916      62.4395      -2      0.876815      0.127364     0.0417257       8.33546   0.000106030
# 14.3657      85.1979      -2      0.881377      0.126253     0.0445881       8.07541   0.000106462
# 14.3413      91.5973      -2      0.886068      0.125289     0.0475124       8.09864   0.000106801
# 14.3183      74.1197      -2      0.890553      0.124362     0.0505480       7.85515   0.000107293
# 14.2963      74.7126      -2      0.895084      0.123496     0.0537303       7.59763   0.000107814
# 14.276       84.7923      -2      0.899641      0.122766     0.0568886       7.62741   0.000108174
# 14.2611      59.4458      -3      0.918373      0.119567     0.0708588       6.67177   0.000110604
# 14.2132      110.444      -2      0.918535      0.119089     0.0735944       7.06016   0.000110099
# 14.2072      48.6432      -2      0.920677      0.118619     0.0759892       6.94973   0.000110464
# 14.2014      20.9187      -2      0.922927      0.118178     0.0784345       6.85310   0.000110764
# 14.1959      19.7606      -2      0.925177      0.117755     0.0809188       6.75611   0.000111066
# 14.1907      31.5117      -2      0.927414      0.117371     0.0833683       6.73035   0.000111313
# 14.1857      16.9083      -2      0.929565      0.116999     0.0858237       6.64802   0.000111616
# 14.181       16.8504      -2      0.931690      0.116645     0.0882920       6.56480   0.000111924
# 14.1765      16.1948      -2      0.933785      0.116308     0.0907659       6.48190   0.000112231
# 14.1741      15.4762      -3      0.943548      0.114754      0.102494       6.09237   0.000113685
# 14.1562      271.167      -3      0.948893      0.113782      0.110675       6.17750   0.000114028
# 14.1533      96.6436      -3      0.954001      0.112657      0.119713       5.87992   0.000115042
# 14.1512      147.466      -4      0.960595      0.111527      0.130924       5.85956   0.000115722
# 14.1452      125.123      -5      0.964785      0.110891      0.138773       5.74073   0.000116363
# 14.1452      53.9977      -6      0.963880      0.111144      0.136603       5.92458   0.000115760
# ============================================================
#  Variances and Principal Axes
#                  1        2        5        6        9
#  3.7768E-10| -0.0001   0.0025   0.0002   0.0000   1.0000
#  1.7809E-06| -0.0701   0.9904   0.1190  -0.0001  -0.0025
#  7.7239E-04|  0.8688   0.1192  -0.4806  -0.0019  -0.0001
#  5.6466E-02|  0.4900  -0.0697   0.8684   0.0301   0.0000
#  3.3202E+01| -0.0131   0.0024  -0.0270   0.9995  -0.0000
# ------------------------------------------------------------
#
# ============================================================
#   Covariance Matrix
#         1           2           3           4           5
#    1.986e-02  -2.898e-03   3.547e-02  -4.346e-01   2.798e-06
#   -2.898e-03   4.797e-04  -5.621e-03   7.983e-02  -4.930e-07
#    3.547e-02  -5.621e-03   6.697e-02  -8.946e-01   5.609e-06
#   -4.346e-01   7.983e-02  -8.946e-01   3.317e+01  -1.335e-04
#    2.798e-06  -4.930e-07   5.609e-06  -1.335e-04   1.024e-09
# ------------------------------------------------------------
#
# ========================================================================
# Model TBabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.963880     +/-  0.140909
#    2    2   apec       kT         keV      0.111144     +/-  2.19028E-02
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                0.136603     +/-  0.258779
#    6    3   apec       kT         keV      5.92458      +/-  5.75947
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.15760E-04  +/-  3.20039E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 14.1452     using 16 bins.
#
# Test statistic : Chi-Squared                 14.1452     using 16 bins.
#  Null hypothesis probability of 2.2506e-01 with 11 degrees of freedom

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 9.0637e-05 photons (2.4052e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
plx = 4.1476
d_kpc = 1/plx
F_x = 2.4052*10**-13

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 1.6723953310118652e+30

# %%
F_opt = 1.05*10**-5 * 10**(-0.4*12.93)
print('Optical Flux: ',F_opt)
print('F_x / F_opt: ', F_x/F_opt)
# Out:
# Optical Flux:  7.066254890985327e-11
# F_x / F_opt:  0.0034037832445987745
