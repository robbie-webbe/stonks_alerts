# %%
# %load_ext wurlitzer
import numpy as np
import glob
import os
import matplotlib.pyplot as plt
from astropy.io import fits
from xspec import *
plt.rcParams['figure.figsize'] = [9,6]

# %%
spec_file = sorted(glob.glob("*grpspec.fits"))
spec = Spectrum(spec_file[0])
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0932201101_PN156grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  7.862e-03 +/- 1.685e-03 (53.5 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-7
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 7423 sec
#  Using fit statistic: chi
#  Using Background File                0932201101_PN156spec_bkg.fits
#   Background Exposure Time: 7421 sec
#  Using Response (RMF) File            0932201101_PN156spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0932201101_PN156spec.arf

# %%
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.00001 0.05")
Plot("data")
#spec.ignore("**-0.2 12.0-**")

# %%
AllModels.clear()
mo1 = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared
#               3.949511e+11     using 7 bins.
#
# Test statistic : Chi-Squared              3.949511e+11     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 4 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 22.8378      0.740246     -2      0.177704       2.03960   2.18489e-06
# 12.2692      881750        0     0.0540084       1.41564   2.50933e-06
# 7.85726      216484       -1      0.581880      0.927413   2.12081e-06
# 7.7635       230825       -2      0.514612      0.910865   2.14723e-06
# 7.75162      9497.55      -1      0.613892      0.888274   2.17621e-06
# 7.74881      7554.12      -1      0.541352      0.896708   2.14309e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.4016E-13| -0.0000  -0.0000   1.0000
#  2.3436E-02| -0.2323  -0.9726  -0.0000
#  5.6188E-01|  0.9726  -0.2323   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    5.328e-01  -1.217e-01   1.913e-07
#   -1.217e-01   5.250e-02  -2.409e-09
#    1.913e-07  -2.409e-09   2.777e-13
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.541352     +/-  0.729943
#    2    2   bbody      kT         keV      0.896708     +/-  0.229123
#    3    2   bbody      norm                2.14309E-06  +/-  5.26996E-07
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    7.75     using 7 bins.
#
# Test statistic : Chi-Squared                    7.75     using 7 bins.
#  Null hypothesis probability of 1.01e-01 with 4 degrees of freedom

# %%
AllModels.clear()
mo1 = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              9.453467e+09     using 7 bins.
#
# Test statistic : Chi-Squared              9.453467e+09     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 4 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 6.52172      0.186138     -1       1.17235       4.41115   6.88439e-05
# 6.2515       13520.5      -2       1.27793       4.08478   8.03049e-05
# 6.24575      1775.01      -3       1.20011       4.31638   7.67504e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.8675E-10| -0.0000   0.0000   1.0000
#  2.3060E-01|  0.9880   0.1542   0.0000
#  1.3513E+01| -0.1542   0.9880  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    5.465e-01  -2.024e+00   3.564e-05
#   -2.024e+00   1.320e+01  -1.845e-04
#    3.564e-05  -1.845e-04   2.995e-09
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.20011      +/-  0.739286
#    2    2   bremss     kT         keV      4.31638      +/-  3.63281
#    3    2   bremss     norm                7.67504E-05  +/-  5.47283E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    6.25     using 7 bins.
#
# Test statistic : Chi-Squared                    6.25     using 7 bins.
#  Null hypothesis probability of 1.82e-01 with 4 degrees of freedom

# %%
AllModels.clear()
mo1 = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              1.766086e+09     using 7 bins.
#
# Test statistic : Chi-Squared              1.766086e+09     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 4 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 29.9102      5.07272      -3      0.294969       4.84944   2.63352e-05
# 14.3335      57286.4      -4       2.27002       4.74170   0.000150370
# 13.5766      14709.9      -5      0.480887       7.21348   8.62197e-05
# 8.46223      18391.7      -6       1.65777       3.39441   0.000185257
# 8.22552      9347.68      -7      0.882467       4.25231   0.000164333
# 8.01885      4592.64      -8       1.58072       2.23210   0.000228430
# 7.74218      3884.81      -9       1.04760       3.64171   0.000158822
# 7.05803      5864.31     -10       1.56440       3.01941   0.000220473
# 7.0519       2042.47      -3       1.13621       3.84706   0.000175369
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  1.5248E-09| -0.0001   0.0000   1.0000
#  2.5489E-01|  0.9424   0.3344   0.0001
#  4.2889E+00| -0.3344   0.9424  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    7.061e-01  -1.271e+00   8.767e-05
#   -1.271e+00   3.838e+00  -1.942e-04
#    8.767e-05  -1.942e-04   1.326e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.13621      +/-  0.840307
#    2    2   apec       kT         keV      3.84706      +/-  1.95901
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.75369E-04  +/-  1.15163E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    7.05     using 7 bins.
#
# Test statistic : Chi-Squared                    7.05     using 7 bins.
#  Null hypothesis probability of 1.33e-01 with 4 degrees of freedom

# %%
AllModels.clear()
mo1 = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              6.868622e+10     using 7 bins.
#
# Test statistic : Chi-Squared              6.868622e+10     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 4 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 12.6696      2.31641      -3       1.41772       2.18001   5.39429e-05
# 8.70057      53876.2      -4       1.91358       2.64188   0.000128433
# 8.01348      17974.6      -5       1.04264       1.96622   5.35503e-05
# 6.44629      32479.6      -1       1.30816       1.94710   6.98442e-05
# 6.20887      5979.26      -2       1.53005       2.26012   9.92848e-05
# 6.0187       7747.07      -3       1.59791       2.37488   0.000119839
# 6.00967      1542.6       -4       1.56458       2.35391   0.000117877
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  4.1614E-10| -0.0000  -0.0001   1.0000
#  1.1085E-01|  0.6588  -0.7523  -0.0000
#  1.7359E+00|  0.7523   0.6588   0.0001
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.031e+00   8.054e-01   1.371e-04
#    8.054e-01   8.161e-01   1.272e-04
#    1.371e-04   1.272e-04   2.081e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.56458      +/-  1.01518
#    2    2   powerlaw   PhoIndex            2.35391      +/-  0.903401
#    3    2   powerlaw   norm                1.17877E-04  +/-  1.44250E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    6.01     using 7 bins.
#
# Test statistic : Chi-Squared                    6.01     using 7 bins.
#  Null hypothesis probability of 1.98e-01 with 4 degrees of freedom

# %%
AllModels.calcFlux("0.2 12.0")
# Out:
#  Model Flux 3.4191e-05 photons (1.9148e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
#plx = 1.4843
d_kpc = 8
F_x = 3.9546*10**-13

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 3.0273596549074945e+33

# %%
import numpy as np
print(d_kpc)
print(np.log10(L_x))
# Out:
# 8
# 33.48106401886314

# %%
F_opt = 1.05*10**-5 * 10**(-0.4*20.7)
print('Optical Flux: ',F_opt)
print('F_x / F_opt: ', np.log10(F_x/F_opt))
# Out:
# Optical Flux:  5.510478332622621e-14
# F_x / F_opt:  0.8559132629538776
