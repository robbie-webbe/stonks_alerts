# %%
# %load_ext wurlitzer
import glob
import os
import numpy as np
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12,8]

Fit.statMethod = "chi"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4
os.chdir('other_obs')

# %%
spec = Spectrum('0886110501_M161grpspec.fits')

Plot.device="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.000001 0.001")
Plot("data")
#spec.ignore("**-0.2 12.0-**")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0886110501_M161grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  9.498e-04 +/- 3.184e-04 (39.1 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-6
#   Telescope: XMM Instrument: EMOS1  Channel Type: PI
#   Exposure Time: 2.635e+04 sec
#  Using fit statistic: chi
#  Using Background File                0886110501_M161spec_bkg.fits
#   Background Exposure Time: 2.635e+04 sec
#  Using Response (RMF) File            0886110501_M161spec.rmf for Source 1

# %%
AllModels.clear()
mo = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              3.278422e+08     using 6 bins.
#
# Test statistic : Chi-Squared              3.278422e+08     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 5.65952      0.177444      0      0.481417       3.00300   0.000136073
# 5.12464      1446.79       0     0.0162195       2.94212   0.000128693
# 3.57254      2218.64      -1    0.00564384       1.93026   7.73660e-05
# 2.81403      6086.02      -2     0.0759634       1.25724   6.54844e-05
# 2.65244      1534.23      -3     0.0226208       1.44909   6.86464e-05
# 2.62262      2586.89      -4     0.0280266       1.44110   7.22545e-05
# 2.6226       10.7998       0     0.0201305       1.44226   7.21912e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  4.9482E-10| -0.0000  -0.0000   1.0000
#  1.1804E-01| -0.7520  -0.6592  -0.0000
#  2.8295E-01|  0.6592  -0.7520  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.897e-01  -8.175e-02   6.409e-09
#   -8.175e-02   2.113e-01   8.646e-06
#    6.409e-09   8.646e-06   9.196e-10
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    2.01305E-02  +/-  0.435547
#    2    2   bbody      kT         keV      1.44226      +/-  0.459660
#    3    2   bbody      norm                7.21912E-05  +/-  3.03254E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  2.6226     using 6 bins.
#
# Test statistic : Chi-Squared                  2.6226     using 6 bins.
#  Null hypothesis probability of 4.5354e-01 with 3 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              4.356850e+06     using 6 bins.
#
# Test statistic : Chi-Squared              4.356850e+06     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 3.20263      0.0738466    -1      0.531306       13.8762   0.000924280
# 3.03372      691.781      -2      0.248848       51.8019   0.000890381
# 2.2039       758.447      -3      0.359435       198.647    0.00159634
# 2.06365      231.511      -1      0.314994       198.105    0.00172156
# 2.05542      42.9017      -1      0.334346       198.351    0.00178203
# 2.05541      6.60122       0      0.332768       198.465    0.00178217
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  2.8395E-07| -0.0009  -0.0000   1.0000
#  1.2213E-01|  1.0000   0.0001   0.0009
#  6.3091E+06| -0.0001   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.231e-01  -7.980e+02  -1.845e-03
#   -7.980e+02   6.309e+06   1.547e+01
#   -1.845e-03   1.547e+01   3.833e-05
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.332768     +/-  0.472302
#    2    2   bremss     kT         keV      198.465      +/-  2511.78
#    3    2   bremss     norm                1.78217E-03  +/-  6.19142E-03
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  2.0554     using 6 bins.
#
# Test statistic : Chi-Squared                  2.0554     using 6 bins.
#  Null hypothesis probability of 5.6099e-01 with 3 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared                654109.3     using 6 bins.
#
# Test statistic : Chi-Squared                654109.3     using 6 bins.
#  Null hypothesis probability of 0.0e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 7.19618      0.377013     -1      0.803593       1.56760    0.00202329
# 5.94392      266.863       0      0.664071       1.86630    0.00257748
# 5.11983      139.546       0      0.600612       2.31089    0.00288735
# 4.03013      91.0873       0      0.549382       3.26443    0.00305922
# 3.36361      68.4998      -1      0.269242       6.89616    0.00241481
# 2.45622      62.496       -2      0.359850       13.5319    0.00283249
# 2.33342      62.9104      -1      0.408464       17.0354    0.00328594
# 2.26344      47.0153      -1      0.273647       45.1219    0.00335135
# 2.11508      1.67521      -1      0.352772       60.2304    0.00374331
# 2.11155      10.7465       0      0.351693       62.5742    0.00377904
# 2.10932      9.0776        0      0.350967       63.7384    0.00381158
# 2.10892      4.43228       0      0.350750       63.9063    0.00383811
# 2.10879      1.77386       0      0.351165       63.9642    0.00383811
# 2.10871      1.35802       0      0.351524       63.9925    0.00383824
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  1.3282E-06| -0.0021  -0.0000   1.0000
#  1.2380E-01|  1.0000   0.0007   0.0021
#  2.4923E+05| -0.0007   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.308e-01  -1.633e+02  -1.722e-03
#   -1.633e+02   2.492e+05   3.017e+00
#   -1.722e-03   3.017e+00   3.838e-05
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.351524     +/-  0.480427
#    2    2   apec       kT         keV      63.9925      +/-  499.231
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                3.83824E-03  +/-  6.19500E-03
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  2.1087     using 6 bins.
#
# Test statistic : Chi-Squared                  2.1087     using 6 bins.
#  Null hypothesis probability of 5.5015e-01 with 3 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              4.237349e+07     using 6 bins.
#
# Test statistic : Chi-Squared              4.237349e+07     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 3.20493      0.384954     -3      0.136965      0.805539   0.000227715
# 3.1595       3127.39      -3      0.480827       1.38429   0.000528109
# 2.80276      1424.12      -4      0.202609      0.752852   0.000243918
# 2.77275      2234.34      -5      0.430071       1.30558   0.000509042
# 2.13538      1317.36      -1      0.240079       1.12470   0.000520523
# 2.04153      385.698      -2      0.343982       1.17348   0.000557748
# 2.04056      25.8239      -2      0.273167       1.10452   0.000492718
# 2.03746      31.8521      -3      0.336054       1.15713   0.000541561
# 2.0319       20.009       -1      0.303382       1.14166   0.000526459
# 2.0305       19.0363      -2      0.309465       1.13138   0.000520516
# 2.03045      0.949504     -2      0.301530       1.12352   0.000513686
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  2.4319E-08| -0.0003  -0.0006   1.0000
#  8.4370E-02|  0.8296  -0.5584  -0.0001
#  6.8144E-01|  0.5584   0.8296   0.0006
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.705e-01   2.766e-01   2.381e-04
#    2.766e-01   4.953e-01   3.727e-04
#    2.381e-04   3.727e-04   3.125e-07
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.301530     +/-  0.520116
#    2    2   powerlaw   PhoIndex            1.12352      +/-  0.703769
#    3    2   powerlaw   norm                5.13686E-04  +/-  5.59061E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  2.0305     using 6 bins.
#
# Test statistic : Chi-Squared                  2.0305     using 6 bins.
#  Null hypothesis probability of 5.6611e-01 with 3 degrees of freedom

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux  0.001069 photons (7.1393e-12 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
#plx = 1.4843
d_kpc = 8
F_x = 7*10**-12

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 5.358700648448e+34

# %%
F_opt = 1.05*10**-5 * 10**(-0.4*20.78)
print('Optical Flux: ',F_opt)
print('F_x / F_opt: ', F_x/F_opt)
# Out:
# Optical Flux:  5.119049146085544e-14
# F_x / F_opt:  136.74414525503803
