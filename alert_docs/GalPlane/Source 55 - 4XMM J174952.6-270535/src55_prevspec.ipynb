# %%
# %load_ext wurlitzer
import glob
import os
import numpy as np
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12,8]

Fit.statMethod = "chi"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4
os.chdir('other_obs')

# %%
spec = Spectrum('0932190701_MOS70grpspec.fits')

Plot.device="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.00001 0.005")
Plot("data")
#spec.ignore("**-0.2 12.0-**")
# Out:
# Warning: RMF FILTER keyword (UNDEFINED) is not consistent with that in spectrum (Medium)
#
# 1 spectrum  in use
#
# Spectral Data File: 0932190701_MOS70grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  4.290e-03 +/- 7.619e-04 (68.6 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-7
#   Telescope: XMM Instrument: EPIC  Channel Type: PI
#   Exposure Time: 1.151e+04 sec
#  Using fit statistic: chi
#  Using Background File                0932190701_MOS70spec_bkg.fits
#   Background Exposure Time: 1.152e+04 sec
#  Using Response (RMF) File            0932190701_MOS70spec.rmf for Source 1

# %%
AllModels.clear()
mo = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              5.659515e+11     using 7 bins.
#
# Test statistic : Chi-Squared              5.659515e+11     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 4 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 7.53248      0.50082      -3      0.117183       3.48838   6.33744e-06
# 6.81588      267999       -3     0.0305317       2.39285   2.61416e-06
# 3.92039      819139       -4    0.00942573       2.40885   3.47276e-06
# 3.72217      299900       -5    0.00264943       2.36058   3.38236e-06
# 3.66029      281960       -6    0.00112124       2.34274   3.34822e-06
# 3.64132      275518       -7   0.000379247       2.33794   3.33893e-06
# 3.63241      273686       -8   1.26680e-05       2.33562   3.33428e-06
# 3.62952      272909       -9   1.27913e-06       2.33457   3.33225e-06
# 3.62919      272561      -10   5.67928e-07       2.33443   3.33194e-06
# 3.62907      272538       -4   2.12408e-07       2.33441   3.33195e-06
# 3.62903      272500       -4   3.46552e-08       2.33439   3.33190e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  4.7373E-13| -0.0000  -0.0000   1.0000
#  1.1326E-01|  0.9785   0.2061   0.0000
#  1.4516E+00| -0.2061   0.9785   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.701e-01  -2.699e-01  -5.855e-07
#   -2.699e-01   1.395e+00   3.659e-06
#   -5.855e-07   3.659e-06   1.020e-11
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    3.46552E-08  +/-  0.412411
#    2    2   bbody      kT         keV      2.33439      +/-  1.18100
#    3    2   bbody      norm                3.33190E-06  +/-  3.19379E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  3.6290     using 7 bins.
#
# Test statistic : Chi-Squared                  3.6290     using 7 bins.
#  Null hypothesis probability of 4.5853e-01 with 4 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              3.451188e+10     using 7 bins.
#
# Test statistic : Chi-Squared              3.451188e+10     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 4 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 7.47119      0.0556362     0      0.990528       11.7848   2.50734e-05
# 6.64042      12162.3       0      0.876751       31.4249   2.51304e-05
# 5.77854      33237.8      -1      0.537816       194.135   3.39729e-05
# 5.49672      23813.1      -1      0.553210       198.082   3.87580e-05
# 5.4903       2628.62       0      0.561606       198.459   3.88786e-05
# 5.48649      2044.16       0      0.568348       198.702   3.90152e-05
# 5.48405      1852.31       0      0.573925       198.878   3.91521e-05
# 5.48241      1853.23       0      0.578649       199.013   3.92812e-05
# 5.48132      1939.97       0      0.582695       199.122   3.94005e-05
# 5.48056      2070.82       0      0.586231       199.210   3.95069e-05
# 5.48008      2200.73       0      0.589298       199.284   3.96034e-05
# 5.47973      2339.74       0      0.592020       199.346   3.96877e-05
# 5.4796       2456.89       0      0.594403       199.360   3.97630e-05
# 5.47954      2582.74       0      0.596528       199.362   3.98283e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  5.7186E-11| -0.0000  -0.0000   1.0000
#  1.1723E-01|  1.0000   0.0001   0.0000
#  9.0591E+06| -0.0001   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.732e-01  -1.189e+03  -6.584e-05
#   -1.189e+03   9.059e+06   5.213e-01
#   -6.584e-05   5.213e-01   3.011e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.596528     +/-  0.522678
#    2    2   bremss     kT         keV      199.362      +/-  3009.84
#    3    2   bremss     norm                3.98283E-05  +/-  1.73516E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  5.4795     using 7 bins.
#
# Test statistic : Chi-Squared                  5.4795     using 7 bins.
#  Null hypothesis probability of 2.4153e-01 with 4 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              8.103645e+09     using 7 bins.
#
# Test statistic : Chi-Squared              8.103645e+09     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 4 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 17.3232      1.70875      -1      0.944334       1.71516   3.44416e-05
# 13.8878      40969.6       0      0.783921       2.16735   4.46369e-05
# 11.0983      20164.2       0      0.701566       3.32530   4.98260e-05
# 8.73165      13080.9       0      0.642046       5.91198   5.18872e-05
# 7.45308      10386         0      0.589418       11.1924   5.34451e-05
# 6.78549      10142.1       0      0.539825       22.2791   5.70884e-05
# 6.50636      11788.4       0      0.528070       28.5605   6.08316e-05
# 6.34181      8443.68       0      0.526263       33.6689   6.38742e-05
# 6.32735      6327.19      -1      0.489274       58.0487   8.27666e-05
# 5.96601      12862.1       0      0.518654       63.9113   8.15266e-05
# 5.91722      5010.76       0      0.537304       63.9760   8.16273e-05
# 5.89268      3637.39       0      0.551879       63.9910   8.19512e-05
# 5.87874      2989.35       0      0.563637       63.9982   8.23665e-05
# 5.87028      2710.42       0      0.573384       63.9996   8.28055e-05
# 5.8649       2624.35       0      0.581644       64.0000   8.32330e-05
# 5.86141      2633.8        0      0.588758       64.0000   8.36329e-05
# 5.85911      2688.11       0      0.594956       64.0000   8.39984e-05
# 5.8576       2760.44       0      0.600398       64.0000   8.43282e-05
# 5.85661      2837.04       0      0.605203       64.0000   8.46237e-05
# 5.85598      2911.14       0      0.609460       64.0000   8.48873e-05
# 5.85559      2979.69       0      0.613242       64.0000   8.51219e-05
# 5.85537      3041.61       0      0.616607       64.0000   8.53305e-05
# 5.85527      3096.79       0      0.619604       64.0000   8.55158e-05
# 5.85525      3145.61       0      0.622276       64.0000   8.56804e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  2.5868E-10| -0.0000  -0.0000   1.0000
#  1.1824E-01|  1.0000   0.0004   0.0000
#  1.2153E+06| -0.0004   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.693e-01  -4.285e+02  -5.881e-05
#   -4.285e+02   1.215e+06   1.827e-01
#   -5.881e-05   1.827e-01   2.799e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.622276     +/-  0.518966
#    2    2   apec       kT         keV      64.0000      +/-  1102.39
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                8.56804E-05  +/-  1.67290E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  5.8552     using 7 bins.
#
# Test statistic : Chi-Squared                  5.8552     using 7 bins.
#  Null hypothesis probability of 2.1022e-01 with 4 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.748226e+11     using 7 bins.
#
# Test statistic : Chi-Squared              1.748226e+11     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 4 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 4.61966      0.42123      -2      0.430963      0.189591   5.09192e-06
# 3.54521      348175       -2      0.130667     0.0887497   3.00823e-06
# 2.28271      464461       -3     0.0268125      0.101782   3.41197e-06
# 2.23463      80798.9      -4     0.0144061      0.130521   3.58526e-06
# 2.23447      225.149      -5     0.0161419      0.130314   3.58951e-06
# 2.23447      20.0508      -6     0.0160649      0.130168   3.58876e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  4.2555E-13| -0.0000  -0.0000   1.0000
#  1.8376E-02|  0.9189  -0.3946   0.0000
#  3.1679E-01|  0.3946   0.9189   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    6.484e-02   1.082e-01   5.641e-07
#    1.082e-01   2.703e-01   1.265e-06
#    5.641e-07   1.265e-06   6.503e-12
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.60649E-02  +/-  0.254644
#    2    2   powerlaw   PhoIndex            0.130168     +/-  0.519928
#    3    2   powerlaw   norm                3.58876E-06  +/-  2.55016E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  2.2345     using 7 bins.
#
# Test statistic : Chi-Squared                  2.2345     using 7 bins.
#  Null hypothesis probability of 6.9272e-01 with 4 degrees of freedom

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 3.4177e-05 photons (3.1964e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
#plx = 1.4843
d_kpc = 8
F_x = 3.2*10**-13

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 2.4496917250048004e+33

# %%
F_opt = 1.05*10**-5 * 10**(-0.4*20.78)
print('Optical Flux: ',F_opt)
print('F_x / F_opt: ', F_x/F_opt)
# Out:
# Optical Flux:  5.119049146085544e-14
# F_x / F_opt:  6.251160925944597
