# %%
# %load_ext wurlitzer
import glob
import os
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12,8]
os.chdir('pps/')

Fit.statMethod = "chi"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4

# %%
import numpy as np
out_arr = np.full((4,19),-np.inf,dtype=object)

# %%
spec_fnames = glob.glob('P*PNS*SRSPEC*.FTZ')

spec = Spectrum(spec_fnames[0])
Plot.device="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.0001 0.02")
Plot("data")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: P0916800801PNS003SRSPEC0003.FTZ  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  2.029e-02 +/- 1.832e-03 (82.8 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-8
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 7345 sec
#  Using fit statistic: chi
#  Using Background File                P0916800801PNS003BGSPEC0003.FTZ
#   Background Exposure Time: 7345 sec
#  Using Response (RMF) File            epn_e3_ff20_sdY2.rmf for Source 1
#  Using Auxiliary Response (ARF) File  P0916800801PNS003SRCARF0003.FTZ

# %%
#spec.ignore("**-0.2 12.0-**")
mo = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              1.014891e+12     using 8 bins.
#
# Test statistic : Chi-Squared              1.014891e+12     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 5 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 77.3218      1.6615        0      0.165928       3.09591   5.43687e-06
# 72.255       542766        0     0.0524606       2.92069   5.27640e-06
# 64.1031      550146       -1    0.00101983       2.03901   2.50848e-06
# 40.1943      2.38212e+06  -2   8.67939e-05      0.526674   6.68188e-07
# 16.8539      8.73169e+06  -3   1.39892e-07      0.920260   1.46947e-06
# 5.18121      5.85465e+06  -4   3.93387e-08      0.964748   2.19050e-06
# 5.05931      645686       -5   1.64434e-08      0.960604   2.20875e-06
# 5.05272      419347       -6   5.41000e-09      0.959840   2.20746e-06
# 5.05148      413339       -7   2.66406e-09      0.959696   2.20723e-06
# 5.05125      412123       -8   1.29223e-09      0.959671   2.20719e-06
# 5.05112      411896       -9   6.06544e-10      0.959653   2.20716e-06
# 5.05111      411794       -5   2.63743e-10      0.959655   2.20717e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  4.2721E-14| -0.0000  -0.0000   1.0000
#  2.8597E-03| -0.8506  -0.5258  -0.0000
#  1.3297E-02|  0.5258  -0.8506  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    5.746e-03  -4.668e-03   7.989e-12
#   -4.668e-03   1.041e-02   1.867e-08
#    7.989e-12   1.867e-08   9.541e-14
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    2.63743E-10  +/-  7.58000E-02
#    2    2   bbody      kT         keV      0.959655     +/-  0.102033
#    3    2   bbody      norm                2.20717E-06  +/-  3.08891E-07
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  5.0511     using 8 bins.
#
# Test statistic : Chi-Squared                  5.0511     using 8 bins.
#  Null hypothesis probability of 4.0967e-01 with 5 degrees of freedom

# %%
Fit.error("1")
Fit.error("2")

out_arr[0,0] = 'bbody'
out_arr[0,1:4] = mo.TBabs.nH.values[0], mo.TBabs.nH.values[0] - mo.TBabs.nH.error[0], mo.TBabs.nH.error[1] - mo.TBabs.nH.values[0]
out_arr[0,4:7] = mo.bbody.kT.values[0], mo.bbody.kT.values[0] - mo.bbody.kT.error[0], mo.bbody.kT.error[1] - mo.bbody.kT.values[0]
out_arr[0,-2:] = Fit.dof, Fit.statistic / Fit.dof
# Out:
#  Parameter   Confidence Range (2.706)
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 4.92437      1.25765       2   3.02448e-12      0.938594   2.19958e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  4.0449E-14| -0.0000  -0.0000   1.0000
#  2.6092E-03| -0.8510  -0.5251  -0.0000
#  1.2394E-02|  0.5251  -0.8510  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    5.307e-03  -4.373e-03   3.281e-11
#   -4.373e-03   9.696e-03   1.761e-08
#    3.281e-11   1.761e-08   9.152e-14
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    3.02448E-12  +/-  7.28521E-02
#    2    2   bbody      kT         keV      0.938594     +/-  9.84678E-02
#    3    2   bbody      norm                2.19958E-06  +/-  3.02525E-07
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  4.9244     using 8 bins.
#
# Test statistic : Chi-Squared                  4.9244     using 8 bins.
#  Null hypothesis probability of 4.2518e-01 with 5 degrees of freedom
# ***Warning: New best fit found, fit parameters will be set to new values.
# ***Warning: Parameter pegged at hard limit: 0
#      1            0     0.116879    (-9.7417e-13,0.116879)
#  Parameter   Confidence Range (2.706)
#      2     0.781952      1.08691    (-0.156642,0.148311)

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.603413e+11     using 8 bins.
#
# Test statistic : Chi-Squared              1.603413e+11     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 5 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 34.1025      8.48818      -3      0.375274       1.03306   1.37243e-05
# 17.6778      625343       -4      0.276932       1.94802   3.61506e-05
# 5.95624      36582.8      -5      0.308971       1.34205   3.48545e-05
# 2.41988      164220       -6      0.388628       1.60778   4.10290e-05
# 2.3984       2400.76      -7      0.398951       1.64426   4.26074e-05
# 2.39833      585.044      -8      0.398406       1.64275   4.25651e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.4882E-11| -0.0000  -0.0000   1.0000
#  4.3102E-03|  0.9304  -0.3666   0.0000
#  7.9780E-02|  0.3666   0.9304   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.445e-02   2.574e-02   1.402e-06
#    2.574e-02   6.964e-02   3.178e-06
#    1.402e-06   3.178e-06   1.704e-10
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.398406     +/-  0.120211
#    2    2   powerlaw   PhoIndex            1.64275      +/-  0.263892
#    3    2   powerlaw   norm                4.25651E-05  +/-  1.30551E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  2.3983     using 8 bins.
#
# Test statistic : Chi-Squared                  2.3983     using 8 bins.
#  Null hypothesis probability of 7.9172e-01 with 5 degrees of freedom

# %%
Fit.error("1")
Fit.error("2")

out_arr[1,0] = 'powerlaw'
out_arr[1,1:4] = mo.TBabs.nH.values[0], mo.TBabs.nH.values[0] - mo.TBabs.nH.error[0], mo.TBabs.nH.error[1] - mo.TBabs.nH.values[0]
out_arr[1,14:17] = mo.powerlaw.PhoIndex.values[0], mo.powerlaw.PhoIndex.values[0] - mo.powerlaw.PhoIndex.error[0], mo.powerlaw.PhoIndex.error[1] - mo.powerlaw.PhoIndex.values[0]
out_arr[1,-2:] = Fit.dof, Fit.statistic / Fit.dof
# Out:
#  Parameter   Confidence Range (2.706)
#      1     0.227119     0.637812    (-0.17131,0.239383)
#  Parameter   Confidence Range (2.706)
#      2       1.2451      2.11309    (-0.397718,0.470278)

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.995794e+10     using 8 bins.
#
# Test statistic : Chi-Squared              1.995794e+10     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 5 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 3.34116      4.78569      -1      0.346076       7.12910   5.56363e-05
# 2.26139      57597.9      -2      0.339851       9.29337   5.00839e-05
# 2.20032      12430.3      -3      0.339466       10.1691   5.07525e-05
# 2.20007      889.671      -4      0.339694       10.2068   5.08213e-05
# 2.20007      0.0329022    -5      0.339662       10.2106   5.08195e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  2.1112E-11| -0.0001  -0.0000   1.0000
#  4.6947E-03|  1.0000   0.0082   0.0001
#  5.2849E+01| -0.0082   1.0000  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    8.290e-03  -4.359e-01   4.571e-07
#   -4.359e-01   5.285e+01  -2.398e-05
#    4.571e-07  -2.398e-05   4.631e-11
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.339662     +/-  9.10499E-02
#    2    2   bremss     kT         keV      10.2106      +/-  7.26952
#    3    2   bremss     norm                5.08195E-05  +/-  6.80526E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  2.2001     using 8 bins.
#
# Test statistic : Chi-Squared                  2.2001     using 8 bins.
#  Null hypothesis probability of 8.2083e-01 with 5 degrees of freedom

# %%
Fit.error("1")
Fit.error("2")

out_arr[3,0] = 'bremss'
out_arr[3,1:4] = mo.TBabs.nH.values[0], mo.TBabs.nH.values[0] - mo.TBabs.nH.error[0], mo.TBabs.nH.error[1] - mo.TBabs.nH.values[0]
out_arr[3,4:7] = mo.bremss.kT.values[0], mo.bremss.kT.values[0] - mo.bremss.kT.error[0], mo.bremss.kT.error[1] - mo.bremss.kT.values[0]
out_arr[3,-2:] = Fit.dof, Fit.statistic / Fit.dof
# Out:
#  Parameter   Confidence Range (2.706)
#      1      0.21061     0.522982    (-0.129052,0.18332)
#  Parameter   Confidence Range (2.706)
#      2      4.25375       102.35    (-5.95669,92.1393)

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              4.283112e+09     using 8 bins.
#
# Test statistic : Chi-Squared              4.283112e+09     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 5 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 40.5965      7.42941      -3       1.50966      0.805344   0.000262880
# 40.0896      21810.7      -2       1.39266       1.21415   0.000168100
# 17.5514      43525.4      -3      0.895090       2.01553   0.000182687
# 9.01857      16563.8      -1      0.578676       3.03117   0.000173017
# 4.67464      14450.6      -2      0.328501       4.90253   0.000127476
# 2.50303      353.294      -3      0.352465       6.61344   0.000134509
# 2.37951      260.13       -4      0.350206       7.50535   0.000135065
# 2.37649      109.523      -5      0.349270       7.70226   0.000135144
# 2.37648      5.55797      -6      0.349475       7.69059   0.000135166
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  1.4951E-10| -0.0001  -0.0000   1.0000
#  4.9560E-03|  0.9999   0.0131   0.0001
#  2.2998E+01| -0.0131   0.9999  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    8.886e-03  -3.006e-01   1.025e-06
#   -3.006e-01   2.299e+01  -2.281e-05
#    1.025e-06  -2.281e-05   2.787e-10
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.349475     +/-  9.42659E-02
#    2    2   apec       kT         keV      7.69059      +/-  4.79523
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.35166E-04  +/-  1.66934E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  2.3765     using 8 bins.
#
# Test statistic : Chi-Squared                  2.3765     using 8 bins.
#  Null hypothesis probability of 7.9497e-01 with 5 degrees of freedom

# %%
Fit.error("1")
Fit.error("2")

out_arr[2,0] = 'apec'
out_arr[2,1:4] = mo.TBabs.nH.values[0], mo.TBabs.nH.values[0] - mo.TBabs.nH.error[0], mo.TBabs.nH.error[1] - mo.TBabs.nH.values[0]
out_arr[2,13] = mo.apec.Abundanc.values[0]
out_arr[2,4:7] = mo.apec.kT.values[0], mo.apec.kT.values[0] - mo.apec.kT.error[0], mo.apec.kT.error[1] - mo.apec.kT.values[0]
out_arr[2,-2:] = Fit.dof, Fit.statistic / Fit.dof
# Out:
#  Parameter   Confidence Range (2.706)
#      1     0.209458     0.565137    (-0.140019,0.21566)
#  Parameter   Confidence Range (2.706)
# ***Warning: Parameter pegged at hard limit: 64
#      2      3.91346            0    (-3.77713,-7.69058)

# %%
np.savetxt('../spec50_output.csv',out_arr,fmt=['%s','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.2f','%.1f','%.2f','%.2f','%.2f','%i','%.2f'],delimiter=',')

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 4.6985e-05 photons (2.3701e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
plx = 2.7476
d_kpc = 1/plx
F_x = 2.5444*10**-13

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 4.0314367861415656e+30

# %%
import numpy as np
print(d_kpc)
print(np.log10(L_x))
# Out:
# 0.36395399621487845
# 30.60545985435114

# %%
F_opt = 1.05*10**-5 * 10**(-0.4*18.6553)
print('Optical Flux: ',F_opt)
print('F_x / F_opt: ', np.log10(F_x/F_opt))
# Out:
# Optical Flux:  3.6230080505907564e-13
# F_x / F_opt:  -0.15348391216544277

# %%
AllModels.clear()
mo = Model("tbabs*(apec+apec)")
mo.apec.kT = 0.5
mo.apec_3.kT = 4
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.713479e+10     using 8 bins.
#
# Test statistic : Chi-Squared              1.713479e+10     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              9.802874e+09     using 8 bins.
#
# Test statistic : Chi-Squared              9.802874e+09     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              5.636731e+09     using 8 bins.
#
# Test statistic : Chi-Squared              5.636731e+09     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm          6:kT        9:norm
# 2.89018      7088.47      -2      0.810267      0.305585   8.51361e-05       4.50317   0.000180702
# 2.55858      6239.06      -3      0.817787      0.245652   0.000150049       4.69854   0.000168124
# 2.23824      3962.3       -4      0.995587      0.291820   0.000263001       4.39888   0.000177915
# 2.06248      1041.54      -2      0.930106      0.251631   0.000290193       4.52475   0.000175071
# 2.03259      513.529      -3      0.922762      0.259053   0.000274815       4.58447   0.000173277
# 2.03223      55.5816      -2      0.921616      0.256792   0.000279551       4.55991   0.000173636
# 2.03214      12.0342      -1      0.921969      0.257174   0.000279332       4.56903   0.000173555
# ============================================================
#  Variances and Principal Axes
#                  1        2        5        6        9
#  3.4113E-10| -0.0001   0.0003   0.0798   0.0000   0.9968
#  6.6410E-09| -0.0013   0.0027   0.9968  -0.0000  -0.0798
#  2.8384E-02|  0.0832   0.9936  -0.0026  -0.0760  -0.0001
#  6.3706E-01|  0.9283  -0.0495   0.0013   0.3685   0.0000
#  2.0855E+01| -0.3624   0.1012  -0.0007   0.9265  -0.0000
# ------------------------------------------------------------
#
# ============================================================
#   Covariance Matrix
#         1           2           3           4           5
#    3.288e+00  -7.921e-01   6.157e-03  -6.784e+00   2.135e-04
#   -7.921e-01   2.434e-01  -1.618e-03   1.943e+00  -5.761e-05
#    6.157e-03  -1.618e-03   1.188e-05  -1.344e-02   4.146e-07
#   -6.784e+00   1.943e+00  -1.344e-02   1.799e+01  -4.973e-04
#    2.135e-04  -5.761e-05   4.146e-07  -4.973e-04   1.516e-08
# ------------------------------------------------------------
#
# ========================================================================
# Model TBabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.921969     +/-  1.81321
#    2    2   apec       kT         keV      0.257174     +/-  0.493309
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                2.79332E-04  +/-  3.44729E-03
#    6    3   apec       kT         keV      4.56903      +/-  4.24142
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.73555E-04  +/-  1.23137E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  2.0321     using 8 bins.
#
# Test statistic : Chi-Squared                  2.0321     using 8 bins.
#  Null hypothesis probability of 5.6576e-01 with 3 degrees of freedom
