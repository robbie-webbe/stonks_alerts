# %%
# %load_ext wurlitzer
import glob
import os
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12,8]
os.chdir('pps/')

Fit.statMethod = "chi"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4

# %%
spec_fnames = glob.glob('P*PNS*SRSPEC*.FTZ')

spec = Spectrum(spec_fnames[0])
Plot.device="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.00001 0.005")
Plot("data")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: P0886080201PNS003SRSPEC0008.FTZ  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  8.845e-03 +/- 8.127e-04 (77.3 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-10
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 1.765e+04 sec
#  Using fit statistic: chi
#  Using Background File                P0886080201PNS003BGSPEC0008.FTZ
#   Background Exposure Time: 1.765e+04 sec
#  Using Response (RMF) File            epn_e3_ff20_sdY3.rmf for Source 1
#  Using Auxiliary Response (ARF) File  P0886080201PNS003SRCARF0008.FTZ

# %%
spec.ignore("**-0.2 12.0-**")
mo = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
#       No channels ignored (no channels in specified range)
#      1 channels (10) ignored in spectrum #     1
#
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross s
# ection setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              2.699007e+12     using 9 bins.
#
# Test statistic : Chi-Squared              2.699007e+12     using 9 bins.
#  Null hypothesis probability of 0.000000e+00 with 6 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 29.0269      2.16747      -1     0.0830566       3.00871   4.38461e-06
# 20.9658      1.21227e+06  -1      0.104013       2.45249   3.88290e-06
# 17.8525      300781       -1      0.211916       2.14174   3.03307e-06
# 14.1292      146764       -1      0.317016       1.81116   2.40836e-06
# 12.6979      234053       -2      0.691393       1.11519   1.28411e-06
# 8.48259      4.05729e+06  -3      0.916134       1.16572   1.68479e-06
# 8.42025      341433       -4      0.810408       1.18852   1.69631e-06
# 8.41362      7470.07      -5      0.845740       1.18261   1.70334e-06
# 8.41318      938.722      -6      0.835522       1.18483   1.70181e-06
# 8.41314      64.1141      -7      0.838417       1.18432   1.70239e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  2.5078E-14| -0.0000  -0.0000   1.0000
#  1.2755E-02| -0.3017  -0.9534  -0.0000
#  1.9151E-01|  0.9534  -0.3017   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.752e-01  -5.141e-02   7.869e-09
#   -5.141e-02   2.902e-02   1.597e-08
#    7.869e-09   1.597e-08   4.939e-14
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.838417     +/-  0.418623
#    2    2   bbody      kT         keV      1.18432      +/-  0.170357
#    3    2   bbody      norm                1.70239E-06  +/-  2.22236E-07
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  8.4131     using 9 bins.
#
# Test statistic : Chi-Squared                  8.4131     using 9 bins.
#  Null hypothesis probability of 2.0937e-01 with 6 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              6.224248e+11     using 9 bins.
#
# Test statistic : Chi-Squared              6.224248e+11     using 9 bins.
#  Null hypothesis probability of 0.000000e+00 with 6 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 7.26773      2.04571      -2       1.55518       1.32147   2.09408e-05
# 7.04282      172756       -3       2.00595       1.64557   3.36031e-05
# 5.45971      120093       -4       2.00445       1.65311   3.82698e-05
# 5.45957      1009.61      -5       2.00760       1.65425   3.83866e-05
# 5.45957      4.11925      -6       2.00710       1.65402   3.83720e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.2441E-11| -0.0000  -0.0000   1.0000
#  3.6337E-02|  0.5278  -0.8494  -0.0000
#  7.0267E-01|  0.8494   0.5278   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    5.171e-01   2.987e-01   1.794e-05
#    2.987e-01   2.219e-01   1.251e-05
#    1.794e-05   1.251e-05   7.283e-10
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    2.00710      +/-  0.719084
#    2    2   powerlaw   PhoIndex            1.65402      +/-  0.471092
#    3    2   powerlaw   norm                3.83720E-05  +/-  2.69866E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  5.4596     using 9 bins.
#
# Test statistic : Chi-Squared                  5.4596     using 9 bins.
#  Null hypothesis probability of 4.8636e-01 with 6 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.132460e+11     using 9 bins.
#
# Test statistic : Chi-Squared              1.132460e+11     using 9 bins.
#  Null hypothesis probability of 0.000000e+00 with 6 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 9.35903      8.04335      -3       1.44384       15.0665   3.31335e-05
# 5.71207      136157       -4       1.83407       14.6246   4.25216e-05
# 5.68624      10582.9      -5       1.78213       15.3273   4.24128e-05
# 5.68563      180.699      -6       1.79613       14.9480   4.25895e-05
# 5.68561      88.9122      -7       1.79299       15.0490   4.25529e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.5347E-11| -0.0000   0.0000   1.0000
#  1.0842E-01|  0.9998   0.0214   0.0000
#  4.1749E+02| -0.0214   0.9998  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.992e-01  -8.922e+00   3.827e-06
#   -8.922e+00   4.173e+02  -1.253e-04
#    3.827e-06  -1.253e-04   6.513e-11
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.79299      +/-  0.547030
#    2    2   bremss     kT         keV      15.0490      +/-  20.4279
#    3    2   bremss     norm                4.25529E-05  +/-  8.07055E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  5.6856     using 9 bins.
#
# Test statistic : Chi-Squared                  5.6856     using 9 bins.
#  Null hypothesis probability of 4.5931e-01 with 6 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              6.200629e+10     using 9 bins.
#
# Test statistic : Chi-Squared              6.200629e+10     using 9 bins.
#  Null hypothesis probability of 0.000000e+00 with 6 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 99.1718      5.10693      -3      0.204612       11.0768   7.41021e-06
# 24.9781      417564       -4       2.05762       40.0472   8.35414e-05
# 11.5361      109525       -5       1.58911       8.68920   8.47907e-05
# 7.2885       78958.9      -6       2.36336       4.10412   0.000131539
# 4.40674      39564.5      -7       1.99760       5.98612   0.000122814
# 4.30507      12684.5      -8       2.28989       4.53633   0.000143193
# 4.23723      8508.66      -9       2.07208       5.85326   0.000126415
# 4.10815      11038.6      -2       2.24818       4.89955   0.000140677
# 4.04951      4696.67      -3       2.12479       5.84326   0.000131468
# 4.02031      3451.28      -1       2.16651       5.53752   0.000135322
# 4.01485      1348.24      -2       2.20567       5.38994   0.000138019
# 4.01383      213.29       -1       2.19393       5.52042   0.000136973
# 4.0128       27.4989      -1       2.19721       5.45356   0.000137394
# 4.01275      92.9836       0       2.19764       5.44837   0.000137437
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  1.5756E-10| -0.0000   0.0000   1.0000
#  1.2671E-01|  0.9917   0.1289   0.0000
#  2.2203E+01| -0.1289   0.9917  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    4.936e-01  -2.822e+00   3.213e-05
#   -2.822e+00   2.184e+01  -2.151e-04
#    3.213e-05  -2.151e-04   2.421e-09
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    2.19764      +/-  0.702578
#    2    2   apec       kT         keV      5.44837      +/-  4.67293
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.37437E-04  +/-  4.92048E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  4.0128     using 9 bins.
#
# Test statistic : Chi-Squared                  4.0128     using 9 bins.
#  Null hypothesis probability of 6.7495e-01 with 6 degrees of freedom

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 2.217e-05 photons (1.5354e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
#plx = 0.5317
d_kpc = 8
F_x = 1.5354*10**-13

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 1.1753927108038658e+33
