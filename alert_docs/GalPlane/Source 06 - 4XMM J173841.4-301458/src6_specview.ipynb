# %%
# %load_ext wurlitzer
import glob
import os
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12,8]

Fit.statMethod = "chi"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4

# %%
spec_file = sorted(glob.glob("*grpspec.fits"))
spec = Spectrum(spec_file[0])

Plot.device="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.00001 0.001")
Plot("data")
# Out:
# ***Warning: Detected response matrix energy bin value = 0 (or neg).
#      XSPEC will instead use small finite value (response file will not be altered).
#
# 1 spectrum  in use
#
# Spectral Data File: 0886010801_M211grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  1.059e-03 +/- 4.008e-04 (35.9 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-6
#   Telescope: XMM Instrument: EMOS2  Channel Type: PI
#   Exposure Time: 2.133e+04 sec
#  Using fit statistic: chi
#  Using Background File                0886010801_M211spec_bkg.fits
#   Background Exposure Time: 2.133e+04 sec
#  Using Response (RMF) File            0886010801_M211spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0886010801_M211spec.arf

# %%
#spec.ignore("**-0.2 12.0-**")
AllModels.clear()
mo = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              9.010901e+11     using 6 bins.
#
# Test statistic : Chi-Squared              9.010901e+11     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 4.71022      0.0548044    -2       2.21703       2.27211   2.19565e-06
# 4.70674      78835.6      -1       1.15528       2.32888   2.18685e-06
# 4.69432      26722.5      -2       2.39522       1.98294   1.88180e-06
# 4.67039      19240.6      -1       1.39181       2.10653   1.86652e-06
# 4.66609      17702.2      -2       2.23699       1.99003   1.86284e-06
# 4.64732      17013.3      -1       1.50362       2.09198   1.86230e-06
# 4.64391      8230.79      -2       2.08551       2.04574   1.91182e-06
# 4.6336       7089.85      -1       1.55819       2.12070   1.91646e-06
# 4.6321       3834.65      -2       1.98081       2.09586   1.96702e-06
# 4.62626      3242.22      -1       1.58834       2.15148   1.97124e-06
# 4.62593      2031.17      -2       1.91064       2.13307   2.01147e-06
# 4.62241      1760.45      -1       1.60707       2.17562   2.01430e-06
# 4.61979      1236.21      -1       1.80848       2.16765   2.04271e-06
# 4.61869      1954.01      -1       1.65588       2.19167   2.05048e-06
# 4.61827      345.781      -2       1.77204       2.19722   2.08606e-06
# 4.6177       214.942      -1       1.65804       2.21426   2.08922e-06
# 4.61764      64.4031      -2       1.75102       2.21347   2.10907e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  3.8949E-13| -0.0000  -0.0000   1.0000
#  2.1419E+00| -0.4645  -0.8856  -0.0000
#  1.8342E+01|  0.8856  -0.4645  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.485e+01  -6.663e+00  -7.838e-06
#   -6.663e+00   5.637e+00   7.982e-06
#   -7.838e-06   7.982e-06   1.206e-11
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.75102      +/-  3.85314
#    2    2   bbody      kT         keV      2.21347      +/-  2.37420
#    3    2   bbody      norm                2.10907E-06  +/-  3.47244E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  4.6176     using 6 bins.
#
# Test statistic : Chi-Squared                  4.6176     using 6 bins.
#  Null hypothesis probability of 2.0203e-01 with 3 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              6.108265e+10     using 6 bins.
#
# Test statistic : Chi-Squared              6.108265e+10     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 7.56327      0.810588     -3       2.82795       38.0629   1.21931e-05
# 5.15266      74873.2      -4       5.37636       95.2119   3.24942e-05
# 4.62813      17692.5      -1       3.08483       194.495   3.42081e-05
# 4.60737      7908.55       0       3.10278       190.987   3.44598e-05
# 4.57762      7041.96       0       3.12208       180.206   3.46847e-05
# 4.57562      5240.83       0       3.14542       128.531   3.48524e-05
# 4.54757      4595.85       0       3.40262       177.970   3.49314e-05
# 4.53477      8212.99       1       3.40174       173.294   3.49622e-05
# 4.52067      7499.37       1       3.40121       167.424   3.49900e-05
# 4.50657      6595.47       1       3.40109       160.497   3.50139e-05
# 4.49468      5492.31       1       3.40146       153.194   3.50334e-05
# 4.48681      4266.82       1       3.40234       146.667   3.50483e-05
# 4.48271      3106.05       1       3.40368       141.737   3.50589e-05
# 4.48087      2186.28       1       3.40535       138.508   3.50662e-05
# 4.47999      1567.76       1       3.40724       136.567   3.50715e-05
# 4.47945      1196.61       1       3.40926       135.426   3.50755e-05
# 4.47896      986.115       0       3.42885       124.888   3.51128e-05
# 4.45651      1078.69       0       3.57545       128.991   3.53067e-05
# 4.45576      1495.38       1       3.57638       126.759   3.53117e-05
# 4.4555       1028.97       1       3.57748       125.677   3.53152e-05
# 4.45535      804.911       1       3.57866       125.153   3.53179e-05
# 4.45485      702.004       0       3.59013       120.592   3.53437e-05
# 4.44886      211.042       0       3.67534       125.851   3.55167e-05
# 4.44779      1644.08       1       3.67561       122.963   3.55222e-05
# 4.44755      1023.43       1       3.67613       121.680   3.55257e-05
# 4.44747      743.551       1       3.67676       121.130   3.55282e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.1250E-10| -0.0000  -0.0000   1.0000
#  6.2248E+00|  1.0000   0.0012   0.0000
#  1.2969E+07| -0.0012   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.434e+01  -1.533e+04  -1.014e-03
#   -1.533e+04   1.297e+07   8.829e-01
#   -1.014e-03   8.829e-01   6.035e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    3.67676      +/-  4.93401
#    2    2   bremss     kT         keV      121.130      +/-  3601.28
#    3    2   bremss     norm                3.55282E-05  +/-  2.45664E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  4.4475     using 6 bins.
#
# Test statistic : Chi-Squared                  4.4475     using 6 bins.
#  Null hypothesis probability of 2.1702e-01 with 3 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              1.556381e+10     using 6 bins.
#
# Test statistic : Chi-Squared              1.556381e+10     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
#  Due to zero model norms, the following fit parameters are temporarily frozen:1 2
# 15.825       12338.6      -3       1.00000       1.00000       0.00000
#  Due to zero model norms, the following fit parameters are temporarily frozen:1 2
# 15.825       12338.6      -3       1.00000       1.00000       0.00000
# ====================
#  Variances and Principal Axes
#                  5
#  2.5701E-10|  1.0000
# --------------------
#
# ============
#   Covariance Matrix
#         1
#    2.570e-10
# ------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  -1.00000
#    2    2   apec       kT         keV      1.00000      +/-  -1.00000
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                0.0          +/-  1.60314E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 15.8250     using 6 bins.
#
# Test statistic : Chi-Squared                 15.8250     using 6 bins.
#  Null hypothesis probability of 1.2316e-03 with 3 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              3.026131e+11     using 6 bins.
#
# Test statistic : Chi-Squared              3.026131e+11     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 4.65001      1.00309      -3       3.59861       1.14973   1.04594e-05
# 4.50818      44872        -3       2.88454      0.769638   6.09724e-06
# 4.46023      57146        -4       3.61334      0.967969   8.94537e-06
# 4.39251      28580.9      -2       2.99418      0.852201   7.62936e-06
# 4.39092      2856.59      -3       3.43923      0.923496   8.82153e-06
# 4.38551      4171.63      -2       3.10455      0.859068   7.81160e-06
# 4.38361      2643.64      -3       3.24571      0.859962   8.00100e-06
# 4.38284      26.1173      -2       3.12083      0.833375   7.60230e-06
# 4.38251      368.733      -3       3.15607      0.826292   7.56931e-06
# 4.38243      11.4874      -2       3.11794      0.817265   7.44462e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  5.0070E-12| -0.0000  -0.0000   1.0000
#  8.6070E-01|  0.3353  -0.9421  -0.0000
#  3.7388E+01|  0.9421   0.3353   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    3.328e+01   1.154e+01   1.466e-04
#    1.154e+01   4.968e+00   6.058e-05
#    1.466e-04   6.058e-05   7.490e-10
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    3.11794      +/-  5.76893
#    2    2   powerlaw   PhoIndex            0.817265     +/-  2.22896
#    3    2   powerlaw   norm                7.44462E-06  +/-  2.73683E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  4.3824     using 6 bins.
#
# Test statistic : Chi-Squared                  4.3824     using 6 bins.
#  Null hypothesis probability of 2.2302e-01 with 3 degrees of freedom

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 1.4723e-05 photons (1.4841e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
#plx = 1.4843
d_kpc = 8
F_x = 1.4841*10**-13

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 1.1361210903373824e+33

# %%
import numpy as np
print(np.log10(L_x))
# Out:
# 33.055424621923166

# %%
F_opt = 1.05*10**-5 * 10**(-0.4*20.7)
print('Optical Flux: ',F_opt)
print('F_x / F_opt: ', np.log10(F_x/F_opt))
# Out:
# Optical Flux:  5.510478332622621e-14
# F_x / F_opt:  0.4302738660139049
