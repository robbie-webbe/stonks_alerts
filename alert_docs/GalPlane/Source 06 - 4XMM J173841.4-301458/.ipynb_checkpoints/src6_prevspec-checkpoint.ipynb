# %%
# %load_ext wurlitzer
import glob
import os
import numpy as np
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12,8]

Fit.statMethod = "chi"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4
# Out:
# The wurlitzer extension is already loaded. To reload it, use:
#   %reload_ext wurlitzer
# Default fit statistic is set to: Chi-Squared
#    This will apply to all current and newly loaded spectra.
#
# Fit statistic  : Chi-Squared                  2.1964     using 6 bins.
#
# Test statistic : Chi-Squared                  2.1964     using 6 bins.
#  Null hypothesis probability of 5.3266e-01 with 3 degrees of freedom
#  Current data and model not fit yet.
# Parameter delta values for fits will now be 0.0001 * parValue

# %%
os.chdir('other_obs')
spec_files = sorted(glob.glob("*grpspec.fits"))
spec = Spectrum(spec_files[0])

Plot.device="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.00001 0.001")
Plot("data")
spec.ignore("**-0.2 12.0-**")
# Out:
# Warning: RMF FILTER keyword (UNDEFINED) is not consistent with that in spectrum (Thin1)
#
# 1 spectrum  in use
#
# Spectral Data File: 0561580101_MOS12grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  1.707e-03 +/- 3.264e-04 (50.4 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-7
#   Telescope: XMM Instrument: EPIC  Channel Type: PI
#   Exposure Time: 3.427e+04 sec
#  Using fit statistic: chi
#  Using Background File                0561580101_MOS12spec_bkg.fits
#   Background Exposure Time: 3.427e+04 sec
#  Using Response (RMF) File            0561580101_MOS12spec.rmf for Source 1
# ***Error: Requested ARF extension not found in 0561580101_MOS12spec.arf
#      1 channels (1) ignored in spectrum #     1
#       No channels ignored (no channels in specified range)

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              3.640306e+11     using 6 bins.
#
# Test statistic : Chi-Squared              3.640306e+11     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 25.1307      0.753942      0       1.90908       31.0461   3.87711e-06
# 15.2819      304931       -1       6.06153       199.120   1.60279e-05
# 6.29746      132850       -2       15.3565       199.306   4.75028e-05
# 3.46595      39072        -2       21.2247       199.339   8.15216e-05
# 3.21659      4167.45      -2       24.5747       199.352   0.000102900
# 3.06391      5938.05      -1       25.8800       199.361   0.000104238
# 3.03359      1344.82      -1       26.7087       199.362   0.000106332
# 3.02405      18.7189      -1       27.2156       199.363   0.000108293
# 3.02028      107.732      -1       27.5265       199.363   0.000109856
# 3.01924      135.198      -1       27.7223       199.363   0.000110998
# 3.01846      418.967       0       27.7739       199.363   0.000110968
# 3.01815      203.442       0       27.8105       199.363   0.000110997
# 3.01799      95.3831       0       27.8385       199.363   0.000111055
# 3.01788      43.7819       0       27.8615       199.363   0.000111125
# 3.01779      21.2372       0       27.8813       199.363   0.000111198
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  3.8457E-10| -0.0000  -0.0000   1.0000
#  8.6763E+01|  1.0000   0.0031   0.0000
#  4.9147E+07| -0.0031   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    5.545e+02  -1.516e+05  -1.969e-02
#   -1.516e+05   4.915e+07   6.499e+00
#   -1.969e-02   6.499e+00   8.612e-07
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    27.8813      +/-  23.5474
#    2    2   bremss     kT         keV      199.363      +/-  7010.45
#    3    2   bremss     norm                1.11198E-04  +/-  9.28024E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  3.0178     using 6 bins.
#
# Test statistic : Chi-Squared                  3.0178     using 6 bins.
#  Null hypothesis probability of 3.8889e-01 with 3 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              3.502470e+10     using 6 bins.
#
# Test statistic : Chi-Squared              3.502470e+10     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 34.8192      0.0817546    -3      0.191640       42.2442   2.37068e-07
# 34.4086      204530       -2       141.940       63.7276   5.20242e-05
# 33.1627      2236.56      -3       55.8592       63.9246   1.88555e-05
# 32.1992      16944.9      -4       12.3514       26.1062   5.12028e-06
# 7.63271      92367.2      -2       27.8935       48.1897   0.000146050
# 3.05356      17203.2      -2       28.5564       40.9064   0.000234306
# 3.04526      207.23       -1       28.4269       53.3241   0.000242444
# 3.04343      160.438      -2       28.7646       50.2954   0.000244195
# 3.04317      1.92035      -1       28.8040       51.4436   0.000245304
# 3.04315      20.257       -1       28.8587       50.8710   0.000245483
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  1.8780E-09| -0.0000  -0.0000   1.0000
#  8.7960E+01|  0.9999   0.0132   0.0000
#  2.4884E+06| -0.0132   0.9999   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    5.209e+02  -3.282e+04  -1.912e-02
#   -3.282e+04   2.488e+06   1.511e+00
#   -1.912e-02   1.511e+00   9.266e-07
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    28.8587      +/-  22.8236
#    2    2   apec       kT         keV      50.8710      +/-  1577.32
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                2.45483E-04  +/-  9.62591E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  3.0432     using 6 bins.
#
# Test statistic : Chi-Squared                  3.0432     using 6 bins.
#  Null hypothesis probability of 3.8502e-01 with 3 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.910874e+12     using 6 bins.
#
# Test statistic : Chi-Squared              1.910874e+12     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 6.73807      2.10084      -1       3.19100      0.189382   2.10557e-06
# 4.50318      432222       -2       5.37789     -0.296300   8.84891e-07
# 2.29441      2.1494e+06   -2       6.62222     -0.623134   7.52973e-07
# 2.23838      561342       -2       6.25128     -0.664124   6.63055e-07
# 2.22685      98801.1      -2       5.88176     -0.710566   6.05448e-07
# 2.22003      58250.5      -2       5.60434     -0.747204   5.63371e-07
# 2.21599      36918.9      -2       5.39760     -0.775682   5.32799e-07
# 2.21367      21067.7      -2       5.24472     -0.797457   5.10576e-07
# 2.21256      10763.5      -3       4.83848     -0.858072   4.49990e-07
# 2.21072      180667       -4       4.81256     -0.862561   4.49482e-07
# 2.21072      682.575      -5       4.82307     -0.861041   4.50822e-07
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  6.1399E-15| -0.0000  -0.0000   1.0000
#  4.1865E-01|  0.1212  -0.9926  -0.0000
#  9.7370E+01|  0.9926   0.1212   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    9.595e+01   1.167e+01   1.071e-05
#    1.167e+01   1.843e+00   1.619e-06
#    1.071e-05   1.619e-06   1.437e-12
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    4.82307      +/-  9.79515
#    2    2   powerlaw   PhoIndex            -0.861041    +/-  1.35775
#    3    2   powerlaw   norm                4.50822E-07  +/-  1.19878E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  2.2107     using 6 bins.
#
# Test statistic : Chi-Squared                  2.2107     using 6 bins.
#  Null hypothesis probability of 5.2984e-01 with 3 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              5.879490e+12     using 6 bins.
#
# Test statistic : Chi-Squared              5.879490e+12     using 6 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 5.97869      0.634682     -2       3.38021       4.38880   4.74651e-06
# 2.99712      445138       -2       7.29055       4.75517   8.64621e-06
# 2.37791      145949
# -2       7.94196       5.01242   1.13145e-05
# 2.32887      27436.4      -2       7.94304       5.28051   1.30725e-05
# 2.31029      8217.21      -2       7.78732       5.53104   1.45858e-05
# 2.29691      4228.31      -2       7.59704       5.76329   1.60190e-05
# 2.28615      2792.78      -2       7.41413       5.98068   1.74226e-05
# 2.2772       2128.96      -2       7.25102       6.18454   1.88116e-05
# 2.26964      1657.32      -2       7.10827       6.37703   2.01931e-05
# 2.26318      1324.31      -2       6.98390       6.55915   2.15655e-05
# 2.25761      1096.34      -2       6.87467       6.73222   2.29307e-05
# 2.25275      930.812      -2       6.77773       6.89736   2.42914e-05
# 2.24849      781.305      -2       6.69146       7.05488   2.56421e-05
# 2.24473      668.566      -2       6.61412       7.20529   2.69807e-05
# 2.24137      586.663      -2       6.54375       7.35010   2.83165e-05
# 2.23838      504.507      -2       6.47999       7.48884   2.96392e-05
# 2.23568      442.804      -2       6.42154       7.62258   3.09546e-05
# 2.23325      392.739      -2       6.36776       7.75158   3.22619e-05
# 2.23104      351.291      -2       6.31803       7.87618   3.35617e-05
# 2.22903      306.148      -2       6.27209       7.99635   3.48496e-05
# 2.22719      267.842      -2       6.22934       8.11277   3.61285e-05
# 2.22552      245.567      -2       6.18971       8.22492   3.73917e-05
# 2.22398      223.301      -2       6.15266       8.33355   3.86441e-05
# 2.22256      203.094      -2       6.11779       8.43921   3.98896e-05
# 2.22125      187.013      -2       6.08477       8.54235   4.11321e-05
# 2.22003      171.947      -2       6.05380       8.64238   4.23631e-05
# 2.21992      154.345      -3       5.83456       9.45891   5.25685e-05
# 2.21184      3197.82      -3       5.68681       10.1243   6.29583e-05
# 2.20629      2025.57      -3       5.57933       10.6856   7.28298e-05
# 2.20319      1154.84      -3       5.49643       11.1725   8.21444e-05
# 2.20131      692.292      -3       5.43014       11.6021   9.09563e-05
# 2.20005      443.176      -3       5.37711       11.9765   9.91226e-05
# 2.19917      288.838      -3       5.33324       12.3090   0.000106753
# 2.19852      201.832      -3       5.29526       12.6142   0.000114081
# 2.19802      148.112      -3       5.26292       12.8894   0.000120967
# 2.19763      111.394      -3       5.23589       13.1310   0.000127248
# 2.19734      79.1373      -3       5.21264       13.3478   0.000133054
# 2.1971       59.7766      -3       5.19182       13.5484   0.000138576
# 2.1969       48.0725      -3       5.17384       13.7278   0.000143649
# 2.19674      36.681       -3       5.15756       13.8948   0.000148476
# 2.19661      30.2409      -3       5.14260       14.0523   0.000153125
# 2.1965       24.9424      -3       5.12916       14.1976   0.000157501
# 2.1964       20.621       -3       5.11638       14.3389   0.000161832
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  7.5404E-10| -0.0000  -0.0000   1.0000
#  2.3469E+01|  0.9961   0.0882   0.0000
#  5.7722E+03| -0.0882   0.9961   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    6.821e+01  -5.052e+02  -1.517e-02
#   -5.052e+02   5.727e+03   1.739e-01
#   -1.517e-02   1.739e-01   5.285e-06
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    5.11638      +/-  8.25913
#    2    2   bbody      kT         keV      14.3389      +/-  75.6798
#    3    2   bbody      norm                1.61832E-04  +/-  2.29885E-03
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  2.1964     using 6 bins.
#
# Test statistic : Chi-Squared                  2.1964     using 6 bins.
#  Null hypothesis probability of 5.3266e-01 with 3 degrees of freedom

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 1.9904e-05 photons (2.6436e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
#plx = 1.4843
d_kpc = 8
F_x = 2.6436*10**-13

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 2.023751576319591e+33

# %%
F_opt = 1.05*10**-5 * 10**(-0.4*20.78)
print('Optical Flux: ',F_opt)
print('F_x / F_opt: ', F_x/F_opt)
# Out:
# Optical Flux:  5.119049146085544e-14
# F_x / F_opt:  5.16424031994598
