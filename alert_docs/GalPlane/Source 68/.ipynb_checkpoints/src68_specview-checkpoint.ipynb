# %%
# %load_ext wurlitzer
import glob
import os
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12,8]
os.chdir('pps/')

Fit.statMethod = "chi"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4

# %%
spec_fnames = glob.glob('P*PNS*SRSPEC*.FTZ')

spec = Spectrum(spec_fnames[0])
Plot.device="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.00002 0.02")
Plot("data")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: P0934201001PNS003SRSPEC0002.FTZ  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  1.834e-02 +/- 2.244e-03 (27.3 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-46
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 1.393e+04 sec
#  Using fit statistic: chi
#  Using Background File                P0934201001PNS003BGSPEC0002.FTZ
#   Background Exposure Time: 1.393e+04 sec
#  Using Response (RMF) File            epn_e3_ff20_sdY5.rmf for Source 1
#  Using Auxiliary Response (ARF) File  P0934201001PNS003SRCARF0002.FTZ

# %%
spec.ignore("**-0.2 12.0-**")
mo = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
#       No channels ignored (no channels in specified range)
#      1 channels (46) ignored in spectrum #     1
#
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              4.911365e+11     using 45 bins.
#
# Test statistic : Chi-Squared              4.911365e+11     using 45 bins.
#  Null hypothesis probability of 0.000000e+00 with 42 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 55.9801      1.52833      -1      0.219628       2.77429   7.36615e-06
# 47.817       455734       -1      0.260752       2.03339   5.72556e-06
# 46.3849      47710.6      -2      0.786369       1.32370   3.09663e-06
# 44.5666      977576       -3      0.749956       1.43328   3.87949e-06
# 44.5481      97643.9      -4      0.758088       1.43276   3.94675e-06
# 44.548       108.491      -5      0.751168       1.43476   3.94783e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  2.1471E-13| -0.0000  -0.0000   1.0000
#  3.5851E-02| -0.3147  -0.9492  -0.0000
#  4.1947E-01|  0.9492  -0.3147  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    3.815e-01  -1.146e-01  -6.813e-08
#   -1.146e-01   7.384e-02   1.439e-07
#   -6.813e-08   1.439e-07   6.135e-13
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.751168     +/-  0.617639
#    2    2   bbody      kT         keV      1.43476      +/-  0.271744
#    3    2   bbody      norm                3.94783E-06  +/-  7.83241E-07
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 44.5480     using 45 bins.
#
# Test statistic : Chi-Squared                 44.5480     using 45 bins.
#  Null hypothesis probability of 3.6503e-01 with 42 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.071043e+11     using 45 bins.
#
# Test statistic : Chi-Squared              1.071043e+11     using 45 bins.
#  Null hypothesis probability of 0.000000e+00 with 42 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 45.4199      1.92782      -3       1.96012       1.43130   4.59245e-05
# 43.192       76884        -4       2.07429       1.45680   5.81093e-05
# 43.1815      4332.54      -5       2.01750       1.43515   5.65024e-05
# 43.1812      129.019      -6       2.03674       1.44376   5.73370e-05
# 43.1812      44.6518      -7       2.03075       1.44106   5.70834e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  4.4484E-11| -0.0000  -0.0001   1.0000
#  5.7604E-02|  0.4580  -0.8890  -0.0001
#  1.1672E+00|  0.8890   0.4580   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    9.345e-01   4.517e-01   4.261e-05
#    4.517e-01   2.903e-01   2.557e-05
#    4.261e-05   2.557e-05   2.331e-09
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    2.03075      +/-  0.966681
#    2    2   powerlaw   PhoIndex            1.44106      +/-  0.538796
#    3    2   powerlaw   norm                5.70834E-05  +/-  4.82805E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 43.1812     using 45 bins.
#
# Test statistic : Chi-Squared                 43.1812     using 45 bins.
#  Null hypothesis probability of 4.2061e-01 with 42 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.897668e+10     using 45 bins.
#
# Test statistic : Chi-Squared              1.897668e+10     using 45 bins.
#  Null hypothesis probability of 0.000000e+00 with 42 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 50.6597      4.62605      -3       1.43948       20.5500   5.29234e-05
# 43.5097      89491.4      -4       2.05805       32.6496   8.47387e-05
# 43.22        14363.3      -5       1.83820       37.9791   8.74259e-05
# 43.2089      611.387      -6       1.92637       29.8696   8.62072e-05
# 43.2075      88.2539      -7       1.90080       33.1706   8.67904e-05
# 43.2074      104.815      -8       1.90859       32.7776   8.68377e-05
# 43.2074      0.0703862    -1       1.90728       32.8715   8.68437e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.0205E-10| -0.0000  -0.0000   1.0000
#  2.2760E-01|  1.0000   0.0066   0.0000
#  7.9077E+03| -0.0066   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    5.680e-01  -5.188e+01  -6.467e-06
#   -5.188e+01   7.907e+03   1.623e-03
#   -6.467e-06   1.623e-03   5.120e-10
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.90728      +/-  0.753680
#    2    2   bremss     kT         keV      32.8715      +/-  88.9236
#    3    2   bremss     norm                8.68437E-05  +/-  2.26265E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 43.2074     using 45 bins.
#
# Test statistic : Chi-Squared                 43.2074     using 45 bins.
#  Null hypothesis probability of 4.1951e-01 with 42 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              8.299321e+09     using 45 bins.
#
# Test statistic : Chi-Squared              8.299321e+09     using 45 bins.
#  Null hypothesis probability of 0.000000e+00 with 42 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 104.731      2.67368      -3       4.11885      0.938729   0.000145104
# 99.8356      12869.1      -4      0.780607       5.47335   2.28402e-05
# 65.2337      111601       -5       3.42268       42.6287   0.000157851
# 56.9992      35422        -6      0.925875       55.8957   0.000249865
# 49.11        34753        -2       1.44746       62.0534   0.000307385
# 45.4828      24854.4      -1       1.65345       63.1258   0.000299780
# 44.975       14131.4      -1       1.71393       63.6477   0.000299064
# 44.9455      11987.7      -1       1.72193       63.9108   0.000299585
# 44.2015      11854.2       0       1.77335       63.9587   0.000290482
# 43.9374      7463.28       0       1.79510       63.9956   0.000284822
# 43.8332      5062.61       0       1.80112       64.0000   0.000281198
# 43.7863      3719.23       0       1.80015       64.0000   0.000278795
# 43.7625      2933.14       0       1.79669       64.0000   0.000277155
# 43.7494      2452.09       0       1.79277       64.0000   0.000276010
# 43.7417      2144.96       0       1.78923       64.0000   0.000275195
# 43.7369      1941.27       0       1.78631       64.0000   0.000274609
# 43.7338      1801.91       0       1.78399       64.0000   0.000274183
# 43.7318      1704.26       0       1.78222       64.0000   0.000273872
# 43.7304      1634.64       0       1.78087       64.0000   0.000273644
# 43.7294      1584.4        0       1.77986       64.0000   0.000273476
# 43.7287      1547.85       0       1.77911       64.0000   0.000273352
# 43.7282      1521.11       0       1.77854       64.0000   0.000273261
# 43.7278      1501.48       0       1.77813       64.0000   0.000273194
# 43.7276      1487.04       0       1.77782       64.0000   0.000273144
# 43.7274      1476.39       0       1.77759       64.0000   0.000273108
# 43.7273      1468.54       0       1.77743       64.0000   0.000273081
# 43.7272      1462.75       0       1.77730       64.0000   0.000273061
# 43.7271      1458.47       0       1.77721       64.0000   0.000273046
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  9.8416E-10| -0.0001  -0.0000   1.0000
#  2.0680E-01|  1.0000   0.0010   0.0001
#  2.3303E+05| -0.0010   1.0000   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    4.195e-01  -2.227e+02  -7.911e-05
#   -2.227e+02   2.330e+05   9.535e-02
#   -7.911e-05   9.535e-02   4.070e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.77721      +/-  0.647726
#    2    2   apec       kT         keV      64.0000      +/-  482.729
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                2.73046E-04  +/-  2.01735E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 43.7271     using 45 bins.
#
# Test statistic : Chi-Squared                 43.7271     using 45 bins.
#  Null hypothesis probability of 3.9801e-01 with 42 degrees of freedom
