# %%
# %load_ext wurlitzer
import numpy as np
import glob
import os
import matplotlib.pyplot as plt
from astropy.io import fits
from xspec import *
plt.rcParams['figure.figsize'] = [9,6]

Fit.statMethod = "cstat"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4

# %%
#spec_file = sorted(glob.glob("*grpspec.fits"))
#spec = Spectrum(spec_file[0])

spec = Spectrum(glob.glob("*cash.fits")[0],backFile=glob.glob("*spec_bkg.fits")[0],respFile=glob.glob("*rmf")[0],arfFile=glob.glob("*.arf")[0])
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0934210201_M29spec_cash.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  3.890e-03 +/- 6.229e-04
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-406
#   Telescope: XMM Instrument: EMOS2  Channel Type: PI
#   Exposure Time: 1.003e+04 sec
#  Using fit statistic: cstat
#  No response loaded.
#
# ***Warning!  One or more spectra are missing responses,
#                and are not suitable for fit.
# Net count rate (cts/s) for Spectrum:1  2.755e-03 +/- 6.455e-04 (70.8 % total)
# ***Warning!  One or more spectra are missing responses,
#                and are not suitable for fit.
# ***Warning: Detected response matrix energy bin value = 0 (or neg).
#      XSPEC will instead use small finite value (response file will not be altered).
# Response successfully loaded.
# Arf successfully loaded.
# Spectrum 1  Spectral Data File: 0934210201_M29spec_cash.fits
# Net count rate (cts/s) for Spectrum:1  2.755e-03 +/- 6.455e-04 (70.8 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-406
#   Telescope: XMM Instrument: EMOS2  Channel Type: PI
#   Exposure Time: 1.003e+04 sec
#  Using fit statistic: cstat
#  Using Background File                0934210201_M29spec_bkg.fits
#   Background Exposure Time: 1.003e+04 sec
#  Using Response (RMF) File            0934210201_M29spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0934210201_M29spec.arf
#
#  Spectral data counts: 39
#  Model predicted rate: 0.0

# %%
Plot.device ="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.00001 0.05")
Plot.addCommand("Rescale X 0.1 15")
Plot("data")

# %%
#spec.ignore("**-0.2 12.0-**")
AllModels.clear()
mo1 = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : C-Statistic              5.872046e+06     using 406 bins.
#
# Test statistic : Chi-Squared              4.216929e+11     using 406 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 0.000000e+00 with 403 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 60.9616      1.2034e+06   -3      0.269628       199.166      0.304553
# 59.6061      7.20013      -3     0.0451533       197.709      0.314194
# 50.1579      7.32939      -4    0.00197017       54.6686     0.0328971
# 49.1843      112.654      -1   0.000101619       61.3030     0.0200041
# 48.098       96.5838      -2   3.87415e-05       58.3356     0.0190693
# 47.712       87.0249      -3   6.86864e-06       35.4733    0.00816057
# 45.9652      286.823       0   1.48768e-06       37.1182    0.00699949
# 45.965       12.5393       1   5.76389e-07       37.1162    0.0070
# 0021
# 45.9649      12.2919       1   1.20859e-07       37.1142    0.00700091
# 45.9647      12.0494       1   7.00369e-09       37.1123    0.00700159
# 45.9645      11.8118       1   3.44650e-09       37.1104    0.00700226
# 45.9644      11.5788       1   1.66837e-09       37.1085    0.00700290
# 45.9643      11.3494       1   7.79462e-10       37.1066    0.00700354
# 45.9641      11.1253       1   3.35050e-10       37.1048    0.00700415
# 45.964       10.9058       1   1.12963e-10       37.1030    0.00700476
# 45.9638      10.6894       1   1.93307e-12       37.1013    0.00700534
# 45.9637      10.4787       1   2.39235e-13       37.0995    0.00700591
# 45.9636      10.2719       1   3.21967e-14       37.0978    0.00700648
# 45.9633      10.0861       0   6.69515e-15       37.0910    0.00700636
# 45.9627      9.67396       0   9.79308e-17       37.0807    0.00700820
# 45.9627      8.50379      17   1.47539e-16       37.0807    0.00700820
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  2.4348E-06| -0.0000  -0.0006   1.0000
#  1.4434E+03|  1.0000   0.0009   0.0000
#  1.5686E+05|  0.0009  -1.0000  -0.0006
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.443e+03  -1.410e+02  -7.703e-02
#   -1.410e+02   1.569e+05   8.730e+01
#   -7.703e-02   8.730e+01   4.859e-02
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.47539E-16  +/-  37.9933
#    2    2   bbody      kT         keV      37.0807      +/-  396.059
#    3    2   bbody      norm                7.00820E-03  +/-  0.220423
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                 45.9627     using 406 bins.
#
# Test statistic : Chi-Squared                 37.9361     using 406 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 1.0000e+00 with 403 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic              3.407751e+06     using 406 bins.
#
# Test statistic : Chi-Squared              1.315818e+11     using 406 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 0.000000e+00 with 403 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 80.2712      860316       -1       11062.9       5.57260     0.0394026
# 80.2712      1.38091e-38  -2       999999.       9.36815     0.0138216
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  5.4146E+83| -0.0003  -0.0972   0.9953
#  7.7917E+89|  0.0203  -0.9951  -0.0972
#  2.9112E+98|  0.9998   0.0202   0.0023
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.910e+98   5.875e+96   6.558e+95
#    5.875e+96   1.186e+95   1.324e+94
#    6.558e+95   1.324e+94   1.478e+93
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    9.99999E+05  +/-  1.70588E+49
#    2    2   powerlaw   PhoIndex            9.36815      +/-  3.44400E+47
#    3    2   powerlaw   norm                1.38216E-02  +/-  3.84453E+46
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                 80.2712     using 406 bins.
#
# Test statistic : Chi-Squared                 30.8096     using 406 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 1.0000e+00 with 403 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic              1.404432e+06     using 406 bins.
#
# Test statistic : Chi-Squared              2.816975e+10     using 406 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 0.000000e+00 with 403 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        3:norm
#
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    4.030e+00  -4.777e+00   4.318e-04
#   -4.777e+00   9.209e+00  -6.744e-04
#    4.318e-04  -6.744e-04   5.747e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    4.07254      +/-  2.00738
#    2    2   apec       kT         keV      3.43047      +/-  3.03466
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                2.93019E-04  +/-  2.39726E-04
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                 36.1186     using 406 bins.
#
# Test statistic : Chi-Squared                 31.1943     using 406 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 1.0000e+00 with 403 degrees of freedom

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 2.6539e-05 photons (1.8748e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
plx = 0.2744
d_kpc = 1/plx
F_x = 1.6234*10**-13

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 2.5789255831167283e+32

# %%
import numpy as np
print(d_kpc)
print(np.log10(L_x))
# Out:
# 3.644314868804665
# 32.411438810417096

# %%
F_opt = 1.05*10**-5 * 10**(-0.4*19.88)
print('Optical Flux: ',F_opt)
print('F_x / F_opt: ', np.log10(F_x/F_opt))
# Out:
# Optical Flux:  1.1727064101695894e-13
# F_x / F_opt:  0.14123624256114856

# %%
AllModels.clear()
mo = Model("tbabs*(apec+apec)")
mo.apec.kT = 0.5
mo.apec_3.kT = 4.0
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic              1.027068e+06     using 406 bins.
#
# Test statistic : Chi-Squared              6.138429e+10     using 406 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 0.000000e+00 with 401 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                755265.8     using 406 bins.
#
# Test statistic : Chi-Squared              3.579364e+10     using 406 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 0.000000e+00 with 401 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                751361.6     using 406 bins.
#
# Test statistic : Chi-Squared              1.479999e+10     using 406 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 0.000000e+00 with 401 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        5:norm          6:kT        9:norm
# 344726       118837       -3      0.296796       52.3420     0.0557680       41.4625      0.451191
# 103444       98980.7      -4      0.124812       13.5236     0.0222862       61.2329      0.109695
# 29130.9      125380       -1       178.744       55.4261     0.0110265       63.3755       23.0874
# 3160.71      189.5         0       254.376       60.1413    0.00439556       63.8148       9.18582
# 245.636      49.4255       0       337.797       62.3405   0.000973958       63.9545       2.11322
# 137.333      12.7764       0       301.062       63.2117   0.000197595       63.9802      0.521012
# 101.015      20.0092       0       284.518       63.7673   3.96231e-05       63.9936      0.197495
# 86.1848      22.0927       0       275.930       63.9195   1.12013e-05       63.9976     0.0811055
# 84.6422      18.359        0       268.763       63.9826   2.09286e-06       63.9992     0.0624564
# 82.467       18.9545       0       259.542       63.9953   7.21589e-07       63.9999     0.0399895
# 80.5611      18.4086      -1       115.893       63.9984   1.84801e-07       64.0000    0.00481034
# 73.3035      221.597      -2       57.1225       63.9999   5.86157e-08       64.0000   0.000675479
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                 36.0010     using 406 bins.
#
# Test statistic : Chi-Squared                 30.8743     using 406 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 1.0000e+00 with 401 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*(apec+apec+apec)")
mo.apec.kT = 0.5
mo.apec_3.kT = 4.0
mo.apec_4.kT = 10.0
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>(apec<2> + apec<3> + apec<4>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
#   10    4   apec       kT         keV      1.00000      +/-  0.0
#   11    4   apec       Abundanc            1.00000      frozen
#   12    4   apec       Redshift            0.0          frozen
#   13    4   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic              1.540878e+06     using 406 bins.
#
# Test statistic : Chi-Squared              1.381148e+11     using 406 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 0.000000e+00 with 399 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic              1.269061e+06     using 406 bins.
#
# Test statistic : Chi-Squared              9.793056e+10     using 406 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 0.000000e+00 with 399 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic              1.265181e+06     using 406 bins.
#
# Test statistic : Chi-Squared              5.922630e+10     using 406 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 0.000000e+00 with 399 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic              1.299950e+06     using 406 bins.
#
# Test statistic : Chi-Squared              3.201472e+10     using 406 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 0.000000e+00 with 399 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# C-Statistic  |beta|/N    Lvl          1:nH          2:kT        5:norm          6:kT        9:norm         10:kT       13:norm
# 448489       104342       -2      0.342753      0.193402      0.344051       1.73045     0.0991251       37.4600      0.424551
# 55612.5      130271       -1     0.0992403     0.0151704     0.0928054       50.3309     0.0309883       63.8149     0.0406597
# 847.269      79578.4       0       23.0345    0.00818935     0.0388272       57.9811    0.00418233       63.9246     0.0126937
# ***Warning: Zero alpha-matrix diagonal element for parameter 2
# ***Warning: Zero alpha-matrix diagonal element for parameter 5
#  Parameter 2 is pegged at 0.00818935 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
#  Parameter 5 is pegged at 0.0388272 due to zero or negative pivot element, likely
#  caused by the fit being insensitive to the parameter.
# 615.263      7780.74       0       9.26593    0.00818935     0.038827
# 2       61.4531    0.00206920       63.9634    0.00404609
# 55.1188      16482        -1       2.07394    0.00818935     0.0388272       63.2353   0.000174651       63.9919   0.000221767
# 43.3906      20418.7      -2       3.46945    0.00818935     0.0388272       13.8068   7.84939e-05       25.0649   2.81250e-05
# 41.0642      23146.3      -1       2.85138    0.00818935     0.0388272       57.8956   8.77680e-05       5.61420   3.66702e-05
# 37.1494      18835.3      -1       3.00793    0.00818935     0.0388272       7.96544   0.000106221       8.00556   4.70727e-05
# 36.3938      7089.02      -2       3.12407    0.00818935     0.0388272       8.03464   0.000121264       8.16170   6.20955e-05
# 36.3404      1109.11      -3       3.23521    0.00818935     0.0388272       3.73893   0.000134252       44.0029   7.46200e-05
# 36.1035      2952.95      -1       3.51695    0.00818935     0.0388272       2.44197   0.000159599       60.0482   0.000105700
# 36.0372      1593.9       -1       3.74056    0.00818935     0.0388272       2.40164   0.000165157       29.4431   0.000103571
# 35.9824      1036.6       -2       3.87494    0.00818935     0.0388272       2.68386   0.000198453       34.9890   8.97561e-05
# 35.9557      82.8064       0       3.85637    0.00818935     0.0388272       2.67651   0.000200936       49.8034   9.09928e-05
# 35.9508      142.095      -1       3.90410    0.00818935     0.0388272       2.49367   0.000203881       45.4654   9.65942e-05
# 35.9501      65.0316       0       3.90146    0.00818935     0.0388272       2.51338   0.000205493       55.7064   9.78718e-05
# 35.9483      120.103       0       3.90837    0.00818935     0.0388272       2.50888   0.000205652       53.1591   9.81158e-05
# 35.9471      31.9749       0       3.91686    0.00818935     0.0388272       2.49579   0.000205394       48.7844   9.80223e-05
# 35.9457      16.6314      -1       3.94135    0.00818935     0.0388272       2.44251   0.000207028       50.3477   0.000100118
# 35.9452      22.465       -1       3.96140    0.00818935     0.0388272       2.39487   0.000208499       51.2916   0.000102150
# 35.9452      29.2425       0       3.96165    0.00818935     0.0388272       2.39550   0.000208523       51.2861   0.000102176
# 35.9452      16.6465       0       3.96160    0.00803468     0.0178335       2.39621   0.000208566       51.2543   0.000102209
# ================================================================================
#  Variances and Principal Axes
#                  1        2        5        6        9       10       13
#  1.3018E-09|  0.0000  -1.0000  -0.0000   0.0000   0.0000  -0.0000   0.0000
#  1.3018E-07|  0.0000   0.0000   0.0000   0.0000  -0.3766   0.0000   0.9264
#  9.3287E-07|  0.0000   0.0000   0.0000  -0.0000   0.9264   0.0000   0.3766
#  5.4641E+00|  1.0000   0.0000   0.0000   0.0000   0.0000   0.0000   0.0000
#  2.3807E+03|  0.0000   0.0000   0.0000   1.0000   0.0000   0.0002   0.0000
#  4.7736E+07|  0.0000   0.0000   0.0000   0.0002   0.0000  -1.0000   0.0000
#  4.0599E+95|  0.0000  -0.0000   1.0000   0.0000   0.0000   0.0000  -0.0000
# --------------------------------------------------------------------------------
#
# ====================================================================================
#   Covariance Matrix
#         1           2           3           4           5           6           7
#    5.464e+00   3.397e+33  -6.008e+40  -7.879e+00   3.772e-04  -5.531e+02   8.219e-05
#   -4.416e+33   1.295e+81  -2.293e+88   3.280e+34   2.313e+30   7.984e+36  -5.727e+28
#    7.823e+40  -2.293e+88   4.060e+95  -5.805e+41  -4.095e+37  -1.413e+44   1.010e+36
#   -7.879e+00  -1.577e+34   2.792e+41   4.028e+01   1.086e-03   4.127e+03  -1.139e-03
#    3.772e-04  -5.120e+29   9.067e+36   1.086e-03   1.818e-07   3.318e-01  -2.337e-08
#   -5.531e+02  -2.519e+36   4.461e+43   4.127e+03   3.318e-01   1.323e+06   9.048e-02
#    8.219e-05   1.630e+29  -2.889e+36  -1.139e-03  -2.337e-08   9.048e-02   1.025e-07
# ------------------------------------------------------------------------------------
#
# ========================================================================
# Model TBabs<1>(apec<2> + apec<3> + apec<4>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    3.96160      +/-  2.33753
#    2    2   apec       kT         keV      8.03468E-03  +/-  3.59905E+40
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.78335E-02  +/-  6.37172E+47
#    6    3   apec       kT         keV      2.39621      +/-  6.34667
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                2.08566E-04  +/-  4.26426E-04
#   10    4   apec       kT         keV      51.2543      +/-  1150.26
#   11    4   apec       Abundanc            1.00000      frozen
#   12    4   apec       Redshift            0.0          frozen
#   13    4   apec       norm                1.02209E-04  +/-  3.20091E-04
# ________________________________________________________________________
#
#
# Fit statistic  : C-Statistic                 35.9452     using 406 bins.
#
# Test statistic : Chi-Squared                 30.8583     using 406 bins.
#
# ***Warning: Chi-square may not be valid due to bins with zero variance
#             in spectrum number(s): 1
#
#  Null hypothesis probability of 1.0000e+00 with 399 degrees of freedom
