# %%
# %load_ext wurlitzer
import glob
import os
import numpy as np
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12,8]

Fit.statMethod = "chi"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4
os.chdir('other_obs')

# %%
spec = Spectrum('P0902780501M2S003SRSPEC008C.FTZ',backFile='P0902780501M2S003BGSPEC008C.FTZ')
spec.response.arf='P0902780501M2S003SRCARF008C.FTZ'

Plot.device="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.000001 0.0005")
Plot("data")
#spec.ignore("**-0.2 12.0-**")
# Out:
# ***Warning: Detected response matrix energy bin value = 0 (or neg).
#      XSPEC will instead use small finite value (response file will not be altered).
#
# 1 spectrum  in use
#
# Spectral Data File: P0902780501M2S003SRSPEC008C.FTZ  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  3.535e-04 +/- 8.534e-05 (40.7 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-5
#   Telescope: XMM Instrument: EMOS2  Channel Type: PI
#   Exposure Time: 1.197e+05 sec
#  Using fit statistic: chi
#  Using Background File                P0902780501M2S003BGSPEC008C.FTZ
#   Background Exposure Time: 1.197e+05 sec
#  Using Response (RMF) File            m2_e13_im_pall_o.rmf for Source 1
#  Using Auxiliary Response (ARF) File  P0902780501M2S003SRCARF008C.FTZ
#
# Net count rate (cts/s) for Spectrum:1  3.535e-04 +/- 8.534e-05 (40.7 % total)
# Spectrum 1  Spectral Data File: P0902780501M2S003SRSPEC008C.FTZ
# ...

# %%
AllModels.clear()
mo = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
# ...
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              5.279449e+12     using 5 bins.
#
# Test statistic : Chi-Squared              5.279449e+12     using 5 bins.
#  Null hypothesis probability of 0.000000e+00 with 2 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 4.72042      0.374111     -1    0.00899596       2.87113   1.40037e-06
# 3.58742      351747       -1      0.443953       2.42621   1.23505e-06
# 3.13282      133854       -1      0.496726       2.16473   9.83842e-07
# ...

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ...
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              3.032766e+11     using 5 bins.
#
# Test statistic : Chi-Squared              3.032766e+11     using 5 bins.
#  Null hypothesis probability of 0.000000e+00 with 2 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 1.92153      1.53115      -3       1.93323       14.4355   1.03103e-05
# 1.60552      71852.9      -2       2.59033       7.08467   1.32758e-05
# ...

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
# Out:
# ...
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              9.275061e+10     using 5 bins.
#
# Test statistic : Chi-Squared              9.275061e+10     using 5 bins.
#  Null hypothesis probability of 0.000000e+00 with 2 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# ...

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ...
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.583882e+12     using 5 bins.
#
# Test statistic : Chi-Squared              1.583882e+12     using 5 bins.
#  Null hypothesis probability of 0.000000e+00 with 2 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 2.08058      0.843048     -2       2.08978       1.37598   6.36787e-06
# 1.57227      157576       -2       2.48741       1.57423   9.49938e-06
# ...

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 6.161e-06 photons (4.7373e-14 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
#plx = 1.4843
d_kpc = 8
F_x = 4.7*10**-14

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 3.597984721100801e+32

# %%
F_opt = 1.05*10**-5 * 10**(-0.4*20.78)
print('Optical Flux: ',F_opt)
print('F_x / F_opt: ', F_x/F_opt)
# Out:
# Optical Flux:  5.119049146085544e-14
# F_x / F_opt:  0.9181392609981125
