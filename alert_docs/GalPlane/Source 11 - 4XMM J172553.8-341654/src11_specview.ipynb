# %%
# %load_ext wurlitzer
import glob
import os
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12,8]
os.chdir('pps/')

Fit.statMethod = "chi"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4

# %%
spec_fnames = glob.glob('P*PNS*SRSPEC*.FTZ')

spec = Spectrum(spec_fnames[0])
Plot.device="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.00001 0.01")
Plot("data")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: P0886040401PNS003SRSPEC000F.FTZ  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  1.351e-02 +/- 1.033e-03 (74.1 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-15
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 1.733e+04 sec
#  Using fit statistic: chi
#  Using Background File                P0886040401PNS003BGSPEC000F.FTZ
#   Background Exposure Time: 1.733e+04 sec
#  Using Response (RMF) File            epn_e3_ff20_sdY7.rmf for Source 1
#  Using Auxiliary Response (ARF) File  P0886040401PNS003SRCARF000F.FTZ

# %%
spec.ignore("**-0.2 12.0-**")
mo = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
#       No channels ignored (no channels in specified range)
#      1 channels (15) ignored in spectrum #     1
#
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared              2.028011e+12     using 14 bins.
#
# Test statistic : Chi-Squared              2.028011e+12     using 14 bins.
#  Null hypothesis probability of 0.000000e+00 with 11 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 76.3536      3.33836      -3      0.162283       1.01570   6.35928e-07
# 21.5583      1.97785e+07  -4      0.705528       1.08065   1.80681e-06
# 20.2712      3.1077e+06   -5      0.226390       1.07095   1.79760e-06
# 16.2973      1.9862e+06   -6      0.439304       1.02603   1.82297e-06
# 16.2086      254528       -7      0.495956       1.01764   1.83564e-06
# 16.206       10944.8      -8      0.482099       1.02201   1.83245e-06
# 16.2057      41.4491      -9      0.486066       1.02108   1.83371e-06
# 16.2057      44.3677     -10      0.484942       1.02137   1.83339e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  2.0553E-14| -0.0000  -0.0000   1.0000
#  5.4885E-03| -0.3443  -0.9389  -0.0000
#  5.6025E-02|  0.9389  -0.3443   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    5.004e-02  -1.633e-02   8.217e-09
#   -1.633e-02   1.148e-02   7.599e-09
#    8.217e-09   7.599e-09   3.910e-14
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    0.484942     +/-  0.223687
#    2    2   bbody      kT         keV      1.02137      +/-  0.107136
#    3    2   bbody      norm                1.83339E-06  +/-  1.97742E-07
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 16.2057     using 14 bins.
#
# Test statistic : Chi-Squared                 16.2057     using 14 bins.
#  Null hypothesis probability of 1.3366e-01 with 11 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              4.548980e+11     using 14 bins.
#
# Test statistic : Chi-Squared              4.548980e+11     using 14 bins.
#  Null hypothesis probability of 0.000000e+00 with 11 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 21.6104      6.33395      -3       1.26946       1.69513   3.48330e-05
# 15.0578      252361       -4       1.35576       1.75868   4.68670e-05
# 14.9808      24540        -5       1.33906       1.74549   4.69923e-05
# 14.9807      280.121      -6       1.33985       1.74626   4.70301e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.3391E-11| -0.0000  -0.0000   1.0000
#  1.8289E-02|  0.6703  -0.7421  -0.0000
#  2.6505E-01|  0.7421   0.6703   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.542e-01   1.227e-01   8.380e-06
#    1.227e-01   1.292e-01   8.096e-06
#    8.380e-06   8.096e-06   5.334e-10
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.33985      +/-  0.392637
#    2    2   powerlaw   PhoIndex            1.74626      +/-  0.359404
#    3    2   powerlaw   norm                4.70301E-05  +/-  2.30944E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 14.9807     using 14 bins.
#
# Test statistic : Chi-Squared                 14.9807     using 14 bins.
#  Null hypothesis probability of 1.8338e-01 with 11 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              7.636098e+10     using 14 bins.
#
# Test statistic : Chi-Squared              7.636098e+10     using 14 bins.
#  Null hypothesis probability of 0.000000e+00 with 11 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 15.0643      3.31938      -3       1.12369       9.78690   4.59243e-05
# 14.8533      32437.5      -4       1.20500       8.53400   4.92105e-05
# 14.8469      6447.71      -5       1.20367       8.70176   4.93507e-05
# 14.8468      82.4053      -6       1.20486       8.67065   4.93984e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.4766E-11| -0.0000   0.0000   1.0000
#  3.6530E-02|  0.9994   0.0356   0.0000
#  4.5346E+01| -0.0356   0.9994  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    9.403e-02  -1.613e+00   2.901e-06
#   -1.613e+00   4.529e+01  -6.169e-05
#    2.901e-06  -6.169e-05   1.123e-10
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.20486      +/-  0.306640
#    2    2   bremss     kT         keV      8.67065      +/-  6.72970
#    3    2   bremss     norm                4.93984E-05  +/-  1.05986E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 14.8468     using 14 bins.
#
# Test statistic : Chi-Squared                 14.8468     using 14 bins.
#  Null hypothesis probability of 1.8962e-01 with 11 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              2.770590e+10     using 14 bins.
#
# Test statistic : Chi-Squared              2.770590e+10     using 14 bins.
#  Null hypothesis probability of 0.000000e+00 with 11 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 114.645      18.0919      -3       2.48458      0.775877   0.000157364
# 66.9692      52829.6      -1       2.47970       1.87571   0.000143632
# 46.1356      86246.9      -1      0.954744       3.74014   0.000150705
# 18.7217      129262       -2       1.01555       6.14306   0.000119119
# 15.1069      10590.4      -3       1.12802       8.87611   0.000126663
# 14.9518      5014.87      -4       1.24422       7.39114   0.000134505
# 14.9314      2996.14      -5       1.23641       7.79985   0.000134570
# 14.9314      118.301      -6       1.23587       7.82358   0.000134557
# ========================================
#  Variances and Principal Axes
#                  1        2        5
#  1.0990E-10| -0.0001   0.0000   1.0000
#  3.6517E-02|  0.9988   0.0486   0.0001
#  3.7223E+01| -0.0486   0.9988  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    1.243e-01  -1.805e+00   8.284e-06
#   -1.805e+00   3.713e+01  -1.308e-04
#    8.284e-06  -1.308e-04   6.721e-10
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.23587      +/-  0.352576
#    2    2   apec       kT         keV      7.82358      +/-  6.09383
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.34557E-04  +/-  2.59258E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 14.9314     using 14 bins.
#
# Test statistic : Chi-Squared                 14.9314     using 14 bins.
#  Null hypothesis probability of 1.8566e-01 with 11 degrees of freedom
