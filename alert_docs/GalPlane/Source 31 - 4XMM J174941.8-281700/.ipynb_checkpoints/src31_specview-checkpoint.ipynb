# %%
# %load_ext wurlitzer
import glob
import os
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12,8]

Fit.statMethod = "chi"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4

# %%
spec_fnames = glob.glob('*grpspec*')

spec = Spectrum(spec_fnames[0])
Plot.device="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.000001 0.005")
Plot("data")
#spec.ignore("**-0.2 12.0-**")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0886080701_PN53grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  3.805e-03 +/- 6.150e-04 (41.7 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-12
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 2.64e+04 sec
#  Using fit statistic: chi
#  Using Background File                0886080701_PN53spec_bkg.fits
#   Background Exposure Time: 2.64e+04 sec
#  Using Response (RMF) File            0886080701_PN53spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0886080701_PN53spec.arf

# %%
AllModels.clear()
mo = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# Fit statistic  : Chi-Squared
#               1.094847e+12     using 12 bins.
#
# Test statistic : Chi-Squared              1.094847e+12     using 12 bins.
#  Null hypothesis probability of 0.000000e+00 with 9 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 36.0189      0.271122     -3       4.31029      0.986930   1.75725e-06
# 34.5912      510519       -4       3.85357       1.31844   1.64294e-06
# 34.2088      403248       -5       5.22922       1.21855   1.97463e-06
# 34.2         49445.3      -6       5.10746       1.25869   2.01253e-06
# 34.1995      4435.47      -7       5.21046       1.24207   2.01857e-06
# 34.1994      685.44       -8       5.17745       1.24836   2.01845e-06
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.7595E-13| -0.0000  -0.0000   1.0000
#  1.2243E-01| -0.1073  -0.9942  -0.0000
#  2.0643E+01|  0.9942  -0.1073   0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.041e+01  -2.190e+00   1.938e-06
#   -2.190e+00   3.589e-01  -8.811e-08
#    1.938e-06  -8.811e-08   4.759e-13
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    5.17745      +/-  4.51739
#    2    2   bbody      kT         keV      1.24836      +/-  0.599051
#    3    2   bbody      norm                2.01845E-06  +/-  6.89852E-07
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 34.1994     using 12 bins.
#
# Test statistic : Chi-Squared                 34.1994     using 12 bins.
#  Null hypothesis probability of 8.2411e-05 with 9 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              9.778152e+10     using 12 bins.
#
# Test statistic : Chi-Squared              9.778152e+10     using 12 bins.
#  Null hypothesis probability of 0.000000e+00 with 9 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 47.4711      1.2273        0       1.50202       32.8006   8.08405e-06
# 38.9896      136236       -1       5.43192       19.4627   2.56070e-05
# 35.8499      71264.4      -2       9.05413       8.83273   5.50487e-05
# 35.0467      20073        -2       8.01447       3.96194   8.09031e-05
# 34.5603      11773.7      -3       7.79935       5.19832   7.27575e-05
# 34.4978      5445.18      -4       8.17972       4.57302   8.48756e-05
# 34.4858      1907.74      -5       8.13763       4.78802   8.36620e-05
# 34.4857      127.906      -6       8.19268       4.68887   8.53611e-05
# 34.4856      48.68        -7       8.18401       4.71773   8.49835e-05
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  3.1881E-10| -0.0000   0.0000   1.0000
#  6.2791E+00|  0.8459   0.5333   0.0000
#  8.1844E+01| -0.5333   0.8459  -0.0000
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    2.777e+01  -3.409e+01   6.475e-04
#   -3.409e+01   6.036e+01  -1.020e-03
#    6.475e-04  -1.020e-03   1.817e-08
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    8.18401      +/-  5.26954
#    2    2   bremss     kT         keV      4.71773      +/-  7.76888
#    3    2   bremss     norm                8.49835E-05  +/-  1.34783E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 34.4856     using 12 bins.
#
# Test statistic : Chi-Squared                 34.4856     using 12 bins.
#  Null hypothesis probability of 7.3402e-05 with 9 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              4.278867e+11     using 12 bins.
#
# Test statistic : Chi-Squared              4.278867e+11     using 12 bins.
#  Null hypothesis probability of 0.000000e+00 with 9 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 40.7045      1.94333      -3       2.37468      0.109834   4.10562e-06
# 37.8587      765158       -2       4.33924      0.912809   8.67269e-06
# 35.8997      174570       -1       4.03411      0.923528   1.19751e-05
# 35.7406      11826.6      -1       4.41722      0.999454   1.38180e-05
# 35.608       14560.6      -1       4.62647       1.07408   1.57798e-05
# 35.4952      11406.5      -1       4.82561       1.14273   1.78311e-05
# 35.3985      9021.1       -1       5.01220       1.20635   1.99602e-05
# 35.3151      7233.82      -1       5.18749       1.26548   2.21584e-05
# 35.2428      5880.55      -1       5.35248       1.32061   2.44177e-05
# 35.1798      4839.65      -1       5.50805       1.37212   2.67301e-05
# 35.1246      4027.25      -1       5.65497       1.42036   2.90883e-05
# 35.076       3384.76      -1       5.79396       1.46564   3.14854e-05
# 35.0332      2870.55      -1       5.92561       1.50820   3.39148e-05
# 34.9952      2454.52      -1       6.05048       1.54829   3.63701e-05
# 34.9939      2114.57      -2       6.93426       1.83926   5.44674e-05
# 34.7883      12038.4      -2       7.52193       2.01145   7.61652e-05
# 34.6872      5672.77      -2       7.92398       2.12605   9.59154e-05
# 34.6533      2252.51      -2       8.22288       2.20953   0.000112445
# 34.6393      981.116      -2       8.44941       2.27157   0.000126038
# 34.6325      476.412      -2       8.62203       2.31814   0.000137090
# 34.6288      250.744      -2       8.75408       2.35334   0.000145988
# 34.6281      140.043      -3       9.09015       2.45130   0.000170653
# 34.624       564.479      -4       9.17895       2.46727   0.000178070
# 34.624       35.3558      -5       9.19360       2.46859   0.000178794
# ========================================
#  Variances and Principal Axes
#                  1        2        3
#  1.3966E-09| -0.0000  -0.0002   1.0000
#  6.3281E-01|  0.2485  -0.9686  -0.0002
#  5.1332E+01|  0.9686   0.2485   0.0001
# ----------------------------------------
#
# ====================================
#   Covariance Matrix
#         1           2           3
#    4.820e+01   1.221e+01   3.795e-03
#    1.221e+01   3.764e+00   1.124e-03
#    3.795e-03   1.124e-03   3.396e-07
# ------------------------------------
#
# ========================================================================
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    9.19360      +/-  6.94263
#    2    2   powerlaw   PhoIndex            2.46859      +/-  1.94022
#    3    2   powerlaw   norm                1.78794E-04  +/-  5.82748E-04
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 34.6240     using 12 bins.
#
# Test statistic : Chi-Squared                 34.6240     using 12 bins.
#  Null hypothesis probability of 6.9401e-05 with 9 degrees of freedom

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
# Out:
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              3.855343e+10     using 12 bins.
#
# Test statistic : Chi-Squared              3.855343e+10     using 12 bins.
#  Null hypothesis probability of 0.000000e+00 with 9 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
#  Due to zero model norms, the following fit parameters are temporarily frozen:1 2
# 57.3662      238.78       -3       1.00000       1.00000       0.00000
#  Due to zero model norms, the following fit parameters are temporarily frozen:1 2
# 57.3662      238.78       -3       1.00000       1.00000       0.00000
# ====================
#  Variances and Principal Axes
#                  5
#  1.0375E-10|  1.0000
# --------------------
#
# ============
#   Covariance Matrix
#         1
#    1.038e-10
# ------------
#
# ========================================================================
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  -1.00000
#    2    2   apec       kT         keV      1.00000      +/-  -1.00000
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                0.0          +/-  1.01859E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 57.3662     using 12 bins.
#
# Test statistic : Chi-Squared                 57.3662     using 12 bins.
#  Null hypothesis probability of 4.2997e-09 with 9 degrees of freedom

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux         0 photons (0 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
#plx = 2.3643
d_kpc = 8
F_x = 1.5839*10**-13

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 1.21252085101097e+33
