# %%
# %load_ext wurlitzer
import glob
import os
import numpy as np
from xspec import *
from stingray import Lightcurve
from astropy.io import fits
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12,8]

Fit.statMethod = "chi"
Fit.nIterations = 100000
Fit.delta = 1e-4
Fit.criticalDelta = 1e-4
os.chdir('other_obs')

# %%
spec_files = sorted(glob.glob("*grpspec.fits"))
spec = Spectrum('P0410580401M1S002SRSPEC0006.FTZ',backFile='P0410580401M1S002BGSPEC0006.FTZ')
spec.response.arf = 'P0410580501M1S002SRCARF0004.FTZ'

Plot.device="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.00001 0.005")
Plot("data")
#spec.ignore("**-0.2 12.0-**")
# Out:
# ***Warning: Detected response matrix energy bin value = 0 (or neg).
#      XSPEC will instead use small finite value (response file will not be altered).
# ...
#
# 1 spectrum  in use
#
# Spectral Data File: P0410580401M1S002SRSPEC0006.FTZ  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  1.768e-03 +/- 4.136e-04 (32.4 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-8
#   Telescope: XMM Instrument: EMOS1  Channel Type: PI
#   Exposure Time: 3.21e+04 sec
#  Using fit statistic: chi
#  Using Background File                P0410580401M1S002BGSPEC0006.FTZ
#   Background Exposure Time: 3.21e+04 sec
#  Using Response (RMF) File            m1_e9_im_pall_o.rmf for Source 1
#  Using Auxiliary Response (ARF) File  P0410580401M1S002SRCARF0006.FTZ
#
# Net count rate (cts/s) for Spectrum:1  1.768e-03 +/- 4.136e-04 (32.4 % total)
# Spectrum 1  Spectral Data File: P0410580401M1S002SRSPEC0006.FTZ
# ...

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ...
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#
# ...

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ...
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.600221e+11     using 8 bins.
#
# Test statistic : Chi-Squared              1.600221e+11     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 5 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
#  Due to zero model norms, the following fit parameters are temporarily frozen:1 2
# 62.7513      505068       -3       1.00000       7.00000       0.00000
# ...

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
# Out:
# ...
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              5.056709e+10     using 8 bins.
#
# Test statistic : Chi-Squared              5.056709e+10     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 5 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# ...

# %%
AllModels.clear()
mo = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
# ...
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.522216e+12     using 8 bins.
#
# Test statistic : Chi-Squared              1.522216e+12     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 5 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 42.0523      1.36075      -2       13.8583       1.37459   1.61490e-06
# 33.7072      1.60244e+06   0       11.0474       1.40249   2.71986e-06
# 31.7919      593268        0       12.9450       1.46136   3.21942e-06
# ...

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 1.3519e-05 photons (1.1292e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
AllData.clear()
AllModels.clear()
spec = Spectrum(spec_files[0])

Plot.device="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.00005 0.01")
Plot("data")
spec.ignore("**-0.2 12.0-**")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0784860101_PN4grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  1.158e-02 +/- 6.582e-04 (33.4 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-60
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 8.83e+04 sec
#  Using fit statistic: chi
#  Using Background File                0784860101_PN4spec_bkg.fits
#   Background Exposure Time: 8.83e+04 sec
#  Using Response (RMF) File            0784860101_PN4spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0784860101_PN4spec.arf
#      1 channels (1) ignored in spectrum #     1
#      3 channels (58-60) ignored in spectrum #     1

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ...
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.375378e+12     using 56 bins.
#
# Test statistic : Chi-Squared              1.375378e+12     using 56 bins.
#  Null hypothesis probability of 0.000000e+00 with 53 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 98.7224      35.4961      -1       1.98117      0.380135   1.00622e-05
# 82.4216      1.24033e+06  -2       3.58446      0.635349   1.47255e-05
# ...

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ...
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              3.005593e+11     using 56 bins.
#
# Test statistic : Chi-Squared              3.005593e+11     using 56 bins.
#  Null hypothesis probability of 0.000000e+00 with 53 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 294.328      16.2761       0       1.39114       32.6420   1.72776e-05
# 171.828      965528       -1       3.75547       199.321   5.94064e-05
# ...

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
# Out:
# ...
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.229053e+11     using 56 bins.
#
# Test statistic : Chi-Squared              1.229053e+11     using 56 bins.
#  Null hypothesis probability of 0.000000e+00 with 53 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
# 428.543      1.51895      -3       3.82127       1.21350   2.37350e-05
# ...

# %%
AllModels.clear()
mo = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
# ...
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              4.468604e+12     using 56 bins.
#
# Test statistic : Chi-Squared              4.468604e+12     using 56 bins.
#  Null hypothesis probability of 0.000000e+00 with 53 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 86.8889      2.50355      -2       2.46432       1.95847   4.18843e-06
# 72.3338      4.27505e+06  -3       3.91100       1.70194   4.85768e-06
# ...

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 3.2759e-05 photons (2.968e-13 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
AllData.clear()
AllModels.clear()
spec = Spectrum(spec_files[1])

Plot.device="/svg"
Plot.xAxis="keV"
Plot.xLog=True
Plot.yLog=True
Plot.addCommand("Rescale Y 0.000001 0.001")
Plot("data")
#spec.ignore("**-0.2 12.0-**")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: 0872392001_M259grpspec.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  6.733e-04 +/- 2.928e-04 (22.0 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-8
#   Telescope: XMM Instrument: EMOS2  Channel Type: PI
#   Exposure Time: 4.257e+04 sec
#  Using fit statistic: chi
#  Using Background File                0872392001_M259spec_bkg.fits
#   Background Exposure Time: 4.257e+04 sec
#  Using Response (RMF) File            0872392001_M259spec.rmf for Source 1
#  Using Auxiliary Response (ARF) File  0872392001_M259spec.arf

# %%
AllModels.clear()
mo = Model("tbabs*powerlaw")
Fit.perform()
Plot("data resid")
# Out:
# ...
# Model TBabs<1>*powerlaw<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   powerlaw   PhoIndex            1.00000      +/-  0.0
#    3    2   powerlaw   norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              5.624720e+11     using 8 bins.
#
# Test statistic : Chi-Squared              5.624720e+11     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 5 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH    2:PhoIndex        3:norm
# 9.97032      0.95263      -2       4.41038     -0.875617   5.46131e-07
# 9.53932      2.18535e+06  -3       1.32555     -0.283173   8.81155e-07
# ...

# %%
AllModels.clear()
mo = Model("tbabs*bremss")
Fit.perform()
Plot("data resid")
# Out:
# ...
# Model TBabs<1>*bremss<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bremss     kT         keV      7.00000      +/-  0.0
#    3    2   bremss     norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.133315e+11     using 8 bins.
#
# Test statistic : Chi-Squared              1.133315e+11     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 5 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 16.5016      0.332867      0       2.80847       62.6238   2.44818e-06
# 16.3505      128328       -1       36.9492       17.7960   1.77357e-05
# ...

# %%
AllModels.clear()
mo = Model("tbabs*apec")
Fit.perform()
Plot("data resid")
# Out:
# ...
# Model TBabs<1>*apec<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              2.239838e+10     using 8 bins.
#
# Test statistic : Chi-Squared              2.239838e+10     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 5 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm
#  Due to zero model norms, the following fit parameters are temporarily frozen:1 2
# ...

# %%
AllModels.clear()
mo = Model("tbabs*bbody")
Fit.perform()
Plot("data resid")
# Out:
# ...
# Model TBabs<1>*bbody<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   TBabs      nH         10^22    1.00000      +/-  0.0
#    2    2   bbody      kT         keV      3.00000      +/-  0.0
#    3    2   bbody      norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.693496e+12     using 8 bins.
#
# Test statistic : Chi-Squared              1.693496e+12     using 8 bins.
#  Null hypothesis probability of 0.000000e+00 with 5 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        3:norm
# 7.96271      0.262409     -2       6.72681       1.26466   9.59205e-07
# 7.57407      625322       -1       8.82684      0.832978   1.17154e-06
# 6.83296      597475
# -1       10.5418      0.782168   1.71919e-06
# ...

# %%
AllModels.calcFlux(".2 12.0")
# Out:
#  Model Flux 4.5319e-06 photons (2.6481e-14 ergs/cm^2/s) range (0.20000 - 12.000 keV)

# %%
#plx = 1.4843
d_kpc = 8
F_x = 3*10**-13

L_x = 4*3.14*F_x*(d_kpc*3.086*10**21)**2
print(L_x)
# Out:
# 2.2965859921920005e+33

# %%
F_opt = 1.05*10**-5 * 10**(-0.4*20.78)
print('Optical Flux: ',F_opt)
print('F_x / F_opt: ', F_x/F_opt)
# Out:
# Optical Flux:  5.119049146085544e-14
# F_x / F_opt:  5.860463368073059
